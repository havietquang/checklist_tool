# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `business_vault`;

CREATE OR REPLACE TABLE calendar (
    ref_holiday_hashkey string COMMENT 'Mã quốc gia và năm',
    msr_prd_id string COMMENT 'Năm',
    cdr_yr int COMMENT 'Năm trong dữ liệu',
    cdr_qtr int COMMENT 'Quý trong năm',
    day_of_wk int COMMENT 'Ngày trong tuần',
    msr_prd_dt date COMMENT 'Ngày dữ liệu',
    bsn_day_f int COMMENT 'Cờ ngày làm việc',
    pblc_hol_f int COMMENT 'Cờ ngày nghỉ lễ',
    last_bsn_day_f int COMMENT 'Cờ ngày làm việc cuối cùng',
    next_wk_id string COMMENT 'Mã tuần kế tiếp',
    last_wk_id string COMMENT 'Mã tuần trước',
    next_wk_dt date COMMENT 'Ngày của tuần kế tiếp',
    last_wk_dt date COMMENT 'Ngày của tuần trước',
    is_w_bom int COMMENT 'Cờ tuần đầu tháng',
    is_w_eom int COMMENT 'Cờ tuần cuối tháng',
    is_w_boy int COMMENT 'Cờ tuần đầu năm',
    is_w_eoy int COMMENT 'Cờ tuần cuối năm',
    source_event_date date COMMENT 'Ngày sự kiện nguồn',
    record_source string COMMENT 'Nguồn dữ liệu',
    load_timestamp timestamp COMMENT 'Thời điểm tải dữ liệu'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE bridge_account (
    account_hashkey string COMMENT 'Hashkey của Hub account',
    crb_hashkey string COMMENT 'Hashkey của Hub CRB',
    loans_hashkey string COMMENT 'Hashkey của Hub Loans (loans của tiết kiệm trả trước )',
    branch_hashkey string COMMENT 'Hashkey của Hub branch',
    customer_hashkey string COMMENT 'Hashkey của Hub customer',
    dept_acct_officer_hashkey string COMMENT 'Hashkey của Hub account officer',
    account_business_key string COMMENT 'Business Key của Hub account',
    crb_gl string COMMENT 'Business Key của Hub CRB',
    crb_tieukhoan string COMMENT 'Business Key của Hub CRB',
    loans_business_key string COMMENT 'Business Key của Hub Loans (loans của tiết kiệm trả trước )',
    branch_business_key string COMMENT 'Business Key của Hub branch',
    customer_business_key bigint COMMENT 'Business Key của Hub customer',
    dept_acct_officer_business_key string COMMENT 'Business Key của Hub account officer',
    snapshot_date date COMMENT 'Ngày dữ liệu'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE bridge_card (
    card_hashkey string COMMENT 'Hashkey của card trong hub_acnt_contract',
    account_contract_hashkey string COMMENT 'Hashkey của account contract trong hub_acnt_contract',
    client_hashkey string COMMENT 'Hashkey của hub_client',
    customer_hashkey string COMMENT 'Hashkey của hub_customer (T24)',
    branch_hashkey string COMMENT 'Hashkey của hub_branch',
    product_hashkey string COMMENT 'Hashkey của hub_product',
    card_business_key bigint COMMENT 'Business key của card trong hub_acnt_contract',
    account_contract_business_key bigint COMMENT 'Business key của account contract trong hub_acnt_contract',
    client_business_key bigint COMMENT 'Business key của hub_client',
    customer_business_key bigint COMMENT 'Business key của hub_customer (T24) - mã CIF',
    branch_business_key string COMMENT 'Business key của hub_branch',
    product_business_key bigint COMMENT 'Business key của hub_product',
    snapshot_date date COMMENT 'Ngày dữ liệu'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE bridge_doc (
    document_fin_hashkey string COMMENT 'Hashkey của hub giao dịch fin',
    document_auth_hashkey string COMMENT 'Hashkey của hub giao dịch auth',
    m_transaction_hashkey string COMMENT 'Hashkey của hub_m_transation',
    acnt_contract_hashkey string COMMENT 'Hashkey của hub_acnt_contract',
    client_hashkey string COMMENT 'Hashkey của hub_client',
    customer_hashkey string COMMENT 'Hashkey của hub_customer',
    document_business_key bigint COMMENT 'Business key của hub giao dịch',
    m_transaction_business_key bigint COMMENT 'Business key của hub_m_transation',
    acnt_contract_business_key bigint COMMENT 'Business key của hub_acnt_contract',
    client_business_key bigint COMMENT 'Business key của hub_client',
    customer_business_key bigint COMMENT 'Business key của hub_customer',
    snapshot_date date COMMENT 'Ngày dữ liệu'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE bridge_ft (
    funds_transfer_hashkey string COMMENT 'hashkey của ft',
    account_debit_hashkey string COMMENT 'hashkey của account debit',
    account_credit_hashkey string COMMENT 'hashkey của account credit',
    customer_debit_hashkey string COMMENT 'hashkey của customer debit',
    customer_credit_hashkey string COMMENT 'hashkey của customer credit',
    branch_hashkey string COMMENT 'hashkey của branch',
    clearing_citad_hashkey string COMMENT 'Hashkey của clearing citad',
    funds_transfer_business_key string COMMENT 'business key của ft',
    account_debit_business_key string COMMENT 'business key của account debit',
    account_credit_business_key string COMMENT 'business key của account credit',
    customer_debit_business_key bigint COMMENT 'business key của customer debit',
    customer_credit_business_key bigint COMMENT 'business key của customer credit',
    branch_business_key string COMMENT 'business key của branch',
    clearing_citad_business_key string COMMENT 'business key của clearing citad',
    snapshot_date date COMMENT 'Ngày dữ liệu'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE bridge_loan (
    crb_hashkey string COMMENT 'Hashkey của Hub CRB (Loans, OD)',
    acct_hashkey string COMMENT 'Hashkey của Hub account (thấu chi)',
    loans_hashkey string COMMENT 'Hashkey của Hub Loan',
    branch_hashkey string COMMENT 'Hashkey của Hub branch',
    customer_hashkey string COMMENT 'Hashkey của Hub customer',
    dept_acct_officer_hashkey string COMMENT 'Hashkey của Hub account officer (Mã cán bộ quản lý khoản vay )',
    saleid_hashkey string COMMENT 'Hashkey của Hub account officer (Mã sale được gán với khoản vay)',
    loans_payment_due_hashkey string COMMENT 'Hashkey của Hub loans payment due',
    loans_business_key string COMMENT 'Business key của Hub Loan',
    loans_payment_due_business_key string COMMENT 'Business key của Hub loans payment due',
    acct_business_key string COMMENT 'Business key của Hub account (thấu chi)',
    crb_gl string COMMENT 'Business key của Hub CRB (Loans, OD)',
    crb_tieukhoan string COMMENT 'Business key của Hub CRB (Loans, OD)',
    branch_business_key string COMMENT 'Business key của Hub branch',
    customer_business_key bigint COMMENT 'Business key của Hub customer',
    dept_acct_officer_business_key string COMMENT 'Business key của Hub account officer (Mã cán bộ quản lý khoản vay)',
    saleid_business_key string COMMENT 'Business key của Hub account officer (Mã sale được gán với khoản vay)',
    snapshot_date date COMMENT 'Ngày dữ liệu'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE pit_account (
    account_hashkey string COMMENT 'Tham chiếu Hub account',
    snapshot_date date COMMENT 'Ngày dữ liệu',
    sat_deposits_rate_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_deposits_information_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_deposits_terms_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_account_balance_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_account_information_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_account_classification_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE pit_acnt_contract (
    acnt_contract_hashkey string COMMENT 'Hashkey của hub_acnt_contract',
    snapshot_date date COMMENT 'Ngày dữ liệu',
    sat_acnt_contract_cs_status_log_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_acnt_contract_information_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_acnt_contract_other_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_acnt_contract_add_data_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_acnt_contract_type_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date'
) CLUSTER BY AUTO;


CREATE OR REPLACE TABLE pit_customer (
    customer_hashkey string COMMENT 'Hashkey của Customer',
    snapshot_date date COMMENT 'Ngày dữ liệu',
    sat_customer_information_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_customer_extra_information_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_customer_contact_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_customer_classification_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_customer_kyc_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_customer_financial_statement_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date',
    sat_cust_package_src_ev_dt date COMMENT 'LDTS của bản ghi Sat có hiệu lực tại Snapshot_Date'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE pit_loan (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    snapshot_date date COMMENT 'Ngày dữ liệu',
    sat_loans_information_src_ev_dt date COMMENT 'LDTS của bản ghi Sat loan infor có hiệu lực tại Snapshot_Date',
    sat_loans_classification_src_ev_dt date COMMENT 'LDTS của bản ghi Sat clas có hiệu lực tại Snapshot_Date',
    sat_loans_rate_src_ev_dt date COMMENT 'LDTS của bản ghi Sat loan rate có hiệu lực tại Snapshot_Date',
    sat_loans_terms_src_ev_dt date COMMENT 'LDTS của bản ghi Sat loan term có hiệu lực tại Snapshot_Date'
) CLUSTER BY AUTO;

CREATE OR REPLACE TABLE csat_crb_balance (
    crb_hashkey string NOT NULL COMMENT 'Hashkey Hub CRB',
    gl string COMMENT 'GL',
    tieukhoan string COMMENT 'Tiểu khoản',
    currency string COMMENT 'Loại tiền',
    ngoaite decimal(38,10) COMMENT 'Số tiền ngoại tệ',
    noite decimal(38,10) COMMENT 'Số tiền nội tệ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.'
) CLUSTER BY AUTO;
ALTER TABLE csat_crb_balance ADD CONSTRAINT csat_crb_balance_pk PRIMARY KEY (crb_hashkey);


CREATE OR REPLACE TABLE csat_customer_sum_balance (
    customer_hashkey string NOT NULL COMMENT 'Hashkey Hub Customer',
    so_du_tien_gui decimal(38,10) COMMENT 'Số dư tiền gửi của khách hàng',
    so_du_tien_vay decimal(38,10) COMMENT 'Số dư tiền vay của khách hàng',
    so_du_bao_lanh decimal(38,10) COMMENT 'Số dư bảo lãnh của khách hàng',
    so_du_lc decimal(38,10) COMMENT 'Số dư LC theo khách hàng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.'
) CLUSTER BY AUTO;
ALTER TABLE csat_customer_sum_balance ADD CONSTRAINT csat_customer_sum_balance_pk PRIMARY KEY (customer_hashkey);


CREATE OR REPLACE TABLE csat_loans_payment_due (
    loans_payment_due_hashkey string NOT NULL COMMENT 'Hashkey Hub Loans Payment Due',
    tot_pd_pr decimal(38,10) COMMENT 'Số tiền quá hạn gốc quy đổi',
    tot_pd_int decimal(38,10) COMMENT 'Số tiền quá hạn lãi',
    tot_pd_pe decimal(38,10) COMMENT 'Số tiền phạt quá hạn',
    tot_pd_ps decimal(38,10) COMMENT 'Số tiền phạt quá hạn',
    max_pd_pr_days int COMMENT 'Số ngày quá hạn gốc lớn nhất của Loan',
    max_pd_in_days int COMMENT 'Số ngày quá hạn lãi lớn nhất của Loan',
    max_pd_pe_days int COMMENT 'Số ngày quá hạn lãi phạt lớn nhất của Loan',
    max_pd_ps_days int COMMENT 'Số ngày quá hạn phí phạt lớn nhất của Loan',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.'
) CLUSTER BY AUTO;
ALTER TABLE csat_loans_payment_due ADD CONSTRAINT csat_loans_payment_due_pk PRIMARY KEY (loans_payment_due_hashkey);


CREATE OR REPLACE TABLE csat_loans_schedule (
    loans_hashkey string NOT NULL COMMENT 'Hashkey Hub Loans',
    t_k_date date COMMENT 'Ngày bắt đầu của lịch trả nợ',
    k_date_seq int COMMENT 'Thứ tự lịch ngày bắt đầu của lịch trả nợ',
    t_sch_type string COMMENT '"Loại kỳ trả nợ (P: Kỳ Trả gốc; I: Kỳ trả lãi. R: Kỳ thay đổi lãi suất, A: Trả cả gốc và lãi)"',
    t_frequency string COMMENT 'Tần suất kỳ trả nợ',
    t_number int COMMENT 'Số kỳ trả nợ',
    t_cycled_dates string COMMENT 'Các kỳ của lịch trả nợ',
    cycled_dates_seq int COMMENT 'Thứ tự các kỳ của lịch trả nợ',
    t_currency string COMMENT 'Loại tiền',
    t_amount decimal(38,10) COMMENT 'Số tiền phải trả cho từng kỳ trả nợ',
    t_date_time string COMMENT 'Ngày giờ cập nhật thông tin thay đổi lịch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.'
) CLUSTER BY AUTO;
ALTER TABLE csat_loans_schedule ADD CONSTRAINT csat_loans_schedule_pk PRIMARY KEY (loans_hashkey);
