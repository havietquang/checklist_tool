# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE hub_account (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    business_key string COMMENT 'Business Key: Mã tài khoản',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_account ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE hub_account ADD CONSTRAINT hub_account_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE hub_account_locked_events (
    ac_locked_events_hashkey string COMMENT 'Hub Hash Key Account Locked',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_account_locked_events ALTER COLUMN ac_locked_events_hashkey SET NOT NULL;
ALTER TABLE hub_account_locked_events ADD CONSTRAINT hub_account_locked_events_pk PRIMARY KEY (ac_locked_events_hashkey);



CREATE OR REPLACE TABLE hub_virtual_account (
    virtual_account_hashkey string COMMENT 'Hub Virtual Account',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_virtual_account ALTER COLUMN virtual_account_hashkey SET NOT NULL;
ALTER TABLE hub_virtual_account ADD CONSTRAINT hub_virtual_account_pk PRIMARY KEY (virtual_account_hashkey);



CREATE OR REPLACE TABLE sat_account_information (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_account_title_1 string COMMENT 'Tên tài khoản 1',
    t_account_title_2 string COMMENT 'Tên tài khoản 2',
    t_short_title string COMMENT 'Tên tài khoản rút ngắn',
    t_opening_date string COMMENT 'Ngày mở TK',
    t_create_date string COMMENT 'Ngày tạo',
    t_mature_date string COMMENT 'Ngày đáo hạn',
    t_value_date string COMMENT 'Ngày giá trị',
    t_acct_close_date string COMMENT 'Ngày đóng tài khoản',
    t_term_xau string COMMENT 'Kỳ hạn',
    t_posting_restrict string COMMENT 'Thuộc tính hạn chế tài khoản',
    t_record_status string COMMENT 'Tình trạng bản ghi',
    t_alt_acct_id string COMMENT 'Số TK cũ',
    t_joint_holder string COMMENT 'Đồng sở hữu',
    t_arrangement_id string COMMENT 'Mã số HĐ AA',
    t_source_of_fund string COMMENT 'Mã SOF',
    t_ocb_beauty_sts string COMMENT 'Kênh mở TK ngắn'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_information ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_information ADD CONSTRAINT sat_account_information_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_other (
    account_hashkey string COMMENT 'Tham chiếu Hub Tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_open_cleared_bal decimal(23,4) COMMENT 'Không dùng ',
    t_online_cleared_bal decimal(23,4) COMMENT 'Không dùng ',
    t_int_balance decimal(15,4) COMMENT 'Không dùng ',
    t_ref_officer string COMMENT 'Không dùng ',
    t_master_account string COMMENT 'Không dùng ',
    t_int_liqu_acct string COMMENT 'Không dùng ',
    t_accr_dr_amount string COMMENT 'Không dùng ',
    t_dpi_fin_date string COMMENT 'Không dùng ',
    t_tran_last_cr_cust string COMMENT 'Không dùng ',
    t_tran_last_dr_cust string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_account_other ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_other ADD CONSTRAINT sat_account_other_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_classification (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_category int COMMENT 'Mã phân loại category',
    t_sub_product string COMMENT 'Mã sản phẩm thấu chi TK',
    t_pl_cate string COMMENT 'Mã PL category liên quan đến thu nhập chi phí',
    t_cust_group string COMMENT 'Mã khối',
    t_condition_group int COMMENT 'Mã nhóm điều kiện lãi suất',
    t_limit_ref string COMMENT 'Mã hạn mức',
    t_cb_package_id string COMMENT 'Mã gói ưu đãi KHDN (Smart)'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_classification ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_classification ADD CONSTRAINT sat_account_classification_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_balance (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_interest_rate decimal(10,4) COMMENT 'Lãi suất',
    t_currency string COMMENT 'Đơn vị tiền tệ',
    t_open_actual_bal decimal(23,4) COMMENT 'Số dư đầu ngày',
    t_online_actual_bal decimal(23,4) COMMENT 'Số dư hiện tại',
    t_working_balance decimal(23,4) COMMENT 'Số dư khả dụng',
    t_locked_amount string COMMENT 'Số dư bị phong tỏa',
    t_date_last_cr_cust string COMMENT 'Ngày sau cùng KH thực hiện giao dịch ghi có',
    t_date_last_dr_cust string COMMENT 'Ngày sau cùng KH thực hiện giao dịch ghi nợ',
    t_amnt_last_cr_cust string COMMENT 'Số tiền sau cùng KH thực hiện giao dịch ghi có',
    t_amnt_last_dr_cust string COMMENT 'Số tiền sau cùng KH thực hiện giao dịch ghi nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_balance ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_balance ADD CONSTRAINT sat_account_balance_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_debit_int (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Ngay ap dung lai suat debit interest duoc cat tu ID sau dau gach ngang',
    t_charge_key string COMMENT 'Mã code phí',
    t_interest_day_basis string COMMENT 'Cơ sở tính lãi',
    t_dr_balance_type string COMMENT 'Cách tính số dư ghi nợ',
    t_dr_calcul_type string COMMENT 'Phương pháp tính lãi ghi nợ',
    t_dr_int_rate decimal(38,10) COMMENT 'Lãi suất ghi nợ',
    t_dr_margin_rate decimal(38,10) COMMENT 'Giá trị biên độ để điều chỉnh lãi suất',
    t_dr_basic_rate decimal(38,10) COMMENT 'Mức Lãi suất cơ bản ghi nợ',
    t_dr_margin_oper string COMMENT 'Phương pháp điều chỉnh lãi suất bằng biên độ'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_debit_int ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_debit_int ADD CONSTRAINT sat_account_debit_int_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_credit_int (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Ngay ap dung lai suat credit interest duoc cat tu ID sau dau gach ngang',
    t_interest_day_basic string COMMENT 'Cơ sở tính lãi',
    t_cr_balance_type string COMMENT 'Loại số dư tính lãi ghi có',
    t_cr_calcul_type string COMMENT 'Phương pháp tính lãi ghi có',
    t_cr_int_rate string COMMENT 'Lãi suất ghi có',
    t_cre_margin_rate string COMMENT 'Margin lãi suất',
    t_cr_minimum_bal decimal(38,10) COMMENT 'Số dư tối thiểu tính lãi ghi có'
    -- t_ref_officer string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_account_credit_int ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_credit_int ADD CONSTRAINT sat_account_credit_int_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_system (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày giờ cập nhật thông tin TK',
    t_date_last_update string COMMENT 'Ngày phát sinh giao dịch sau cùng',
    t_package_date string COMMENT 'Mã gói ưu đãi KHDN (Smart)',
    t_curr_no string COMMENT 'Số lần thay đổi',
    t_ocb_reason_rest string COMMENT 'Lý do hạn chế TK'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_system ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_account_system ADD CONSTRAINT sat_account_system_pk PRIMARY KEY (account_hashkey);



CREATE OR REPLACE TABLE sat_account_locked_events (
    ac_locked_events_hashkey string COMMENT 'Hub Hash Key Account Locked',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_account_number string COMMENT 'Số tài khoản',
    t_description string COMMENT 'Diễn giải',
    t_from_date string COMMENT 'Từ ngày',
    t_to_date string COMMENT 'Đến ngày',
    t_locked_amount decimal(38,10) COMMENT 'Số tiền phong tỏa',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày giờ thực hiện',
    t_block_reason string COMMENT 'Lý do phong tỏa'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_locked_events ALTER COLUMN ac_locked_events_hashkey SET NOT NULL;
ALTER TABLE sat_account_locked_events ADD CONSTRAINT sat_account_locked_events_pk PRIMARY KEY (ac_locked_events_hashkey);



CREATE OR REPLACE TABLE sat_virtual_account (
    virtual_account_hashkey string COMMENT 'Hub Virtual Account',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_va_id string COMMENT 'Prefix của ID TK định danh',
    t_sub_va_name string COMMENT 'Tên TK định danh',
    t_credit_acct_spa string COMMENT 'TK ghi có của TK định danh',
    t_sva_record_status string COMMENT 'Tình trạng bản ghi ( Duyệt/chờ duyệt)',
    t_sva_status string COMMENT 'Tình trạng ( Active/Inative_',
    t_date_time_input string COMMENT 'Ngày nhập',
    t_date_time_approval string COMMENT 'Ngày duyệt',
    t_sub_id string COMMENT 'ID phụ để phân biệt các TK định danh có cùng t_va_id'
) CLUSTER BY AUTO;
ALTER TABLE sat_virtual_account ALTER COLUMN virtual_account_hashkey SET NOT NULL;
ALTER TABLE sat_virtual_account ADD CONSTRAINT sat_virtual_account_pk PRIMARY KEY (virtual_account_hashkey);



CREATE OR REPLACE TABLE link_account_customer (
    link_account_customer_hashkey string COMMENT 'Link HK',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_customer ALTER COLUMN link_account_customer_hashkey SET NOT NULL;
ALTER TABLE link_account_customer ADD CONSTRAINT link_account_customer_pk PRIMARY KEY (link_account_customer_hashkey);



CREATE OR REPLACE TABLE link_account_branch (
    link_account_branch_hashkey string COMMENT 'Link HK',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_branch ALTER COLUMN link_account_branch_hashkey SET NOT NULL;
ALTER TABLE link_account_branch ADD CONSTRAINT link_account_branch_pk PRIMARY KEY (link_account_branch_hashkey);



CREATE OR REPLACE TABLE link_account_dept_acct_officer (
    link_account_dept_acct_officer_hashkey string COMMENT 'Link HK',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_dept_acct_officer ALTER COLUMN link_account_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_account_dept_acct_officer ADD CONSTRAINT link_account_dept_acct_officer_pk PRIMARY KEY (link_account_dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE link_account_limit (
    link_account_limit_hashkey string COMMENT 'Link HK',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    limit_hashkey string COMMENT 'Tham chiếu Hub Limit',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_limit ALTER COLUMN link_account_limit_hashkey SET NOT NULL;
ALTER TABLE link_account_limit ADD CONSTRAINT link_account_limit_pk PRIMARY KEY (link_account_limit_hashkey);



CREATE OR REPLACE TABLE link_virtual_account_account_t24 (
    link_virtual_account_account_t24_hashkey string COMMENT 'Link HK',
    virtual_account_hashkey string COMMENT 'Tham chiếu Hub Virtual Account',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_virtual_account_account_t24 ALTER COLUMN link_virtual_account_account_t24_hashkey SET NOT NULL;
ALTER TABLE link_virtual_account_account_t24 ADD CONSTRAINT link_virtual_account_account_t24_pk PRIMARY KEY (link_virtual_account_account_t24_hashkey);



CREATE OR REPLACE TABLE link_virtual_account_customer (
    link_virtual_account_customer_hashkey string COMMENT 'Link HK',
    virtual_account_hashkey string COMMENT 'Tham chiếu Hub Virtual Account',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_virtual_account_customer ALTER COLUMN link_virtual_account_customer_hashkey SET NOT NULL;
ALTER TABLE link_virtual_account_customer ADD CONSTRAINT link_virtual_account_customer_pk PRIMARY KEY (link_virtual_account_customer_hashkey);



CREATE OR REPLACE TABLE link_account_locked_events_account (
    link_account_locked_events_account_hashkey string COMMENT 'Link HK',
    ac_locked_events_hashkey string COMMENT 'Tham chiếu Hub Account Locked',
    account_hashkey string COMMENT 'Tham chiếu Hub Tài khoản',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_locked_events_account ALTER COLUMN link_account_locked_events_account_hashkey SET NOT NULL;
ALTER TABLE link_account_locked_events_account ADD CONSTRAINT link_account_locked_events_account_pk PRIMARY KEY (link_account_locked_events_account_hashkey);



CREATE OR REPLACE TABLE link_account_locked_events_branch (
    link_account_locked_events_branch_hashkey string COMMENT 'Link HK',
    ac_locked_events_hashkey string COMMENT 'Tham chiếu Hub Account Locked',
    branch_hashkey string COMMENT 'Tham chiếu Hub chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_locked_events_branch ALTER COLUMN link_account_locked_events_branch_hashkey SET NOT NULL;
ALTER TABLE link_account_locked_events_branch ADD CONSTRAINT link_account_locked_events_branch_pk PRIMARY KEY (link_account_locked_events_branch_hashkey);



CREATE OR REPLACE TABLE hub_categ_entry (
    categ_entry_hashkey string COMMENT 'Hash Key Categ Entry',
    business_key string COMMENT 'Business Key: mã bút toán',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_categ_entry ALTER COLUMN categ_entry_hashkey SET NOT NULL;
ALTER TABLE hub_categ_entry ADD CONSTRAINT hub_categ_entry_pk PRIMARY KEY (categ_entry_hashkey);



CREATE OR REPLACE TABLE hub_re_stat_line_bal (
    re_stat_line_bal_hashkey string COMMENT 'Hub Hashkey Re Stat Line Bal',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_re_stat_line_bal ALTER COLUMN re_stat_line_bal_hashkey SET NOT NULL;
ALTER TABLE hub_re_stat_line_bal ADD CONSTRAINT hub_re_stat_line_bal_pk PRIMARY KEY (re_stat_line_bal_hashkey);



CREATE OR REPLACE TABLE hub_pc_re_stat_line_bal (
    pc_re_stat_line_bal_hashkey string COMMENT 'Hub Hashkey Pc Re Stat Line Bal',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.'
) CLUSTER BY AUTO;
ALTER TABLE hub_pc_re_stat_line_bal ALTER COLUMN pc_re_stat_line_bal_hashkey SET NOT NULL;
ALTER TABLE hub_pc_re_stat_line_bal ADD CONSTRAINT hub_pc_re_stat_line_bal_pk PRIMARY KEY (pc_re_stat_line_bal_hashkey);



CREATE OR REPLACE TABLE hub_consolidate_profit_n_loss (
    consolidate_profit_n_loss_hashkey string COMMENT 'Hub Hashkey Consolidate Profit and Loss',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_consolidate_profit_n_loss ALTER COLUMN consolidate_profit_n_loss_hashkey SET NOT NULL;
ALTER TABLE hub_consolidate_profit_n_loss ADD CONSTRAINT hub_consolidate_profit_n_loss_pk PRIMARY KEY (consolidate_profit_n_loss_hashkey);



CREATE OR REPLACE TABLE hub_line_movement_toanhang (
    line_movement_toanhang_hashkey string COMMENT 'Hub Hashkey Line Movement Toanhang',
    t_line_id string COMMENT 'Mã dòng nguồn',
    t_stt string COMMENT 'Số thứ tự dòng nguồn',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_line_movement_toanhang ALTER COLUMN line_movement_toanhang_hashkey SET NOT NULL;
ALTER TABLE hub_line_movement_toanhang ADD CONSTRAINT hub_line_movement_toanhang_pk PRIMARY KEY (line_movement_toanhang_hashkey);



CREATE OR REPLACE TABLE hub_re_consol_spec_entry (
    re_consol_spec_entry_hashkey string COMMENT 'Hub Hashkey Re Consol Spec Entry',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_re_consol_spec_entry ALTER COLUMN re_consol_spec_entry_hashkey SET NOT NULL;
ALTER TABLE hub_re_consol_spec_entry ADD CONSTRAINT hub_re_consol_spec_entry_pk PRIMARY KEY (re_consol_spec_entry_hashkey);



CREATE OR REPLACE TABLE hub_stmt_entry (
    stmt_entry_hashkey string COMMENT 'Hub Hashkey Stmt Entry',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_stmt_entry ALTER COLUMN stmt_entry_hashkey SET NOT NULL;
ALTER TABLE hub_stmt_entry ADD CONSTRAINT hub_stmt_entry_pk PRIMARY KEY (stmt_entry_hashkey);



CREATE OR REPLACE TABLE sat_categ_entry_information (
    categ_entry_hashkey string COMMENT 'Hub Hash Key Categ Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_currency string COMMENT 'Loại tiền',
    t_amount_fcy decimal(38,10) COMMENT 'Số tiền ngoại tệ',
    t_amount_lcy decimal(38,10) COMMENT 'Số tiền nội tệ',
    t_value_date string COMMENT 'Ngày giá trị',
    t_narrative string COMMENT 'Nội dung',
    t_trans_reference string COMMENT 'Mã giao dịch',
    t_their_reference string COMMENT 'Số giao dịch',
    t_our_reference string COMMENT 'Số giao dịch',
    t_stmt_no string COMMENT 'Mã stmt'
) CLUSTER BY AUTO;
ALTER TABLE sat_categ_entry_information ALTER COLUMN categ_entry_hashkey SET NOT NULL;
ALTER TABLE sat_categ_entry_information ADD CONSTRAINT sat_categ_entry_information_pk PRIMARY KEY (categ_entry_hashkey);



CREATE OR REPLACE TABLE sat_categ_entry_classification (
    categ_entry_hashkey string COMMENT 'Hub Hash Key Categ Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_product_category bigint COMMENT 'Mã cate sản phẩm',
    t_pl_category bigint COMMENT 'Mã cate PL',
    t_crf_type string COMMENT 'Loại nợ có',
    t_system_id string COMMENT 'Loại Giao dịch',
    t_transaction_code bigint COMMENT 'Mã giao dịch',
    t_consol_key string COMMENT 'Khóa tổng hợp Sổ cái (GL)'
) CLUSTER BY AUTO;
ALTER TABLE sat_categ_entry_classification ALTER COLUMN categ_entry_hashkey SET NOT NULL;
ALTER TABLE sat_categ_entry_classification ADD CONSTRAINT sat_categ_entry_classification_pk PRIMARY KEY (categ_entry_hashkey);



CREATE OR REPLACE TABLE sat_categ_entry_audit (
    categ_entry_hashkey string COMMENT 'Hub Hash Key Categ Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'User nhập',
    t_authoriser string COMMENT 'Users duyệt',
    t_date_time string COMMENT 'Timestamp hệ thống ghi nhận chính xác đến phút/giây',
    t_pc_period_end string COMMENT 'Kỳ đóng sổ điều chỉnh',
    t_reversal_marker string COMMENT 'Cờ đánh dấu hủy/đảo',
    t_booking_date string COMMENT 'Ngày bút toán được ghi nhận vào hệ thống',
    t_accounting_date string COMMENT 'Ngày hạch toán sổ cái'
) CLUSTER BY AUTO;
ALTER TABLE sat_categ_entry_audit ALTER COLUMN categ_entry_hashkey SET NOT NULL;
ALTER TABLE sat_categ_entry_audit ADD CONSTRAINT sat_categ_entry_audit_pk PRIMARY KEY (categ_entry_hashkey);



CREATE OR REPLACE TABLE sat_pc_re_stat_line_bal (
    pc_re_stat_line_bal_hashkey string COMMENT 'Tham chieu Hub Pc Re Stat Line Bal',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_mvmt_a_split string COMMENT 'Khong dung',
    t_mvmt_p_split string COMMENT 'Khong dung',
    t_mvmt_r_split string COMMENT 'Khong dung',
    t_mvmt_id string COMMENT 'Khong dung',
    t_adj_mvmt_id string COMMENT 'Khong dung',
    t_open_bal decimal(38,10) COMMENT 'Số dư đầu ngày',
    t_open_bal_lcl decimal(38,10) COMMENT 'Số dư đầu ngày qui đổi',
    t_cr_movement decimal(38,10) COMMENT 'PS có ngày nguyên tệ',
    t_cr_mvmt_lcl bigint COMMENT 'PS có ngày qui đổi',
    t_db_movement decimal(38,10) COMMENT 'PS nợ ngày nguyên tệ',
    t_db_mvmt_lcl bigint COMMENT 'PS nợ ngày qui đổi',
    t_closing_bal decimal(38,10) COMMENT 'Du cuối nguyên tệ',
    t_closing_bal_lcl decimal(38,10) COMMENT 'Dư cuối qui đổi',
    t_cr_mvmt_ytd decimal(38,10) COMMENT 'PS có năm',
    t_cr_mvmt_mth decimal(38,10) COMMENT 'PS có năm qui đổi',
    t_cr_mvmt_ytd_lcl decimal(38,10) COMMENT 'PS nợ năm',
    t_cr_mvmt_mth_lcl bigint COMMENT 'PS nợ năm qui đổi',
    t_db_mvmt_ytd decimal(38,10) COMMENT 'PS có tháng',
    t_db_mvmt_mth decimal(38,10) COMMENT 'PS có tháng qui đổi',
    t_db_mvmt_ytd_lcl decimal(38,10) COMMENT 'PS nợ tháng',
    t_db_mvmt_mth_lcl bigint COMMENT 'PS nợ tháng qui đổi',
    t_pc_adjust_date string COMMENT 'Ngày điều chỉnh'
) CLUSTER BY AUTO;
ALTER TABLE sat_pc_re_stat_line_bal ALTER COLUMN pc_re_stat_line_bal_hashkey SET NOT NULL;
ALTER TABLE sat_pc_re_stat_line_bal ADD CONSTRAINT sat_pc_re_stat_line_bal_pk PRIMARY KEY (pc_re_stat_line_bal_hashkey);



CREATE OR REPLACE TABLE sat_re_stat_line_bal (
    re_stat_line_bal_hashkey string COMMENT 'Tham chiếu Hub Re Stat Line Bal',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_open_bal decimal(38,10) COMMENT 'Số dư đầu ngày',
    t_open_bal_lcl decimal(38,10) COMMENT 'Số dư đầu ngày qui đổi',
    t_cr_movement decimal(38,10) COMMENT 'PS có ngày nguyên tệ',
    t_cr_mvmt_lcl bigint COMMENT 'PS có ngày qui đổi',
    t_db_movement decimal(38,10) COMMENT 'PS nợ ngày nguyên tệ',
    t_db_mvmt_lcl bigint COMMENT 'PS nợ ngày qui đổi',
    t_closing_bal decimal(38,10) COMMENT 'Du cuối nguyên tệ',
    t_closing_bal_lcl decimal(38,10) COMMENT 'Dư cuối qui đổi',
    t_cr_mvmt_ytd decimal(38,10) COMMENT 'PS có năm',
    t_cr_mvmt_ytd_lcl decimal(38,10) COMMENT 'PS có năm qui đổi',
    t_db_mvmt_ytd decimal(38,10) COMMENT 'PS nợ năm',
    t_db_mvmt_ytd_lcl decimal(38,10) COMMENT 'PS nợ năm qui đổi',
    t_cr_mvmt_mth decimal(38,10) COMMENT 'PS có tháng',
    t_cr_mvmt_mth_lcl bigint COMMENT 'PS có tháng qui đổi',
    t_db_mvmt_mth decimal(38,10) COMMENT 'PS nợ tháng',
    t_db_mvmt_mth_lcl bigint COMMENT 'PS nợ tháng qui đổi'
) CLUSTER BY AUTO;
ALTER TABLE sat_re_stat_line_bal ALTER COLUMN re_stat_line_bal_hashkey SET NOT NULL;
ALTER TABLE sat_re_stat_line_bal ADD CONSTRAINT sat_re_stat_line_bal_pk PRIMARY KEY (re_stat_line_bal_hashkey);



CREATE OR REPLACE TABLE sat_consolidate_profit_n_loss_information (
    consolidate_profit_n_loss_hashkey string COMMENT 'Tham chiếu Hub Consolidate Profit and Loss',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_currency string COMMENT 'Loại tiền',
    t_pl_category string COMMENT 'PL category',
    t_balance_ytd string COMMENT 'Số dư tích lũy của năm qui đổi',
    t_ccy_balance_ytd string COMMENT 'Số dư tích lũy năm nguyên tệ'
) CLUSTER BY AUTO;
ALTER TABLE sat_consolidate_profit_n_loss_information ALTER COLUMN consolidate_profit_n_loss_hashkey SET NOT NULL;
ALTER TABLE sat_consolidate_profit_n_loss_information ADD CONSTRAINT sat_consolidate_profit_n_loss_information_pk PRIMARY KEY (consolidate_profit_n_loss_hashkey);



CREATE OR REPLACE TABLE sat_line_movement_toanhang (
    line_movement_toanhang_hashkey string COMMENT 'Tham chiếu Hub Line Movement Toanhang',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_y_trans_code string COMMENT 'Mã loại giao dịch',
    t_amount_lcy string COMMENT 'Số tiền nội tệ',
    t_amount_fcy string COMMENT 'Số tiền ngoại tệ',
    t_ccy string COMMENT 'Mã loại tiền',
    t_consol_key string COMMENT 'Consol key',
    t_y_xref_rev_marker string COMMENT 'Đánh dấu reverse giao dịch',
    t_y_dr_cr string COMMENT 'Show the debit or credit entry',
    t_y_xref_booking_date string COMMENT 'Ngày hạch toán',
    t_y_xref_value_date string COMMENT 'Ngày giá trị',
    t_y_xref_accounting_date string COMMENT 'Ngày kế toán',
    t_stt string COMMENT 'Không có mô tả trong metadata',
    t_xref_nxt_version string COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_line_movement_toanhang ALTER COLUMN line_movement_toanhang_hashkey SET NOT NULL;
ALTER TABLE sat_line_movement_toanhang ADD CONSTRAINT sat_line_movement_toanhang_pk PRIMARY KEY (line_movement_toanhang_hashkey);



CREATE OR REPLACE TABLE sat_re_consol_spec_entry_information (
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_amount_lcy decimal(38,10) COMMENT 'số tiền nội tệ',
    t_narrative string COMMENT 'Nội dung',
    t_value_date string COMMENT 'Ngày giá trị',
    t_amount_fcy decimal(38,10) COMMENT 'Số tiên ngoại tệ',
    t_exchange_rate decimal(38,10) COMMENT 'Tỷ giá quy đổi',
    t_our_reference string COMMENT 'Số giao dịch',
    t_local_ref string COMMENT 'LOCAL_REF',
    t_trans_reference string COMMENT 'Số giao dịch',
    t_booking_date string COMMENT 'ngày',
    t_stmt_no string COMMENT 'số stmt',
    -- t_maturity_date string COMMENT 'Ngày đén hạn'
    t_currency string COMMENT 'loại tiền'
) CLUSTER BY AUTO;
ALTER TABLE sat_re_consol_spec_entry_information ALTER COLUMN re_consol_spec_entry_hashkey SET NOT NULL;
ALTER TABLE sat_re_consol_spec_entry_information ADD CONSTRAINT sat_re_consol_spec_entry_information_pk PRIMARY KEY (re_consol_spec_entry_hashkey);



CREATE OR REPLACE TABLE sat_re_consol_spec_entry_classification (
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_consol_key_type string COMMENT 'loại CONSOL_KEY',
    t_pl_category bigint COMMENT 'Mã cate PL',
    t_product_category string COMMENT 'Mã cate sản phẩm',
    t_system_id string COMMENT 'SYSTEM_ID',
    t_department_code bigint COMMENT 'Mã code  Deparment',
    -- pst_entr_id string COMMENT 'PST_ENTR_ID'
    t_transaction_code string COMMENT 'Mã giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_re_consol_spec_entry_classification ALTER COLUMN re_consol_spec_entry_hashkey SET NOT NULL;
ALTER TABLE sat_re_consol_spec_entry_classification ADD CONSTRAINT sat_re_consol_spec_entry_classification_pk PRIMARY KEY (re_consol_spec_entry_hashkey);



CREATE OR REPLACE TABLE sat_re_consol_spec_entry_audit (
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_reversal_marker string COMMENT 'REVERSAL_MARKER',
    t_record_status string COMMENT 'trang thái giao dich',
    t_curr_no bigint COMMENT 'loại tiền',
    t_inputter string COMMENT 'users nhập',
    t_date_time string COMMENT 'năm tháng ngày giờ phút',
    t_authoriser string COMMENT 'users duyệt'
) CLUSTER BY AUTO;
ALTER TABLE sat_re_consol_spec_entry_audit ALTER COLUMN re_consol_spec_entry_hashkey SET NOT NULL;
ALTER TABLE sat_re_consol_spec_entry_audit ADD CONSTRAINT sat_re_consol_spec_entry_audit_pk PRIMARY KEY (re_consol_spec_entry_hashkey);



CREATE OR REPLACE TABLE sat_stmt_entry_information (
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub  Stmt Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_account_number string COMMENT 'tài khoản',
    t_amount_lcy decimal(38,10) COMMENT 'số tiền nôi tệ',
    t_their_reference string COMMENT 'Số GD',
    t_value_date string COMMENT 'Ngày giá trị',
    t_amount_fcy decimal(38,10) COMMENT 'Số tiên Ngoại tệ',
    t_exchange_rate string COMMENT 'Tỷ giá quy đổi',
    t_our_reference string COMMENT 'Số giao dịch',
    t_trans_reference string COMMENT 'Số giao dịch',
    t_currency string COMMENT 'Loại tiền',
    t_narrative string COMMENT 'Diễn giải',
    t_stmt_no string COMMENT 'Số stmt',
    t_master_account string COMMENT 'TK master',
    t_local_ref string COMMENT 'LOCAL_REF'
) CLUSTER BY AUTO;
ALTER TABLE sat_stmt_entry_information ALTER COLUMN stmt_entry_hashkey SET NOT NULL;
ALTER TABLE sat_stmt_entry_information ADD CONSTRAINT sat_stmt_entry_information_pk PRIMARY KEY (stmt_entry_hashkey);



CREATE OR REPLACE TABLE sat_stmt_entry_classification (
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub  Stmt Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_pl_category bigint COMMENT 'Mã cate PL',
    t_product_category bigint COMMENT 'Mã cate sản phẩm',
    t_crf_type string COMMENT 'Loại nợ có',
    t_system_id string COMMENT 'Loại Giao dịch',
    t_transaction_code bigint COMMENT 'Mã giao dịch',
    t_department_code bigint COMMENT 'Mã code  Deparment',
    -- pst_entr_id string COMMENT 'PST_ENTR_ID'
    t_consol_key string COMMENT 'CONSOL_KEY'
) CLUSTER BY AUTO;
ALTER TABLE sat_stmt_entry_classification ALTER COLUMN stmt_entry_hashkey SET NOT NULL;
ALTER TABLE sat_stmt_entry_classification ADD CONSTRAINT sat_stmt_entry_classification_pk PRIMARY KEY (stmt_entry_hashkey);



CREATE OR REPLACE TABLE sat_stmt_entry_audit (
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub  Stmt Entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_record_status string COMMENT 'Trạng thái giao dịch',
    t_booking_date string COMMENT 'Ngày',
    t_inputter string COMMENT 'user nhập',
    t_authoriser string COMMENT 'users duyệt',
    t_processing_date string COMMENT 'Ngày xử lý',
    t_exposure_date string COMMENT 'Ngày thực hiện',
    t_date_time string COMMENT 'năm tháng ngày giờ phút',
    t_reversal_marker string COMMENT 'REVERSAL_MARKER',
    t_accounting_date string COMMENT 'ACCOUNTING_DATE',
    t_pc_period_end string COMMENT 'PC_PERIOD_END'
) CLUSTER BY AUTO;
ALTER TABLE sat_stmt_entry_audit ALTER COLUMN stmt_entry_hashkey SET NOT NULL;
ALTER TABLE sat_stmt_entry_audit ADD CONSTRAINT sat_stmt_entry_audit_pk PRIMARY KEY (stmt_entry_hashkey);



CREATE OR REPLACE TABLE link_categ_entry_customer (
    link_categ_entry_customer_hashkey string COMMENT 'Link HK',
    categ_entry_hashkey string COMMENT 'Tham chiếu Hub Categ Entry',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_categ_entry_customer ALTER COLUMN link_categ_entry_customer_hashkey SET NOT NULL;
ALTER TABLE link_categ_entry_customer ADD CONSTRAINT link_categ_entry_customer_pk PRIMARY KEY (link_categ_entry_customer_hashkey);



CREATE OR REPLACE TABLE link_categ_entry_branch (
    link_categ_entry_branch_hashkey string COMMENT 'Link HK',
    categ_entry_hashkey string COMMENT 'Tham chiếu Hub Categ Entry',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_categ_entry_branch ALTER COLUMN link_categ_entry_branch_hashkey SET NOT NULL;
ALTER TABLE link_categ_entry_branch ADD CONSTRAINT link_categ_entry_branch_pk PRIMARY KEY (link_categ_entry_branch_hashkey);



CREATE OR REPLACE TABLE link_line_movement_toanhang_categ_entry (
    link_line_movement_toanhang_categ_entry_hashkey string COMMENT 'Link HK',
    line_movement_toanhang_hashkey string COMMENT 'Tham chiếu Hub Line Movement Toanhang',
    categ_entry_hashkey string COMMENT 'Tham chiếu Hub Categ Entry',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_line_movement_toanhang_categ_entry ALTER COLUMN link_line_movement_toanhang_categ_entry_hashkey SET NOT NULL;
ALTER TABLE link_line_movement_toanhang_categ_entry ADD CONSTRAINT link_line_movement_toanhang_categ_entry_pk PRIMARY KEY (link_line_movement_toanhang_categ_entry_hashkey);



CREATE OR REPLACE TABLE link_line_movement_toanhang_stmt_entry (
    link_line_movement_toanhang_stmt_entry_hashkey string COMMENT 'Link HK',
    line_movement_toanhang_hashkey string COMMENT 'Tham chiếu Hub Line Movement Toanhang',
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub Stmt Entry',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_line_movement_toanhang_stmt_entry ALTER COLUMN link_line_movement_toanhang_stmt_entry_hashkey SET NOT NULL;
ALTER TABLE link_line_movement_toanhang_stmt_entry ADD CONSTRAINT link_line_movement_toanhang_stmt_entry_pk PRIMARY KEY (link_line_movement_toanhang_stmt_entry_hashkey);



CREATE OR REPLACE TABLE link_line_movement_toanhang_re_consol_spec_entry (
    link_line_movement_toanhang_re_consol_spec_entry_hashkey string COMMENT 'Link HK',
    line_movement_toanhang_hashkey string COMMENT 'Tham chiếu Hub Line Movement Toanhang',
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_line_movement_toanhang_re_consol_spec_entry ALTER COLUMN link_line_movement_toanhang_re_consol_spec_entry_hashkey SET NOT NULL;
ALTER TABLE link_line_movement_toanhang_re_consol_spec_entry ADD CONSTRAINT link_line_movement_toanhang_re_consol_spec_entry_pk PRIMARY KEY (link_line_movement_toanhang_re_consol_spec_entry_hashkey);



CREATE OR REPLACE TABLE link_re_consol_spec_entry_branch (
    link_re_consol_spec_entry_branch_hashkey string COMMENT 'Link HK',
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_re_consol_spec_entry_branch ALTER COLUMN link_re_consol_spec_entry_branch_hashkey SET NOT NULL;
ALTER TABLE link_re_consol_spec_entry_branch ADD CONSTRAINT link_re_consol_spec_entry_branch_pk PRIMARY KEY (link_re_consol_spec_entry_branch_hashkey);



CREATE OR REPLACE TABLE link_re_consol_spec_entry_customer (
    link_re_consol_spec_entry_customer_hashkey string COMMENT 'Link HK',
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_re_consol_spec_entry_customer ALTER COLUMN link_re_consol_spec_entry_customer_hashkey SET NOT NULL;
ALTER TABLE link_re_consol_spec_entry_customer ADD CONSTRAINT link_re_consol_spec_entry_customer_pk PRIMARY KEY (link_re_consol_spec_entry_customer_hashkey);



CREATE OR REPLACE TABLE link_re_consol_spec_entry_officer (
    link_re_consol_spec_entry_officer_hashkey string COMMENT 'Link HK',
    re_consol_spec_entry_hashkey string COMMENT 'Tham chiếu Hub Re Consol Spec Entry',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_re_consol_spec_entry_officer ALTER COLUMN link_re_consol_spec_entry_officer_hashkey SET NOT NULL;
ALTER TABLE link_re_consol_spec_entry_officer ADD CONSTRAINT link_re_consol_spec_entry_officer_pk PRIMARY KEY (link_re_consol_spec_entry_officer_hashkey);



CREATE OR REPLACE TABLE link_stmt_entry_customer (
    link_stmt_entry_customer_hashkey string COMMENT 'Link HK',
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub Stmt Entry',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_stmt_entry_customer ALTER COLUMN link_stmt_entry_customer_hashkey SET NOT NULL;
ALTER TABLE link_stmt_entry_customer ADD CONSTRAINT link_stmt_entry_customer_pk PRIMARY KEY (link_stmt_entry_customer_hashkey);



CREATE OR REPLACE TABLE link_stmt_entry_branch (
    link_stmt_entry_branch_hashkey string COMMENT 'Link HK',
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub  Stmt Entry',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_stmt_entry_branch ALTER COLUMN link_stmt_entry_branch_hashkey SET NOT NULL;
ALTER TABLE link_stmt_entry_branch ADD CONSTRAINT link_stmt_entry_branch_pk PRIMARY KEY (link_stmt_entry_branch_hashkey);



CREATE OR REPLACE TABLE link_stmt_entry_officer (
    link_stmt_entry_officer_hashkey string COMMENT 'Link HK',
    stmt_entry_hashkey string COMMENT 'Tham chiếu Hub  Stmt Entry',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_stmt_entry_officer ALTER COLUMN link_stmt_entry_officer_hashkey SET NOT NULL;
ALTER TABLE link_stmt_entry_officer ADD CONSTRAINT link_stmt_entry_officer_pk PRIMARY KEY (link_stmt_entry_officer_hashkey);



CREATE OR REPLACE TABLE hub_collateral (
    collateral_hashkey string COMMENT 'Hub Hash Key TSBĐ (kỹ thuật)',
    business_key string COMMENT 'Business Key: ID TSBĐ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_collateral ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE hub_collateral ADD CONSTRAINT hub_collateral_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE hub_collateral_right (
    collateral_right_hashkey string COMMENT 'Hub Hash Key TSBĐ (kỹ thuật)',
    business_key string COMMENT 'Business Key: ID TSBĐ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_collateral_right ALTER COLUMN collateral_right_hashkey SET NOT NULL;
ALTER TABLE hub_collateral_right ADD CONSTRAINT hub_collateral_right_pk PRIMARY KEY (collateral_right_hashkey);



CREATE OR REPLACE TABLE sat_collateral_information (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_collateral_type bigint COMMENT 'Loại tài sản bảo đảm',
    t_description string COMMENT 'Mô tả tài sản bảo đảm',
    t_collateral_code bigint COMMENT 'Mã TSBĐ',
    t_coll_status string COMMENT 'Trạng thái tài sản',
    t_expiry_date string COMMENT 'Ngày hết hạn',
    t_value_date string COMMENT 'Ngày giá trị',
    t_ocb_co_note string COMMENT 'Ghi chú khác',
    t_notes string COMMENT 'Ghi chú',
    t_in_cluster string COMMENT 'Thuộc cụm',
    t_borrow_purpose string COMMENT 'Mục đích mượn',
    t_ld_cust_group string COMMENT 'Khối quản lý hồ sơ vay',
    t_ocb_start_date string COMMENT 'Ngày bắt đầu/ phát hành/ sản xuất',
    t_ocb_end_date string COMMENT 'Ngày đáo hạn/ hết hạn sử dụng',
    t_inputter string COMMENT 'Người nhập',
    t_date_time string COMMENT 'Ngày nhập',
    t_authoriser string COMMENT 'Người duyệt',
    T_CURRENCY string COMMENT 'Loại tiền tệ',
    t_application_id string COMMENT 'Loại tiền tệ'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_information ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_information ADD CONSTRAINT sat_collateral_information_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_valuation (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_nominal_value decimal(38,10) COMMENT 'Giá trị danh nghĩa',
    t_execution_value decimal(38,10) COMMENT 'Giá trị đảm bảo',
    t_gen_ledger_value decimal(38,10) COMMENT 'Giá trị ghi sổ',
    t_central_bank_value decimal(38,10) COMMENT 'Giá trị báo cáo NHNN',
    t_coll_price decimal(38,10) COMMENT 'Đơn giá TSBĐ',
    t_coll_number string COMMENT 'Số lượng tài sản',
    t_maximum_value decimal(38,10) COMMENT 'Giá trị tối đa TSĐB',
    t_loan_ratio string COMMENT 'Tỷ lệ bảo đảm phê duyệt (%)',
    t_ocb_val_date string COMMENT 'Ngày định giá TSĐB',
    t_ocb_val_agent string COMMENT 'Đơn vị định giá TSĐB',
    t_ocb_reval_date string COMMENT 'Ngày định giá gần nhất',
    t_ocb_reval_agent string COMMENT 'Đơn vị định giá gần nhất',
    t_ocb_reval_amt string COMMENT 'Giá trị TSĐB cấp tín dụng',
    t_reval_next_date string COMMENT 'Ngày hết hiệu lực đánh giá',
    t_ocb_pric_date string COMMENT 'Ngày định giá gần nhất (AD tính DP)',
    t_ocb_pric_organ string COMMENT 'Đơn vị đinh giá gần nhất(AD tính DP)',
    t_ocb_next_date string COMMENT 'Ngày định giá tiếp theo (AD tính DP)',
    t_ocb_is_revalu string COMMENT 'Tái định giá',
    t_ocb_coll_rls string COMMENT 'Tài sản đang xử lý nợ',
    t_ocb_pric_val_rl string COMMENT 'GIá trị định giá TS để xử lý nợ',
    t_ocb_pric_dat_rl string COMMENT 'Ngày định giá TS đề xử lý nợ',
    t_ocb_pric_or_rls string COMMENT 'Đơn vị định giá để xử lý nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_valuation ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_valuation ADD CONSTRAINT sat_collateral_valuation_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_insurance (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ins_contract string COMMENT 'Số hợp đồng bảo hiểm',
    t_coll_ins_status string COMMENT 'TSĐB phải mua bảo hiểm (Yes/No)',
    t_coll_ins_prod string COMMENT 'Sản phẩm bảo hiểm',
    t_coll_ins_comp string COMMENT 'Công ty bảo hiểm',
    t_ins_amount string COMMENT 'Số tiền mua bảo hiểm',
    t_ins_fee string COMMENT 'Phí bảo hiểm',
    t_ins_start string COMMENT 'Ngày hiệu lực bảo hiểm',
    t_ins_end string COMMENT 'Ngày hết hiệu lực bảo hiểm'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_insurance ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_insurance ADD CONSTRAINT sat_collateral_insurance_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_vehicle (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ocb_estate_num string COMMENT 'Số phát hành GCN/biển số/biến kiểm soát',
    t_ocb_fram_num string COMMENT 'Số khung',
    t_ocb_estate_reg string COMMENT 'Số vào sổ cấp GCN/Hồ sơ gốc',
    t_ocb_coll_type string COMMENT 'Phân loại TSĐB/loại phương tiện',
    t_ocb_trade_mark string COMMENT 'Thương hiệu',
    t_ocb_pr_licen_no string COMMENT 'Số giấy phép',
    t_ocb_series string COMMENT 'Số serie giấy tờ/seri máy'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_vehicle ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_vehicle ADD CONSTRAINT sat_collateral_vehicle_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_instrument (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_coll_sec_id string COMMENT 'Mã cổ phiếu/chứng khoán',
    t_coll_sec_number string COMMENT 'Số lượng cổ phiếu',
    t_appoint_date string COMMENT 'Ngày hẹn',
    t_ocb_bonds_id string COMMENT 'Mã trái phiếu',
    t_ocb_listing string COMMENT 'Sàn niêm yết',
    t_ocb_inter_rate string COMMENT 'Lãi suất trái phiếu',
    t_ocb_pay_me_rate string COMMENT 'Phương pháp trả lãi',
    t_ocb_listed string COMMENT 'Niêm yết (Yes/No)',
    t_ocb_ward_2 string COMMENT 'Số lượng trái phiếu (theo nguồn)',
    t_ocb_quantity bigint COMMENT 'Khối lượng (kim loại quý)/SL TP',
    t_ocb_credit_orga string COMMENT 'Tổ chức phát hành (STK/HĐTG)',
    t_imp_store_id string COMMENT 'Mã lệnh kho quỹ',
    t_ocb_gtcg_issuer string COMMENT 'Tổ chức phát hành',
    t_ocb_issuer string COMMENT 'Cơ quan cấp GCN(TSĐB Bất động sản)/Tổ chức phát hành(TSĐB Cố phiếu)',
    t_ocb_series string COMMENT 'Số serie giấy tờ/seri máy'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_instrument ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_instrument ADD CONSTRAINT sat_collateral_instrument_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_real_estate (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_houseprj_cb string COMMENT 'Mã tài sản dự án liên quan',
    t_ocb_project_nam string COMMENT 'Tên dự án liên quan',
    t_ocb_project_inv string COMMENT 'Chủ đầu tư dự án liên quan',
    t_ocb_tot_vl_inve bigint COMMENT 'Tổng giá trị đầu tư',
    t_ocb_pr_end_date string COMMENT 'Thời hạn dự án',
    t_ocb_rec_est_dat string COMMENT 'Ngày bàn giao BĐS dự kiến',
    t_ocb_lea_est_dat string COMMENT 'Ngày bàn giao BĐS thực tế',
    t_ocb_issuer string COMMENT 'Cơ quan cấp GCN(TSĐB Bất động sản)/Tổ chức phát hành(TSĐB Cố phiếu)',
    t_ocb_parcel_num string COMMENT 'Số thửa đất',
    t_ocb_map_num string COMMENT 'Số tờ bản đồ',
    t_country string COMMENT 'Mã quốc gia',
    t_province_2 string COMMENT 'Tỉnh/Thành phố',
    t_town_country_2 string COMMENT 'Quận/Huyện/Thị xã',
    t_ward_2 string COMMENT 'Phường/Xã/Thị trấn',
    t_add_num string COMMENT 'Số nhà',
    t_address string COMMENT 'Địa chỉ'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_real_estate ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_real_estate ADD CONSTRAINT sat_collateral_real_estate_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_other (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ocb_coll_store string COMMENT 'Địa điểm lưu kho',
    t_contract_link string COMMENT 'Số hợp đồng thế chấp TSĐB'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_other ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_other ADD CONSTRAINT sat_collateral_other_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE sat_collateral_right_information (
    collateral_right_hashkey string COMMENT 'Tham chiếu Hub quyền TSĐB',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_limit_ref_cust string COMMENT 'Hạn mức khách hàng (mã)',
    t_percent_alloc string COMMENT '% phân bổ quyền TSĐB',
    t_validity_date string COMMENT 'Ngày hiệu lực',
    t_expiry_date string COMMENT 'Ngày hết hạn',
    t_status string COMMENT 'Trạng thái quyền',
    t_inputter string COMMENT 'Người nhập (hệ thống)',
    t_authoriser string COMMENT 'Người duyệt (hệ thống)'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_right_information ALTER COLUMN collateral_right_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_right_information ADD CONSTRAINT sat_collateral_right_information_pk PRIMARY KEY (collateral_right_hashkey);



CREATE OR REPLACE TABLE sat_collateral_basel (
    collateral_hashkey string COMMENT 'Tham chiếu Hub Collateral',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_dbstk_publisher string COMMENT 'Loại tổ chức phát hành CK nợ',
    t_fitch_rtg_form string COMMENT 'Hình thức xếp hạng fitch',
    t_fitch_rating string COMMENT 'Loại xếp hạng fitch',
    t_moody_rtg_form string COMMENT 'Hình thức xếp hạng moody',
    t_moody_rating string COMMENT 'Loại xếp hạng moody',
    t_sp_rtg_form string COMMENT 'Hình thức xếp hạng standard poor',
    t_sp_rating string COMMENT 'Loại xếp hạng standard poor',
    t_other_rtg_form string COMMENT 'Hình thức xếp hạng tổ chức khác',
    t_other_rating string COMMENT 'Loại xếp hạng tổ chức khác',
    t_ot_rating_name string COMMENT 'Tên tổ chức xếp hạng khác',
    t_coupon_int_rate string COMMENT 'Lãi suất coupon',
    t_int_mode_pay string COMMENT 'Phương thức thanh toán lãi',
    t_intpay_num_year string COMMENT 'Số lần trả lãi trong năm',
    t_stk_exchange string COMMENT 'Sàn giao dịch',
    t_sale_area_perct string COMMENT 'Tỷ lệ BĐS dùng để kinh doanh',
    t_re_buy_mortgage string COMMENT 'KH có dùng BĐS mua để thế chấp [Mandatory Field]',
    t_vpaper_issg_org string COMMENT 'Đơn vị phát hành',
    t_sb_vpaper_no string COMMENT 'Số STK/ Giấy tờ có giá',
    t_sv_expire_date string COMMENT 'Ngày hết hạn STK/ Giấy tờ có giá',
    t_sb_vp_term string COMMENT 'Kỳ hạn STK/ Giấy tờ có giá',
    t_inputter string COMMENT 'user input',
    t_authoriser string COMMENT 'user duyệt',
    t_date_time string COMMENT 'ngày giờ'
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_basel ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_basel ADD CONSTRAINT sat_collateral_basel_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE link_collateral_branch (
    link_collateral_branch_hashkey string COMMENT 'Link Hash Key',
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    branch_hashkey string COMMENT 'Mã đơn vị quản lý hồ sơ vật lý',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_branch ALTER COLUMN link_collateral_branch_hashkey SET NOT NULL;
ALTER TABLE link_collateral_branch ADD CONSTRAINT link_collateral_branch_pk PRIMARY KEY (link_collateral_branch_hashkey);



CREATE OR REPLACE TABLE link_collateral_man_branch (
    link_collateral_man_branch_hashkey string COMMENT 'Link Hash Key',
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    branch_hashkey string COMMENT 'Tham chiếu Hub Chi nhánh quản lý tsbđ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_man_branch ALTER COLUMN link_collateral_man_branch_hashkey SET NOT NULL;
ALTER TABLE link_collateral_man_branch ADD CONSTRAINT link_collateral_man_branch_pk PRIMARY KEY (link_collateral_man_branch_hashkey);



CREATE OR REPLACE TABLE link_collateral_collateral_right (
    link_collateral_collateral_right_hashkey string COMMENT 'Link Hash Key (HASH(HK_COLLATERAL, HK_COLLATER_RIGHT))',
    collateral_right_hashkey string COMMENT 'Hub Hash Key TSBĐ (kỹ thuật)',
    collateral_hashkey string COMMENT 'Hub Hash Key quyền TSBĐ (kỹ thuật)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_collateral_right ALTER COLUMN link_collateral_collateral_right_hashkey SET NOT NULL;
ALTER TABLE link_collateral_collateral_right ADD CONSTRAINT link_collateral_collateral_right_pk PRIMARY KEY (link_collateral_collateral_right_hashkey);



CREATE OR REPLACE TABLE link_collateral_right_limit (
    collateral_right_hashkey string COMMENT 'Hub Hash Key quyền TSBĐ (kỹ thuật)',
    link_collateral_right_limit_hashkey string COMMENT 'Link Hash Key (HASH(HK_LIMIT, HK_COLLATER_RIGHT))',
    limit_hashkey string COMMENT 'Hub Hash Key hạn mức (kỹ thuật)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_right_limit ALTER COLUMN link_collateral_right_limit_hashkey SET NOT NULL;
ALTER TABLE link_collateral_right_limit ADD CONSTRAINT link_collateral_right_limit_pk PRIMARY KEY (link_collateral_right_limit_hashkey);



CREATE OR REPLACE TABLE link_collateral_customer (
    link_collateral_customer_hashkey string COMMENT 'Link Hash Key (HASH(HK_CUSTOMER, HK_COLLATERAL))',
    collateral_hashkey string COMMENT 'Hub Hash Key TSBĐ (kỹ thuật)',
    customer_hashkey string COMMENT 'Hub Hash Key khách hàng (kỹ thuật)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_customer ALTER COLUMN link_collateral_customer_hashkey SET NOT NULL;
ALTER TABLE link_collateral_customer ADD CONSTRAINT link_collateral_customer_pk PRIMARY KEY (link_collateral_customer_hashkey);



CREATE OR REPLACE TABLE link_collateral_az_account (
    link_collateral_az_account_hashkey string COMMENT 'Link Hash Key (HASH(HK_CUSTOMER, HK_COLLATERAL))',
    collateral_hashkey string COMMENT 'Hub Hash Key TSBĐ (kỹ thuật)',
    account_hashkey string COMMENT 'Hub Hash Key Account (kỹ thuật)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_az_account ALTER COLUMN link_collateral_az_account_hashkey SET NOT NULL;
ALTER TABLE link_collateral_az_account ADD CONSTRAINT link_collateral_az_account_pk PRIMARY KEY (link_collateral_az_account_hashkey);



CREATE OR REPLACE TABLE hub_crb (
    crb_hashkey string COMMENT 'Hub Hashkey',
    gl string COMMENT 'Mã TK GL',
    tieukhoan string COMMENT 'Mã tiểu khoản',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_crb ALTER COLUMN crb_hashkey SET NOT NULL;
ALTER TABLE hub_crb ADD CONSTRAINT hub_crb_pk PRIMARY KEY (crb_hashkey);



CREATE OR REPLACE TABLE sat_crb_balance (
    crb_hashkey string COMMENT 'Hub Hashkey',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active Business key ( Data date)',
    ngoaite string COMMENT 'Loại đồng tiền',
    ngoaite1 string COMMENT 'Số tiền ngoại tệ',
    noite string COMMENT 'Số tiền nội tệ',
    category int COMMENT 'Phân loại sản phẩm'
) CLUSTER BY AUTO;
ALTER TABLE sat_crb_balance ALTER COLUMN crb_hashkey SET NOT NULL;
ALTER TABLE sat_crb_balance ADD CONSTRAINT sat_crb_balance_pk PRIMARY KEY (crb_hashkey);



CREATE OR REPLACE TABLE sat_crb_information (
    crb_hashkey string COMMENT 'Hub Hashkey',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active Business key ( Data date)',
    sotkcu string COMMENT 'Số tài khoản cũ',
    laisuat string COMMENT 'Lãi suất',
    kyhan string COMMENT 'Kỳ hạn hối phiếu (at sight/usance)',
    startdate string COMMENT 'Ngày bắt đầu',
    enddate string COMMENT 'Ngày kết thúc',
    masp string COMMENT 'Mã sản phẩm',
    laidatra string COMMENT 'Lãi đã trả',
    loanclass string COMMENT 'Nhóm nợ',
    ten string COMMENT 'Tên TK'
) CLUSTER BY AUTO;
ALTER TABLE sat_crb_information ALTER COLUMN crb_hashkey SET NOT NULL;
ALTER TABLE sat_crb_information ADD CONSTRAINT sat_crb_information_pk PRIMARY KEY (crb_hashkey);



CREATE OR REPLACE TABLE link_crb_branch (
    link_crb_branch_hashkey string COMMENT 'Link Hash Key',
    crb_hashkey string COMMENT 'FK tới hub_CRB',
    branch_hashkey string COMMENT 'FK tới hub_BRANCH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_crb_branch ALTER COLUMN link_crb_branch_hashkey SET NOT NULL;
ALTER TABLE link_crb_branch ADD CONSTRAINT link_crb_branch_pk PRIMARY KEY (link_crb_branch_hashkey);



CREATE OR REPLACE TABLE link_crb_customer (
    link_crb_customer_hashkey string COMMENT 'Link Hash Key',
    crb_hashkey string COMMENT 'FK tới hub_CRB',
    customer_hashkey string COMMENT 'FK tới hub_CUSTOMER',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_crb_customer ALTER COLUMN link_crb_customer_hashkey SET NOT NULL;
ALTER TABLE link_crb_customer ADD CONSTRAINT link_crb_customer_pk PRIMARY KEY (link_crb_customer_hashkey);



CREATE OR REPLACE TABLE link_crb_loans (
    link_crb_loans_hashkey string COMMENT 'Link Hash Key',
    crb_hashkey string COMMENT 'FK tới hub_CRB',
    loans_hashkey string COMMENT 'FK tới hub_loans',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_crb_loans ALTER COLUMN link_crb_loans_hashkey SET NOT NULL;
ALTER TABLE link_crb_loans ADD CONSTRAINT link_crb_loans_pk PRIMARY KEY (link_crb_loans_hashkey);



CREATE OR REPLACE TABLE link_crb_loans_payment_due (
    link_crb_loans_payment_due_hashkey string COMMENT 'Link Hash Key',
    crb_hashkey string COMMENT 'FK tới hub_CRB',
    loans_payment_due_hashkey string COMMENT 'FK tới hub_loans_payment_due',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_crb_loans_payment_due ALTER COLUMN link_crb_loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE link_crb_loans_payment_due ADD CONSTRAINT link_crb_loans_payment_due_pk PRIMARY KEY (link_crb_loans_payment_due_hashkey);



CREATE OR REPLACE TABLE link_crb_account (
    link_crb_account_hashkey string COMMENT 'Link Hash Key',
    crb_hashkey string COMMENT 'FK tới hub_CRB',
    account_hashkey string COMMENT 'FK tới hub account',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_crb_account ALTER COLUMN link_crb_account_hashkey SET NOT NULL;
ALTER TABLE link_crb_account ADD CONSTRAINT link_crb_account_pk PRIMARY KEY (link_crb_account_hashkey);



CREATE OR REPLACE TABLE hub_gdi (
    gdi_hashkey string COMMENT 'Hub Hash Key GDI',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_gdi ALTER COLUMN gdi_hashkey SET NOT NULL;
ALTER TABLE hub_gdi ADD CONSTRAINT hub_gdi_pk PRIMARY KEY (gdi_hashkey);



CREATE OR REPLACE TABLE hub_gci (
    gci_hashkey string COMMENT 'Hub Hash Key GCI',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_gci ALTER COLUMN gci_hashkey SET NOT NULL;
ALTER TABLE hub_gci ADD CONSTRAINT hub_gci_pk PRIMARY KEY (gci_hashkey);



CREATE OR REPLACE TABLE sat_gdi_information (
    gdi_hashkey string COMMENT 'Tham chiếu Hub GDI',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_charge_key int COMMENT 'Cơ số tính lãi',
    t_interest_day_basis string COMMENT 'Loại số dư tính lãi ghi có',
    t_dr_balance_type string COMMENT 'Phương pháp tính lãi ghi có',
    t_dr_calcul_type string COMMENT 'Mức Lãi suất cơ bản ghi có',
    t_dr_basic_rate string COMMENT 'Lãi suất ghi có',
    t_dr_int_rate string COMMENT 'Trạng thái bản ghi',
    t_apr_required string COMMENT 'Số bản ghi',
    t_record_status string COMMENT 'User nhập',
    t_curr_no int COMMENT 'User duyệt',
    t_inputter string COMMENT 'Ngày thực hiện',
    t_authoriser string COMMENT 'Số tiền tối thiểu ghi có',
    t_date_time string COMMENT 'Số tiền tối thiểu ghi có 2',
    t_dr_limit_amt string COMMENT 'Số tiền tối thiểu'
) CLUSTER BY AUTO;
ALTER TABLE sat_gdi_information ALTER COLUMN gdi_hashkey SET NOT NULL;
ALTER TABLE sat_gdi_information ADD CONSTRAINT sat_gdi_information_pk PRIMARY KEY (gdi_hashkey);



CREATE OR REPLACE TABLE sat_gci_information (
    gci_hashkey string COMMENT 'Tham chiếu Hub GCI',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_interest_day_basis string COMMENT 'Mã code phí',
    t_cr_balance_type string COMMENT 'Cơ số tính lãi',
    t_cr_calcul_type string COMMENT 'Loại số dư tính lãi ghi nợ',
    t_cr_basic_rate string COMMENT 'Phương pháp tính lãi ghi nợ',
    t_cr_int_rate string COMMENT 'Mức Lãi suất cơ bản ghi nợ',
    t_record_status string COMMENT 'Lãi suất ghi nợ',
    t_curr_no int COMMENT 'Lãi suất phần trăm hàng năm - TEG có bắt buộc hay không.',
    t_inputter string COMMENT 'Trạng thái bản ghi',
    t_authoriser string COMMENT 'Số bản ghi',
    t_date_time string COMMENT 'User nhập',
    t_cr_minimum_bal decimal(20,4) COMMENT 'User duyệt',
    t_cr2_minimum_bal decimal(20,4) COMMENT 'Ngày thực hiện',
    t_cr_limit_amt string COMMENT 'Số tiền tối thiểu'
) CLUSTER BY AUTO;
ALTER TABLE sat_gci_information ALTER COLUMN gci_hashkey SET NOT NULL;
ALTER TABLE sat_gci_information ADD CONSTRAINT sat_gci_information_pk PRIMARY KEY (gci_hashkey);



CREATE OR REPLACE TABLE link_gdi_branch (
    link_gdi_branch_hashkey string COMMENT 'Link HK',
    gdi_hashkey string COMMENT 'Tham chiếu Hub GDI',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_gdi_branch ALTER COLUMN link_gdi_branch_hashkey SET NOT NULL;
ALTER TABLE link_gdi_branch ADD CONSTRAINT link_gdi_branch_pk PRIMARY KEY (link_gdi_branch_hashkey);



CREATE OR REPLACE TABLE link_gci_branch (
    link_gci_branch_hashkey string COMMENT 'Link HK',
    gci_hashkey string COMMENT 'Tham chiếu Hub GCI',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_gci_branch ALTER COLUMN link_gci_branch_hashkey SET NOT NULL;
ALTER TABLE link_gci_branch ADD CONSTRAINT link_gci_branch_pk PRIMARY KEY (link_gci_branch_hashkey);



CREATE OR REPLACE TABLE hub_deposits (
    deposit_hashkey string COMMENT 'Hub Hash Key (kỹ thuật)',
    business_key string COMMENT 'Business Key: Số TK/Hợp đồng AZ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_deposits ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE hub_deposits ADD CONSTRAINT hub_deposits_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE sat_deposits_information (
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_currency string COMMENT 'Loại tiền tệ',
    t_value_date string COMMENT 'Ngày mở kỳ hiện tại',
    t_maturity_date string COMMENT 'Ngày đáo hạn',
    t_create_date string COMMENT 'Ngày mở đầu tiên',
    t_principal decimal(38,10) COMMENT 'Số dư gốc hiện tại',
    t_orig_principal decimal(38,10) COMMENT 'Gốc ban đầu',
    t_rollover_date string COMMENT 'Ngày tái tục',
    t_ocb_term_commit string COMMENT 'Local: Kỳ hạn cam kết',
    t_ocb_mat_dt_comm string COMMENT 'Local: Ngày đáo hạn cam kết',
    t_ocb_id_hotro string COMMENT 'Local: mã phê duyệt',
    t_ocb_loyal_intr string COMMENT 'Local: ưu đãi khách hàng thân thiết',
    t_record_status string COMMENT 'Trạng thái bản ghi'
) CLUSTER BY AUTO;
ALTER TABLE sat_deposits_information ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sat_deposits_information ADD CONSTRAINT sat_deposits_information_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE sat_deposits_classification (
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_deposit_prgm string COMMENT 'Local: Mã CTKM',
    t_all_in_one_product string COMMENT 'Mã sản phẩm',
    t_category bigint COMMENT 'Mã phân loại',
    t_roll_aio_product string COMMENT 'Mã SP chuyển sang khi tái tục',
    t_preclose_reason string COMMENT 'Local field : Lý do tất toán',
    t_waive_chg string COMMENT 'Có miễn thu phí'
) CLUSTER BY AUTO;
ALTER TABLE sat_deposits_classification ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sat_deposits_classification ADD CONSTRAINT sat_deposits_classification_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE sat_deposits_terms (
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_term string COMMENT 'Kỳ hạn',
    t_rollover_term string COMMENT 'Kỳ hạn khi tái tục',
    t_type_of_schdle string COMMENT 'Loại lịch',
    t_frequency string COMMENT 'Định kỳ của lịch',
    t_maturity_instr string COMMENT 'Chỉ định đáo hạn',
    t_schedules string COMMENT 'Có định lịch (Y/N)',
    -- t_org_term string COMMENT 'Kỳ hạn ban đầu'
    t_forward_backward string COMMENT 'Lịch: Forward/Backward'
) CLUSTER BY AUTO;
ALTER TABLE sat_deposits_terms ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sat_deposits_terms ADD CONSTRAINT sat_deposits_terms_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE sat_deposits_rate (
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_interest_rate decimal(38,10) COMMENT 'Lãi suất hiện tại',
    t_sch_fixed_rate string COMMENT 'Lãi suất cố định của lịch',
    t_org_int_rate decimal(38,10) COMMENT 'Lãi suất ban đầu',
    t_rollover_int_rate string COMMENT 'Lãi suất khi tái tục (chỉ định)',
    t_calculation_base string COMMENT 'Cơ sở tính lãi',
    t_pay_int_at_mat string COMMENT 'Trả lãi khi đáo hạn (Y/N)',
    t_early_rate string COMMENT 'Lãi suất rút trước hạn',
    t_early_red_int string COMMENT 'LS phạt rút trước hạn',
    t_ocb_auth_level string COMMENT 'Local: cấp duyệt LS ưu đãi',
    t_ocb_ipre_date string COMMENT 'Local: ngày áp dụng LS ưu đãi',
    t_ocb_intratetype string COMMENT 'Local field : Loại lãi suất'
) CLUSTER BY AUTO;
ALTER TABLE sat_deposits_rate ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sat_deposits_rate ADD CONSTRAINT sat_deposits_rate_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE sat_deposits_ftp (
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ocb_ftp_bd_type string COMMENT 'Local FTP: Loại BOND',
    t_ocb_ftp_callput string COMMENT 'Local FTP: Loại call/put',
    t_ocb_ftp_frdate string COMMENT 'Local FTP: Từ ngày',
    t_ocb_ftp_tright string COMMENT 'Local FTP: Loại kỳ hạn',
    t_ocb_ftp_vlpaper string COMMENT 'Local FTP: Loại GTCG',
    t_ocb_ftp_cifcoll string COMMENT 'Local FTP: Mã KH'
) CLUSTER BY AUTO;
ALTER TABLE sat_deposits_ftp ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sat_deposits_ftp ADD CONSTRAINT sat_deposits_ftp_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE sat_deposits_system (
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày giờ nhập/duyệt',
    t_trans_unique_id string COMMENT 'Mã giao dịch ESB/MCS',
    t_curr_no string COMMENT 'Số bản ghi',
    t_dept_code string COMMENT 'Mã phòng ban'
) CLUSTER BY AUTO;
ALTER TABLE sat_deposits_system ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sat_deposits_system ADD CONSTRAINT sat_deposits_system_pk PRIMARY KEY (deposit_hashkey);



CREATE OR REPLACE TABLE link_deposits_customer (
    link_deposits_customer_hashkey string COMMENT 'Link Hash Key',
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    customer_hashkey string COMMENT 'Tham chiếu Hub khách hàng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_deposits_customer ALTER COLUMN link_deposits_customer_hashkey SET NOT NULL;
ALTER TABLE link_deposits_customer ADD CONSTRAINT link_deposits_customer_pk PRIMARY KEY (link_deposits_customer_hashkey);



CREATE OR REPLACE TABLE link_deposits_branch (
    link_deposits_branch_hashkey string COMMENT 'Link Hash Key',
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    branch_hashkey string COMMENT 'Tham chiếu Hub chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_deposits_branch ALTER COLUMN link_deposits_branch_hashkey SET NOT NULL;
ALTER TABLE link_deposits_branch ADD CONSTRAINT link_deposits_branch_pk PRIMARY KEY (link_deposits_branch_hashkey);



CREATE OR REPLACE TABLE link_deposits_nominated_account (
    link_deposits_nominated_account_hashkey string COMMENT 'Link Hash Key',
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    account_hashkey string COMMENT 'Tham chiếu Hub account',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_deposits_nominated_account ALTER COLUMN link_deposits_nominated_account_hashkey SET NOT NULL;
ALTER TABLE link_deposits_nominated_account ADD CONSTRAINT link_deposits_nominated_account_pk PRIMARY KEY (link_deposits_nominated_account_hashkey);



CREATE OR REPLACE TABLE link_deposits_repay_account (
    link_deposits_repay_account_hashkey string COMMENT 'Link Hash Key',
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits',
    account_hashkey string COMMENT 'Tham chiếu Hub account',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_deposits_repay_account ALTER COLUMN link_deposits_repay_account_hashkey SET NOT NULL;
ALTER TABLE link_deposits_repay_account ADD CONSTRAINT link_deposits_repay_account_pk PRIMARY KEY (link_deposits_repay_account_hashkey);



CREATE OR REPLACE TABLE hub_customer (
    customer_hashkey string COMMENT 'Hub Hash Key (hash(ID))',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_customer ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE hub_customer ADD CONSTRAINT hub_customer_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE hub_acct_officer (
    dept_acct_officer_hashkey string COMMENT 'Hub Hash Key NVBH (kỹ thuật)',
    business_key string COMMENT 'Business Key: Mã NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_acct_officer ALTER COLUMN dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE hub_acct_officer ADD CONSTRAINT hub_acct_officer_pk PRIMARY KEY (dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE hub_user (
    user_hashkey string COMMENT 'Hub Hash Key User (kỹ thuật)',
    business_key string COMMENT 'Business Key: Mã người dùng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_user ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE hub_user ADD CONSTRAINT hub_user_pk PRIMARY KEY (user_hashkey);



CREATE OR REPLACE TABLE hub_branch (
    branch_hashkey string COMMENT 'Hub Hash Key Chi nhánh (kỹ thuật)',
    business_key string COMMENT 'Business Key: Mã chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_branch ALTER COLUMN branch_hashkey SET NOT NULL;
ALTER TABLE hub_branch ADD CONSTRAINT hub_branch_pk PRIMARY KEY (branch_hashkey);



CREATE OR REPLACE TABLE hub_product_package_partner (
    product_package_partner_hashkey string COMMENT 'Hub Hash Key Product Package Partner',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_product_package_partner ALTER COLUMN product_package_partner_hashkey SET NOT NULL;
ALTER TABLE hub_product_package_partner ADD CONSTRAINT hub_product_package_partner_pk PRIMARY KEY (product_package_partner_hashkey);



CREATE OR REPLACE TABLE sat_customer_information (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    name_1 string COMMENT 'Tên đầy đủ',
    short_name string COMMENT 'Tên viết tắt',
    name_2 string COMMENT 'Tên tiếng Anh',
    family_name string COMMENT 'Họ tên đệm',
    birth_incorp_date string COMMENT 'Ngày sinh/Ngày thành lập',
    gender string COMMENT 'Giới tính',
    title string COMMENT 'Danh xưng',
    nationality string COMMENT 'Quốc tịch',
    residence string COMMENT 'Quốc gia cư trú',
    education_level string COMMENT 'Trình độ học vấn',
    language string COMMENT 'Ngôn ngữ',
    cifcontactdate string COMMENT 'Ngày phát sinh giao dịch đầu tiên',
    create_date string COMMENT 'Ngày mở CIF',
    inputter string COMMENT 'User nhập',
    authoriser string COMMENT 'User duyệt',
    occupation string COMMENT 'Nghề nghiệp',
    cu_profession string COMMENT 'Nghề nghiệp (chuẩn KH)',
    job_title string COMMENT 'Chức vụ',
    seniority string COMMENT 'Ngày bắt đầu làm việc',
    imp_exp_busines string COMMENT 'Hoạt động XNK',
    marital_status string COMMENT 'TT hôn nhân (*)',
    mnemonic string COMMENT 'Mã viết tắt',
    target bigint COMMENT 'Mục tiêu',
    labour_number bigint COMMENT 'Số lượng lao động',
    given_names string COMMENT 'Tên   (*)',
    date_time string COMMENT 'Trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_information ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_information ADD CONSTRAINT sat_customer_information_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_customer_other (
    customer_hashkey string COMMENT 'Tham chiếu Hub Khách hàng',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    post_code string COMMENT 'Không dùng ',
    customer_liability bigint COMMENT 'Không dùng ',
    contact_date string COMMENT 'Không dùng ',
    province bigint COMMENT 'Không dùng ',
    fax_1 string COMMENT 'Không dùng ',
    legacy_ref string COMMENT 'Không dùng ',
    posting_restrict bigint COMMENT 'Không dùng ',
    black_listed string COMMENT 'Không dùng ',
    curr_company string COMMENT 'Không dùng ',
    email_2 string COMMENT 'Không dùng ',
    introducer string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_other ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_other ADD CONSTRAINT sat_customer_other_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_customer_extra_information (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_comp_under_1y string COMMENT 'DN dưới 1 năm',
    t_comp_fi_statement string COMMENT 'Doanh nghiệp cung cấp BCTC',
    t_ld_gua_by_deposit string COMMENT 'Khoản vay/Bảo lãnh/LC được đảm bảo 100% bằng HĐTG/STK/',
    t_sale_income string COMMENT 'Doanh thu thuần',
    t_total_debt_loan string COMMENT 'Tổng nợ vay',
    t_equity string COMMENT 'Tổng tài sản',
    t_labour_number string COMMENT 'SL lao động',
    t_cus_income string COMMENT 'Tổng thu nhập trong năm của KH',
    t_total_in_date string COMMENT 'Thời điểm báo cáo',
    t_total_income string COMMENT 'Tổng thu nhập',
    t_total_property string COMMENT 'Tổng tài sản',
    t_inputter string COMMENT 'Người nhâp',
    t_authoriser string COMMENT 'Người duyêt',
    t_date_time string COMMENT 'Ngày giờ cập nhập'
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_extra_information ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_extra_information ADD CONSTRAINT sat_customer_extra_information_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_customer_contact (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    address string COMMENT 'Địa chỉ (số nhà, đường)',
    ward_1 string COMMENT 'Xã/Phường cư trú',
    town_country string COMMENT 'Quận/Huyện cư trú',
    province_1 string COMMENT 'Tỉnh/Thành thường trú',
    phone_1 string COMMENT 'SĐT nhà',
    sms_1 string COMMENT 'SĐT di động',
    off_phone string COMMENT 'SĐT nơi làm việc',
    email_1 string COMMENT 'Email 1',
    contact_person string COMMENT 'Người liên hệ',
    contact_title string COMMENT 'Chức vụ người liên hệ',
    status_contact string COMMENT 'Tình trạng liên hệ',
    company_name string COMMENT 'Tên công ty',
    bussiness_addr string COMMENT 'Địa chỉ công ty',
    representative string COMMENT 'Người đại diện PL',
    represent_job string COMMENT 'Chức vụ người đại diện PL',
    legal_id_deputy string COMMENT 'Số GTTT người đại diện',
    country string COMMENT 'Quốc tịch người liên hệ',
    street string COMMENT 'Địa chỉ cư trú nước ngoài',
    add_num string COMMENT 'Số nhà, đường',
    ward_2 string COMMENT 'Xã/ phường thường trú',
    province_2 string COMMENT 'Tỉnh thành cư trú',
    town_country_2 string COMMENT 'Quận huyện',
    sms_2 string COMMENT 'Lưu giá trị Số điện thoại DĐ của CIF có mối quan hệ (CIF mối quan hệ là cá nhân)',
    phone_2 string COMMENT 'Số điện thoại nhà',
    off_phone_2 string COMMENT 'Số điện thoại nơi làm việc'
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_contact ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_contact ADD CONSTRAINT sat_customer_contact_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_customer_classification (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    sector bigint COMMENT 'Mã ngành kinh tế (sector)',
    industry bigint COMMENT 'Ngành kinh tế',
    sub_industry string COMMENT 'Ngành chi tiết',
    classification string COMMENT 'Phân khúc khách hàng',
    cus_type string COMMENT 'Loại khách hàng',
    customer_status bigint COMMENT 'Trạng thái KH',
    customer_act string COMMENT 'Tình trạng KH',
    cust_group string COMMENT 'Phân loại khách hàng',
    asset_class bigint COMMENT 'Nhóm nợ của khách hàng',
    relation_code string COMMENT 'Mã mối quan hệ',
    ca_man string COMMENT 'Nhân viên hỗ trợ TD'
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_classification ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_classification ADD CONSTRAINT sat_customer_classification_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_customer_kyc (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    legal_doc_name string COMMENT 'Loại giấy tờ',
    legal_id string COMMENT 'Số giấy tờ',
    legal_iss_auth string COMMENT 'Mã nơi cấp',
    legal_iss_date string COMMENT 'Ngày cấp',
    legal_holder_name string COMMENT 'Tên nơi cấp',
    legal_exp_date string COMMENT 'Ngày hết hạn GTTT',
    tax_id string COMMENT 'Mã số thuế',
    text string COMMENT 'Đặc điểm KH (free text)'
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_kyc ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_kyc ADD CONSTRAINT sat_customer_kyc_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_customer_financial_statement (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    total_property string COMMENT 'Tổng tài sản',
    total_income string COMMENT 'Tổng doanh thu',
    sale_income string COMMENT 'Doanh thu thuần',
    profit_bf_tax string COMMENT 'Lợi nhuận trước thuế',
    plan_revenue string COMMENT 'Doanh thu kế hoạch năm',
    commit_revenue string COMMENT 'Doanh thu cam kết',
    commit_date string COMMENT 'Ngày cam kết DT',
    charter_capital string COMMENT 'Vốn điều lệ',
    net_monthly_in bigint COMMENT 'Thu nhập hàng tháng',
    income_source string COMMENT 'Nguồn thu nhập',
    income_by string COMMENT 'Phương thức nhận TN'
) CLUSTER BY AUTO;
ALTER TABLE sat_customer_financial_statement ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_customer_financial_statement ADD CONSTRAINT sat_customer_financial_statement_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_acct_officer_information (
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_name string COMMENT 'Tên NVBH',
    t_telephone_no string COMMENT 'Số điện thoại NVBH',
    t_emp_hr_code string COMMENT 'Mã HR (iHRP)',
    t_t24_id string COMMENT 'Mã T24 ID (nếu có)',
    t_active string COMMENT 'Tình trạng NVBH (Active/Inactive)',
    t_area string COMMENT 'Khu vực phụ trách',
    t_position_id string COMMENT 'Mã chức vụ',
    t_curr_no bigint COMMENT 'Số thứ tự bản ghi (hệ thống)',
    t_inputter string COMMENT 'Người nhập (hệ thống)',
    t_authoriser string COMMENT 'Người duyệt (hệ thống)',
    t_date_time string COMMENT 'Ngày/giờ thực hiện (hệ thống)',
    t_record_status string COMMENT 'Tình trạng bản ghi (Trường hệ thống)',
    t_domain string COMMENT 'Mail domain OCB'
) CLUSTER BY AUTO;
ALTER TABLE sat_acct_officer_information ALTER COLUMN dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE sat_acct_officer_information ADD CONSTRAINT sat_acct_officer_information_pk PRIMARY KEY (dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE sat_acct_officer_other (
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_delivery_point string COMMENT 'Không dùng ',
    t_restr_to_comps string COMMENT 'Không dùng ',
    t_prohibit_comps string COMMENT 'Không dùng ',
    t_fax_no string COMMENT 'Không dùng ',
    t_telex_no string COMMENT 'Không dùng ',
    t_auditor_code string COMMENT 'Không dùng ',
    t_audit_date_time string COMMENT 'Không dùng ',
    t_dept_level string COMMENT 'Không dùng ',
    t_dept_parent string COMMENT 'Không dùng ',
    t_alt_dept_level string COMMENT 'Không dùng ',
    t_alt_dept_parent string COMMENT 'Không dùng ',
    t_mnemonic string COMMENT 'Không dùng ',
    t_department string COMMENT 'Không dùng ',
    t_accept_message string COMMENT 'Không dùng ',
    t_dept_code string COMMENT 'Không dùng ',
    t_rm_create_date string COMMENT 'Không dùng ',
    t_comp_report string COMMENT 'Không dùng ',
    t_cust_group string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_acct_officer_other ALTER COLUMN dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE sat_acct_officer_other ADD CONSTRAINT sat_acct_officer_other_pk PRIMARY KEY (dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE sat_user_information (
    user_hashkey string COMMENT 'Tham chiếu Hub User',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_user_name string COMMENT 'Tên hiển thị người dùng',
    t_sign_on_name string COMMENT 'Tên đăng nhập',
    t_language bigint COMMENT 'Ngôn ngữ',
    t_start_date_profile string COMMENT 'Ngày bắt đầu profile',
    t_end_date_profile string COMMENT 'Ngày kết thúc profile',
    t_start_time string COMMENT 'Giờ bắt đầu làm việc',
    t_end_time string COMMENT 'Giờ kết thúc làm việc',
    t_time_out_minutes bigint COMMENT 'Thời gian timeout (phút)',
    t_init_application string COMMENT 'Ứng dụng khởi tạo mặc định',
    t_passw_change_date string COMMENT 'Ngày đổi mật khẩu',
    t_passw_end_date string COMMENT 'Ngày hết hạn mật khẩu',
    t_inputter string COMMENT 'Người nhập (hệ thống)',
    t_date_time string COMMENT 'Ngày/giờ thao tác (hệ thống)',
    t_authoriser string COMMENT 'Người duyệt (hệ thống)'
) CLUSTER BY AUTO;
ALTER TABLE sat_user_information ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sat_user_information ADD CONSTRAINT sat_user_information_pk PRIMARY KEY (user_hashkey);



CREATE OR REPLACE TABLE sat_user_other (
    user_hashkey string COMMENT 'Tham chiếu Hub Người dùng',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_password_validity string COMMENT 'Không dùng ',
    t_attempts bigint COMMENT 'Không dùng ',
    t_customer string COMMENT 'Không dùng ',
    t_account string COMMENT 'Không dùng ',
    t_application string COMMENT 'Không dùng ',
    t_version string COMMENT 'Không dùng ',
    t_function string COMMENT 'Không dùng ',
    t_field_no string COMMENT 'Không dùng ',
    t_data_comparison string COMMENT 'Không dùng ',
    t_data_from string COMMENT 'Không dùng ',
    t_data_to string COMMENT 'Không dùng ',
    t_sign_on_off_log string COMMENT 'Không dùng ',
    t_security_mgmt_l string COMMENT 'Không dùng ',
    t_application_log string COMMENT 'Không dùng ',
    t_function_id_log string COMMENT 'Không dùng ',
    t_input_day_month string COMMENT 'Không dùng ',
    t_attempts_since bigint COMMENT 'Không dùng ',
    t_date_last_sign_on string COMMENT 'Không dùng ',
    t_clear_screen string COMMENT 'Không dùng ',
    t_dealer_desk string COMMENT 'Không dùng ',
    t_comp_report string COMMENT 'Không dùng ',
    t_ocb_department string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_user_other ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sat_user_other ADD CONSTRAINT sat_user_other_pk PRIMARY KEY (user_hashkey);



CREATE OR REPLACE TABLE sat_user_classification (
    user_hashkey string COMMENT 'Tham chiếu Hub User',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_classification string COMMENT 'Phân loại người dùng',
    t_department_code bigint COMMENT 'Mã phòng ban',
    t_company_restr string COMMENT 'Giới hạn theo công ty',
    t_attributes string COMMENT 'Thuộc tính bổ sung (key/value)'
) CLUSTER BY AUTO;
ALTER TABLE sat_user_classification ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sat_user_classification ADD CONSTRAINT sat_user_classification_pk PRIMARY KEY (user_hashkey);



CREATE OR REPLACE TABLE sat_branch_information (
    branch_hashkey string COMMENT 'Tham chiếu Hub Chi nhánh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_mnemonic string COMMENT 'Tên tắt chi nhánh',
    t_company_name string COMMENT 'Tên chi nhánh'
) CLUSTER BY AUTO;
ALTER TABLE sat_branch_information ALTER COLUMN branch_hashkey SET NOT NULL;
ALTER TABLE sat_branch_information ADD CONSTRAINT sat_branch_information_pk PRIMARY KEY (branch_hashkey);



CREATE OR REPLACE TABLE sat_cust_package (
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_product_package_id string COMMENT 'Mã gói TKTM',
    t_begin_date string COMMENT 'Ngày bắt đầu /Ngày áp dụng',
    t_expire_date string COMMENT 'Ngày đóng gói TK',
    t_curr_no string COMMENT 'Số bản ghi',
    t_inputter string COMMENT 'User nhập',
    t_date_time string COMMENT 'Ngày thực hiện',
    t_authoriser string COMMENT 'User duyệt',
    t_dept_code string COMMENT 'Mã phòng ban',
    t_account_charge string COMMENT 'Số tài khoản gắn gói',
    -- crt_tm timestamp COMMENT 'Không có trong bảng OCBH.CUS.PACKAGE'
    t_partner_id string COMMENT 'Mã ưu đãi đối tác'
) CLUSTER BY AUTO;
ALTER TABLE sat_cust_package ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_cust_package ADD CONSTRAINT sat_cust_package_pk PRIMARY KEY (customer_hashkey);



CREATE OR REPLACE TABLE sat_product_package_partner (
    product_package_partner_hashkey string COMMENT 'Tham chiếu Hub Product Package Partner',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_partner_name string COMMENT 'Tên gói ưu đãi đối tác',
    t_ac_manage_fee_per string COMMENT 'Phần trăm ưu đãi phí quản lý TK',
    t_ac_manage_fee_term string COMMENT 'Thời hạn ưu đãi phí quản lý TK',
    t_ext_ft_fee_per string COMMENT 'Phần trăm ưu đãi phí chuyển tiền ngoài hệ thống',
    t_ext_ft_fee_term string COMMENT 'Thời hạn ưu đãi phí chuyển tiền ngoài hệ thống',
    t_ib_fee_per string COMMENT 'Phần trăm ưu đãi phí ebanking',
    t_ib_fee_term string COMMENT 'Thời hạn ưu đãi phí ebanking',
    t_mb_fee_per string COMMENT 'Phần trăm ưu đãi phí Mobile banking',
    t_mb_fee_term string COMMENT 'Thời hạn ưu đãi phí Mobile banking',
    t_sms_fee_per string COMMENT 'Phần trăm ưu đãi phí SMS',
    t_sms_fee_term string COMMENT 'Thời hạn ưu đãi phí SMS',
    t_package_fdate string COMMENT 'Ngày bắt đầu',
    t_package_tdate string COMMENT 'Ngày kết thúc',
    t_prod_package_id string COMMENT 'Mã gói TKTM áp dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_product_package_partner ALTER COLUMN product_package_partner_hashkey SET NOT NULL;
ALTER TABLE sat_product_package_partner ADD CONSTRAINT sat_product_package_partner_pk PRIMARY KEY (product_package_partner_hashkey);



CREATE OR REPLACE TABLE link_product_package_partner_customer (
    link_product_package_partner_customer_hashkey string COMMENT 'Link HK',
    product_package_partner_hashkey string COMMENT 'Tham chiếu Hub Product Package Partner',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_product_package_partner_customer ALTER COLUMN link_product_package_partner_customer_hashkey SET NOT NULL;
ALTER TABLE link_product_package_partner_customer ADD CONSTRAINT link_product_package_partner_customer_pk PRIMARY KEY (link_product_package_partner_customer_hashkey);



CREATE OR REPLACE TABLE link_customer_branch (
    link_customer_branch_hashkey string COMMENT 'Link Hash Key',
    customer_hashkey string COMMENT 'Hub KH',
    branch_hashkey string COMMENT 'Hub chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_customer_branch ALTER COLUMN link_customer_branch_hashkey SET NOT NULL;
ALTER TABLE link_customer_branch ADD CONSTRAINT link_customer_branch_pk PRIMARY KEY (link_customer_branch_hashkey);



CREATE OR REPLACE TABLE link_customer_dept_acct_officer_nvql (
    link_customer_dept_acct_officer_nvql_hashkey string COMMENT 'Link Hash Key',
    customer_hashkey string COMMENT 'Hub KH gốc',
    dept_acct_officer_hashkey string COMMENT 'Hub NV giới thiệu',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_customer_dept_acct_officer_nvql ALTER COLUMN link_customer_dept_acct_officer_nvql_hashkey SET NOT NULL;
ALTER TABLE link_customer_dept_acct_officer_nvql ADD CONSTRAINT link_customer_dept_acct_officer_nvql_pk PRIMARY KEY (link_customer_dept_acct_officer_nvql_hashkey);



CREATE OR REPLACE TABLE link_customer_dept_acct_officer_nvgt (
    link_customer_dept_acct_officer_nvgt_hashkey string COMMENT 'Link Hash Key',
    customer_hashkey string COMMENT 'Hub KH gốc',
    dept_acct_officer_hashkey string COMMENT 'Hub NV giới thiệu',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_customer_dept_acct_officer_nvgt ALTER COLUMN link_customer_dept_acct_officer_nvgt_hashkey SET NOT NULL;
ALTER TABLE link_customer_dept_acct_officer_nvgt ADD CONSTRAINT link_customer_dept_acct_officer_nvgt_pk PRIMARY KEY (link_customer_dept_acct_officer_nvgt_hashkey);



CREATE OR REPLACE TABLE link_customer_related_customer (
    link_cust_relcust_hashkey string COMMENT 'Link Hash Key',
    customer_hashkey string COMMENT 'Hub KH gốc',
    related_customer_hashkey string COMMENT 'Hub KH liên quan',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_customer_related_customer ALTER COLUMN link_cust_relcust_hashkey SET NOT NULL;
ALTER TABLE link_customer_related_customer ADD CONSTRAINT link_customer_related_customer_pk PRIMARY KEY (link_cust_relcust_hashkey);



CREATE OR REPLACE TABLE link_acct_officer_branch (
    link_dept_acct_officer_branch_hashkey string COMMENT 'Link Hash Key (HASH(HK_NVHB, HK_BRANCH))',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    branch_hashkey string COMMENT 'Tham chiếu Hub chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_acct_officer_branch ALTER COLUMN link_dept_acct_officer_branch_hashkey SET NOT NULL;
ALTER TABLE link_acct_officer_branch ADD CONSTRAINT link_acct_officer_branch_pk PRIMARY KEY (link_dept_acct_officer_branch_hashkey);



CREATE OR REPLACE TABLE link_user_customer (
    link_user_customer_hashkey string COMMENT 'Link Hash Key (HASH(HK_USER, HK_CUSTOMER))',
    user_hashkey string COMMENT 'Tham chiếu Hub User',
    customer_hashkey string COMMENT 'Tham chiếu Hub KH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_user_customer ALTER COLUMN link_user_customer_hashkey SET NOT NULL;
ALTER TABLE link_user_customer ADD CONSTRAINT link_user_customer_pk PRIMARY KEY (link_user_customer_hashkey);



CREATE OR REPLACE TABLE link_user_account (
    link_user_account_hashkey string COMMENT 'Link Hash Key (HASH(HK_USER, HK_ACCOUNT))',
    user_hashkey string COMMENT 'Tham chiếu Hub User',
    account_hashkey string COMMENT 'Tham chiếu Hub Tài khoản',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_user_account ALTER COLUMN link_user_account_hashkey SET NOT NULL;
ALTER TABLE link_user_account ADD CONSTRAINT link_user_account_pk PRIMARY KEY (link_user_account_hashkey);



CREATE OR REPLACE TABLE link_cust_package_branch (
    link_cust_package_branch_hashkey string COMMENT 'Link HK',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_cust_package_branch ALTER COLUMN link_cust_package_branch_hashkey SET NOT NULL;
ALTER TABLE link_cust_package_branch ADD CONSTRAINT link_cust_package_branch_pk PRIMARY KEY (link_cust_package_branch_hashkey);



CREATE OR REPLACE TABLE hub_forex (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    business_key string COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_forex ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE hub_forex ADD CONSTRAINT hub_forex_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_classification (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_deal_type string COMMENT 'Loại deal',
    t_fx_type string COMMENT 'Local field Loại FX',
    t_category bigint COMMENT 'Mã category',
    t_buyfcy_pp string COMMENT 'Local field Mục đích mua bán ngoaiẹ tệ',
    t_deal_market string COMMENT 'Thị trường giao dịch',
    t_our_account_pay string COMMENT 'Tài khoản thanh toán',
    t_our_account_rec string COMMENT 'Tài khoản nhận tiền',
    t_co_code_inp string COMMENT 'Mã chi nhánh nhập giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_classification ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_classification ADD CONSTRAINT sat_forex_classification_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_information (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_deal_date string COMMENT 'Ngày tạo deal',
    t_value_date_buy string COMMENT 'Ngày mua',
    t_value_date_sell string COMMENT 'Ngày giá trị bán',
    t_currency_bought string COMMENT 'Mã ngoại tệ mua',
    t_currency_sold string COMMENT 'Mã ngoại tệ bán',
    t_base_ccy string COMMENT 'Đồng ngoại tệ cơ bản',
    t_amount_bought decimal(38,10) COMMENT 'Số lượng mua',
    t_amount_sold decimal(38,10) COMMENT 'Số lượng bán',
    t_spot_lcy_amount decimal(38,10) COMMENT 'Số tiền nội tệ SPOT',
    t_buy_lcy_equiv bigint COMMENT 'Số tiền nội tệ quy đổi của ngoại tệ mua',
    t_sel_lcy_equiv bigint COMMENT 'Số tiền nội tệ quy đổi của ngoại tệ bán',
    t_swap_base_ccy string COMMENT 'Mã ngoại tệ cơ bản cho gd Swap',
    t_limit_reference_no string COMMENT 'Mã hạn mức của KH',
    t_swap_ref_no string COMMENT 'Mã giao dịch chân kia cho giao dịch SW'
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_information ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_information ADD CONSTRAINT sat_forex_information_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_other (
    forex_hashkey string COMMENT 'Tham chiếu Hub Ngoại tệ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_bk_to_bk_inf string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_other ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_other ADD CONSTRAINT sat_forex_other_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_rate (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_exch_rate decimal(38,10) COMMENT 'Tỷ giá chuyển đổi',
    t_forward_rate decimal(38,10) COMMENT 'Tỷ giá forward',
    t_spot_rate decimal(38,10) COMMENT 'Tỷ giá spot'
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_rate ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_rate ADD CONSTRAINT sat_forex_rate_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_pricing_pnl (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ho_price string COMMENT 'Giá giao dịch của HO với chi nhánh',
    t_ho_crss_sell1 string COMMENT 'Bán chéo hội sở',
    t_cu_crss_sell1 string COMMENT 'Bán chéo khách hàng 1',
    t_cu_crss_sell2 string COMMENT 'Bán chéo khách hàng 2',
    t_branch_pnl string COMMENT 'Lãi lỗ của chi nhánh trong giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_pricing_pnl ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_pricing_pnl ADD CONSTRAINT sat_forex_pricing_pnl_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_payment_swift (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_r_ci_code string COMMENT 'Mã citad NH nhận( của FT)',
    t_ibps_bene string COMMENT 'Người thụ hưởng( của FT)',
    t_receiving_addr string COMMENT 'Địa chỉ người nhận( của FT)',
    t_ben_acct_no string COMMENT 'Tài khoản người nhận',
    t_cpy_corr_add string COMMENT 'Ngân hàng thụ hưởng',
    t_cparty_bank_acc string COMMENT 'Số tài khoản ngân hàng thụ hưởng',
    t_cparty_corr_no string COMMENT 'Mã CIF bank chỉ định thanh toán',
    t_send_confirmation string COMMENT 'Có gửi điện xác nhận',
    t_send_payment string COMMENT 'Có gửi điện thanh toán',
    t_send_advice string COMMENT 'Có gửi điện  thông báo',
    t_ocb_is_tag57a string COMMENT 'Local field Có tag 57A hay không',
    t_address string COMMENT 'Local field Địa chỉ',
    t_transaction_ref_no string COMMENT 'Mã giao dịch tham chiếu',
    t_trans_code string COMMENT 'Mã giao dịch (của FT)',
    t_mkfile_com string COMMENT 'Mã chi nhánh tạo điện citad ( của FT)'
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_payment_swift ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_payment_swift ADD CONSTRAINT sat_forex_payment_swift_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE sat_forex_audit_status (
    forex_hashkey string COMMENT 'Hub Hash Key Forex',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_status string COMMENT 'Trạng thái giao dịch',
    t_record_status string COMMENT 'Trạng thái bản ghi',
    t_dealer_desk string COMMENT 'Mã dealer desk',
    t_group_partner string COMMENT 'Local field Nhóm đối tác',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày nhập duyệt',
    t_curr_no string COMMENT 'Số thứ tự bản ghi',
    t_pst_immdt string COMMENT 'Local field Post giao dịch ngay',
    t_override string COMMENT 'Thông báo override',
    t_dealer_notes string COMMENT 'Nội dung giao dịch',
    t_notes string COMMENT 'Nội dung giao dịch',
    t_contact_name string COMMENT 'Người liên hệ',
    t_national_id string COMMENT 'Local field Số giấy tờ'
) CLUSTER BY AUTO;
ALTER TABLE sat_forex_audit_status ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sat_forex_audit_status ADD CONSTRAINT sat_forex_audit_status_pk PRIMARY KEY (forex_hashkey);



CREATE OR REPLACE TABLE link_forex_customer (
    link_forex_customer_hashkey string COMMENT 'Link HK',
    forex_hashkey string COMMENT 'Tham chiếu Hub Forex',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_forex_customer ALTER COLUMN link_forex_customer_hashkey SET NOT NULL;
ALTER TABLE link_forex_customer ADD CONSTRAINT link_forex_customer_pk PRIMARY KEY (link_forex_customer_hashkey);



CREATE OR REPLACE TABLE link_forex_branch (
    link_forex_branch_hashkey string COMMENT 'Link HK',
    forex_hashkey string COMMENT 'Tham chiếu Hub Forex',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_forex_branch ALTER COLUMN link_forex_branch_hashkey SET NOT NULL;
ALTER TABLE link_forex_branch ADD CONSTRAINT link_forex_branch_pk PRIMARY KEY (link_forex_branch_hashkey);



CREATE OR REPLACE TABLE link_forex_dept_acct_officer (
    link_forex_dept_acct_officer_hashkey string COMMENT 'Link HK',
    forex_hashkey string COMMENT 'Tham chiếu Hub Forex',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub Acct Officer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_forex_dept_acct_officer ALTER COLUMN link_forex_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_forex_dept_acct_officer ADD CONSTRAINT link_forex_dept_acct_officer_pk PRIMARY KEY (link_forex_dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE hub_limit (
    limit_hashkey string COMMENT 'Hub Hash Key hạn mức',
    business_key string COMMENT 'Business Key: Mã hạn mức',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_limit ALTER COLUMN limit_hashkey SET NOT NULL;
ALTER TABLE hub_limit ADD CONSTRAINT hub_limit_pk PRIMARY KEY (limit_hashkey);



CREATE OR REPLACE TABLE sat_limit_information (
    limit_hashkey string COMMENT 'Hub Hash Key hạn mức',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_limit_currency string COMMENT 'Loại tiền tệ',
    t_collateral_code string COMMENT 'Mã TSĐB',
    t_collat_right string COMMENT 'Mã loại TSĐB',
    t_maximum_secured string COMMENT 'Hạn mức có TSĐB',
    t_maximum_unsecured decimal(38,10) COMMENT 'Hạn mức tín chấp',
    t_expiry_date string COMMENT 'Ngày hết hiệu lực',
    t_limit_product bigint COMMENT 'Sản phẩm hạn mức',
    t_liability_number bigint COMMENT 'Mã khách hàng',
    t_approval_date string COMMENT 'Ngày phê duyệt',
    t_fixed_variable string COMMENT 'Cố định / Biến đổi (Fixed/Variable/None)',
    t_internal_amount decimal(38,10) COMMENT 'Giá trị hạn mức',
    t_maximum_total decimal(38,10) COMMENT 'Tổng hạn mức được cấp',
    t_online_limit_date string COMMENT 'Ngày hiệu lực',
    t_online_limit string COMMENT 'Hạn mức được cấp',
    t_total_os string COMMENT 'Hạn mức đã sử dụng',
    t_avail_amt string COMMENT 'Hạn mức còn lại',
    t_other_secured string COMMENT 'Hạn mức chưa có đảm bảo',
    t_collat_amount string COMMENT 'Giá trị tài sản',
    t_secured_amt string COMMENT 'Hạn mức có TSĐB',
    t_available_marker string COMMENT 'Tình trạng hạn mức',
    t_os_ccy string COMMENT 'Loại tiền dư nợ',
    t_os_amt string COMMENT 'Số tiền dư nợ',
    t_allowed_comp string COMMENT 'Chi nhánh được sử dụng',
    t_product_allowed string COMMENT 'Sản phẩm hạn mức',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_disb_exp_date string COMMENT 'Ngày hết hạn giải ngân',
    t_record_parent string COMMENT 'Hạn mức cha',
    t_credit_line string COMMENT 'Hạn mức tổng thể',
    t_notes string COMMENT 'Ghi chú',
    t_review_frequency string COMMENT 'Tần suất đánh giá',
    t_reducing_limit string COMMENT 'Hạn mức giảm dần',
    t_account string COMMENT 'TK gắn HMTC'
) CLUSTER BY AUTO;
ALTER TABLE sat_limit_information ALTER COLUMN limit_hashkey SET NOT NULL;
ALTER TABLE sat_limit_information ADD CONSTRAINT sat_limit_information_pk PRIMARY KEY (limit_hashkey);



CREATE OR REPLACE TABLE link_limit (
    link_limit_hashkey string COMMENT 'Link HK',
    limit_parent_hashkey string COMMENT 'Hub Hash Key hạn mức cha',
    limit_child_hashkey string COMMENT 'Hub Hash Key hạn mức con',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_limit ALTER COLUMN link_limit_hashkey SET NOT NULL;
ALTER TABLE link_limit ADD CONSTRAINT link_limit_pk PRIMARY KEY (link_limit_hashkey);



CREATE OR REPLACE TABLE link_limit_branch (
    link_limit_branch_hashkey string COMMENT 'Link HK',
    limit_hashkey string COMMENT 'Hub Hash Key hạn mức',
    branch_hashkey string COMMENT 'Hub Hash Key chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_limit_branch ALTER COLUMN link_limit_branch_hashkey SET NOT NULL;
ALTER TABLE link_limit_branch ADD CONSTRAINT link_limit_branch_pk PRIMARY KEY (link_limit_branch_hashkey);



CREATE OR REPLACE TABLE hub_loans (
    loans_hashkey string COMMENT 'Hub Hash Key Hợp đồng tín dụng',
    business_key string COMMENT 'Business Key: Mã hợp đồng tín dụng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_loans ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE hub_loans ADD CONSTRAINT hub_loans_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE hub_loans_payment_due (
    loans_payment_due_hashkey string COMMENT 'Hub Hash Key Hợp đồng tín dụng quá hạn',
    business_key string COMMENT 'Business Key: Mã hợp đồng tín dụng quá hạn',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_loans_payment_due ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE hub_loans_payment_due ADD CONSTRAINT hub_loans_payment_due_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_loans_information (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_legacy_ref string COMMENT 'Số hợp đồng bán nợ (legacy)',
    t_link_reference string COMMENT 'Số hợp đồng tham chiếu',
    t_vmb_ln_class int COMMENT 'Nhóm nợ',
    t_ln_class_manual string COMMENT 'Phân loại nợ thủ công',
    t_status string COMMENT 'Trạng thái khoản vay',
    t_ocb_class_covid string COMMENT 'Nhóm nợ COVID/cơ cấu',
    t_amount decimal(38,10) COMMENT 'Số tiền giải ngân (kế hoạch)',
    t_drawdown_net_amt decimal(20,4) COMMENT 'Số tiền giải ngân thực tế',
    t_purpose_amt string COMMENT 'Số tiền theo mục đích vay',
    t_amount_increase string COMMENT 'Tiền gốc tăng/giảm',
    t_ocb_ln_hold_cif string COMMENT 'Mã khách hàng đồng vay',
    t_drawdown_account string COMMENT 'Tài khoản giải ngân cho KH',
    t_ocb_ln_hold_rel string COMMENT 'Quan hệ với KH chính',
    t_currency string COMMENT 'Loại tiền',
    -- t_purpose_amt_orig decimal(20,4) COMMENT 'Số tiền mục đích vay đầu tiên',
    t_doubtful_sta int COMMENT 'Tình trạng món vay chờ xử lý / nợ khoanh vùng',
    t_linked_tfdr_ref string COMMENT 'Mã tham chiếu tài trợ thương mại',
    t_fee_pay_account string COMMENT 'Tài khoản thu phí',
    t_prin_liq_acct string COMMENT 'Tài khoản thanh toán gốc',
    t_int_liq_acct string COMMENT 'Tài khoản thanh toán lãi',
    t_limit_reference string COMMENT 'Tham chiếu hạn mức'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_information ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_information ADD CONSTRAINT sat_loans_information_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_terms (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_term string COMMENT 'Kỳ hạn khoản vay (hiện tại)',
    t_org_term string COMMENT 'Kỳ hạn gốc ban đầu',
    t_value_date string COMMENT 'Ngày giá trị',
    t_fin_mat_date string COMMENT 'Ngày đáo hạn',
    t_amt_v_date string COMMENT 'Ngày hiệu lực số tiền',
    t_bpm_disb_id string COMMENT 'Mã giao dịch giải ngân BPM',
    t_ocb_ln_end_date string COMMENT 'Ngày kết thúc HĐTD',
    t_orig_val_date string COMMENT 'Ngày ký HĐTD'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_terms ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_terms ADD CONSTRAINT sat_loans_terms_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_rate (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_interest_rate decimal(38,10) COMMENT 'Lãi suất cố định',
    t_interest_spread decimal(38,10) COMMENT 'Biên độ lãi suất',
    t_new_spread string COMMENT 'Biên độ kỳ tiếp theo',
    t_int_rate_v_date string COMMENT 'Ngày hiệu lực lãi suất thay đổi',
    t_spread_v_date string COMMENT 'Ngày áp dụng LS thả nổi',
    t_interest_key int COMMENT 'Khoá lãi suất (thả nổi)',
    t_int_key_name string COMMENT 'Tên công thức tính lãi',
    t_int_rate_type int COMMENT 'Loại lãi suất',
    t_interest_basis string COMMENT 'Cơ sở tính lãi',
    t_ocbint_chg_typ string COMMENT 'Kiểu thay đổi lãi suất OCB',
    t_ocbint_chg_date string COMMENT 'Ngày bắt đầu thay đổi lãi suất',
    t_ocb_int_supprt string COMMENT 'CT hỗ trợ lãi suất CP',
    t_ocb_date_supprt string COMMENT 'Ngày hiệu lực hỗ trợ LS',
    t_tot_interest_amt decimal(20,4) COMMENT 'Tổng số lãi',
    t_min_contract_rate decimal(20,10) COMMENT 'Lãi suất tối thiểu'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_rate ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_rate ADD CONSTRAINT sat_loans_rate_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_classification (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_category bigint COMMENT 'Nhóm sản phẩm vay',
    t_loan_subproduct int COMMENT 'Sản phẩm vay',
    t_loan_method string COMMENT 'Phương thức vay',
    t_loan_purpose string COMMENT 'Mục đích vay',
    t_ld_cust_group string COMMENT 'Khối quản lý',
    t_cu_cust_group string COMMENT 'Loại khách hàng',
    t_ocb_prod_main string COMMENT 'Sản phẩm chính',
    t_ocb_pro_bundle string COMMENT 'Gói sản phẩm vay',
    t_ocb_promotion string COMMENT 'Gói khuyến mãi OCB',
    t_ocb_pro_partner string COMMENT 'Mã đối tác liên kết với khoản vay',
    t_source_of_fund string COMMENT 'Nguồn cho vay',
    t_ocb_outof_area string COMMENT 'Ngoài địa bàn OCB (flag)',
    t_industry_lev1 string COMMENT 'Ngành kinh tế level 1',
    t_industry_lev2 string COMMENT 'Ngành kinh tế level 2',
    t_industry_lev3 string COMMENT 'Ngành kinh tế level 3',
    t_industry_levo string COMMENT 'Ngành kinh tế level 0',
    t_industry_levt string COMMENT 'Ngành kinh tế level 2 (biến thể)',
    t_liquidation_mode string COMMENT 'Phương thức tất toán khoản vay',
    t_extend_sch string COMMENT 'Cơ cấu lại nợ',
    t_vmb_class_date string COMMENT 'Ngày chuyển nhóm nợ',
    t_extendsch_date string COMMENT 'Ngày phân loại nợ thủ công',
    t_annuity_pay_method string COMMENT 'Khoản vay trả gốc đều mỗi kỳ',
    t_ocb_ln_hold_yn string COMMENT 'Khoản vay có người đồng vay (None/Y/N)'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_classification ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_classification ADD CONSTRAINT sat_loans_classification_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_approval (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ld_aprv_date string COMMENT 'Ngày phê duyệt',
    t_ld_aprv_level string COMMENT 'Cấp phê duyệt TD',
    t_ld_aprv_user string COMMENT 'Người phê duyệt',
    t_aprv_reval_user string COMMENT 'Người tái thẩm định',
    t_ld_aprv_ch_date string COMMENT 'Ngày phê duyệt thay đổi',
    t_aprv_ch_desc string COMMENT 'Nội dung thay đổi điều kiện',
    t_aprv_ch_level string COMMENT 'Cấp phê duyệt thay đổi',
    t_aprv_ch_user string COMMENT 'Người phê duyệt thay đổi',
    t_ap_rev_ch_user string COMMENT 'Người phê duyệt (biến thể)'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_approval ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_approval ADD CONSTRAINT sat_loans_approval_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_insurance (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ins_type string COMMENT 'Loại bảo hiểm',
    t_ins_company string COMMENT 'Công ty bảo hiểm',
    t_ins_contract string COMMENT 'Số HĐ bảo hiểm',
    t_ins_fee string COMMENT 'Phí bảo hiểm',
    t_ins_start string COMMENT 'Ngày hiệu lực bảo hiểm',
    t_ins_end string COMMENT 'Ngày hết hạn BH',
    t_ins_amount string COMMENT 'Số tiền bảo hiểm',
    t_ins_trans string COMMENT 'Số GD nộp phí',
    t_ins_sales_id string COMMENT 'NV bán bảo hiểm'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_insurance ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_insurance ADD CONSTRAINT sat_loans_insurance_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_system (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày/giờ thay đổi liên quan LD',
    t_curr_no string COMMENT 'Số dòng history'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_system ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_system ADD CONSTRAINT sat_loans_system_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_other (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_our_remarks string COMMENT 'Diễn giải của ngân hàng',
    t_cust_remarks string COMMENT 'Diễn giải của khách hàng',
    t_real_type string COMMENT 'Loại bất động sản',
    t_auto_name string COMMENT 'Nhãn hiệu xe',
    t_auto_type string COMMENT 'Loại xe',
    t_ins_auto_numpla string COMMENT 'Biển số xe được bảo hiểm',
    t_dept_code int COMMENT 'Mã phòng ban',
    t_bosc_comp_ref string COMMENT 'Công ty Chứng khoán liên quan',
    t_collaborator string COMMENT 'Cộng tác viên'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_other ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_other ADD CONSTRAINT sat_loans_other_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_schedule (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    -- t_data_date date COMMENT 'Ngày dữ liệu',
    t_k_date string COMMENT 'Ngày bắt đầu của lịch trả nợ',
    t_sch_type string COMMENT 'Loại kỳ trả nợ (P: Kỳ Trả gốc; I:Kỳ  trả lãi. R: Kỳ thay đổi lãi suất)',
    t_frequency string COMMENT 'Tần suất kỳ trả nợ(M: tháng',
    t_number string COMMENT 'Số kỳ trả nợ',
    t_cycled_dates string COMMENT 'các kỳ của lịch trả nợ',
    t_currency string COMMENT 'Loại tiền',
    t_amount string COMMENT 'Số tiền phải trả cho từng kỳ trả nợ',
    t_date_time string COMMENT 'Ngày giờ cập nhật thông tin thay đổi lịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_schedule ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_schedule ADD CONSTRAINT sat_loans_schedule_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_loans_payment_due_information (
    loans_payment_due_hashkey string COMMENT 'Tham chiếu Hub Loans Payment Due',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_payment_dte_due string COMMENT 'Ngày đến hạn thanh toán theo lịch',
    t_final_due_date string COMMENT 'Ngày kết thúc quá hạn/hết hạn HĐ',
    t_start_date string COMMENT 'Ngày giải ngân',
    t_currency string COMMENT 'Loại tiền tệ',
    t_consol_key string COMMENT 'Mã consol',
    t_payment_amount string COMMENT 'Số tiền cần thanh toán đến kỳ gần nhất',
    t_status string COMMENT 'Trạng thái khoản vay',
    t_repayment_acct string COMMENT 'Tài khoản thanh toán khoản vay',
    t_extendsch_date string COMMENT 'Ngày cơ cấu lại lịch trả nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_payment_due_information ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sat_loans_payment_due_information ADD CONSTRAINT sat_loans_payment_due_information_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_loans_payment_due_classification (
    loans_payment_due_hashkey string COMMENT 'Tham chiếu Hub Loans Payment Due',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_vmb_ln_class int COMMENT 'Nhóm nợ (VMB_LN_CLASS)',
    t_industry_lev1 string COMMENT 'Ngành kinh tế cấp 1',
    t_industry_lev3 string COMMENT 'Ngành kinh tế cấp 3',
    t_contract_grp string COMMENT 'Nhóm phân loại hợp đồng',
    t_ln_class_manual string COMMENT 'Chuyển nhóm nợ tay?',
    t_extend_sch string COMMENT 'Khoản vay cơ cấu lại (Y/N)',
    t_manual_nab string COMMENT 'Trạng thái NAB chỉnh tay',
    t_source_of_fund string COMMENT 'Nghiệp vụ ủy thác/đặc biệt',
    t_doubtful_sta string COMMENT 'Tình trạng chờ xử lý'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_payment_due_classification ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sat_loans_payment_due_classification ADD CONSTRAINT sat_loans_payment_due_classification_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_loans_payment_due_overdue (
    loans_payment_due_hashkey string COMMENT 'Tham chiếu Hub Loans Payment Due',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_pay_type string COMMENT 'Loại khoản mục quá hạn (IN/PR/PE/PS)',
    t_outstanding_amt string COMMENT 'Số tiền trong hạn chưa trả',
    t_penalty_rate decimal(21,10) COMMENT 'Lãi suất quá hạn',
    t_penalty_spread decimal(21,10) COMMENT 'Biên độ LS quá hạn',
    t_pay_amt_orig string COMMENT 'Số tiền đến hạn theo lịch',
    t_pay_amt_outs string COMMENT 'Số tiền đến hạn chưa thanh toán',
    t_total_overdue_amt string COMMENT 'Tổng tiền quá hạn',
    t_total_amt_to_repay string COMMENT 'Tổng cần trả (quá hạn + thuế)',
    t_tot_od_type_amt string COMMENT 'Tổng theo loại (PR/IN/PE/PS)',
    t_tot_ovrdue_type string COMMENT 'Danh mục khoản mục quá hạn',
    t_penalty_key string COMMENT 'Phí phạt trả nợ trễ hạn'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_payment_due_overdue ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sat_loans_payment_due_overdue ADD CONSTRAINT sat_loans_payment_due_overdue_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_loans_payment_due_repay (
    loans_payment_due_hashkey string COMMENT 'Tham chiếu Hub Loans Payment Due',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_repaid_status string COMMENT 'Trạng thái thanh toán',
    t_repayment_date string COMMENT 'Ngày trả (thực tế)',
    t_repay_amt string COMMENT 'Số tiền đã trả',
    t_repaid_amt string COMMENT 'Số tiền đã trả quá hạn',
    t_new_outs_amt string COMMENT 'Quá hạn mới sau điều chỉnh',
    t_repay_type string COMMENT 'Khoản mục thanh toán (PR/IN/PE/PS)',
    t_repay_default string COMMENT 'Số tiền mặc định',
    t_tot_repay_amt string COMMENT 'Tổng đã thanh toán quá hạn',
    t_repayment_ref string COMMENT 'Ghi chú/Ref thanh toán',
    t_repay_date string COMMENT 'Ngày theo lịch trả nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_payment_due_repay ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sat_loans_payment_due_repay ADD CONSTRAINT sat_loans_payment_due_repay_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_loans_payment_due_contract (
    loans_payment_due_hashkey string COMMENT 'Tham chiếu Hub Loans Payment Due',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_limit_reference string COMMENT 'Mã tham chiếu hạn mức hiện hành',
    t_orig_limit_ref string COMMENT 'Mã tham chiếu hạn mức cũ',
    t_link_reference string COMMENT 'Số hợp đồng tham chiếu',
    t_interest_basis string COMMENT 'Cơ sở tính lãi (360/365)',
    t_loan_spread string COMMENT 'Biên độ lãi trong hạn',
    t_limit_amount string COMMENT 'Số tiền hạn mức',
    t_parameter_record string COMMENT 'ID trong PD_PARAMETER',
    t_curr_no string COMMENT 'Số dòng history/bản ghi',
    t_bosc_comp_ref string COMMENT 'Thông tin bán nợ',
    t_ocbint_chg_date string COMMENT 'Ngày ký hợp đồng bán nợ',
    t_min_contrt_rate string COMMENT 'Tỷ lệ phí phải trả (Của hợp đồng bán nợ)',
    notes string COMMENT 'Ghi chú'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_payment_due_contract ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sat_loans_payment_due_contract ADD CONSTRAINT sat_loans_payment_due_contract_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_ld_aprv_information (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_aprv_dte string COMMENT 'Không dùng ',
    t_aprv_level string COMMENT 'Không dùng ',
    t_aprv_name string COMMENT 'Không dùng ',
    t_aprv_reval_name string COMMENT 'Không dùng ',
    t_aprv_chg_dte string COMMENT 'Không dùng ',
    t_aprv_chg_des string COMMENT 'Không dùng ',
    t_aprv_chg_level string COMMENT 'Không dùng ',
    t_aprv_chg_name string COMMENT 'Không dùng ',
    t_aprv_chg_revname string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_ld_aprv_information ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_ld_aprv_information ADD CONSTRAINT sat_ld_aprv_information_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_lmm_account_balances (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_date_from string COMMENT 'Ngày bắt đầu',
    t_effective_date string COMMENT 'ngày hiệu lực',
    t_trans_prin_amt string COMMENT 'số dư giao dich',
    t_outs_curr_princ string COMMENT 'số dư gốc',
    t_outs_accrued_int decimal(38,10) COMMENT 'số dự thu kỳ gần nhất đến hiện tại',
    t_start_period_int string COMMENT 'ngày bắt đầu kỳ lãi',
    t_end_period_int string COMMENT 'ngày kết thúc kỳ lãi',
    t_committed_int decimal(38,10) COMMENT 'lãi kỳ hiện tại',
    t_princ_int_bal string COMMENT 'số dư nợ tính lãi',
    t_int_amt_todate string COMMENT 'lãi tính đến ngày T_DATE_INT_ACC_TO',
    t_ac_int_rate string COMMENT 'lãi suất tính lãi',
    t_ac_int_spread string COMMENT 'biên độ tính lãi',
    t_date_int_acc_to string COMMENT 'ngày tính lãi',
    t_actual_acc_amt string COMMENT 'lãi tính đến ngày (số chưa làm tròn)',
    t_currency string COMMENT 'Loại tiền',
    t_outs_susp_int string COMMENT 'lãi treo'
) CLUSTER BY AUTO;
ALTER TABLE sat_lmm_account_balances ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_lmm_account_balances ADD CONSTRAINT sat_lmm_account_balances_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_lmm_account_balances_other (
    loans_hashkey string COMMENT 'Tham chiếu Hub Khoản vay',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_outs_accrued_comm bigint COMMENT 'Không dùng ',
    t_last_int_rev_date string COMMENT 'Không dùng ',
    t_next_int_rev_date string COMMENT 'Không dùng ',
    t_prev_int_st_date string COMMENT 'Không dùng ',
    t_int_accr_start string COMMENT 'Không dùng ',
    t_committed_comm bigint COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_lmm_account_balances_other ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_lmm_account_balances_other ADD CONSTRAINT sat_lmm_account_balances_other_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_ln_cust_revs_dtls (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_date string COMMENT 'Không dùng ',
    account_balance string COMMENT 'Không dùng ',
    total_accrual string COMMENT 'Không dùng ',
    contract_id string COMMENT 'Không dùng ',
    outs_amount string COMMENT 'Không dùng ',
    currency string COMMENT 'Không dùng ',
    k_type string COMMENT 'Không dùng ',
    outs_accr_int string COMMENT 'Không dùng ',
    stmt_no string COMMENT 'Không dùng ',
    t_line_no string COMMENT 'Không dùng ',
    t_account_no string COMMENT 'Không dùng ',
    t_pre_line_no string COMMENT 'Không dùng ',
    t_pre_account_no string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_ln_cust_revs_dtls ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_ln_cust_revs_dtls ADD CONSTRAINT sat_ln_cust_revs_dtls_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_pdpd_ln_cust_revs_dtls (
    loans_payment_due_hashkey string COMMENT 'Tham chiếu Hub Loans Payment Due',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_date string COMMENT 'Không dùng',
    account_balance string COMMENT 'Không dùng',
    total_accrual string COMMENT 'Không dùng',
    contract_id string COMMENT 'Không dùng',
    outs_amount string COMMENT 'Không dùng',
    currency string COMMENT 'Không dùng',
    k_type string COMMENT 'Không dùng',
    outs_accr_int string COMMENT 'Không dùng',
    stmt_no string COMMENT 'Không dùng',
    t_line_no string COMMENT 'Không dùng',
    t_account_no string COMMENT 'Không dùng',
    t_pre_line_no string COMMENT 'Không dùng',
    t_pre_account_no string COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdpd_ln_cust_revs_dtls ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sat_pdpd_ln_cust_revs_dtls ADD CONSTRAINT sat_pdpd_ln_cust_revs_dtls_pk PRIMARY KEY (loans_payment_due_hashkey);



CREATE OR REPLACE TABLE sat_loans_basel (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_basel_home_pp string COMMENT 'Vay mua nhà đã hoàn thanh theo hợp đồng(Yes/No)',
    t_basel_rd_party string COMMENT 'Bên thứ 3 bảo lãnh theo Basel',
    t_basel_clr_bal string COMMENT 'Bù trừ nội bảng(Yes/No)',
    t_baselderivative string COMMENT 'Sản phẩm phái sinh tín dụng(Yes/No)',
    t_cb_liab_ccy string COMMENT 'Loại tiền của nợ phải trả nội bảng',
    t_cb_liab_amt string COMMENT 'Giá trị của thỏa thuận bù trừ nội bảng',
    t_cb_liab_duedate string COMMENT 'Ngày đáo hạn của nợ phải trả nội bảng',
    t_drvt_pr_ccy string COMMENT 'Loại tiền của SP phái sinh tín dụng',
    t_drvt_pr_amt string COMMENT 'Giá trị của SP phái sinh tín dụng',
    t_drvt_pr_duedate string COMMENT 'Ngày đáo hạn của SP phái sinh tín dụng',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày nhập'
) CLUSTER BY AUTO;
ALTER TABLE sat_loans_basel ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_loans_basel ADD CONSTRAINT sat_loans_basel_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE sat_ld_extra_information (
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_note string COMMENT 'Ghi chú',
    t_record_status string COMMENT 'trạng thái record',
    t_curr_no bigint COMMENT 'số record',
    t_inputter string COMMENT 'user input',
    t_authoriser string COMMENT 'uesr duyệt',
    t_date_time string COMMENT 'ngày giờ',
    t_ftp_int_rate_tp string COMMENT 'Loại lãi suất(cố định/Thả nổi định kỳ)',
    t_ocbint_chg_date string COMMENT 'Ngày bắt đầu đổi lãi suất',
    t_ftp_nd_term_int string COMMENT 'Định kỳ đổi lãi suất',
    t_ftp_fee_repaid string COMMENT 'Có thu phí tất toán trước hạn ?(Yes/No)'
) CLUSTER BY AUTO;
ALTER TABLE sat_ld_extra_information ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_ld_extra_information ADD CONSTRAINT sat_ld_extra_information_pk PRIMARY KEY (loans_hashkey);



CREATE OR REPLACE TABLE link_loans_customer (
    link_loans_customer_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_customer ALTER COLUMN link_loans_customer_hashkey SET NOT NULL;
ALTER TABLE link_loans_customer ADD CONSTRAINT link_loans_customer_pk PRIMARY KEY (link_loans_customer_hashkey);



CREATE OR REPLACE TABLE link_loans_branch (
    link_loans_branch_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_branch ALTER COLUMN link_loans_branch_hashkey SET NOT NULL;
ALTER TABLE link_loans_branch ADD CONSTRAINT link_loans_branch_pk PRIMARY KEY (link_loans_branch_hashkey);



CREATE OR REPLACE TABLE link_loans_dept_acct_officer_nvql (
    link_loans_dept_acct_officer_nvql_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_dept_acct_officer_nvql ALTER COLUMN link_loans_dept_acct_officer_nvql_hashkey SET NOT NULL;
ALTER TABLE link_loans_dept_acct_officer_nvql ADD CONSTRAINT link_loans_dept_acct_officer_nvql_pk PRIMARY KEY (link_loans_dept_acct_officer_nvql_hashkey);



CREATE OR REPLACE TABLE link_loans_dept_acct_officer_nvgt (
    link_loans_dept_acct_officer_nvgt_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub Acct Officer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_dept_acct_officer_nvgt ALTER COLUMN link_loans_dept_acct_officer_nvgt_hashkey SET NOT NULL;
ALTER TABLE link_loans_dept_acct_officer_nvgt ADD CONSTRAINT link_loans_dept_acct_officer_nvgt_pk PRIMARY KEY (link_loans_dept_acct_officer_nvgt_hashkey);



CREATE OR REPLACE TABLE link_loans_saleid (
    link_loans_saleid_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_saleid ALTER COLUMN link_loans_saleid_hashkey SET NOT NULL;
ALTER TABLE link_loans_saleid ADD CONSTRAINT link_loans_saleid_pk PRIMARY KEY (link_loans_saleid_hashkey);



CREATE OR REPLACE TABLE link_loans_limit (
    link_loans_limit_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    limit_hashkey string COMMENT 'Tham chiếu Hub Limit',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_limit ALTER COLUMN link_loans_limit_hashkey SET NOT NULL;
ALTER TABLE link_loans_limit ADD CONSTRAINT link_loans_limit_pk PRIMARY KEY (link_loans_limit_hashkey);



CREATE OR REPLACE TABLE link_loans_prin_liq_account (
    link_loans_prin_liq_account_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_prin_liq_account ALTER COLUMN link_loans_prin_liq_account_hashkey SET NOT NULL;
ALTER TABLE link_loans_prin_liq_account ADD CONSTRAINT link_loans_prin_liq_account_pk PRIMARY KEY (link_loans_prin_liq_account_hashkey);



CREATE OR REPLACE TABLE link_loans_int_liq_account (
    link_loans_int_liq_account_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_int_liq_account ALTER COLUMN link_loans_int_liq_account_hashkey SET NOT NULL;
ALTER TABLE link_loans_int_liq_account ADD CONSTRAINT link_loans_int_liq_account_pk PRIMARY KEY (link_loans_int_liq_account_hashkey);



CREATE OR REPLACE TABLE link_loans_fee_pay_account (
    link_loans_fee_pay_account_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    fee_pay_account_hashkey string COMMENT 'Tài khoản thu phí',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_fee_pay_account ALTER COLUMN link_loans_fee_pay_account_hashkey SET NOT NULL;
ALTER TABLE link_loans_fee_pay_account ADD CONSTRAINT link_loans_fee_pay_account_pk PRIMARY KEY (link_loans_fee_pay_account_hashkey);



CREATE OR REPLACE TABLE link_loans_chrg_liq_account (
    link_loans_chrg_liq_account_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    chrg_liq_acct_hashkey string COMMENT 'TK thanh toán phí',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_chrg_liq_account ALTER COLUMN link_loans_chrg_liq_account_hashkey SET NOT NULL;
ALTER TABLE link_loans_chrg_liq_account ADD CONSTRAINT link_loans_chrg_liq_account_pk PRIMARY KEY (link_loans_chrg_liq_account_hashkey);



CREATE OR REPLACE TABLE link_loans_letter_of_credit (
    link_loans_lc_hashkey string COMMENT 'Link HK',
    loans_hashkey string COMMENT 'Tham chiếu Hub Loans',
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC/TF',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_letter_of_credit ALTER COLUMN link_loans_lc_hashkey SET NOT NULL;
ALTER TABLE link_loans_letter_of_credit ADD CONSTRAINT link_loans_letter_of_credit_pk PRIMARY KEY (link_loans_lc_hashkey);



CREATE OR REPLACE TABLE link_loans_payment_due (
    loans_payment_due_hashkey string COMMENT 'HK của hub_loans_payment_due',
    link_loans_payment_due_hashkey string COMMENT 'Link Hash Key',
    loans_hashkey string COMMENT 'HK của hub_loan',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_loans_payment_due ALTER COLUMN link_loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE link_loans_payment_due ADD CONSTRAINT link_loans_payment_due_pk PRIMARY KEY (link_loans_payment_due_hashkey);



CREATE OR REPLACE TABLE hub_money_market (
    money_market_hashkey string COMMENT 'Hub Hash Key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_money_market ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE hub_money_market ADD CONSTRAINT hub_money_market_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_classification (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_category bigint COMMENT 'Mã sản phẩm (Phân loại category)',
    t_mm_type string COMMENT 'Loại giao dịch MM',
    t_limit_reference string COMMENT 'Mã hạn mức',
    t_prin_liq_acct string COMMENT 'Tài khoản trả gốc',
    t_ben_acct_no string COMMENT 'Tài khoản người thụ hưởng chuyển tiền',
    t_int_liq_acct string COMMENT 'Tài khoản trả lãi',
    t_co_code_inp string COMMENT 'Mã chi nhánh nhập giao dịch',
    t_benef_prin_acct string COMMENT 'Tài khoản thụ hưởng gốc',
    t_drawdown_account string COMMENT 'Tài khoản thụ hưởng'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_classification ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_classification ADD CONSTRAINT sat_money_market_classification_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_information (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_deal_date string COMMENT 'Ngày giao dịch',
    t_value_date string COMMENT 'Ngày bắt đầu',
    t_term string COMMENT 'Kỳ hạn',
    t_maturity_date string COMMENT 'Ngày đáo hạn',
    t_principal decimal(22,4) COMMENT 'Giá trị hợp đồng',
    t_currency string COMMENT 'loại tiền',
    t_orig_start_date string COMMENT 'Ngày mở ban đầu',
    t_mis_acct_officer string COMMENT 'Mã NV được ghi nhận Profit',
    t_linked_contract string COMMENT 'Mã HĐ tham chiếu',
    t_contract_no string COMMENT 'Không sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_information ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_information ADD CONSTRAINT sat_money_market_information_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_lmm_account_balances (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_date_from string COMMENT 'Ngày bắt đầu',
    t_effective_date string COMMENT 'Ngày hiệu lực',
    t_trans_prin_amt string COMMENT 'Số dư giao dịch',
    t_outs_curr_princ string COMMENT 'Số dư gốc',
    t_outs_accrued_int decimal(38,10) COMMENT 'Số dự thu kỳ gần nhất đến hiện tại',
    t_start_period_int string COMMENT 'Ngày bắt đầu kỳ lãi',
    t_end_period_int string COMMENT 'Ngày kết thúc kỳ lãi',
    t_committed_int decimal(38,10) COMMENT 'Lãi kỳ hiện tại',
    t_princ_int_bal string COMMENT 'số dư nợ tính lãi',
    t_int_amt_todate string COMMENT 'lãi tính đến ngày T_DATE_INT_ACC_TO',
    t_ac_int_rate string COMMENT 'lãi suất tính lãi',
    t_ac_int_spread string COMMENT 'biên độ tính lãi',
    t_date_int_acc_to string COMMENT 'Ngày tính lãi',
    t_actual_acc_amt string COMMENT 'Lãi tính đến ngày (số chưa làm tròn)',
    t_currency string COMMENT 'Loại tiền',
    t_outs_susp_int string COMMENT 'Lãi treo',
    t_outs_accrued_comm bigint COMMENT 'Không dùng',
    t_last_int_rev_date string COMMENT 'Không dùng',
    t_next_int_rev_date string COMMENT 'Không dùng',
    t_prev_int_st_date string COMMENT 'Không dùng',
    t_int_accr_start string COMMENT 'Không dùng',
    t_committed_comm bigint COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_lmm_account_balances ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_lmm_account_balances ADD CONSTRAINT sat_money_market_lmm_account_balances_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_rate (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_interest_rate decimal(22,10) COMMENT 'Lãi suất',
    t_int_rate_type string COMMENT 'Loại lãi suất',
    t_interest_basis string COMMENT 'Cơ số tính lãi',
    t_interest_spread_1 string COMMENT 'Biên độ lãi suất',
    t_ocb_intratetype string COMMENT 'OCB loại LS thả nổi hay cố định',
    t_interest_key string COMMENT 'Key lãi suất'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_rate ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_rate ADD CONSTRAINT sat_money_market_rate_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_rollover_schedule (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_rollover_marker string COMMENT 'Đánh dấu tái tục',
    t_new_interest_rate decimal(21,10) COMMENT 'Lãi suất mới áp dụng sau khi tái tục',
    t_rollover_date string COMMENT 'Ngày tái tục',
    t_capitalisation string COMMENT 'Có lãi nhập vốn không',
    t_prin_increase bigint COMMENT 'Số tiền gốc tăng thêm',
    t_incr_eff_date string COMMENT 'Ngày hiệu lực tăng vốn thêm',
    t_tot_interest_amt decimal(28,10) COMMENT 'Tổng tiền lãi',
    t_next_prin_amount decimal(23,4) COMMENT 'Số tiền gốc mới sau tái tục',
    t_next_int_amount decimal(23,4) COMMENT 'Số tiền lãi mới sau tái tục',
    t_int_period_start string COMMENT 'Ngày bắt đầu chu kỳ tính lãi',
    t_int_period_end string COMMENT 'Ngày kết thúc chu kỳ tính lãi',
    t_int_schedule string COMMENT 'Lịch trả lãi'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_rollover_schedule ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_rollover_schedule ADD CONSTRAINT sat_money_market_rollover_schedule_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_payment_information (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_prin_ben_bank_1 bigint COMMENT 'Ngân hàng thụ hưởng 1',
    t_prin_ben_bank_2 bigint COMMENT 'Ngân hàng thụ hưởng 2',
    t_int_ben_bank_1 string COMMENT 'Ngân hàng thụ hưởng lãi 1',
    t_int_ben_bank_2 string COMMENT 'Ngân hàng thụ hưởng lãi 2',
    t_send_payment string COMMENT 'Có gửi điện thanh toán',
    t_trans_code string COMMENT 'Mã loại giao dịch chuyển tiền',
    t_mkfile_com string COMMENT 'Chi nhánh tạo file chuyển tiền',
    t_r_ci_code string COMMENT 'Mã citad',
    t_ibps_bene string COMMENT 'Tên người thụ hưởng chuyển tiền',
    t_receiving_addr string COMMENT 'Địa chỉ người thụ hưởng chuyển tiền',
    t_prin_address string COMMENT 'Địa chỉ người thụ hưởng',
    t_int_address string COMMENT 'Địa chỉ người thụ hưởng lãi',
    t_our_remarks string COMMENT 'Nội dung chuyển tiền'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_payment_information ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_payment_information ADD CONSTRAINT sat_money_market_payment_information_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_guarantee (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_md_limit_avail string COMMENT 'Hạn mức giao dịch TSĐB còn lại',
    t_is_guarantee string COMMENT 'Có bảo lảnh?',
    t_mm_gua_org string COMMENT 'Tổ chức bảo lãnh',
    t_mm_gua_amt string COMMENT 'Giá trị bảo lãnh',
    t_gua_mat_date string COMMENT 'Ngày đáo hạn hợp đồng bảo lãnh',
    t_gua_type string COMMENT 'Loại bảo lãnh',
    t_clr_bal_sheet string COMMENT 'Có sử dụng bù trừ số dư nội bảng?',
    t_cr_derivative string COMMENT 'Có sử dụng phái sinh tín dụng?',
    t_drvt_prod_amt string COMMENT 'Giá trị sản phẩm phái sinh tín dụng',
    t_drvt_p_mat_date string COMMENT 'Ngày đáo hạn sản phẩm phái sinh TD',
    t_link_reference string COMMENT 'Mã hạn mức',
    t_md_ref string COMMENT 'Số Ref của TSĐB'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_guarantee ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_guarantee ADD CONSTRAINT sat_money_market_guarantee_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE sat_money_market_audit_status (
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_status string COMMENT 'Trạng thái MM',
    t_record_status string COMMENT 'Tình trạng bản ghi',
    t_override string COMMENT 'Cảnh báo override',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_date_time string COMMENT 'Ngày giờ thực hiện sau cùng',
    t_curr_no string COMMENT 'Số lần thay đổi',
    t_dept_code string COMMENT 'Mã phòng ban',
    t_activity_code string COMMENT 'Mã activity',
    t_dealer_desk string COMMENT 'Bàn giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_money_market_audit_status ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sat_money_market_audit_status ADD CONSTRAINT sat_money_market_audit_status_pk PRIMARY KEY (money_market_hashkey);



CREATE OR REPLACE TABLE link_money_market_customer (
    link_money_market_customer_hashkey string COMMENT 'Link HK',
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_money_market_customer ALTER COLUMN link_money_market_customer_hashkey SET NOT NULL;
ALTER TABLE link_money_market_customer ADD CONSTRAINT link_money_market_customer_pk PRIMARY KEY (link_money_market_customer_hashkey);



CREATE OR REPLACE TABLE link_money_market_branch (
    link_money_market_branch_hashkey string COMMENT 'Link HK',
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    branch_hashkey string COMMENT 'Tham chiếu Hub Branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_money_market_branch ALTER COLUMN link_money_market_branch_hashkey SET NOT NULL;
ALTER TABLE link_money_market_branch ADD CONSTRAINT link_money_market_branch_pk PRIMARY KEY (link_money_market_branch_hashkey);



CREATE OR REPLACE TABLE link_money_market_dept_acct_officer (
    link_money_market_dept_acct_officer_hashkey string COMMENT 'Link HK',
    money_market_hashkey string COMMENT 'Tham chiếu Hub Money Market',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub Acct Officer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_money_market_dept_acct_officer ALTER COLUMN link_money_market_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_money_market_dept_acct_officer ADD CONSTRAINT link_money_market_dept_acct_officer_pk PRIMARY KEY (link_money_market_dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE hub_repo (
    repo_hashkey string COMMENT 'Repo Hash Key (kỹ thuật)',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_repo ALTER COLUMN repo_hashkey SET NOT NULL;
ALTER TABLE hub_repo ADD CONSTRAINT hub_repo_pk PRIMARY KEY (repo_hashkey);
