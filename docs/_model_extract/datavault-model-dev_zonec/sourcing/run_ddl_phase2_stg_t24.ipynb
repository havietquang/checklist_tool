# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- Phase 2

CREATE OR REPLACE VIEW v_stg_t24_t24_accr_acct_cr AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_liquidity_ccy,
    CAST(NULL AS STRING) AS t_period_first_date,
    CAST(NULL AS STRING) AS t_period_last_date,
    CAST(NULL AS STRING) AS t_cr_int_rate,
    CAST(NULL AS STRING) AS t_cr_int_date,
    CAST(NULL AS STRING) AS t_cr_no_of_days,
    CAST(NULL AS STRING) AS t_cr_int_amt,
    CAST(NULL AS STRING) AS t_cr_int_categ,
    CAST(NULL AS STRING) AS t_cr_val_balance,
    CAST(NULL AS STRING) AS t_cr_int_tr_ac,
    CAST(NULL AS STRING) AS t_cr_int_tr_pl,
    CAST(NULL AS STRING) AS t_cr_int_tax_code,
    CAST(NULL AS STRING) AS t_cr_int_tax_rate,
    CAST(NULL AS STRING) AS t_cr_int_tax_amt,
    CAST(NULL AS STRING) AS t_cr_int_taxcateg,
    CAST(NULL AS STRING) AS t_cr_int_taxtrsdr,
    CAST(NULL AS STRING) AS t_cr_int_taxtrscr,
    CAST(NULL AS STRING) AS t_liquidity_account,
    CAST(NULL AS STRING) AS t_compens_account,
    CAST(NULL AS STRING) AS t_int_no_booking,
    CAST(NULL AS STRING) AS t_total_interest,
    CAST(NULL AS STRING) AS t_tax_for_customer,
    CAST(NULL AS STRING) AS t_tax_for_bank,
    CAST(NULL AS STRING) AS t_grand_total,
    CAST(NULL AS STRING) AS t_ica_post_interest,
    CAST(NULL AS STRING) AS t_ica_main_acct,
    CAST(NULL AS STRING) AS t_ica_dist_type,
    CAST(NULL AS STRING) AS t_ica_dist_ratio,
    CAST(NULL AS STRING) AS t_ica_int_categ,
    CAST(NULL AS STRING) AS t_ica_tr_ac,
    CAST(NULL AS STRING) AS t_ica_tr_pl,
    CAST(NULL AS STRING) AS t_ica_main_int,
    CAST(NULL AS STRING) AS t_ica_sub_int,
    CAST(NULL AS STRING) AS t_correction_number,
    CAST(NULL AS STRING) AS t_cr_min_value,
    CAST(NULL AS STRING) AS t_cr_min_waive,
    CAST(NULL AS STRING) AS t_unadj_total_int,
    CAST(NULL AS STRING) AS t_int_post_date,
    CAST(NULL AS STRING) AS t_tax_exch_rate,
    CAST(NULL AS STRING) AS t_manual_adj_amt,
    CAST(NULL AS STRING) AS t_correction_id,
    CAST(NULL AS STRING) AS t_adj_int_amt,
    CAST(NULL AS STRING) AS t_adj_tax_amt,
    CAST(NULL AS STRING) AS t_withheld_int_amt,
    CAST(NULL AS STRING) AS t_db_netting_amt,
    CAST(NULL AS STRING) AS t_correction_date,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_accr_acct_cr_information,
    CAST(NULL AS STRING) AS hashdiff_accr_acct_cr_dynamic,
    CAST(NULL AS STRING) AS hashdiff_accr_acct_cr_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_accr_acct_dr AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_liquidity_ccy,
    CAST(NULL AS STRING) AS t_period_first_date,
    CAST(NULL AS STRING) AS t_period_last_date,
    CAST(NULL AS STRING) AS t_dr_int_rate,
    CAST(NULL AS STRING) AS t_dr_int_date,
    CAST(NULL AS STRING) AS t_dr_no_of_days,
    CAST(NULL AS STRING) AS t_dr_int_amt,
    CAST(NULL AS STRING) AS t_dr_int_categ,
    CAST(NULL AS STRING) AS t_dr_val_balance,
    CAST(NULL AS STRING) AS t_dr_int_tr_ac,
    CAST(NULL AS STRING) AS t_dr_int_tr_pl,
    CAST(NULL AS STRING) AS t_total_interest,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_accr_acct_dr_information,
    CAST(NULL AS STRING) AS hashdiff_accr_acct_dr_dynamic,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_acct_activity AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_day_no,
    CAST(NULL AS STRING) AS t_turnover_credit,
    CAST(NULL AS STRING) AS t_turnover_debit,
    CAST(NULL AS STRING) AS t_balance,
    CAST(NULL AS STRING) AS t_transact_code,
    CAST(NULL AS STRING) AS t_no_of_transact,
    CAST(NULL AS STRING) AS t_transact_amt,
    CAST(NULL AS STRING) AS t_bk_day_no,
    CAST(NULL AS STRING) AS t_bk_balance,
    CAST(NULL AS STRING) AS t_bk_credit_mvmt,
    CAST(NULL AS STRING) AS t_bk_debit_mvmt,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_acct_activity,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_acct_gen_condition AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_description,
    CAST(NULL AS STRING) AS t_item,
    CAST(NULL AS STRING) AS t_priority,
    CAST(NULL AS STRING) AS t_value,
    CAST(NULL AS STRING) AS t_multivalue,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_acct_group_condition AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS DECIMAL(38,10)) AS t_minimum_bal,
    CAST(NULL AS BIGINT) AS t_curr_no,
    CAST(NULL AS STRING) AS inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_apportion_acct_categ AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_parent_account,
    CAST(NULL AS STRING) AS t_level3,
    CAST(NULL AS STRING) AS t_line,
    CAST(NULL AS STRING) AS t_account_name,
    CAST(NULL AS STRING) AS t_categ_internal,
    CAST(NULL AS STRING) AS t_cust_group,
    CAST(NULL AS STRING) AS t_no,
    CAST(NULL AS STRING) AS t_categ_pl,
    CAST(NULL AS STRING) AS t_type_business,
    CAST(NULL AS STRING) AS t_is_mand,
    CAST(NULL AS STRING) AS t_categ_type,
    CAST(NULL AS STRING) AS t_from_date,
    CAST(NULL AS STRING) AS t_status,
    CAST(NULL AS STRING) AS t_pbnb,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_apportion_acct_categ,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_auto_name AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_name,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_bank_assure_inp AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_contract_ld,
    CAST(NULL AS STRING) AS t_ccy_assr,
    CAST(NULL AS STRING) AS t_cr_product_code,
    CAST(NULL AS STRING) AS t_assr_request_date,
    CAST(NULL AS STRING) AS t_assr_begin_date,
    CAST(NULL AS STRING) AS t_assr_end_date,
    CAST(NULL AS STRING) AS t_fee_rate,
    CAST(NULL AS STRING) AS t_pay_fee_period,
    CAST(NULL AS STRING) AS t_first_term_amt,
    CAST(NULL AS STRING) AS t_next_fee_cal_date,
    CAST(NULL AS STRING) AS t_next_int_begin_date,
    CAST(NULL AS STRING) AS t_next_int_end_date,
    CAST(NULL AS STRING) AS t_loan_amount,
    CAST(NULL AS STRING) AS t_paid_int_freq,
    CAST(NULL AS STRING) AS t_paid_ori_freq,
    CAST(NULL AS STRING) AS t_advisory_cadre,
    CAST(NULL AS STRING) AS t_info_note,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_first_fee_cal_date,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_bank_assure_inp,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_bosc_comp_reg AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_account_number,
    CAST(NULL AS STRING) AS t_branch_id,
    CAST(NULL AS STRING) AS t_company_name,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_comp_level_group AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_description,
    CAST(NULL AS STRING) AS t_level2_comp,
    CAST(NULL AS STRING) AS t_lead_company,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_branch_comp_level_group,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_denom_exchange AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_denomination,
    CAST(NULL AS STRING) AS t_denom_buy_rate,
    CAST(NULL AS STRING) AS t_denom_sell_rate,
    CAST(NULL AS STRING) AS t_denom_revl_rate,
    CAST(NULL AS STRING) AS t_denom_rate_sprd,
    CAST(NULL AS STRING) AS t_curr_no,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_diary AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_security_no,
    CAST(NULL AS STRING) AS t_narrative,
    CAST(NULL AS STRING) AS t_event_type,
    CAST(NULL AS STRING) AS t_depository,
    CAST(NULL AS STRING) AS t_vault_update,
    CAST(NULL AS STRING) AS t_ex_date,
    CAST(NULL AS STRING) AS t_pay_date,
    CAST(NULL AS STRING) AS t_value_date,
    CAST(NULL AS STRING) AS t_currency,
    CAST(NULL AS STRING) AS t_rate_type,
    CAST(NULL AS STRING) AS t_option_desc,
    CAST(NULL AS STRING) AS t_rate,
    CAST(NULL AS STRING) AS t_percentage,
    CAST(NULL AS STRING) AS t_local_tax_perc,
    CAST(NULL AS STRING) AS t_commission_code,
    CAST(NULL AS STRING) AS t_net_charges,
    CAST(NULL AS STRING) AS t_bond_share_flag,
    CAST(NULL AS STRING) AS t_dep_no,
    CAST(NULL AS STRING) AS t_dep_type,
    CAST(NULL AS STRING) AS t_dep_account_no,
    CAST(NULL AS STRING) AS t_total_cash,
    CAST(NULL AS STRING) AS t_total_cash_ccy,
    CAST(NULL AS STRING) AS t_total_cash_xch,
    CAST(NULL AS STRING) AS t_total_cash_lccy,
    CAST(NULL AS STRING) AS t_rp_tot_cash,
    CAST(NULL AS STRING) AS t_rp_tot_cash_lcy,
    CAST(NULL AS STRING) AS t_tot_security,
    CAST(NULL AS STRING) AS t_total_debit,
    CAST(NULL AS STRING) AS t_option,
    CAST(NULL AS STRING) AS t_option_nominal,
    CAST(NULL AS STRING) AS t_option1,
    CAST(NULL AS STRING) AS t_opt1_depot,
    CAST(NULL AS STRING) AS t_opt1_nominal,
    CAST(NULL AS STRING) AS t_opt1_cash,
    CAST(NULL AS STRING) AS t_opt1_cash_ccy,
    CAST(NULL AS STRING) AS t_opt1_sec,
    CAST(NULL AS STRING) AS t_opt1_debit,
    CAST(NULL AS STRING) AS t_auto_update,
    CAST(NULL AS STRING) AS t_source,
    CAST(NULL AS STRING) AS t_accrual_start_date,
    CAST(NULL AS STRING) AS t_portfolio_no,
    CAST(NULL AS STRING) AS t_cash_hold_settle,
    CAST(NULL AS STRING) AS t_sec_hold_settle,
    CAST(NULL AS STRING) AS t_total_credit,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_diary_information,
    CAST(NULL AS STRING) AS hashdiff_diary_system,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_entitlement AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_portfolio_no,
    CAST(NULL AS STRING) AS t_security_no,
    CAST(NULL AS STRING) AS t_record_status,
    CAST(NULL AS DECIMAL(38,10)) AS t_entitlement_amt,
    CAST(NULL AS STRING) AS t_event_type,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_entitlement,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_group_capitalisation AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_dr_cap_frequency,
    CAST(NULL AS STRING) AS t_cr_cap_frequency,
    CAST(NULL AS STRING) AS t_settle_acct_close,
    CAST(NULL AS STRING) AS t_start_of_day_cap,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_int_chg_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_descriptions,
    CAST(NULL AS STRING) AS t_frequency,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_job_title AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS description,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_lc_enrichment AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_operation,
    CAST(NULL AS STRING) AS t_revocable,
    CAST(NULL AS STRING) AS t_ucp_ind,
    CAST(NULL AS STRING) AS t_part_ship,
    CAST(NULL AS STRING) AS t_transship,
    CAST(NULL AS STRING) AS t_reimburse,
    CAST(NULL AS STRING) AS t_charges_from,
    CAST(NULL AS STRING) AS t_party_chrgd,
    CAST(NULL AS STRING) AS t_chrg_status,
    CAST(NULL AS STRING) AS t_drawing_type,
    CAST(NULL AS STRING) AS t_pay_method,
    CAST(NULL AS STRING) AS t_coll_reply,
    CAST(NULL AS STRING) AS t_chrg_period,
    CAST(NULL AS STRING) AS t_imp_exp,
    CAST(NULL AS STRING) AS t_pay_type,
    CAST(NULL AS STRING) AS t_inco_terms,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_li_comp_level_right AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_description,
    CAST(NULL AS STRING) AS t_parent_company,
    CAST(NULL AS STRING) AS t_currency,
    CAST(NULL AS STRING) AS t_cust_type,
    CAST(NULL AS STRING) AS t_amount,
    CAST(NULL AS STRING) AS t_lead_company,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_branch_li_comp_level_right,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_limit_level_auth AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_limit_amount,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_ac_restrict AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS BIGINT) AS t_customer,
    CAST(NULL AS STRING) AS t_ac_title,
    CAST(NULL AS BIGINT) AS t_category,
    CAST(NULL AS STRING) AS t_currency,
    CAST(NULL AS STRING) AS t_ac_restrict,
    CAST(NULL AS STRING) AS t_res_customer,
    CAST(NULL AS STRING) AS t_res_ac_title,
    CAST(NULL AS STRING) AS t_res_category,
    CAST(NULL AS STRING) AS t_res_currency,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ac_restrict,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_coll_bpm_store AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_txn_status,
    CAST(NULL AS STRING) AS t_collateral_id,
    CAST(NULL AS STRING) AS t_bpm_trans_id,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_coll_bpm_store,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_cu_add_inf_corp_vn AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_rep_address,
    CAST(NULL AS STRING) AS t_rep_ward,
    CAST(NULL AS STRING) AS t_rep_dist,
    CAST(NULL AS STRING) AS t_rep_city,
    CAST(NULL AS STRING) AS t_legrep_is_acrep,
    CAST(NULL AS STRING) AS t_acrep_nat,
    CAST(NULL AS STRING) AS t_acrep_name,
    CAST(NULL AS STRING) AS t_acrep_job,
    CAST(NULL AS STRING) AS t_acrep_doc,
    CAST(NULL AS STRING) AS t_acrep_id,
    CAST(NULL AS STRING) AS t_acrep_dob,
    CAST(NULL AS STRING) AS t_acrep_phone,
    CAST(NULL AS STRING) AS t_acrep_email,
    CAST(NULL AS STRING) AS t_acrep_addr,
    CAST(NULL AS STRING) AS t_acrep_ward,
    CAST(NULL AS STRING) AS t_acrep_dist,
    CAST(NULL AS STRING) AS t_acrep_city,
    CAST(NULL AS STRING) AS t_ceo_name,
    CAST(NULL AS STRING) AS t_ceo_nation,
    CAST(NULL AS STRING) AS t_ceo_job,
    CAST(NULL AS STRING) AS t_ceo_doc,
    CAST(NULL AS STRING) AS t_ceo_id,
    CAST(NULL AS STRING) AS t_ceo_addr,
    CAST(NULL AS STRING) AS t_ceo_ward,
    CAST(NULL AS STRING) AS t_ceo_dist,
    CAST(NULL AS STRING) AS t_ceo_city,
    CAST(NULL AS STRING) AS t_capital_ccy,
    CAST(NULL AS STRING) AS t_rep_residence,
    CAST(NULL AS STRING) AS t_rep_visa_no,
    CAST(NULL AS STRING) AS t_rep_lg_iss_dep,
    CAST(NULL AS STRING) AS t_rep_lg_exp_dep,
    CAST(NULL AS STRING) AS t_rep_lg_pla_dep,
    CAST(NULL AS STRING) AS t_acrep_residence,
    CAST(NULL AS STRING) AS t_acrep_legal_iss,
    CAST(NULL AS STRING) AS t_acrep_legal_exp,
    CAST(NULL AS STRING) AS t_acrep_legal_pla,
    CAST(NULL AS STRING) AS t_ceo_residence,
    CAST(NULL AS STRING) AS t_ceo_visa_no,
    CAST(NULL AS STRING) AS t_ceo_iss_date,
    CAST(NULL AS STRING) AS t_ceo_exp_date,
    CAST(NULL AS STRING) AS t_ceo_legal_place,
    CAST(NULL AS STRING) AS t_acc_nation,
    CAST(NULL AS STRING) AS t_acc_residence,
    CAST(NULL AS STRING) AS t_acc_name,
    CAST(NULL AS STRING) AS t_acc_title,
    CAST(NULL AS STRING) AS t_acc_visa_no,
    CAST(NULL AS STRING) AS t_acc_job_title,
    CAST(NULL AS STRING) AS t_acc_legal_id,
    CAST(NULL AS STRING) AS t_acc_legal_type,
    CAST(NULL AS STRING) AS t_acc_iss_date,
    CAST(NULL AS STRING) AS t_acc_exp_date,
    CAST(NULL AS STRING) AS t_acc_legal_place,
    CAST(NULL AS STRING) AS t_acc_birth_date,
    CAST(NULL AS STRING) AS t_acc_phone,
    CAST(NULL AS STRING) AS t_acc_email,
    CAST(NULL AS STRING) AS t_ocb_indus_tt15,
    CAST(NULL AS STRING) AS t_ocb_visa_type,
    CAST(NULL AS STRING) AS t_rep_visa_exp,
    CAST(NULL AS STRING) AS t_acrep_visa_exp,
    CAST(NULL AS STRING) AS t_ceo_visa_exp,
    CAST(NULL AS STRING) AS t_acc_visa_exp,
    CAST(NULL AS STRING) AS t_acrep_visa_no,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_cu_add_inf_corp_vn,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_industry_tt15 AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_industry_tt15_l1,
    CAST(NULL AS STRING) AS t_industry_tt15_l2,
    CAST(NULL AS STRING) AS t_industry_tt15_l3,
    CAST(NULL AS STRING) AS t_industry_name,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_scm_extra_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_ftp_int_rate_tp,
    CAST(NULL AS STRING) AS t_ftp_int_chg_date,
    CAST(NULL AS STRING) AS t_ftp_nd_term_int,
    CAST(NULL AS STRING) AS t_ftp_fee_repaid,
    CAST(NULL AS STRING) AS t_ftp_description,
    CAST(NULL AS STRING) AS t_ocb_ftp_bd_type,
    CAST(NULL AS STRING) AS t_ocb_ftp_callput,
    CAST(NULL AS STRING) AS t_ocb_ftp_frdate,
    CAST(NULL AS STRING) AS t_ocb_ftp_tright,
    CAST(NULL AS STRING) AS t_ocb_ftp_vlpaper,
    CAST(NULL AS STRING) AS t_ocb_ftp_cifcoll,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_scm_extra_info,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_periodic_interest AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_description,
    CAST(NULL AS STRING) AS t_default_mis_table,
    CAST(NULL AS STRING) AS t_rest_date,
    CAST(NULL AS STRING) AS t_days_since_spot,
    CAST(NULL AS STRING) AS t_bid_rate,
    CAST(NULL AS STRING) AS t_offer_rate,
    CAST(NULL AS STRING) AS t_rest_period,
    CAST(NULL AS STRING) AS t_record_status,
    CAST(NULL AS BIGINT) AS t_curr_no,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_periodic_interest,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_prod_package_cb AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_package_name,
    CAST(NULL AS STRING) AS t_ac_manage_fee_per,
    CAST(NULL AS STRING) AS t_ext_ft_fee_per,
    CAST(NULL AS STRING) AS t_ib_fee_per,
    CAST(NULL AS STRING) AS t_tax_fee_per,
    CAST(NULL AS STRING) AS t_sms_fee_per,
    CAST(NULL AS STRING) AS t_record_status,
    CAST(NULL AS STRING) AS t_curr_no,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_dept_code,
    CAST(NULL AS STRING) AS t_package_fdate,
    CAST(NULL AS STRING) AS t_package_tdate,
    CAST(NULL AS STRING) AS t_ac_manage_fee_term,
    CAST(NULL AS STRING) AS t_ext_ft_fee_term,
    CAST(NULL AS STRING) AS t_ib_fee_term,
    CAST(NULL AS STRING) AS t_tax_fee_term,
    CAST(NULL AS STRING) AS t_sms_fee_term,
    CAST(NULL AS STRING) AS t_ac_min_avr_balance,
    CAST(NULL AS STRING) AS t_batch_ft_fee_per,
    CAST(NULL AS STRING) AS t_batch_ft_fee_term,
    CAST(NULL AS STRING) AS t_ft_8s_fee_per,
    CAST(NULL AS STRING) AS t_ft_8s_fee_term,
    CAST(NULL AS STRING) AS t_ext_fo_fee_per,
    CAST(NULL AS STRING) AS t_ext_fo_fee_term,
    CAST(NULL AS STRING) AS t_avr_balance_from,
    CAST(NULL AS STRING) AS t_avr_balance_to,
    CAST(NULL AS STRING) AS t_ac_manage_fee,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_re_txn_code AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_description,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sc_block_sec_pos AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_action_date,
    CAST(NULL AS STRING) AS t_addition_info,
    CAST(NULL AS STRING) AS t_block_eff_from,
    CAST(NULL AS STRING) AS t_blocked_until,
    CAST(NULL AS DECIMAL(38,10)) AS t_curr_amt_blocked,
    CAST(NULL AS STRING) AS t_diary_id,
    CAST(NULL AS STRING) AS t_eff_from_date,
    CAST(NULL AS STRING) AS t_eff_to_date,
    CAST(NULL AS STRING) AS t_entitlement,
    CAST(NULL AS STRING) AS t_interest_rate,
    CAST(NULL AS STRING) AS t_maturity_date,
    CAST(NULL AS DECIMAL(38,10)) AS t_new_amt_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS t_new_block_amt,
    CAST(NULL AS STRING) AS t_sec_depot,
    CAST(NULL AS STRING) AS t_securities_account,
    CAST(NULL AS STRING) AS t_security_code,
    CAST(NULL AS STRING) AS t_sub_account,
    CAST(NULL AS STRING) AS t_trans_reference,
    CAST(NULL AS STRING) AS t_transaction_type,
    CAST(NULL AS STRING) AS t_product,
    CAST(NULL AS STRING) AS t_notification_msg,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_ocb_sc_pp_gtcg,
    CAST(NULL AS STRING) AS t_ocb_sc_co_gtcg,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_security_block,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sc_trans_pos_history AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_security_ccy,
    CAST(NULL AS STRING) AS t_curr_per_st_date,
    CAST(NULL AS STRING) AS t_sop_position,
    CAST(NULL AS STRING) AS t_sop_avg_price,
    CAST(NULL AS STRING) AS t_sop_cost_position,
    CAST(NULL AS STRING) AS t_close_bus_date,
    CAST(NULL AS STRING) AS t_cob_position,
    CAST(NULL AS STRING) AS t_cob_avg_price,
    CAST(NULL AS STRING) AS t_cob_cost_position,
    CAST(NULL AS STRING) AS t_ptd_real_pl_posted,
    CAST(NULL AS STRING) AS t_ptd_real_pl_calc,
    CAST(NULL AS STRING) AS t_ptd_da_calc,
    CAST(NULL AS STRING) AS t_trade_date,
    CAST(NULL AS STRING) AS t_pos_date_time,
    CAST(NULL AS STRING) AS t_trade_ref,
    CAST(NULL AS STRING) AS t_trans_type,
    CAST(NULL AS STRING) AS t_nominal,
    CAST(NULL AS STRING) AS t_clean_price,
    CAST(NULL AS STRING) AS t_consid,
    CAST(NULL AS STRING) AS t_accr_interest,
    CAST(NULL AS STRING) AS t_value_date,
    CAST(NULL AS STRING) AS t_trd_disc_accr,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_sc_trans_pos_history,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_security_position AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS DECIMAL(38,10)) AS t_book_cost_sec_ccy,
    CAST(NULL AS DECIMAL(38,10)) AS t_cap_amt,
    CAST(NULL AS DECIMAL(38,10)) AS t_closing_bal_no_nom,
    CAST(NULL AS DECIMAL(38,10)) AS t_cost_invst_bse_ccy,
    CAST(NULL AS DECIMAL(38,10)) AS t_cost_invst_ref_ccy,
    CAST(NULL AS DECIMAL(38,10)) AS t_cost_invst_sec_ccy,
    CAST(NULL AS STRING) AS t_date_last_traded,
    CAST(NULL AS BIGINT) AS t_depository,
    CAST(NULL AS STRING) AS t_fin_company,
    CAST(NULL AS DECIMAL(38,10)) AS t_gr_bk_cost_sec_ccy,
    CAST(NULL AS DECIMAL(38,10)) AS t_gross_cost_sec_ccy,
    CAST(NULL AS STRING) AS t_held_since,
    CAST(NULL AS BIGINT) AS t_income_curr_period,
    CAST(NULL AS STRING) AS t_issue_date,
    CAST(NULL AS DECIMAL(38,10)) AS t_nom_amt_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS t_opening_bal_no_nom,
    CAST(NULL AS STRING) AS t_security_account,
    CAST(NULL AS STRING) AS t_security_number,
    CAST(NULL AS BIGINT) AS t_urlz_ccy_gn_cr_ptf,
    CAST(NULL AS BIGINT) AS t_urlz_mrk_gn_cr_ptf,
    CAST(NULL AS DECIMAL(38,10)) AS t_val_dat_book_cost,
    CAST(NULL AS DECIMAL(38,10)) AS t_value_dat_cost_ref,
    CAST(NULL AS DECIMAL(38,10)) AS t_value_dated_cost,
    CAST(NULL AS BIGINT) AS t_value_dated_posn,
    CAST(NULL AS BIGINT) AS t_ytd_invst_sec_ccy,
    CAST(NULL AS DECIMAL(38,10)) AS t_amt_blocked,
    CAST(NULL AS STRING) AS t_reference_number,
    CAST(NULL AS STRING) AS t_nominee_code,
    CAST(NULL AS STRING) AS t_maturity_date,
    CAST(NULL AS DECIMAL(38,10)) AS t_interest_rate,
    CAST(NULL AS STRING) AS t_opn_cost_invst_sec,
    CAST(NULL AS STRING) AS t_opn_cost_invst_ptf,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_security_position,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_standing_order AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_currency,
    CAST(NULL AS STRING) AS t_payment_details,
    CAST(NULL AS STRING) AS t_type,
    CAST(NULL AS STRING) AS t_pay_method,
    CAST(NULL AS DECIMAL(38,10)) AS t_current_amount_bal,
    CAST(NULL AS STRING) AS t_current_frequency,
    CAST(NULL AS STRING) AS t_ordering_cust,
    CAST(NULL AS BIGINT) AS t_debit_customer,
    CAST(NULL AS BIGINT) AS t_credit_customer,
    CAST(NULL AS STRING) AS t_current_end_date,
    CAST(NULL AS STRING) AS t_cpty_acct_no,
    CAST(NULL AS STRING) AS t_last_run_date,
    CAST(NULL AS STRING) AS t_curr_freq_date,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_acct_officer,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_standing_order,
    CAST(NULL AS STRING) AS hashdiff_standing_order_dynamic,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_stmt_acct_cr AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_liquidity_ccy,
    CAST(NULL AS STRING) AS t_period_first_date,
    CAST(NULL AS STRING) AS t_period_last_date,
    CAST(NULL AS STRING) AS t_cr_int_rate,
    CAST(NULL AS STRING) AS t_cr_int_date,
    CAST(NULL AS STRING) AS t_cr_no_of_days,
    CAST(NULL AS STRING) AS t_cr_int_amt,
    CAST(NULL AS STRING) AS t_cr_int_categ,
    CAST(NULL AS STRING) AS t_cr_val_balance,
    CAST(NULL AS STRING) AS t_cr_int_tr_ac,
    CAST(NULL AS STRING) AS t_cr_int_tr_pl,
    CAST(NULL AS STRING) AS t_cr_int_tax_code,
    CAST(NULL AS STRING) AS t_cr_int_tax_rate,
    CAST(NULL AS STRING) AS t_cr_int_tax_amt,
    CAST(NULL AS STRING) AS t_cr_int_taxcateg,
    CAST(NULL AS STRING) AS t_cr_int_taxtrsdr,
    CAST(NULL AS STRING) AS t_cr_int_taxtrscr,
    CAST(NULL AS STRING) AS t_liquidity_account,
    CAST(NULL AS STRING) AS t_compens_account,
    CAST(NULL AS STRING) AS t_int_no_booking,
    CAST(NULL AS STRING) AS t_total_interest,
    CAST(NULL AS STRING) AS t_tax_for_customer,
    CAST(NULL AS STRING) AS t_tax_for_bank,
    CAST(NULL AS STRING) AS t_grand_total,
    CAST(NULL AS STRING) AS t_ica_int_categ,
    CAST(NULL AS STRING) AS t_ica_tr_ac,
    CAST(NULL AS STRING) AS t_ica_tr_pl,
    CAST(NULL AS STRING) AS t_ica_main_int,
    CAST(NULL AS STRING) AS t_ica_sub_int,
    CAST(NULL AS STRING) AS t_ica_post_interest,
    CAST(NULL AS STRING) AS t_ica_main_acct,
    CAST(NULL AS STRING) AS t_ica_dist_type,
    CAST(NULL AS STRING) AS t_ica_dist_ratio,
    CAST(NULL AS STRING) AS t_cr_min_value,
    CAST(NULL AS STRING) AS t_cr_min_waive,
    CAST(NULL AS STRING) AS t_unadj_total_int,
    CAST(NULL AS STRING) AS t_int_post_date,
    CAST(NULL AS STRING) AS t_tax_exch_rate,
    CAST(NULL AS STRING) AS t_manual_adj_amt,
    CAST(NULL AS STRING) AS t_correction_number,
    CAST(NULL AS STRING) AS t_correction_id,
    CAST(NULL AS STRING) AS t_adj_int_amt,
    CAST(NULL AS STRING) AS t_adj_tax_amt,
    CAST(NULL AS STRING) AS t_withheld_int_amt,
    CAST(NULL AS STRING) AS t_db_netting_amt,
    CAST(NULL AS STRING) AS t_correction_date,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_stmt_acct_cr,
    CAST(NULL AS STRING) AS hashdiff_stmt_acct_cr_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_stmt_acct_dr AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_liquidity_ccy,
    CAST(NULL AS STRING) AS t_period_first_date,
    CAST(NULL AS STRING) AS t_period_last_date,
    CAST(NULL AS STRING) AS t_dr_int_rate,
    CAST(NULL AS STRING) AS t_dr_int_date,
    CAST(NULL AS STRING) AS t_dr_no_of_days,
    CAST(NULL AS STRING) AS t_dr_int_amt,
    CAST(NULL AS STRING) AS t_dr_int_categ,
    CAST(NULL AS STRING) AS t_dr_val_balance,
    CAST(NULL AS STRING) AS t_dr_int_tr_ac,
    CAST(NULL AS STRING) AS t_dr_int_tr_pl,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_stmt_acct_dr,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_teller_id AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_status,
    CAST(NULL AS STRING) AS t_user,
    CAST(NULL AS STRING) AS t_date_of_open,
    CAST(NULL AS STRING) AS t_time_of_open,
    CAST(NULL AS STRING) AS t_date_of_close,
    CAST(NULL AS STRING) AS t_time_of_close,
    CAST(NULL AS STRING) AS t_curr_no,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_dept_code,
    CAST(NULL AS STRING) AS t_till_limit,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_teller_id,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_teller_transaction AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_short_desc,
    CAST(NULL AS STRING) AS t_desc,
    CAST(NULL AS STRING) AS t_transaction_code_1,
    CAST(NULL AS STRING) AS t_transaction_code_2,
    CAST(NULL AS STRING) AS t_record_status,
    CAST(NULL AS STRING) AS t_curr_no,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_dept_code,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_transfer_deposit AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS az_number,
    CAST(NULL AS STRING) AS cif_old,
    CAST(NULL AS STRING) AS cif_new,
    CAST(NULL AS STRING) AS produc_code,
    CAST(NULL AS STRING) AS term,
    CAST(NULL AS STRING) AS principal,
    CAST(NULL AS STRING) AS mobile_new,
    CAST(NULL AS STRING) AS legal_id_new,
    CAST(NULL AS STRING) AS date_transfer,
    CAST(NULL AS STRING) AS transfer_time_no,
    CAST(NULL AS STRING) AS nominated_ac,
    CAST(NULL AS STRING) AS rm_code,
    CAST(NULL AS STRING) AS opening_date,
    CAST(NULL AS STRING) AS rm_cif,
    CAST(NULL AS STRING) AS rm_ac,
    CAST(NULL AS STRING) AS record_status,
    CAST(NULL AS STRING) AS inputter,
    CAST(NULL AS STRING) AS date_time,
    CAST(NULL AS STRING) AS authoriser,
    CAST(NULL AS STRING) AS co_code,
    CAST(NULL AS STRING) AS name_old,
    CAST(NULL AS STRING) AS name_new,
    CAST(NULL AS STRING) AS rm_cif_name,
    CAST(NULL AS STRING) AS rm_ac_name,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_transfer_deposit,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_user_level_auth AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_auth_level_default,
    CAST(NULL AS STRING) AS t_auth_level_short_term,
    CAST(NULL AS STRING) AS t_begin_date,
    CAST(NULL AS STRING) AS t_expire_date,
    CAST(NULL AS STRING) AS t_value_date,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_user_level_auth,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_vmbh_rpt_pl_vat AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS DECIMAL(38,10)) AS t_begin_bal,
    CAST(NULL AS BIGINT) AS t_buy_month,
    CAST(NULL AS STRING) AS t_avr_rate,
    CAST(NULL AS BIGINT) AS t_sell_month,
    CAST(NULL AS STRING) AS t_buy_avr_rate,
    CAST(NULL AS STRING) AS t_pl_current,
    CAST(NULL AS STRING) AS t_pl_accumulate,
    CAST(NULL AS BIGINT) AS t_tot_pl_month,
    CAST(NULL AS BIGINT) AS t_tot_vat_month,
    CAST(NULL AS BIGINT) AS t_tot_vat_prev,
    CAST(NULL AS BIGINT) AS t_vat_pay_month,
    CAST(NULL AS BIGINT) AS t_vat_carry_fwd,
    CAST(NULL AS BIGINT) AS t_reserved_1,
    CAST(NULL AS STRING) AS t_record_status,
    CAST(NULL AS BIGINT) AS t_curr_no,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_dept_code,
    CAST(NULL AS STRING) AS t_auditor_code,
    CAST(NULL AS STRING) AS t_audit_date_time,
    CAST(NULL AS BIGINT) AS t_tot_pl_prev,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_rpt_pl_vat,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_vmbh_teller_limit AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_ccy,
    CAST(NULL AS STRING) AS t_txn_cod,
    CAST(NULL AS STRING) AS t_limit_amount,
    CAST(NULL AS STRING) AS t_co_code,
    CAST(NULL AS STRING) AS t_date_time,
    CAST(NULL AS STRING) AS t_curr_mo,
    CAST(NULL AS STRING) AS t_inputter,
    CAST(NULL AS STRING) AS t_authoriser,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_teller_limit,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_vmbl_fx_fwsw_work AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_fx_contract,
    CAST(NULL AS STRING) AS t_deal_type,
    CAST(NULL AS STRING) AS t_deal_date,
    CAST(NULL AS STRING) AS t_ccy_bought,
    CAST(NULL AS STRING) AS t_amt_bought,
    CAST(NULL AS STRING) AS t_ccy_sold,
    CAST(NULL AS STRING) AS t_amt_sold,
    CAST(NULL AS DECIMAL(38,10)) AS t_spot_rate,
    CAST(NULL AS DECIMAL(38,10)) AS t_fwd_rate,
    CAST(NULL AS BIGINT) AS t_no_days,
    CAST(NULL AS DECIMAL(38,10)) AS t_profit_loss,
    CAST(NULL AS BIGINT) AS t_dly_amort,
    CAST(NULL AS BIGINT) AS t_last_amort,
    CAST(NULL AS STRING) AS t_base,
    CAST(NULL AS STRING) AS t_value_date,
    CAST(NULL AS STRING) AS t_lcy_equiv,
    CAST(NULL AS BIGINT) AS t_lcy_dly_amort,
    CAST(NULL AS BIGINT) AS t_lcy_last_amort,
    CAST(NULL AS DECIMAL(38,10)) AS t_lcy_profit_loss,
    CAST(NULL AS STRING) AS t_tran_date,
    CAST(NULL AS STRING) AS t_tran_type,
    CAST(NULL AS STRING) AS t_tran_id,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS INT) AS row_number,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_fx_fwsw_work,
    CAST(NULL AS STRING) AS hashdiff_fx_fwsw_work_dynamic,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- Phase 1 -> phase 2, bảng ko đổi 


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_account AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS INT) AS T_CUSTOMER,
    CAST(NULL AS INT) AS T_CATEGORY,
    CAST(NULL AS STRING) AS T_ACCOUNT_TITLE_1,
    CAST(NULL AS STRING) AS T_ACCOUNT_TITLE_2,
    CAST(NULL AS STRING) AS T_SHORT_TITLE,
    CAST(NULL AS STRING) AS T_CURRENCY,
    CAST(NULL AS STRING) AS T_ACCOUNT_OFFICER,
    CAST(NULL AS DECIMAL) AS T_OPEN_ACTUAL_BAL,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_classification,
    CAST(NULL AS STRING) AS hashdiff_account_balance,
    CAST(NULL AS STRING) AS hashdiff_account_system,
    CAST(NULL AS STRING) AS hashdiff_account_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_account_closed AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_ACCT_CLOSE_DATE,
    CAST(NULL AS STRING) AS T_ACCOUNT_NO,
    CAST(NULL AS STRING) AS T_CUSTOMER_ID,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_account_credit_int AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_interest_day_basic,
    CAST(NULL AS STRING) AS t_cr_balance_type,
    CAST(NULL AS STRING) AS t_cr_calcul_type,
    CAST(NULL AS STRING) AS t_cr_int_rate,
    CAST(NULL AS STRING) AS t_cre_margin_rate,
    CAST(NULL AS DECIMAL) AS t_cr_minimum_bal,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_credit_int_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_account_debit_int AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CHARGE_KEY,
    CAST(NULL AS STRING) AS T_INTEREST_DAY_BASIS,
    CAST(NULL AS STRING) AS T_DR_BALANCE_TYPE,
    CAST(NULL AS STRING) AS T_DR_CALCUL_TYPE,
    CAST(NULL AS DECIMAL) AS T_DR_INT_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_debit_int_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_az_account AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_MATURITY_DATE,
    CAST(NULL AS DECIMAL) AS T_INTEREST_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_deposits_terms,
    CAST(NULL AS STRING) AS hashdiff_deposits_system,
    CAST(NULL AS STRING) AS hashdiff_deposits_rate,
    CAST(NULL AS STRING) AS hashdiff_deposits_information,
    CAST(NULL AS STRING) AS hashdiff_deposits_ftp,
    CAST(NULL AS STRING) AS hashdiff_deposits_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_collateral AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_COLLATERAL_TYPE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_collateral_information,
    CAST(NULL AS STRING) AS hashdiff_collateral_insurance,
    CAST(NULL AS STRING) AS hashdiff_collateral_instrument,
    CAST(NULL AS STRING) AS hashdiff_collateral_valuation,
    CAST(NULL AS STRING) AS hashdiff_collateral_vehicle,
    CAST(NULL AS STRING) AS hashdiff_collateral_other,
    CAST(NULL AS STRING) AS hashdiff_collateral_real_estate,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_ld_aprv_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_APRV_DTE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ld_aprv_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_ld_extra_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_SALES_ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ld_extra_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTSv_stg_t24_t24_ld_schedule_define AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_K_DATE,
    CAST(NULL AS STRING) AS T_SCH_TYPE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_schedule,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_lmm_account_balances AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DATE_FROM,
    CAST(NULL AS STRING) AS T_EFFECTIVE_DATE,
    CAST(NULL AS STRING) AS T_TRANS_PRIN_AMT,
    CAST(NULL AS STRING) AS T_OUTS_CURR_PRINC,
    CAST(NULL AS DECIMAL) AS T_OUTS_ACCRUED_INT,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_lmm_account_balances,
    CAST(NULL AS STRING) AS hashdiff_lmm_account_balances_other,
    CAST(NULL AS STRING) AS hashdiff_money_market_lmm_account_balances,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_ln_cust_revs_dtls AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DATE,
    CAST(NULL AS STRING) AS ACCOUNT_BALANCE,
    CAST(NULL AS STRING) AS TOTAL_ACCRUAL,
    CAST(NULL AS STRING) AS CUSTOMER,
    CAST(NULL AS STRING) AS CONTRACT_ID,
    CAST(NULL AS STRING) AS OUTS_AMOUNT,
    CAST(NULL AS STRING) AS CURRENCY,
    CAST(NULL AS STRING) AS K_TYPE,
    CAST(NULL AS STRING) AS OUTS_ACCR_INT,
    CAST(NULL AS STRING) AS STMT_NO,
    CAST(NULL AS STRING) AS T_LINE_NO,
    CAST(NULL AS STRING) AS T_ACCOUNT_NO,
    CAST(NULL AS STRING) AS T_PRE_LINE_NO,
    CAST(NULL AS STRING) AS T_PRE_ACCOUNT_NO,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ln_cust_revs_dtls,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_loans_and_deposits AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_INTEREST_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_approval,
    CAST(NULL AS STRING) AS hashdiff_loans_classification,
    CAST(NULL AS STRING) AS hashdiff_loans_information,
    CAST(NULL AS STRING) AS hashdiff_loans_other,
    CAST(NULL AS STRING) AS hashdiff_loans_insurance,
    CAST(NULL AS STRING) AS hashdiff_loans_system,
    CAST(NULL AS STRING) AS hashdiff_loans_rate,
    CAST(NULL AS STRING) AS hashdiff_loans_terms,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_ocbh_ld_basel AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_BASEL_HOME_PP,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_basel,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_sc_trading_position AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CONSOL_TRADING_BAL,
    CAST(NULL AS STRING) AS T_CPN_ACCR,
    CAST(NULL AS STRING) AS T_CPN_ACCR_POSTED,
    CAST(NULL AS STRING) AS T_CUR_AVG_PRICE,
    CAST(NULL AS STRING) AS T_CUR_COST_POSITION,
    CAST(NULL AS STRING) AS T_CUR_REALIZED_PL,
    CAST(NULL AS STRING) AS T_CURRENT_POSITION,
    CAST(NULL AS STRING) AS T_DATE,
    CAST(NULL AS STRING) AS T_DATE_LAST_TRADED,
    CAST(NULL AS STRING) AS T_DEALER_BOOK,
    CAST(NULL AS STRING) AS T_DISC_ACCR_POSTED,
    CAST(NULL AS STRING) AS T_DISCOUNT_ACCRUED,
    CAST(NULL AS STRING) AS T_ISSUER,
    CAST(NULL AS STRING) AS T_REVAL_UNREAL_PL,
    CAST(NULL AS STRING) AS T_REVALUATION_DATE,
    CAST(NULL AS STRING) AS T_SECURITY_CCY,
    CAST(NULL AS STRING) AS T_SECURITY_CODE,
    CAST(NULL AS STRING) AS T_SETTLED_POSITION,
    CAST(NULL AS STRING) AS T_SETTLEMENT_CCY,
    CAST(NULL AS STRING) AS T_V_DATE_COST_OF_POS,
    CAST(NULL AS STRING) AS T_V_DATE_REAL_PROFIT,
    CAST(NULL AS STRING) AS T_V_DATED_CPN_ACCR,
    CAST(NULL AS STRING) AS T_V_DATED_DIS_ACC,
    CAST(NULL AS STRING) AS T_VALUE_DATED_POS,
    CAST(NULL AS STRING) AS T_POSITION_KEY,
    CAST(NULL AS STRING) AS T_TAX_BALANCE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_sc_trading_position_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


CREATE VIEW IF NOT EXISTS v_stg_t24_t24_security_master AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_COMPANY_NAME,
    CAST(NULL AS STRING) AS T_DESCRIPT,
    CAST(NULL AS STRING) AS T_SHORT_NAME,
    CAST(NULL AS STRING) AS T_MNEMONIC,
    CAST(NULL AS STRING) AS T_SECURITY_CURRENCY,
    CAST(NULL AS STRING) AS T_BOND_OR_SHARE,
    CAST(NULL AS STRING) AS T_QUOTED_LISTED_NO,
    CAST(NULL AS STRING) AS T_SUB_ASSET_TYPE,
    CAST(NULL AS STRING) AS T_LIMIT_REF,
    CAST(NULL AS DECIMAL) AS T_SET_UP_DATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_security_information,
    CAST(NULL AS STRING) AS hashdiff_security_classification,
    CAST(NULL AS STRING) AS hashdiff_security_terms,
    CAST(NULL AS STRING) AS hashdiff_security_pricing,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE VIEW IF NOT EXISTS v_stg_t24_t24_user AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_USER_NAME,
    CAST(NULL AS STRING) AS T_SIGN_ON_NAME,
    CAST(NULL AS STRING) AS T_CLASSIFICATION,
    CAST(NULL AS DECIMAL) AS T_LANGUAGE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_user_information,
    CAST(NULL AS STRING) AS hashdiff_user_classification,
    CAST(NULL AS STRING) AS hashdiff_user_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
