# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE hub_clevertap_tracking (
    clevertap_tracking_hashkey string NOT NULL COMMENT 'Hashkey Hub Clevertap Tracking',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_clevertap_tracking ALTER COLUMN clevertap_tracking_hashkey SET NOT NULL;
ALTER TABLE hub_clevertap_tracking ADD CONSTRAINT hub_clevertap_tracking_pk PRIMARY KEY (clevertap_tracking_hashkey);

CREATE OR REPLACE TABLE hub_message (
    message_hashkey string NOT NULL COMMENT 'Hashkey Hub Message',
    business_key int COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_message ALTER COLUMN message_hashkey SET NOT NULL;
ALTER TABLE hub_message ADD CONSTRAINT hub_message_pk PRIMARY KEY (message_hashkey);

CREATE OR REPLACE TABLE sat_payment_order_information (
    payment_order_hashkey string NOT NULL COMMENT 'Hashkey Hub Payment Order',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account string COMMENT 'Số tài khoản thực hiện giao dịch',
    name string COMMENT 'Tên tài khoản thực hiện giao dịch',
    amount string COMMENT 'Số tiền chuyển',
    currency string COMMENT 'Loại tiền',
    orig_acc_currency string COMMENT 'Tiền tệ tài khoản gốc',
    send_to_core_datetime string COMMENT 'Thời điểm gửi core',
    delivery_date string COMMENT 'Ngày thực hiện',
    rejection_reason string COMMENT 'Lý do từ chối',
    reason_code string COMMENT 'Mã lý do',
    reason_text string COMMENT 'Mô tả lý do',
    error_description string COMMENT 'Mô tả lỗi',
    address_line1 string COMMENT 'Địa chỉ dòng 1',
    address_line2 string COMMENT 'Địa chỉ dòng 2',
    street_name string COMMENT 'Tên đường',
    town string COMMENT 'Thị trấn',
    country_sub_division string COMMENT 'Tỉnh/Thành phố trực thuộc trung ương',
    post_code string COMMENT 'Mã bưu chính',
    country string COMMENT 'Mã quốc gia',
    arrangement_id string COMMENT 'Mã thỏa thuận',
    ext_arrangement_id string COMMENT 'Mã thỏa thuận từ bên ngoài',
    service_agreement_id string COMMENT 'Mã hợp đồng dịch vụ thanh toán',
    additions string COMMENT 'Thông tin bổ sung',
    payment_setup_id string COMMENT 'Mã thiết lập lệnh thanh toán',
    approval_id string COMMENT 'Mã luồng phê duyệt',
    payment_submission_id string COMMENT 'Mã đẩy lệnh thanh toán',
    confirmation_id string COMMENT 'Mã xác nhận giao dịch',
    bank_reference_id string COMMENT 'Mã giao dịch ft',
    created_at string COMMENT 'Thời gian tạo bản ghi',
    created_by string COMMENT 'Mã người tạo bản ghi',
    updated_at string COMMENT 'Thời gian cập nhật bản ghi',
    updated_by string COMMENT 'Mã người cập nhật bản ghi'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_order_information ALTER COLUMN payment_order_hashkey SET NOT NULL;
ALTER TABLE sat_payment_order_information ADD CONSTRAINT sat_payment_order_information_pk PRIMARY KEY (payment_order_hashkey);

CREATE OR REPLACE TABLE sat_payment_order_schedule (
    payment_order_hashkey string NOT NULL COMMENT 'Hashkey Hub Payment Order',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    requested_exec_date string COMMENT 'Ngày yêu cầu thực hiện',
    start_date string COMMENT 'Ngày bắt đầu',
    end_date string COMMENT 'Ngày kết thúc',
    frequency string COMMENT 'Chu kỳ',
    every string COMMENT 'Xử lý hàng ngày',
    when_execute bigint COMMENT 'Thời điểm execute',
    repetition bigint COMMENT 'Số lần lặp',
    remaining_occurrences bigint COMMENT 'Số lần còn lại',
    non_working_day_strategy string COMMENT 'Chiến lược ngày nghỉ'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_order_schedule ALTER COLUMN payment_order_hashkey SET NOT NULL;
ALTER TABLE sat_payment_order_schedule ADD CONSTRAINT sat_payment_order_schedule_pk PRIMARY KEY (payment_order_hashkey);

CREATE OR REPLACE TABLE sat_onboarding_information (
    onboarding_hashkey string NOT NULL COMMENT 'Hashkey Hub Onboarding',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    step_name string COMMENT 'Tên bước thực hiện',
    report_data string COMMENT 'Trường tham chiếu qua Appsflyer',
    phone_number string COMMENT 'Số điện thoại',
    email string COMMENT 'Email',
    identity_number string COMMENT 'Số định danh',
    full_name string COMMENT 'Tên đầy đủ',
    created_at string COMMENT 'Thời gian tạo',
    modified_at string COMMENT 'Thời gian cập nhật'
) CLUSTER BY AUTO;
ALTER TABLE sat_onboarding_information ALTER COLUMN onboarding_hashkey SET NOT NULL;
ALTER TABLE sat_onboarding_information ADD CONSTRAINT sat_onboarding_information_pk PRIMARY KEY (onboarding_hashkey);

CREATE OR REPLACE TABLE sat_device_omni_information (
    device_omni_hashkey string NOT NULL COMMENT 'Hashkey Hub Device OMNI',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    friendly_name string COMMENT 'Tên thiết bị',
    vendor string COMMENT 'Hãng sản xuất thiết bị',
    model string COMMENT 'Model thiết bị',
    created_date_time bigint COMMENT 'Thời điểm tạo thiết bị',
    updated_date_time bigint COMMENT 'Thời điểm cập nhật',
    status string COMMENT 'Trạng thái thiết bị',
    platform string COMMENT 'Nền tảng hệ điều hành',
    push_token string COMMENT 'Token push notification',
    dbs_user_id string COMMENT 'ID người dùng trong hệ thống DBS'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_omni_information ALTER COLUMN device_omni_hashkey SET NOT NULL;
ALTER TABLE sat_device_omni_information ADD CONSTRAINT sat_device_omni_information_pk PRIMARY KEY (device_omni_hashkey);

CREATE OR REPLACE TABLE sat_device_detail (
    device_omni_hashkey string NOT NULL COMMENT 'Hashkey Hub Device OMNI',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active Business Key',
    nfc_enabled tinyint COMMENT 'Thiết bị hỗ trợ NFC hay không',
    omni_version string COMMENT 'Phiên bản ứng dụng',
    os_version string COMMENT 'Hệ điều hành',
    unique_device_id string COMMENT 'Mã thiết bị độc nhất'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_detail ALTER COLUMN device_omni_hashkey SET NOT NULL;
ALTER TABLE sat_device_detail ADD CONSTRAINT sat_device_detail_pk PRIMARY KEY (device_omni_hashkey);

CREATE OR REPLACE TABLE sat_od_registration_agreement (
    od_registration_hashkey string NOT NULL COMMENT 'Hashkey Hub Od Registration',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    contract_file_id string COMMENT 'Mã tệp hợp đồng',
    result_file_id string COMMENT 'Mã tệp kết quả',
    approval_file_id string COMMENT 'Mã tệp phê duyệt',
    contract_bill_code string COMMENT 'Mã hóa đơn hợp đồng',
    first_approval_agreement_uuid string COMMENT 'Mã thỏa thuận phê duyệt lần 1',
    first_approval_bill_code string COMMENT 'Mã hóa đơn phê duyệt lần 1',
    second_approval_agreement_uuid string COMMENT 'Mã thỏa thuận phê duyệt lần 2',
    second_approval_bill_code string COMMENT 'Mã hóa đơn phê duyệt lần 2',
    ecm_approval_document_id string COMMENT 'ID tài liệu phê duyệt trong ECM',
    ecm_contract_document_id string COMMENT 'ID tài liệu hợp đồng trong ECM',
    prepare_certificate_request_id string COMMENT 'ID yêu cầu chuẩn bị chứng thư',
    confirmation_id string COMMENT 'Mã xác nhận hợp đồng',
    approval_agreement_id string COMMENT 'Mã thỏa thuận phê duyệt'
) CLUSTER BY AUTO;
ALTER TABLE sat_od_registration_agreement ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE sat_od_registration_agreement ADD CONSTRAINT sat_od_registration_agreement_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE sat_credit_card_registration_other (
    credit_card_registration_hashkey string NOT NULL COMMENT 'Hashkey Hub Credit Card Registration',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    birthday string COMMENT 'Ngày sinh',
    contact_address string COMMENT 'Địa chỉ liên hệ',
    customer_name string COMMENT 'Tên khách hàng',
    email string COMMENT 'Email',
    id_card_tampering_status string COMMENT 'Trạng thái kiểm tra chỉnh sửa giấy tờ',
    legal_id_num string COMMENT 'Số giấy tờ tùy thân',
    legal_issue_date string COMMENT 'Ngày cấp giấy tờ tùy thân',
    legal_issue_place string COMMENT 'Nơi cấp giấy tờ tùy thân',
    limit_suggest decimal(38,2) COMMENT 'Hạn mức đề xuất',
    marital_status string COMMENT 'Tình trạng hôn nhân',
    legal_id_num_other string COMMENT 'Số giấy tờ tùy thân khác',
    permanent_address string COMMENT 'Địa chỉ thường trú',
    phone_number string COMMENT 'Số điện thoại',
    product_code string COMMENT 'Mã sản phẩm thẻ',
    product_name string COMMENT 'Tên sản phẩm thẻ',
    branch_name string COMMENT 'Tên chi nhánh',
    branch_code string COMMENT 'Mã chi nhánh',
    card_repayment_type string COMMENT 'Loại hình trả nợ thẻ',
    card_repayment_account_no string COMMENT 'Số tài khoản thanh toán thẻ',
    delivery_address string COMMENT 'Địa chỉ giao thẻ',
    old_legal_id_no string COMMENT 'Số giấy tờ tùy thân cũ',
    legal_id_type string COMMENT 'Loại giấy tờ tùy thân',
    legal_expired_date string COMMENT 'Ngày hết hạn giấy tờ tùy thân',
    gender string COMMENT 'Giới tính',
    sale_name string COMMENT 'Tên nhân viên kinh doanh',
    nationality string COMMENT 'Quốc tịch',
    education_level string COMMENT 'Trình độ học vấn',
    card_token_number string COMMENT 'Số token thẻ',
    spouse_name string COMMENT 'Tên vợ/chồng',
    spouse_legal_type string COMMENT 'Loại giấy tờ vợ/chồng',
    spouse_legal_id string COMMENT 'Số giấy tờ vợ/chồng',
    product_code_offer string COMMENT 'Mã sản phẩm thẻ đề xuất',
    product_name_offer string COMMENT 'Tên sản phẩm thẻ đề xuất',
    product_code_offer_list string COMMENT 'Danh sách mã sản phẩm thẻ đề xuất',
    spouse_phone_number string COMMENT 'Số điện thoại vợ/chồng',
    relationship_type string COMMENT 'Loại quan hệ người tham chiếu',
    reference_id string COMMENT 'Mã tham chiếu giao dịch BPM (reference_id)'
) CLUSTER BY AUTO;
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE sat_credit_card_registration_other ADD CONSTRAINT sat_credit_card_registration_other_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE sat_clevertap_tracking_detail (
    clevertap_tracking_hashkey string NOT NULL COMMENT 'Hashkey Hub Clevertap Tracking',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    clevertap_id string COMMENT 'ID định danh người dùng trên CleverTap',
    event_name string COMMENT 'Tên sự kiện được theo dõi',
    channel string COMMENT 'Kênh phát sinh sự kiện',
    created_at string COMMENT 'Thời gian tạo bản ghi',
    modified_at string COMMENT 'Thời gian cập nhật bản ghi gần nhất',
    cif string COMMENT 'Tham chiếu bảng customer (T24)'
) CLUSTER BY AUTO;
ALTER TABLE sat_clevertap_tracking_detail ALTER COLUMN clevertap_tracking_hashkey SET NOT NULL;
ALTER TABLE sat_clevertap_tracking_detail ADD CONSTRAINT sat_clevertap_tracking_detail_pk PRIMARY KEY (clevertap_tracking_hashkey);

CREATE OR REPLACE TABLE sat_message_information (
    message_hashkey string NOT NULL COMMENT 'Hashkey Hub Message',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    uuid string COMMENT 'Khóa chính dạng string',
    root_message_id string COMMENT 'Mã tham chiếu thư gốc (reply chain)',
    subject string COMMENT 'Tiêu đề thư',
    body string COMMENT 'Nội dung body của thư',
    is_body_html boolean COMMENT 'Cờ xác định body có dạng HTML không',
    category string COMMENT 'Phân loại thư',
    important int COMMENT 'Cờ đánh dấu quan trọng',
    sender string COMMENT 'Người gửi (username/id)',
    sender_name string COMMENT 'Tên hiển thị của người gửi',
    sent_date_time string COMMENT 'Thời gian gửi thư',
    read_receipt string COMMENT 'Trạng thái đọc thư',
    deletable int COMMENT 'Cờ cho phép xóa thư',
    read_only int COMMENT 'Cờ chế độ chỉ đọc',
    content_repo_id string COMMENT 'Mã tham chiếu kho nội dung',
    content_path string COMMENT 'Đường dẫn nội dung đính kèm',
    metric_dimensions string COMMENT 'Metadata đo lường theo từng chiều (cột metric dimension)',
    additions string COMMENT 'Thông tin metadata bổ sung',
    recipient string COMMENT 'Tham chiếu en_user'
) CLUSTER BY AUTO;
ALTER TABLE sat_message_information ALTER COLUMN message_hashkey SET NOT NULL;
ALTER TABLE sat_message_information ADD CONSTRAINT sat_message_information_pk PRIMARY KEY (message_hashkey);

CREATE OR REPLACE TABLE sat_notification_information (
    notification_hashkey string NOT NULL COMMENT 'Hashkey Hub Notification',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    uuid string COMMENT 'UUID của thông báo',
    management_id string COMMENT 'Mã quản lý thông báo',
    legal_entity_id string COMMENT 'Mã pháp nhân',
    target_group_code tinyint COMMENT 'Mã nhóm đối tượng nhận thông báo',
    link string COMMENT 'Đường dẫn liên kết của thông báo',
    valid_from string COMMENT 'Thời điểm thông báo bắt đầu hiệu lực',
    expires_on string COMMENT 'Thời điểm thông báo hết hiệu lực',
    origin string COMMENT 'Nguồn gốc của thông báo',
    where_to string COMMENT 'Đích đến điều hướng của thông báo',
    additions string COMMENT 'Thông tin bổ sung',
    route_data string COMMENT 'Dữ liệu định tuyến thông báo',
    service_agreement_id string COMMENT 'Mã hợp đồng dịch vụ liên kết'
) CLUSTER BY AUTO;
ALTER TABLE sat_notification_information ALTER COLUMN notification_hashkey SET NOT NULL;
ALTER TABLE sat_notification_information ADD CONSTRAINT sat_notification_information_pk PRIMARY KEY (notification_hashkey);

CREATE OR REPLACE TABLE sat_od_linked_deposit_information (
    od_registration_hashkey string NOT NULL COMMENT 'Hashkey Hub Od Registration',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active Business Key',
    deposit_balance decimal(38, 2),
    maturity_date string COMMENT 'Ngày đáo hạn sổ tiết kiệm',
    opening_date string COMMENT 'Ngày mở sổ tiết kiệm',
    is_additional_request boolean COMMENT 'Cờ xác định đây có phải yêu cầu bổ sung hay không',
    created_at string COMMENT 'Thời gian tạo bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    updated_at string COMMENT 'Thời gian cập nhật bản ghi gần nhất',
    updated_by string COMMENT 'Người cập nhật bản ghi gần nhất'
) CLUSTER BY AUTO;
ALTER TABLE sat_od_linked_deposit_information ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE sat_od_linked_deposit_information ADD CONSTRAINT sat_od_linked_deposit_information_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE sat_od_registration_information (
    od_registration_hashkey string NOT NULL COMMENT 'Hashkey Hub Od Registration',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status string COMMENT 'Trạng thái yêu cầu',
    full_name string COMMENT 'Họ tên đầy đủ của khách hàng',
    identity_number string COMMENT 'Số giấy tờ tùy thân',
    email string COMMENT 'Địa chỉ email khách hàng',
    phone_number string COMMENT 'Số điện thoại khách hàng',
    address string COMMENT 'Địa chỉ khách hàng',
    username string COMMENT 'Tên đăng nhập của khách hàng',
    issued_by string COMMENT 'Nơi cấp giấy tờ tùy thân',
    created_by string COMMENT 'Người tạo bản ghi',
    updated_by string COMMENT 'Người cập nhật bản ghi'
) CLUSTER BY AUTO;
ALTER TABLE sat_od_registration_information ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE sat_od_registration_information ADD CONSTRAINT sat_od_registration_information_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE sat_data_sharing_consent_other (
    data_sharing_consent_hashkey string NOT NULL COMMENT 'Hashkey Hub Data Sharing Consent',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    created_at string COMMENT 'Thời điểm tạo bản ghi',
    updated_at string COMMENT 'Thời điểm cập nhật bản ghi',
    tracking_schema string COMMENT 'Schema tracking của consent',
    tracking_item string COMMENT 'Item tracking của consent',
    additions string COMMENT 'Thông tin bổ sung'
) CLUSTER BY AUTO;
ALTER TABLE sat_data_sharing_consent_other ALTER COLUMN data_sharing_consent_hashkey SET NOT NULL;
ALTER TABLE sat_data_sharing_consent_other ADD CONSTRAINT sat_data_sharing_consent_other_pk PRIMARY KEY (data_sharing_consent_hashkey);

CREATE OR REPLACE TABLE sat_party_account_other (
    party_hashkey string NOT NULL COMMENT 'Hashkey Hub Party',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    uuid string COMMENT 'UUID định danh tài khoản thụ hưởng',
    alias string COMMENT 'Tên gợi tắt của tài khoản',
    phone_number string COMMENT 'Số điện thoại liên kết tài khoản',
    email string COMMENT 'Email liên kết tài khoản thụ hưởng',
    external_id string COMMENT 'ID tài khoản từ hệ thống bên ngoài',
    party_id string COMMENT 'ID bên thụ hưởng',
    additions string COMMENT 'Thông tin bổ sung',
    bank_address_source string COMMENT 'Nguồn gốc địa chỉ ngân hàng',
    bank_address_line1 string COMMENT 'Địa chỉ ngân hàng - dòng 1',
    bank_address_line2 string COMMENT 'Địa chỉ ngân hàng - dòng 2',
    bank_street_name string COMMENT 'Tên đường - ngân hàng',
    bank_town string COMMENT 'Thành phố - ngân hàng',
    bank_country string COMMENT 'Quốc gia - ngân hàng',
    bank_post_code string COMMENT 'Mã bưu chính - ngân hàng',
    bank_country_sub_division string COMMENT 'Tỉnh/thành - ngân hàng',
    acc_holder_addr_line1 string COMMENT 'Địa chỉ chủ tài khoản - dòng 1',
    acc_holder_addr_line2 string COMMENT 'Địa chỉ chủ tài khoản - dòng 2',
    acc_holder_street_name string COMMENT 'Tên đường - chủ tài khoản',
    acc_holder_town string COMMENT 'Thành phố - chủ tài khoản',
    acc_holder_country string COMMENT 'Quốc gia - chủ tài khoản',
    acc_holder_post_code string COMMENT 'Mã bưu chính - chủ tài khoản',
    acc_holder_country_sub_div string COMMENT 'Tỉnh/thành - chủ tài khoản'
) CLUSTER BY AUTO;
ALTER TABLE sat_party_account_other ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE sat_party_account_other ADD CONSTRAINT sat_party_account_other_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE sat_party_other (
    party_hashkey string NOT NULL COMMENT 'Hashkey Hub Party',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    access_context_scope int COMMENT 'Phạm vi truy cập của party (User/Legal Entity/Service Agreement)',
    bb_id string COMMENT 'ID user đã lưu party này',
    email_id string COMMENT 'Địa chỉ email của party',
    phone_number string COMMENT 'Số điện thoại của party',
    legal_entity_id string COMMENT 'ID pháp nhân liên kết party',
    service_agreement_id string COMMENT 'ID hợp đồng dịch vụ liên kết',
    external_id string COMMENT 'ID party từ hệ thống bên ngoài',
    approval_id string COMMENT 'ID phê duyệt của party',
    active_party_id string COMMENT 'ID party đang active tương ứng',
    import_id string COMMENT 'ID dùng khi import party',
    user_reference string COMMENT 'Mã tham chiếu của user cho giao dịch',
    contact_reference string COMMENT 'Mã tham chiếu của contact cho giao dịch',
    searchable_field_one string COMMENT 'Trường tìm kiếm 1',
    searchable_field_two string COMMENT 'Trường tìm kiếm 2',
    created_at string COMMENT 'Thời điểm tạo party',
    updated_at string COMMENT 'Thời điểm cập nhật party',
    additions string COMMENT 'Thông tin bổ sung',
    address_line1 string COMMENT 'Địa chỉ party - dòng 1',
    address_line2 string COMMENT 'Địa chỉ party - dòng 2',
    street_name string COMMENT 'Tên đường - party',
    town string COMMENT 'Thành phố - party',
    country string COMMENT 'Quốc gia - party',
    post_code string COMMENT 'Mã bưu chính - party',
    country_sub_division string COMMENT 'Tỉnh/thành - party'
) CLUSTER BY AUTO;
ALTER TABLE sat_party_other ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE sat_party_other ADD CONSTRAINT sat_party_other_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE sat_payment_history_other (
    payment_history_hashkey string NOT NULL COMMENT 'Hashkey Hub Payment History',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    detail_code string COMMENT 'Mã chi tiết trạng thái giao dịch',
    arrangement_id string COMMENT 'Mã thỏa thuận liên kết giao dịch',
    core_counter_party_bank_id bigint COMMENT 'Mã ID ngân hàng đối ứng từ core',
    counter_party_name string COMMENT 'Tên đối tác/người thụ hưởng',
    bank_branch string COMMENT 'Chi nhánh ngân hàng đối ứng',
    bank_province string COMMENT 'Tỉnh/thành ngân hàng đối ứng',
    created_at string COMMENT 'Thời gian tạo bản ghi',
    modified_at string COMMENT 'Thời gian cập nhật bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    modified_by string COMMENT 'Người cập nhật bản ghi',
    additions string COMMENT 'Thông tin bổ sung',
    prop1 string COMMENT 'Trường thuộc tính 1 (longtext)',
    prop2 string COMMENT 'Trường thuộc tính 2 (varchar)',
    prop3 decimal(19, 2),
    prop4 bigint COMMENT 'Trường thuộc tính 4 (bigint)',
    prop5 string COMMENT 'Trường thuộc tính 5 (datetime)'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_history_other ALTER COLUMN payment_history_hashkey SET NOT NULL;
ALTER TABLE sat_payment_history_other ADD CONSTRAINT sat_payment_history_other_pk PRIMARY KEY (payment_history_hashkey);

CREATE OR REPLACE TABLE sat_transfer_bill_other (
    transfer_bill_hashkey string NOT NULL COMMENT 'Hashkey Hub Transfer Bill',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account_name string COMMENT 'Tên chủ tài khoản thực hiện giao dịch',
    customer_name string COMMENT 'Tên khách hàng',
    ft_trans_no string COMMENT 'Mã FT',
    reference_id string COMMENT 'Mã tham chiếu giao dịch',
    client_trans_id string COMMENT 'Mã ID giao dịch phía client',
    created_by string COMMENT 'Người tạo giao dịch',
    modified_by string COMMENT 'Người chỉnh sửa giao dịch',
    additions string COMMENT 'Thông tin bổ sung',
    extras string COMMENT 'Thông tin mở rộng',
    prop1 string COMMENT 'Trường dự phòng 1 (longtext)',
    prop2 string COMMENT 'Trường dự phòng 2 (varchar)',
    prop3 decimal(38, 10),
    prop4 bigint COMMENT 'Trường dự phòng 4 (bigint)',
    prop5 string COMMENT 'Trường dự phòng 5 (datetime)'
) CLUSTER BY AUTO;
ALTER TABLE sat_transfer_bill_other ALTER COLUMN transfer_bill_hashkey SET NOT NULL;
ALTER TABLE sat_transfer_bill_other ADD CONSTRAINT sat_transfer_bill_other_pk PRIMARY KEY (transfer_bill_hashkey);

CREATE OR REPLACE TABLE sat_voucher_campaign_other (
    voucher_campaign_hashkey string NOT NULL COMMENT 'Hashkey Hub Voucher Campaign',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id string COMMENT 'ID định danh campaign',
    created_at string COMMENT 'Thời điểm tạo campaign',
    updated_at string COMMENT 'Thời điểm cập nhật campaign',
    created_by string COMMENT 'Người tạo campaign',
    updated_by string COMMENT 'Người cập nhật campaign',
    voucher_user_group_id string COMMENT 'ID nhóm người dùng áp dụng campaign'
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_campaign_other ALTER COLUMN voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_campaign_other ADD CONSTRAINT sat_voucher_campaign_other_pk PRIMARY KEY (voucher_campaign_hashkey);

CREATE OR REPLACE TABLE sat_voucher_generate_other (
    voucher_generate_hashkey string NOT NULL COMMENT 'Hashkey Hub Voucher Generate',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id string COMMENT 'ID định danh bản ghi voucher được claim',
    created_at string COMMENT 'Thời điểm user claim voucher',
    updated_at string COMMENT 'Thời điểm cập nhật bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    updated_by string COMMENT 'Người cập nhật bản ghi'
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_generate_other ALTER COLUMN voucher_generate_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_generate_other ADD CONSTRAINT sat_voucher_generate_other_pk PRIMARY KEY (voucher_generate_hashkey);

CREATE OR REPLACE TABLE sat_voucher_other (
    voucher_hashkey string NOT NULL COMMENT 'Hashkey Hub Voucher',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id string COMMENT 'ID định danh voucher',
    created_at string COMMENT 'Thời điểm tạo voucher',
    updated_at string COMMENT 'Thời điểm cập nhật voucher',
    created_by string COMMENT 'Người tạo voucher',
    updated_by string COMMENT 'Người cập nhật voucher'
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_other ALTER COLUMN voucher_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_other ADD CONSTRAINT sat_voucher_other_pk PRIMARY KEY (voucher_hashkey);

CREATE OR REPLACE TABLE link_voucher_campaign (
    link_voucher_campaign_hashkey string NOT NULL COMMENT 'Link Hashkey',
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hashkey Hub Voucher Campagin',
    voucher_hashkey string COMMENT 'Tham chiếu Hashkey Hub Voucher',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_campaign ALTER COLUMN link_voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE link_voucher_campaign ADD CONSTRAINT link_voucher_campaign_pk PRIMARY KEY (link_voucher_campaign_hashkey);

CREATE OR REPLACE TABLE link_voucher_generate_voucher_campaign (
    link_voucher_generate_voucher_campaign_hashkey string NOT NULL COMMENT 'Link Hashkey',
    voucher_generate_hashkey string COMMENT 'Tham chiếu Hashkey Hub Voucher Generate',
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hashkey Hub Voucher Campaign',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_generate_voucher_campaign ALTER COLUMN link_voucher_generate_voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE link_voucher_generate_voucher_campaign ADD CONSTRAINT link_voucher_generate_voucher_campaign_pk PRIMARY KEY (link_voucher_generate_voucher_campaign_hashkey);


CREATE OR REPLACE TABLE link_clevertap_tracking_customer (
    link_clevertap_tracking_customer_hashkey string NOT NULL COMMENT 'Link Hashkey',
    clevertap_tracking_hashkey string COMMENT 'Tham chiếu Hashkey Hub Clevertap Tracking (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hashkey Hub Customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_clevertap_tracking_customer ALTER COLUMN link_clevertap_tracking_customer_hashkey SET NOT NULL;
ALTER TABLE link_clevertap_tracking_customer ADD CONSTRAINT link_clevertap_tracking_customer_pk PRIMARY KEY (link_clevertap_tracking_customer_hashkey);

CREATE OR REPLACE TABLE link_message_user (
    link_message_user_hashkey string NOT NULL COMMENT 'Link Hashkey',
    message_hashkey string COMMENT 'Tham chiếu Hashkey Hub Message',
    omni_user_hashkey string COMMENT 'Tham chiếu Hashkey Hub User OMNI',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_message_user ALTER COLUMN link_message_user_hashkey SET NOT NULL;
ALTER TABLE link_message_user ADD CONSTRAINT link_message_user_pk PRIMARY KEY (link_message_user_hashkey);

CREATE OR REPLACE TABLE ref_omni_fee_discount (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    created_at string COMMENT 'Thời gian tạo bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    updated_at string COMMENT 'Thời gian cập nhật bản ghi',
    updated_by string COMMENT 'Người cập nhật bản ghi',
    discount_rate decimal(19,2) COMMENT 'Tỷ lệ giảm phí áp dụng',
    end_at string COMMENT 'Thời điểm kết thúc hiệu lực của chương trình giảm phí',
    name string COMMENT 'Tên chương trình giảm phí',
    start_at string COMMENT 'Thời điểm bắt đầu hiệu lực của chương trình giảm phí',
    status string COMMENT 'Trạng thái chương trình giảm phí',
    fee_discount_type string COMMENT 'Loại hình/Phương thức giảm phí',
    fee_reduction_time int COMMENT 'Số lần được áp dụng giảm phí',
    approved_by string COMMENT 'Người phê duyệt chương trình giảm phí',
    hashdiff_full string COMMENT 'Hash diff của bản ghi',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_omni_fee_discount ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_omni_fee_discount ADD CONSTRAINT ref_omni_fee_discount_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_omni_service_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    business_function_id string COMMENT 'Mã chức năng nghiệp vụ gắn với loại dịch vụ',
    maximum_default_transaction_bound decimal(19,2) COMMENT 'Hạn mức giao dịch mặc định tối đa',
    minimum_default_transaction_bound decimal(19,2) COMMENT 'Hạn mức giao dịch mặc định tối thiểu',
    support_limit tinyint COMMENT 'Cờ cho biết loại dịch vụ có hỗ trợ hạn mức hay không',
    payment_type string COMMENT 'Loại hình thanh toán của dịch vụ',
    hashdiff_full string COMMENT 'Hash diff của bản ghi',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_omni_service_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_omni_service_type ADD CONSTRAINT ref_omni_service_type_pk PRIMARY KEY (Ref_hashkey);
