# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- Phase 2
CREATE OR REPLACE VIEW v_stg_clevertap_campaigns AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS campaign_name,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS os,
    CAST(NULL AS STRING) AS device,
    CAST(NULL AS STRING) AS start_time,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS created_time,
    CAST(NULL AS STRING) AS labels,
    CAST(NULL AS STRING) AS delivery,
    CAST(NULL AS STRING) AS type,
    CAST(NULL AS STRING) AS variant,
    CAST(NULL AS STRING) AS title,
    CAST(NULL AS STRING) AS message,
    CAST(NULL AS STRING) AS who_query,
    CAST(NULL AS STRING) AS constant_property,
    CAST(NULL AS STRING) AS badge_id,
    CAST(NULL AS STRING) AS badge_icon,
    CAST(NULL AS STRING) AS send_to_app_inbox_as_well,
    CAST(NULL AS STRING) AS service_provider,
    CAST(NULL AS STRING) AS conversion_event,
    CAST(NULL AS STRING) AS conversion_time_in_minutes,
    CAST(NULL AS STRING) AS campaign_url,
    CAST(NULL AS STRING) AS template_name,
    CAST(NULL AS STRING) AS provider_name,
    CAST(NULL AS STRING) AS waba_number,
    CAST(NULL AS STRING) AS estimated_reach,
    CAST(NULL AS STRING) AS reach,
    CAST(NULL AS STRING) AS total_sent_users,
    CAST(NULL AS STRING) AS total_viewed_users,
    CAST(NULL AS STRING) AS total_clicked_users,
    CAST(NULL AS STRING) AS total_delivered_users,
    CAST(NULL AS STRING) AS total_sent_events,
    CAST(NULL AS STRING) AS total_viewed_events,
    CAST(NULL AS STRING) AS total_clicked_events,
    CAST(NULL AS STRING) AS total_delivered_events,
    CAST(NULL AS STRING) AS errors,
    CAST(NULL AS STRING) AS unique_sent_users,
    CAST(NULL AS STRING) AS click_through_conversions,
    CAST(NULL AS STRING) AS click_through_conversions_pct,
    CAST(NULL AS STRING) AS click_through_conversion_revenue,
    CAST(NULL AS STRING) AS unique_viewed_within_conversion_time,
    CAST(NULL AS STRING) AS unique_clicked_within_conversion_time,
    CAST(NULL AS STRING) AS unique_converted_within_conversion_time,
    CAST(NULL AS STRING) AS revenue_within_conversion_time,
    CAST(NULL AS STRING) AS influenced_conversions,
    CAST(NULL AS STRING) AS influenced_conversions_pct,
    CAST(NULL AS STRING) AS influenced_revenue,
    CAST(NULL AS STRING) AS total_unsubscribes78,
    CAST(NULL AS STRING) AS total_unsubscribes100,
    CAST(NULL AS STRING) AS sent_influenced_conversions,
    CAST(NULL AS STRING) AS sent_influenced_conversions_pct,
    CAST(NULL AS STRING) AS sent_influenced_revenue,
    CAST(NULL AS STRING) AS total_html_viewed_events,
    CAST(NULL AS STRING) AS total_amp_viewed_events,
    CAST(NULL AS STRING) AS total_html_clicked_events,
    CAST(NULL AS STRING) AS total_amp_clicked_events,
    CAST(NULL AS STRING) AS total_html_unsubscribes,
    CAST(NULL AS STRING) AS total_amp_unsubscribes,
    CAST(NULL AS STRING) AS dnd,
    CAST(NULL AS STRING) AS timezone,
    CAST(NULL AS STRING) AS cutoff,
    CAST(NULL AS STRING) AS fcap,
    CAST(NULL AS STRING) AS throttle,
    CAST(NULL AS STRING) AS campaign_overall_limit,
    CAST(NULL AS STRING) AS safety_check_limit,
    CAST(NULL AS STRING) AS campaign_per_day_limit,
    CAST(NULL AS STRING) AS collapse_notification,
    CAST(NULL AS STRING) AS notification_channels,
    CAST(NULL AS STRING) AS push_amplification_applied,
    CAST(NULL AS STRING) AS web_priority,
    CAST(NULL AS STRING) AS time_to_live_type,
    CAST(NULL AS STRING) AS time_to_live_value,
    CAST(NULL AS STRING) AS rendermax_enabled,
    CAST(NULL AS STRING) AS ios_rich_media_type,
    CAST(NULL AS STRING) AS ios_rich_media_url,
    CAST(NULL AS STRING) AS ios_sound_file,
    CAST(NULL AS STRING) AS ios_badge_count,
    CAST(NULL AS STRING) AS ios_category,
    CAST(NULL AS STRING) AS ios_deep_link,
    CAST(NULL AS STRING) AS ios_mutable_content,
    CAST(NULL AS STRING) AS android_subtitle,
    CAST(NULL AS STRING) AS android_image_url,
    CAST(NULL AS STRING) AS android_summary,
    CAST(NULL AS STRING) AS android_large_icon_url,
    CAST(NULL AS STRING) AS android_small_app_icon_colour,
    CAST(NULL AS STRING) AS android_deep_link,
    CAST(NULL AS STRING) AS android_sound_file,
    CAST(NULL AS STRING) AS android_notification_tray_priority,
    CAST(NULL AS STRING) AS android_notification_delivery_priority,
    CAST(NULL AS STRING) AS total_control_group_count,
    CAST(NULL AS STRING) AS total_control_group_conversions,
    CAST(NULL AS STRING) AS total_control_group_conversions_pct,
    CAST(NULL AS STRING) AS total_control_group_revenue,
    CAST(NULL AS STRING) AS system_control_group_count,
    CAST(NULL AS STRING) AS system_control_group_conversions,
    CAST(NULL AS STRING) AS system_control_group_conversions_pct,
    CAST(NULL AS STRING) AS system_control_group_revenue,
    CAST(NULL AS STRING) AS campaign_control_group_count,
    CAST(NULL AS STRING) AS campaign_control_group_conversions,
    CAST(NULL AS STRING) AS campaign_control_group_conversions_pct,
    CAST(NULL AS STRING) AS campaign_control_group_revenue,
    CAST(NULL AS STRING) AS custom_control_group_count,
    CAST(NULL AS STRING) AS custom_control_group_conversions,
    CAST(NULL AS STRING) AS custom_control_group_conversions_pct,
    CAST(NULL AS STRING) AS custom_control_group_revenue,
    CAST(NULL AS STRING) AS custom_control_group_name,
    CAST(NULL AS STRING) AS error_apns_bad_device_token,
    CAST(NULL AS STRING) AS error_user_not_reachable,
    CAST(NULL AS STRING) AS error_inbox_ttl_expired,
    CAST(NULL AS STRING) AS error_user_dnd,
    CAST(NULL AS STRING) AS error_push_unregistered_android,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_campaigns_information,
    CAST(NULL AS STRING) AS hashdiff_campaigns_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_clevertap_events AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS ts,
    CAST(NULL AS STRING) AS profile,
    CAST(NULL AS STRING) AS eventName,
    CAST(NULL AS STRING) AS eventProps,
    CAST(NULL AS STRING) AS deviceInfo,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_events_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
