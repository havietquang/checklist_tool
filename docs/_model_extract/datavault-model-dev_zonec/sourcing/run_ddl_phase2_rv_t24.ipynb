# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;


-- Phase 2


CREATE OR REPLACE TABLE sat_accr_acct_cr_information (
    account_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_liquidity_ccy string COMMENT 'Loại ngoại tệ TK kép lãi',
    t_period_first_date string COMMENT 'Ngày đầu kỳ tính lãi',
    t_cr_int_rate string COMMENT 'Lãi suất',
    t_cr_int_date string COMMENT 'Ngày tính lãi',
    t_cr_int_categ string COMMENT 'Category PL trả lãi',
    t_cr_val_balance string COMMENT 'Số dư tính lãi',
    t_cr_int_tr_ac string COMMENT 'Mã transaction code cho gd trả lãi vào AC',
    t_cr_int_tr_pl string COMMENT 'Mã transaction code cho gd trả lãi ghi nợ từ PL',
    t_liquidity_account string COMMENT 'Tài khoản kép lãi',
    t_compens_account string COMMENT 'Tài khoản phụ để bù trừ lãi và phí',
    t_int_no_booking string COMMENT 'Chỉ tính lãi, không post bút toán',
    t_cr_min_value string COMMENT 'Số tiền lãi MIN',
    t_cr_min_waive string COMMENT 'Số tiền lãi MIN sẽ được set = 0'
) CLUSTER BY AUTO;
ALTER TABLE sat_accr_acct_cr_information ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_accr_acct_cr_information ADD CONSTRAINT sat_accr_acct_cr_information_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_accr_acct_cr_dynamic (
    account_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_period_last_date string COMMENT 'Ngày cuối kỳ tính lãi',
    t_int_post_date string COMMENT 'Ngày post tính lãi cuối',
    t_cr_no_of_days string COMMENT 'Số ngày tính lãi',
    t_cr_int_amt string COMMENT 'Số tiền lãi',
    t_total_interest string COMMENT 'Tổng tiền lãi',
    t_grand_total string COMMENT 'Tổng tiền lãi'
) CLUSTER BY AUTO;
ALTER TABLE sat_accr_acct_cr_dynamic ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_accr_acct_cr_dynamic ADD CONSTRAINT sat_accr_acct_cr_dynamic_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_accr_acct_cr_other (
    account_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_cr_int_tax_code string COMMENT 'Không sử dụng',
    t_cr_int_tax_rate string COMMENT 'Không sử dụng',
    t_cr_int_tax_amt string COMMENT 'Không sử dụng',
    t_cr_int_taxcateg string COMMENT 'Không sử dụng',
    t_cr_int_taxtrsdr string COMMENT 'Không sử dụng',
    t_cr_int_taxtrscr string COMMENT 'Không sử dụng',
    t_tax_for_customer string COMMENT 'Không sử dụng',
    t_tax_for_bank string COMMENT 'Không sử dụng',
    t_ica_post_interest string COMMENT 'Không sử dụng',
    t_ica_main_acct string COMMENT 'Không sử dụng',
    t_ica_dist_type string COMMENT 'Không sử dụng',
    t_ica_dist_ratio string COMMENT 'Không sử dụng',
    t_ica_int_categ string COMMENT 'Không sử dụng',
    t_ica_tr_ac string COMMENT 'Không sử dụng',
    t_ica_tr_pl string COMMENT 'Không sử dụng',
    t_ica_main_int string COMMENT 'Không sử dụng',
    t_ica_sub_int string COMMENT 'Không sử dụng',
    t_correction_number string COMMENT 'Không sử dụng',
    t_unadj_total_int string COMMENT 'Không sử dụng',
    t_tax_exch_rate string COMMENT 'Không sử dụng',
    t_manual_adj_amt string COMMENT 'Không sử dụng',
    t_correction_id string COMMENT 'Không sử dụng',
    t_adj_int_amt string COMMENT 'Không sử dụng',
    t_adj_tax_amt string COMMENT 'Không sử dụng',
    t_withheld_int_amt string COMMENT 'Không sử dụng',
    t_db_netting_amt string COMMENT 'Không sử dụng',
    t_correction_date string COMMENT 'Không sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_accr_acct_cr_other ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_accr_acct_cr_other ADD CONSTRAINT sat_accr_acct_cr_other_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_accr_acct_dr_information (
    account_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_liquidity_ccy string COMMENT 'Mã ngoại tệ kép lãi',
    t_period_first_date string COMMENT 'Ngày đầu kỳ tính lãi',
    t_dr_int_rate string COMMENT 'Lãi suất tính lãi dư nợ',
    t_dr_int_date string COMMENT 'Ngày tính lãi',
    t_dr_int_amt string COMMENT 'Số dư tính lãi',
    t_dr_int_categ string COMMENT 'Mã category PL tính lãi',
    t_dr_val_balance string COMMENT 'Số dư tính lãi',
    t_dr_int_tr_ac string COMMENT 'Mã transaction code cho giao dịch kép lãi vào AC',
    t_dr_int_tr_pl string COMMENT 'Mã transaction code cho giao dịch ghi nợ từ PL',
    t_total_interest string COMMENT 'Tổng tiền lãi'
) CLUSTER BY AUTO;
ALTER TABLE sat_accr_acct_dr_information ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_accr_acct_dr_information ADD CONSTRAINT sat_accr_acct_dr_information_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_accr_acct_dr_dynamic (
    account_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_period_last_date string COMMENT 'Ngày cuối kỳ tính lãi',
    t_dr_no_of_days string COMMENT 'Số ngày'
) CLUSTER BY AUTO;
ALTER TABLE sat_accr_acct_dr_dynamic ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_accr_acct_dr_dynamic ADD CONSTRAINT sat_accr_acct_dr_dynamic_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_acct_activity (
    account_hashkey string NOT NULL COMMENT 'Hub Hash Key tài khoản',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key',
    t_day_no string COMMENT 'Ngày trong tháng',
    t_turnover_credit string COMMENT 'Doanh số ghi có',
    t_turnover_debit string COMMENT 'Doanh số ghi nợ',
    t_balance string COMMENT 'số dư',
    t_transact_code string COMMENT 'Mã loại giao dịch',
    t_no_of_transact string COMMENT 'Số lượng giao dịch',
    t_transact_amt string COMMENT 'Số tiền theo giao dịch',
    t_bk_day_no string COMMENT 'Backup field Số ngày',
    t_bk_balance string COMMENT 'Backup field Số dư',
    t_bk_credit_mvmt string COMMENT 'Backup field doanh số ghi có',
    t_bk_debit_mvmt string COMMENT 'Backup field doanh số ghi nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_acct_activity ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_acct_activity ADD CONSTRAINT sat_acct_activity_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_ac_restrict (
    account_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_customer bigint COMMENT 'Mã CIF của TK bị hạn chế',
    t_ac_title string COMMENT 'Tên TK bị hạn chế',
    t_category bigint COMMENT 'Category của TK bị hạn chế',
    t_currency string COMMENT 'Loại tiền TK',
    t_ac_restrict string COMMENT 'TK được phép ghi có của TK bị hạn chế',
    t_res_customer string COMMENT 'Mã CIF của TK được phép ghi có',
    t_res_ac_title string COMMENT 'Tên TK được phép ghi có',
    t_res_category string COMMENT 'Category của TK được phép ghi có',
    t_res_currency string COMMENT 'Loại tiền của TK được phép ghi có',
    t_inputter string COMMENT 'Người nhập -- trường hệ thống',
    t_authoriser string COMMENT 'Người duyệt -- trường hệ thống',
    t_date_time string COMMENT 'Ngày thực hiện -- trường hệ thống',
    t_co_code string COMMENT 'Chi nhánh thực hiện -- trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_ac_restrict ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_ac_restrict ADD CONSTRAINT sat_ac_restrict_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE sat_cu_add_inf_corp_vn (
    customer_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Customer',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_rep_address string COMMENT 'Số nhà, đường (*)',
    t_rep_ward string COMMENT 'Xã/Phường/ thị trấn (*)',
    t_rep_dist string COMMENT 'Quận/ Huyện (*)',
    t_rep_city string COMMENT 'Tỉnh/TP (*)',
    t_legrep_is_acrep string COMMENT 'Cờ người đại diện CTK cũng là người đại diện pháp luật',
    t_acrep_nat string COMMENT 'Quốc tịch người đại diện CTK',
    t_acrep_name string COMMENT 'Họ và tên người đại diện CTK',
    t_acrep_job string COMMENT 'Chức vụ người đại diện CTK',
    t_acrep_doc string COMMENT 'Loại giấy tờ người đại diện CTK',
    t_acrep_id string COMMENT 'Số giấy tờ người đại diện CTK(*)',
    t_acrep_dob string COMMENT 'Ngày sinh người đại diện CTK(*)',
    t_acrep_phone string COMMENT 'Số điện thoại di động người đại diện CTK (*)',
    t_acrep_email string COMMENT 'Email người đại diện CTK (*)',
    t_acrep_addr string COMMENT 'Số nhà, đường (*)',
    t_acrep_ward string COMMENT 'Xã/Phường/ thị trấn (*)',
    t_acrep_dist string COMMENT 'Quận/ Huyện (*)',
    t_acrep_city string COMMENT 'Tỉnh/TP (*)',
    t_ceo_name string COMMENT 'Họ tên (*) Tổng giám đốc/giám đốc',
    t_ceo_nation string COMMENT 'Quốc tịch (*) Tổng giám đốc/giám đốc',
    t_ceo_job string COMMENT 'Chức vụ (*)',
    t_ceo_doc string COMMENT 'Loại giấy tờ (*)',
    t_ceo_id string COMMENT 'Số giấy tờ Tổng giám đốc/giám đốc(*)',
    t_ceo_addr string COMMENT 'Số nhà, đường (*)',
    t_ceo_ward string COMMENT 'Xã/Phường/ thị trấn (*)',
    t_ceo_dist string COMMENT 'Quận/ Huyện (*)',
    t_ceo_city string COMMENT 'Tỉnh/TP (*)',
    t_capital_ccy string COMMENT 'Mã tiền tệ (*)',
    t_rep_residence string COMMENT 'Cư trú (*) của ng đại diện pháp luật',
    t_rep_visa_no string COMMENT 'Số thị thực người đại diện pháp luật (*)',
    t_rep_lg_iss_dep string COMMENT 'Ngày cấp của ng đại diện pháp luật(*)',
    t_rep_lg_exp_dep string COMMENT 'Ngày hết hạn của ng đại diện pháp luật (*)',
    t_rep_lg_pla_dep string COMMENT 'Nơi cấp của ng đại diện pháp luật (*)',
    t_acrep_residence string COMMENT 'Cư trú (*) của ng đại diện CTK',
    t_acrep_legal_iss string COMMENT 'Ngày cấp của ng đại diện CTK',
    t_acrep_legal_exp string COMMENT 'Ngày hết hạn của ng đại diện CTK',
    t_acrep_legal_pla string COMMENT 'Nơi cấp của ng đại diện CTK',
    t_ceo_residence string COMMENT 'Cư trú của GĐ/Tổng giám đốc',
    t_ceo_visa_no string COMMENT 'Số thị thực của GĐ/Tổng giám đốc',
    t_ceo_iss_date string COMMENT 'Ngày cấp của GĐ/Tổng giám đốc',
    t_ceo_exp_date string COMMENT 'Ngày hết hạn của GĐ/Tổng giám đốc',
    t_ceo_legal_place string COMMENT 'Nơi cấp của GĐ/Tổng giám đốc',
    t_acc_nation string COMMENT 'Quốc tịch kế toán',
    t_acc_residence string COMMENT 'Cư trú kế toán',
    t_acc_name string COMMENT 'Họ và tên kế toán',
    t_acc_title string COMMENT 'Danh xưng kế toán',
    t_acc_visa_no string COMMENT 'Số thị thực kế toán',
    t_acc_job_title string COMMENT 'Chức vụ kế toán',
    t_acc_legal_id string COMMENT 'Số GTTT của Kế toán viên',
    t_acc_legal_type string COMMENT 'Số GTTT kế toán',
    t_acc_iss_date string COMMENT 'Ngày cấp của kế toán',
    t_acc_exp_date string COMMENT 'Ngày hết hạn của kế toán',
    t_acc_legal_place string COMMENT 'Nơi cấp của kế toán',
    t_acc_birth_date string COMMENT 'Ngày sinh kế toán',
    t_acc_phone string COMMENT 'Số điện thoại di động của kế toán',
    t_acc_email string COMMENT 'Email của kế toán',
    t_ocb_indus_tt15 string COMMENT 'Ngành kinh tế chi tiết (TT15) (*)',
    t_ocb_visa_type string COMMENT 'Giấy tờ chứng minh tình trạng cư trú',
    t_rep_visa_exp string COMMENT 'Ngày hết hạn thị thực người đại diện pháp luật *',
    t_acrep_visa_exp string COMMENT 'Ngày hết hạn thị thực ng đại diện tài khoản',
    t_ceo_visa_exp string COMMENT 'Ngày hết hạn thị thực giám đốc/ TGĐ *',
    t_acc_visa_exp string COMMENT 'Ngày hết hạn thị thực KẾ TOÁN',
    t_acrep_visa_no string COMMENT 'Số thị thực người đại diện CTK *'
) CLUSTER BY AUTO;
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_cu_add_inf_corp_vn ADD CONSTRAINT sat_cu_add_inf_corp_vn_pk PRIMARY KEY (customer_hashkey);


CREATE OR REPLACE TABLE hub_standing_order (
    standing_order_hashkey string NOT NULL COMMENT 'Hub Hashkey Standing Order',
    business_key string COMMENT 'Business Key - Mã lệnh thanh toán định kỳ T24',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_standing_order ALTER COLUMN standing_order_hashkey SET NOT NULL;
ALTER TABLE hub_standing_order ADD CONSTRAINT hub_standing_order_pk PRIMARY KEY (standing_order_hashkey);


CREATE OR REPLACE TABLE sts_hub_standing_order (
    standing_order_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_standing_order ALTER COLUMN standing_order_hashkey SET NOT NULL;
ALTER TABLE sts_hub_standing_order ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_standing_order ADD CONSTRAINT sts_hub_standing_order_pk PRIMARY KEY (standing_order_hashkey, source_event_date);


CREATE OR REPLACE TABLE sat_standing_order (
    standing_order_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Standing Order',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_currency string COMMENT 'Mã ngoại tệ',
    t_payment_details string COMMENT 'Nội dung giao dịch',
    t_type string COMMENT 'Loại STO',
    t_pay_method string COMMENT 'Phương thức thanh toán AC/BC/OT',
    t_current_amount_bal decimal(38,10) COMMENT 'Số dư duy trì',
    t_ordering_cust string COMMENT 'Người chỉ định lệnh STO',
    t_debit_customer bigint COMMENT 'Số CIF KH ghi nợ',
    t_credit_customer bigint COMMENT 'Số CIF KH thụ hưởng',
    t_cpty_acct_no string COMMENT 'Tài khoản thụ hưởng',
    t_co_code string COMMENT 'Mã chi nhánh',
    t_acct_officer string COMMENT 'Mã NV quản lý'
) CLUSTER BY AUTO;
ALTER TABLE sat_standing_order ALTER COLUMN standing_order_hashkey SET NOT NULL;
ALTER TABLE sat_standing_order ADD CONSTRAINT sat_standing_order_pk PRIMARY KEY (standing_order_hashkey);


CREATE OR REPLACE TABLE sat_standing_order_dynamic (
    standing_order_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Standing Order',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_current_frequency string COMMENT 'Định kỳ thực hiện',
    t_curr_freq_date string COMMENT 'Kỳ hiện tại',
    t_current_end_date string COMMENT 'Ngày kết thúc',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_last_run_date string COMMENT 'Ngày chạy cuối cùng gần đây'
) CLUSTER BY AUTO;
ALTER TABLE sat_standing_order_dynamic ALTER COLUMN standing_order_hashkey SET NOT NULL;
ALTER TABLE sat_standing_order_dynamic ADD CONSTRAINT sat_standing_order_dynamic_pk PRIMARY KEY (standing_order_hashkey);


CREATE OR REPLACE TABLE link_standing_order_debit_customer (
    link_standing_order_debit_customer_hashkey string NOT NULL COMMENT 'Link Hashkey',
    standing_order_hashkey string COMMENT 'Tham chiếu Hub Standing Order',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer (KH ghi nợ)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_standing_order_debit_customer ALTER COLUMN link_standing_order_debit_customer_hashkey SET NOT NULL;
ALTER TABLE link_standing_order_debit_customer ADD CONSTRAINT link_standing_order_debit_customer_pk PRIMARY KEY (link_standing_order_debit_customer_hashkey);


CREATE OR REPLACE TABLE link_standing_order_credit_customer (
    link_standing_order_credit_customer_hashkey string NOT NULL COMMENT 'Link Hashkey',
    standing_order_hashkey string COMMENT 'Tham chiếu Hub Standing Order',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer (KH thụ hưởng)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_standing_order_credit_customer ALTER COLUMN link_standing_order_credit_customer_hashkey SET NOT NULL;
ALTER TABLE link_standing_order_credit_customer ADD CONSTRAINT link_standing_order_credit_customer_pk PRIMARY KEY (link_standing_order_credit_customer_hashkey);


CREATE OR REPLACE TABLE sat_branch_comp_level_group (
    branch_hashkey string NOT NULL COMMENT 'Tham chieu Hub Branch',
    hashdiff string COMMENT 'Hash diff cua cac cot satellite',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    t_description string COMMENT 'Dien giai',
    t_level2_comp string COMMENT 'Ma chi nhanh con',
    t_lead_company string COMMENT 'Ma chi nhanh hoi so'
) CLUSTER BY AUTO;
ALTER TABLE sat_branch_comp_level_group ALTER COLUMN branch_hashkey SET NOT NULL;
ALTER TABLE sat_branch_comp_level_group ADD CONSTRAINT sat_branch_comp_level_group_pk PRIMARY KEY (branch_hashkey);


CREATE OR REPLACE TABLE sat_branch_li_comp_level_right (
    branch_hashkey string NOT NULL COMMENT 'Tham chieu Hub Branch',
    hashdiff string COMMENT 'Hash diff cua cac cot satellite',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    t_description string COMMENT 'Ten don vi',
    t_parent_company string COMMENT 'Ma don vi quan ly',
    t_currency string COMMENT 'Loai tien',
    t_cust_type string COMMENT 'Loai khach hang',
    t_amount string COMMENT 'So tien phe duyet han muc',
    t_lead_company string COMMENT 'Ma don vi truc thuoc'
) CLUSTER BY AUTO;
ALTER TABLE sat_branch_li_comp_level_right ALTER COLUMN branch_hashkey SET NOT NULL;
ALTER TABLE sat_branch_li_comp_level_right ADD CONSTRAINT sat_branch_li_comp_level_right_pk PRIMARY KEY (branch_hashkey);


CREATE OR REPLACE TABLE sat_user_level_auth (
    user_hashkey string NOT NULL COMMENT 'Tham chieu Hub User',
    hashdiff string COMMENT 'Hash diff cua cac cot satellite',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    t_co_code string COMMENT 'Truong he thong',
    t_auth_level_default string COMMENT 'Ten quyen',
    t_auth_level_short_term string COMMENT 'Ten quyen viet tat',
    t_begin_date string COMMENT 'Ngay bat dau',
    t_expire_date string COMMENT 'Ngay ket thuc',
    t_value_date string COMMENT 'Ngay hieu luc'
) CLUSTER BY AUTO;
ALTER TABLE sat_user_level_auth ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sat_user_level_auth ADD CONSTRAINT sat_user_level_auth_pk PRIMARY KEY (user_hashkey);


CREATE OR REPLACE TABLE sat_teller_limit (
    user_hashkey string NOT NULL COMMENT 'Tham chieu Hub User',
    hashdiff string COMMENT 'Hash diff cua cac cot satellite',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    t_ccy string COMMENT 'Ma ngoai te',
    t_txn_cod string COMMENT 'Ma giao dich TT',
    t_limit_amount string COMMENT 'Han muc GD1C',
    t_co_code string COMMENT 'Ma chi nhanh',
    t_date_time string COMMENT 'Ngay gio nhap duyet',
    t_curr_mo string COMMENT 'So ban ghi',
    t_inputter string COMMENT 'Nguoi nhap',
    t_authoriser string COMMENT 'Nguoi duyet'
) CLUSTER BY AUTO;
ALTER TABLE sat_teller_limit ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sat_teller_limit ADD CONSTRAINT sat_teller_limit_pk PRIMARY KEY (user_hashkey);


CREATE OR REPLACE TABLE ref_t24_ocbh_industry_tt15 (
    id string COMMENT 'Hệ thống tự sinh tăng dần bắt đầu từ 1 Tối đa 6 ký số',
    t_industry_tt15_l1 string COMMENT 'Mã ngành cấp 1',
    t_industry_tt15_l2 string COMMENT 'Mã ngành cấp 2',
    t_industry_tt15_l3 string COMMENT 'Mã ngành cấp 3',
    t_industry_name string COMMENT 'Tên ngành kinh tế',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_industry_tt15 ALTER COLUMN id SET NOT NULL;
ALTER TABLE ref_t24_ocbh_industry_tt15 ADD CONSTRAINT ref_t24_ocbh_industry_tt15_pk PRIMARY KEY (id);


CREATE OR REPLACE TABLE hub_periodic_interest (
    periodic_interest_hashkey string COMMENT 'Hub Periodic Interest Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_periodic_interest ALTER COLUMN periodic_interest_hashkey SET NOT NULL;
ALTER TABLE hub_periodic_interest ADD CONSTRAINT hub_periodic_interest_pk PRIMARY KEY (periodic_interest_hashkey);



CREATE OR REPLACE TABLE sat_periodic_interest (
    periodic_interest_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Periodic Interest Hashkey',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_description string COMMENT 'Tên key lãi suất',
    t_default_mis_table string COMMENT 'Mã key lãi suất',
    t_rest_date string COMMENT 'Ngày kết thúc kỳ hạn',
    t_days_since_spot string COMMENT 'Số ngày từ ngày áp dụng của key',
    t_bid_rate string COMMENT 'Lãi suất áp dụng',
    t_offer_rate string COMMENT 'Lãi suất áp dụng',
    t_rest_period string COMMENT 'Kỳ hạn áp dụng',
    t_record_status string COMMENT 'Trạng thái bản ghi',
    t_curr_no bigint COMMENT 'Số bản ghi',
    t_inputter string COMMENT 'User nhập',
    t_authoriser string COMMENT 'User duyệt',
    t_date_time string COMMENT 'Ngày thực hiện',
    t_co_code string COMMENT 'Chi nhánh thực hiện'
) CLUSTER BY AUTO;
ALTER TABLE sat_periodic_interest ALTER COLUMN periodic_interest_hashkey SET NOT NULL;
ALTER TABLE sat_periodic_interest ADD CONSTRAINT sat_periodic_interest_pk PRIMARY KEY (periodic_interest_hashkey);


CREATE OR REPLACE TABLE hub_teller_id (
    teller_id_hashkey string COMMENT 'Hub Teller ID Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_teller_id ALTER COLUMN teller_id_hashkey SET NOT NULL;
ALTER TABLE hub_teller_id ADD CONSTRAINT hub_teller_id_pk PRIMARY KEY (teller_id_hashkey);



CREATE OR REPLACE TABLE sat_teller_id (
    teller_id_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Teller ID Hashkey',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_status string COMMENT 'Trạng thái',
    t_user string COMMENT 'Mã user sử dụng till',
    t_date_of_open string COMMENT 'Ngày mở till',
    t_time_of_open string COMMENT 'Giờ mở till',
    t_date_of_close string COMMENT 'Ngày đóng till',
    t_time_of_close string COMMENT 'Giờ đóng till',
    t_curr_no string COMMENT 'Số bảng ghi',
    t_inputter string COMMENT 'Người nhập',
    t_date_time string COMMENT 'Ngày giờ nhập duyệt',
    t_authoriser string COMMENT 'Người duyệt',
    t_co_code string COMMENT 'Mã chi nhánh',
    t_dept_code string COMMENT 'Mã phòng ban',
    t_till_limit string COMMENT 'Hạn mức till'
) CLUSTER BY AUTO;
ALTER TABLE sat_teller_id ALTER COLUMN teller_id_hashkey SET NOT NULL;
ALTER TABLE sat_teller_id ADD CONSTRAINT sat_teller_id_pk PRIMARY KEY (teller_id_hashkey);


CREATE OR REPLACE TABLE ref_t24_auto_name (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_auto_name ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_auto_name ADD CONSTRAINT ref_t24_auto_name_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_int_chg_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_FREQUENCY string COMMENT 'tần suất',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_int_chg_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_int_chg_type ADD CONSTRAINT ref_t24_int_chg_type_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_job_title (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_job_title ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_job_title ADD CONSTRAINT ref_t24_job_title_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_limit_level_auth (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_limit_level_auth ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_limit_level_auth ADD CONSTRAINT ref_t24_limit_level_auth_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_prod_package_cb (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_AC_MANAGE_FEE_PER string COMMENT 'Phần trăm ưu đãi phí quản lý TK',
    T_EXT_FT_FEE_PER string COMMENT 'Phần trăm ưu đãi phí chuyển tiền NHT online',
    T_IB_FEE_PER string COMMENT 'Phần trăm ưu đãi phí ebanking',
    T_TAX_FEE_PER string COMMENT 'Phần trăm ưu đãi phí nộp thuế điện tử',
    T_SMS_FEE_PER string COMMENT 'Phần trăm ưu đãi phí SMS',
    T_RECORD_STATUS string COMMENT 'Trạng thái',
    T_CURR_NO string COMMENT 'Mã số bản ghi',
    T_INPUTTER string COMMENT 'User nhập',
    T_DATE_TIME string COMMENT 'Ngày thực hiện',
    T_AUTHORISER string COMMENT 'User duyệt',
    T_CO_CODE string COMMENT 'Mã CNQL',
    T_DEPT_CODE string COMMENT 'Trường không sử dụng',
    T_PACKAGE_FDATE string COMMENT 'Ngày bắt đầu',
    T_PACKAGE_TDATE string COMMENT 'Ngày kết thúc',
    T_AC_MANAGE_FEE_TERM string COMMENT 'Thời gian ưu đãi phí quản lý TK',
    T_EXT_FT_FEE_TERM string COMMENT 'Thời gian ưu đãi phí chuyển tiền NHT online',
    T_IB_FEE_TERM string COMMENT 'Thời gian ưu đãi phí ebanking',
    T_TAX_FEE_TERM string COMMENT 'Thời gian ưu đãi phí nộp thuế điện tử',
    T_SMS_FEE_TERM string COMMENT 'Thời gian ưu đãi phí SMS',
    T_AC_MIN_AVR_BALANCE string COMMENT 'Số dư bình quân tối thiểu',
    T_BATCH_FT_FEE_PER string COMMENT 'Phần trăm ưu đãi phí chi lô',
    T_BATCH_FT_FEE_TERM string COMMENT 'Thời gian ưu đãi phí chi lô',
    T_FT_8S_FEE_PER string COMMENT 'Phần trăm ưu đãi phí chuyển tiền 24/7',
    T_FT_8S_FEE_TERM string COMMENT 'Thời gian ưu đãi phí chuyển tiền 24/7',
    T_EXT_FO_FEE_PER string COMMENT 'Phần trăm ưu đãi phí chuyển tiền NHT tại quầy',
    T_EXT_FO_FEE_TERM string COMMENT 'Thời gian ưu đãi phí chuyển tiền NHT tại quầy',
    T_AVR_BALANCE_FROM string COMMENT 'Số dư bình quân_Từ',
    T_AVR_BALANCE_TO string COMMENT 'Số dư bình quân_Đến',
    T_AC_MANAGE_FEE string COMMENT 'Phí quản lý TK',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_prod_package_cb ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_prod_package_cb ADD CONSTRAINT ref_t24_prod_package_cb_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_re_txn_code (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_re_txn_code ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_re_txn_code ADD CONSTRAINT ref_t24_re_txn_code_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_teller_transaction (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SHORT_DESC string COMMENT 'Tên viết tắt',
    T_TRANSACTION_CODE_1 string COMMENT 'Mã loại phí 1',
    T_TRANSACTION_CODE_2 string COMMENT 'Mã loại phí 2',
    T_RECORD_STATUS string COMMENT 'Trạng thái bản ghi',
    T_CURR_NO string COMMENT 'Số bản ghi',
    T_INPUTTER string COMMENT 'User nhập',
    T_DATE_TIME string COMMENT 'Ngày giờ cập nhật',
    T_AUTHORISER string COMMENT 'User duyệt',
    T_CO_CODE string COMMENT 'CN thực hiện',
    T_DEPT_CODE string COMMENT 'Trường không sử dụng',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_teller_transaction ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_teller_transaction ADD CONSTRAINT ref_t24_teller_transaction_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_t24_denom_exchange (
    ID string COMMENT 'Loại tiền',
    data_date string COMMENT 'Ngày dữ liệu',
    t_denomination string COMMENT 'Mệnh giá',
    t_denom_buy_rate string COMMENT 'Tỷ giá mua',
    t_denom_sell_rate string COMMENT 'Tỷ giá bán',
    t_denom_revl_rate string COMMENT 'Tỷ giá đánh giá lại',
    t_denom_rate_sprd string COMMENT 'N/A',
    t_curr_no string COMMENT 'Số lần thay đổi',
    t_inputter string COMMENT 'Người nhập',
    t_date_time string COMMENT 'Ngày giờ thay đổi',
    t_authoriser string COMMENT 'Người duyệt',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_denom_exchange ALTER COLUMN ID SET NOT NULL;
ALTER TABLE ref_t24_denom_exchange ADD CONSTRAINT ref_t24_denom_exchange_pk PRIMARY KEY (ID);


CREATE OR REPLACE TABLE ref_t24_acct_group_condition (
    ID string COMMENT 'Mã nhóm Tài khoản và loại tiền tệ',
    t_minimum_bal decimal(38,10) COMMENT 'Số dư tối thiểu',
    t_curr_no bigint COMMENT 'Số bản ghi',
    inputter string COMMENT 'User nhập',
    t_date_time string COMMENT 'Ngày thực hiện',
    t_authoriser string COMMENT 'User duyệt',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_acct_group_condition ALTER COLUMN ID SET NOT NULL;
ALTER TABLE ref_t24_acct_group_condition ADD CONSTRAINT ref_t24_acct_group_condition_pk PRIMARY KEY (ID);


CREATE OR REPLACE TABLE ref_t24_lc_enrichment (
    ID string COMMENT 'Mã Enrichment',
    t_operation string COMMENT 'Không dùng',
    t_revocable string COMMENT 'Không dùng',
    t_ucp_ind string COMMENT 'Không dùng',
    t_part_ship string COMMENT 'Không dùng',
    t_transship string COMMENT 'Không dùng',
    t_reimburse string COMMENT 'Không dùng',
    t_charges_from string COMMENT 'Không dùng',
    t_party_chrgd string COMMENT 'Không dùng',
    t_chrg_status string COMMENT 'Không dùng',
    t_drawing_type string COMMENT 'Không dùng',
    t_pay_method string COMMENT 'Không dùng',
    t_coll_reply string COMMENT 'Không dùng',
    t_chrg_period string COMMENT 'Không dùng',
    t_imp_exp string COMMENT 'Không dùng',
    t_pay_type string COMMENT 'Không dùng',
    t_inco_terms string COMMENT 'Không dùng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_lc_enrichment ALTER COLUMN ID SET NOT NULL;
ALTER TABLE ref_t24_lc_enrichment ADD CONSTRAINT ref_t24_lc_enrichment_pk PRIMARY KEY (ID);


CREATE OR REPLACE TABLE ref_t24_group_capitalisation (
    ID string COMMENT 'ID nhóm tài khoản',
    data_date string COMMENT 'Ngày dữ liệu',
    t_dr_cap_frequency string COMMENT 'Định kỳ kép lãi ghi nợ',
    t_cr_cap_frequency string COMMENT 'Định kỳ kép lãi ghi có',
    t_settle_acct_close string COMMENT 'Cần TK chỉ định kép lãi khác khi TK này đóng',
    t_start_of_day_cap string COMMENT 'Kép lãi đầu ngày hay không',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_group_capitalisation ALTER COLUMN ID SET NOT NULL;
ALTER TABLE ref_t24_group_capitalisation ADD CONSTRAINT ref_t24_group_capitalisation_pk PRIMARY KEY (ID);


CREATE OR REPLACE TABLE ref_t24_acct_gen_condition (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_ITEM string COMMENT 'Trường điều kiện ưu tiên',
    T_PRIORITY string COMMENT 'Mức độ ưu tiên',
    T_VALUE string COMMENT 'Giá trị thực tế theo ITEM',
    T_MULTIVALUE string COMMENT 'Khai báo cụm đa giá trị tiếp theo hay không',
    T_CO_CODE string COMMENT 'Mã CN quản lý',
    T_INPUTTER string COMMENT 'User nhập',
    T_DATE_TIME string COMMENT 'Ngày thực hiện',
    T_AUTHORISER string COMMENT 'User duyệt',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_acct_gen_condition ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_acct_gen_condition ADD CONSTRAINT ref_t24_acct_gen_condition_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE sat_scm_extra_info (
    security_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ftp_int_rate_tp string COMMENT 'Loại lãi suất',
    t_ftp_int_chg_date string COMMENT 'Ngày đổi lãi suất',
    t_ftp_nd_term_int string COMMENT 'Kỳ hạn',
    t_ftp_fee_repaid string COMMENT 'Có thu phí tất toán trước hạn',
    t_ftp_description string COMMENT 'Diễn giải',
    t_ocb_ftp_bd_type string COMMENT 'Loại trái phiếu',
    t_ocb_ftp_callput string COMMENT 'Loại quyền call/put',
    t_ocb_ftp_frdate string COMMENT 'Ngày thực hiện quyền đầu tiên',
    t_ocb_ftp_tright string COMMENT 'Định kỳ thực hiện quyền',
    t_ocb_ftp_vlpaper string COMMENT 'Có đảm bảo bằng GTCG',
    t_ocb_ftp_cifcoll string COMMENT 'Cif của TCTD'
) CLUSTER BY AUTO;
ALTER TABLE sat_scm_extra_info ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_scm_extra_info ADD CONSTRAINT sat_scm_extra_info_pk PRIMARY KEY (security_hashkey);


CREATE OR REPLACE TABLE sat_stmt_acct_cr (
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key',
    t_liquidity_ccy string COMMENT 'Mã ngoại tệ kép lãi',
    t_period_first_date string COMMENT 'Ngày đầu kỳ tính lãi',
    t_period_last_date string COMMENT 'Ngày cuối kỳ tính lãi',
    t_cr_int_rate string COMMENT 'Lãi suất ghi có',
    t_cr_int_date string COMMENT 'Ngày tính lãi ghi có',
    t_cr_no_of_days string COMMENT 'Số ngày tính lãi ghi có',
    t_cr_int_amt string COMMENT 'Số tiền lãi ghi có',
    t_cr_int_categ string COMMENT 'Loại category PL trả lãi ghi có',
    t_cr_val_balance string COMMENT 'Số dư tính lãi ghi có',
    t_cr_int_tr_ac string COMMENT 'Mã transaction code cho gd trả lãi vào AC',
    t_cr_int_tr_pl string COMMENT 'Mã transaction code cho gd trả lãi ghi nợ từ PL',
    t_liquidity_account string COMMENT 'Tài khoản kép lãi',
    t_compens_account string COMMENT 'Tài khoản phụ để bù trừ lãi và phí',
    t_int_no_booking string COMMENT 'Chỉ tính lãi, không post bút toán',
    t_total_interest string COMMENT 'Tổng tiền lãi',
    t_grand_total string COMMENT 'Tổng số tiền',
    t_cr_min_value string COMMENT 'Số tiền lãi MIN',
    t_cr_min_waive string COMMENT 'Số tiền lãi MIN sẽ được set = 0',
    t_unadj_total_int string COMMENT 'Không sử dụng',
    t_int_post_date string COMMENT 'Ngày post tính lãi cuối'
) CLUSTER BY AUTO;
ALTER TABLE sat_stmt_acct_cr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_stmt_acct_cr ADD CONSTRAINT sat_stmt_acct_cr_pk PRIMARY KEY (account_hashkey);

CREATE OR REPLACE TABLE sat_stmt_acct_cr_other (
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key',
    t_cr_int_tax_code string COMMENT 'Không sử dụng',
    t_cr_int_tax_rate string COMMENT 'Không sử dụng',
    t_cr_int_tax_amt string COMMENT 'Không sử dụng',
    t_cr_int_taxcateg string COMMENT 'Không sử dụng',
    t_cr_int_taxtrsdr string COMMENT 'Không sử dụng',
    t_cr_int_taxtrscr string COMMENT 'Không sử dụng',
    t_tax_for_customer string COMMENT 'Không sử dụng',
    t_tax_for_bank string COMMENT 'Không sử dụng',
    t_ica_int_categ string COMMENT 'Không sử dụng',
    t_ica_tr_ac string COMMENT 'Không sử dụng',
    t_ica_tr_pl string COMMENT 'Không sử dụng',
    t_ica_main_int string COMMENT 'Không sử dụng',
    t_ica_sub_int string COMMENT 'Không sử dụng',
    t_ica_post_interest string COMMENT 'Không sử dụng',
    t_ica_main_acct string COMMENT 'Không sử dụng',
    t_ica_dist_type string COMMENT 'Không sử dụng',
    t_ica_dist_ratio string COMMENT 'Không sử dụng',
    t_tax_exch_rate string COMMENT 'Không sử dụng',
    t_manual_adj_amt string COMMENT 'Không sử dụng',
    t_correction_number string COMMENT 'Không sử dụng',
    t_correction_id string COMMENT 'Không sử dụng',
    t_adj_int_amt string COMMENT 'Không sử dụng',
    t_adj_tax_amt string COMMENT 'Không sử dụng',
    t_withheld_int_amt string COMMENT 'Không sử dụng',
    t_db_netting_amt string COMMENT 'Không sử dụng',
    t_correction_date string COMMENT 'Không sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_stmt_acct_cr_other ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_stmt_acct_cr_other ADD CONSTRAINT sat_stmt_acct_cr_other_pk PRIMARY KEY (account_hashkey);

CREATE OR REPLACE TABLE sat_stmt_acct_dr (
    account_hashkey string COMMENT 'Tham chiếu Hub Account',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key',
    t_liquidity_ccy string COMMENT 'Mã ngoại tệ kép lãi',
    t_period_first_date string COMMENT 'Ngày đầu kỳ tính lãi',
    t_period_last_date string COMMENT 'Ngày cuối kỳ tính lãi',
    t_dr_int_rate string COMMENT 'Lãi suất tính lãi dư nợ',
    t_dr_int_date string COMMENT 'Ngày tính lãi',
    t_dr_no_of_days string COMMENT 'Số ngày',
    t_dr_int_amt string COMMENT 'Số dư tính lãi',
    t_dr_int_categ string COMMENT 'Mã category PL tính lãi',
    t_dr_val_balance string COMMENT 'Số dư tính lãi',
    t_dr_int_tr_ac string COMMENT 'Mã transaction code cho giao dịch kép lãi vào AC',
    t_dr_int_tr_pl string COMMENT 'Mã transaction code cho giao dịch ghi nợ từ PL'
) CLUSTER BY AUTO;
ALTER TABLE sat_stmt_acct_dr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sat_stmt_acct_dr ADD CONSTRAINT sat_stmt_acct_dr_pk PRIMARY KEY (account_hashkey);


CREATE OR REPLACE TABLE hub_apportion_acct_categ (
    apportion_acct_categ_hashkey string COMMENT 'Hub Apportion Acct Categ Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_apportion_acct_categ ALTER COLUMN apportion_acct_categ_hashkey SET NOT NULL;
ALTER TABLE hub_apportion_acct_categ ADD CONSTRAINT hub_apportion_acct_categ_pk PRIMARY KEY (apportion_acct_categ_hashkey);



CREATE OR REPLACE TABLE sat_apportion_acct_categ (
    apportion_acct_categ_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Apportion Acct Categ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_parent_account string COMMENT 'tài khoản',
    t_level3 string COMMENT 'tài khoản cấp 3',
    t_line string COMMENT 'line',
    t_account_name string COMMENT 'tên tài khoản',
    t_categ_internal string COMMENT 'categ internal',
    t_cust_group string COMMENT 'khối',
    t_no string COMMENT 'stt',
    t_categ_pl string COMMENT 'categ pl',
    t_type_business string COMMENT 'loại tài khoản',
    t_is_mand string COMMENT 'quy định tài khoản (theo quy tắc tckh)',
    t_categ_type string COMMENT 'loại tài khoản',
    t_from_date string COMMENT 'từ ngày',
    t_status string COMMENT 'Không dùng',
    t_pbnb string COMMENT 'là phân bổ nội bộ'
) CLUSTER BY AUTO;
ALTER TABLE sat_apportion_acct_categ ALTER COLUMN apportion_acct_categ_hashkey SET NOT NULL;
ALTER TABLE sat_apportion_acct_categ ADD CONSTRAINT sat_apportion_acct_categ_pk PRIMARY KEY (apportion_acct_categ_hashkey);


CREATE OR REPLACE TABLE hub_coll_bpm_store (
    coll_bpm_store_hashkey string COMMENT 'Hub Coll BPM Store Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_coll_bpm_store ALTER COLUMN coll_bpm_store_hashkey SET NOT NULL;
ALTER TABLE hub_coll_bpm_store ADD CONSTRAINT hub_coll_bpm_store_pk PRIMARY KEY (coll_bpm_store_hashkey);



CREATE OR REPLACE TABLE sat_coll_bpm_store (
    coll_bpm_store_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Coll BPM Store',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_txn_status string COMMENT 'Trạng thái BPM',
    t_collateral_id string COMMENT 'Mã TSĐB',
    t_bpm_trans_id string COMMENT 'Mã giao dịch BPM'
) CLUSTER BY AUTO;
ALTER TABLE sat_coll_bpm_store ALTER COLUMN coll_bpm_store_hashkey SET NOT NULL;
ALTER TABLE sat_coll_bpm_store ADD CONSTRAINT sat_coll_bpm_store_pk PRIMARY KEY (coll_bpm_store_hashkey);



CREATE OR REPLACE TABLE link_coll_bpm_store_collateral (
    link_coll_bpm_store_collateral_hashkey string COMMENT 'Link Hash Key',
    coll_bpm_store_hashkey string COMMENT 'FK tới hub_coll_bpm_store',
    collateral_hashkey string COMMENT 'FK tới hub_collateral',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_coll_bpm_store_collateral ALTER COLUMN link_coll_bpm_store_collateral_hashkey SET NOT NULL;
ALTER TABLE link_coll_bpm_store_collateral ADD CONSTRAINT link_coll_bpm_store_collateral_pk PRIMARY KEY (link_coll_bpm_store_collateral_hashkey);


CREATE OR REPLACE TABLE sat_bank_assure_inp (
    loans_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Loans',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key',
    t_ccy_assr string COMMENT 'Không dùng',
    t_cr_product_code string COMMENT 'Không dùng',
    t_assr_request_date string COMMENT 'Không dùng',
    t_assr_begin_date string COMMENT 'Không dùng',
    t_assr_end_date string COMMENT 'Không dùng',
    t_fee_rate string COMMENT 'Không dùng',
    t_pay_fee_period string COMMENT 'Không dùng',
    t_first_term_amt string COMMENT 'Không dùng',
    t_next_fee_cal_date string COMMENT 'Không dùng',
    t_next_int_begin_date string COMMENT 'Không dùng',
    t_next_int_end_date string COMMENT 'Không dùng',
    t_loan_amount string COMMENT 'Không dùng',
    t_paid_int_freq string COMMENT 'Không dùng',
    t_paid_ori_freq string COMMENT 'Không dùng',
    t_advisory_cadre string COMMENT 'Không dùng',
    t_info_note string COMMENT 'Không dùng',
    t_co_code string COMMENT 'Không dùng',
    t_first_fee_cal_date string COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_bank_assure_inp ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sat_bank_assure_inp ADD CONSTRAINT sat_bank_assure_inp_pk PRIMARY KEY (loans_hashkey);


CREATE OR REPLACE TABLE sat_sc_trans_pos_history (
    sc_trading_position_hashkey string NOT NULL COMMENT 'Tham chiếu Hub SC Trading Position',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_security_ccy string COMMENT 'loại tiền',
    t_curr_per_st_date string COMMENT 'ngày cập nhật trạng thái chứng khoán',
    t_sop_position string COMMENT 'giá trị chứng khoán',
    t_sop_avg_price string COMMENT 'giá trung bình khi COB',
    t_sop_cost_position string COMMENT 'giá trị gốc',
    t_close_bus_date string COMMENT 'giá trị khi COB',
    t_cob_position string COMMENT 'giá trị trung bình',
    t_cob_avg_price string COMMENT 'số dư',
    t_cob_cost_position string COMMENT 'giá chứng khoán khi COB',
    t_ptd_real_pl_posted string COMMENT 'lời lỗ thực tế đã thực hiện',
    t_ptd_real_pl_calc string COMMENT 'lời lỗ thực tế',
    t_ptd_da_calc string COMMENT 'lời lỗ thực tế chưa thực hiện',
    t_trade_date string COMMENT 'ngày giao dịch',
    t_pos_date_time string COMMENT 'ngày pos hệ thống',
    t_trade_ref string COMMENT 'GD liên quan',
    t_trans_type string COMMENT 'loại giao dịch',
    t_nominal string COMMENT 'số tiền',
    t_clean_price string COMMENT 'giá clean',
    t_consid string COMMENT 'trường hệ thống',
    t_accr_interest string COMMENT 'tiền lãi',
    t_value_date string COMMENT 'ngày hiệu lực',
    t_trd_disc_accr string COMMENT 'trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_sc_trans_pos_history ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE sat_sc_trans_pos_history ADD CONSTRAINT sat_sc_trans_pos_history_pk PRIMARY KEY (sc_trading_position_hashkey);


CREATE OR REPLACE TABLE sat_security_position (
    security_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key',
    t_book_cost_sec_ccy decimal(38,10) COMMENT 'loại tiền',
    t_cap_amt decimal(38,10) COMMENT 'số tiền',
    t_closing_bal_no_nom decimal(38,10) COMMENT 'số dư trạng thái chứng khoán',
    t_cost_invst_bse_ccy decimal(38,10) COMMENT 'trường hệ thống',
    t_cost_invst_ref_ccy decimal(38,10) COMMENT 'trường hệ thống',
    t_cost_invst_sec_ccy decimal(38,10) COMMENT 'trường hệ thống',
    t_date_last_traded string COMMENT 'trường hệ thống',
    t_depository bigint COMMENT 'depo',
    t_fin_company string COMMENT 'đơn vị',
    t_gr_bk_cost_sec_ccy decimal(38,10) COMMENT 'loại tiền',
    t_gross_cost_sec_ccy decimal(38,10) COMMENT 'số dư',
    t_held_since string COMMENT 'trường hệ thống',
    t_income_curr_period bigint COMMENT 'trường hệ thống',
    t_issue_date string COMMENT 'ngày issue',
    t_nom_amt_blocked decimal(38,10) COMMENT 'số tiền block',
    t_opening_bal_no_nom decimal(38,10) COMMENT 'số dư',
    t_security_account string COMMENT 'tài khoản chứng khoán',
    t_urlz_ccy_gn_cr_ptf bigint COMMENT 'trường hệ thống',
    t_urlz_mrk_gn_cr_ptf bigint COMMENT 'trường hệ thống',
    t_val_dat_book_cost decimal(38,10) COMMENT 'trường hệ thống',
    t_value_dat_cost_ref decimal(38,10) COMMENT 'trường hệ thống',
    t_value_dated_cost decimal(38,10) COMMENT 'số tiền theo value date',
    t_value_dated_posn bigint COMMENT 'trường hệ thống',
    t_ytd_invst_sec_ccy bigint COMMENT 'trường hệ thống',
    t_amt_blocked decimal(38,10) COMMENT 'số tiền block',
    t_reference_number string COMMENT 'số tham chiếu',
    t_nominee_code string COMMENT 'trường hệ thống',
    t_maturity_date string COMMENT 'ngày đến hạn',
    t_interest_rate decimal(38,10) COMMENT 'lãi suất',
    t_opn_cost_invst_sec string COMMENT 'trường hệ thống',
    t_opn_cost_invst_ptf string COMMENT 'trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_security_position ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_security_position ADD CONSTRAINT sat_security_position_pk PRIMARY KEY (security_hashkey);


CREATE OR REPLACE TABLE hub_diary (
    diary_hashkey string COMMENT 'Hub Hashkey Diary',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_diary ALTER COLUMN diary_hashkey SET NOT NULL;
ALTER TABLE hub_diary ADD CONSTRAINT hub_diary_pk PRIMARY KEY (diary_hashkey);


CREATE OR REPLACE TABLE sts_hub_diary (
    diary_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_diary ALTER COLUMN diary_hashkey SET NOT NULL;
ALTER TABLE sts_hub_diary ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_diary ADD CONSTRAINT sts_hub_diary_pk PRIMARY KEY (diary_hashkey, source_event_date);


CREATE OR REPLACE TABLE sat_diary_information (
    diary_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Diary',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_security_no string COMMENT 'Mã chứng khoán',
    t_narrative string COMMENT 'Diễn giải',
    t_event_type string COMMENT 'Loại sự kiện',
    t_depository string COMMENT 'Depository',
    t_ex_date string COMMENT 'Ngày được hưởng quyền',
    t_pay_date string COMMENT 'Ngày chi trả',
    t_value_date string COMMENT 'Ngày hiệu lực',
    t_currency string COMMENT 'Loại tiền',
    t_rate_type string COMMENT 'Tỷ lệ được trích dẫn',
    t_option_desc string COMMENT 'Diễn giải',
    t_rate string COMMENT 'Tỷ lệ chia cổ tức/coupon',
    t_percentage string COMMENT '%',
    t_commission_code string COMMENT 'Mã phí',
    t_net_charges string COMMENT 'Phí',
    t_bond_share_flag string COMMENT 'Bond/share',
    t_dep_no string COMMENT 'Depository liên quan',
    t_dep_type string COMMENT 'Loại depo',
    t_dep_account_no string COMMENT 'Số tài khoản',
    t_total_cash string COMMENT 'Tổng tiền',
    t_total_cash_ccy string COMMENT 'Loại tiền',
    t_total_cash_xch string COMMENT 'Tổng tiền',
    t_total_cash_lccy string COMMENT 'Tổng tiền',
    t_rp_tot_cash string COMMENT 'Tổng tiền',
    t_rp_tot_cash_lcy string COMMENT 'Tổng tiền',
    t_tot_security string COMMENT 'SL mã chứng khoán nằm giữ',
    t_option string COMMENT 'Diễn giải',
    t_accrual_start_date string COMMENT 'Ngày bắt đầu tính',
    t_portfolio_no string COMMENT 'Porfolio',
    t_cash_hold_settle string COMMENT 'Trường hệ thống',
    t_sec_hold_settle string COMMENT 'Trường hệ thống',
    t_total_credit string COMMENT 'Trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_diary_information ALTER COLUMN diary_hashkey SET NOT NULL;
ALTER TABLE sat_diary_information ADD CONSTRAINT sat_diary_information_pk PRIMARY KEY (diary_hashkey);


CREATE OR REPLACE TABLE sat_diary_system (
    diary_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Diary',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_vault_update string COMMENT 'Trường hệ thống',
    t_local_tax_perc string COMMENT 'Trường hệ thống',
    t_total_debit string COMMENT 'Trường hệ thống',
    t_option_nominal string COMMENT 'Trường hệ thống',
    t_option1 string COMMENT 'Trường hệ thống',
    t_opt1_depot string COMMENT 'Trường hệ thống',
    t_opt1_nominal string COMMENT 'Trường hệ thống',
    t_opt1_cash string COMMENT 'Trường hệ thống',
    t_opt1_cash_ccy string COMMENT 'Trường hệ thống',
    t_opt1_sec string COMMENT 'Trường hệ thống',
    t_opt1_debit string COMMENT 'Trường hệ thống',
    t_auto_update string COMMENT 'Trường hệ thống',
    t_source string COMMENT 'Trường hệ thống',
    t_cash_hold_settle string COMMENT 'Trường hệ thống',
    t_sec_hold_settle string COMMENT 'Trường hệ thống',
    t_total_credit string COMMENT 'Trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_diary_system ALTER COLUMN diary_hashkey SET NOT NULL;
ALTER TABLE sat_diary_system ADD CONSTRAINT sat_diary_system_pk PRIMARY KEY (diary_hashkey);


CREATE OR REPLACE TABLE sat_entitlement (
    diary_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Diary',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã Key',
    t_portfolio_no string COMMENT 'portfolio liên quan',
    t_security_no string COMMENT 'mã chứng khoán',
    t_record_status string COMMENT 'trường hệ thống',
    t_entitlement_amt decimal(38,10) COMMENT 'số tiền',
    t_event_type string COMMENT 'loại quyền'
) CLUSTER BY AUTO;
ALTER TABLE sat_entitlement ALTER COLUMN diary_hashkey SET NOT NULL;
ALTER TABLE sat_entitlement ADD CONSTRAINT sat_entitlement_pk PRIMARY KEY (diary_hashkey);


CREATE OR REPLACE TABLE hub_security_block (
    security_block_hashkey string COMMENT 'Hub Security Block Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_security_block ALTER COLUMN security_block_hashkey SET NOT NULL;
ALTER TABLE hub_security_block ADD CONSTRAINT hub_security_block_pk PRIMARY KEY (security_block_hashkey);


CREATE OR REPLACE TABLE sts_hub_security_block (
    security_block_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_security_block ALTER COLUMN security_block_hashkey SET NOT NULL;
ALTER TABLE sts_hub_security_block ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_security_block ADD CONSTRAINT sts_hub_security_block_pk PRIMARY KEY (security_block_hashkey, source_event_date);


CREATE OR REPLACE TABLE sat_security_block (
    security_block_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Security Block',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_action_date string COMMENT 'Ngày block',
    t_addition_info string COMMENT 'Thông tin diễn giải',
    t_block_eff_from string COMMENT 'Thời gian block từ ..',
    t_blocked_until string COMMENT 'Thời gian block đến ...',
    t_curr_amt_blocked decimal(38,10) COMMENT 'Số lượng block',
    t_diary_id string COMMENT 'Diary',
    t_eff_from_date string COMMENT 'Ngày hiệu lực từ',
    t_eff_to_date string COMMENT 'Ngày hiệu lực đến',
    t_entitlement string COMMENT 'Entitlement liên quan',
    t_interest_rate string COMMENT 'Lãi suất',
    t_maturity_date string COMMENT 'Ngày đến hạn',
    t_new_amt_blocked decimal(38,10) COMMENT 'Số lượng block',
    t_new_block_amt decimal(38,10) COMMENT 'Số lượng mới',
    t_sec_depot string COMMENT 'Depository',
    t_securities_account string COMMENT 'Danh mục chứng khoán',
    t_security_code string COMMENT 'Mã chứng khoán',
    t_sub_account string COMMENT 'Tài khoản',
    t_trans_reference string COMMENT 'Mã giao dịch',
    t_transaction_type string COMMENT 'Loại giao dịch',
    t_product string COMMENT 'Sản phẩm',
    t_notification_msg string COMMENT 'Chưa sử dụng',
    t_inputter string COMMENT 'Người nhập',
    t_date_time string COMMENT 'Thời gian cập nhật',
    t_authoriser string COMMENT 'Người duyệt',
    t_co_code string COMMENT 'Chi nhánh',
    t_ocb_sc_pp_gtcg string COMMENT 'Mục đích cầm cố',
    t_ocb_sc_co_gtcg string COMMENT 'Cầm cố GTCG'
) CLUSTER BY AUTO;
ALTER TABLE sat_security_block ALTER COLUMN security_block_hashkey SET NOT NULL;
ALTER TABLE sat_security_block ADD CONSTRAINT sat_security_block_pk PRIMARY KEY (security_block_hashkey);


CREATE OR REPLACE TABLE link_security_block_security (
    link_security_block_security_hashkey string COMMENT 'Link HK',
    security_block_hashkey string COMMENT 'Tham chiếu Hub Security Block',
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_security_block_security ALTER COLUMN link_security_block_security_hashkey SET NOT NULL;
ALTER TABLE link_security_block_security ADD CONSTRAINT link_security_block_security_pk PRIMARY KEY (link_security_block_security_hashkey);


CREATE OR REPLACE TABLE hub_fx_fwsw_work (
    fx_fwsw_work_hashkey string COMMENT 'Hub Forex Forward Swap Work Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_fx_fwsw_work ALTER COLUMN fx_fwsw_work_hashkey SET NOT NULL;
ALTER TABLE hub_fx_fwsw_work ADD CONSTRAINT hub_fx_fwsw_work_pk PRIMARY KEY (fx_fwsw_work_hashkey);


CREATE OR REPLACE TABLE sts_hub_fx_fwsw_work (
    fx_fwsw_work_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_fx_fwsw_work ALTER COLUMN fx_fwsw_work_hashkey SET NOT NULL;
ALTER TABLE sts_hub_fx_fwsw_work ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_fx_fwsw_work ADD CONSTRAINT sts_hub_fx_fwsw_work_pk PRIMARY KEY (fx_fwsw_work_hashkey, source_event_date);


CREATE OR REPLACE TABLE sat_fx_fwsw_work (
    fx_fwsw_work_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Forex Forward Swap Work',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_fx_contract string COMMENT 'Mã FX',
    t_deal_type string COMMENT 'Loại deal',
    t_deal_date string COMMENT 'Ngày giao dịch',
    t_ccy_bought string COMMENT 'Mã ngoại tệ mua',
    t_amt_bought string COMMENT 'Số lượng mua',
    t_ccy_sold string COMMENT 'Mã ngoại tệ bán',
    t_amt_sold string COMMENT 'Số lượng bán',
    t_spot_rate decimal(38,10) COMMENT 'Tỷ giá spot',
    t_fwd_rate decimal(38,10) COMMENT 'Tỷ giá forward',
    t_no_days bigint COMMENT 'Tổng số ngày',
    t_profit_loss decimal(38,10) COMMENT 'Lãi và lỗ',
    t_dly_amort bigint COMMENT 'Số tiền cộng dồn hàng ngày',
    t_last_amort bigint COMMENT 'Số cộng dồn cuối',
    t_base string COMMENT 'Cơ sở',
    t_value_date string COMMENT 'Ngày bắt đầu',
    t_lcy_equiv string COMMENT 'Số tiền nội tệ quy đổi',
    t_lcy_dly_amort bigint COMMENT 'Số nội tệ cộng dồn hàng ngày',
    t_lcy_last_amort bigint COMMENT 'Số nội tệ cộng dồn cuối',
    t_lcy_profit_loss decimal(38,10) COMMENT 'Lãi và lỗ nội tệ'
) CLUSTER BY AUTO;
ALTER TABLE sat_fx_fwsw_work ALTER COLUMN fx_fwsw_work_hashkey SET NOT NULL;
ALTER TABLE sat_fx_fwsw_work ADD CONSTRAINT sat_fx_fwsw_work_pk PRIMARY KEY (fx_fwsw_work_hashkey);


CREATE OR REPLACE TABLE sat_fx_fwsw_work_dynamic (
    fx_fwsw_work_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Forex Forward Swap Work',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_tran_date string COMMENT 'Ngày giao dịch',
    t_tran_type string COMMENT 'Loại giao dịch',
    t_tran_id string COMMENT 'Mã giao dịch FX'
) CLUSTER BY AUTO;
ALTER TABLE sat_fx_fwsw_work_dynamic ALTER COLUMN fx_fwsw_work_hashkey SET NOT NULL;
ALTER TABLE sat_fx_fwsw_work_dynamic ADD CONSTRAINT sat_fx_fwsw_work_dynamic_pk PRIMARY KEY (fx_fwsw_work_hashkey);


CREATE OR REPLACE TABLE link_diary_security (
    link_diary_security_hashkey string COMMENT 'Link HK',
    diary_hashkey string COMMENT 'Tham chiếu Hub Diary',
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_diary_security ALTER COLUMN link_diary_security_hashkey SET NOT NULL;
ALTER TABLE link_diary_security ADD CONSTRAINT link_diary_security_pk PRIMARY KEY (link_diary_security_hashkey);


CREATE OR REPLACE TABLE sts_hub_teller_id (
    teller_id_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_teller_id ALTER COLUMN teller_id_hashkey SET NOT NULL;
ALTER TABLE sts_hub_teller_id ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_teller_id ADD CONSTRAINT sts_hub_teller_id_pk PRIMARY KEY (teller_id_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_coll_bpm_store (
    coll_bpm_store_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_coll_bpm_store ALTER COLUMN coll_bpm_store_hashkey SET NOT NULL;
ALTER TABLE sts_hub_coll_bpm_store ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_coll_bpm_store ADD CONSTRAINT sts_hub_coll_bpm_store_pk PRIMARY KEY (coll_bpm_store_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_periodic_interest (
    periodic_interest_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_periodic_interest ALTER COLUMN periodic_interest_hashkey SET NOT NULL;
ALTER TABLE sts_hub_periodic_interest ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_periodic_interest ADD CONSTRAINT sts_hub_periodic_interest_pk PRIMARY KEY (periodic_interest_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_apportion_acct_categ (
    apportion_acct_categ_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_apportion_acct_categ ALTER COLUMN apportion_acct_categ_hashkey SET NOT NULL;
ALTER TABLE sts_hub_apportion_acct_categ ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_apportion_acct_categ ADD CONSTRAINT sts_hub_apportion_acct_categ_pk PRIMARY KEY (apportion_acct_categ_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_diary_entitlement (
    diary_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_diary_entitlement ALTER COLUMN diary_hashkey SET NOT NULL;
ALTER TABLE sts_hub_diary_entitlement ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_diary_entitlement ADD CONSTRAINT sts_hub_diary_entitlement_pk PRIMARY KEY (diary_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_account_acct_activity (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_acct_activity ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_acct_activity ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_acct_activity ADD CONSTRAINT sts_hub_account_acct_activity_pk PRIMARY KEY (account_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_user_teller_limit (
    user_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_user_teller_limit ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sts_hub_user_teller_limit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_user_teller_limit ADD CONSTRAINT sts_hub_user_teller_limit_pk PRIMARY KEY (user_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_security_position (
    security_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_security_position ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sts_hub_security_position ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_security_position ADD CONSTRAINT sts_hub_security_position_pk PRIMARY KEY (security_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_security_scm_extra_info (
    security_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_security_scm_extra_info ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sts_hub_security_scm_extra_info ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_security_scm_extra_info ADD CONSTRAINT sts_hub_security_scm_extra_info_pk PRIMARY KEY (security_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_sc_trans_pos_history (
    sc_trading_position_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_sc_trans_pos_history ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE sts_hub_sc_trans_pos_history ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_sc_trans_pos_history ADD CONSTRAINT sts_hub_sc_trans_pos_history_pk PRIMARY KEY (sc_trading_position_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_user_level_auth (
    user_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_user_level_auth ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sts_hub_user_level_auth ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_user_level_auth ADD CONSTRAINT sts_hub_user_level_auth_pk PRIMARY KEY (user_hashkey, source_event_date);


CREATE OR REPLACE TABLE ref_t24_bosc_comp_reg (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'không dùng',
    T_ACCOUNT_NUMBER string COMMENT 'không dùng',
    T_BRANCH_ID string COMMENT 'không dùng',
    hashdiff_full string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_bosc_comp_reg ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_bosc_comp_reg ADD CONSTRAINT ref_t24_bosc_comp_reg_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE hub_transfer_deposit (
    transfer_deposit_hashkey string NOT NULL COMMENT 'Hub Transfer Deposit Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_transfer_deposit ALTER COLUMN transfer_deposit_hashkey SET NOT NULL;
ALTER TABLE hub_transfer_deposit ADD CONSTRAINT hub_transfer_deposit_pk PRIMARY KEY (transfer_deposit_hashkey);

CREATE OR REPLACE TABLE sts_hub_transfer_deposit (
    transfer_deposit_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_transfer_deposit ALTER COLUMN transfer_deposit_hashkey SET NOT NULL;
ALTER TABLE sts_hub_transfer_deposit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_transfer_deposit ADD CONSTRAINT sts_hub_transfer_deposit PRIMARY KEY (transfer_deposit_hashkey, source_event_date);

CREATE OR REPLACE TABLE sat_transfer_deposit (
    transfer_deposit_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Transfer Deposit',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    az_number string COMMENT 'Mã tài khoản sổ tiết kiệm/tiền gửi',
    cif_old string COMMENT 'Mã định danh của chủ sở hữu cũ',
    cif_new string COMMENT 'Mã định danh của chủ sở hữu mới',
    produc_code string COMMENT 'Mã sản phẩm sổ tiết kiệm/tiền gửi',
    term string COMMENT 'Kì hạn',
    principal string COMMENT 'Gốc ban đầu',
    mobile_new string COMMENT 'Số điện thoại của chủ sở hữu mới',
    legal_id_new string COMMENT 'Giấy tờ định danh của chủ sở hữu mới',
    date_transfer string COMMENT 'Ngày chuyển nhượng',
    transfer_time_no string COMMENT 'Lần chuyển nhượng',
    nominated_ac string COMMENT 'Tài khoản chỉ định nhận',
    rm_code string COMMENT 'Mã RM của user thực hiện giao dịch chuyển nhượng',
    opening_date string COMMENT 'Ngày mở sổ',
    rm_cif string COMMENT 'Mã NVQL CIF',
    rm_ac string COMMENT 'Mã NVQL AC',
    record_status string COMMENT 'Trạng thái bản ghi',
    inputter string COMMENT 'User nhập',
    date_time string COMMENT 'Ngày giờ nhập & duyệt',
    authoriser string COMMENT 'User duyệt',
    co_code string COMMENT 'Chi nhánh quản lý sổ',
    name_old string COMMENT 'Tên chủ sở hữu cũ',
    name_new string COMMENT 'Tên chủ sở hữu mới',
    rm_cif_name string COMMENT 'Tên mã NV quản lý CIF',
    rm_ac_name string COMMENT 'Mã NVQL AC'
) CLUSTER BY AUTO;
ALTER TABLE sat_transfer_deposit ALTER COLUMN transfer_deposit_hashkey SET NOT NULL;
ALTER TABLE sat_transfer_deposit ADD CONSTRAINT sat_transfer_deposit_pk PRIMARY KEY (transfer_deposit_hashkey);


CREATE OR REPLACE TABLE link_transfer_deposit_az_account (
    link_transfer_deposit_az_account_hashkey string COMMENT 'Link HK',
    transfer_deposit_hashkey string COMMENT 'Tham chiếu Hub Transfer Deposit',
    deposit_hashkey string COMMENT 'Tham chiếu Hub Deposits',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_deposit_az_account ALTER COLUMN link_transfer_deposit_az_account_hashkey SET NOT NULL;
ALTER TABLE link_transfer_deposit_az_account ADD CONSTRAINT link_transfer_deposit_az_account_pk PRIMARY KEY (link_transfer_deposit_az_account_hashkey);


CREATE OR REPLACE TABLE link_transfer_deposit_acct_officer (
    link_transfer_deposit_acct_officer_hashkey string COMMENT 'Link HK',
    transfer_deposit_hashkey string COMMENT 'Tham chiếu Hub Transfer Deposit',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub Acct Officer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_deposit_acct_officer ALTER COLUMN link_transfer_deposit_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_transfer_deposit_acct_officer ADD CONSTRAINT link_transfer_deposit_acct_officer_pk PRIMARY KEY (link_transfer_deposit_acct_officer_hashkey);


CREATE OR REPLACE TABLE effsat_link_transfer_deposit_acct_officer (
    link_transfer_deposit_acct_officer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_transfer_deposit_acct_officer ALTER COLUMN link_transfer_deposit_acct_officer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_transfer_deposit_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_transfer_deposit_acct_officer ADD CONSTRAINT effsat_link_transfer_deposit_acct_officer_pk PRIMARY KEY (link_transfer_deposit_acct_officer_hashkey, source_event_date);


CREATE OR REPLACE TABLE link_transfer_deposit_customer (
    link_transfer_deposit_customer_hashkey string COMMENT 'Link HK',
    transfer_deposit_hashkey string COMMENT 'Tham chiếu Hub Transfer Deposit',
    customer_hashkey string COMMENT 'Tham chiếu Hub Customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_deposit_customer ALTER COLUMN link_transfer_deposit_customer_hashkey SET NOT NULL;
ALTER TABLE link_transfer_deposit_customer ADD CONSTRAINT link_transfer_deposit_customer_pk PRIMARY KEY (link_transfer_deposit_customer_hashkey);


CREATE OR REPLACE TABLE effsat_link_transfer_deposit_customer (
    link_transfer_deposit_customer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_transfer_deposit_customer ALTER COLUMN link_transfer_deposit_customer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_transfer_deposit_customer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_transfer_deposit_customer ADD CONSTRAINT effsat_link_transfer_deposit_customer_pk PRIMARY KEY (link_transfer_deposit_customer_hashkey, source_event_date);


CREATE OR REPLACE TABLE hub_rpt_pl_vat (
    rpt_pl_vat_hashkey string COMMENT 'Hub RPT PL VAT Hashkey',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_rpt_pl_vat ALTER COLUMN rpt_pl_vat_hashkey SET NOT NULL;
ALTER TABLE hub_rpt_pl_vat ADD CONSTRAINT hub_rpt_pl_vat_pk PRIMARY KEY (rpt_pl_vat_hashkey);


CREATE OR REPLACE TABLE sts_hub_rpt_pl_vat (
    rpt_pl_vat_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_rpt_pl_vat ALTER COLUMN rpt_pl_vat_hashkey SET NOT NULL;
ALTER TABLE sts_hub_rpt_pl_vat ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_rpt_pl_vat ADD CONSTRAINT sts_hub_rpt_pl_vat_pk PRIMARY KEY (rpt_pl_vat_hashkey, source_event_date);


CREATE OR REPLACE TABLE sat_rpt_pl_vat (
    rpt_pl_vat_hashkey string NOT NULL COMMENT 'Tham chiếu Hub RPT PL VAT',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_begin_bal decimal(38,10) COMMENT 'Không dùng',
    t_buy_month bigint COMMENT 'null',
    t_avr_rate string COMMENT 'Không dùng',
    t_sell_month bigint COMMENT 'null',
    t_buy_avr_rate string COMMENT 'Không dùng',
    t_pl_current string COMMENT 'Không dùng',
    t_pl_accumulate string COMMENT 'Không dùng',
    t_tot_pl_month bigint COMMENT 'null',
    t_tot_vat_month bigint COMMENT 'null',
    t_tot_vat_prev bigint COMMENT 'null',
    t_vat_pay_month bigint COMMENT 'null',
    t_vat_carry_fwd bigint COMMENT 'null',
    t_reserved_1 bigint COMMENT 'null',
    t_record_status string COMMENT 'Không dùng',
    t_curr_no bigint COMMENT 'null',
    t_inputter string COMMENT 'Không dùng',
    t_date_time string COMMENT 'Không dùng',
    t_authoriser string COMMENT 'Không dùng',
    t_co_code string COMMENT 'Không dùng',
    t_dept_code string COMMENT 'Không dùng',
    t_auditor_code string COMMENT 'Không dùng',
    t_audit_date_time string COMMENT 'Không dùng',
    t_tot_pl_prev bigint COMMENT 'null'
) CLUSTER BY AUTO;
ALTER TABLE sat_rpt_pl_vat ALTER COLUMN rpt_pl_vat_hashkey SET NOT NULL;
ALTER TABLE sat_rpt_pl_vat ADD CONSTRAINT sat_rpt_pl_vat_pk PRIMARY KEY (rpt_pl_vat_hashkey);


CREATE OR REPLACE TABLE sts_hub_account_accr_acct_cr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_accr_acct_cr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_cr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_cr ADD CONSTRAINT sts_hub_account_accr_acct_cr_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_account_accr_acct_dr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_accr_acct_dr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_dr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_dr ADD CONSTRAINT sts_hub_account_accr_acct_dr_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_account_ac_restrict (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_ac_restrict ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_ac_restrict ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_ac_restrict ADD CONSTRAINT sts_hub_account_ac_restrict_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_account_stmt_acct_cr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_stmt_acct_cr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_cr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_cr ADD CONSTRAINT sts_hub_account_stmt_acct_cr_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_account_stmt_acct_dr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_stmt_acct_dr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_dr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_dr ADD CONSTRAINT sts_hub_account_stmt_acct_dr_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_loans_bank_assure_inp (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_bank_assure_inp ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_bank_assure_inp ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_bank_assure_inp ADD CONSTRAINT sts_hub_loans_bank_assure_inp_pk PRIMARY KEY (loans_hashkey, source_event_date);

# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;


-- Phase 1 -> Phase 2, drop bảng chạy lại


CREATE OR REPLACE TABLE sat_collateral_information (
    collateral_hashkey string COMMENT 'Tham chiếu Hub TSBĐ',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_collateral_type bigint COMMENT 'Loại tài sản bảo đảm',
    t_description string COMMENT 'Mô tả tài sản bảo đảm',
    t_collateral_code bigint COMMENT 'Mã TSBĐ',
    t_coll_status string COMMENT 'Trạng thái tài sản',
    t_expiry_date string COMMENT 'Ngày hết hạn',
    t_value_date string COMMENT 'Ngày giá trị',
    t_ocb_co_note string COMMENT 'Ghi chú khác',
    t_notes string COMMENT 'Ghi chú',
    t_in_cluster string COMMENT 'Thuộc cụm',
    t_borrow_purpose string COMMENT 'Mục đích mượn',
    t_ld_cust_group string COMMENT 'Khối quản lý hồ sơ vay',
    t_ocb_start_date string COMMENT 'Ngày bắt đầu/ phát hành/ sản xuất',
    t_ocb_end_date string COMMENT 'Ngày đáo hạn/ hết hạn sử dụng',
    t_inputter string COMMENT 'Người nhập',
    t_date_time string COMMENT 'Ngày nhập',
    t_authoriser string COMMENT 'Người duyệt',
    T_CURRENCY string COMMENT 'Loại tiền tệ',
    t_application_id string COMMENT 'Loại tiền tệ'      -- cột thêm
) CLUSTER BY AUTO;
ALTER TABLE sat_collateral_information ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sat_collateral_information ADD CONSTRAINT sat_collateral_information_pk PRIMARY KEY (collateral_hashkey);



CREATE OR REPLACE TABLE link_collateral_az_account (
    link_collateral_az_account_hashkey string COMMENT 'Link Hash Key (HASH(HK_CUSTOMER, HK_COLLATERAL))',
    collateral_hashkey string COMMENT 'Hub Hash Key TSBĐ (kỹ thuật)',
    account_hashkey string COMMENT 'Hub Hash Key Account (kỹ thuật)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_collateral_az_account ALTER COLUMN link_collateral_az_account_hashkey SET NOT NULL;
ALTER TABLE link_collateral_az_account ADD CONSTRAINT link_collateral_az_account_pk PRIMARY KEY (link_collateral_az_account_hashkey);



CREATE OR REPLACE TABLE sat_security_information (
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_company_name string COMMENT 'Tên chứng khoán',
    t_descript string COMMENT 'Mô tả',
    t_short_name string COMMENT 'Tên viết tắt',
    t_mnemonic string COMMENT 'Tên gợi nhớ',
    t_stock_exchange string COMMENT 'Sàn giao dịch',
    t_issue_date string COMMENT 'Ngày phát hành',
    t_maturity_date string COMMENT 'Ngày đáo hạn',
    t_alt_security_id string COMMENT 'Mã altisin (ID)',
    t_alt_security_no string COMMENT 'Số altisin',
    t_company_domicile string COMMENT 'Quốc gia công ty mẹ',
    t_set_up_date bigint COMMENT 'Ngày setup',
    t_group_partner string COMMENT 'Phân loại partner',
    t_business_pp string COMMENT 'Mục đích',
    t_bss_detail_pp string COMMENT 'Chi tiết mục đích',
    t_sc_ind_internal string COMMENT 'Trường hệ thống',
    t_trading_units string COMMENT 'Quy tắc hệ thống',
    t_margin_control string COMMENT 'Margin',
    t_ftp_description string COMMENT 'Mô tả FTP',
    t_limit_ref string COMMENT 'Mã limit'       -- cột thêm
) CLUSTER BY AUTO;
ALTER TABLE sat_security_information ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_security_information ADD CONSTRAINT sat_security_information_pk PRIMARY KEY (security_hashkey);

# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;


-- Phase 1 -> Phase 2, bảng không đổi


CREATE TABLE IF NOT EXISTS hub_account (
    account_hashkey string COMMENT 'Hub Hash Key tài khoản',
    business_key string COMMENT 'Business Key: Mã tài khoản',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_account ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE hub_account DROP CONSTRAINT IF EXISTS hub_account_pk;
ALTER TABLE hub_account ADD CONSTRAINT hub_account_pk PRIMARY KEY (account_hashkey);


CREATE TABLE IF NOT EXISTS sts_hub_account (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account DROP CONSTRAINT IF EXISTS sts_hub_account_pk;
ALTER TABLE sts_hub_account ADD CONSTRAINT sts_hub_account_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE TABLE IF NOT EXISTS hub_deposits (
    deposit_hashkey string COMMENT 'Hub Hash Key (kỹ thuật)',
    business_key string COMMENT 'Business Key: Số TK/Hợp đồng AZ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_deposits ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE hub_deposits DROP CONSTRAINT IF EXISTS hub_deposits_pk;
ALTER TABLE hub_deposits ADD CONSTRAINT hub_deposits_pk PRIMARY KEY (deposit_hashkey);


CREATE TABLE IF NOT EXISTS sts_hub_deposits (
    deposit_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_deposits ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sts_hub_deposits ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_deposits DROP CONSTRAINT IF EXISTS sts_hub_deposits_pk;
ALTER TABLE sts_hub_deposits ADD CONSTRAINT sts_hub_deposits_pk PRIMARY KEY (deposit_hashkey, source_event_date);


CREATE TABLE IF NOT EXISTS hub_loans (
    loans_hashkey string COMMENT 'Hub Hash Key Hợp đồng tín dụng',
    business_key string COMMENT 'Business Key: Mã hợp đồng tín dụng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_loans ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE hub_loans DROP CONSTRAINT IF EXISTS hub_loans_pk;
ALTER TABLE hub_loans ADD CONSTRAINT hub_loans_pk PRIMARY KEY (loans_hashkey);


CREATE TABLE IF NOT EXISTS sts_hub_loans (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans DROP CONSTRAINT IF EXISTS sts_hub_loans_pk;
ALTER TABLE sts_hub_loans ADD CONSTRAINT sts_hub_loans_pk PRIMARY KEY (loans_hashkey, source_event_date);


CREATE TABLE IF NOT EXISTS hub_sc_trading_position (
    sc_trading_position_hashkey string COMMENT 'SC Trading Position Hash Key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_sc_trading_position ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE hub_sc_trading_position DROP CONSTRAINT IF EXISTS hub_sc_trading_position_pk;
ALTER TABLE hub_sc_trading_position ADD CONSTRAINT hub_sc_trading_position_pk PRIMARY KEY (sc_trading_position_hashkey);

CREATE TABLE IF NOT EXISTS sts_hub_sc_trading_position (
    sc_trading_position_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_sc_trading_position ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE sts_hub_sc_trading_position ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_sc_trading_position DROP CONSTRAINT IF EXISTS sts_hub_sc_trading_position_pk;
ALTER TABLE sts_hub_sc_trading_position ADD CONSTRAINT sts_hub_sc_trading_position_pk PRIMARY KEY (sc_trading_position_hashkey, source_event_date);


CREATE TABLE IF NOT EXISTS hub_security (
    security_hashkey string COMMENT 'Security Hash Key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_security ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE hub_security DROP CONSTRAINT IF EXISTS hub_security_pk;
ALTER TABLE hub_security ADD CONSTRAINT hub_security_pk PRIMARY KEY (security_hashkey);


CREATE TABLE IF NOT EXISTS sts_hub_security (
    security_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_security ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sts_hub_security ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_security DROP CONSTRAINT IF EXISTS sts_hub_security_pk;
ALTER TABLE sts_hub_security ADD CONSTRAINT sts_hub_security_pk PRIMARY KEY (security_hashkey, source_event_date);


CREATE TABLE IF NOT EXISTS hub_user (
    user_hashkey string COMMENT 'Hub Hash Key User (kỹ thuật)',
    business_key string COMMENT 'Business Key: Mã người dùng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_user ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE hub_user DROP CONSTRAINT IF EXISTS hub_user_pk;
ALTER TABLE hub_user ADD CONSTRAINT hub_user_pk PRIMARY KEY (user_hashkey);


CREATE TABLE IF NOT EXISTS sts_hub_user (
    user_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_user ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sts_hub_user ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_user DROP CONSTRAINT IF EXISTS sts_hub_user_pk;
ALTER TABLE sts_hub_user ADD CONSTRAINT sts_hub_user_pk PRIMARY KEY (user_hashkey, source_event_date);
