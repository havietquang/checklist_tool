# %%
# %sql

USE CATALOG `ocb_datavault_${environment}_cleaned`;

USE SCHEMA `raw_vault`;

ALTER TABLE hub_account ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_account_debit_int.id

ALTER TABLE hub_crb ALTER COLUMN tieukhoan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_crb.tieukhoan

ALTER TABLE hub_customer ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=t24.t24_customer.id

ALTER TABLE hub_deposits ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_az_account.id

ALTER TABLE hub_device_omni ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.device.device_id

ALTER TABLE hub_drawings ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_drawings.id

ALTER TABLE hub_forex ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.id

ALTER TABLE hub_giao_dich ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.giao_dich.gd_id

ALTER TABLE hub_letter_of_credit ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_letter_of_credit.id

ALTER TABLE hub_loans ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ld_extra_info.id

ALTER TABLE hub_loans_payment_due ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_payment_due.id

ALTER TABLE hub_md_deal ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.id

ALTER TABLE hub_money_market ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_lmm_account_balances.id

ALTER TABLE hub_payment_history ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_history.id

ALTER TABLE hub_payment_order ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_order.id

ALTER TABLE hub_pdtd_nhom_giao_dich ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.pdtd_nhom_giao_dich.ma_giao_dich

ALTER TABLE hub_tsbd_giaodich_chinh ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.tsbd_giaodich_chinh.ma_giao_dich

ALTER TABLE hub_xl_ksgn_chung ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.xl_ksgn_chung.ma_giao_dich

ALTER TABLE sat_giao_dich_tht_nhom_chinh_sach_the ALTER COLUMN chi_tiet_1_ten SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=STRING; source=bpm.tht_nhom_chinh_sach_the.chi_tiet_1_ten
ALTER TABLE sat_giao_dich_tht_nhom_chinh_sach_the ALTER COLUMN chi_tiet_2_ten SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=STRING; source=bpm.tht_nhom_chinh_sach_the.chi_tiet_2_ten
ALTER TABLE sat_giao_dich_tht_nhom_chinh_sach_the ALTER COLUMN giay_to_the_phu SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.tht_nhom_chinh_sach_the.giay_to_the_phu

ALTER TABLE sat_account_information ALTER COLUMN t_account_title_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_account.t_account_title_1
ALTER TABLE sat_account_information ALTER COLUMN t_account_title_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_account.t_account_title_2
ALTER TABLE sat_account_information ALTER COLUMN t_alt_acct_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_account.t_alt_acct_id
ALTER TABLE sat_account_information ALTER COLUMN t_arrangement_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_account.t_arrangement_id
ALTER TABLE sat_account_information ALTER COLUMN t_joint_holder SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_account.t_joint_holder
ALTER TABLE sat_account_information ALTER COLUMN t_short_title SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_account.t_short_title

ALTER TABLE sat_account_locked_events ALTER COLUMN t_account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ac_locked_events.t_account_number
ALTER TABLE sat_account_locked_events ALTER COLUMN t_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ac_locked_events.t_description

ALTER TABLE sat_acnt_contract_information ALTER COLUMN contract_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_acnt_contract.contract_name
ALTER TABLE sat_acnt_contract_information ALTER COLUMN contract_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acnt_contract.contract_number
ALTER TABLE sat_acnt_contract_information ALTER COLUMN rbs_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acnt_contract.rbs_number

ALTER TABLE sat_acnt_contract_other ALTER COLUMN tr_first_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_acnt_contract.tr_first_nam
ALTER TABLE sat_acnt_contract_other ALTER COLUMN tr_last_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_acnt_contract.tr_last_nam

ALTER TABLE sat_audit_message_device ALTER COLUMN ip_address SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.audit_message.ip_address

ALTER TABLE sat_audit_message_emulator ALTER COLUMN emulator_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.audit_message.emulator_user_id

ALTER TABLE sat_audit_message_information ALTER COLUMN actor_username SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.audit_message.actor_username

ALTER TABLE sat_auth_nhan_vien ALTER COLUMN so_dien_thoai SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=STRING; source=bpm.auth_nhan_vien.so_dien_thoai

ALTER TABLE sat_auto_debit_customer ALTER COLUMN account_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.auto_debit.account_name
ALTER TABLE sat_auto_debit_customer ALTER COLUMN account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.account_number
ALTER TABLE sat_auto_debit_customer ALTER COLUMN card_account_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.card_account_num
ALTER TABLE sat_auto_debit_customer ALTER COLUMN card_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.card_number
ALTER TABLE sat_auto_debit_customer ALTER COLUMN customer_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.auto_debit.customer_name

ALTER TABLE sat_auto_debit_information ALTER COLUMN bill_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.bill_code

ALTER TABLE sat_auto_debit_properties ALTER COLUMN prop1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.prop1
ALTER TABLE sat_auto_debit_properties ALTER COLUMN prop2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.prop2
ALTER TABLE sat_auto_debit_properties ALTER COLUMN prop3 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=decimal(38,18); source=omni.auto_debit.prop3
ALTER TABLE sat_auto_debit_properties ALTER COLUMN prop4 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=omni.auto_debit.prop4
ALTER TABLE sat_auto_debit_properties ALTER COLUMN prop5 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.auto_debit.prop5

ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN t_ben_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_vmbl_int_clr_citad.t_ben_acct_no
ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN t_credit_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_vmbl_int_clr_citad.t_credit_acct_no
ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN t_debit_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_vmbl_int_clr_citad.t_debit_acct_no
ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN t_payment_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_vmbl_int_clr_citad.t_payment_details
ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN t_receiving_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_vmbl_int_clr_citad.t_receiving_name
ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN t_sending_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_vmbl_int_clr_citad.t_sending_name

ALTER TABLE sat_client_address ALTER COLUMN address_line_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client_address.address_line_1
ALTER TABLE sat_client_address ALTER COLUMN address_line_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client_address.address_line_2
ALTER TABLE sat_client_address ALTER COLUMN address_line_3 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client_address.address_line_3
ALTER TABLE sat_client_address ALTER COLUMN address_line_4 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client_address.address_line_4
ALTER TABLE sat_client_address ALTER COLUMN address_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client_address.address_name
ALTER TABLE sat_client_address ALTER COLUMN birth_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client_address.birth_nam
ALTER TABLE sat_client_address ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=way4.ows_client_address.e_mail
ALTER TABLE sat_client_address ALTER COLUMN fax SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=way4.ows_client_address.fax
ALTER TABLE sat_client_address ALTER COLUMN fax_h SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=way4.ows_client_address.fax_h
ALTER TABLE sat_client_address ALTER COLUMN first_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client_address.first_nam
ALTER TABLE sat_client_address ALTER COLUMN last_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client_address.last_nam
ALTER TABLE sat_client_address ALTER COLUMN parent_address SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client_address.parent_address
ALTER TABLE sat_client_address ALTER COLUMN phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=way4.ows_client_address.phone
ALTER TABLE sat_client_address ALTER COLUMN phone_h SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=way4.ows_client_address.phone_h
ALTER TABLE sat_client_address ALTER COLUMN phone_m SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=way4.ows_client_address.phone_m

ALTER TABLE sat_client_classification ALTER COLUMN affiliated_with SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.affiliated_with

ALTER TABLE sat_client_information ALTER COLUMN birth_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=way4.ows_client.birth_date
ALTER TABLE sat_client_information ALTER COLUMN date_expire SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=way4.ows_client.date_expire
ALTER TABLE sat_client_information ALTER COLUMN father_s_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.father_s_nam
ALTER TABLE sat_client_information ALTER COLUMN first_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.first_nam
ALTER TABLE sat_client_information ALTER COLUMN itn SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client.itn
ALTER TABLE sat_client_information ALTER COLUMN last_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.last_nam
ALTER TABLE sat_client_information ALTER COLUMN mother_s_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.mother_s_nam
ALTER TABLE sat_client_information ALTER COLUMN reg_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client.reg_details
ALTER TABLE sat_client_information ALTER COLUMN reg_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client.reg_number
ALTER TABLE sat_client_information ALTER COLUMN short_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.short_name
ALTER TABLE sat_client_information ALTER COLUMN social_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client.social_number
ALTER TABLE sat_client_information ALTER COLUMN tax_position SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_client.tax_position
ALTER TABLE sat_client_information ALTER COLUMN tr_first_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.tr_first_nam
ALTER TABLE sat_client_information ALTER COLUMN tr_last_nam SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_client.tr_last_nam

ALTER TABLE sat_collateral_other ALTER COLUMN t_contract_link SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_collateral.t_contract_link

ALTER TABLE sat_collateral_real_estate ALTER COLUMN t_add_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_collateral.t_add_num
ALTER TABLE sat_collateral_real_estate ALTER COLUMN t_address SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_collateral.t_address
ALTER TABLE sat_collateral_real_estate ALTER COLUMN t_town_country_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_collateral.t_town_country_2

ALTER TABLE sat_collateral_vehicle ALTER COLUMN t_ocb_estate_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_collateral.t_ocb_estate_num

ALTER TABLE sat_crb_information ALTER COLUMN sotkcu SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_crb.sotkcu
ALTER TABLE sat_crb_information ALTER COLUMN ten SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_crb.ten

ALTER TABLE sat_credit_card_registration_flow ALTER COLUMN contract_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.contract_no

ALTER TABLE sat_credit_card_registration_introduce ALTER COLUMN introduce_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.credit_card_registration.introduce_name
ALTER TABLE sat_credit_card_registration_introduce ALTER COLUMN reference_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.credit_card_registration.reference_name
ALTER TABLE sat_credit_card_registration_introduce ALTER COLUMN reference_phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.credit_card_registration.reference_phone_number

ALTER TABLE sat_cust_package ALTER COLUMN t_account_charge SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_cus_pkg.t_account_charge

ALTER TABLE sat_customer_contact ALTER COLUMN add_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.add_num
ALTER TABLE sat_customer_contact ALTER COLUMN address SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.address
ALTER TABLE sat_customer_contact ALTER COLUMN bussiness_addr SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.bussiness_addr
ALTER TABLE sat_customer_contact ALTER COLUMN contact_person SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.contact_person
ALTER TABLE sat_customer_contact ALTER COLUMN email_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=t24.t24_customer.email_1
ALTER TABLE sat_customer_contact ALTER COLUMN legal_id_deputy SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.legal_id_deputy
ALTER TABLE sat_customer_contact ALTER COLUMN off_phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_customer.off_phone
ALTER TABLE sat_customer_contact ALTER COLUMN off_phone_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_customer.off_phone_2
ALTER TABLE sat_customer_contact ALTER COLUMN phone_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_customer.phone_1
ALTER TABLE sat_customer_contact ALTER COLUMN phone_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_customer.phone_2
ALTER TABLE sat_customer_contact ALTER COLUMN representative SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.representative
ALTER TABLE sat_customer_contact ALTER COLUMN sms_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_customer.sms_1
ALTER TABLE sat_customer_contact ALTER COLUMN sms_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_customer.sms_2
ALTER TABLE sat_customer_contact ALTER COLUMN street SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.street
ALTER TABLE sat_customer_contact ALTER COLUMN ward_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.ward_1
ALTER TABLE sat_customer_contact ALTER COLUMN ward_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.ward_2

ALTER TABLE sat_customer_information ALTER COLUMN birth_incorp_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_customer.birth_incorp_date
ALTER TABLE sat_customer_information ALTER COLUMN family_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.family_name
ALTER TABLE sat_customer_information ALTER COLUMN given_names SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.given_names
ALTER TABLE sat_customer_information ALTER COLUMN name_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.name_1
ALTER TABLE sat_customer_information ALTER COLUMN name_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.name_2
ALTER TABLE sat_customer_information ALTER COLUMN short_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_customer.short_name

ALTER TABLE sat_customer_kyc ALTER COLUMN legal_exp_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_customer.legal_exp_date
ALTER TABLE sat_customer_kyc ALTER COLUMN legal_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.legal_id
ALTER TABLE sat_customer_kyc ALTER COLUMN tax_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_customer.tax_id

ALTER TABLE sat_customer_other ALTER COLUMN email_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=t24.t24_customer.email_2

ALTER TABLE sat_device_information ALTER COLUMN phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=way4.ows_device_rec.phone
ALTER TABLE sat_device_information ALTER COLUMN serial_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_device_rec.serial_number
ALTER TABLE sat_device_information ALTER COLUMN x_25_address SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_device_rec.x_25_address

ALTER TABLE sat_device_omni_information ALTER COLUMN push_token SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.device.push_token

ALTER TABLE sat_document_classification ALTER COLUMN requirement SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.requirement

ALTER TABLE sat_document_description ALTER COLUMN reason_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.reason_details
ALTER TABLE sat_document_description ALTER COLUMN trans_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.trans_details

ALTER TABLE sat_document_identifiers ALTER COLUMN acq_ref_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.acq_ref_number
ALTER TABLE sat_document_identifiers ALTER COLUMN iss_ref_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.iss_ref_number
ALTER TABLE sat_document_identifiers ALTER COLUMN ps_ref_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.ps_ref_number
ALTER TABLE sat_document_identifiers ALTER COLUMN ret_ref_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.ret_ref_number
ALTER TABLE sat_document_identifiers ALTER COLUMN source_reg_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.source_reg_num

ALTER TABLE sat_document_source ALTER COLUMN source_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.source_number

ALTER TABLE sat_document_target ALTER COLUMN target_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_doc.target_number

ALTER TABLE sat_drawings_information ALTER COLUMN t_link_ld_ref SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_drawings.t_link_ld_ref
ALTER TABLE sat_drawings_information ALTER COLUMN t_payment_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_drawings.t_payment_account
ALTER TABLE sat_drawings_information ALTER COLUMN t_presentor SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_drawings.t_presentor

ALTER TABLE sat_forex_audit_status ALTER COLUMN t_contact_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_forex.t_contact_name
ALTER TABLE sat_forex_audit_status ALTER COLUMN t_dealer_notes SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_dealer_notes
ALTER TABLE sat_forex_audit_status ALTER COLUMN t_national_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_national_id
ALTER TABLE sat_forex_audit_status ALTER COLUMN t_notes SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_notes

ALTER TABLE sat_forex_classification ALTER COLUMN t_buyfcy_pp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_buyfcy_pp
ALTER TABLE sat_forex_classification ALTER COLUMN t_our_account_pay SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_our_account_pay
ALTER TABLE sat_forex_classification ALTER COLUMN t_our_account_rec SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_our_account_rec

ALTER TABLE sat_forex_information ALTER COLUMN t_swap_ref_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_swap_ref_no

ALTER TABLE sat_forex_payment_swift ALTER COLUMN t_ben_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_ben_acct_no
ALTER TABLE sat_forex_payment_swift ALTER COLUMN t_cparty_bank_acc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_cparty_bank_acc
ALTER TABLE sat_forex_payment_swift ALTER COLUMN t_transaction_ref_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_forex.t_transaction_ref_no

ALTER TABLE sat_funds_transfer_account ALTER COLUMN t_acct_with_bank_acc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_acct_with_bank_acc
ALTER TABLE sat_funds_transfer_account ALTER COLUMN t_ben_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_ben_acct_no
ALTER TABLE sat_funds_transfer_account ALTER COLUMN t_in_ben_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_in_ben_acct_no
ALTER TABLE sat_funds_transfer_account ALTER COLUMN t_ordering_ac SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_ordering_ac
ALTER TABLE sat_funds_transfer_account ALTER COLUMN t_sub_va_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_sub_va_id

ALTER TABLE sat_funds_transfer_fee ALTER COLUMN t_charges_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_charges_acct_no

ALTER TABLE sat_funds_transfer_information ALTER COLUMN t_credit_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_credit_acct_no
ALTER TABLE sat_funds_transfer_information ALTER COLUMN t_debit_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_debit_acct_no
ALTER TABLE sat_funds_transfer_information ALTER COLUMN t_payment_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_payment_details

ALTER TABLE sat_funds_transfer_other ALTER COLUMN t_msg_narrative SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_msg_narrative
ALTER TABLE sat_funds_transfer_other ALTER COLUMN t_ocb_ben_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_ocb_ben_acct
ALTER TABLE sat_funds_transfer_other ALTER COLUMN t_ocb_tax_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_ocb_tax_code
ALTER TABLE sat_funds_transfer_other ALTER COLUMN t_tax_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_tax_code

ALTER TABLE sat_funds_transfer_party ALTER COLUMN t_ben_customer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_funds_transfer.t_ben_customer
ALTER TABLE sat_funds_transfer_party ALTER COLUMN t_cu_d_ord_cpt SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_funds_transfer.t_cu_d_ord_cpt
ALTER TABLE sat_funds_transfer_party ALTER COLUMN t_in_ben_customer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_funds_transfer.t_in_ben_customer

ALTER TABLE sat_giao_dich_tdtc_thong_tin_chung ALTER COLUMN ma_so_thue_dn SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.tdtc_thong_tin_chung.ma_so_thue_dn

ALTER TABLE sat_giao_dich_tdtc_thong_tin_to_trinh ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=STRING; source=bpm.tdtc_thong_tin_to_trinh.email
ALTER TABLE sat_giao_dich_tdtc_thong_tin_to_trinh ALTER COLUMN ma_so_thue_dn SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.tdtc_thong_tin_to_trinh.ma_so_thue_dn
ALTER TABLE sat_giao_dich_tdtc_thong_tin_to_trinh ALTER COLUMN sdt SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=bpm.tdtc_thong_tin_to_trinh.sdt

ALTER TABLE sat_giao_dich_tsbd ALTER COLUMN chu_so_huu SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.giao_dich_tsbd.chu_so_huu
ALTER TABLE sat_giao_dich_tsbd ALTER COLUMN cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.giao_dich_tsbd.cif
ALTER TABLE sat_giao_dich_tsbd ALTER COLUMN cmnd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.giao_dich_tsbd.cmnd

ALTER TABLE sat_khach_hang_thong_tin_chung ALTER COLUMN khach_hang_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.khach_hang.khach_hang_no
ALTER TABLE sat_khach_hang_thong_tin_chung ALTER COLUMN ten_khach_hang SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=STRING; source=bpm.khach_hang.ten_khach_hang

ALTER TABLE sat_ld_aprv_information ALTER COLUMN t_aprv_chg_des SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ld_aprv_info.t_aprv_chg_des

ALTER TABLE sat_ld_extra_information ALTER COLUMN t_note SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ld_extra_info.t_note

ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_applicant SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_letter_of_credit.t_applicant
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_applicant_custno SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=t24.t24_letter_of_credit.t_applicant_custno
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_beneficiary SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_letter_of_credit.t_beneficiary
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_beneficiary_custno SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=t24.t24_letter_of_credit.t_beneficiary_custno
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_external_reference SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_letter_of_credit.t_external_reference
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_link_ld_ref SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_letter_of_credit.t_link_ld_ref
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN t_old_lc_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_letter_of_credit.t_old_lc_number

ALTER TABLE sat_letter_of_credit_value ALTER COLUMN t_credit_provis_acc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_letter_of_credit.t_credit_provis_acc
ALTER TABLE sat_letter_of_credit_value ALTER COLUMN t_provis_acc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_letter_of_credit.t_provis_acc

ALTER TABLE sat_limit_information ALTER COLUMN t_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_limit.t_account
ALTER TABLE sat_limit_information ALTER COLUMN t_liability_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=t24.t24_limit.t_liability_number
ALTER TABLE sat_limit_information ALTER COLUMN t_notes SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_limit.t_notes

ALTER TABLE sat_link_giao_dich_link ALTER COLUMN mo_ta SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.giao_dich_link.mo_ta

ALTER TABLE sat_loans_information ALTER COLUMN t_drawdown_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_drawdown_account
ALTER TABLE sat_loans_information ALTER COLUMN t_fee_pay_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_fee_pay_account
ALTER TABLE sat_loans_information ALTER COLUMN t_int_liq_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_int_liq_acct
ALTER TABLE sat_loans_information ALTER COLUMN t_linked_tfdr_ref SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_linked_tfdr_ref
ALTER TABLE sat_loans_information ALTER COLUMN t_ocb_ln_hold_cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_ocb_ln_hold_cif
ALTER TABLE sat_loans_information ALTER COLUMN t_prin_liq_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_prin_liq_acct

ALTER TABLE sat_loans_other ALTER COLUMN t_cust_remarks SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_cust_remarks
ALTER TABLE sat_loans_other ALTER COLUMN t_ins_auto_numpla SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_ins_auto_numpla
ALTER TABLE sat_loans_other ALTER COLUMN t_our_remarks SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_our_remarks

ALTER TABLE sat_loans_payment_due_information ALTER COLUMN t_repayment_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_payment_due.t_repayment_acct

ALTER TABLE sat_loans_terms ALTER COLUMN t_bpm_disb_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_loans_and_deposits.t_bpm_disb_id

ALTER TABLE sat_md_deal_classification ALTER COLUMN t_md_pp_detail SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_md_pp_detail
ALTER TABLE sat_md_deal_classification ALTER COLUMN t_md_purpose SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_md_purpose

ALTER TABLE sat_md_deal_information ALTER COLUMN t_benef_cust_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_md_deal.t_benef_cust_1
ALTER TABLE sat_md_deal_information ALTER COLUMN t_benef_cust_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_md_deal.t_benef_cust_2
ALTER TABLE sat_md_deal_information ALTER COLUMN t_charge_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_charge_account
ALTER TABLE sat_md_deal_information ALTER COLUMN t_ocb_charge_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_ocb_charge_acct
ALTER TABLE sat_md_deal_information ALTER COLUMN t_text_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_text_1
ALTER TABLE sat_md_deal_information ALTER COLUMN t_text_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_text_2

ALTER TABLE sat_md_deal_value ALTER COLUMN t_charge_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_charge_account
ALTER TABLE sat_md_deal_value ALTER COLUMN t_ocb_charge_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_ocb_charge_acct
ALTER TABLE sat_md_deal_value ALTER COLUMN t_ocb_sch_acc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_md_deal.t_ocb_sch_acc

ALTER TABLE sat_money_market_classification ALTER COLUMN t_drawdown_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_money_market.t_drawdown_account
ALTER TABLE sat_money_market_classification ALTER COLUMN t_int_liq_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_money_market.t_int_liq_acct
ALTER TABLE sat_money_market_classification ALTER COLUMN t_prin_liq_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_money_market.t_prin_liq_acct

ALTER TABLE sat_money_market_payment_information ALTER COLUMN t_ibps_bene SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_money_market.t_ibps_bene
ALTER TABLE sat_money_market_payment_information ALTER COLUMN t_our_remarks SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_money_market.t_our_remarks

ALTER TABLE sat_notification ALTER COLUMN message SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.user_notification.message
ALTER TABLE sat_notification ALTER COLUMN title SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.user_notification.title

ALTER TABLE sat_omni_user_information ALTER COLUMN cb_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.en_user.cb_user_id
ALTER TABLE sat_omni_user_information ALTER COLUMN external_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.en_user.external_id
ALTER TABLE sat_omni_user_information ALTER COLUMN external_id_up SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.en_user.external_id_up
ALTER TABLE sat_omni_user_information ALTER COLUMN full_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.en_user.full_name
ALTER TABLE sat_omni_user_information ALTER COLUMN full_name_up SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.en_user.full_name_up
ALTER TABLE sat_omni_user_information ALTER COLUMN legal_entity_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.en_user.legal_entity_id

ALTER TABLE sat_onboarding_information ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=omni.onboarding_report.email
ALTER TABLE sat_onboarding_information ALTER COLUMN full_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.onboarding_report.full_name
ALTER TABLE sat_onboarding_information ALTER COLUMN identity_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.onboarding_report.identity_number
ALTER TABLE sat_onboarding_information ALTER COLUMN phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.onboarding_report.phone_number

ALTER TABLE sat_oversea_ft_request_beneficiary ALTER COLUMN ben_account_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.oversea_ft_request.ben_account_no
ALTER TABLE sat_oversea_ft_request_beneficiary ALTER COLUMN ben_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.oversea_ft_request.ben_name

ALTER TABLE sat_oversea_ft_request_information ALTER COLUMN account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.oversea_ft_request.account_number

ALTER TABLE sat_oversea_ft_request_related_party ALTER COLUMN related_legal_id_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.oversea_ft_request.related_legal_id_no
ALTER TABLE sat_oversea_ft_request_related_party ALTER COLUMN related_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.oversea_ft_request.related_name

ALTER TABLE sat_party_account_information ALTER COLUMN account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.account_information.account_number
ALTER TABLE sat_party_account_information ALTER COLUMN iban SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.account_information.iban
ALTER TABLE sat_party_account_information ALTER COLUMN name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.account_information.name

ALTER TABLE sat_party_information ALTER COLUMN alias SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.party.alias
ALTER TABLE sat_party_information ALTER COLUMN contact_person SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.party.contact_person
ALTER TABLE sat_party_information ALTER COLUMN name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.party.name

ALTER TABLE sat_payment_history_information ALTER COLUMN description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_history.description
ALTER TABLE sat_payment_history_information ALTER COLUMN to_account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_history.to_account_number
ALTER TABLE sat_payment_history_information ALTER COLUMN to_card_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_history.to_card_number

ALTER TABLE sat_payment_information ALTER COLUMN card_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.oms_payment.card_number

ALTER TABLE sat_payment_order_information ALTER COLUMN account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_order.account
ALTER TABLE sat_payment_order_information ALTER COLUMN ext_arrangement_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.payment_order.ext_arrangement_id
ALTER TABLE sat_payment_order_information ALTER COLUMN name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.payment_order.name

ALTER TABLE sat_pdtd_nhom_giao_dich_ho_so ALTER COLUMN noi_dung_ycgt SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.pdtd_nhom_giao_dich.noi_dung_ycgt

ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN cmnd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.qlns_nguoi_lao_dong_info.cmnd
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN email_ca_nhan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=STRING; source=bpm.qlns_nguoi_lao_dong_info.email_ca_nhan
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN email_co_quan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=STRING; source=bpm.qlns_nguoi_lao_dong_info.email_co_quan
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN ho_ten SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=STRING; source=bpm.qlns_nguoi_lao_dong_info.ho_ten
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN ngay_sinh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.qlns_nguoi_lao_dong_info.ngay_sinh
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN so_dien_thoai SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=STRING; source=bpm.qlns_nguoi_lao_dong_info.so_dien_thoai

ALTER TABLE sat_re_consol_spec_entry_information ALTER COLUMN t_narrative SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_re_consol_spec_entry.t_narrative

ALTER TABLE sat_repo_deal ALTER COLUMN drawdown_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_repo.drawdown_account
ALTER TABLE sat_repo_deal ALTER COLUMN int_liq_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_repo.int_liq_acct
ALTER TABLE sat_repo_deal ALTER COLUMN new_cu_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_repo.new_cu_acct_no
ALTER TABLE sat_repo_deal ALTER COLUMN prin_liq_acct SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_repo.prin_liq_acct
ALTER TABLE sat_repo_deal ALTER COLUMN send_payment SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_repo.send_payment

ALTER TABLE sat_sec_trade_broker ALTER COLUMN t_br_acc_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_sec_trade.t_br_acc_no

ALTER TABLE sat_sec_trade_information ALTER COLUMN cust_acc_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_sec_trade.cust_acc_no
ALTER TABLE sat_sec_trade_information ALTER COLUMN cust_remarks SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_sec_trade.cust_remarks
ALTER TABLE sat_sec_trade_information ALTER COLUMN t_cust_acc_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_sec_trade.t_cust_acc_no

ALTER TABLE sat_security_information ALTER COLUMN t_mnemonic SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_security_master.t_mnemonic
ALTER TABLE sat_security_information ALTER COLUMN t_short_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_security_master.t_short_name

ALTER TABLE sat_service_audit ALTER COLUMN last_login_device_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.omni_service.last_login_device_id

ALTER TABLE sat_service_information ALTER COLUMN account_number_temp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.omni_service.account_number_temp
ALTER TABLE sat_service_information ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=omni.omni_service.email
ALTER TABLE sat_service_information ALTER COLUMN phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.omni_service.phone_number

ALTER TABLE sat_service_package ALTER COLUMN package_mounting_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.omni_service.package_mounting_account

ALTER TABLE sat_stmt_entry_information ALTER COLUMN t_account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_stmt_entry.t_account_number
ALTER TABLE sat_stmt_entry_information ALTER COLUMN t_master_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_stmt_entry.t_master_account
ALTER TABLE sat_stmt_entry_information ALTER COLUMN t_narrative SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_stmt_entry.t_narrative

ALTER TABLE sat_teller_information ALTER COLUMN t_account_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_account_1
ALTER TABLE sat_teller_information ALTER COLUMN t_account_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_account_2
ALTER TABLE sat_teller_information ALTER COLUMN t_narrative_1 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_narrative_1
ALTER TABLE sat_teller_information ALTER COLUMN t_narrative_2 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_narrative_2

ALTER TABLE sat_teller_other ALTER COLUMN t_sub_va_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_sub_va_id

ALTER TABLE sat_teller_vat ALTER COLUMN t_charge_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_charge_account
ALTER TABLE sat_teller_vat ALTER COLUMN t_contact_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_teller.t_contact_name
ALTER TABLE sat_teller_vat ALTER COLUMN t_cust_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_cust_id
ALTER TABLE sat_teller_vat ALTER COLUMN t_national_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_national_id
ALTER TABLE sat_teller_vat ALTER COLUMN t_tax_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_teller.t_tax_code

ALTER TABLE sat_transfer_bill_information ALTER COLUMN card_account_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.transfer_bill_history.card_account_num
ALTER TABLE sat_transfer_bill_information ALTER COLUMN card_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.transfer_bill_history.card_number
ALTER TABLE sat_transfer_bill_information ALTER COLUMN description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.transfer_bill_history.description
ALTER TABLE sat_transfer_bill_information ALTER COLUMN provider_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.transfer_bill_history.provider_code

ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_chung ALTER COLUMN giao_dich_goc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tsbd_giaodich_chinh.giao_dich_goc
ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_chung ALTER COLUMN sdt_nguoi_hd_khao_sat SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=STRING; source=bpm.tsbd_giaodich_chinh.sdt_nguoi_hd_khao_sat

ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_dinh_gia ALTER COLUMN ten_nguoi_hd_khao_sat SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=STRING; source=bpm.tsbd_giaodich_chinh.ten_nguoi_hd_khao_sat

ALTER TABLE sat_tsbd_tai_san_phuong_tien ALTER COLUMN ptvt_bienks SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.tsbd_tai_san.ptvt_bienks

ALTER TABLE sat_virtual_account ALTER COLUMN t_credit_acct_spa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_sub_virtual_account.t_credit_acct_spa
ALTER TABLE sat_virtual_account ALTER COLUMN t_sub_va_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_ocbh_sub_virtual_account.t_sub_va_name

ALTER TABLE sat_xl_ksgn_chung_quy_trinh_trang_thai ALTER COLUMN MA_GIAO_DICH SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.xl_ksgn_chung.ma_giao_dich
ALTER TABLE sat_xl_ksgn_chung_quy_trinh_trang_thai ALTER COLUMN working_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=STRING; source=bpm.xl_ksgn_chung.working_account

ALTER TABLE hub_appsflyer ALTER COLUMN business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.appsflyer_id

ALTER TABLE hub_events ALTER COLUMN identity SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=clevertap.events.profile:identity

ALTER TABLE sat_ac_restrict ALTER COLUMN t_ac_restrict SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_ac_restrict.t_ac_restrict
ALTER TABLE sat_ac_restrict ALTER COLUMN t_customer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_ac_restrict.t_customer
ALTER TABLE sat_ac_restrict ALTER COLUMN t_res_ac_title SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_ocbh_ac_restrict.t_res_ac_title

ALTER TABLE sat_acc_templ_gl ALTER COLUMN acc_number_counter SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acc_templ.acc_number_counter
ALTER TABLE sat_acc_templ_gl ALTER COLUMN account_numeration SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acc_templ.account_numeration

ALTER TABLE sat_acc_templ_information ALTER COLUMN account_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_acc_templ.account_name

ALTER TABLE sat_acc_templ_interest ALTER COLUMN int_fee_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acc_templ.int_fee_account

ALTER TABLE sat_acc_templ_limit ALTER COLUMN suppl_cr_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acc_templ.suppl_cr_account
ALTER TABLE sat_acc_templ_limit ALTER COLUMN suppl_dr_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_acc_templ.suppl_dr_account

ALTER TABLE sat_account_w4_information ALTER COLUMN account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.account_number
ALTER TABLE sat_account_w4_information ALTER COLUMN alter_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.alter_account
ALTER TABLE sat_account_w4_information ALTER COLUMN alter_due_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.alter_due_account
ALTER TABLE sat_account_w4_information ALTER COLUMN due_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.due_account
ALTER TABLE sat_account_w4_information ALTER COLUMN gl_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.gl_number
ALTER TABLE sat_account_w4_information ALTER COLUMN interest_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.interest_account
ALTER TABLE sat_account_w4_information ALTER COLUMN low_lim_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.low_lim_account
ALTER TABLE sat_account_w4_information ALTER COLUMN main_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.main_account
ALTER TABLE sat_account_w4_information ALTER COLUMN top_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.top_account
ALTER TABLE sat_account_w4_information ALTER COLUMN upp_lim_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_account.upp_lim_account

ALTER TABLE sat_accr_acct_cr_information ALTER COLUMN t_compens_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_accr_acct_cr.t_compens_account
ALTER TABLE sat_accr_acct_cr_information ALTER COLUMN t_liquidity_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_accr_acct_cr.t_liquidity_account

ALTER TABLE sat_apportion_acct_categ ALTER COLUMN t_account_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_apportion_acct_categ.t_account_name
ALTER TABLE sat_apportion_acct_categ ALTER COLUMN t_level3 SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_apportion_acct_categ.t_level3
ALTER TABLE sat_apportion_acct_categ ALTER COLUMN t_parent_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_apportion_acct_categ.t_parent_account

ALTER TABLE sat_callcenter_information ALTER COLUMN accountcode SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=callcenter.callcenter.accountcode
ALTER TABLE sat_callcenter_information ALTER COLUMN customer_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=callcenter.callcenter.customer_code
ALTER TABLE sat_callcenter_information ALTER COLUMN customer_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=callcenter.callcenter.customer_id
ALTER TABLE sat_callcenter_information ALTER COLUMN customercif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=callcenter.callcenter.customercif
ALTER TABLE sat_callcenter_information ALTER COLUMN customername SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=callcenter.callcenter.customername
ALTER TABLE sat_callcenter_information ALTER COLUMN dst SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=callcenter.callcenter.dst
ALTER TABLE sat_callcenter_information ALTER COLUMN sipserver SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=callcenter.callcenter.sipserver
ALTER TABLE sat_callcenter_information ALTER COLUMN src SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=callcenter.callcenter.src

ALTER TABLE sat_card_info_information ALTER COLUMN card_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=way4.ows_card_info.card_name
ALTER TABLE sat_card_info_information ALTER COLUMN card_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_card_info.card_number
ALTER TABLE sat_card_info_information ALTER COLUMN comment_text SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_card_info.comment_text
ALTER TABLE sat_card_info_information ALTER COLUMN offl_pin SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_card_info.offl_pin

ALTER TABLE sat_clevertap_tracking_detail ALTER COLUMN cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.clevertap_tracking.cif

ALTER TABLE sat_collateral_information ALTER COLUMN t_application_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_collateral.t_application_id

ALTER TABLE sat_credit_card_registration_other ALTER COLUMN birthday SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=omni.credit_card_registration.birthday
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN card_repayment_account_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.card_repayment_account_no
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN customer_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.credit_card_registration.customer_name
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=omni.credit_card_registration.email
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN legal_expired_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=omni.credit_card_registration.legal_expired_date
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN legal_id_num SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.legal_id_num
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN legal_id_num_other SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.legal_id_num_other
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN old_legal_id_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.old_legal_id_no
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.credit_card_registration.phone_number
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN relationship_type SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.credit_card_registration.relationship_type
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN reference_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.reference_id
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN spouse_legal_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.credit_card_registration.spouse_legal_id
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN spouse_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.credit_card_registration.spouse_name
ALTER TABLE sat_credit_card_registration_other ALTER COLUMN spouse_phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.credit_card_registration.spouse_phone_number

ALTER TABLE sat_crm_contact_hist_information ALTER COLUMN cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_hist.cif
ALTER TABLE sat_crm_contact_hist_information ALTER COLUMN condition_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=crm.crm_contact_hist.condition_date
ALTER TABLE sat_crm_contact_hist_information ALTER COLUMN notes SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_hist.notes

ALTER TABLE sat_crm_users_information ALTER COLUMN user_email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=crm.crm_users.user_email
ALTER TABLE sat_crm_users_information ALTER COLUMN user_first_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=crm.crm_users.user_first_name
ALTER TABLE sat_crm_users_information ALTER COLUMN user_full_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=crm.crm_users.user_full_name
ALTER TABLE sat_crm_users_information ALTER COLUMN user_last_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=crm.crm_users.user_last_name
ALTER TABLE sat_crm_users_information ALTER COLUMN user_phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=crm.crm_users.user_phone

ALTER TABLE sat_crm_users_other ALTER COLUMN old_user_full_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=crm.crm_users.old_user_full_name
ALTER TABLE sat_crm_users_other ALTER COLUMN old_user_phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=crm.crm_users.old_user_phone

ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_birth_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_birth_date
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_email
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_exp_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_exp_date
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_legal_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_legal_id
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_legal_type SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_legal_type
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_name
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_phone
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_visa_exp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_visa_exp
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acc_visa_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acc_visa_no
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_addr SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_addr
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_dob SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_dob
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_email
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_id
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_legal_exp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_legal_exp
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_phone SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_phone
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_visa_exp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_visa_exp
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_acrep_visa_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_acrep_visa_no
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_addr SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_addr
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_doc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_doc
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_exp_date SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_exp_date
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_id
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_name
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_visa_exp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_visa_exp
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ceo_visa_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ceo_visa_no
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_ocb_visa_type SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_ocb_visa_type
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_rep_lg_exp_dep SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_rep_lg_exp_dep
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_rep_visa_exp SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_rep_visa_exp
ALTER TABLE sat_cu_add_inf_corp_vn ALTER COLUMN t_rep_visa_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_cu_add_inf_corp_vn.t_rep_visa_no

ALTER TABLE sat_data_sharing_consent_other ALTER COLUMN additions SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.customer_data_sharing_consent.additions

ALTER TABLE sat_device_detail ALTER COLUMN unique_device_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.device_detail.unique_device_id

ALTER TABLE sat_device_omni_information ALTER COLUMN dbs_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.device.dbs_user_id

ALTER TABLE sat_diary_information ALTER COLUMN t_dep_account_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_diary.t_dep_account_no
ALTER TABLE sat_diary_information ALTER COLUMN t_option_desc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_diary.t_option_desc

ALTER TABLE sat_events_information ALTER COLUMN profile SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_clevertap_profile; -- target_type=string; source=clevertap.events.profile

ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN cmnd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.cmnd
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.email
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN ho_ten SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.ho_ten
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN ls_so_stk SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.ls_so_stk
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN ma_giao_dich SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.ma_giao_dich
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN sdt SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.sdt
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN so_cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.so_cif
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN so_stk SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tc_stk_thong_tin_tong_hop.so_stk

ALTER TABLE sat_giao_dich_tcstk_thong_tin_bao_dam ALTER COLUMN so_so_tk SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tcstk_thong_tin_bao_dam.so_so_tk
ALTER TABLE sat_giao_dich_tcstk_thong_tin_bao_dam ALTER COLUMN so_tai_khoan_so SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tcstk_thong_tin_bao_dam.so_tai_khoan_so

ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=bpm.tcstk_thong_tin_chung.email
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN ma_gd_omni SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tcstk_thong_tin_chung.ma_gd_omni
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN so_cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tcstk_thong_tin_chung.so_cif
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN so_tk_tc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tcstk_thong_tin_chung.so_tk_tc
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN sodt SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=bpm.tcstk_thong_tin_chung.sodt
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN ten_kh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.tcstk_thong_tin_chung.ten_kh

ALTER TABLE sat_giao_dich_tcstk_thong_tin_giao_dich ALTER COLUMN ma_gd_omni SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tcstk_thong_tin_giao_dich.ma_gd_omni
ALTER TABLE sat_giao_dich_tcstk_thong_tin_giao_dich ALTER COLUMN tt_tai_khoan_tc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.tcstk_thong_tin_giao_dich.tt_tai_khoan_tc

ALTER TABLE sat_giao_dich_tdcn_chi_tiet_san_pham ALTER COLUMN gd_tsbd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tdcn_chi_tiet_san_pham.gd_tsbd

ALTER TABLE sat_giao_dich_tdcn_nguoi_dong_vay ALTER COLUMN ngay_sinh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.tdcn_nguoi_dong_vay.ngay_sinh
ALTER TABLE sat_giao_dich_tdcn_nguoi_dong_vay ALTER COLUMN so_cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tdcn_nguoi_dong_vay.so_cif

ALTER TABLE sat_giao_dich_the ALTER COLUMN reason_message SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.giao_dich_the.reason_message
ALTER TABLE sat_giao_dich_the ALTER COLUMN so_the SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.giao_dich_the.so_the
ALTER TABLE sat_giao_dich_the ALTER COLUMN so_tk_the SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.giao_dich_the.so_tk_the
ALTER TABLE sat_giao_dich_the ALTER COLUMN ten_in_tren_the SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.giao_dich_the.ten_in_tren_the

ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN cif SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.ttd_giao_dich_igen.cif
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=bpm.ttd_giao_dich_igen.email
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN gtttcu SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.ttd_giao_dich_igen.gtttcu
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN gtttdoitac SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.ttd_giao_dich_igen.gtttdoitac
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN ngaysinh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.ttd_giao_dich_igen.ngaysinh
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN nghiepvuchitiet SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.ttd_giao_dich_igen.nghiepvuchitiet
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN sdtdoitac SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=bpm.ttd_giao_dich_igen.sdtdoitac
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN sodienthoai SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=bpm.ttd_giao_dich_igen.sodienthoai
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN sogiaytotuythan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.ttd_giao_dich_igen.sogiaytotuythan
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN sothe SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.ttd_giao_dich_igen.sothe
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN tenintrenthe SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.ttd_giao_dich_igen.tenintrenthe
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN tenkhachhang SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.ttd_giao_dich_igen.tenkhachhang
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN tenkhachhangdoitac SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.ttd_giao_dich_igen.tenkhachhangdoitac

ALTER TABLE sat_gl_trace_credit ALTER COLUMN cr_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_gl_trace.cr_account
ALTER TABLE sat_gl_trace_credit ALTER COLUMN cr_account_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_gl_trace.cr_account_number

ALTER TABLE sat_h_pdtd_gdich_ctiet_pduyet ALTER COLUMN ma_giao_dich SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.h_pdtd_gdich_ctiet_pduyet.ma_giao_dich

ALTER TABLE sat_h_pdtd_gdich_lsu_pduyet ALTER COLUMN chu_thich SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.h_pdtd_gdich_lsu_pduyet.chu_thich

ALTER TABLE sat_installs_report_device ALTER COLUMN advertising_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.advertising_id
ALTER TABLE sat_installs_report_device ALTER COLUMN android_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.android_id
ALTER TABLE sat_installs_report_device ALTER COLUMN city SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.city
ALTER TABLE sat_installs_report_device ALTER COLUMN country_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.country_code
ALTER TABLE sat_installs_report_device ALTER COLUMN customer_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.customer_user_id
ALTER TABLE sat_installs_report_device ALTER COLUMN dma SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.dma
ALTER TABLE sat_installs_report_device ALTER COLUMN http_referrer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.http_referrer
ALTER TABLE sat_installs_report_device ALTER COLUMN idfa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.idfa
ALTER TABLE sat_installs_report_device ALTER COLUMN idfv SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.idfv
ALTER TABLE sat_installs_report_device ALTER COLUMN imei SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.imei
ALTER TABLE sat_installs_report_device ALTER COLUMN ip SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.ip
ALTER TABLE sat_installs_report_device ALTER COLUMN original_url SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.original_url
ALTER TABLE sat_installs_report_device ALTER COLUMN postal_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.postal_code
ALTER TABLE sat_installs_report_device ALTER COLUMN region SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.region
ALTER TABLE sat_installs_report_device ALTER COLUMN state SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.state

ALTER TABLE sat_installs_report_event ALTER COLUMN ad_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.ad_id
ALTER TABLE sat_installs_report_event ALTER COLUMN attributed_touch_time SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.attributed_touch_time
ALTER TABLE sat_installs_report_event ALTER COLUMN keywords SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.installs_report.keywords

ALTER TABLE sat_invoice_log_detail ALTER COLUMN invoice_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_invoice_log.invoice_details
ALTER TABLE sat_invoice_log_detail ALTER COLUMN posting_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_invoice_log.posting_details

ALTER TABLE sat_invoice_log_information ALTER COLUMN invoice_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=way4.ows_invoice_log.invoice_code

ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN can_cuoc_cong_dan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_ca_nhan.can_cuoc_cong_dan
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN cmnd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_ca_nhan.cmnd
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=bpm.khach_hang_ca_nhan.email
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN ho_chieu SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_ca_nhan.ho_chieu
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN ngay_het_han_cmnd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.khach_hang_ca_nhan.ngay_het_han_cmnd
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN ngay_het_han_visa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.khach_hang_ca_nhan.ngay_het_han_visa
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN ngay_sinh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.khach_hang_ca_nhan.ngay_sinh
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN so_dien_thoai SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=bpm.khach_hang_ca_nhan.so_dien_thoai
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN the_can_cuoc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_ca_nhan.the_can_cuoc
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN visa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_ca_nhan.visa

ALTER TABLE sat_khach_hang_doanh_nghiep ALTER COLUMN chuc_vu_nguoi_dd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.khach_hang_doanh_nghiep.chuc_vu_nguoi_dd
ALTER TABLE sat_khach_hang_doanh_nghiep ALTER COLUMN ma_dang_ky_kinh_doanh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_doanh_nghiep.ma_dang_ky_kinh_doanh
ALTER TABLE sat_khach_hang_doanh_nghiep ALTER COLUMN ma_giay_phep_nganh_nghe SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.khach_hang_doanh_nghiep.ma_giay_phep_nganh_nghe
ALTER TABLE sat_khach_hang_doanh_nghiep ALTER COLUMN nguoi_dai_dien_phap_luat SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.khach_hang_doanh_nghiep.nguoi_dai_dien_phap_luat

ALTER TABLE sat_message_information ALTER COLUMN body SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.message.body
ALTER TABLE sat_message_information ALTER COLUMN sender SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.message.sender
ALTER TABLE sat_message_information ALTER COLUMN sender_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.message.sender_name
ALTER TABLE sat_message_information ALTER COLUMN subject SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.message.subject

ALTER TABLE sat_notification_information ALTER COLUMN additions SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.user_notification.additions
ALTER TABLE sat_notification_information ALTER COLUMN link SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.user_notification.link

ALTER TABLE sat_od_registration_information ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=omni.od_registration.email
ALTER TABLE sat_od_registration_information ALTER COLUMN full_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.od_registration.full_name
ALTER TABLE sat_od_registration_information ALTER COLUMN identity_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.od_registration.identity_number
ALTER TABLE sat_od_registration_information ALTER COLUMN phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.od_registration.phone_number
ALTER TABLE sat_od_registration_information ALTER COLUMN username SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.od_registration.username

ALTER TABLE sat_organic_installs_report_device ALTER COLUMN advertising_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.advertising_id
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN android_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.android_id
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN city SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.city
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN country_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.country_code
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN customer_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.customer_user_id
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN dma SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.dma
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN http_referrer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.http_referrer
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN idfa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.idfa
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN idfv SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.idfv
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN imei SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.imei
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN ip SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.ip
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN original_url SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.original_url
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN postal_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.postal_code
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN region SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.region
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN state SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.state

ALTER TABLE sat_organic_installs_report_event ALTER COLUMN ad_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.ad_id
ALTER TABLE sat_organic_installs_report_event ALTER COLUMN attributed_touch_time SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.attributed_touch_time
ALTER TABLE sat_organic_installs_report_event ALTER COLUMN keywords SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_installs_report.keywords

ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN advertising_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.advertising_id
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN android_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.android_id
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN city SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.city
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN country_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.country_code
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN customer_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.customer_user_id
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN dma SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.dma
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN http_referrer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.http_referrer
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN idfa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.idfa
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN idfv SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.idfv
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN imei SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.imei
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN ip SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.ip
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN original_url SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.original_url
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN postal_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.postal_code
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN region SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.region
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN state SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.state

ALTER TABLE sat_organic_uninstall_events_report_event ALTER COLUMN ad_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.ad_id
ALTER TABLE sat_organic_uninstall_events_report_event ALTER COLUMN attributed_touch_time SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.attributed_touch_time
ALTER TABLE sat_organic_uninstall_events_report_event ALTER COLUMN keywords SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.organic_uninstall_events_report.keywords

ALTER TABLE sat_party_account_other ALTER COLUMN email SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=omni.account_information.email
ALTER TABLE sat_party_account_other ALTER COLUMN phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.account_information.phone_number

ALTER TABLE sat_party_other ALTER COLUMN email_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=omni.party.email_id
ALTER TABLE sat_party_other ALTER COLUMN phone_number SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=omni.party.phone_number

ALTER TABLE sat_payment_history_other ALTER COLUMN counter_party_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.payment_history.counter_party_name

ALTER TABLE sat_qlns_nguoi_lao_dong_info_don_vi ALTER COLUMN ten_dang_nhap SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_email; -- target_type=string; source=bpm.qlns_nguoi_lao_dong_info.ten_dang_nhap

ALTER TABLE sat_reinstalls_device ALTER COLUMN advertising_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.advertising_id
ALTER TABLE sat_reinstalls_device ALTER COLUMN android_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.android_id
ALTER TABLE sat_reinstalls_device ALTER COLUMN city SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.city
ALTER TABLE sat_reinstalls_device ALTER COLUMN country_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.country_code
ALTER TABLE sat_reinstalls_device ALTER COLUMN customer_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.customer_user_id
ALTER TABLE sat_reinstalls_device ALTER COLUMN dma SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.dma
ALTER TABLE sat_reinstalls_device ALTER COLUMN http_referrer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.http_referrer
ALTER TABLE sat_reinstalls_device ALTER COLUMN idfa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.idfa
ALTER TABLE sat_reinstalls_device ALTER COLUMN idfv SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.idfv
ALTER TABLE sat_reinstalls_device ALTER COLUMN imei SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.imei
ALTER TABLE sat_reinstalls_device ALTER COLUMN ip SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.ip
ALTER TABLE sat_reinstalls_device ALTER COLUMN original_url SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.original_url
ALTER TABLE sat_reinstalls_device ALTER COLUMN postal_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.postal_code
ALTER TABLE sat_reinstalls_device ALTER COLUMN region SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.region
ALTER TABLE sat_reinstalls_device ALTER COLUMN state SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.state

ALTER TABLE sat_reinstalls_event ALTER COLUMN ad_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.ad_id
ALTER TABLE sat_reinstalls_event ALTER COLUMN attributed_touch_time SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.attributed_touch_time
ALTER TABLE sat_reinstalls_event ALTER COLUMN keywords SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls.keywords

ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN advertising_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.advertising_id
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN android_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.android_id
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN city SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.city
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN country_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.country_code
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN customer_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.customer_user_id
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN dma SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.dma
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN http_referrer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.http_referrer
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN idfa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.idfa
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN idfv SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.idfv
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN imei SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.imei
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN ip SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.ip
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN original_url SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.original_url
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN postal_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.postal_code
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN region SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.region
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN state SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.state

ALTER TABLE sat_reinstalls_organic_event ALTER COLUMN ad_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.ad_id
ALTER TABLE sat_reinstalls_organic_event ALTER COLUMN attributed_touch_time SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.attributed_touch_time
ALTER TABLE sat_reinstalls_organic_event ALTER COLUMN keywords SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.reinstalls_organic.keywords

ALTER TABLE sat_security_block ALTER COLUMN t_addition_info SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_sc_block_sec_pos.t_addition_info
ALTER TABLE sat_security_block ALTER COLUMN t_sub_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_sc_block_sec_pos.t_sub_account

ALTER TABLE sat_security_position ALTER COLUMN t_security_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_security_position.t_security_account

ALTER TABLE sat_standing_order ALTER COLUMN t_cpty_acct_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_standing_order.t_cpty_acct_no
ALTER TABLE sat_standing_order ALTER COLUMN t_payment_details SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_standing_order.t_payment_details

ALTER TABLE sat_stmt_acct_cr ALTER COLUMN t_compens_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_stmt_acct_cr.t_compens_account
ALTER TABLE sat_stmt_acct_cr ALTER COLUMN t_liquidity_account SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_stmt_acct_cr.t_liquidity_account

ALTER TABLE sat_transfer_bill_other ALTER COLUMN account_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.transfer_bill_history.account_name
ALTER TABLE sat_transfer_bill_other ALTER COLUMN customer_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=omni.transfer_bill_history.customer_name
ALTER TABLE sat_transfer_bill_other ALTER COLUMN reference_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=omni.transfer_bill_history.reference_id

ALTER TABLE sat_tsbd_chu_so_huu ALTER COLUMN cmnd SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=bpm.tsbd_chu_so_huu.cmnd
ALTER TABLE sat_tsbd_chu_so_huu ALTER COLUMN ho_ten SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=bpm.tsbd_chu_so_huu.ho_ten
ALTER TABLE sat_tsbd_chu_so_huu ALTER COLUMN ngay_sinh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=bpm.tsbd_chu_so_huu.ngay_sinh

ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN advertising_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.advertising_id
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN android_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.android_id
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN city SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.city
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN country_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.country_code
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN customer_user_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.customer_user_id
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN dma SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.dma
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN http_referrer SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.http_referrer
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN idfa SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.idfa
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN idfv SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.idfv
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN imei SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.imei
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN ip SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.ip
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN original_url SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.original_url
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN postal_code SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.postal_code
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN region SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.region
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN state SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.state

ALTER TABLE sat_uninstall_events_report_event ALTER COLUMN ad_id SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.ad_id
ALTER TABLE sat_uninstall_events_report_event ALTER COLUMN attributed_touch_time SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.attributed_touch_time
ALTER TABLE sat_uninstall_events_report_event ALTER COLUMN keywords SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=appsflyer.uninstall_events_report.keywords

ALTER TABLE ref_crm_contact_result ALTER COLUMN position SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_result.position

ALTER TABLE ref_crm_contact_status ALTER COLUMN ref_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=crm.crm_contact_status.contact_status_name
ALTER TABLE ref_crm_contact_status ALTER COLUMN kh_denhan_bh SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.kh_denhan_bh
ALTER TABLE ref_crm_contact_status ALTER COLUMN hd_tiengui_denhan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.hd_tiengui_denhan
ALTER TABLE ref_crm_contact_status ALTER COLUMN sn_khachhang SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_extract_year; -- target_type=string; source=crm.crm_contact_status.sn_khachhang
ALTER TABLE ref_crm_contact_status ALTER COLUMN kh_hienhuu SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.kh_hienhuu
ALTER TABLE ref_crm_contact_status ALTER COLUMN taikichhoat SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.taikichhoat
ALTER TABLE ref_crm_contact_status ALTER COLUMN kh_expiredcard SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.kh_expiredcard
ALTER TABLE ref_crm_contact_status ALTER COLUMN chbh_ganden SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.chbh_ganden
ALTER TABLE ref_crm_contact_status ALTER COLUMN kh_cosp_dexuat SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=crm.crm_contact_status.kh_cosp_dexuat

ALTER TABLE ref_t24_bc_sort_code ALTER COLUMN t_telephone_no SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_phone_number; -- target_type=string; source=t24.t24_bc_sort_code.t_telephone_no

ALTER TABLE ref_t24_collateral_code ALTER COLUMN t_short_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_collateral_code.t_short_name

ALTER TABLE ref_t24_de_bic ALTER COLUMN t_address SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_de_bic.t_address

ALTER TABLE ref_t24_limit_reference ALTER COLUMN t_short_name SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_limit_reference.t_short_name

ALTER TABLE ref_t24_sub_asset_type ALTER COLUMN t_short_descr SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_sub_asset_type.t_short_descr

ALTER TABLE ref_t24_teller_transaction ALTER COLUMN t_short_desc SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_teller_transaction.t_short_desc

ALTER TABLE ref_t24_acct_gen_condition ALTER COLUMN ref_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_acct_gen_condition.t_description

ALTER TABLE ref_t24_ft_txn_type_condition ALTER COLUMN ref_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ft_txn_type_condition.t_short_descr

ALTER TABLE ref_t24_lc_types ALTER COLUMN ref_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_lc_types.t_description

ALTER TABLE ref_t24_ocbh_ft_outward_purpose ALTER COLUMN ref_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=t24.t24_ocbh_ft_outward_purpose.t_desc

ALTER TABLE ref_t24_sec_acc_master ALTER COLUMN ref_description SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_name; -- target_type=string; source=t24.t24_sec_acc_master.t_account_name

USE SCHEMA business_vault;

ALTER TABLE bridge_account ALTER COLUMN account_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_account.business_key <= t24.t24_account_debit_int.id
ALTER TABLE bridge_account ALTER COLUMN crb_tieukhoan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_crb.tieukhoan <= t24.t24_crb.tieukhoan
ALTER TABLE bridge_account ALTER COLUMN customer_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=raw_vault.hub_customer.business_key <= t24.t24_customer.id
ALTER TABLE bridge_account ALTER COLUMN loans_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_loans.business_key <= t24.t24_ld_extra_info.id

ALTER TABLE bridge_card ALTER COLUMN customer_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=raw_vault.hub_customer.business_key <= t24.t24_customer.id

ALTER TABLE bridge_doc ALTER COLUMN customer_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=raw_vault.hub_customer.business_key <= t24.t24_customer.id

ALTER TABLE bridge_ft ALTER COLUMN account_credit_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_account.business_key <= t24.t24_account_debit_int.id
ALTER TABLE bridge_ft ALTER COLUMN account_debit_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_account.business_key <= t24.t24_account_debit_int.id
ALTER TABLE bridge_ft ALTER COLUMN customer_credit_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=raw_vault.hub_customer.business_key <= t24.t24_customer.id
ALTER TABLE bridge_ft ALTER COLUMN customer_debit_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=raw_vault.hub_customer.business_key <= t24.t24_customer.id

ALTER TABLE bridge_loan ALTER COLUMN acct_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_account.business_key <= t24.t24_account_debit_int.id
ALTER TABLE bridge_loan ALTER COLUMN crb_tieukhoan SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_crb.tieukhoan <= t24.t24_crb.tieukhoan
ALTER TABLE bridge_loan ALTER COLUMN customer_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=bigint; source=raw_vault.hub_customer.business_key <= t24.t24_customer.id
ALTER TABLE bridge_loan ALTER COLUMN loans_business_key SET MASK `ocb_datavault_${environment}_sourcing`.audit_log.mask_string; -- target_type=string; source=raw_vault.hub_loans.business_key <= t24.t24_ld_extra_info.id
