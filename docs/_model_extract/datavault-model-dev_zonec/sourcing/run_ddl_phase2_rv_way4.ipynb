# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE hub_acc_templ (
    acc_templ_hashkey string COMMENT 'Hashkey Hub Acc Templ',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_acc_templ ALTER COLUMN acc_templ_hashkey SET NOT NULL;
ALTER TABLE hub_acc_templ ADD CONSTRAINT hub_acc_templ_pk PRIMARY KEY (acc_templ_hashkey);

CREATE OR REPLACE TABLE hub_account_w4 (
    account_w4_hashkey string COMMENT 'Hashkey Hub Account W4',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_account_w4 ALTER COLUMN account_w4_hashkey SET NOT NULL;
ALTER TABLE hub_account_w4 ADD CONSTRAINT hub_account_w4_pk PRIMARY KEY (account_w4_hashkey);

CREATE OR REPLACE TABLE hub_card_info (
    card_info_hashkey string COMMENT 'Hashkey Hub Card Info',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_card_info ALTER COLUMN card_info_hashkey SET NOT NULL;
ALTER TABLE hub_card_info ADD CONSTRAINT hub_card_info_pk PRIMARY KEY (card_info_hashkey);

CREATE OR REPLACE TABLE hub_gl_trace (
    gl_trace_hashkey string COMMENT 'Hashkey Hub GL Trace',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_gl_trace ALTER COLUMN gl_trace_hashkey SET NOT NULL;
ALTER TABLE hub_gl_trace ADD CONSTRAINT hub_gl_trace_pk PRIMARY KEY (gl_trace_hashkey);

CREATE OR REPLACE TABLE hub_invoice_log (
    invoice_log_hashkey string COMMENT 'Hashkey Hub Invoice Log',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_invoice_log ALTER COLUMN invoice_log_hashkey SET NOT NULL;
ALTER TABLE hub_invoice_log ADD CONSTRAINT hub_invoice_log_pk PRIMARY KEY (invoice_log_hashkey);

CREATE OR REPLACE TABLE hub_item (
    item_hashkey string COMMENT 'Hashkey Hub Item',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_item ALTER COLUMN item_hashkey SET NOT NULL;
ALTER TABLE hub_item ADD CONSTRAINT hub_item_pk PRIMARY KEY (item_hashkey);

CREATE OR REPLACE TABLE hub_td_auth_sch (
    td_auth_sch_hashkey string COMMENT 'Hashkey Hub Td Auth Sch',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_td_auth_sch ALTER COLUMN td_auth_sch_hashkey SET NOT NULL;
ALTER TABLE hub_td_auth_sch ADD CONSTRAINT hub_td_auth_sch_pk PRIMARY KEY (td_auth_sch_hashkey);

CREATE OR REPLACE TABLE hub_usage_action (
    usage_action_hashkey string COMMENT 'Hashkey Hub Usage Action',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_usage_action ALTER COLUMN usage_action_hashkey SET NOT NULL;
ALTER TABLE hub_usage_action ADD CONSTRAINT hub_usage_action_pk PRIMARY KEY (usage_action_hashkey);

CREATE OR REPLACE TABLE sts_hub_account_w4 (
    account_w4_hashkey string COMMENT 'Hashkey Hub Account W4',
    source_event_date date COMMENT 'Ngày sự kiện nguồn',
    cdc_status string COMMENT 'Trạng thái CDC - Change Data Capture (D = Deleted, I = Insert/ Reinsert)
• D (Deleted): ID đã tồn tại trong Hub nhưng bị mất dấu (xóa vật lý) ở bảng nguồn trong ngày tương ứng source_event_date
• I (Inserted/Reinserted): ID từng bị xóa trong quá khứ, nay xuất hiện trở lại ở bảng nguồn trong ngày tương ứng source_event_date'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_w4 ALTER COLUMN account_w4_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_w4 ADD CONSTRAINT sts_hub_account_w4_pk PRIMARY KEY (account_w4_hashkey);

CREATE OR REPLACE TABLE sts_hub_acnt_contract (
    acnt_contract_hashkey string COMMENT 'Hashkey Hub Acnt Contract',
    source_event_date date COMMENT 'Ngày sự kiện nguồn',
    cdc_status string COMMENT 'Trạng thái CDC - Change Data Capture (D = Deleted, I = Insert/ Reinsert)
• D (Deleted): ID đã tồn tại trong Hub nhưng bị mất dấu (xóa vật lý) ở bảng nguồn trong ngày tương ứng source_event_date
• I (Inserted/Reinserted): ID từng bị xóa trong quá khứ, nay xuất hiện trở lại ở bảng nguồn trong ngày tương ứng source_event_date'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_acnt_contract ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sts_hub_acnt_contract ADD CONSTRAINT sts_hub_acnt_contract_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_acc_templ_gl (
    acc_templ_hashkey string COMMENT 'Hashkey Hub Acc Templ',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acc_number_counter string COMMENT 'Bộ đếm số tài khoản',
    account_numeration string COMMENT 'Kiểu đánh số tài khoản',
    gl_credit decimal(38,10) COMMENT 'Mã GL phía có (credit)',
    gl_debit decimal(38,10) COMMENT 'Mã GL phía nợ (debit)',
    gl_number string COMMENT 'Số tài khoản GL',
    gl_tariff string COMMENT 'Biểu phí GL áp dụng',
    gl_turnover decimal(38,10) COMMENT 'Mã GL luân chuyển',
    gl_type string COMMENT 'Loại hạch toán GL',
    hd_gl_number string COMMENT 'Số tài khoản GL hiện hành',
    use_gl string COMMENT 'Cờ sử dụng hạch toán GL'
) CLUSTER BY AUTO;
ALTER TABLE sat_acc_templ_gl ALTER COLUMN acc_templ_hashkey SET NOT NULL;
ALTER TABLE sat_acc_templ_gl ADD CONSTRAINT sat_acc_templ_gl_pk PRIMARY KEY (acc_templ_hashkey);

CREATE OR REPLACE TABLE sat_acc_templ_information (
    acc_templ_hashkey string COMMENT 'Hashkey Hub Acc Templ',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acat string COMMENT 'Danh mục tài khoản',
    acc_scheme__oid bigint COMMENT 'FK tham chiếu bảng acc_scheme',
    account_name string COMMENT 'Tên mẫu tài khoản',
    account_type__id bigint COMMENT 'FK tham chiếu bảng account_type',
    ageing_tariff string COMMENT 'Biểu phí phân loại nợ quá hạn',
    balance_type bigint COMMENT 'Loại số dư tài khoản',
    charge_for_open bigint COMMENT 'Phí mở tài khoản',
    code string COMMENT 'Mã mẫu tài khoản',
    curr string COMMENT 'Mã loại tiền tệ',
    due_period bigint COMMENT 'Số ngày kỳ hạn đến hạn',
    due_to_work_day string COMMENT 'Cờ điều chỉnh đến ngày làm việc',
    due_type string COMMENT 'Loại nợ đến hạn',
    f_i bigint COMMENT 'Mã tổ chức tài chính',
    from_acc_scheme bigint COMMENT 'Tham chiếu acc_scheme nguồn',
    fx_type string COMMENT 'Loại tỷ giá ngoại tệ',
    grace_period bigint COMMENT 'Số ngày ân hạn thanh toán',
    group_code string COMMENT 'Mã nhóm mẫu tài khoản',
    is_am_available string COMMENT 'Cờ khả dụng quản lý tài sản',
    min_repayment bigint COMMENT 'Số tiền hoàn trả tối thiểu',
    min_rq_repayment bigint COMMENT 'Số tiền hoàn trả tối thiểu yêu cầu',
    pcat string COMMENT 'Loại sản phẩm liên quan đến mẫu tài khoản',
    reference_only string COMMENT 'Cờ chỉ dùng để tham chiếu',
    repayment_percent bigint COMMENT 'Tỷ lệ phần trăm hoàn trả tối thiểu'
) CLUSTER BY AUTO;
ALTER TABLE sat_acc_templ_information ALTER COLUMN acc_templ_hashkey SET NOT NULL;
ALTER TABLE sat_acc_templ_information ADD CONSTRAINT sat_acc_templ_information_pk PRIMARY KEY (acc_templ_hashkey);

CREATE OR REPLACE TABLE sat_acc_templ_interest (
    acc_templ_hashkey string COMMENT 'Hashkey Hub Acc Templ',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    calc_when_credit string COMMENT 'Cờ tính lãi khi phía có (credit)',
    fee_rate_regime string COMMENT 'Chế độ tỷ lệ phí',
    int_accrual_acc bigint COMMENT 'Tài khoản tích lũy lãi suất',
    int_fee_account string COMMENT 'Tài khoản phí lãi suất',
    int_rev_exp_acc bigint COMMENT 'Tài khoản doanh thu/chi phí lãi',
    interest_acc_templ decimal(38,10) COMMENT 'FK mẫu tài khoản hạch toán lãi',
    interest_algorithm string COMMENT 'Thuật toán tính lãi suất',
    interest_contract decimal(38,10) COMMENT 'FK hợp đồng lãi suất',
    interest_delay string COMMENT 'Cờ hoãn tính lãi suất',
    interest_fee decimal(38,10) COMMENT 'Phí lãi suất',
    interest_fee_type bigint COMMENT 'Loại phí lãi suất',
    interest_rate decimal(38,10) COMMENT 'Lãi suất cơ bản',
    interest_scheme decimal(38,10) COMMENT 'Sơ đồ tính lãi suất',
    interest_tariff string COMMENT 'Biểu phí lãi suất áp dụng',
    last_int_accrual string COMMENT 'Ngày tích lũy lãi gần nhất'
) CLUSTER BY AUTO;
ALTER TABLE sat_acc_templ_interest ALTER COLUMN acc_templ_hashkey SET NOT NULL;
ALTER TABLE sat_acc_templ_interest ADD CONSTRAINT sat_acc_templ_interest_pk PRIMARY KEY (acc_templ_hashkey);

CREATE OR REPLACE TABLE sat_acc_templ_limit (
    acc_templ_hashkey string COMMENT 'Hashkey Hub Acc Templ',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ageing_priority bigint COMMENT 'Ưu tiên phân loại nợ quá hạn',
    alter_due_templ bigint COMMENT 'FK mẫu tài khoản đến hạn thay thế',
    due_acc_templ bigint COMMENT 'FK mẫu tài khoản đến hạn',
    event_type bigint COMMENT 'FK loại sự kiện liên kết',
    is_ready string COMMENT 'Cờ mẫu tài khoản sẵn sàng sử dụng',
    low_lim_acc_templ bigint COMMENT 'Hạn mức mẫu tài khoản tối thiểu',
    low_lim_amount decimal(38,10) COMMENT 'Hạn mức số tiền tối thiểu',
    offbalance_xf_acc decimal(38,10) COMMENT 'Tài khoản ngoại bảng chuyển đổi',
    priority bigint COMMENT 'Ưu tiên của mẫu tài khoản',
    suppl_cr_account string COMMENT 'Tài khoản bổ sung phía có',
    suppl_dr_account string COMMENT 'Tài khoản bổ sung phía nợ',
    template_details string COMMENT 'Chi tiết mẫu tài khoản',
    upp_lim_acc_templ bigint COMMENT 'Hạn mức mẫu tài khoản tối đa',
    upp_lim_amount decimal(38,10) COMMENT 'Hạn mức số tiền tối đa'
) CLUSTER BY AUTO;
ALTER TABLE sat_acc_templ_limit ALTER COLUMN acc_templ_hashkey SET NOT NULL;
ALTER TABLE sat_acc_templ_limit ADD CONSTRAINT sat_acc_templ_limit_pk PRIMARY KEY (acc_templ_hashkey);

CREATE OR REPLACE TABLE sat_account_w4_balance (
    account_w4_hashkey string COMMENT 'Hashkey Hub Account W4',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    begin_balance decimal(38,0) COMMENT 'Số dư đầu kỳ',
    current_balance decimal(38,0) COMMENT 'Số dư hiện tại của tài khoản',
    cycle_date_from string COMMENT 'Ngày bắt đầu chu kỳ tài khoản',
    cycle_date_to string COMMENT 'Ngày kết thúc chu kỳ tài khoản',
    low_lim_amount decimal(38,0) COMMENT 'Hạn mức số tiền tối thiểu',
    n_of_cycle bigint COMMENT 'Số chu kỳ của tài khoản',
    on_date string COMMENT 'Ngày tra cứu số dư cụ thể',
    on_date_balance decimal(38,0) COMMENT 'Số dư tại ngày cụ thể',
    upp_lim_amount decimal(38,0) COMMENT 'Hạn mức số tiền tối đa'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_w4_balance ALTER COLUMN account_w4_hashkey SET NOT NULL;
ALTER TABLE sat_account_w4_balance ADD CONSTRAINT sat_account_w4_balance_pk PRIMARY KEY (account_w4_hashkey);

CREATE OR REPLACE TABLE sat_account_w4_information (
    account_w4_hashkey string COMMENT 'Hashkey Hub Account W4',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acat string COMMENT 'Danh mục tài khoản',
    acc_templ__id bigint COMMENT 'FK tham chiếu mẫu tài khoản (acc_templ)',
    account_name string COMMENT 'Tên loại tài khoản',
    account_number string COMMENT 'Số tài khoản GL',
    account_type bigint COMMENT 'FK tham chiếu bảng account_type',
    acnt_contract__oid bigint COMMENT 'Tham chiếu bảng acnt_contract',
    ageing_priority bigint COMMENT 'Ưu tiên phân loại nợ quá hạn',
    alter_account string COMMENT 'Tài khoản thay thế chính',
    alter_due_account string COMMENT 'Tài khoản thay thế cho tài khoản đến hạn',
    apply_dt string COMMENT 'Ngày áp dụng bản ghi vào hệ thống',
    charge_for_open bigint COMMENT 'Phí mở tài khoản',
    code string COMMENT 'Mã loại tài khoản',
    curr string COMMENT 'Mã loại tiền tệ tài khoản',
    due_account string COMMENT 'Tài khoản đến hạn liên kết',
    due_type string COMMENT 'Loại nợ đến hạn của tài khoản',
    gl_number string COMMENT 'Số tài khoản GL hạch toán',
    interest_account string COMMENT 'Tài khoản hạch toán lãi suất',
    interest_fee_rate decimal(38,0) COMMENT 'Lãi suất phí của tài khoản',
    interest_rate decimal(38,0) COMMENT 'Lãi suất cơ bản của tài khoản',
    is_am_available string COMMENT 'Cờ trạng thái khả dụng tài khoản',
    local_version bigint COMMENT 'Số phiên bản nội bộ của bản ghi',
    low_lim_account string COMMENT 'Tài khoản hạn mức tối thiểu',
    main_account string COMMENT 'Mã tài khoản chính liên kết',
    own_blocked bigint COMMENT 'Số tiền bị phong tỏa chính tài khoản',
    payment_priority bigint COMMENT 'Ưu tiên thanh toán của tài khoản',
    remote_version bigint COMMENT 'Số phiên bản đồng bộ từ hệ thống bên ngoài',
    routing_idt string COMMENT 'Mã định tuyến tài khoản',
    top_account string COMMENT 'Tài khoản cấp cao nhất trong cấu trúc',
    total_blocked bigint COMMENT 'Tổng số tiền đã bị phong tỏa',
    upp_lim_account string COMMENT 'Tài khoản hạn mức tối đa'
) CLUSTER BY AUTO;
ALTER TABLE sat_account_w4_information ALTER COLUMN account_w4_hashkey SET NOT NULL;
ALTER TABLE sat_account_w4_information ADD CONSTRAINT sat_account_w4_information_pk PRIMARY KEY (account_w4_hashkey);

CREATE OR REPLACE TABLE sat_acnt_contract_scan (
    acnt_contract_hashkey string COMMENT 'Hashkey Hub Acnt Contract',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    last_scan string COMMENT 'Ngày quét hợp đồng gần nhất'
) CLUSTER BY AUTO;
ALTER TABLE sat_acnt_contract_scan ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sat_acnt_contract_scan ADD CONSTRAINT sat_acnt_contract_scan_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_card_info_information (
    card_info_hashkey string COMMENT 'Hashkey Hub Card Info',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract__oid bigint COMMENT 'Tham chiếu bảng acnt_contract',
    add_track_data string COMMENT 'Dữ liệu track bổ sung (PII)',
    apply_dt string COMMENT 'Ngày áp dụng bản ghi vào hệ thống',
    atc string COMMENT 'Application Transaction Counter (không sử dụng)',
    card_expire string COMMENT 'Ngày hết hạn thẻ (PII)',
    card_name string COMMENT 'Tên in nổi trên thẻ (PII)',
    card_number string COMMENT 'Số thẻ (PII)',
    card_subtype bigint COMMENT 'Phân loại phụ của thẻ',
    card_track_1 string COMMENT 'Dữ liệu track 1 của thẻ',
    comment_text string COMMENT 'Nội dung ghi chú (PII)',
    company_name string COMMENT 'Tên công ty in trên thẻ (PII)',
    cvc string COMMENT 'Card Verification Code (PII)',
    cvc2 string COMMENT 'Card Verification Code 2 (PII)',
    event string COMMENT 'Sự kiện xử lý thẻ',
    ext_data string COMMENT 'Dữ liệu mở rộng (không sử dụng)',
    file_info__id bigint COMMENT 'FK tham chiếu file_info (không sử dụng)',
    icvv string COMMENT 'Integrated Circuit CVC (PII)',
    limit_curr string COMMENT 'Loại tiền tệ hạn mức thẻ',
    local_version bigint COMMENT 'Số phiên bản nội bộ của bản ghi',
    offl_pin string COMMENT 'PIN xác thực offline (PII)',
    offset_data string COMMENT 'Dữ liệu offset thẻ',
    parent_card bigint COMMENT 'Tham chiếu bảng card_info (liên kết tới parent card)',
    pin string COMMENT 'Mã PIN thẻ (PII)',
    pin_format string COMMENT 'Dịnh dạng mã PIN',
    pm_code string COMMENT 'Mã quản lý PIN',
    pm_parms bigint COMMENT 'Tham số quản lý PIN (không sử dụng)',
    prev_card bigint COMMENT 'Tham chiếu bảng card_info (liên kết tới previous card)',
    pvv string COMMENT 'PIN Verification Value (PII)',
    remote_version bigint COMMENT 'Số phiên bản đồng bộ từ hệ thống bên ngoài',
    routing_idt string COMMENT 'Mã định tuyến thẻ (không sử dụng)',
    seqv_number string COMMENT 'Số thứ tự thẻ (PII)',
    service_code string COMMENT 'Mã dịch vụ của thẻ',
    status string COMMENT 'Trạng thái hiện tại của thẻ',
    subtype_code string COMMENT 'Mã loại phụ thẻ',
    trans_status string COMMENT 'Trạng thái giao dịch của thẻ'
) CLUSTER BY AUTO;
ALTER TABLE sat_card_info_information ALTER COLUMN card_info_hashkey SET NOT NULL;
ALTER TABLE sat_card_info_information ADD CONSTRAINT sat_card_info_information_pk PRIMARY KEY (card_info_hashkey);

CREATE OR REPLACE TABLE sat_card_info_production (
    card_info_hashkey string COMMENT 'Hashkey Hub Card Info',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    chip_scheme bigint COMMENT 'Scheme chip của thẻ',
    date_from string COMMENT 'Ngày bắt đầu hiệu lực thẻ',
    order_from string COMMENT 'Nơi xuất phát đơn đặt hàng thẻ',
    order_n string COMMENT 'Mã số đơn đặt hàng thẻ',
    order_to string COMMENT 'Nơi nhận đơn đặt hàng thẻ',
    prod_date string COMMENT 'Ngày sản xuất thẻ',
    production_code bigint COMMENT 'Mã sản xuất thẻ',
    production_event string COMMENT 'Sự kiện sản xuất thẻ',
    production_type string COMMENT 'Loại sản xuất thẻ'
) CLUSTER BY AUTO;
ALTER TABLE sat_card_info_production ALTER COLUMN card_info_hashkey SET NOT NULL;
ALTER TABLE sat_card_info_production ADD CONSTRAINT sat_card_info_production_pk PRIMARY KEY (card_info_hashkey);

CREATE OR REPLACE TABLE sat_gl_trace_credit (
    gl_trace_hashkey string COMMENT 'Hashkey Hub GL Trace',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    cr_account string COMMENT 'Mã tài khoản bên có',
    cr_account_number string COMMENT 'Số tài khoản GL bên có',
    cr_main_account bigint COMMENT 'FK tham chiếu bảng account (bên có)',
    cr_service bigint COMMENT 'Mã dịch vụ bên có',
    cr_tariff bigint COMMENT 'Mã biểu phí bên có'
) CLUSTER BY AUTO;
ALTER TABLE sat_gl_trace_credit ALTER COLUMN gl_trace_hashkey SET NOT NULL;
ALTER TABLE sat_gl_trace_credit ADD CONSTRAINT sat_gl_trace_credit_pk PRIMARY KEY (gl_trace_hashkey);

CREATE OR REPLACE TABLE sat_gl_trace_debit (
    gl_trace_hashkey string COMMENT 'Hashkey Hub GL Trace',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    dr_account bigint COMMENT 'Mã tài khoản bên nợ',
    dr_account_number string COMMENT 'Số tài khoản GL bên nợ',
    dr_main_account bigint COMMENT 'FK tham chiếu bảng account (bên nợ)',
    dr_service bigint COMMENT 'Mã dịch vụ bên nợ',
    dr_tariff bigint COMMENT 'Mã biểu phí bên nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_gl_trace_debit ALTER COLUMN gl_trace_hashkey SET NOT NULL;
ALTER TABLE sat_gl_trace_debit ADD CONSTRAINT sat_gl_trace_debit_pk PRIMARY KEY (gl_trace_hashkey);

CREATE OR REPLACE TABLE sat_gl_trace_information (
    gl_trace_hashkey string COMMENT 'Hashkey Hub GL Trace',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    amount decimal(38,10) COMMENT 'Số tiền giao dịch',
    cr_main_entry bigint COMMENT 'Tham chiếu credit entry',
    curr string COMMENT 'Mã loại tiền tệ của giao dịch',
    db_date string COMMENT 'Ngày ghi vào cơ sở dữ liệu',
    description string COMMENT 'Diễn giải giao dịch',
    dr_main_entry bigint COMMENT 'Tham chiếu debit entry',
    entry_role string COMMENT 'Vai trò bút toán (B: base, F: fee, A: add. fee, M: main)',
    gl_doc_id bigint COMMENT 'ID tài liệu GL liên kết',
    gl_transfer__id bigint COMMENT 'FK tham chiếu bảng gl_transfer',
    m_transaction__id bigint COMMENT 'FK tham chiếu bảng m_transaction',
    order_date string COMMENT 'Ngày lệnh giao dịch',
    partition_key string COMMENT 'Khóa phân vùng dữ liệu',
    trans_role string COMMENT 'Vai trò giao dịch trong bút toán'
) CLUSTER BY AUTO;
ALTER TABLE sat_gl_trace_information ALTER COLUMN gl_trace_hashkey SET NOT NULL;
ALTER TABLE sat_gl_trace_information ADD CONSTRAINT sat_gl_trace_information_pk PRIMARY KEY (gl_trace_hashkey);

CREATE OR REPLACE TABLE sat_invoice_log_detail (
    invoice_log_hashkey string COMMENT 'Hashkey Hub Invoice Log',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    action_code string COMMENT 'Mã hành động kích hoạt hóa đơn',
    amount_type string COMMENT 'Loại số tiền của hóa đơn',
    balance_code string COMMENT 'Mã loại số dư liên quan',
    begin_date string COMMENT 'Ngày bắt đầu hiệu lực hóa đơn',
    creation_date string COMMENT 'Ngày tạo hóa đơn',
    creation_type string COMMENT 'Kiểu tạo hóa đơn',
    debt_type string COMMENT 'Loại nợ của hóa đơn',
    end_date string COMMENT 'Ngày kết thúc hiệu lực hóa đơn',
    invoice_details string COMMENT 'Nội dung chi tiết hóa đơn',
    invoice_event bigint COMMENT 'Sự kiện kích hoạt hóa đơn',
    last_updated string COMMENT 'Ngày cập nhật cuối cùng',
    partition_key string COMMENT 'Khóa phân vùng dữ liệu',
    posting_details string COMMENT 'Chi tiết hạch toán hóa đơn',
    sort_code string COMMENT 'Mã sắp xếp hóa đơn'
) CLUSTER BY AUTO;
ALTER TABLE sat_invoice_log_detail ALTER COLUMN invoice_log_hashkey SET NOT NULL;
ALTER TABLE sat_invoice_log_detail ADD CONSTRAINT sat_invoice_log_detail_pk PRIMARY KEY (invoice_log_hashkey);

CREATE OR REPLACE TABLE sat_invoice_log_information (
    invoice_log_hashkey string COMMENT 'Hashkey Hub Invoice Log',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract__oid bigint COMMENT 'Tham chiếu bảng acnt_contract',
    contract_for bigint COMMENT 'Hợp đồng liên kết với hóa đơn',
    curr string COMMENT 'Mã loại tiền tệ của hóa đơn',
    doc_id bigint COMMENT 'Tham chiếu bảng doc',
    due_date string COMMENT 'Ngày đến hạn thanh toán hóa đơn',
    eff_date string COMMENT 'Ngày hiệu lực của hóa đơn',
    inst_chain_idt bigint COMMENT 'Mã chuỗi kế hoạch trả góp',
    inst_fee__id bigint COMMENT 'FK tham chiếu bảng phí trả góp',
    instalment_plan bigint COMMENT 'Mã kế hoạch trả góp',
    instalment_scheme bigint COMMENT 'FK tham chiếu bảng lược đồ trả góp',
    invoice_amount decimal(38,10) COMMENT 'Số tiền hóa đơn',
    invoice_code string COMMENT 'Mã hóa đơn',
    invoice_group string COMMENT 'Nhóm hóa đơn',
    invoice_log__oid bigint COMMENT 'FK tham chiếu bảng invoice_log',
    invoice_ref_number string COMMENT 'Số tham chiếu hóa đơn',
    invoice_status string COMMENT 'Trạng thái hóa đơn (WAITING/PAID/OPEN/CLOSED)',
    invoice_status_pre string COMMENT 'Trạng thái hóa đơn trước khi thay đổi',
    paid_amount decimal(38,10) COMMENT 'Số tiền đã thanh toán',
    rep_date string COMMENT 'Ngày báo cáo hóa đơn',
    written_off_amount decimal(38,10) COMMENT 'Số tiền đã xóa nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_invoice_log_information ALTER COLUMN invoice_log_hashkey SET NOT NULL;
ALTER TABLE sat_invoice_log_information ADD CONSTRAINT sat_invoice_log_information_pk PRIMARY KEY (invoice_log_hashkey);

CREATE OR REPLACE TABLE sat_item_balance_rate (
    item_hashkey string COMMENT 'Hashkey Hub Item',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    begin_balance decimal(38,10) COMMENT 'Số dư đầu chu kỳ của item',
    cycle_balance decimal(38,10) COMMENT 'Số dư trong chu kỳ của item',
    fee_total decimal(38,10) COMMENT 'Tổng phí của item',
    interest_factor decimal(38,10) COMMENT 'Hệ số tính lãi của item',
    interest_fee_rate decimal(38,10) COMMENT 'Lãi suất phí của item',
    interest_rate decimal(38,10) COMMENT 'Lãi suất cơ bản của item',
    item_total decimal(38,10) COMMENT 'Tổng giá trị của item',
    number_of_docs bigint COMMENT 'Số lượng chứng từ liên quan đến item',
    partition_key string COMMENT 'Khóa phân vùng dữ liệu'
) CLUSTER BY AUTO;
ALTER TABLE sat_item_balance_rate ALTER COLUMN item_hashkey SET NOT NULL;
ALTER TABLE sat_item_balance_rate ADD CONSTRAINT sat_item_balance_rate_pk PRIMARY KEY (item_hashkey);

CREATE OR REPLACE TABLE sat_item_information (
    item_hashkey string COMMENT 'Hashkey Hub Item',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acc_cycle_code string COMMENT 'Mã chu kỳ của tài khoản',
    account__oid bigint COMMENT 'Tham chiếu bảng account (way4)',
    account_number string COMMENT 'Số tài khoản GL của item',
    currency string COMMENT 'Mã loại tiền tệ của item',
    cycle_date_to string COMMENT 'Ngày kết thúc chu kỳ của item',
    cycle_event string COMMENT 'Sự kiện kích hoạt chu kỳ',
    cycle_id bigint COMMENT 'ID định danh chu kỳ của item',
    cycle_template bigint COMMENT 'Mẫu chu kỳ áp dụng cho item',
    date_from string COMMENT 'Ngày bắt đầu hiệu lực của item',
    date_to string COMMENT 'Ngày kết thúc hiệu lực của item',
    due_date string COMMENT 'Ngày đến hạn thanh toán',
    due_status string COMMENT 'Trạng thái đến hạn của item',
    gl_number string COMMENT 'Số tài khoản GL hạch toán',
    interest_tariff decimal(38,10) COMMENT 'Biểu phí lãi suất áp dụng cho item',
    n_of_cycle bigint COMMENT 'Số chu kỳ của item',
    service_class string COMMENT 'Mã phân loại dịch vụ của item',
    templ_approved_id bigint COMMENT 'Tham chiếu bảng templ_approved'
) CLUSTER BY AUTO;
ALTER TABLE sat_item_information ALTER COLUMN item_hashkey SET NOT NULL;
ALTER TABLE sat_item_information ADD CONSTRAINT sat_item_information_pk PRIMARY KEY (item_hashkey);

CREATE OR REPLACE TABLE sat_td_auth_sch_information (
    td_auth_sch_hashkey string COMMENT 'Hashkey Hub Td Auth Sch',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract__id bigint COMMENT 'Tham chiếu bảng acnt_contract',
    apply_dt string COMMENT 'Ngày thực tế áp dụng cấu hình vào hệ thống',
    auth_idt string COMMENT 'Mã định danh xác thực chính',
    auth_idt_extension string COMMENT 'Phần mở rộng của định danh xác thực',
    auth_type bigint COMMENT 'Mã loại phương thức xác thực',
    auth_type_cat string COMMENT 'Phân loại nhóm của loại xác thực',
    auth_type_version_idt string COMMENT 'Định danh phiên bản của loại xác thực',
    client__id bigint COMMENT 'Tham chiếu bảng client',
    date_from string COMMENT 'Ngày bắt đầu có hiệu lực của cấu hình',
    date_to string COMMENT 'Ngày kết thúc hiệu lực của cấu hình',
    is_ready string COMMENT 'Cờ xác nhận sẵn sàng sử dụng',
    local_version bigint COMMENT 'Số phiên bản được ghi nhận tại hệ thống nội bộ',
    name string COMMENT 'Tên gọi hiển thị của phương thức xác thực',
    parm_data string COMMENT 'Dữ liệu tham số cấu hình chi tiết',
    remote_version bigint COMMENT 'Số phiên bản đồng bộ từ hệ thống bên ngoài',
    scheme_rc bigint COMMENT 'Mã sơ đồ hoặc mã phản hồi liên quan',
    td_cons__id bigint COMMENT 'Mã định danh hợp nhất của bản ghi'
) CLUSTER BY AUTO;
ALTER TABLE sat_td_auth_sch_information ALTER COLUMN td_auth_sch_hashkey SET NOT NULL;
ALTER TABLE sat_td_auth_sch_information ADD CONSTRAINT sat_td_auth_sch_information_pk PRIMARY KEY (td_auth_sch_hashkey);

CREATE OR REPLACE TABLE sat_usage_action_date (
    usage_action_hashkey string COMMENT 'Hashkey Hub Usage Action',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    end_date string COMMENT 'Ngày kết thúc hiệu lực chuẩn',
    end_local_date string COMMENT 'Ngày kết thúc hiệu lực địa phương',
    record_date string COMMENT 'Ngày bản ghi lưu vào hệ thống',
    start_date string COMMENT 'Ngày bắt đầu hiệu lực chuẩn',
    start_local_date string COMMENT 'Ngày bắt đầu hiệu lực địa phương'
) CLUSTER BY AUTO;
ALTER TABLE sat_usage_action_date ALTER COLUMN usage_action_hashkey SET NOT NULL;
ALTER TABLE sat_usage_action_date ADD CONSTRAINT sat_usage_action_date_pk PRIMARY KEY (usage_action_hashkey);

CREATE OR REPLACE TABLE sat_usage_action_information (
    usage_action_hashkey string COMMENT 'Hashkey Hub Usage Action',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract__id bigint COMMENT 'Tham chiếu bảng acnt_contract',
    base_amount decimal(38,10) COMMENT 'Giá trị tiền tệ gốc phát sinh',
    base_curr string COMMENT 'Mã loại tiền tệ cơ sở',
    cl_stop_list bigint COMMENT 'Trạng thái danh sách chặn kỹ thuật',
    client_stop_list string COMMENT 'Chi tiết danh sách chặn khách hàng',
    con_cat string COMMENT 'Phân loại danh mục hợp đồng',
    custom_event_code string COMMENT 'Mã hành động tùy chỉnh nghiệp vụ',
    doc bigint COMMENT 'Tham chiếu bảng doc',
    event_details string COMMENT 'Mô tả chi tiết nội dung hành động',
    event_type bigint COMMENT 'Mã loại sự kiện hệ thống',
    event_type_next bigint COMMENT 'Mã loại sự kiện kế tiếp dự kiến',
    fee_type bigint COMMENT 'Loại phí dịch vụ áp dụng',
    group_code string COMMENT 'Mã nhóm phân loại hành động',
    next_action bigint COMMENT 'Mã định danh hành động kế tiếp',
    partition_key string COMMENT 'Khóa kỹ thuật phân vùng dữ liệu',
    posting_status string COMMENT 'Trạng thái hạch toán hành động',
    process_log__id bigint COMMENT 'Mã định danh liên kết đến nhật ký tiến trình',
    standing_order__id bigint COMMENT 'Mã lệnh chi định kỳ liên quan',
    switch_tag string COMMENT 'Nhãn điều hướng xử lý hệ thống',
    target_doc bigint COMMENT 'Mã tài liệu mục tiêu tác động',
    usage_action__oid bigint COMMENT 'Mã định danh action',
    usage_limiter__id bigint COMMENT 'Mã định danh hạn mức sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_usage_action_information ALTER COLUMN usage_action_hashkey SET NOT NULL;
ALTER TABLE sat_usage_action_information ADD CONSTRAINT sat_usage_action_information_pk PRIMARY KEY (usage_action_hashkey);

CREATE OR REPLACE TABLE sat_usage_action_state (
    usage_action_hashkey string COMMENT 'Hashkey Hub Usage Action',
    hashdiff string COMMENT 'Trường kỹ thuật: Hash diff phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    new_beh_type bigint COMMENT 'Loại hành vi mới của đối tượng',
    new_pack bigint COMMENT 'Gói dịch vụ mới sau cập nhật',
    new_scheme bigint COMMENT 'Sơ đồ biểu phí mới áp dụng',
    new_status bigint COMMENT 'Trạng thái sau khi hoàn tất',
    old_beh_type bigint COMMENT 'Loại hành vi cũ của đối tượng',
    old_pack bigint COMMENT 'Gói dịch vụ trước khi thay đổi',
    old_scheme bigint COMMENT 'Sơ đồ biểu phí cũ đang dùng',
    old_status bigint COMMENT 'Trạng thái trước khi thực hiện'
) CLUSTER BY AUTO;
ALTER TABLE sat_usage_action_state ALTER COLUMN usage_action_hashkey SET NOT NULL;
ALTER TABLE sat_usage_action_state ADD CONSTRAINT sat_usage_action_state_pk PRIMARY KEY (usage_action_hashkey);

CREATE OR REPLACE TABLE link_account_w4_acc_templ (
    link_account_w4_acc_templ_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acc_templ_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acc Templ',
    account_w4_hashkey string COMMENT 'Tham chiếu Hashkey Hub Account W4'
) CLUSTER BY AUTO;
ALTER TABLE link_account_w4_acc_templ ALTER COLUMN link_account_w4_acc_templ_hashkey SET NOT NULL;
ALTER TABLE link_account_w4_acc_templ ADD CONSTRAINT link_account_w4_acc_templ_pk PRIMARY KEY (link_account_w4_acc_templ_hashkey);

CREATE OR REPLACE TABLE link_account_w4_acnt_contract (
    link_account_w4_acnt_contract_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account_w4_hashkey string COMMENT 'Tham chiếu Hashkey Hub Account W4',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acnt Contract'
) CLUSTER BY AUTO;
ALTER TABLE link_account_w4_acnt_contract ALTER COLUMN link_account_w4_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_account_w4_acnt_contract ADD CONSTRAINT link_account_w4_acnt_contract_pk PRIMARY KEY (link_account_w4_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_card_info_acnt_contract (
    link_card_info_acnt_contract_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acnt Contract',
    card_info_hashkey string COMMENT 'Tham chiếu Hashkey Hub Card Info'
) CLUSTER BY AUTO;
ALTER TABLE link_card_info_acnt_contract ALTER COLUMN link_card_info_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_card_info_acnt_contract ADD CONSTRAINT link_card_info_acnt_contract_pk PRIMARY KEY (link_card_info_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_entry_item (
    link_entry_item_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    entry_hashkey string COMMENT 'Tham chiếu Hashkey Hub Entry',
    item_hashkey string COMMENT 'Tham chiếu Hashkey Hub Item'
) CLUSTER BY AUTO;
ALTER TABLE link_entry_item ALTER COLUMN link_entry_item_hashkey SET NOT NULL;
ALTER TABLE link_entry_item ADD CONSTRAINT link_entry_item_pk PRIMARY KEY (link_entry_item_hashkey);

CREATE OR REPLACE TABLE link_gl_trace_credit_entry (
    link_gl_trace_credit_entry_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    entry_hashkey string COMMENT 'Tham chiếu Hashkey Hub Entry',
    gl_trace_hashkey string COMMENT 'Tham chiếu Hashkey Hub GL Trace'
) CLUSTER BY AUTO;
ALTER TABLE link_gl_trace_credit_entry ALTER COLUMN link_gl_trace_credit_entry_hashkey SET NOT NULL;
ALTER TABLE link_gl_trace_credit_entry ADD CONSTRAINT link_gl_trace_credit_entry_pk PRIMARY KEY (link_gl_trace_credit_entry_hashkey);

CREATE OR REPLACE TABLE link_gl_trace_debit_entry (
    link_gl_trace_debit_entry_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    entry_hashkey string COMMENT 'Tham chiếu Hashkey Hub Entry',
    gl_trace_hashkey string COMMENT 'Tham chiếu Hashkey Hub GL Trace'
) CLUSTER BY AUTO;
ALTER TABLE link_gl_trace_debit_entry ALTER COLUMN link_gl_trace_debit_entry_hashkey SET NOT NULL;
ALTER TABLE link_gl_trace_debit_entry ADD CONSTRAINT link_gl_trace_debit_entry_pk PRIMARY KEY (link_gl_trace_debit_entry_hashkey);

CREATE OR REPLACE TABLE link_invoice_log_acnt_contract (
    link_invoice_log_acnt_contract_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acnt Contract',
    invoice_log_hashkey string COMMENT 'Tham chiếu Hashkey Hub Invoice Log'
) CLUSTER BY AUTO;
ALTER TABLE link_invoice_log_acnt_contract ALTER COLUMN link_invoice_log_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_invoice_log_acnt_contract ADD CONSTRAINT link_invoice_log_acnt_contract_pk PRIMARY KEY (link_invoice_log_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_invoice_log_doc (
    link_invoice_log_doc_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    document_hashkey string COMMENT 'Tham chiếu Hashkey Hub Document',
    invoice_log_hashkey string COMMENT 'Tham chiếu Hashkey Hub Invoice Log'
) CLUSTER BY AUTO;
ALTER TABLE link_invoice_log_doc ALTER COLUMN link_invoice_log_doc_hashkey SET NOT NULL;
ALTER TABLE link_invoice_log_doc ADD CONSTRAINT link_invoice_log_doc_pk PRIMARY KEY (link_invoice_log_doc_hashkey);

CREATE OR REPLACE TABLE link_item_account_w4 (
    link_item_account_w4_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account_w4_hashkey string COMMENT 'Tham chiếu Hashkey Hub Account W4',
    item_hashkey string COMMENT 'Tham chiếu Hashkey Hub Item'
) CLUSTER BY AUTO;
ALTER TABLE link_item_account_w4 ALTER COLUMN link_item_account_w4_hashkey SET NOT NULL;
ALTER TABLE link_item_account_w4 ADD CONSTRAINT link_item_account_w4_pk PRIMARY KEY (link_item_account_w4_hashkey);

CREATE OR REPLACE TABLE link_item_templ_approved (
    link_item_templ_approved_hashkey string COMMENT 'Link Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    item_hashkey string COMMENT 'Tham chiếu Hashkey Hub Item',
    templ_approved_hashkey string COMMENT 'Tham chiếu Hashkey Hub Templ Approved'
) CLUSTER BY AUTO;
ALTER TABLE link_item_templ_approved ALTER COLUMN link_item_templ_approved_hashkey SET NOT NULL;
ALTER TABLE link_item_templ_approved ADD CONSTRAINT link_item_templ_approved_pk PRIMARY KEY (link_item_templ_approved_hashkey);

CREATE OR REPLACE TABLE link_td_auth_sch_acnt_contract (
    link_td_auth_sch_acnt_contract_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acnt Contract',
    td_auth_sch_hashkey string COMMENT 'Tham chiếu Hashkey Hub Td Auth Sch'
) CLUSTER BY AUTO;
ALTER TABLE link_td_auth_sch_acnt_contract ALTER COLUMN link_td_auth_sch_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_td_auth_sch_acnt_contract ADD CONSTRAINT link_td_auth_sch_acnt_contract_pk PRIMARY KEY (link_td_auth_sch_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_td_auth_sch_client (
    link_td_auth_sch_client_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    client_hashkey string COMMENT 'Tham chiếu Hashkey Hub Client',
    td_auth_sch_hashkey string COMMENT 'Tham chiếu Hashkey Hub Td Auth Sch'
) CLUSTER BY AUTO;
ALTER TABLE link_td_auth_sch_client ALTER COLUMN link_td_auth_sch_client_hashkey SET NOT NULL;
ALTER TABLE link_td_auth_sch_client ADD CONSTRAINT link_td_auth_sch_client_pk PRIMARY KEY (link_td_auth_sch_client_hashkey);

CREATE OR REPLACE TABLE link_templ_approved_acc_templ (
    link_templ_approved_acc_templ_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acc_templ_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acc Templ',
    templ_approved_hashkey string COMMENT 'Tham chiếu Hashkey Hub Templ Approved'
) CLUSTER BY AUTO;
ALTER TABLE link_templ_approved_acc_templ ALTER COLUMN link_templ_approved_acc_templ_hashkey SET NOT NULL;
ALTER TABLE link_templ_approved_acc_templ ADD CONSTRAINT link_templ_approved_acc_templ_pk PRIMARY KEY (link_templ_approved_acc_templ_hashkey);

CREATE OR REPLACE TABLE link_usage_action_acnt_contract (
    link_usage_action_acnt_contract_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hashkey Hub Acnt Contract',
    usage_action_hashkey string COMMENT 'Tham chiếu Hashkey Hub Usage Action'
) CLUSTER BY AUTO;
ALTER TABLE link_usage_action_acnt_contract ALTER COLUMN link_usage_action_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_usage_action_acnt_contract ADD CONSTRAINT link_usage_action_acnt_contract_pk PRIMARY KEY (link_usage_action_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_usage_action_document (
    link_usage_action_document_hashkey string COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    document_hashkey string COMMENT 'Tham chiếu Hashkey Hub Document',
    usage_action_hashkey string COMMENT 'Tham chiếu Hashkey Hub Usage Action'
) CLUSTER BY AUTO;
ALTER TABLE link_usage_action_document ALTER COLUMN link_usage_action_document_hashkey SET NOT NULL;
ALTER TABLE link_usage_action_document ADD CONSTRAINT link_usage_action_document_pk PRIMARY KEY (link_usage_action_document_hashkey);

CREATE OR REPLACE TABLE effsat_link_invoice_log_doc (
    link_invoice_log_doc_hashkey string COMMENT 'Link Hashkey',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)',
    source_event_date date COMMENT 'Ngày hiệu lực của bản ghi',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_invoice_log_doc ALTER COLUMN link_invoice_log_doc_hashkey SET NOT NULL;
ALTER TABLE effsat_link_invoice_log_doc ADD CONSTRAINT effsat_link_invoice_log_doc_pk PRIMARY KEY (link_invoice_log_doc_hashkey);

CREATE OR REPLACE TABLE effsat_link_td_auth_sch_acnt_contract (
    link_td_auth_sch_acnt_contract_hashkey string COMMENT 'Link Hashkey',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)',
    source_event_date date COMMENT 'Ngày hiệu lực của bản ghi',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_td_auth_sch_acnt_contract ALTER COLUMN link_td_auth_sch_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE effsat_link_td_auth_sch_acnt_contract ADD CONSTRAINT effsat_link_td_auth_sch_acnt_contract_pk PRIMARY KEY (link_td_auth_sch_acnt_contract_hashkey);

-- ====================== REFERENCE TABLES (phase2) ======================
CREATE OR REPLACE TABLE ref_way4_ows_add_data (
    Ref_hashkey string NOT NULL COMMENT 'HASH of (Ref_type + Ref_code)',
    Ref_type string COMMENT 'Loại tham chiếu (tên bảng nguồn)',
    Ref_code string COMMENT 'Mã tham chiếu',
    Ref_description string COMMENT 'Mô tả/diễn giải mã tham chiếu',
    AMND_STATE string COMMENT 'Trạng thái sửa đổi bản ghi (A = đang hiệu lực)',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên thực hiện sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi (trước khi sửa đổi)',
    ID bigint COMMENT 'Định danh duy nhất của bản ghi tại hệ thống nguồn',
    ADD_DATA_COL__ID bigint COMMENT 'Định danh cột dữ liệu bổ sung (tham chiếu định nghĩa cột)',
    FOR_ID bigint COMMENT 'Định danh đối tượng được gắn dữ liệu bổ sung',
    ADD_DATA_TAB bigint COMMENT 'Mã bảng/nhóm dữ liệu bổ sung',
    VAL string COMMENT 'Giá trị của trường dữ liệu bổ sung',
    PARTITION_KEY string COMMENT 'Khóa phân vùng dữ liệu',
    DATA_DATE string COMMENT 'Ngày dữ liệu (ngày snapshot từ hệ thống nguồn)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_ows_add_data ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_ows_add_data ADD CONSTRAINT ref_way4_ows_add_data_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_ows_bank_unit (
    Ref_hashkey string NOT NULL COMMENT 'HASH of (Ref_type + Ref_code)',
    Ref_type string COMMENT 'Loại tham chiếu (tên bảng nguồn)',
    Ref_code string COMMENT 'Mã tham chiếu',
    Ref_description string COMMENT 'Mô tả/diễn giải mã tham chiếu',
    AMND_STATE string COMMENT 'Trạng thái sửa đổi bản ghi (A = đang hiệu lực)',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên thực hiện sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi (trước khi sửa đổi)',
    ID bigint COMMENT 'Định danh duy nhất của bản ghi tại hệ thống nguồn',
    NAME string COMMENT 'name',
    CODE string COMMENT 'code',
    UNIT_TYPE string COMMENT 'Loại đơn vị ngân hàng',
    BANK_UNIT__OID bigint COMMENT 'Định danh đơn vị ngân hàng cấp trên',
    F_I bigint COMMENT 'Mã định danh tổ chức tài chính (Financial Institution)',
    LIAB_CONTRACT bigint COMMENT 'Định danh hợp đồng trách nhiệm (liability contract)',
    BANK_CLIENT bigint COMMENT 'Định danh khách hàng nội bộ ngân hàng',
    IS_READY string COMMENT 'Cờ sẵn sàng sử dụng (Y/N)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_ows_bank_unit ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_ows_bank_unit ADD CONSTRAINT ref_way4_ows_bank_unit_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_ows_bin_table (
    Ref_hashkey string NOT NULL COMMENT 'HASH of (Ref_type + Ref_code)',
    Ref_type string COMMENT 'Loại tham chiếu (tên bảng nguồn)',
    Ref_code string COMMENT 'Mã tham chiếu',
    Ref_description string COMMENT 'Mô tả/diễn giải mã tham chiếu',
    AMND_STATE string COMMENT 'A for active value',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên thực hiện sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi (trước khi sửa đổi)',
    ID bigint COMMENT 'Định danh duy nhất của bản ghi tại hệ thống nguồn',
    BIN_GROUP__OID bigint COMMENT 'Định danh nhóm BIN',
    NAME string COMMENT 'Bank Name',
    MEMBER_ID string COMMENT 'Bank ID',
    START_BIN string COMMENT 'Start BIN card',
    END_BIN string COMMENT 'End BIN card',
    START_BIN_4 string COMMENT '4 chữ số đầu của dải BIN',
    PAN_LENGTH bigint COMMENT 'Độ dài số thẻ (PAN)',
    BIN_CONDITION string COMMENT 'Điều kiện áp dụng của BIN',
    BIN_DETAILS string COMMENT 'Chi tiết bổ sung của BIN',
    CARD_BRAND string COMMENT 'Thương hiệu thẻ (Visa, Mastercard, ...)',
    CARD_ORG string COMMENT 'Tổ chức thẻ phát hành/chấp nhận',
    CARD_TECHNOLOGY string COMMENT 'Công nghệ thẻ (từ, chip, contactless, ...)',
    CDV_ALGORITHM string COMMENT 'Thuật toán tính số kiểm tra thẻ (check digit)',
    CHANNEL string COMMENT 'Card Scheme: V for Visa, E for MasterCard, J for JCB',
    COUNTRY string COMMENT 'Mã quốc gia',
    DATA_SOURCE string COMMENT 'Nguồn dữ liệu BIN',
    EC_ATM_TYPE string COMMENT 'Loại thiết bị EC/ATM',
    FORWARDING_ID string COMMENT 'Định danh tổ chức chuyển tiếp giao dịch',
    ICA_NUMBER string COMMENT 'Số ICA (Interbank Card Association)',
    PROCESSING_CLASS string COMMENT 'Lớp xử lý của BIN',
    PRODUCT_ID string COMMENT 'Định danh sản phẩm thẻ',
    LICENSED_PRODUCT_ID string COMMENT 'Định danh sản phẩm thẻ được cấp phép',
    PRODUCT_CATEGORY string COMMENT 'Nhóm sản phẩm thẻ',
    REGION_FOR_ISSUER string COMMENT 'Vùng phát hành của tổ chức phát hành',
    SERVICE_INDICATOR string COMMENT 'Chỉ báo dịch vụ thẻ',
    TERMINAL_CATEGORY string COMMENT 'Nhóm thiết bị đầu cuối',
    USAGE string COMMENT 'Mục đích sử dụng BIN',
    USAGE_DOMAIN string COMMENT 'Miền sử dụng (trong nước/quốc tế, ...)',
    BIN_STATUS string COMMENT 'Trạng thái của BIN',
    DATA_DATE string COMMENT 'Ngày dữ liệu (ngày snapshot từ hệ thống nguồn)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_ows_bin_table ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_ows_bin_table ADD CONSTRAINT ref_way4_ows_bin_table_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_ows_event_type (
    Ref_hashkey string NOT NULL COMMENT 'HASH of (Ref_type + Ref_code)',
    Ref_type string COMMENT 'Loại tham chiếu (tên bảng nguồn)',
    Ref_code string COMMENT 'Mã tham chiếu',
    Ref_description string COMMENT 'Mô tả/diễn giải mã tham chiếu',
    AMND_STATE string COMMENT 'Trạng thái sửa đổi bản ghi (A = đang hiệu lực)',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên thực hiện sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi (trước khi sửa đổi)',
    ID bigint COMMENT 'Định danh duy nhất của bản ghi tại hệ thống nguồn',
    NAME string COMMENT 'event name',
    GROUP_CODE string COMMENT 'event group',
    CODE string COMMENT 'event code',
    F_I bigint COMMENT 'Mã định danh tổ chức tài chính (Financial Institution)',
    PCAT string COMMENT 'product category, C: issuing ,M: acquiring, A: accounting, B: bank accounting',
    CON_CAT string COMMENT 'contract category, A: account, C: card ,M: device',
    EVENT_RENEW_TYPE string COMMENT 'Loại gia hạn/làm mới sự kiện',
    EVENT_PERIOD bigint COMMENT 'Chu kỳ lặp của sự kiện',
    DUE_TO_WORK_DAY string COMMENT 'Quy tắc dời hạn theo ngày làm việc',
    POST_IMMEDIATE string COMMENT 'Cờ hạch toán ngay khi phát sinh',
    FEE_TYPE bigint COMMENT 'Loại phí áp dụng cho sự kiện',
    NEW_STATUS bigint COMMENT 'Trạng thái mới của hợp đồng sau sự kiện',
    NEXT_EVENT bigint COMMENT 'Sự kiện kế tiếp được kích hoạt',
    START_JOB bigint COMMENT 'Tiến trình (job) được khởi chạy bởi sự kiện',
    CLIENT_STOP_LIST string COMMENT 'Cờ đưa khách hàng vào danh sách dừng',
    CR_LIMIT_ACTION string COMMENT 'Hành động đối với hạn mức tín dụng',
    USED_IN_HISTORY string COMMENT 'Cờ sự kiện được dùng trong lịch sử',
    SUPPL_FORMULA string COMMENT 'Công thức tính bổ sung',
    CUSTOM_EVENT_CODE string COMMENT 'Mã sự kiện tùy biến',
    SPECIAL_PARMS string COMMENT 'Tham số đặc biệt của sự kiện',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_ows_event_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_ows_event_type ADD CONSTRAINT ref_way4_ows_event_type_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_ows_evnt_action (
    Ref_hashkey string NOT NULL COMMENT 'HASH of (Ref_type + Ref_code)',
    Ref_type string COMMENT 'Loại tham chiếu (tên bảng nguồn)',
    Ref_code string COMMENT 'Mã tham chiếu',
    Ref_description string COMMENT 'Mô tả/diễn giải mã tham chiếu',
    ID bigint COMMENT 'Định danh duy nhất của bản ghi tại hệ thống nguồn',
    USAGE_ACTION__OID bigint COMMENT 'Định danh hành động sử dụng',
    ACTION_CODE string COMMENT 'Mã hành động',
    NEW_ID bigint COMMENT 'Định danh trạng thái/đối tượng mới',
    OLD_ID bigint COMMENT 'Định danh trạng thái/đối tượng cũ',
    STATUS string COMMENT 'Trạng thái bản ghi',
    EVENT_DETAILS string COMMENT 'Chi tiết hành động sự kiện',
    DATA_DATE string COMMENT 'Ngày dữ liệu (ngày snapshot từ hệ thống nguồn)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_ows_evnt_action ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_ows_evnt_action ADD CONSTRAINT ref_way4_ows_evnt_action_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_ows_td_auth_type (
    Ref_hashkey string NOT NULL COMMENT 'HASH of (Ref_type + Ref_code)',
    Ref_type string COMMENT 'Loại tham chiếu (tên bảng nguồn)',
    Ref_code string COMMENT 'Mã tham chiếu',
    Ref_description string COMMENT 'Mô tả/diễn giải mã tham chiếu',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên thực hiện sửa đổi bản ghi gần nhất',
    AMND_STATE string COMMENT 'Trạng thái sửa đổi bản ghi (A = đang hiệu lực)',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi (trước khi sửa đổi)',
    ID bigint COMMENT 'Định danh duy nhất của bản ghi tại hệ thống nguồn',
    AUTH_TYPE_CAT string COMMENT 'Nhóm loại xác thực',
    NAME string COMMENT 'Tên gọi',
    CODE string COMMENT 'Mã định danh nghiệp vụ',
    IDT_REQUIRED string COMMENT 'Cờ yêu cầu định danh (identity)',
    VERSION_IDT string COMMENT 'Phiên bản mẫu định danh',
    BASE_TYPE bigint COMMENT 'Loại xác thực cơ sở',
    IS_READY string COMMENT 'Cờ sẵn sàng sử dụng (Y/N)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_ows_td_auth_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_ows_td_auth_type ADD CONSTRAINT ref_way4_ows_td_auth_type_pk PRIMARY KEY (Ref_hashkey);
