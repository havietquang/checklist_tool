# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;



CREATE OR REPLACE TABLE hub_campaigns (
    campaigns_hashkey string NOT NULL COMMENT 'Hashkey Hub Campaigns – MD5(campaign_id)',
    business_key string COMMENT 'ID chiến dịch Marketing (khóa nghiệp vụ)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_campaigns ALTER COLUMN campaigns_hashkey SET NOT NULL;
ALTER TABLE hub_campaigns ADD CONSTRAINT hub_campaigns_pk PRIMARY KEY (campaigns_hashkey);

CREATE OR REPLACE TABLE sts_hub_campaigns (
    campaigns_hashkey string NOT NULL COMMENT 'STS Hub Hash Key – MD5(campaign_id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_campaigns ALTER COLUMN campaigns_hashkey SET NOT NULL;
ALTER TABLE sts_hub_campaigns ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_campaigns ADD CONSTRAINT sts_hub_campaigns_pk PRIMARY KEY (campaigns_hashkey, source_event_date);


CREATE OR REPLACE TABLE hub_events (
    events_hashkey string NOT NULL COMMENT 'Hashkey Hub Events',
    ts string,
    eventName string,
    eventProps string,
    identity string,
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_events ALTER COLUMN events_hashkey SET NOT NULL;
ALTER TABLE hub_events ADD CONSTRAINT hub_events_pk PRIMARY KEY (events_hashkey);

CREATE OR REPLACE TABLE sts_hub_events (
    events_hashkey string NOT NULL COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_events ALTER COLUMN events_hashkey SET NOT NULL;
ALTER TABLE sts_hub_events ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_events ADD CONSTRAINT sts_hub_events_pk PRIMARY KEY (events_hashkey, source_event_date);


CREATE OR REPLACE TABLE sat_campaigns_information (
    campaigns_hashkey string NOT NULL COMMENT 'Hashkey Hub Campaigns',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    total_sent_events string COMMENT 'Tổng số events/thiết bị đã gửi thông báo',
    total_clicked_users string COMMENT 'Tổng số người dùng đã click vào thông báo',
    total_viewed_users string COMMENT 'Tổng số người dùng đã xem thông báo',
    total_viewed_events string COMMENT 'Tổng số events/thiết bị đã xem thông báo',
    total_clicked_events string COMMENT 'Tổng số events/thiết bị đã click vào thông báo',
    unique_sent_users string COMMENT 'Số người dùng duy nhất đã được gửi thông báo',
    unique_viewed_within_conversion_time string COMMENT 'Người dùng duy nhất đã xem trong thời gian chuyển đổi',
    unique_clicked_within_conversion_time string COMMENT 'Người dùng duy nhất đã click trong thời gian chuyển đổi',
    error_user_not_reachable string COMMENT 'Lỗi: Không liên lạc được người dùng',
    error_push_unregistered_android string COMMENT 'Lỗi: Push token Android không còn hợp lệ',
    influenced_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi có ảnh hưởng (%)',
    influenced_conversions string COMMENT 'Số chuyển đổi có ảnh hưởng (sent to converted funnel)',
    error_user_dnd string COMMENT 'Lỗi: Người dùng đang trong trạng thái DND',
    click_through_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi click-through (%)',
    total_sent_users string COMMENT 'Tổng số người dùng đã được gửi thông báo',
    error_apns_bad_device_token string COMMENT 'Lỗi: APNS bad device token (token iOS không hợp lệ)',
    estimated_reach string COMMENT 'Ước tính số người dùng đủ điều kiện nhận chiến dịch',
    click_through_conversions string COMMENT 'Tổng người dùng chuyển đổi qua click (click-through funnel)',
    unique_converted_within_conversion_time string COMMENT 'Người dùng duy nhất đã chuyển đổi trong thời gian quy định',
    errors string COMMENT 'Tổng số lỗi phát sinh trong chiến dịch',
    status string COMMENT 'Trạng thái hiện tại của chiến dịch',
    error_inbox_ttl_expired string COMMENT 'Lỗi: Inbox TTL đã hết hạn'
) CLUSTER BY AUTO;
ALTER TABLE sat_campaigns_information ALTER COLUMN campaigns_hashkey SET NOT NULL;
ALTER TABLE sat_campaigns_information ADD CONSTRAINT sat_campaigns_information_pk PRIMARY KEY (campaigns_hashkey);


CREATE OR REPLACE TABLE sat_campaigns_classification (
    campaigns_hashkey string NOT NULL COMMENT 'Hashkey Hub Campaigns',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    sent_influenced_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi sent-influenced (%)',
    title string COMMENT 'Tiêu đề thông báo push/email',
    message string COMMENT 'Nội dung thông báo của chiến dịch',
    start_date string COMMENT 'Ngày bắt đầu chiến dịch',
    start_time string COMMENT 'Thời gian bắt đầu chiến dịch',
    device string COMMENT 'Thiết bị mục tiêu (mobile, TV, tablet, v.v.)',
    who_query string COMMENT 'Truy vấn phân khúc người nhận (segment query) trong chiến dịch',
    constant_property string COMMENT 'Thuộc tính hằng số được gán với chiến dịch',
    safety_check_limit string COMMENT 'Ngưỡng kiểm tra an toàn – chiến dịch dừng nếu vượt qua',
    campaign_per_day_limit string COMMENT 'Số tin nhắn tối đa gửi mỗi ngày trong chiến dịch',
    reach string COMMENT 'Gửi đến tất cả thiết bị hay thiết bị hoạt động gần nhất',
    created_by string COMMENT 'Người tạo chiến dịch',
    created_time string COMMENT 'Thời điểm tạo chiến dịch',
    labels string COMMENT 'Nhãn/thẻ phân loại và tổ chức chiến dịch',
    total_delivered_users string COMMENT 'Tổng số người dùng nhận được Email/SMS/WhatsApp',
    total_unsubscribes100 string COMMENT 'Tổng số hủy đăng ký (đo theo events)',
    ios_badge_count string COMMENT 'Badge count hiển thị trên icon iOS',
    ios_deep_link string COMMENT 'Deep link cho iOS push notification',
    ios_mutable_content string COMMENT 'Nội dung mutable trên iOS (Yes/No)',
    android_summary string COMMENT 'Summary text cho Android push notification',
    android_large_icon_url string COMMENT 'URL icon lớn cho Android push notification',
    android_small_app_icon_colour string COMMENT 'Màu icon nhỏ ứng dụng cho Android push notification',
    android_sound_file string COMMENT 'Tệp âm thanh Android push (NA/Default/file URL)',
    android_notification_tray_priority string COMMENT 'Mức độ ưu tiên hiển thị trong tray Android',
    android_notification_delivery_priority string COMMENT 'Mức độ ưu tiên gửi server cho Android push',
    notification_channels string COMMENT 'Kênh giao tiếp đã được người dùng đồng ý nhận',
    badge_icon string COMMENT 'Badge icon cho push notification Android',
    send_to_app_inbox_as_well string COMMENT 'Gửi đồng thời vào App Inbox (chỉ áp dụng cho push)',
    service_provider string COMMENT 'Nhà cung cấp dịch vụ gửi thông báo',
    conversion_event string COMMENT 'Sự kiện chuyển đổi được theo dõi trong chiến dịch',
    conversion_time_in_minutes string COMMENT 'Khoảng thời gian theo dõi chuyển đổi (phút)',
    campaign_url string COMMENT 'URL liên kết của chiến dịch',
    push_amplification_applied string COMMENT 'Có áp dụng Enhanced Push Delivery không',
    web_priority string COMMENT 'Mức độ ưu tiên thông báo web (High/Medium/Low)',
    time_to_live_type string COMMENT 'Loại TTL của thông báo push',
    time_to_live_value string COMMENT 'Giá trị TTL của thông báo push',
    template_name string COMMENT 'Tên template dùng trong chiến dịch WhatsApp',
    provider_name string COMMENT 'Tên nhà cung cấp dịch vụ WhatsApp',
    waba_number string COMMENT 'Số điện thoại nguồn gửi tin WhatsApp (WABA number)',
    total_control_group_count string COMMENT 'Tổng số người dùng trong nhóm kiểm soát tổng',
    total_control_group_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi nhóm kiểm soát tổng (%)',
    revenue_within_conversion_time string COMMENT 'Doanh thu phát sinh trong thời gian chuyển đổi',
    system_control_group_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi nhóm kiểm soát hệ thống (%)',
    system_control_group_revenue string COMMENT 'Doanh thu từ nhóm kiểm soát hệ thống',
    campaign_control_group_count string COMMENT 'Số người dùng trong nhóm kiểm soát chiến dịch',
    campaign_control_group_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi nhóm kiểm soát chiến dịch (%)',
    campaign_control_group_revenue string COMMENT 'Doanh thu từ nhóm kiểm soát chiến dịch',
    custom_control_group_count string COMMENT 'Số người dùng trong nhóm kiểm soát tùy chỉnh',
    custom_control_group_conversions_pct string COMMENT 'Tỷ lệ chuyển đổi nhóm kiểm soát tùy chỉnh (%)',
    custom_control_group_revenue string COMMENT 'Doanh thu từ nhóm kiểm soát tùy chỉnh',
    custom_control_group_name string COMMENT 'Tên nhóm kiểm soát tùy chỉnh',
    sent_influenced_revenue string COMMENT 'Doanh thu từ chuyển đổi sent-influenced',
    total_html_viewed_events string COMMENT 'Tổng số email HTML đã được mở/xem',
    total_amp_viewed_events string COMMENT 'Tổng số email AMP đã được mở/xem',
    total_html_clicked_events string COMMENT 'Tổng số click vào phiên bản HTML của email',
    total_amp_clicked_events string COMMENT 'Tổng số click vào phiên bản AMP của email',
    campaign_name string COMMENT 'Tên chiến dịch marketing',
    channel string COMMENT 'Kênh phân phối (Email, Mobile Push, SMS, WhatsApp, v.v.)',
    delivery string COMMENT 'Loại phân phối chiến dịch (Action/Inaction/One-time/v.v.)',
    type string COMMENT 'Loại chiến dịch (single message/sequence/journey/v.v.)',
    variant string COMMENT 'Biến thể thông điệp – áp dụng cho A/B test',
    os string COMMENT 'Hệ điều hành thiết bị mục tiêu (iOS, Android)',
    dnd string COMMENT 'Cấu hình DND / tần suất gửi chiến dịch',
    timezone string COMMENT 'Cấu hình gửi theo múi giờ người dùng',
    cutoff string COMMENT 'Thời gian cutoff sau khi chiến dịch hết hiệu lực',
    fcap string COMMENT 'Số tin nhắn tối đa gửi cho một người dùng (frequency cap)',
    throttle string COMMENT 'Giới hạn tốc độ gửi của chiến dịch',
    campaign_overall_limit string COMMENT 'Chiến dịch không gửi nếu số người đủ điều kiện vượt ngưỡng tổng',
    end_date string COMMENT 'Ngày kết thúc chiến dịch',
    total_delivered_events string COMMENT 'Tổng số Email/SMS/WhatsApp đã giao thành công',
    total_unsubscribes78 string COMMENT 'Tổng số hủy đăng ký (đo theo users)',
    ios_rich_media_type string COMMENT 'Loại rich media cho iOS push (Single/Carousel)',
    ios_rich_media_url string COMMENT 'URL hình ảnh cho iOS push notification',
    ios_sound_file string COMMENT 'Tệp âm thanh iOS push (mặc định hoặc custom URL)',
    ios_category string COMMENT 'Category cho iOS push notification (nếu có)',
    android_subtitle string COMMENT 'Tiêu đề phụ cho Android push notification',
    android_image_url string COMMENT 'URL hình ảnh cho Android push notification',
    android_deep_link string COMMENT 'Deep link cho Android push notification',
    collapse_notification string COMMENT 'Thông báo có thể gộp/collapse không',
    badge_id string COMMENT 'Badge ID cho push notification Android',
    rendermax_enabled string COMMENT 'Có bật RenderMax (Enhanced Push Delivery) không',
    click_through_conversion_revenue string COMMENT 'Doanh thu từ click-through conversions',
    total_control_group_conversions string COMMENT 'Tổng số người dùng nhóm kiểm soát đã chuyển đổi',
    total_control_group_revenue string COMMENT 'Doanh thu từ nhóm kiểm soát tổng',
    influenced_revenue string COMMENT 'Doanh thu từ chuyển đổi có ảnh hưởng',
    system_control_group_count string COMMENT 'Số người dùng trong nhóm kiểm soát hệ thống',
    system_control_group_conversions string COMMENT 'Số chuyển đổi của nhóm kiểm soát hệ thống',
    campaign_control_group_conversions string COMMENT 'Số chuyển đổi của nhóm kiểm soát chiến dịch',
    custom_control_group_conversions string COMMENT 'Số chuyển đổi của nhóm kiểm soát tùy chỉnh',
    sent_influenced_conversions string COMMENT 'Số chuyển đổi có ảnh hưởng từ lượt gửi (sent-influenced)',
    total_html_unsubscribes string COMMENT 'Tổng số hủy đăng ký qua email HTML',
    total_amp_unsubscribes string COMMENT 'Tổng số hủy đăng ký qua email AMP'
) CLUSTER BY AUTO;
ALTER TABLE sat_campaigns_classification ALTER COLUMN campaigns_hashkey SET NOT NULL;
ALTER TABLE sat_campaigns_classification ADD CONSTRAINT sat_campaigns_classification_pk PRIMARY KEY (campaigns_hashkey);


CREATE OR REPLACE TABLE sat_events_information (
    events_hashkey string NOT NULL COMMENT 'Hashkey Hub Events',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    profile string COMMENT 'Thông tin profile người dùng gắn với sự kiện (struct: identity, email, name, platform, push_token)',
    deviceInfo string COMMENT 'Thông tin thiết bị (struct: appVersion, browser, model, osVersion, sdkVersion, dpi)'
) CLUSTER BY AUTO;
ALTER TABLE sat_events_information ALTER COLUMN events_hashkey SET NOT NULL;
ALTER TABLE sat_events_information ADD CONSTRAINT sat_events_information_pk PRIMARY KEY (events_hashkey);
