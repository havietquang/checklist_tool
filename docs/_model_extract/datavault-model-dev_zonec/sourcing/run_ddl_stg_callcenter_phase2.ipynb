# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- Phase 2
CREATE OR REPLACE VIEW v_stg_callcenter_callcenter AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS _id,
    CAST(NULL AS STRING) AS uniqueid,
    CAST(NULL AS STRING) AS gcalluuid,
    CAST(NULL AS STRING) AS accountcode,
    CAST(NULL AS STRING) AS dialid,
    CAST(NULL AS STRING) AS sipserver,
    CAST(NULL AS STRING) AS src,
    CAST(NULL AS STRING) AS dst,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS dstchannel,
    CAST(NULL AS STRING) AS queue,
    CAST(NULL AS STRING) AS in_out,
    CAST(NULL AS STRING) AS did_number,
    CAST(NULL AS STRING) AS prefix_detail,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS callername,
    CAST(NULL AS INT) AS customer_id,
    CAST(NULL AS STRING) AS customer_code,
    CAST(NULL AS STRING) AS customername,
    CAST(NULL AS STRING) AS customercif,
    CAST(NULL AS BIGINT) AS calldate,
    CAST(NULL AS STRING) AS calldatetime,
    CAST(NULL AS BIGINT) AS createtime,
    CAST(NULL AS INT) AS duration,
    CAST(NULL AS INT) AS billsec,
    CAST(NULL AS INT) AS billtime,
    CAST(NULL AS INT) AS holdtime,
    CAST(NULL AS INT) AS talktime,
    CAST(NULL AS INT) AS waitingtime,
    CAST(NULL AS INT) AS moh_time,
    CAST(NULL AS STRING) AS disposition,
    CAST(NULL AS STRING) AS system_disposition,
    CAST(NULL AS STRING) AS extension_disposition,
    CAST(NULL AS STRING) AS calltype,
    CAST(NULL AS STRING) AS hangup_by,
    CAST(NULL AS STRING) AS connected,
    CAST(NULL AS STRING) AS not_connected,
    CAST(NULL AS INT) AS processed,
    CAST(NULL AS STRING) AS filename,
    CAST(NULL AS STRING) AS moh_log,
    CAST(NULL AS STRING) AS moh_log_process,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_callcenter_information,
    CAST(NULL AS STRING) AS hashdiff_callcenter_outcome,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
