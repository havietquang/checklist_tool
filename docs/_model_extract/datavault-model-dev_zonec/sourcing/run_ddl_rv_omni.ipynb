# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE hub_user_omni (
    omni_user_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_user_omni ALTER COLUMN omni_user_hashkey SET NOT NULL;
ALTER TABLE hub_user_omni ADD CONSTRAINT hub_user_omni_pk PRIMARY KEY (omni_user_hashkey);

CREATE OR REPLACE TABLE sat_omni_user_information (
    omni_user_hashkey string COMMENT 'Tham chiếu Hub user_omni',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    username string COMMENT 'Tên tài khoản OMNI',
    username_up string COMMENT 'Tên tài khoản OMNI (in hoa)',
    preferred_language string COMMENT 'Ngôn ngữ ưu tiên',
    realm_id string COMMENT 'Khách hàng là nhân viên của OCB',
    external_id string COMMENT 'External ID của người dùng',
    external_id_up string COMMENT 'External ID của người dùng (in hoa)',
    legal_entity_id string COMMENT 'Entity ID pháp lý',
    full_name string COMMENT 'Tên đầy đủ',
    full_name_up string COMMENT 'Tên đầy đủ (in hoa)',
    idp_id string COMMENT 'Mã IDP',
    cb_user_id string COMMENT 'Mã định danh người trong hệ thống Core Banking',
    cb_issuer string COMMENT 'Đơn vị phát hành tài khoản người dùng trong hệ thống Core Banking'
) CLUSTER BY AUTO;
ALTER TABLE sat_omni_user_information ALTER COLUMN omni_user_hashkey SET NOT NULL;
ALTER TABLE sat_omni_user_information ADD CONSTRAINT sat_omni_user_information_pk PRIMARY KEY (omni_user_hashkey);

CREATE OR REPLACE TABLE link_omni_user_customer (
    link_omni_user_customer_hashkey string COMMENT 'Link Hash Key',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub user_omni (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_omni_user_customer ALTER COLUMN link_omni_user_customer_hashkey SET NOT NULL;
ALTER TABLE link_omni_user_customer ADD CONSTRAINT link_omni_user_customer_pk PRIMARY KEY (link_omni_user_customer_hashkey);

CREATE OR REPLACE TABLE sat_omni_customer_information (
    customer_hashkey string COMMENT 'Tham chiếu Hub customer từ T24',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    created_at string COMMENT 'Ngày tạo trên OMNI',
    customer_status string COMMENT 'Trạng thái khách hàng'
) CLUSTER BY AUTO;
ALTER TABLE sat_omni_customer_information ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sat_omni_customer_information ADD CONSTRAINT sat_omni_customer_information_pk PRIMARY KEY (customer_hashkey);

CREATE OR REPLACE TABLE hub_service (
    omni_service_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_service ALTER COLUMN omni_service_hashkey SET NOT NULL;
ALTER TABLE hub_service ADD CONSTRAINT hub_service_pk PRIMARY KEY (omni_service_hashkey);

CREATE OR REPLACE TABLE link_service_customer (
    link_omni_service_customer_hashkey string COMMENT 'Link Hash Key',
    omni_service_hashkey string COMMENT 'Tham chiếu Hub service (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_service_customer ALTER COLUMN link_omni_service_customer_hashkey SET NOT NULL;
ALTER TABLE link_service_customer ADD CONSTRAINT link_service_customer_pk PRIMARY KEY (link_omni_service_customer_hashkey);

CREATE OR REPLACE TABLE sat_service_package (
    omni_service_hashkey string COMMENT 'Tham chiếu Hub service',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    package_id string COMMENT 'Mã gói của khách hàng',
    package_mounting_account string COMMENT 'Gói dịch vụ được liên kết với tài khoản',
    account_package_code string COMMENT 'Mã gói tài khoản',
    account_package_date string COMMENT 'Ngày tạo gói',
    smart_account_package_code string COMMENT 'Mã gói OMNI',
    smart_account_package_name string COMMENT 'Tên gói OMNI',
    package_offer_code string COMMENT 'Mã gói đề nghị',
    package_offer_name string COMMENT 'Tên gói đề nghị',
    limit decimal(38,10) COMMENT 'Giới hạn giao dịch',
    service_agreement_id string COMMENT 'Mã hợp đồng/thỏa thuận sử dụng dịch vụ',
    fee_discount_id string COMMENT 'Mã chương trình giảm phí đang được áp dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_service_package ALTER COLUMN omni_service_hashkey SET NOT NULL;
ALTER TABLE sat_service_package ADD CONSTRAINT sat_service_package_pk PRIMARY KEY (omni_service_hashkey);

CREATE OR REPLACE TABLE sat_service_information (
    omni_service_hashkey string COMMENT 'Tham chiếu Hub service',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    email string COMMENT 'Địa chỉ email',
    phone_number string COMMENT 'Số điện thoại',
    username string COMMENT 'Tên tài khoản OMNI',
    old_omni_username string COMMENT 'Tên tài khoản OMNI cũ',
    status string COMMENT 'Trạng thái giao dịch',
    authentication_type_id string COMMENT 'Phương thức xác thực (RV. Smart OTP + SMS OTP)',
    account_number_temp string COMMENT 'Số tài khoản tạm thời',
    branch_code string COMMENT 'Mã chi nhánh quản lý',
    branch_name string COMMENT 'Tên chi nhánh quản lý',
    is_same_username_group binary COMMENT 'Cờ xác nhận tài khoản này có thuộc cùng một nhóm tên đăng nhập hay không'
) CLUSTER BY AUTO;
ALTER TABLE sat_service_information ALTER COLUMN omni_service_hashkey SET NOT NULL;
ALTER TABLE sat_service_information ADD CONSTRAINT sat_service_information_pk PRIMARY KEY (omni_service_hashkey);

CREATE OR REPLACE TABLE sat_service_audit (
    omni_service_hashkey string COMMENT 'Tham chiếu Hub service',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    created_at string COMMENT 'Ngày khởi tạo giao dịch (tạo tài khoản OMNI)',
    created_by string COMMENT 'Người khởi tạo giao dịch (tạo tài khoản OMNI)',
    updated_at string COMMENT 'Ngày update giao dịch',
    updated_by string COMMENT 'Người update giao dịch',
    locked_at string COMMENT 'Ngày lock tài khoản OMNI',
    locked_by string COMMENT 'Người khóa tài khoản OMNI',
    locking_reason string COMMENT 'Lý do khóa',
    last_login_platform string COMMENT 'Nền tảng login cuối',
    first_login_new_omni_app_at string COMMENT 'Lần đầu login OMNI mới',
    last_login_device_id string COMMENT 'Thiết bị logic lần cuối',
    created_from string COMMENT 'Kênh/Nguồn tạo dịch vụ',
    sale_employee_id string COMMENT 'Mã ID của nhân viên kinh doanh'
) CLUSTER BY AUTO;
ALTER TABLE sat_service_audit ALTER COLUMN omni_service_hashkey SET NOT NULL;
ALTER TABLE sat_service_audit ADD CONSTRAINT sat_service_audit_pk PRIMARY KEY (omni_service_hashkey);

CREATE OR REPLACE TABLE hub_notification (
    notification_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key bigint COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_notification ALTER COLUMN notification_hashkey SET NOT NULL;
ALTER TABLE hub_notification ADD CONSTRAINT hub_notification_pk PRIMARY KEY (notification_hashkey);

CREATE OR REPLACE TABLE link_user_notification (
    link_user_notification_hashkey string COMMENT 'Link Hash Key',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub user_omni',
    notification_hashkey string COMMENT 'Tham chiếu Hub notification',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_user_notification ALTER COLUMN link_user_notification_hashkey SET NOT NULL;
ALTER TABLE link_user_notification ADD CONSTRAINT link_user_notification_pk PRIMARY KEY (link_user_notification_hashkey);

CREATE OR REPLACE TABLE sat_notification (
    notification_hashkey string COMMENT 'Tham chiếu Hub notification',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    created_on string COMMENT 'Ngày tạo thông báo',
    effective_date string COMMENT 'Ngày gửi thông báo',
    severity_level string COMMENT 'Mức độ nghiêm trọng',
    title string COMMENT 'Tiêu đề',
    message string COMMENT 'Tin nhắn',
    acknowledgement_code tinyint COMMENT 'Mã xác nhận'
) CLUSTER BY AUTO;
ALTER TABLE sat_notification ALTER COLUMN notification_hashkey SET NOT NULL;
ALTER TABLE sat_notification ADD CONSTRAINT sat_notification_pk PRIMARY KEY (notification_hashkey);

CREATE OR REPLACE TABLE hub_transfer_bill (
    transfer_bill_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key bigint COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_transfer_bill ALTER COLUMN transfer_bill_hashkey SET NOT NULL;
ALTER TABLE hub_transfer_bill ADD CONSTRAINT hub_transfer_bill_pk PRIMARY KEY (transfer_bill_hashkey);

CREATE OR REPLACE TABLE sat_transfer_bill_information (
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    card_number string COMMENT 'Số thẻ thực hiện giao dịch',
    card_account_num string COMMENT 'Số tài khoản thẻ thực hiện giao dịch',
    method string COMMENT 'Phương thức giao dịch (autobill, manual)',
    service_code string COMMENT 'Dịch vụ',
    provider_code string COMMENT 'Nhà cung cấp',
    description string COMMENT 'Mô tả giao dịch',
    bill_code string COMMENT 'Mã hóa đơn',
    bill_item_no string COMMENT 'Số bill item',
    bill_type string COMMENT 'Loại hóa đơn',
    status string COMMENT 'Trạng thái giao dịch',
    consumption_id string COMMENT 'Mã định danh của giao dịch',
    created_at string COMMENT 'Ngày tạo bill',
    modified_at string COMMENT 'Ngày điều chỉnh'
) CLUSTER BY AUTO;
ALTER TABLE sat_transfer_bill_information ALTER COLUMN transfer_bill_hashkey SET NOT NULL;
ALTER TABLE sat_transfer_bill_information ADD CONSTRAINT sat_transfer_bill_information_pk PRIMARY KEY (transfer_bill_hashkey);

CREATE OR REPLACE TABLE sat_transfer_bill_amount (
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    currency string COMMENT 'Loại tiền',
    amount string COMMENT 'Giá trị thanh toán',
    amount_per_month decimal(38,10) COMMENT 'Giá tiền mỗi tháng',
    quantity bigint COMMENT 'Số lượng'
) CLUSTER BY AUTO;
ALTER TABLE sat_transfer_bill_amount ALTER COLUMN transfer_bill_hashkey SET NOT NULL;
ALTER TABLE sat_transfer_bill_amount ADD CONSTRAINT sat_transfer_bill_amount_pk PRIMARY KEY (transfer_bill_hashkey);

CREATE OR REPLACE TABLE sat_transfer_bill_response (
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    core_response string COMMENT 'Thông tin core trả về',
    core_response_time string COMMENT 'Thời gian core trả về'
) CLUSTER BY AUTO;
ALTER TABLE sat_transfer_bill_response ALTER COLUMN transfer_bill_hashkey SET NOT NULL;
ALTER TABLE sat_transfer_bill_response ADD CONSTRAINT sat_transfer_bill_response_pk PRIMARY KEY (transfer_bill_hashkey);

CREATE OR REPLACE TABLE link_transfer_bill_customer (
    link_transfer_bill_customer_hashkey string COMMENT 'Link Hash Key',
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_bill_customer ALTER COLUMN link_transfer_bill_customer_hashkey SET NOT NULL;
ALTER TABLE link_transfer_bill_customer ADD CONSTRAINT link_transfer_bill_customer_pk PRIMARY KEY (link_transfer_bill_customer_hashkey);

CREATE OR REPLACE TABLE link_transfer_bill_account (
    link_transfer_bill_account_hashkey string COMMENT 'Link Hash Key',
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill (OMNI)',
    account_hashkey string COMMENT 'Tham chiếu Hub account (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_bill_account ALTER COLUMN link_transfer_bill_account_hashkey SET NOT NULL;
ALTER TABLE link_transfer_bill_account ADD CONSTRAINT link_transfer_bill_account_pk PRIMARY KEY (link_transfer_bill_account_hashkey);

CREATE OR REPLACE TABLE link_transfer_bill_payment_order (
    link_transfer_bill_payment_order_hashkey string COMMENT 'Link Hash Key',
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill',
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_bill_payment_order ALTER COLUMN link_transfer_bill_payment_order_hashkey SET NOT NULL;
ALTER TABLE link_transfer_bill_payment_order ADD CONSTRAINT link_transfer_bill_payment_order_pk PRIMARY KEY (link_transfer_bill_payment_order_hashkey);

CREATE OR REPLACE TABLE link_transfer_bill_funds_transfer (
    link_transfer_bill_funds_transfer_hashkey string COMMENT 'Link Hash Key',
    transfer_bill_hashkey string COMMENT 'Tham chiếu Hub transfer_bill (OMNI)',
    funds_transfer_hashkey string COMMENT 'Tham chiếu Hub funds_transfer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_transfer_bill_funds_transfer ALTER COLUMN link_transfer_bill_funds_transfer_hashkey SET NOT NULL;
ALTER TABLE link_transfer_bill_funds_transfer ADD CONSTRAINT link_transfer_bill_funds_transfer_pk PRIMARY KEY (link_transfer_bill_funds_transfer_hashkey);

CREATE OR REPLACE TABLE hub_payment_order (
    payment_order_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_payment_order ALTER COLUMN payment_order_hashkey SET NOT NULL;
ALTER TABLE hub_payment_order ADD CONSTRAINT hub_payment_order_pk PRIMARY KEY (payment_order_hashkey);

CREATE OR REPLACE TABLE sat_payment_order_classification (
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status string COMMENT 'Trạng thái order',
    bank_status string COMMENT 'Trạng thái xử lý core',
    pmt_mode string COMMENT 'Mode thanh toán',
    pmt_type string COMMENT 'Loại giao dịch',
    priority string COMMENT 'Mức ưu tiên',
    role string COMMENT 'Vai trò',
    entry_class string COMMENT 'Phân loại đầu vào',
    intra_legal_entity binary COMMENT 'Nội bộ pháp nhân',
    remaining_occurrences bigint COMMENT 'Số lần còn lại',
    account_scheme string COMMENT 'Định dạng của số tài khoản'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_order_classification ALTER COLUMN payment_order_hashkey SET NOT NULL;
ALTER TABLE sat_payment_order_classification ADD CONSTRAINT sat_payment_order_classification_pk PRIMARY KEY (payment_order_hashkey);

CREATE OR REPLACE TABLE sat_payment_order_information (
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account string COMMENT 'Số tài khoản thực hiện giao dịch',
    name string COMMENT 'Tên tài khoản thực hiện giao dịch',
    amount string COMMENT 'Số tiền chuyển',
    currency string COMMENT 'Loại tiền',
    orig_acc_currency string COMMENT 'Tiền tệ tài khoản gốc',
    send_to_core_datetime string COMMENT 'Thời điểm gửi core',
    delivery_date string COMMENT 'Ngày thực hiện',
    rejection_reason string COMMENT 'Lý do từ chối',
    reason_code string COMMENT 'Mã lý do',
    reason_text string COMMENT 'Mô tả lý do',
    error_description string COMMENT 'Mô tả lỗi',
    address_line1 string COMMENT 'Địa chỉ dòng 1',
    address_line2 string COMMENT 'Địa chỉ dòng 2',
    street_name string COMMENT 'Tên đường',
    town string COMMENT 'Thị trấn',
    country_sub_division string COMMENT 'Tỉnh/Thành phố trực thuộc trung ương',
    post_code string COMMENT 'Mã bưu chính',
    country string COMMENT 'Mã quốc gia',
    arrangement_id string COMMENT 'Mã thỏa thuận',
    ext_arrangement_id string COMMENT 'Mã thỏa thuận từ bên ngoài',
    service_agreement_id string COMMENT 'Mã hợp đồng dịch vụ thanh toán',
    additions string COMMENT 'Thông tin bổ sung',
    payment_setup_id string COMMENT 'Mã thiết lập lệnh thanh toán',
    approval_id string COMMENT 'Mã luồng phê duyệt',
    payment_submission_id string COMMENT 'Mã đẩy lệnh thanh toán',
    confirmation_id string COMMENT 'Mã xác nhận giao dịch',
    bank_reference_id string COMMENT 'Mã tham chiếu ngân hàng'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_order_information ALTER COLUMN payment_order_hashkey SET NOT NULL;
ALTER TABLE sat_payment_order_information ADD CONSTRAINT sat_payment_order_information_pk PRIMARY KEY (payment_order_hashkey);

CREATE OR REPLACE TABLE sat_payment_order_schedule (
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    requested_exec_date string COMMENT 'Ngày yêu cầu thực hiện',
    start_date string COMMENT 'Ngày bắt đầu',
    end_date string COMMENT 'Ngày kết thúc',
    frequency string COMMENT 'Chu kỳ',
    every string COMMENT 'Xử lý hàng ngày',
    when_execute bigint COMMENT 'Thời điểm execute',
    repetition bigint COMMENT 'Số lần lặp',
    remaining_occurrences bigint COMMENT 'Số lần còn lại',
    non_working_day_strategy string COMMENT 'Chiến lược ngày nghỉ',
    created_at string COMMENT 'Thời gian tạo bản ghi',
    created_by string COMMENT 'Mã người tạo bản ghi',
    updated_at string COMMENT 'Thời gian cập nhật bản ghi',
    updated_by string COMMENT 'Mã người cập nhật bản ghi'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_order_schedule ALTER COLUMN payment_order_hashkey SET NOT NULL;
ALTER TABLE sat_payment_order_schedule ADD CONSTRAINT sat_payment_order_schedule_pk PRIMARY KEY (payment_order_hashkey);

CREATE OR REPLACE TABLE link_payment_order_user (
    link_payment_order_user_hashkey string COMMENT 'Link Hash Key',
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub user_omni',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_order_user ALTER COLUMN link_payment_order_user_hashkey SET NOT NULL;
ALTER TABLE link_payment_order_user ADD CONSTRAINT link_payment_order_user_pk PRIMARY KEY (link_payment_order_user_hashkey);

CREATE OR REPLACE TABLE link_payment_order_hierarchy (
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    parent_payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    link_payment_order_hashkey string COMMENT 'Link Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_order_hierarchy ALTER COLUMN link_payment_order_hashkey SET NOT NULL;
ALTER TABLE link_payment_order_hierarchy ADD CONSTRAINT link_payment_order_hierarchy_pk PRIMARY KEY (link_payment_order_hashkey);

CREATE OR REPLACE TABLE link_payment_order_funds_transfer (
    link_payment_order_funds_transfer_hashkey string COMMENT 'Link Hash Key',
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order (OMNI)',
    funds_transfer_hashkey string COMMENT 'Tham chiếu Hub funds_transfer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_order_funds_transfer ALTER COLUMN link_payment_order_funds_transfer_hashkey SET NOT NULL;
ALTER TABLE link_payment_order_funds_transfer ADD CONSTRAINT link_payment_order_funds_transfer_pk PRIMARY KEY (link_payment_order_funds_transfer_hashkey);

CREATE OR REPLACE TABLE link_payment_history_payment_order (
    link_payment_history_payment_order_hashkey string COMMENT 'Link Hash Key',
    payment_history_hashkey string COMMENT 'Tham chiếu Hub payment_history',
    payment_order_hashkey string COMMENT 'Tham chiếu Hub payment_order',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_history_payment_order ALTER COLUMN link_payment_history_payment_order_hashkey SET NOT NULL;
ALTER TABLE link_payment_history_payment_order ADD CONSTRAINT link_payment_history_payment_order_pk PRIMARY KEY (link_payment_history_payment_order_hashkey);

CREATE OR REPLACE TABLE hub_payment_history (
    payment_history_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_payment_history ALTER COLUMN payment_history_hashkey SET NOT NULL;
ALTER TABLE hub_payment_history ADD CONSTRAINT hub_payment_history_pk PRIMARY KEY (payment_history_hashkey);

CREATE OR REPLACE TABLE sat_payment_history_information (
    payment_history_hashkey string COMMENT 'Tham chiếu Hub payment_history',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    description string COMMENT 'Mô tả',
    payment_type string COMMENT 'Loại thanh toán',
    status string COMMENT 'Trạng thái',
    amount bigint COMMENT 'Số tiền chuyển',
    to_account_number string COMMENT 'Số tài khoản nhận',
    to_card_number string COMMENT 'Số thẻ nhận',
    bank_reference_id string COMMENT 'Mã tham chiếu ngân hàng'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_history_information ALTER COLUMN payment_history_hashkey SET NOT NULL;
ALTER TABLE sat_payment_history_information ADD CONSTRAINT sat_payment_history_information_pk PRIMARY KEY (payment_history_hashkey);

CREATE OR REPLACE TABLE link_payment_history_funds_transfer (
    link_payment_history_funds_transfer_hashkey string COMMENT 'Link Hash Key',
    payment_history_hashkey string COMMENT 'Tham chiếu Hub payment_history (OMNI)',
    funds_transfer_hashkey string COMMENT 'Tham chiếu Hub funds_transfer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_history_funds_transfer ALTER COLUMN link_payment_history_funds_transfer_hashkey SET NOT NULL;
ALTER TABLE link_payment_history_funds_transfer ADD CONSTRAINT link_payment_history_funds_transfer_pk PRIMARY KEY (link_payment_history_funds_transfer_hashkey);

CREATE OR REPLACE TABLE link_payment_history_user (
    link_payment_history_omni_user_hashkey string COMMENT 'Link Hash Key',
    payment_history_hashkey string COMMENT 'Tham chiếu Hub payment_history',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub user_omni',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_history_user ALTER COLUMN link_payment_history_omni_user_hashkey SET NOT NULL;
ALTER TABLE link_payment_history_user ADD CONSTRAINT link_payment_history_user_pk PRIMARY KEY (link_payment_history_omni_user_hashkey);

CREATE OR REPLACE TABLE hub_device_omni (
    device_omni_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_device_omni ALTER COLUMN device_omni_hashkey SET NOT NULL;
ALTER TABLE hub_device_omni ADD CONSTRAINT hub_device_omni_pk PRIMARY KEY (device_omni_hashkey);

CREATE OR REPLACE TABLE sat_device_omni_information (
    device_omni_hashkey string COMMENT 'Tham chiếu Hub device_omni',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    friendly_name string COMMENT 'Tên thiết bị',
    vendor string COMMENT 'Hãng sản xuất thiết bị',
    model string COMMENT 'Model thiết bị',
    created_date_time bigint COMMENT 'Thời điểm tạo thiết bị',
    updated_date_time bigint COMMENT 'Thời điểm cập nhật',
    status string COMMENT 'Trạng thái thiết bị',
    platform string COMMENT 'Nền tảng hệ điều hành',
    push_token string COMMENT 'Token push notification'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_omni_information ALTER COLUMN device_omni_hashkey SET NOT NULL;
ALTER TABLE sat_device_omni_information ADD CONSTRAINT sat_device_omni_information_pk PRIMARY KEY (device_omni_hashkey);

CREATE OR REPLACE TABLE sat_device_detail (
    device_omni_hashkey string COMMENT 'Tham chiếu Hub device_omni',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active Business key ( device_detail.id )',
    nfc_enabled tinyint COMMENT 'Thiết bị hỗ trợ NFC hay không',
    omni_version string COMMENT 'Phiên bản ứng dụng',
    os_version string COMMENT 'Hệ điều hành'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_detail ALTER COLUMN device_omni_hashkey SET NOT NULL;
ALTER TABLE sat_device_detail ADD CONSTRAINT sat_device_detail_pk PRIMARY KEY (device_omni_hashkey);

CREATE OR REPLACE TABLE link_device_user (
    link_device_user_hashkey string COMMENT 'Link Hash Key',
    device_omni_hashkey string COMMENT 'Tham chiếu Hub device_omni',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub omni_user',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_device_user ALTER COLUMN link_device_user_hashkey SET NOT NULL;
ALTER TABLE link_device_user ADD CONSTRAINT link_device_user_pk PRIMARY KEY (link_device_user_hashkey);

CREATE OR REPLACE TABLE hub_data_sharing_consent (
    data_sharing_consent_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_data_sharing_consent ALTER COLUMN data_sharing_consent_hashkey SET NOT NULL;
ALTER TABLE hub_data_sharing_consent ADD CONSTRAINT hub_data_sharing_consent_pk PRIMARY KEY (data_sharing_consent_hashkey);

CREATE OR REPLACE TABLE sat_data_sharing_consent_information (
    data_sharing_consent_hashkey string COMMENT 'Tham chiếu hub_data_sharing_consent',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    channel string COMMENT 'Kênh thực hiện consent',
    partner_code string COMMENT 'Đối tác nhận chia sẻ dữ liệu',
    consent_status string COMMENT 'Trạng thái đồng ý chia sẻ dữ liệu',
    os_info string COMMENT 'Thông tin hệ điều hành',
    device_name string COMMENT 'Tên thiết bị',
    user_agent string COMMENT 'User Agent trình duyệt'
) CLUSTER BY AUTO;
ALTER TABLE sat_data_sharing_consent_information ALTER COLUMN data_sharing_consent_hashkey SET NOT NULL;
ALTER TABLE sat_data_sharing_consent_information ADD CONSTRAINT sat_data_sharing_consent_information_pk PRIMARY KEY (data_sharing_consent_hashkey);

CREATE OR REPLACE TABLE link_data_sharing_consent_customer (
    link_data_sharing_consent_customer_hashkey string COMMENT 'Link Hash Key',
    data_sharing_consent_hashkey string COMMENT 'Tham chiếu Hub data_sharing_consent',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_data_sharing_consent_customer ALTER COLUMN link_data_sharing_consent_customer_hashkey SET NOT NULL;
ALTER TABLE link_data_sharing_consent_customer ADD CONSTRAINT link_data_sharing_consent_customer_pk PRIMARY KEY (link_data_sharing_consent_customer_hashkey);

CREATE OR REPLACE TABLE hub_onboarding (
    onboarding_hashkey string COMMENT 'Hub Hash Key (case_key)',
    business_key string COMMENT 'Business Key (case_key)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_onboarding ALTER COLUMN onboarding_hashkey SET NOT NULL;
ALTER TABLE hub_onboarding ADD CONSTRAINT hub_onboarding_pk PRIMARY KEY (onboarding_hashkey);

CREATE OR REPLACE TABLE sat_onboarding_information (
    onboarding_hashkey string COMMENT 'Tham chiếu Hub onboarding',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    step_name string COMMENT 'Tên bước thực hiện',
    report_data string COMMENT 'Dữ liệu báo cáo',
    phone_number string COMMENT 'Số điện thoại',
    email string COMMENT 'Email',
    identity_number string COMMENT 'Số định danh',
    full_name string COMMENT 'Tên đầy đủ',
    created_at string COMMENT 'Thời gian tạo',
    modified_at string COMMENT 'Thời gian cập nhật'
) CLUSTER BY AUTO;
ALTER TABLE sat_onboarding_information ALTER COLUMN onboarding_hashkey SET NOT NULL;
ALTER TABLE sat_onboarding_information ADD CONSTRAINT sat_onboarding_information_pk PRIMARY KEY (onboarding_hashkey);

CREATE OR REPLACE TABLE link_onboarding_customer (
    link_onboarding_customer_hashkey string COMMENT 'Link Hash Key',
    onboarding_hashkey string COMMENT 'Tham chiếu Hub onboarding (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_onboarding_customer ALTER COLUMN link_onboarding_customer_hashkey SET NOT NULL;
ALTER TABLE link_onboarding_customer ADD CONSTRAINT link_onboarding_customer_pk PRIMARY KEY (link_onboarding_customer_hashkey);

CREATE OR REPLACE TABLE link_onboarding_appflyer (
    link_onboarding_appflyer_hashkey string COMMENT 'Link Hash Key',
    onboarding_hashkey string COMMENT 'Tham chiếu Hub onboarding (OMNI)',
    appflyer_hashkey string COMMENT 'Tham chiếu Hub appflyer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_onboarding_appflyer ALTER COLUMN link_onboarding_appflyer_hashkey SET NOT NULL;
ALTER TABLE link_onboarding_appflyer ADD CONSTRAINT link_onboarding_appflyer_pk PRIMARY KEY (link_onboarding_appflyer_hashkey);

CREATE OR REPLACE TABLE hub_voucher (
    voucher_hashkey string COMMENT 'Hub Hash Key (code)',
    business_key string COMMENT 'Business Key (code)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_voucher ALTER COLUMN voucher_hashkey SET NOT NULL;
ALTER TABLE hub_voucher ADD CONSTRAINT hub_voucher_pk PRIMARY KEY (voucher_hashkey);

CREATE OR REPLACE TABLE sat_voucher_information (
    voucher_hashkey string COMMENT 'Tham chiếu Hub voucher',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    service_type_code string COMMENT 'Mã loại dịch vụ áp dụng voucher',
    discount_type string COMMENT 'Loại chiết khấu (PERCENT / FIXED)',
    discount_price int COMMENT 'Giá trị chiết khấu cố định',
    discount_percentage int COMMENT '% chiết khấu',
    max_discount int COMMENT 'Số tiền chiết khấu tối đa',
    min_price_acceptable int COMMENT 'Giá trị đơn hàng tối thiểu',
    refund_liability_account string COMMENT 'Tài khoản kế toán hoàn tiền'
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_information ALTER COLUMN voucher_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_information ADD CONSTRAINT sat_voucher_information_pk PRIMARY KEY (voucher_hashkey);

CREATE OR REPLACE TABLE hub_voucher_campaign (
    voucher_campaign_hashkey string COMMENT 'Hub Hash Key (voucher_campaign_code)',
    business_key string COMMENT 'Business Key (voucher_campaign_code)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_voucher_campaign ALTER COLUMN voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE hub_voucher_campaign ADD CONSTRAINT hub_voucher_campaign_pk PRIMARY KEY (voucher_campaign_hashkey);

CREATE OR REPLACE TABLE sat_voucher_campaign_information (
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hub voucher_campaign',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    voucher_campaign_description string COMMENT 'Mô tả chiến dịch voucher',
    effect_date string COMMENT 'Ngày bắt đầu hiệu lực',
    end_effect_date string COMMENT 'Ngày kết thúc hiệu lực',
    limit_date string COMMENT 'Ngày giới hạn sử dụng',
    import_status string COMMENT 'Trạng thái import chiến dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_campaign_information ALTER COLUMN voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_campaign_information ADD CONSTRAINT sat_voucher_campaign_information_pk PRIMARY KEY (voucher_campaign_hashkey);

CREATE OR REPLACE TABLE sat_voucher_campaign_limit (
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hub voucher_campaign',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    max_quantity_use_voucher int COMMENT 'Số lượt tối đa sử dụng voucher',
    current_used_voucher int COMMENT 'Số lượt đã sử dụng',
    number_generated int COMMENT 'Số voucher đã phát hành',
    budget_limit int COMMENT 'Ngân sách tối đa',
    current_budget int COMMENT 'Ngân sách còn lại',
    refund_account string COMMENT 'Tài khoản hoàn tiền chiến dịch',
    time_pending_refund int COMMENT 'Thời gian chờ hoàn tiền (phút/giờ)'
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_campaign_limit ALTER COLUMN voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_campaign_limit ADD CONSTRAINT sat_voucher_campaign_limit_pk PRIMARY KEY (voucher_campaign_hashkey);

CREATE OR REPLACE TABLE link_voucher_campaign (
    link_voucher_campaign_hashkey string COMMENT 'Link Hash Key',
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hub voucher_campaign',
    voucher_hashkey string COMMENT 'Tham chiếu Hub voucher',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_campaign ALTER COLUMN link_voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE link_voucher_campaign ADD CONSTRAINT link_voucher_campaign_pk PRIMARY KEY (link_voucher_campaign_hashkey);

CREATE OR REPLACE TABLE link_voucher_campaign_user_group (
    link_voucher_campaign_user_group_hashkey string COMMENT 'Link Hash Key',
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hub voucher_campaign',
    user_group_hashkey string COMMENT 'Tham chiếu Hub user_group',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_campaign_user_group ALTER COLUMN link_voucher_campaign_user_group_hashkey SET NOT NULL;
ALTER TABLE link_voucher_campaign_user_group ADD CONSTRAINT link_voucher_campaign_user_group_pk PRIMARY KEY (link_voucher_campaign_user_group_hashkey);

CREATE OR REPLACE TABLE hub_voucher_generate (
    voucher_generate_hashkey string COMMENT 'Tham chiếu Hub Voucher Generate',
    business_key string COMMENT 'Khóa nghiệp vụ (voucher_serial_code)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_voucher_generate ALTER COLUMN voucher_generate_hashkey SET NOT NULL;
ALTER TABLE hub_voucher_generate ADD CONSTRAINT hub_voucher_generate_pk PRIMARY KEY (voucher_generate_hashkey);

CREATE OR REPLACE TABLE sat_voucher_generate_information (
    voucher_generate_hashkey string COMMENT 'Tham chiếu Hub Voucher Generate',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status string COMMENT 'Không dùng ',
    is_show tinyint COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_voucher_generate_information ALTER COLUMN voucher_generate_hashkey SET NOT NULL;
ALTER TABLE sat_voucher_generate_information ADD CONSTRAINT sat_voucher_generate_information_pk PRIMARY KEY (voucher_generate_hashkey);

CREATE OR REPLACE TABLE link_voucher_generate_customer (
    link_voucher_generate_customer_hashkey string COMMENT 'Link Hash Key',
    voucher_generate_hashkey string COMMENT 'Tham chiếu Hub voucher_generate (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub t24_customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_generate_customer ALTER COLUMN link_voucher_generate_customer_hashkey SET NOT NULL;
ALTER TABLE link_voucher_generate_customer ADD CONSTRAINT link_voucher_generate_customer_pk PRIMARY KEY (link_voucher_generate_customer_hashkey);

CREATE OR REPLACE TABLE link_voucher_generate_user (
    link_voucher_generate_omni_user_hashkey string COMMENT 'Link Hash Key',
    voucher_generate_hashkey string COMMENT 'Tham chiếu Hub voucher_generate',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub omni_user',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_generate_user ALTER COLUMN link_voucher_generate_omni_user_hashkey SET NOT NULL;
ALTER TABLE link_voucher_generate_user ADD CONSTRAINT link_voucher_generate_user_pk PRIMARY KEY (link_voucher_generate_omni_user_hashkey);

CREATE OR REPLACE TABLE link_voucher_generate_voucher_campaign (
    link_voucher_generate_voucher_campaign_hashkey string COMMENT 'Link Hash Key',
    voucher_generate_hashkey string COMMENT 'Tham chiếu Hub voucher_generate',
    voucher_campaign_hashkey string COMMENT 'Tham chiếu Hub voucher_campaign',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_voucher_generate_voucher_campaign ALTER COLUMN link_voucher_generate_voucher_campaign_hashkey SET NOT NULL;
ALTER TABLE link_voucher_generate_voucher_campaign ADD CONSTRAINT link_voucher_generate_voucher_campaign_pk PRIMARY KEY (link_voucher_generate_voucher_campaign_hashkey);

CREATE OR REPLACE TABLE hub_party (
    party_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_party ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE hub_party ADD CONSTRAINT hub_party_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE sat_party_information (
    party_hashkey string COMMENT 'Tham chiếu Hub party',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    name string COMMENT 'Tên party',
    alias string COMMENT 'Tên viết tắt / alias',
    contact_person string COMMENT 'Người liên hệ'
) CLUSTER BY AUTO;
ALTER TABLE sat_party_information ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE sat_party_information ADD CONSTRAINT sat_party_information_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE sat_party_classification (
    party_hashkey string COMMENT 'Tham chiếu Hub party',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status string COMMENT 'Trạng thái party',
    category string COMMENT 'Nhóm/Category',
    type string COMMENT 'Loại party (CIF, USER, ORG…)'
) CLUSTER BY AUTO;
ALTER TABLE sat_party_classification ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE sat_party_classification ADD CONSTRAINT sat_party_classification_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE sat_party_business (
    party_hashkey string COMMENT 'Tham chiếu Hub party',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    last_payment_date date COMMENT 'Ngày thanh toán gần nhất',
    last_payment_amount decimal(23,5) COMMENT 'Số tiền thanh toán gần nhất',
    action string COMMENT 'Hoạt động'
) CLUSTER BY AUTO;
ALTER TABLE sat_party_business ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE sat_party_business ADD CONSTRAINT sat_party_business_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE link_party_user (
    link_party_user_hashkey string COMMENT 'Link Hash Key',
    party_hashkey string COMMENT 'Tham chiếu Hub party',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub omni_user',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_party_user ALTER COLUMN link_party_user_hashkey SET NOT NULL;
ALTER TABLE link_party_user ADD CONSTRAINT link_party_user_pk PRIMARY KEY (link_party_user_hashkey);

CREATE OR REPLACE TABLE sat_party_account_information (
    party_hashkey string COMMENT 'Tham chiếu Hub party',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account_number string COMMENT 'Số tài khoản',
    account_type string COMMENT 'Loại tài khoản',
    name string COMMENT 'Tên tài khoản',
    other_identifier string COMMENT 'Định danh bổ sung',
    bank_name string COMMENT 'Tên ngân hàng',
    bank_code string COMMENT 'Mã ngân hàng',
    bic string COMMENT 'Mã BIC',
    iban string COMMENT 'Số IBAN'
) CLUSTER BY AUTO;
ALTER TABLE sat_party_account_information ALTER COLUMN party_hashkey SET NOT NULL;
ALTER TABLE sat_party_account_information ADD CONSTRAINT sat_party_account_information_pk PRIMARY KEY (party_hashkey);

CREATE OR REPLACE TABLE hub_od_registration (
    od_registration_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_od_registration ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE hub_od_registration ADD CONSTRAINT hub_od_registration_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE sat_od_registration_limit (
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    requested_limit_amount decimal(38,2) COMMENT 'Hạn mức yêu cầu',
    approved_limit_amount decimal(38,2) COMMENT 'Hạn mức phê duyệt',
    interest_rate double COMMENT 'Lãi suất'
) CLUSTER BY AUTO;
ALTER TABLE sat_od_registration_limit ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE sat_od_registration_limit ADD CONSTRAINT sat_od_registration_limit_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE sat_od_registration_agreement (
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    contract_file_id string COMMENT 'Mã tệp hợp đồng',
    result_file_id string COMMENT 'Mã tệp kết quả',
    approval_file_id string COMMENT 'Mã tệp phê duyệt',
    contract_bill_code string COMMENT 'Mã hóa đơn hợp đồng',
    first_approval_agreement_uuid string COMMENT 'Mã thỏa thuận phê duyệt lần 1',
    first_approval_bill_code string COMMENT 'Mã hóa đơn phê duyệt lần 1',
    second_approval_agreement_uuid string COMMENT 'Mã thỏa thuận phê duyệt lần 2',
    second_approval_bill_code string COMMENT 'Mã hóa đơn phê duyệt lần 2.',
    ecm_approval_document_id string COMMENT 'ID tài liệu phê duyệt trong ECM',
    ecm_contract_document_id string COMMENT 'ID tài liệu hợp đồng trong ECM',
    prepare_certificate_request_id string COMMENT 'ID yêu cầu chuẩn bị chứng thư'
) CLUSTER BY AUTO;
ALTER TABLE sat_od_registration_agreement ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE sat_od_registration_agreement ADD CONSTRAINT sat_od_registration_agreement_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE sat_od_registration_date (
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    due_date string COMMENT 'Ngày đáo hạn',
    effective_date string COMMENT 'Ngày hiệu lực',
    requested_date string COMMENT 'Ngày yêu cầu',
    issued_date string COMMENT 'Ngày phát hành',
    created_at string COMMENT 'Ngày khởi tạo đăng kí vay thấu chi',
    updated_at string COMMENT 'Ngày updated'
) CLUSTER BY AUTO;
ALTER TABLE sat_od_registration_date ALTER COLUMN od_registration_hashkey SET NOT NULL;
ALTER TABLE sat_od_registration_date ADD CONSTRAINT sat_od_registration_date_pk PRIMARY KEY (od_registration_hashkey);

CREATE OR REPLACE TABLE link_od_registration_customer (
    link_od_registration_customer_hashkey string COMMENT 'Link Hash Key',
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_od_registration_customer ALTER COLUMN link_od_registration_customer_hashkey SET NOT NULL;
ALTER TABLE link_od_registration_customer ADD CONSTRAINT link_od_registration_customer_pk PRIMARY KEY (link_od_registration_customer_hashkey);

CREATE OR REPLACE TABLE link_od_registration_overdraft_account (
    link_od_registration_overdraft_account_hashkey string COMMENT 'Link Hash Key',
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration (OMNI)',
    account_hashkey string COMMENT 'Tham chiếu Hub account (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_od_registration_overdraft_account ALTER COLUMN link_od_registration_overdraft_account_hashkey SET NOT NULL;
ALTER TABLE link_od_registration_overdraft_account ADD CONSTRAINT link_od_registration_overdraft_account_pk PRIMARY KEY (link_od_registration_overdraft_account_hashkey);

CREATE OR REPLACE TABLE link_od_registration_user (
    link_od_registration_omni_user_hashkey string COMMENT 'Link Hash Key',
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub omni_user',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_od_registration_user ALTER COLUMN link_od_registration_omni_user_hashkey SET NOT NULL;
ALTER TABLE link_od_registration_user ADD CONSTRAINT link_od_registration_user_pk PRIMARY KEY (link_od_registration_omni_user_hashkey);

CREATE OR REPLACE TABLE link_od_registration_deposit (
    link_od_registration_deposit_hashkey string COMMENT 'Link Hash Key',
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration (OMNI)',
    deposit_hashkey string COMMENT 'Tham chiếu Hub deposits (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_od_registration_deposit ALTER COLUMN link_od_registration_deposit_hashkey SET NOT NULL;
ALTER TABLE link_od_registration_deposit ADD CONSTRAINT link_od_registration_deposit_pk PRIMARY KEY (link_od_registration_deposit_hashkey);

CREATE OR REPLACE TABLE link_od_registration_bpm (
    link_od_registration_bpm_hashkey string COMMENT 'Link Hash Key',
    od_registration_hashkey string COMMENT 'Tham chiếu Hub od_registration (OMNI)',
    giao_dich_hashkey string COMMENT 'Tham chiếu Hub giao_dich (BPM)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_od_registration_bpm ALTER COLUMN link_od_registration_bpm_hashkey SET NOT NULL;
ALTER TABLE link_od_registration_bpm ADD CONSTRAINT link_od_registration_bpm_pk PRIMARY KEY (link_od_registration_bpm_hashkey);

CREATE OR REPLACE TABLE hub_credit_card_registration (
    credit_card_registration_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key bigint COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_credit_card_registration ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE hub_credit_card_registration ADD CONSTRAINT hub_credit_card_registration_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE sat_credit_card_registration_information (
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    card_limit_approved decimal(38,2) COMMENT 'Hạn mức phê duyệt',
    created_date string COMMENT 'Ngày tạo',
    updated_date string COMMENT 'Ngày updated',
    status string COMMENT 'Trạng thái đăng kí',
    sale_code string COMMENT 'Nhân viên phụ trách',
    personal_rank string COMMENT 'Hạng của khách hàng',
    personal_rank_start string COMMENT 'Ngày bắt đầu có hiệu lực của hạng khách hàng',
    personal_rank_renew string COMMENT 'Ngày xét lại hạng của khách hàng',
    group_personal_rank string COMMENT 'Nhóm hạng',
    card_issuance_type string COMMENT 'Loại phát hành thẻ',
    process_type string COMMENT 'Loại quy trình xử lý',
    policy_groups string COMMENT 'Nhóm chính sách'
) CLUSTER BY AUTO;
ALTER TABLE sat_credit_card_registration_information ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE sat_credit_card_registration_information ADD CONSTRAINT sat_credit_card_registration_information_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE sat_credit_card_registration_customer_info (
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    number_of_dependents int COMMENT 'Số người phụ thuộc',
    job string COMMENT 'Nghề nghiệp',
    company_address string COMMENT 'Địa chỉ công ty',
    company_address_info string COMMENT 'Chi tiết địa chỉ công ty',
    company_name string COMMENT 'Tên công ty',
    type_of_labor_contract string COMMENT 'Loại hình lao động',
    position string COMMENT 'Vị trí',
    working_time string COMMENT 'Thời gian làm việc'
) CLUSTER BY AUTO;
ALTER TABLE sat_credit_card_registration_customer_info ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE sat_credit_card_registration_customer_info ADD CONSTRAINT sat_credit_card_registration_customer_info_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE sat_credit_card_registration_financial_profile (
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    income_method string COMMENT 'Loại hình thu nhập',
    debt_expenses_to_pay_other_credit_institutions decimal(38,2) COMMENT 'Chi phí nợ phải trả cho các tổ chức tín dụng khác',
    real_monthly_income decimal(38,2) COMMENT 'Thu nhập thực hàng tháng',
    living_expenses decimal(38,2) COMMENT 'Chi phí mức sống',
    salary_income decimal(38,2) COMMENT 'Thu nhập từ lương',
    business_income decimal(38,2) COMMENT 'Thu nhập từ kinh doanh',
    vehicle_rental_income decimal(38,2) COMMENT 'Thu nhập từ cho thuê xe',
    real_estate_rental_income decimal(38,2) COMMENT 'Thu nhập từ cho thuê BĐS',
    other_income decimal(38,2) COMMENT 'Thu nhập khác'
) CLUSTER BY AUTO;
ALTER TABLE sat_credit_card_registration_financial_profile ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE sat_credit_card_registration_financial_profile ADD CONSTRAINT sat_credit_card_registration_financial_profile_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE sat_credit_card_registration_introduce (
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    introduce_name string COMMENT 'Tên người giới thiệu',
    introduce_code string COMMENT 'Mã người giới thiệu',
    referral_code string COMMENT 'Mã giới thiệu',
    reference_name string COMMENT 'Tên tham chiếu',
    reference_phone_number string COMMENT 'Số điện thoại tham chiếu'
) CLUSTER BY AUTO;
ALTER TABLE sat_credit_card_registration_introduce ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE sat_credit_card_registration_introduce ADD CONSTRAINT sat_credit_card_registration_introduce_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE sat_credit_card_registration_flow (
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ekyc_type string COMMENT 'Loại EKYC',
    face_liveness_status string COMMENT 'Trạng thái kiểm tra thật khuôn mặt',
    face_matching_status string COMMENT 'Trạng thái đối sánh khuôn mặt với giấy tờ.',
    face_sanity_status string COMMENT 'Trạng thái kiểm tra tính hợp lệ ảnh khuôn mặt',
    id_card_ocr_status string COMMENT 'Trạng thái OCR giấy tờ tùy thân.',
    id_card_sanity_status string COMMENT 'Kiểm tra tính hợp lệ ảnh giấy tờ.',
    in_import_list boolean COMMENT 'Có thuộc danh sách import hay không.',
    signed_contract_file_path string COMMENT 'Đường dẫn file hợp đồng đã ký.',
    contract_file_path string COMMENT 'Đường dẫn file hợp đồng hệ thống tạo.',
    document_id string COMMENT 'ID tài liệu',
    agreement_uuid string COMMENT 'Mã định danh thỏa thuận',
    contract_no string COMMENT 'Số hợp đồng đăng ký thẻ.'
) CLUSTER BY AUTO;
ALTER TABLE sat_credit_card_registration_flow ALTER COLUMN credit_card_registration_hashkey SET NOT NULL;
ALTER TABLE sat_credit_card_registration_flow ADD CONSTRAINT sat_credit_card_registration_flow_pk PRIMARY KEY (credit_card_registration_hashkey);

CREATE OR REPLACE TABLE link_credit_card_registration_customer (
    link_credit_card_registration_customer_hashkey string COMMENT 'Link Hash Key',
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_credit_card_registration_customer ALTER COLUMN link_credit_card_registration_customer_hashkey SET NOT NULL;
ALTER TABLE link_credit_card_registration_customer ADD CONSTRAINT link_credit_card_registration_customer_pk PRIMARY KEY (link_credit_card_registration_customer_hashkey);

CREATE OR REPLACE TABLE link_credit_card_registration_bpm (
    link_credit_card_registration_bpm_hashkey string COMMENT 'Link Hash Key',
    credit_card_registration_hashkey string COMMENT 'Tham chiếu Hub credit_card_registration (OMNI)',
    giao_dich_hashkey string COMMENT 'Tham chiếu Hub giao_dich (BPM)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_credit_card_registration_bpm ALTER COLUMN link_credit_card_registration_bpm_hashkey SET NOT NULL;
ALTER TABLE link_credit_card_registration_bpm ADD CONSTRAINT link_credit_card_registration_bpm_pk PRIMARY KEY (link_credit_card_registration_bpm_hashkey);

CREATE OR REPLACE TABLE hub_oversea_ft_request (
    oversea_ft_request_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key string COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_oversea_ft_request ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE hub_oversea_ft_request ADD CONSTRAINT hub_oversea_ft_request_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE link_oversea_ft_request_user (
    link_oversea_ft_request_omni_user_hashkey string COMMENT 'Link Hash Key',
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub omni_user',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_oversea_ft_request_user ALTER COLUMN link_oversea_ft_request_omni_user_hashkey SET NOT NULL;
ALTER TABLE link_oversea_ft_request_user ADD CONSTRAINT link_oversea_ft_request_user_pk PRIMARY KEY (link_oversea_ft_request_omni_user_hashkey);

CREATE OR REPLACE TABLE link_oversea_ft_request_forex (
    link_oversea_ft_request_forex_hashkey string COMMENT 'Link Hash Key',
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request (OMNI)',
    forex_hashkey string COMMENT 'Tham chiếu Hub Forex',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_oversea_ft_request_forex ALTER COLUMN link_oversea_ft_request_forex_hashkey SET NOT NULL;
ALTER TABLE link_oversea_ft_request_forex ADD CONSTRAINT link_oversea_ft_request_forex_pk PRIMARY KEY (link_oversea_ft_request_forex_hashkey);

CREATE OR REPLACE TABLE link_oversea_ft_request_funds_transfer_charge (
    link_oversea_ft_request_funds_transfer_charge_hashkey string COMMENT 'Link Hash Key',
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request (OMNI)',
    funds_transfer_hashkey string COMMENT 'Tham chiếu Hub funds_transfer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_oversea_ft_request_funds_transfer_charge ALTER COLUMN link_oversea_ft_request_funds_transfer_charge_hashkey SET NOT NULL;
ALTER TABLE link_oversea_ft_request_funds_transfer_charge ADD CONSTRAINT link_oversea_ft_request_funds_transfer_charge_pk PRIMARY KEY (link_oversea_ft_request_funds_transfer_charge_hashkey);

CREATE OR REPLACE TABLE link_oversea_ft_request_account (
    link_oversea_ft_request_account_hashkey string COMMENT 'Link Hash Key',
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request (OMNI)',
    account_hashkey string COMMENT 'Tham chiếu Hub account (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_oversea_ft_request_account ALTER COLUMN link_oversea_ft_request_account_hashkey SET NOT NULL;
ALTER TABLE link_oversea_ft_request_account ADD CONSTRAINT link_oversea_ft_request_account_pk PRIMARY KEY (link_oversea_ft_request_account_hashkey);

CREATE OR REPLACE TABLE sat_oversea_ft_request_information (
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    purpose_code string COMMENT 'Mã mục đích chuyển tiền',
    currency string COMMENT 'Loại tiền tệ yêu cầu',
    req_amount decimal(38,18) COMMENT 'Số tiền yêu cầu',
    req_charge_type string COMMENT 'Loại phí yêu cầu',
    internal_reference string COMMENT 'Mã tham chiếu nội bộ',
    external_id string COMMENT 'Mã định danh hệ thống ngoài',
    external_reference string COMMENT 'Mã tham chiếu hệ thống ngoài',
    status string COMMENT 'Trạng thái của yêu cầu',
    account_number string COMMENT 'Số tài khoản trích tiền',
    account_cur string COMMENT 'Loại tiền tệ của tài khoản',
    contract_limit_id string COMMENT 'Mã định danh hạn mức hợp đồng',
    rm_code string COMMENT 'Mã giám đốc quan hệ khách hàng',
    rm_name string COMMENT 'Tên giám đốc quan hệ khách hàng',
    latest_bpm_comment string COMMENT 'Ghi chú mới nhất từ bpm',
    lasted_bpm_updated_at string COMMENT 'Thời gian cập nhật bpm gần nhất'
) CLUSTER BY AUTO;
ALTER TABLE sat_oversea_ft_request_information ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE sat_oversea_ft_request_information ADD CONSTRAINT sat_oversea_ft_request_information_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE sat_oversea_ft_request_beneficiary (
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ben_name string COMMENT 'Tên người thụ hưởng',
    ben_address string COMMENT 'Địa chỉ người thụ hưởng',
    ben_bank_name string COMMENT 'Tên ngân hàng thụ hưởng',
    ben_bank_code string COMMENT 'Mã ngân hàng thụ hưởng',
    ben_bank_address string COMMENT 'Địa chỉ ngân hàng thụ hưởng',
    ben_account_no string COMMENT 'Số tài khoản người thụ hưởng',
    beneficiary_branch_code string COMMENT 'Mã chi nhánh ngân hàng thụ hưởng'
) CLUSTER BY AUTO;
ALTER TABLE sat_oversea_ft_request_beneficiary ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE sat_oversea_ft_request_beneficiary ADD CONSTRAINT sat_oversea_ft_request_beneficiary_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE sat_oversea_ft_request_related_party (
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    related_name string COMMENT 'Tên bên liên quan',
    related_legal_id_no string COMMENT 'Giấy tờ tùy thân bên liên quan',
    related_address string COMMENT 'Địa chỉ bên liên quan',
    related_relationship_code string COMMENT 'Mã mối quan hệ'
) CLUSTER BY AUTO;
ALTER TABLE sat_oversea_ft_request_related_party ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE sat_oversea_ft_request_related_party ADD CONSTRAINT sat_oversea_ft_request_related_party_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE sat_oversea_ft_request_visa_commit (
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    is_debt_visa_bit string COMMENT 'Cờ đánh dấu nợ visa',
    visa_commit_date string COMMENT 'Ngày cam kết visa',
    visa_commit_id string COMMENT 'Mã định danh cam kết visa',
    visa_commit_reference string COMMENT 'Mã tham chiếu cam kết visa'
) CLUSTER BY AUTO;
ALTER TABLE sat_oversea_ft_request_visa_commit ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE sat_oversea_ft_request_visa_commit ADD CONSTRAINT sat_oversea_ft_request_visa_commit_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE sat_oversea_ft_request_execution (
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    mt103_reference string COMMENT 'Mã điện mt103',
    transferred_amount decimal(38,18) COMMENT 'Số tiền thực tế đã chuyển',
    transferred_cur string COMMENT 'Loại tiền tệ đã chuyển',
    transferred_at string COMMENT 'Thời gian chuyển tiền',
    transferred_status string COMMENT 'Trạng thái chuyển tiền',
    exchange_rate decimal(38,18) COMMENT 'Tỷ giá áp dụng',
    charge_amt_before decimal(38,18) COMMENT 'Số tiền phí trước chiết khấu',
    charge_amt decimal(38,18) COMMENT 'Số tiền phí thực tế',
    charge_type string COMMENT 'Loại phí thực tế',
    discount decimal(38,18) COMMENT 'Số tiền chiết khấu'
) CLUSTER BY AUTO;
ALTER TABLE sat_oversea_ft_request_execution ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE sat_oversea_ft_request_execution ADD CONSTRAINT sat_oversea_ft_request_execution_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE sat_oversea_ft_request_audit (
    oversea_ft_request_hashkey string COMMENT 'Tham chiếu Hub oversea_ft_request',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    created_at string COMMENT 'Thời gian tạo',
    updated_at string COMMENT 'Thời gian cập nhật',
    created_by string COMMENT 'Người tạo',
    updated_by string COMMENT 'Người cập nhật',
    deleted string COMMENT 'Trạng thái xóa'
) CLUSTER BY AUTO;
ALTER TABLE sat_oversea_ft_request_audit ALTER COLUMN oversea_ft_request_hashkey SET NOT NULL;
ALTER TABLE sat_oversea_ft_request_audit ADD CONSTRAINT sat_oversea_ft_request_audit_pk PRIMARY KEY (oversea_ft_request_hashkey);

CREATE OR REPLACE TABLE hub_auto_debit (
    auto_debit_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key bigint COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_auto_debit ALTER COLUMN auto_debit_hashkey SET NOT NULL;
ALTER TABLE hub_auto_debit ADD CONSTRAINT hub_auto_debit_pk PRIMARY KEY (auto_debit_hashkey);

CREATE OR REPLACE TABLE link_auto_debit_customer (
    link_auto_debit_customer_hashkey string COMMENT 'Link Hash Key',
    auto_debit_hashkey string COMMENT 'Tham chiếu Hub auto_debit (OMNI)',
    customer_hashkey string COMMENT 'Tham chiếu Hub customer (T24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_auto_debit_customer ALTER COLUMN link_auto_debit_customer_hashkey SET NOT NULL;
ALTER TABLE link_auto_debit_customer ADD CONSTRAINT link_auto_debit_customer_pk PRIMARY KEY (link_auto_debit_customer_hashkey);

CREATE OR REPLACE TABLE sat_auto_debit_information (
    auto_debit_hashkey string COMMENT 'Tham chiếu Hub auto_debit',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    order_code string COMMENT 'Mã đơn hàng',
    bill_code string COMMENT 'Mã hóa đơn',
    status int COMMENT 'Trạng thái',
    channel string COMMENT 'Kênh giao dịch',
    service_provider_id bigint COMMENT 'Định danh nhà cung cấp dịch vụ',
    service_code string COMMENT 'Mã dịch vụ',
    provider_code string COMMENT 'Mã nhà cung cấp',
    alt_provider_code string COMMENT 'Mã nhà cung cấp thay thế'
) CLUSTER BY AUTO;
ALTER TABLE sat_auto_debit_information ALTER COLUMN auto_debit_hashkey SET NOT NULL;
ALTER TABLE sat_auto_debit_information ADD CONSTRAINT sat_auto_debit_information_pk PRIMARY KEY (auto_debit_hashkey);

CREATE OR REPLACE TABLE sat_auto_debit_customer (
    auto_debit_hashkey string COMMENT 'Tham chiếu Hub auto_debit',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account_number string COMMENT 'Số tài khoản',
    account_name string COMMENT 'Tên tài khoản',
    customer_name string COMMENT 'Tên khách hàng',
    card_number string COMMENT 'Số thẻ',
    card_account_num string COMMENT 'Số tài khoản thẻ'
) CLUSTER BY AUTO;
ALTER TABLE sat_auto_debit_customer ALTER COLUMN auto_debit_hashkey SET NOT NULL;
ALTER TABLE sat_auto_debit_customer ADD CONSTRAINT sat_auto_debit_customer_pk PRIMARY KEY (auto_debit_hashkey);

CREATE OR REPLACE TABLE sat_auto_debit_schedule (
    auto_debit_hashkey string COMMENT 'Tham chiếu Hub auto_debit',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    arrangement_id string COMMENT 'Định danh thỏa thuận thanh toán',
    payment_setting string COMMENT 'Cài đặt thanh toán',
    amount_limit decimal(38,18) COMMENT 'Giới hạn số tiền',
    recurring_period string COMMENT 'Chu kỳ lặp lại',
    finish_date string COMMENT 'Ngày kết thúc',
    payment_date string COMMENT 'Ngày thanh toán'
) CLUSTER BY AUTO;
ALTER TABLE sat_auto_debit_schedule ALTER COLUMN auto_debit_hashkey SET NOT NULL;
ALTER TABLE sat_auto_debit_schedule ADD CONSTRAINT sat_auto_debit_schedule_pk PRIMARY KEY (auto_debit_hashkey);

CREATE OR REPLACE TABLE sat_auto_debit_properties (
    auto_debit_hashkey string COMMENT 'Tham chiếu Hub auto_debit',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    prop1 string COMMENT 'Thuộc tính bổ sung 1',
    prop2 string COMMENT 'Thuộc tính bổ sung 2',
    prop3 decimal(38,18) COMMENT 'Thuộc tính bổ sung 3',
    prop4 bigint COMMENT 'Thuộc tính bổ sung 4',
    prop5 string COMMENT 'Thuộc tính bổ sung 5'
) CLUSTER BY AUTO;
ALTER TABLE sat_auto_debit_properties ALTER COLUMN auto_debit_hashkey SET NOT NULL;
ALTER TABLE sat_auto_debit_properties ADD CONSTRAINT sat_auto_debit_properties_pk PRIMARY KEY (auto_debit_hashkey);

CREATE OR REPLACE TABLE sat_auto_debit_audit (
    auto_debit_hashkey string COMMENT 'Tham chiếu Hub auto_debit',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    is_deleted int COMMENT 'Cờ đánh dấu đã xóa',
    created_at string COMMENT 'Thời gian tạo',
    modified_at string COMMENT 'Thời gian cập nhật',
    created_by string COMMENT 'Người tạo',
    modified_by string COMMENT 'Người cập nhật'
) CLUSTER BY AUTO;
ALTER TABLE sat_auto_debit_audit ALTER COLUMN auto_debit_hashkey SET NOT NULL;
ALTER TABLE sat_auto_debit_audit ADD CONSTRAINT sat_auto_debit_audit_pk PRIMARY KEY (auto_debit_hashkey);

CREATE OR REPLACE TABLE hub_audit_message (
    audit_message_hashkey string COMMENT 'Hub Hash Key (id)',
    business_key bigint COMMENT 'Business Key (id)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_audit_message ALTER COLUMN audit_message_hashkey SET NOT NULL;
ALTER TABLE hub_audit_message ADD CONSTRAINT hub_audit_message_pk PRIMARY KEY (audit_message_hashkey);

CREATE OR REPLACE TABLE link_audit_message_user (
    link_audit_message_user_hashkey string COMMENT 'Link Hash Key',
    audit_message_hashkey string COMMENT 'Tham chiếu Hub audit_message',
    omni_user_hashkey string COMMENT 'Tham chiếu Hub user_omni',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_audit_message_user ALTER COLUMN link_audit_message_user_hashkey SET NOT NULL;
ALTER TABLE link_audit_message_user ADD CONSTRAINT link_audit_message_user_pk PRIMARY KEY (link_audit_message_user_hashkey);

CREATE OR REPLACE TABLE link_audit_message_device (
    link_audit_message_device_hashkey string COMMENT 'Link Hash Key',
    audit_message_hashkey string COMMENT 'Tham chiếu Hub audit_message',
    device_omni_hashkey string COMMENT 'Tham chiếu Hub device_omni',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_audit_message_device ALTER COLUMN link_audit_message_device_hashkey SET NOT NULL;
ALTER TABLE link_audit_message_device ADD CONSTRAINT link_audit_message_device_pk PRIMARY KEY (link_audit_message_device_hashkey);

CREATE OR REPLACE TABLE sat_audit_message_information (
    audit_message_hashkey string COMMENT 'Tham chiếu Hub audit_message',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status string COMMENT 'Trạng thái initiated/successful/failed',
    event_time string COMMENT 'Thời gian thực hiện',
    event_category string COMMENT 'Loại event',
    object_type string COMMENT 'Loại audit',
    event_action string COMMENT 'Loại action',
    event_desc string COMMENT 'Mô tả event',
    message_set_id string COMMENT 'Mã tham chiếu message',
    schema_version int COMMENT 'Phiên bản schema',
    error string COMMENT 'Mô tả lỗi',
    metadata string COMMENT 'Dữ liệu cấu trúc metadata',
    additions string COMMENT 'Thông tin metadata bổ sung',
    temp_legacy_id string COMMENT 'Mã legacy tạm thời',
    day_of_month int COMMENT 'Ngày trong tháng',
    actor_username string COMMENT 'Username của khách hàng',
    legal_entity_id string COMMENT 'Mã pháp nhân',
    sa_id bigint COMMENT 'Mã sa id'
) CLUSTER BY AUTO;
ALTER TABLE sat_audit_message_information ALTER COLUMN audit_message_hashkey SET NOT NULL;
ALTER TABLE sat_audit_message_information ADD CONSTRAINT sat_audit_message_information_pk PRIMARY KEY (audit_message_hashkey);

CREATE OR REPLACE TABLE sat_audit_message_device (
    audit_message_hashkey string COMMENT 'Tham chiếu Hub audit_message',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ip_address string COMMENT 'Địa chỉ IP',
    user_agent string COMMENT 'Thông tin thiết bị người dùng',
    session_id string COMMENT 'Id phiên đăng nhập'
) CLUSTER BY AUTO;
ALTER TABLE sat_audit_message_device ALTER COLUMN audit_message_hashkey SET NOT NULL;
ALTER TABLE sat_audit_message_device ADD CONSTRAINT sat_audit_message_device_pk PRIMARY KEY (audit_message_hashkey);

CREATE OR REPLACE TABLE sat_audit_message_emulator (
    audit_message_hashkey string COMMENT 'Tham chiếu Hub audit_message',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    emulator_user_id string COMMENT 'Mã ID user giả lập',
    emulator_username string COMMENT 'Username giả lập',
    emulator_domain string COMMENT 'Domain giả lập'
) CLUSTER BY AUTO;
ALTER TABLE sat_audit_message_emulator ALTER COLUMN audit_message_hashkey SET NOT NULL;
ALTER TABLE sat_audit_message_emulator ADD CONSTRAINT sat_audit_message_emulator_pk PRIMARY KEY (audit_message_hashkey);

CREATE OR REPLACE TABLE ref_omni_master_data (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    created_at string COMMENT 'Thời điểm tạo bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    updated_at string COMMENT 'Thời điểm cập nhật bản ghi',
    updated_by string COMMENT 'Người cập nhật bản ghi',
    name string COMMENT 'Tên',
    status string COMMENT 'Trạng thái',
    type string COMMENT 'Loại',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_omni_master_data ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_omni_master_data ADD CONSTRAINT ref_omni_master_data_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_omni_package (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    created_at string COMMENT 'Thời điểm tạo bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    updated_at string COMMENT 'Thời điểm cập nhật bản ghi',
    updated_by string COMMENT 'Người cập nhật bản ghi',
    description string COMMENT 'Mô tả',
    status string COMMENT 'Trạng thái',
    can_register_ep_portal tinyint COMMENT 'Cờ cho phép đăng ký trên EP Portal',
    effective_date date COMMENT 'Ngày hiệu lực',
    package_discontinuation_date date COMMENT 'Ngày ngừng cung cấp gói',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_omni_package ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_omni_package ADD CONSTRAINT ref_omni_package_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_omni_service_provider (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    provider_icon string COMMENT 'Icon nhà cung cấp',
    services_id bigint COMMENT 'Mã dịch vụ',
    service_code string COMMENT 'Mã dịch vụ',
    provider_group_code string COMMENT 'Mã nhóm nhà cung cấp',
    provider_group_name string COMMENT 'Tên nhóm nhà cung cấp',
    auto_bill string COMMENT 'Cờ tự động thanh toán hóa đơn',
    title string COMMENT 'Tiêu đề',
    image string COMMENT 'Hình ảnh',
    created_at string COMMENT 'Thời điểm tạo bản ghi',
    modified_at string COMMENT 'Thời điểm cập nhật bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    modified_by string COMMENT 'Người cập nhật bản ghi',
    provider_group_service_id bigint COMMENT 'Mã dịch vụ của nhóm nhà cung cấp',
    prop1 string COMMENT 'Trường thuộc tính dự phòng 1',
    prop2 string COMMENT 'Trường thuộc tính dự phòng 2',
    prop3 decimal(19,2) COMMENT 'Trường thuộc tính dự phòng 3',
    prop4 bigint COMMENT 'Trường thuộc tính dự phòng 4',
    prop5 string COMMENT 'Trường thuộc tính dự phòng 5',
    gateway_id string COMMENT 'Mã cổng thanh toán',
    visible int COMMENT 'Cờ hiển thị',
    allow_credit_card int COMMENT 'Cờ cho phép thẻ tín dụng',
    content_en string COMMENT 'Nội dung (tiếng Anh)',
    content_vi string COMMENT 'Nội dung (tiếng Việt)',
    content_reason string COMMENT 'Nội dung lý do',
    provider_order bigint COMMENT 'Thứ tự nhà cung cấp',
    save_my_bill string COMMENT 'Cờ lưu hóa đơn của tôi',
    module string COMMENT 'Phân hệ',
    group_service string COMMENT 'Nhóm dịch vụ',
    has_fee int COMMENT 'Cờ có phí hay không',
    allow_in_group int COMMENT 'Cờ cho phép hiển thị trong nhóm',
    allow_fav_trans int COMMENT 'Cờ cho phép giao dịch yêu thích',
    alt_provider_code string COMMENT 'Mã nhà cung cấp thay thế',
    alt_gateway_id string COMMENT 'Mã cổng thanh toán thay thế',
    content_ko string COMMENT 'Nội dung (tiếng Hàn)',
    content_ja string COMMENT 'Nội dung (tiếng Nhật)',
    auto_bill_permission tinyint COMMENT 'Quyền tự động thanh toán hóa đơn',
    manual_bill_permission tinyint COMMENT 'Quyền thanh toán hóa đơn thủ công',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_omni_service_provider ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_omni_service_provider ADD CONSTRAINT ref_omni_service_provider_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_omni_services (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    service_icon string COMMENT 'Icon dịch vụ',
    created_at string COMMENT 'Thời điểm tạo bản ghi',
    modified_at string COMMENT 'Thời điểm cập nhật bản ghi',
    created_by string COMMENT 'Người tạo bản ghi',
    modified_by string COMMENT 'Người cập nhật bản ghi',
    prop1 string COMMENT 'Trường thuộc tính dự phòng 1',
    prop2 string COMMENT 'Trường thuộc tính dự phòng 2',
    prop3 decimal(19,2) COMMENT 'Trường thuộc tính dự phòng 3',
    prop4 bigint COMMENT 'Trường thuộc tính dự phòng 4',
    prop5 string COMMENT 'Trường thuộc tính dự phòng 5',
    service_order int COMMENT 'Thứ tự dịch vụ',
    service_code_new string COMMENT 'Mã dịch vụ mới',
    visible int COMMENT 'Cờ hiển thị',
    group_service string COMMENT 'Nhóm dịch vụ',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_omni_services ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_omni_services ADD CONSTRAINT ref_omni_services_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE effsat_link_od_registration_deposit (
    link_od_registration_deposit_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_od_registration_deposit ALTER COLUMN link_od_registration_deposit_hashkey SET NOT NULL;
ALTER TABLE effsat_link_od_registration_deposit ADD CONSTRAINT effsat_link_od_registration_deposit_pk PRIMARY KEY (link_od_registration_deposit_hashkey);

CREATE OR REPLACE TABLE effsat_link_user_notification (
    link_user_notification_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_user_notification ALTER COLUMN link_user_notification_hashkey SET NOT NULL;
ALTER TABLE effsat_link_user_notification ADD CONSTRAINT effsat_link_user_notification_pk PRIMARY KEY (link_user_notification_hashkey);
