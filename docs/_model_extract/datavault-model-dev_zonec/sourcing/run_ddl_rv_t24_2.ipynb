# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE sat_repo_information (
    repo_hashkey string COMMENT 'Tham chiếu Hub Repo',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    contract_status string COMMENT 'Tình trạng hợp đồng',
    trade_date string COMMENT 'Ngày giao dịch',
    value_date string COMMENT 'Ngày hiệu lực',
    maturity_date string COMMENT 'Ngày đến hạn',
    t_st_contract_id string COMMENT 'Số hợp đồng',
    inputter string COMMENT 'Người nhập',
    authoriser string COMMENT 'Người duyệt',
    t_record_status string COMMENT 'Trạng thái bản ghi',
    t_curr_no string COMMENT 'Số lần sửa',
    interest_basis string COMMENT 'Cơ sở tính lãi',
    trans_type string COMMENT 'Loại giao dịch',
    currency string COMMENT 'Loại tiền',
    limit_reference decimal(38,10) COMMENT 'Mã limit',
    mm_contract_id string COMMENT 'Không dùng',
    bank_portfolio string COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_repo_information ALTER COLUMN repo_hashkey SET NOT NULL;
ALTER TABLE sat_repo_information ADD CONSTRAINT sat_repo_information_pk PRIMARY KEY (repo_hashkey);



CREATE OR REPLACE TABLE sat_repo_classification (
    repo_hashkey string COMMENT 'Tham chiếu Hub Repo',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    repo_type string COMMENT 'Repo/Reso',
    product_category string COMMENT 'Mã sản phẩm',
    deal_type string COMMENT 'Loại deal',
    agreement_type string COMMENT 'Thỏa thuận HĐ',
    broker_no string COMMENT 'Mã Broker'
) CLUSTER BY AUTO;
ALTER TABLE sat_repo_classification ALTER COLUMN repo_hashkey SET NOT NULL;
ALTER TABLE sat_repo_classification ADD CONSTRAINT sat_repo_classification_pk PRIMARY KEY (repo_hashkey);



CREATE OR REPLACE TABLE sat_repo_deal (
    repo_hashkey string COMMENT 'Tham chiếu Hub Repo',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    currency string COMMENT 'Loại tiền',
    principal_amount_1 decimal(38,10) COMMENT 'Số tiền 1',
    principal_amount_2 decimal(38,10) COMMENT 'Số tiền 2',
    new_nominal string COMMENT 'Mệnh giá mới',
    repo_rate decimal(38,10) COMMENT 'Lãi suất HĐ repo',
    repo_interest string COMMENT 'Lãi suất',
    dirty_price string COMMENT 'Giá dirty',
    t_clean_price string COMMENT 'Giá clean',
    t_gross_amount string COMMENT 'Tổng tiền',
    t_gross_amt_sec string COMMENT 'Tổng tiền CK',
    accrued_int_amt string COMMENT 'Lãi dồn tích',
    ocb_order_date string COMMENT 'Ngày đặt lệnh OCB',
    send_payment string COMMENT 'Diễn giải',
    t_mm_locref_name string COMMENT 'Tham chiếu MM',
    drawdown_account string COMMENT 'TK rút vốn',
    prin_liq_acct string COMMENT 'TK hoàn trả gốc',
    int_liq_acct string COMMENT 'TK trả lãi',
    new_cu_acct_no string COMMENT 'Tài khoản mới',
    margin_portfolio string COMMENT 'margin porfoio',
    total_settlemnt string COMMENT 'Tổng tiền',
    new_sec_code string COMMENT 'Mã CK'
) CLUSTER BY AUTO;
ALTER TABLE sat_repo_deal ALTER COLUMN repo_hashkey SET NOT NULL;
ALTER TABLE sat_repo_deal ADD CONSTRAINT sat_repo_deal_pk PRIMARY KEY (repo_hashkey);



CREATE OR REPLACE TABLE sat_repo_system (
    repo_hashkey string COMMENT 'Tham chiếu Hub Repo',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    new_depo string COMMENT 'Trường hệ thống',
    business_centre string COMMENT 'Trường hệ thống',
    fwd_settlemnt string COMMENT 'Trường hệ thống',
    fwd_price string COMMENT 'Trường hệ thống',
    fx_rate string COMMENT 'Trường hệ thống',
    new_cu_acct_ccy string COMMENT 'Trường hệ thống',
    capitalisation string COMMENT 'Trường hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_repo_system ALTER COLUMN repo_hashkey SET NOT NULL;
ALTER TABLE sat_repo_system ADD CONSTRAINT sat_repo_system_pk PRIMARY KEY (repo_hashkey);



CREATE OR REPLACE TABLE link_repo_security (
    link_repo_security_hashkey string COMMENT 'Link Hash Key',
    repo_hashkey string COMMENT 'FK tới hub_repo',
    security_hashkey string COMMENT 'FK tới hub_security',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_repo_security ALTER COLUMN link_repo_security_hashkey SET NOT NULL;
ALTER TABLE link_repo_security ADD CONSTRAINT link_repo_security_pk PRIMARY KEY (link_repo_security_hashkey);



CREATE OR REPLACE TABLE link_repo_customer (
    link_repo_customer_hashkey string COMMENT 'Link Hash Key',
    repo_hashkey string COMMENT 'FK tới hub_repo',
    customer_hashkey string COMMENT 'FK tới hub_customer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_repo_customer ALTER COLUMN link_repo_customer_hashkey SET NOT NULL;
ALTER TABLE link_repo_customer ADD CONSTRAINT link_repo_customer_pk PRIMARY KEY (link_repo_customer_hashkey);



CREATE OR REPLACE TABLE link_repo_mm (
    link_repo_mm_hashkey string COMMENT 'Link Hash Key',
    repo_hashkey string COMMENT 'FK tới hub_repo',
    mm_hashkey string COMMENT 'FK tới hub_money_market',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_repo_mm ALTER COLUMN link_repo_mm_hashkey SET NOT NULL;
ALTER TABLE link_repo_mm ADD CONSTRAINT link_repo_mm_pk PRIMARY KEY (link_repo_mm_hashkey);



CREATE OR REPLACE TABLE hub_security (
    security_hashkey string COMMENT 'Security Hash Key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_security ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE hub_security ADD CONSTRAINT hub_security_pk PRIMARY KEY (security_hashkey);



CREATE OR REPLACE TABLE hub_sec_trade (
    sec_trade_hashkey string COMMENT 'Sec Trade Hash Key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_sec_trade ALTER COLUMN sec_trade_hashkey SET NOT NULL;
ALTER TABLE hub_sec_trade ADD CONSTRAINT hub_sec_trade_pk PRIMARY KEY (sec_trade_hashkey);



CREATE OR REPLACE TABLE hub_sc_trading_position (
    sc_trading_position_hashkey string COMMENT 'SC Trading Position Hash Key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_sc_trading_position ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE hub_sc_trading_position ADD CONSTRAINT hub_sc_trading_position_pk PRIMARY KEY (sc_trading_position_hashkey);



CREATE OR REPLACE TABLE sat_security_information (
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_company_name string COMMENT 'Tên chứng khoán',
    t_descript string COMMENT 'Mô tả',
    t_short_name string COMMENT 'Tên viết tắt',
    t_mnemonic string COMMENT 'Tên gợi nhớ',
    t_stock_exchange string COMMENT 'Sàn giao dịch',
    t_issue_date string COMMENT 'Ngày phát hành',
    t_maturity_date string COMMENT 'Ngày đáo hạn',
    t_alt_security_id string COMMENT 'Mã altisin (ID)',
    t_alt_security_no string COMMENT 'Số altisin',
    t_company_domicile string COMMENT 'Quốc gia công ty mẹ',
    t_set_up_date bigint COMMENT 'Ngày setup',
    t_group_partner string COMMENT 'Phân loại partner',
    t_business_pp string COMMENT 'Mục đích',
    t_bss_detail_pp string COMMENT 'Chi tiết mục đích',
    t_sc_ind_internal string COMMENT 'Trường hệ thống',
    t_trading_units string COMMENT 'Quy tắc hệ thống',
    t_margin_control string COMMENT 'Margin',
    t_limit_ref string COMMENT 'Mã limit'
    t_ftp_description string COMMENT 'Mô tả FTP'
) CLUSTER BY AUTO;
ALTER TABLE sat_security_information ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_security_information ADD CONSTRAINT sat_security_information_pk PRIMARY KEY (security_hashkey);



CREATE OR REPLACE TABLE sat_security_classification (
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_bond_or_share string COMMENT 'Phân loại Bond/Share',
    t_quoted_listed_no string COMMENT 'Đã niêm yết? (Y/N)',
    t_sub_asset_type string COMMENT 'Nhóm chứng khoán (mã)',
    t_industry_code string COMMENT 'Mã ngành',
    t_industry_levo string COMMENT 'Ngành nghề (lev0)',
    t_industry_lev1 string COMMENT 'Ngành nghề (lev1)',
    t_industry_lev2 string COMMENT 'Ngành nghề (lev2)',
    t_industry_lev3 string COMMENT 'Ngành nghề (lev3)',
    t_industry_levt string COMMENT 'Ngành nghề (text)',
    t_ocb_ftp_bd_type string COMMENT 'Loại trái phiếu (FTP)',
    t_ocb_ftp_callput string COMMENT 'Loại quyền (Call/Put)',
    t_bond_type_code string COMMENT 'Mã loại bond',
    t_bond_group_code string COMMENT 'Mã nhóm bond',
    t_ftp_fee_repaid string COMMENT 'có thu phí tất toán trước hạn',
    t_ocb_ftp_vlpaper string COMMENT 'có đảm báo bằng GTCG',
    t_ocb_ftp_cifcoll string COMMENT 'cif của TCTD phát hành GTCG'
) CLUSTER BY AUTO;
ALTER TABLE sat_security_classification ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_security_classification ADD CONSTRAINT sat_security_classification_pk PRIMARY KEY (security_hashkey);



CREATE OR REPLACE TABLE sat_security_terms (
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_interest_rate string COMMENT 'Lãi suất',
    t_coupon_method string COMMENT 'Phương thức coupon',
    t_interest_day_basis string COMMENT 'Cơ sở ngày lãi',
    t_no_of_payments string COMMENT 'Số lần trả/năm',
    t_accrual_start_date string COMMENT 'Bắt đầu tính lãi',
    t_add_issue_date string COMMENT 'Ngày issue bổ sung',
    t_rate_ch_date string COMMENT 'Ngày đổi lãi suất',
    t_ocbint_chg_date string COMMENT 'Ngày bắt đầu đổi LS',
    t_ftp_nd_term_int string COMMENT 'Định kỳ đổi LS',
    t_bond_int_rate string COMMENT 'Lãi suất (bond)',
    t_ftp_int_rate_tp string COMMENT 'Loại lãi suất',
    t_int_payment_date string COMMENT 'Ngày trả lãi',
    t_income_date string COMMENT 'Ngày ghi nhận income',
    t_ocb_ftp_frdate string COMMENT 'ngày thực hiện quyền đầu tiên',
    t_ocb_ftp_tright string COMMENT 'định kỳ thực hiện quyền'
) CLUSTER BY AUTO;
ALTER TABLE sat_security_terms ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_security_terms ADD CONSTRAINT sat_security_terms_pk PRIMARY KEY (security_hashkey);



CREATE OR REPLACE TABLE sat_security_pricing (
    security_hashkey string COMMENT 'Tham chiếu Hub Security',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_last_price string COMMENT 'Giá gần nhất',
    t_date_last_price string COMMENT 'Ngày cập nhật giá',
    t_price_currency string COMMENT 'Tiền tệ giá',
    t_price_type string COMMENT 'Kiểu giá',
    t_stk_exch_price string COMMENT 'Giá sàn giao dịch',
    t_par_value string COMMENT 'Mệnh giá',
    t_security_currency string COMMENT 'Loại tiền định danh CK'
) CLUSTER BY AUTO;
ALTER TABLE sat_security_pricing ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sat_security_pricing ADD CONSTRAINT sat_security_pricing_pk PRIMARY KEY (security_hashkey);



CREATE OR REPLACE TABLE sat_sec_trade_information (
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    price_type string COMMENT 'Cách tính giá',
    depository string COMMENT 'Depository',
    trade_date string COMMENT 'Ngày giao dịch',
    value_date string COMMENT 'Ngày hiệu lực',
    market_type string COMMENT 'Loại thị trường',
    cust_trans_code string COMMENT 'Phân loại giao dịch',
    ocb_order_date string COMMENT 'Ngày đặt lệnh',
    cust_nominee string COMMENT 'KH giữ chứng khoán',
    cust_remarks string COMMENT 'Ghi chú',
    cust_act_susp_cat string COMMENT 'Categ KH',
    t_contract_no string COMMENT 'Số hợp đồng',
    t_index_contract string COMMENT 'Hợp đồng chỉ số',
    ocb_altsin string COMMENT 'Mã altisin',
    stock_exchange string COMMENT 'Sàn chứng khoán',
    issue_date string COMMENT 'Ngày issue',
    maturity_date string COMMENT 'Ngày đến hạn',
    cust_sec_acc string COMMENT 'Danh mục chứng khoán',
    cust_acc_no string COMMENT 'Tài khoản KH',
    t_cpty_limit_ref string COMMENT 'Mã limit',
    t_cu_account_ccy string COMMENT 'Loại tiền',
    t_cust_acc_no string COMMENT 'Số tài khoản KH',
    t_value_date_2 string COMMENT 'Ngày hiệu lực',
    trade_ccy string COMMENT 'Loại tiền'
) CLUSTER BY AUTO;
ALTER TABLE sat_sec_trade_information ALTER COLUMN sec_trade_hashkey SET NOT NULL;
ALTER TABLE sat_sec_trade_information ADD CONSTRAINT sat_sec_trade_information_pk PRIMARY KEY (sec_trade_hashkey);



CREATE OR REPLACE TABLE sat_sec_trade_amounts (
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    security_currency string COMMENT 'Loại tiền CK',
    ocb_yield string COMMENT 'Yield',
    cu_gross_am_sec string COMMENT 'Tổng giá trị mua/bán',
    cust_intr_amt string COMMENT 'Giá chứng khoán',
    exch_rate_sec string COMMENT 'Tỷ giá CK',
    exch_rate_trd string COMMENT 'Tỷ giá giao dịch',
    cust_price string COMMENT 'Giá KH',
    cust_tot_nom string COMMENT 'Số tiền giao dịch',
    cu_gross_accr string COMMENT 'Số tiền (accrual)',
    cu_gross_am_trd string COMMENT 'Số tiền giao dịch',
    ocb_int_basic string COMMENT 'Cơ sở tính lãi CP',
    t_cu_net_am_trd string COMMENT 'Net giao dịch',
    t_cu_ex_rate_ref string COMMENT 'Tỷ giá tham chiếu',
    t_cu_amount_due string COMMENT 'Số tiền đến hạn',
    t_ocb_par_value string COMMENT 'Mệnh giá',
    interest_rate decimal(38,10) COMMENT 'Lãi suất',
    cust_no_nom string COMMENT 'Số lượng'
) CLUSTER BY AUTO;
ALTER TABLE sat_sec_trade_amounts ALTER COLUMN sec_trade_hashkey SET NOT NULL;
ALTER TABLE sat_sec_trade_amounts ADD CONSTRAINT sat_sec_trade_amounts_pk PRIMARY KEY (sec_trade_hashkey);



CREATE OR REPLACE TABLE sat_sec_trade_broker (
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_broker_no string COMMENT 'CIF môi giới',
    t_broker_type string COMMENT 'Loại broker',
    t_br_acc_no string COMMENT 'Số TK broker',
    t_br_gross_accr string COMMENT 'Số tiền',
    t_br_gross_am_sec string COMMENT 'Số tiền giao dịch',
    t_br_gross_am_trd string COMMENT 'Số tiền giao dịch',
    t_br_intr_am_trd string COMMENT 'Số tiền giao dịch',
    t_br_no_nom string COMMENT 'Số lượng',
    t_br_price string COMMENT 'Giá',
    t_br_tot_nom string COMMENT 'Tổng số tiền',
    t_br_trans_code string COMMENT 'Phân loại GD (BR)'
) CLUSTER BY AUTO;
ALTER TABLE sat_sec_trade_broker ALTER COLUMN sec_trade_hashkey SET NOT NULL;
ALTER TABLE sat_sec_trade_broker ADD CONSTRAINT sat_sec_trade_broker_pk PRIMARY KEY (sec_trade_hashkey);



CREATE OR REPLACE TABLE sat_sec_trade_system (
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    net_trade string COMMENT 'Trường hệ thống',
    last_paymnt_date string COMMENT 'Ngày trả lãi gần nhất',
    interest_days string COMMENT 'Ngày tính lãi',
    inputter string COMMENT 'Người nhập',
    authoriser string COMMENT 'Người duyệt',
    date_time string COMMENT 'Ngày hệ thống',
    t_record_status string COMMENT 'Trạng thái hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_sec_trade_system ALTER COLUMN sec_trade_hashkey SET NOT NULL;
ALTER TABLE sat_sec_trade_system ADD CONSTRAINT sat_sec_trade_system_pk PRIMARY KEY (sec_trade_hashkey);



CREATE OR REPLACE TABLE sat_sc_trading_position_information (
    sc_trading_position_hashkey string COMMENT 'SC Trading Position Hash Key',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_dealer_book string COMMENT 'Dealer book',
    t_security_ccy string COMMENT 'Loại tiền',
    t_settlement_ccy string COMMENT 'Loại tiền thanh toán',
    t_current_position string COMMENT 'Số dư hiện tại',
    t_consol_trading_bal string COMMENT 'Số dư tổng hợp',
    t_cpn_accr string COMMENT 'Số tiền coupon',
    t_cpn_accr_posted string COMMENT 'Coupon đã hạch toán',
    t_cur_avg_price string COMMENT 'Giá trung bình',
    t_disc_accr_posted string COMMENT 'trường hệ thống',
    t_discount_accrued string COMMENT 'phụ trội, chiết khấu',
    t_cur_cost_position string COMMENT 'Giá trị vị thế',
    t_cur_realized_pl string COMMENT 'Lãi/lỗ đã thực hiện',
    t_reval_unreal_pl string COMMENT 'Lãi/lỗ chưa thực hiện',
    t_revaluation_date string COMMENT 'Ngày đánh giá lại',
    t_date string COMMENT 'Ngày',
    t_date_last_traded string COMMENT 'Giao dịch cuối',
    t_settled_position string COMMENT 'Vị thế đã tất toán',
    t_value_dated_pos string COMMENT 'Vị thế theo ngày value',
    t_v_dated_cpn_accr string COMMENT 'Tích lũy coupon ngày',
    t_v_dated_dis_acc string COMMENT 'Chiết khấu ngày',
    t_v_date_cost_of_pos string COMMENT 'Giá vốn theo ngày',
    t_v_date_real_profit string COMMENT 'Lãi thực theo ngày',
    t_position_key string COMMENT 'Khóa vị thế (src)',
    t_tax_balance string COMMENT 'Thuế (chưa dùng)',
    t_security_code string COMMENT 'Mã security'
) CLUSTER BY AUTO;
ALTER TABLE sat_sc_trading_position_information ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE sat_sc_trading_position_information ADD CONSTRAINT sat_sc_trading_position_information_pk PRIMARY KEY (sc_trading_position_hashkey);



CREATE OR REPLACE TABLE link_security_customer (
    link_security_customer_hashkey string COMMENT 'Link HK',
    security_hashkey string COMMENT 'Security Hash Key',
    customer_hashkey string COMMENT 'CIF phát hành',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_security_customer ALTER COLUMN link_security_customer_hashkey SET NOT NULL;
ALTER TABLE link_security_customer ADD CONSTRAINT link_security_customer_pk PRIMARY KEY (link_security_customer_hashkey);



CREATE OR REPLACE TABLE link_sec_trade_security (
    link_sec_trade_security_hashkey string COMMENT 'Link HK',
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    security_hashkey string COMMENT 'Tham chiếu Hub chứng khoán',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_sec_trade_security ALTER COLUMN link_sec_trade_security_hashkey SET NOT NULL;
ALTER TABLE link_sec_trade_security ADD CONSTRAINT link_sec_trade_security_pk PRIMARY KEY (link_sec_trade_security_hashkey);



CREATE OR REPLACE TABLE link_sec_trade_branch (
    link_sec_trade_branch_hashkey string COMMENT 'Link HK',
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    branch_hashkey string COMMENT 'Tham chiếu Hub branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_sec_trade_branch ALTER COLUMN link_sec_trade_branch_hashkey SET NOT NULL;
ALTER TABLE link_sec_trade_branch ADD CONSTRAINT link_sec_trade_branch_pk PRIMARY KEY (link_sec_trade_branch_hashkey);



CREATE OR REPLACE TABLE link_sec_trade_customer (
    link_sec_trade_customer_hashkey string COMMENT 'Link HK',
    sec_trade_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    customer_hashkey string COMMENT 'Tham chiếu Hub khách hàng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_sec_trade_customer ALTER COLUMN link_sec_trade_customer_hashkey SET NOT NULL;
ALTER TABLE link_sec_trade_customer ADD CONSTRAINT link_sec_trade_customer_pk PRIMARY KEY (link_sec_trade_customer_hashkey);



CREATE OR REPLACE TABLE link_sc_trading_position_security (
    link_sc_trading_position_security_hashkey string COMMENT 'Link HK',
    sc_trading_position_hashkey string COMMENT 'SC Trading Position Hash Key',
    security_hashkey string COMMENT 'Tham chiếu Hub chứng khoán',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_sc_trading_position_security ALTER COLUMN link_sc_trading_position_security_hashkey SET NOT NULL;
ALTER TABLE link_sc_trading_position_security ADD CONSTRAINT link_sc_trading_position_security_pk PRIMARY KEY (link_sc_trading_position_security_hashkey);



CREATE OR REPLACE TABLE link_sc_trading_position_customer (
    link_sc_trading_position_customer_hashkey string COMMENT 'Link HK',
    sc_trading_position_hashkey string COMMENT 'SC Trading Position Hash Key',
    customer_hashkey string COMMENT 'Tham chiếu Hub khách hàng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_sc_trading_position_customer ALTER COLUMN link_sc_trading_position_customer_hashkey SET NOT NULL;
ALTER TABLE link_sc_trading_position_customer ADD CONSTRAINT link_sc_trading_position_customer_pk PRIMARY KEY (link_sc_trading_position_customer_hashkey);



CREATE OR REPLACE TABLE hub_letter_of_credit (
    letter_of_credit_hashkey string COMMENT 'Hub Hash Key LC (kỹ thuật)',
    business_key string COMMENT 'Business Key: Mã LC',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_letter_of_credit ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE hub_letter_of_credit ADD CONSTRAINT hub_letter_of_credit_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE hub_drawings (
    drawings_hashkey string COMMENT 'Hub Hash Key drawings (kỹ thuật)',
    business_key string COMMENT 'Business Key: Mã Bộ chứng từ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_drawings ALTER COLUMN drawings_hashkey SET NOT NULL;
ALTER TABLE hub_drawings ADD CONSTRAINT hub_drawings_pk PRIMARY KEY (drawings_hashkey);



CREATE OR REPLACE TABLE hub_md_deal (
    md_deal_hashkey string COMMENT 'Hub Hash Key bảo lãnh (kỹ thuật)',
    business_key string COMMENT 'Business Key: ID bảo lãnh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_md_deal ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE hub_md_deal ADD CONSTRAINT hub_md_deal_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE sat_letter_of_credit_party (
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_applicant_custno bigint COMMENT 'KH được phát hành LC (mã)',
    t_applicant string COMMENT 'KH được phát hành LC (tên)',
    t_beneficiary_custno bigint COMMENT 'KH thụ hưởng (mã)',
    t_beneficiary string COMMENT 'KH thụ hưởng (tên)',
    t_advise_thru string COMMENT 'Ngân hàng trung gian (tên)',
    t_mt710_57a string COMMENT 'Tham chiếu SWIFT (57A)',
    t_advising_bk_custno string COMMENT 'Mã KH ngân hàng thông báo',
    t_advising_bk string COMMENT 'Tên ngân hàng thông báo',
    t_applicant_bank string COMMENT 'Ngân hàng của applicant',
    t_issuing_bank_no bigint COMMENT 'Mã ngân hàng phát hành',
    t_issuing_bank string COMMENT 'Tên ngân hàng phát hành',
    t_third_party_custno string COMMENT 'Bên thứ ba (mã)',
    t_third_party string COMMENT 'Bên thứ ba (tên)',
    t_external_reference string COMMENT 'Số tham chiếu external',
    t_old_lc_number string COMMENT 'số LC ID quản lý theo qui tắc nghiệp vụ OCB',
    t_link_ld_ref string COMMENT 'Mã LD liên quan',
    t_port_lim_ref string COMMENT 'Mã hạn mức'
) CLUSTER BY AUTO;
ALTER TABLE sat_letter_of_credit_party ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sat_letter_of_credit_party ADD CONSTRAINT sat_letter_of_credit_party_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE sat_letter_of_credit_terms (
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_issue_date string COMMENT 'Ngày phát hành LC',
    t_advice_expiry_date string COMMENT 'Ngày hết hạn (Advice)',
    t_expiry_date string COMMENT 'Ngày hết hạn LC',
    t_closing_date string COMMENT 'Ngày đóng LC',
    t_presenting_date bigint COMMENT 'Ngày xuất trình chứng từ',
    t_tenor string COMMENT 'Thời hạn thanh toán',
    t_drafts_at string COMMENT 'Kỳ hạn hối phiếu (at sight/usance)',
    t_deferred_pay string COMMENT 'Thanh toán trả chậm',
    t_days string COMMENT 'Số ngày usance',
    t_expiry_place string COMMENT 'Nơi hết hạn'
) CLUSTER BY AUTO;
ALTER TABLE sat_letter_of_credit_terms ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sat_letter_of_credit_terms ADD CONSTRAINT sat_letter_of_credit_terms_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE sat_letter_of_credit_value (
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_lc_currency string COMMENT 'Loại tiền LC',
    t_lc_amount decimal(38,10) COMMENT 'Số tiền LC',
    t_credit_provis_acc string COMMENT 'Tài khoản ký quỹ',
    t_provis_amount decimal(38,10) COMMENT 'Số tiền ký quỹ',
    t_liab_port_amt decimal(38,10) COMMENT 'Số dư LC (liability)',
    t_percentage_cr_amt string COMMENT '% ghi Có',
    t_limit_reference string COMMENT 'Mã hạn mức',
    t_percentage_dr_amt string COMMENT '% ghi Nợ',
    t_vmb_ln_class bigint COMMENT 'NA theo mô tả nguồn',
    -- t_ocb_tax_code string COMMENT 'VAT code'
    t_provis_acc string COMMENT 'NA theo mô tả nguồn',
    t_liability_amt decimal(38,10) COMMENT 'NA theo mô tả nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_letter_of_credit_value ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sat_letter_of_credit_value ADD CONSTRAINT sat_letter_of_credit_value_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE sat_letter_of_credit_other (
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub Thư tín dụng',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_vmb_class_date string COMMENT 'Không dùng ',
    t_pro_out_amount decimal(38,10) COMMENT 'Không dùng ',
    t_advise_thru_custno string COMMENT 'Không dùng ',
    t_acp_coll_exp string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_letter_of_credit_other ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sat_letter_of_credit_other ADD CONSTRAINT sat_letter_of_credit_other_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE sat_letter_of_credit_classification (
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_lc_type string COMMENT 'Loại LC',
    t_operation string COMMENT 'Loại nghiệp vụ',
    t_category_code bigint COMMENT 'Mã Category',
    t_industry_levo string COMMENT 'Mã ngành kinh tế (lev0)',
    t_industry_levt string COMMENT 'Mã ngành kinh tế (levT)',
    t_industry_lev1 string COMMENT 'Mã ngành kinh tế (lev1)',
    t_industry_lev2 string COMMENT 'Mã ngành kinh tế (lev2)',
    t_industry_lev3 string COMMENT 'Mã ngành kinh tế (lev3)',
    t_country_code string COMMENT 'Quốc gia (mã)'
) CLUSTER BY AUTO;
ALTER TABLE sat_letter_of_credit_classification ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sat_letter_of_credit_classification ADD CONSTRAINT sat_letter_of_credit_classification_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE sat_letter_of_credit_system (
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_record_status string COMMENT 'Trạng thái bản ghi (hệ thống)',
    t_inputter string COMMENT 'Người nhập (hệ thống)',
    t_authoriser string COMMENT 'Người duyệt (hệ thống)',
    t_date_time string COMMENT 'Ngày/giờ thao tác (hệ thống)'
) CLUSTER BY AUTO;
ALTER TABLE sat_letter_of_credit_system ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sat_letter_of_credit_system ADD CONSTRAINT sat_letter_of_credit_system_pk PRIMARY KEY (letter_of_credit_hashkey);



CREATE OR REPLACE TABLE sat_drawings_information (
    drawings_hashkey string COMMENT 'Tham chiếu Hub Drawings',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_drawing_type string COMMENT 'Loại thanh toán BCT',
    t_draw_currency string COMMENT 'Loại tiền của BCT',
    t_document_amount decimal(38,10) COMMENT 'Số tiền trên bộ chứng từ',
    t_payment_amount string COMMENT 'Số tiền thực thanh toán BCT',
    t_value_date string COMMENT 'Ngày giá trị',
    t_presenting_date string COMMENT 'Ngày thanh toán/nộp BCT',
    t_adv_mat_date string COMMENT 'Ngày hết hạn (advice)',
    t_maturity_review string COMMENT 'Ngày hết hạn (review)',
    t_payment_method string COMMENT 'Phương thức thanh toán',
    t_discrepancy string COMMENT 'Điều khoản bất hợp lệ',
    t_presentor_cust string COMMENT 'Mã KH nộp BCT',
    t_presentor string COMMENT 'Tên KH nộp BCT',
    t_payment_account string COMMENT 'TK thực hiện thanh toán',
    t_link_ld_ref string COMMENT 'Số LD liên quan'
) CLUSTER BY AUTO;
ALTER TABLE sat_drawings_information ALTER COLUMN drawings_hashkey SET NOT NULL;
ALTER TABLE sat_drawings_information ADD CONSTRAINT sat_drawings_information_pk PRIMARY KEY (drawings_hashkey);



CREATE OR REPLACE TABLE sat_drawings_other (
    drawings_hashkey string COMMENT 'Tham chiếu Hub Chứng từ rút vốn',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ben_draw_amt decimal(38,10) COMMENT 'Không dùng ',
    t_drawdown_account string COMMENT 'Không dùng ',
    t_reimburse_amount string COMMENT 'Không dùng ',
    t_presentor_reference string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_drawings_other ALTER COLUMN drawings_hashkey SET NOT NULL;
ALTER TABLE sat_drawings_other ADD CONSTRAINT sat_drawings_other_pk PRIMARY KEY (drawings_hashkey);



CREATE OR REPLACE TABLE sat_drawings_system (
    drawings_hashkey string COMMENT 'Tham chiếu Hub Drawings',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_record_status string COMMENT 'Trạng thái bản ghi (hệ thống)',
    t_inputter string COMMENT 'Người nhập (hệ thống)',
    t_authoriser string COMMENT 'Người duyệt (hệ thống)'
) CLUSTER BY AUTO;
ALTER TABLE sat_drawings_system ALTER COLUMN drawings_hashkey SET NOT NULL;
ALTER TABLE sat_drawings_system ADD CONSTRAINT sat_drawings_system_pk PRIMARY KEY (drawings_hashkey);



CREATE OR REPLACE TABLE sat_md_deal_information (
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_currency string COMMENT 'Loại tiền bảo lãnh',
    t_deal_date string COMMENT 'Ngày phát hành bảo lãnh',
    t_value_date string COMMENT 'Ngày hiệu lực bảo lãnh',
    t_maturity_date string COMMENT 'Ngày hết hạn bảo lãnh',
    t_deal_sub_type string COMMENT 'Loại bảo lãnh',
    t_category bigint COMMENT 'Category bảo lãnh',
    t_reference_1 string COMMENT 'Số/Tham chiếu 1',
    t_reference_2 string COMMENT 'Số/Tham chiếu 2',
    t_text_1 string COMMENT 'Nội dung cam kết',
    t_text_2 string COMMENT 'Nội dung cam kết 2',
    t_no_def_exp string COMMENT 'Bảo lãnh không xác định thời hạn',
    t_local_oversea string COMMENT 'Trong nước/Nước ngoài',
    t_ocb_serial_no string COMMENT 'Số serial phôi BL',
    t_ocb_ser_no_main string COMMENT 'Số serial phôi tu chỉnh',
    t_benef_cust_1 string COMMENT 'Tên KH thụ hưởng 1',
    t_benef_cust_2 string COMMENT 'Tên KH thụ hưởng 2',
    t_ben_address string COMMENT 'Địa chỉ/Người thụ hưởng',
    t_bank_address string COMMENT 'Địa chỉ ngân hàng nhận',
    t_status string COMMENT 'Trạng thái bản ghi',
    t_advice_expiry_date string COMMENT 'Ngày đáo hạn thông báo',
    t_country_risk string COMMENT 'Mã rủi ro quốc gia',
    t_country_exposure string COMMENT 'Mã mức độ phơi nhiễm quốc gia',
    t_receiving_bank string COMMENT 'Ngân hàng nhận',
    t_overdue_status string COMMENT 'Trạng thái quá hạn',
    t_charge_account string COMMENT 'Tài khoản thu phí',
    t_ocb_charge_acct string COMMENT 'Tài khoản thu phí',
    t_fut_real_est string COMMENT 'BL bán/cho thuê nhà ở hình thành ở TL',
    t_prod_promo string COMMENT 'Mã gói KM',
    t_bpm_disb_id string COMMENT 'Mã giao dịch BPM',
    t_limit_reference string COMMENT 'Mã hạn mức liên quan'
) CLUSTER BY AUTO;
ALTER TABLE sat_md_deal_information ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sat_md_deal_information ADD CONSTRAINT sat_md_deal_information_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE sat_md_deal_other (
    md_deal_hashkey string COMMENT 'Tham chiếu Hub MD Deal',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_alternate_id string COMMENT 'Không dùng ',
    t_csn_amount string COMMENT 'Không dùng ',
    t_limit_amount string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_md_deal_other ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sat_md_deal_other ADD CONSTRAINT sat_md_deal_other_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE sat_md_deal_value (
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_principal_amount decimal(38,10) COMMENT 'Số tiền bảo lãnh',
    t_inv_amount string COMMENT 'Số tiền đầu tư/liên quan',
    t_ocb_online_amt string COMMENT 'Số tiền online (OCB)',
    t_charge_date string COMMENT 'Ngày thu phí',
    t_charge_curr string COMMENT 'Loại tiền phí',
    t_charge_account string COMMENT 'Tài khoản thu phí',
    t_charge_code string COMMENT 'Mã phí',
    t_charge_amt decimal(38,10) COMMENT 'Số tiền phí',
    t_ocb_avg_fee decimal(38,10) COMMENT 'Phí thu bình quân',
    t_ocb_charge string COMMENT 'Phí bảo lãnh',
    t_ocb_charge_acct string COMMENT 'TK thu phí (OCB)',
    t_ocb_col_dt_spec string COMMENT 'Thời điểm thu phí đặc biệt',
    t_ocb_coll_period string COMMENT 'Chu kỳ thu phí',
    t_ocb_estim_due_d string COMMENT 'Ngày ước tính đến hạn phí',
    t_ocb_fee_adjust decimal(38,10) COMMENT 'Phí tăng/giảm',
    t_ocb_fee_end_dat string COMMENT 'Ngày kết thúc thu phí',
    t_ocb_gtee_fee decimal(38,10) COMMENT 'Số tiền phí bảo lãnh',
    t_ocb_gtee_letter string COMMENT 'Loại mẫu thư',
    t_ocb_letter_fee decimal(38,10) COMMENT 'Phí mẫu thư bảo lãnh',
    t_ocb_m_fee_rate decimal(38,10) COMMENT 'Tỷ lệ phí ký quỹ',
    t_ocb_mgn_amount decimal(38,10) COMMENT 'Số tiền ký quỹ',
    t_ocb_nonm_fee_r1 decimal(38,10) COMMENT 'Mức phí tín chấp',
    t_ocb_nonm_fee_r2 decimal(38,10) COMMENT 'Mức phí có TSBĐ',
    t_ocb_nonmargin1 bigint COMMENT 'Số tiền BL tín chấp',
    t_ocb_nonmargin2 bigint COMMENT 'Số tiền BL có TSBĐ',
    t_ocb_per_collect string COMMENT 'Định kỳ thu phí',
    t_ocb_sch_date string COMMENT 'Ngày trả phí',
    t_ocb_sch_code string COMMENT 'Mã thu phí',
    t_ocb_sch_amt string COMMENT 'Số tiền phí kỳ',
    t_ocb_sch_ccy string COMMENT 'Loại tiền phí kỳ',
    t_ocb_sch_acc string COMMENT 'Tài khoản thu phí kỳ',
    t_ocb_sch_rem string COMMENT 'Ghi chú kỳ phí',
    t_prin_movement string COMMENT 'Biến động gốc',
    t_ocb_secured1 string COMMENT 'Loại bảo đảm tín chấp',
    t_ocb_secured2 string COMMENT 'Loại bảo đảm có tài sản',
    t_ocb_tot_fee decimal(38,10) COMMENT 'Tổng phí phát hành phải thu từng kỳ'
) CLUSTER BY AUTO;
ALTER TABLE sat_md_deal_value ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sat_md_deal_value ADD CONSTRAINT sat_md_deal_value_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE sat_md_deal_provision (
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_include_provision string COMMENT 'Có trích lập dự phòng?',
    t_provision string COMMENT 'Thông tin dự phòng',
    t_prov_dr_account string COMMENT 'Tài khoản hạch toán DR dự phòng',
    t_prov_percent bigint COMMENT 'Tỷ lệ dự phòng',
    t_prov_amount decimal(38,10) COMMENT 'Số tiền dự phòng'
) CLUSTER BY AUTO;
ALTER TABLE sat_md_deal_provision ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sat_md_deal_provision ADD CONSTRAINT sat_md_deal_provision_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE sat_md_deal_classification (
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_liquidation_mode string COMMENT 'Phương thức xử lý quá hạn',
    t_portfolio_no string COMMENT 'Số portfolio',
    t_md_purpose string COMMENT 'Mã mục đích bảo lãnh',
    t_md_pp_detail string COMMENT 'Mã mục đích chi tiết',
    t_contract_type string COMMENT 'Loại hợp đồng',
    t_industry_levo string COMMENT 'Ngành KT cấp 1',
    t_industry_levt string COMMENT 'Ngành KT cấp 2',
    t_industry_lev1 string COMMENT 'Ngành KT cấp 3',
    t_industry_lev2 string COMMENT 'Ngành KT cấp 4',
    t_industry_lev3 string COMMENT 'Ngành KT cấp 5',
    t_inv_status string COMMENT 'Trạng thái đầu tư/liên quan',
    t_movement_date string COMMENT 'Ngày biến động'
) CLUSTER BY AUTO;
ALTER TABLE sat_md_deal_classification ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sat_md_deal_classification ADD CONSTRAINT sat_md_deal_classification_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE sat_md_deal_system (
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'Người nhập (hệ thống)',
    t_authoriser string COMMENT 'Người duyệt (hệ thống)',
    t_date_time string COMMENT 'Ngày/giờ thao tác (hệ thống)',
    t_events_processing string COMMENT 'Cơ chế cập nhật',
    t_limit_upd_reqd string COMMENT 'Cờ yêu cầu cập nhật hạn mức',
    t_auto_expiry string COMMENT 'Hết hạn tự động?'
) CLUSTER BY AUTO;
ALTER TABLE sat_md_deal_system ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sat_md_deal_system ADD CONSTRAINT sat_md_deal_system_pk PRIMARY KEY (md_deal_hashkey);



CREATE OR REPLACE TABLE link_letter_of_credit_customer (
    link_letter_of_credit_customer_hashkey string COMMENT 'Link Hash Key',
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    customer_hashkey string COMMENT 'Tham chiếu Hub KH (customer)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_letter_of_credit_customer ALTER COLUMN link_letter_of_credit_customer_hashkey SET NOT NULL;
ALTER TABLE link_letter_of_credit_customer ADD CONSTRAINT link_letter_of_credit_customer_pk PRIMARY KEY (link_letter_of_credit_customer_hashkey);



CREATE OR REPLACE TABLE link_letter_of_credit_branch (
    link_letter_of_credit_branch_hashkey string COMMENT 'Link Hash Key',
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    branch_hashkey string COMMENT 'Tham chiếu Hub Chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_letter_of_credit_branch ALTER COLUMN link_letter_of_credit_branch_hashkey SET NOT NULL;
ALTER TABLE link_letter_of_credit_branch ADD CONSTRAINT link_letter_of_credit_branch_pk PRIMARY KEY (link_letter_of_credit_branch_hashkey);



CREATE OR REPLACE TABLE link_letter_of_credit_dept_acct_officer (
    link_letter_of_credit_dept_acct_officer_hashkey string COMMENT 'Link Hash Key',
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NV quản lý',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_letter_of_credit_dept_acct_officer ALTER COLUMN link_letter_of_credit_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_letter_of_credit_dept_acct_officer ADD CONSTRAINT link_letter_of_credit_dept_acct_officer_pk PRIMARY KEY (link_letter_of_credit_dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE link_letter_of_credit_limit (
    link_letter_of_credit_limit_hashkey string COMMENT 'Link Hash Key (HASH(HK_LC, HK_LIMIT))',
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    limit_hashkey string COMMENT 'Tham chiếu Hub Limit (portfolio)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_letter_of_credit_limit ALTER COLUMN link_letter_of_credit_limit_hashkey SET NOT NULL;
ALTER TABLE link_letter_of_credit_limit ADD CONSTRAINT link_letter_of_credit_limit_pk PRIMARY KEY (link_letter_of_credit_limit_hashkey);



CREATE OR REPLACE TABLE link_letter_of_credit_loans (
    link_letter_of_credit_loans_hashkey string COMMENT 'Link Hash Key (HASH(HK_LC, HK_LOANS))',
    letter_of_credit_hashkey string COMMENT 'Tham chiếu Hub LC',
    loans_hashkey string COMMENT 'Tham chiếu Hub LD',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_letter_of_credit_loans ALTER COLUMN link_letter_of_credit_loans_hashkey SET NOT NULL;
ALTER TABLE link_letter_of_credit_loans ADD CONSTRAINT link_letter_of_credit_loans_pk PRIMARY KEY (link_letter_of_credit_loans_hashkey);



CREATE OR REPLACE TABLE link_drawings_letter_of_credit (
    link_drawings_letter_of_credit_hashkey string COMMENT 'Link Hash Key',
    drawings_hashkey string COMMENT 'Hub Hash Key drawings (kỹ thuật)',
    letter_of_credit_hashkey string COMMENT 'Hub Hash Key LC (kỹ thuật)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_drawings_letter_of_credit ALTER COLUMN link_drawings_letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE link_drawings_letter_of_credit ADD CONSTRAINT link_drawings_letter_of_credit_pk PRIMARY KEY (link_drawings_letter_of_credit_hashkey);



CREATE OR REPLACE TABLE link_md_deal_customer (
    link_md_deal_customer_hashkey string COMMENT 'Link Hash Key',
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    customer_hashkey string COMMENT 'Tham chiếu Hub KH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_md_deal_customer ALTER COLUMN link_md_deal_customer_hashkey SET NOT NULL;
ALTER TABLE link_md_deal_customer ADD CONSTRAINT link_md_deal_customer_pk PRIMARY KEY (link_md_deal_customer_hashkey);



CREATE OR REPLACE TABLE link_md_deal_branch (
    link_md_deal_branch_hashkey string COMMENT 'Link Hash Key',
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    branch_hashkey string COMMENT 'Tham chiếu Hub Chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_md_deal_branch ALTER COLUMN link_md_deal_branch_hashkey SET NOT NULL;
ALTER TABLE link_md_deal_branch ADD CONSTRAINT link_md_deal_branch_pk PRIMARY KEY (link_md_deal_branch_hashkey);



CREATE OR REPLACE TABLE link_md_deal_dept_acct_officer (
    link_md_deal_dept_acct_officer_hashkey string COMMENT 'Link Hash Key',
    md_deal_hashkey string COMMENT 'Tham chiếu Hub bảo lãnh',
    dept_acct_officer_hashkey string COMMENT 'Tham chiếu Hub NVBH',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_md_deal_dept_acct_officer ALTER COLUMN link_md_deal_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_md_deal_dept_acct_officer ADD CONSTRAINT link_md_deal_dept_acct_officer_pk PRIMARY KEY (link_md_deal_dept_acct_officer_hashkey);



CREATE OR REPLACE TABLE hub_funds_transfer (
    funds_transfer_hashkey string COMMENT 'Hash Key giao dịch (kỹ thuật)',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_funds_transfer ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE hub_funds_transfer ADD CONSTRAINT hub_funds_transfer_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE hub_teller (
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_teller ALTER COLUMN teller_hashkey SET NOT NULL;
ALTER TABLE hub_teller ADD CONSTRAINT hub_teller_pk PRIMARY KEY (teller_hashkey);



CREATE OR REPLACE TABLE hub_clearing_citad (
    clearing_citad_hashkey string COMMENT 'Hub Hashkey Clearing Citad',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_clearing_citad ALTER COLUMN clearing_citad_hashkey SET NOT NULL;
ALTER TABLE hub_clearing_citad ADD CONSTRAINT hub_clearing_citad_pk PRIMARY KEY (clearing_citad_hashkey);



CREATE OR REPLACE TABLE sat_funds_transfer_information (
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_transaction_type string COMMENT 'Loại giao dịch',
    t_record_status string COMMENT 'Trạng thái bản ghi --Trường hệ thống',
    t_ocb_cont_value string COMMENT 'Loại tiền hợp đồng',
    t_ocb_tot_val_use string COMMENT 'Giá trị hợp đồng',
    t_ocb_value_use string COMMENT 'Giá trị đã sử dụng',
    t_ocb_contract_no string COMMENT 'Giá trị thanh toán',
    t_online_ref_id string COMMENT 'Mã giao dịch online liên quan',
    t_debit_value_date string COMMENT 'Ngày giá trị nợ',
    t_debit_amount decimal(38,10) COMMENT 'Số tiền ghi nợ',
    t_amount_debited string COMMENT 'Số tiền ghi nợ',
    t_loc_amt_debited decimal(38,10) COMMENT 'Số tiền ghi nợ đã được quy đổi ra VNĐ',
    t_debit_their_ref string COMMENT 'Tham chiếu Nợ',
    t_credit_value_date string COMMENT 'Ngày giá trị có',
    t_credit_amount decimal(38,10) COMMENT 'Số tiền ghi có',
    t_amount_credited string COMMENT 'Số tiền ghi có',
    t_loc_amt_credited decimal(38,10) COMMENT 'Số tiền ghi có đã được quy đổi ra VNĐ',
    t_credit_their_ref string COMMENT 'Tham chiếu có',
    t_payment_details string COMMENT 'Nội dung chuyển khoản',
    t_debit_currency string COMMENT 'Loại tiền ghi nợ',
    t_credit_currency string COMMENT 'Loại tiền ghi có',
    t_clearing_id string COMMENT 'Mã điện do hệ thống tự sinh',
    t_debit_acct_no string COMMENT 'Tài khoản ghi nợ',
    t_credit_acct_no string COMMENT 'Tài khoản ghi có'
) CLUSTER BY AUTO;
ALTER TABLE sat_funds_transfer_information ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE sat_funds_transfer_information ADD CONSTRAINT sat_funds_transfer_information_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE sat_funds_transfer_account (
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_acct_with_bank_acc string COMMENT 'TKNH thụ hưởng tại NHTG',
    t_sub_va_id string COMMENT 'Mã TK định danh',
    t_in_ben_acct_no string COMMENT 'Số TK người nhận',
    t_ordering_ac string COMMENT 'Không thấy có trong bảng FT',
    t_ben_acct_no string COMMENT 'TK thụ hưởng',
    t_acct_with_bank string COMMENT 'NH giữ TK người thụ hưởng'
) CLUSTER BY AUTO;
ALTER TABLE sat_funds_transfer_account ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE sat_funds_transfer_account ADD CONSTRAINT sat_funds_transfer_account_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE sat_funds_transfer_fee (
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_commission_type string COMMENT 'Loại hoa hồng',
    t_commission_code string COMMENT 'Mã hoa hồng',
    t_commission_amt string COMMENT 'Số tiền hoa hồng',
    t_processing_date string COMMENT 'Ngày hạch toán',
    t_classify_code string COMMENT 'Mã giá trị cao/thấp',
    t_is_tct string COMMENT 'Chuyển tiền thanh toán Tổng cục thuế (Y/N) ?',
    t_user_type string COMMENT 'Loại KH khi xét thu phí',
    t_total_charge_amt string COMMENT 'Tổng tiền phí',
    t_total_tax_amount string COMMENT 'Tổng tiền VAT',
    t_charges_acct_no string COMMENT 'Số TK chịu phí'
) CLUSTER BY AUTO;
ALTER TABLE sat_funds_transfer_fee ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE sat_funds_transfer_fee ADD CONSTRAINT sat_funds_transfer_fee_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE sat_funds_transfer_party (
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_r_ci_code string COMMENT 'Mã chi nhánh ngân hàng nhận',
    t_bidv_recvrbank string COMMENT 'Ngân hàng nhận lệnh chuyển tiền BIDV',
    t_bidv_benbkcode string COMMENT 'Mã chi nhánh ngân hàng nhận',
    t_bidv_senderbank string COMMENT 'Mã ngân hàng chuyển lệnh chuyển tiền BIDV',
    t_in_ben_customer string COMMENT 'Tên người nhận',
    t_ordering_cust string COMMENT 'KH gửi (người phát lệnh với yc này)',
    t_ben_customer string COMMENT 'KH thụ hưởng',
    t_ben_our_charges string COMMENT 'Bên thanh toán các khoản phí giao dịch',
    t_ocb_o_ci_code string COMMENT 'Mã NH chuyển',
    t_ocb_o_ci_name string COMMENT 'Tên NH chuyển',
    t_inw_send_bic string COMMENT 'Mã BIC NH chuyển đến',
    t_intermed_bank string COMMENT 'NH trung gian',
    t_ben_bank_branch string COMMENT 'Mã chi nhánh ngân hàng nhận',
    t_ordering_bank string COMMENT 'NH nhận yêu cầu',
    t_cu_d_ord_cpt string COMMENT 'Thông tin KH yêu cầu (dùng cho chuyển tiền nước ngoài)',
    t_profit_centre_cust string COMMENT 'KH cho thu nhập'
) CLUSTER BY AUTO;
ALTER TABLE sat_funds_transfer_party ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE sat_funds_transfer_party ADD CONSTRAINT sat_funds_transfer_party_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE sat_funds_transfer_other (
    funds_transfer_hashkey string COMMENT 'Hash Key giao dịch (kỹ thuật)',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_ocb_tax_code string COMMENT 'Mã số thuế KH (nếu có)',
    t_ocb_bank_id string COMMENT 'Mã ngân hàng',
    t_ocb_smartlink string COMMENT 'Mã ID thanh toán qua smartlink',
    t_ocb_ld_htls string COMMENT 'FT có liên quan LD hỗ trợ lãi suất',
    t_ocb_term_htls string COMMENT 'Kỳ thu lãi',
    t_ocb_ben_acct string COMMENT 'TK nhận',
    t_ocb_ben_cust string COMMENT 'Không thấy có trong bảng FT',
    t_ocb_r_ci_name string COMMENT 'Tên NH nhận',
    t_ocb_li_cont_id string COMMENT 'Mã hạn mức hợp đồng',
    t_ocb_contra_ccy string COMMENT 'Loại tiền hợp đồng',
    t_bk_to_bk_out string COMMENT 'Dùng để gửi hướng dẫn hoặc thông tin bổ sung',
    t_ben_name string COMMENT 'Không thấy có trong bảng FT',
    t_ocb_channel string COMMENT 'Kênh thực hiện',
    t_ocb_billi_code string COMMENT 'Mã bill thanh toán',
    t_bc_bank_sort_code string COMMENT 'Mã NH bù trừ',
    t_charge_code string COMMENT 'Không dùng ',
    t_sending_addr string COMMENT 'Địa chỉ gửi',
    t_msg_narrative string COMMENT 'Nội dung giao dịch',
    t_is_prepay string COMMENT 'Phải lệnh hoàn trả (Y/N) ?',
    t_receiving_addr string COMMENT 'Địa chỉ nhận',
    t_border_trans string COMMENT 'Giao dịch biên mậu',
    t_eft_country string COMMENT 'Quốc gia chuyển tiền đến',
    t_in_ordering_bk string COMMENT 'Trường hệ thống (No input field)',
    t_in_ben_name string COMMENT 'Trường hệ thống (No input field)',
    t_tax_code string COMMENT 'Mã số thuế của người chuyển tiền',
    t_at_auth_code string COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_funds_transfer_other ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE sat_funds_transfer_other ADD CONSTRAINT sat_funds_transfer_other_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE sat_funds_transfer_system (
    funds_transfer_hashkey string COMMENT 'Hash Key giao dịch (kỹ thuật)',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'user nhập',
    t_authoriser string COMMENT 'user duyệt',
    t_mkfile_com string COMMENT 'CN tạo file',
    t_message_type string COMMENT 'Trường hệ thống - No input field',
    t_user_input string COMMENT 'User nhập --Trường hệ thống',
    t_user_auth string COMMENT 'User duyệt--Trường hệ thống',
    t_trans_unique_id string COMMENT 'Mã do hệ thống tự sinh',
    t_stmt_nos string COMMENT 'Trường hệ thống (No input field)',
    t_ft_out_purpose string COMMENT 'Mã UNC được hoàn tiền',
    t_in_swift_msg string COMMENT 'Trường hệ thống (No input field)',
    t_date_time string COMMENT 'Ngày giờ ps giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_funds_transfer_system ALTER COLUMN funds_transfer_hashkey SET NOT NULL;
ALTER TABLE sat_funds_transfer_system ADD CONSTRAINT sat_funds_transfer_system_pk PRIMARY KEY (funds_transfer_hashkey);



CREATE OR REPLACE TABLE sat_teller_information (
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_dr_cr_marker string COMMENT 'TK nợ 1 là TK ghi nợ hay ghi có',
    t_currency_1 string COMMENT 'Mã ngoại tệ tài khoản 1',
    t_amount_local_1 string COMMENT 'Số tiền nội tệ 1',
    t_amount_fcy_1 string COMMENT 'Số tiền ngoại tệ 1',
    t_rate_1 decimal(38,10) COMMENT 'Tỷ giá 1',
    t_narrative_1 string COMMENT 'Nội dung giao dịch TK 1',
    t_value_date_1 string COMMENT 'Ngày giá trị TK 1',
    t_currency_2 string COMMENT 'Mã ngoại tệ TK 2',
    t_amount_local_2 string COMMENT 'Số tiền nội tệ 2',
    t_amount_fcy_2 string COMMENT 'Số tiền ngoại tệ 2',
    t_rate_2 decimal(38,10) COMMENT 'Tỷ giá 2',
    t_narrative_2 string COMMENT 'Nội dung giao dịch TK 2',
    t_value_date_2 string COMMENT 'Ngày giá trị TK 2',
    t_record_status string COMMENT 'Trạng thái bản ghi',
    t_transaction_code bigint COMMENT 'Mã loại giao dịch TT',
    sales_person bigint COMMENT 'Mã NV Sale',
    t_date_time string COMMENT 'Ngày giờ nhập duyệt',
    t_account_1 string COMMENT 'Tài khoản 1',
    t_account_2 string COMMENT 'Tài khoản 2'
) CLUSTER BY AUTO;
ALTER TABLE sat_teller_information ALTER COLUMN teller_hashkey SET NOT NULL;
ALTER TABLE sat_teller_information ADD CONSTRAINT sat_teller_information_pk PRIMARY KEY (teller_hashkey);



CREATE OR REPLACE TABLE sat_teller_vat (
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_contact_name string COMMENT 'Tên người liên hệ',
    t_tax_code string COMMENT 'Mã số thuế',
    t_vat_form string COMMENT 'Mẫu hóa đơn',
    t_vat_inv_serial string COMMENT 'Số hóa đơn',
    t_vat_inv_code string COMMENT 'Ký hiệu hóa đơn',
    t_nat_id_type string COMMENT 'Loại giấy tờ',
    t_national_id string COMMENT 'Số giấy tờ',
    t_nat_place_iss string COMMENT 'Nơi cấp giấy tờ',
    t_nat_iss_date string COMMENT 'Ngày cấp giấy tờ',
    t_vat_goods string COMMENT 'Tên mặt hàng VAT',
    t_vat_rate decimal(38,10) COMMENT 'Thuế suất',
    t_vat_inv_date string COMMENT 'Ngày phát hành hóa đơn',
    t_net_amount decimal(38,10) COMMENT 'Số tiền',
    t_charge_account string COMMENT 'Tài khoản thu phí',
    t_charge_category string COMMENT 'Mã PL thu phí',
    t_chrg_amt_local string COMMENT 'Số tiền phí nội tệ',
    t_cust_id string COMMENT 'Mã KH VAT',
    t_cheque_number string COMMENT 'Số séc'
) CLUSTER BY AUTO;
ALTER TABLE sat_teller_vat ALTER COLUMN teller_hashkey SET NOT NULL;
ALTER TABLE sat_teller_vat ADD CONSTRAINT sat_teller_vat_pk PRIMARY KEY (teller_hashkey);



CREATE OR REPLACE TABLE sat_teller_other (
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_inputter string COMMENT 'Người nhập',
    t_authoriser string COMMENT 'Người duyệt',
    t_ocb_comp_rece string COMMENT 'Không có thông tin',
    t_ocb_class_rece string COMMENT 'Không có thông tin',
    t_ocb_class_amt string COMMENT 'Không có thông tin',
    t_trans_unique_id string COMMENT 'Mã giao dịch ID từ hệ thống khác',
    t_sub_va_id string COMMENT 'Tài khoản ảo'
) CLUSTER BY AUTO;
ALTER TABLE sat_teller_other ALTER COLUMN teller_hashkey SET NOT NULL;
ALTER TABLE sat_teller_other ADD CONSTRAINT sat_teller_other_pk PRIMARY KEY (teller_hashkey);



CREATE OR REPLACE TABLE sat_clearing_citad_payment_information (
    clearing_citad_hashkey string COMMENT 'Tham chiếu Hub Clearing Citad',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_trans_date string COMMENT 'Ngày giao dịch',
    t_currency string COMMENT 'Loại tiền',
    t_amount string COMMENT 'Số tiền',
    t_sending_name string COMMENT 'Tên người gửi',
    t_sending_addr string COMMENT 'Địa chỉ người gửi',
    t_receiving_name string COMMENT 'Tên người nhận',
    t_receiving_addr string COMMENT 'Địa chỉ người nhận',
    t_ben_acct_no string COMMENT 'TK thụ hưởng',
    t_payment_details string COMMENT 'Nội dung chuyển tiền',
    t_debit_acct_no string COMMENT 'TK nợ',
    t_credit_acct_no string COMMENT 'TK có',
    t_o_ci_code string COMMENT 'Mã NH chuyển',
    t_r_ci_code string COMMENT 'Mã NH nhận',
    t_o_pci_code string COMMENT 'Mã NH chuyển gián tiếp',
    t_r_pci_code string COMMENT 'Mã NH nhận gián tiếp',
    t_txn_ref string COMMENT 'Mã FT liên quan',
    t_stmt_no string COMMENT 'Mã STMT',
    t_trans_ref string COMMENT 'Mã FT liên quan'
) CLUSTER BY AUTO;
ALTER TABLE sat_clearing_citad_payment_information ALTER COLUMN clearing_citad_hashkey SET NOT NULL;
ALTER TABLE sat_clearing_citad_payment_information ADD CONSTRAINT sat_clearing_citad_payment_information_pk PRIMARY KEY (clearing_citad_hashkey);



CREATE OR REPLACE TABLE sat_clearing_citad_other (
    clearing_citad_hashkey string COMMENT 'Tham chiếu Hub Clearing Citad',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_trans_code string COMMENT 'Không dùng ',
    t_operation_1 string COMMENT 'Không dùng ',
    t_operation_2 string COMMENT 'Không dùng ',
    t_susp_account string COMMENT 'Không dùng ',
    t_his_status string COMMENT 'Không dùng ',
    t_user_auth string COMMENT 'Không dùng ',
    t_receipt_date string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_clearing_citad_other ALTER COLUMN clearing_citad_hashkey SET NOT NULL;
ALTER TABLE sat_clearing_citad_other ADD CONSTRAINT sat_clearing_citad_other_pk PRIMARY KEY (clearing_citad_hashkey);



CREATE OR REPLACE TABLE sat_clearing_citad_classification (
    clearing_citad_hashkey string COMMENT 'Tham chiếu Hub Clearing Citad',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    t_file_name string COMMENT 'Tên file điện',
    t_user_input string COMMENT 'User nhập',
    t_in_out string COMMENT 'Chiều đi / chiều đến',
    t_msg_kind string COMMENT 'Loại điện',
    t_application string COMMENT 'Loại ứng dụng (FT)',
    t_process_dt string COMMENT 'Tình trạng',
    t_status string COMMENT 'Ngày thực hiện',
    t_currency string COMMENT 'Loại tiền',
    t_mkfile_com string COMMENT 'Chi nhánh tạo file',
    t_com_co string COMMENT 'Mã chi nhánh'
) CLUSTER BY AUTO;
ALTER TABLE sat_clearing_citad_classification ALTER COLUMN clearing_citad_hashkey SET NOT NULL;
ALTER TABLE sat_clearing_citad_classification ADD CONSTRAINT sat_clearing_citad_classification_pk PRIMARY KEY (clearing_citad_hashkey);



CREATE OR REPLACE TABLE link_funds_transfer_debit_customer (
    link_funds_transfer_debit_customer_hashkey string COMMENT 'Link Hash Key',
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    customer_hashkey string COMMENT 'Hash Key khách hàng ghi nợ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_funds_transfer_debit_customer ALTER COLUMN link_funds_transfer_debit_customer_hashkey SET NOT NULL;
ALTER TABLE link_funds_transfer_debit_customer ADD CONSTRAINT link_funds_transfer_debit_customer_pk PRIMARY KEY (link_funds_transfer_debit_customer_hashkey);



CREATE OR REPLACE TABLE link_funds_transfer_credit_customer (
    link_funds_transfer_credit_customer_hashkey string COMMENT 'Link Hash Key',
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    customer_hashkey string COMMENT 'Hash Key khách hàng ghi có',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_funds_transfer_credit_customer ALTER COLUMN link_funds_transfer_credit_customer_hashkey SET NOT NULL;
ALTER TABLE link_funds_transfer_credit_customer ADD CONSTRAINT link_funds_transfer_credit_customer_pk PRIMARY KEY (link_funds_transfer_credit_customer_hashkey);



CREATE OR REPLACE TABLE link_funds_transfer_debit_account (
    link_funds_transfer_debit_account_hashkey string COMMENT 'Link Hash Key',
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    account_hashkey string COMMENT 'Hash Key tài khoản nợ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_funds_transfer_debit_account ALTER COLUMN link_funds_transfer_debit_account_hashkey SET NOT NULL;
ALTER TABLE link_funds_transfer_debit_account ADD CONSTRAINT link_funds_transfer_debit_account_pk PRIMARY KEY (link_funds_transfer_debit_account_hashkey);



CREATE OR REPLACE TABLE link_funds_transfer_credit_account (
    link_funds_transfer_credit_account_hashkey string COMMENT 'Link Hash Key',
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    account_hashkey string COMMENT 'Hash Key tài khoản có',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_funds_transfer_credit_account ALTER COLUMN link_funds_transfer_credit_account_hashkey SET NOT NULL;
ALTER TABLE link_funds_transfer_credit_account ADD CONSTRAINT link_funds_transfer_credit_account_pk PRIMARY KEY (link_funds_transfer_credit_account_hashkey);



CREATE OR REPLACE TABLE link_funds_transfer_branch (
    link_funds_transfer_branch_hashkey string COMMENT 'Link Hash Key',
    funds_transfer_hashkey string COMMENT 'Hash key giao dịch',
    branch_hashkey string COMMENT 'Hash Key Chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_funds_transfer_branch ALTER COLUMN link_funds_transfer_branch_hashkey SET NOT NULL;
ALTER TABLE link_funds_transfer_branch ADD CONSTRAINT link_funds_transfer_branch_pk PRIMARY KEY (link_funds_transfer_branch_hashkey);



CREATE OR REPLACE TABLE link_teller_customer1 (
    link_teller_customer1_hashkey string COMMENT 'Link Hash Key',
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    customer_hashkey string COMMENT 'Hash Key khách hàng 1',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_teller_customer1 ALTER COLUMN link_teller_customer1_hashkey SET NOT NULL;
ALTER TABLE link_teller_customer1 ADD CONSTRAINT link_teller_customer1_pk PRIMARY KEY (link_teller_customer1_hashkey);



CREATE OR REPLACE TABLE link_teller_customer2 (
    link_teller_customer2_hashkey string COMMENT 'Link Hash Key',
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    customer_hashkey string COMMENT 'Hash Key khách hàng 2',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_teller_customer2 ALTER COLUMN link_teller_customer2_hashkey SET NOT NULL;
ALTER TABLE link_teller_customer2 ADD CONSTRAINT link_teller_customer2_pk PRIMARY KEY (link_teller_customer2_hashkey);



CREATE OR REPLACE TABLE link_teller_account1 (
    link_teller_account1_hashkey string COMMENT 'Link Hash Key',
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    account_hashkey string COMMENT 'Hash Key mã tài khoản 1',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_teller_account1 ALTER COLUMN link_teller_account1_hashkey SET NOT NULL;
ALTER TABLE link_teller_account1 ADD CONSTRAINT link_teller_account1_pk PRIMARY KEY (link_teller_account1_hashkey);



CREATE OR REPLACE TABLE link_teller_account2 (
    link_teller_account2_hashkey string COMMENT 'Link Hash Key',
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    account_hashkey string COMMENT 'Hash Key mã tài khoản 2',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_teller_account2 ALTER COLUMN link_teller_account2_hashkey SET NOT NULL;
ALTER TABLE link_teller_account2 ADD CONSTRAINT link_teller_account2_pk PRIMARY KEY (link_teller_account2_hashkey);



CREATE OR REPLACE TABLE link_teller_branch (
    link_teller_branch_hashkey string COMMENT 'Link Hash Key',
    teller_hashkey string COMMENT 'Teller Hash Key (từ BK)',
    branch_hashkey string COMMENT 'Hash Key chi nhánh',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_teller_branch ALTER COLUMN link_teller_branch_hashkey SET NOT NULL;
ALTER TABLE link_teller_branch ADD CONSTRAINT link_teller_branch_pk PRIMARY KEY (link_teller_branch_hashkey);



CREATE OR REPLACE TABLE link_funds_transfer_clearing_citad (
    link_funds_transfer_clearing_citad_hashkey string COMMENT 'Link HK',
    funds_transfer_hashkey string COMMENT 'Tham chiếu Hub Funds Transfer',
    clearing_citad_hashkey string COMMENT 'Tham chiếu Hub Clearing Citad',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_funds_transfer_clearing_citad ALTER COLUMN link_funds_transfer_clearing_citad_hashkey SET NOT NULL;
ALTER TABLE link_funds_transfer_clearing_citad ADD CONSTRAINT link_funds_transfer_clearing_citad_pk PRIMARY KEY (link_funds_transfer_clearing_citad_hashkey);



CREATE OR REPLACE TABLE ref_holiday (
    ref_holiday_hashkey string COMMENT 'Mã quốc gia và năm',
    year string COMMENT 'Năm',
    t_january string COMMENT 'Ngày nghỉ lễ công trong tháng 1',
    t_february string COMMENT 'Ngày nghỉ lễ công trong tháng 2',
    t_march string COMMENT 'Ngày nghỉ lễ công trong tháng 3',
    t_april string COMMENT 'Ngày nghỉ lễ công trong tháng 4',
    t_may string COMMENT 'Ngày nghỉ lễ công trong tháng 5',
    t_june string COMMENT 'Ngày nghỉ lễ công trong tháng 6',
    t_july string COMMENT 'Ngày nghỉ lễ công trong tháng 7',
    t_august string COMMENT 'Ngày nghỉ lễ công trong tháng 8',
    t_september string COMMENT 'Ngày nghỉ lễ công trong tháng 9',
    t_october string COMMENT 'Ngày nghỉ lễ công trong tháng 10',
    t_november string COMMENT 'Ngày nghỉ lễ công trong tháng 11',
    t_december string COMMENT 'Ngày nghỉ lễ công trong tháng 12',
    t_weekend_days string COMMENT 'Ký hiệu các ngày cuối tuần không làm việc theo Quốc gia',
    t_mth_01_table string COMMENT 'Ký hiệu những ngày trong tháng 1 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_02_table string COMMENT 'Ký hiệu những ngày trong tháng 2 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_03_table string COMMENT 'Ký hiệu những ngày trong tháng 3 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_04_table string COMMENT 'Ký hiệu những ngày trong tháng 4 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_05_table string COMMENT 'Ký hiệu những ngày trong tháng 5 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_06_table string COMMENT 'Ký hiệu những ngày trong tháng 6 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_07_table string COMMENT 'Ký hiệu những ngày trong tháng 7 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_08_table string COMMENT 'Ký hiệu những ngày trong tháng 8 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_09_table string COMMENT 'Ký hiệu những ngày trong tháng 9 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_10_table string COMMENT 'Ký hiệu những ngày trong tháng 10 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_11_table string COMMENT 'Ký hiệu những ngày trong tháng 11 gồm những ngày làm việc và những ngày không làm việc.',
    t_mth_12_table string COMMENT 'Ký hiệu những ngày trong tháng 12 gồm những ngày làm việc và những ngày không làm việc.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;



CREATE OR REPLACE TABLE ref_t24_az_product_parameter (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_ALLOWED_CATEG bigint COMMENT 'Nhóm tài khoản được phép áp dụng',
    T_DR_TXN_CODE bigint COMMENT 'Mã giao dịch ghi nợ',
    T_CR_TXN_CODE bigint COMMENT 'Mã giao dịch ghi có',
    T_INT_BASIS string COMMENT 'Cơ số tính lãi',
    T_MINIMUM_TERM string COMMENT 'Số tiền gửi tối thiểu',
    T_MAXIMUM_TERM string COMMENT 'Số tiền gửi tối đa',
    T_PERIODIC_RATE_KEY string COMMENT 'Key lãi suất',
    T_MATURITY_INSTR string COMMENT 'Hình thức tái tục',
    T_RECORD_STATUS string COMMENT 'Trạng thái bản ghi',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'User nhập',
    T_AUTHORISER string COMMENT 'User duyệt',
    T_DATE_TIME string COMMENT 'Ngày thực hiện',
    T_CO_CODE string COMMENT 'Mã Chi nhánh',
    T_LOAN_DEPOSIT string COMMENT 'Loại tiền gửi/tiền vay',
    T_PROD_END_DATE string COMMENT 'Ngày bắt đầu',
    T_PROD_START_DATE string COMMENT 'Ngày kết thúc',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_az_product_parameter ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_az_product_parameter ADD CONSTRAINT ref_t24_az_product_parameter_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_basic_interest (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_INTEREST_RATE decimal(38,10) COMMENT 'Lãi suất',
    T_RECORD_STATUS string COMMENT 'Trạng thái',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'Người duyệt',
    T_DATE_TIME string COMMENT 'Ngày giờ duyệt',
    T_CO_CODE string COMMENT 'Mã chi nhánh',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_basic_interest ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_basic_interest ADD CONSTRAINT ref_t24_basic_interest_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_bc_sort_code (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_TELEPHONE_NO string COMMENT 'Kênh tham gia CITAD/VCB/BIDV',
    T_IDENTITY_KIND string COMMENT 'Mã trực tiếp/gián tiếp áp dụng đi CITAD',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_bc_sort_code ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_bc_sort_code ADD CONSTRAINT ref_t24_bc_sort_code_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_category (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SHORT_NAME string COMMENT 'Tên phân loại viết tắt',
    T_PRODUCT string COMMENT 'Không dùng',
    T_PROD_ID bigint COMMENT 'Mã sản phẩm',
    T_CO_VAT string COMMENT 'Không dùng',
    T_TYPE_BUSINESS string COMMENT 'Không dùng',
    T_IS_MAND string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_category ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_category ADD CONSTRAINT ref_t24_category_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_collateral_code (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_COLLATERAL_CODE bigint COMMENT 'Mã loại tài sản bảo đảm',
    T_SHORT_NAME string COMMENT 'Tên viết tắt',
    T_COLLATERAL_TYPE string COMMENT 'Phân loại TSĐB',
    T_RECORD_STATUS string COMMENT 'Trạng thái',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'Người duyệt',
    T_DATE_TIME string COMMENT 'Ngày nhập',
    T_CO_CODE string COMMENT 'Mã chi nhánh',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_collateral_code ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_collateral_code ADD CONSTRAINT ref_t24_collateral_code_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_collateral_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_COLLATERAL_TYPE bigint COMMENT 'Loại tài sản bảo đảm',
    T_APPLICATION string COMMENT 'Module áp dụng',
    T_APPLICATION_INPUT string COMMENT 'Tham số nhập trường Application_ID trong TSĐB(( M: bắt buộc/O không bắt buộc/N: không được nhập)',
    T_NOMINAL_VALUE string COMMENT 'Tham số giá trị định giá( M: bắt buộc/O không bắt buộc)',
    T_EXECUTION_VALUE string COMMENT 'Tham số giá trị định giá( M: bắt buộc/O không bắt buộc)',
    T_GEN_LEDGER_VALUE string COMMENT 'Qui  định của Giá trị  Ghi sổ = X% của giá trị định giá',
    T_CENTRAL_BANK_VALUE string COMMENT 'Qui  định của Giá trị  b.cáo NHNN = X% của giá trị định giá',
    T_THIRD_PARTY_VALUE string COMMENT 'Tham số giá trị định giá( M: bắt buộc/O không bắt buộc)',
    T_RECORD_STATUS string COMMENT 'Trạng thái record',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'Người duyệt',
    T_DATE_TIME string COMMENT 'Ngày nhập',
    T_CO_CODE string COMMENT 'Mã chi nhánh',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_collateral_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_collateral_type ADD CONSTRAINT ref_t24_collateral_type_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_company (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày báo cáo',
    T_MNEMONIC string COMMENT 'Tên tắt',
    T_CONSOLIDATION_MARK string COMMENT 'Không dùng',
    T_DEFAULT_NO_OF_AUTH string COMMENT 'Không dùng',
    T_PGM_AUTOM_ID string COMMENT 'Không dùng',
    T_APPLICATIONS string COMMENT 'Không dùng',
    T_TAX_CODE string COMMENT 'Không dùng',
    T_FINANCIAL_YEAR_END string COMMENT 'Không dùng',
    T_SUB_DIVISION_CODE string COMMENT 'Không dùng',
    T_OFFICIAL_HOLIDAY string COMMENT 'Không dùng',
    T_BRANCH_HOLIDAY string COMMENT 'Không dùng',
    T_BATCH_HOLIDAY string COMMENT 'Không dùng',
    T_NAME_ADDRESS string COMMENT 'Không dùng',
    T_LANGUAGE_CODE string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_company ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_company ADD CONSTRAINT ref_t24_company_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_country (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SHORT_NAME string COMMENT 'Tên quốc gia viết tắt',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_country ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_country ADD CONSTRAINT ref_t24_country_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_currency (
    ID string COMMENT 'Mã loại tiền',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_NUMERIC_CCY_CODE bigint COMMENT 'Mã loại tiền bằng số',
    T_CCY_NAME string COMMENT 'Tên loại tiền',
    T_NO_OF_DECIMALS bigint COMMENT 'Số lượng số lẽ thập phân',
    T_INTEREST_DAY_BASIS string COMMENT 'Cơ số (không dùng)',
    T_CURRENCY_MARKET string COMMENT 'Currency market',
    T_MID_REVAL_RATE string COMMENT 'Tỷ giá giữa đánh giá lại',
    T_DEFAULT_SPREAD string COMMENT 'Không dùng',
    T_BUY_RATE string COMMENT 'Tỷ giá mua',
    T_SELL_RATE string COMMENT 'Tỷ giá bán',
    T_NEGOTIABLE_AMT string COMMENT 'Không dùng',
    T_REVAL_RATE string COMMENT 'Tỷ giá đánh giá lại',
    T_CENTRAL_RATE string COMMENT 'Không dùng',
    T_BLOCKED_DATE string COMMENT 'Không dùng',
    source_event_date string COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_currency ALTER COLUMN ID SET NOT NULL;
ALTER TABLE ref_currency ADD CONSTRAINT ref_currency_pk PRIMARY KEY (ID);



CREATE OR REPLACE TABLE ref_t24_de_bic (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_CITY string COMMENT 'Không dùng',
    T_ADDRESS string COMMENT 'Địa chỉ',
    T_COUNTRY string COMMENT 'Quốc gia',
    T_SUBTYPE_IND string COMMENT 'Không dùng',
    T_RECORDKEY string COMMENT 'Trường hệ thống -- mặc định theo @ID',
    T_BRANCH string COMMENT 'Không dùng',
    T_BIC_CODE string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_de_bic ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_de_bic ADD CONSTRAINT ref_t24_de_bic_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_dealer_desk (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_dealer_desk ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_dealer_desk ADD CONSTRAINT ref_t24_dealer_desk_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_department (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Không dùng',
    T_GROUP_ID string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_department ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_department ADD CONSTRAINT ref_t24_department_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ft_txn_type_condition (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_TXN_CODE_CR string COMMENT 'Txn Code Cr',
    T_TXN_CODE_DR string COMMENT 'Txn Code Dr',
    T_STO_TXN_CODE_CR string COMMENT 'Sto Txn Code Cr',
    T_STO_TXN_CODE_DR string COMMENT 'Sto Txn Code Dr',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ft_txn_type_condition ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ft_txn_type_condition ADD CONSTRAINT ref_t24_ft_txn_type_condition_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_industry (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SBV_INDUSTRY string COMMENT 'Mã ngành kinh tế báo cáo NHNN',
    T_SUB_INDUSTRY bigint COMMENT 'Ngành nghề con',
    T_ACTIVE string COMMENT 'Tình trạng sử dụng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_industry ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_industry ADD CONSTRAINT ref_t24_industry_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_lc_types (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_CATEGORY_CODE bigint COMMENT 'Mã nhóm phân loại',
    T_IMPORT_EXPORT string COMMENT 'Loại LC ( Import/Export/...)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_lc_types ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_lc_types ADD CONSTRAINT ref_t24_lc_types_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ld_aprv_user (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_UBTD1 string COMMENT 'Ủy ban tín dụng 1( None/Yes/No)',
    T_UBTD2 string COMMENT 'Ủy ban tín dụng 2( None/Yes/No)',
    T_UBTD3 string COMMENT 'Ủy ban tín dụng 3( None/Yes/No)',
    T_DIRECT_APRV string COMMENT 'Cấp phê duyệt trực tiếp( None/Yes/No)',
    T_INDIRECT_APRV string COMMENT 'Cấp phê duyệt gián tiếp ( None/Yes/No)',
    T_REVAL_LEVEL string COMMENT 'Cấp tái thẩm định (( None/Yes/No)',
    T_ACTIVE_INFO string COMMENT 'Có hiệu lực ( None/Yes/No)',
    T_USER_STATUS string COMMENT 'Tình trạng làm việc(None/Work/Off/ChangeDept)',
    T_CURR_NO string COMMENT 'số thay đổi trạng thái của record',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'người duyệt',
    T_DATE_TIME string COMMENT 'Ngày nhập',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ld_aprv_user ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ld_aprv_user ADD CONSTRAINT ref_t24_ld_aprv_user_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ld_economic_sector (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_PARENT_ID string COMMENT 'Mã bản ghi cha',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ld_economic_sector ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ld_economic_sector ADD CONSTRAINT ref_t24_ld_economic_sector_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ld_ins_type_comp (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_INS_TYPE string COMMENT 'Loại bảo hiểm( NOne/No/Yes)',
    T_INS_COMPANY string COMMENT 'Công ty bảo hiẻm(None/No/Yes)',
    T_INS_TYPE_ID string COMMENT 'Mã loại cty bảo hiểm',
    T_NUSED string COMMENT 'Đánh dấ không còn hiêu lực',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ld_ins_type_comp ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ld_ins_type_comp ADD CONSTRAINT ref_t24_ld_ins_type_comp_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ld_partner (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_RECORD_STATUS string COMMENT 'Trạng thái bản ghi (T24)',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'người nhập',
    T_DATE_TIME string COMMENT 'ngày nhập',
    T_AUTHORISER string COMMENT 'người duyệt',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ld_partner ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ld_partner ADD CONSTRAINT ref_t24_ld_partner_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ld_promotion (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_RECORD_STATUS string COMMENT 'trrạng thái của recrod',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'người nhập',
    T_DATE_TIME string COMMENT 'ngày nhập',
    T_AUTHORISER string COMMENT 'người duyệt',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ld_promotion ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ld_promotion ADD CONSTRAINT ref_t24_ld_promotion_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_limit_reference (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_LIMIT_REFERENCE bigint COMMENT 'Mã tham chiếu hạn mức',
    T_SHORT_NAME string COMMENT 'Tên viết tắt',
    T_REDUCING_LIMIT string COMMENT 'Giới hạn hạn mức (Yes/No)',
    T_REFERENCE_CHILD string COMMENT 'sản phẩm vay liên kết hạn mức',
    T_RECORD_STATUS string COMMENT 'trạng thái record',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'người duyệt',
    T_AUTHORISER string COMMENT 'người nhập',
    T_DATE_TIME string COMMENT 'người duyệt',
    T_CO_CODE string COMMENT 'mã chi nhánh',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_limit_reference ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_limit_reference ADD CONSTRAINT ref_t24_limit_reference_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_loan_method (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_LOAN_METHOD string COMMENT 'Không dùng',
    T_RECORD_STATUS string COMMENT 'Tình trạng',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'Người duyệt',
    T_DATE_TIME string COMMENT 'Ngày giờ thay đổi',
    T_CO_CODE string COMMENT 'Chi nhánh',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_loan_method ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_loan_method ADD CONSTRAINT ref_t24_loan_method_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_loan_purpose (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_LEVEL_1 bigint COMMENT 'Giá trị phân cấp mức 1',
    T_LEVEL_1_DESC string COMMENT 'Tên cấp 1',
    T_LEVEL_2 bigint COMMENT 'Giá trị phân cấp mức 2',
    T_LEVEL_2_DESC string COMMENT 'Tên cấp 2',
    T_RECORD_STATUS string COMMENT 'Tình trạng',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'Người duyệt',
    T_DATE_TIME string COMMENT 'Ngày giờ thay đổi',
    T_CO_CODE string COMMENT 'Chi nhánh',
    T_CATEGORY string COMMENT 'Mã category sản phẩm (T24)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_loan_purpose ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_loan_purpose ADD CONSTRAINT ref_t24_loan_purpose_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_loan_subproduct (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SUB_CATEG_CODE bigint COMMENT 'Mã nhóm con',
    T_CATEGORY string COMMENT 'Category liên quan',
    T_RECORD_STATUS string COMMENT 'Tình trạng',
    T_CURR_NO bigint COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập',
    T_AUTHORISER string COMMENT 'Người duyệt',
    T_DATE_TIME string COMMENT 'Ngày giờ cập nhật',
    T_CO_CODE string COMMENT 'Chi nhánh',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_loan_subproduct ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_loan_subproduct ADD CONSTRAINT ref_t24_loan_subproduct_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_classification (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_ACTIVE_STATUS string COMMENT 'Tình trạng sử dụng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_classification ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_classification ADD CONSTRAINT ref_t24_ocbh_classification_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_coll_borrow_purpose (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu (ngày snapshot từ hệ thống nguồn)',
    ID2 string COMMENT 'Định danh phụ của bản ghi',
    T_CURR_NO string COMMENT 'Số phiên bản hiện tại của bản ghi',
    T_INPUTTER string COMMENT 'Người nhập liệu bản ghi',
    T_DATE_TIME string COMMENT 'Thời điểm cập nhật bản ghi gần nhất',
    T_AUTHORISER string COMMENT 'Người phê duyệt bản ghi (T24)',
    T_CO_CODE string COMMENT 'Mã đơn vị/chi nhánh (company code)',
    T_DEPT_CODE string COMMENT 'Mã phòng ban',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_coll_borrow_purpose ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_coll_borrow_purpose ADD CONSTRAINT ref_t24_ocbh_coll_borrow_purpose_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_coll_rev_agent (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_INPUTTER string COMMENT 'người nhập',
    T_AUTHORISER string COMMENT 'người duyệt',
    T_DATE_TIME string COMMENT 'ngày nhập',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_coll_rev_agent ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_coll_rev_agent ADD CONSTRAINT ref_t24_ocbh_coll_rev_agent_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_cus_group (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày hệ thống',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_cus_group ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_cus_group ADD CONSTRAINT ref_t24_ocbh_cus_group_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_deposit_prgm (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày hệ thống',
    T_BEGIN_DATE string COMMENT 'Ngày áp dụng',
    T_END_DATE string COMMENT 'Ngày kết thúc',
    T_CO_CODE string COMMENT 'Mã CN quản lý',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_deposit_prgm ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_deposit_prgm ADD CONSTRAINT ref_t24_ocbh_deposit_prgm_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_ft_outward_purpose (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày hệ thống',
    T_PURPOSE_TYPE string COMMENT 'Loại mục đích  chuyển tiền nước ngoài',
    T_CUS_TYPE string COMMENT 'Loại KH',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_ft_outward_purpose ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_ft_outward_purpose ADD CONSTRAINT ref_t24_ocbh_ft_outward_purpose_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_fx_buyfcy_purpose (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_fx_buyfcy_purpose ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_fx_buyfcy_purpose ADD CONSTRAINT ref_t24_ocbh_fx_buyfcy_purpose_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_ld_prod_main (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_CATEGORY string COMMENT 'Mã sản p hẩm',
    T_RECORD_STATUS string COMMENT 'trạng thái của record',
    T_CURR_NO string COMMENT 'Số lần thay đổi của record',
    T_INPUTTER string COMMENT 'người nhập',
    T_DATE_TIME string COMMENT 'ngày nhập',
    T_AUTHORISER string COMMENT 'người duyệt',
    T_CO_CODE string COMMENT 'mã chi nhánh',
    T_DEPT_CODE string COMMENT 'mã phòng ban',
    T_AUDITOR_CODE string COMMENT 'Không dùng',
    T_AUDIT_DATE_TIME string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_ld_prod_main ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_ld_prod_main ADD CONSTRAINT ref_t24_ocbh_ld_prod_main_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_loan_pro_bundle (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    SUB_PRODUCT string COMMENT 'Thuộc mã sản phẩm vay',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_loan_pro_bundle ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_loan_pro_bundle ADD CONSTRAINT ref_t24_ocbh_loan_pro_bundle_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_md_purpose (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_PARENT_ID string COMMENT 'mã mđ cha',
    T_N_USED string COMMENT 'không còn sử dụng ?',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_md_purpose ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_md_purpose ADD CONSTRAINT ref_t24_ocbh_md_purpose_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbh_product_package (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    PACKAGE_REGISTER_FEE string COMMENT 'Phí đăng ký gói',
    MIN_BALANCE string COMMENT 'Số tiền tối thiểu',
    BEGIN_DATE string COMMENT 'Ngày bắt đầu',
    EXPIRE_DATE string COMMENT 'Ngày hết hạn',
    SERVICE string COMMENT 'Tên phí dịch vụ',
    FT_TRANSACTION_TYPE string COMMENT 'Mã phí',
    PROVINCE_TYPE string COMMENT 'Loại phí cùng/khác tỉnh',
    HIGH_LOW_VALUE string COMMENT 'Giá trị phí cao/thấp',
    EXTERNAL_FT_FEE string COMMENT 'Số tiền phí CK ngoài hệ thống',
    EXTERNAL_FT_COMM_TYPE string COMMENT 'Mã loại phí CK ngoài hệ thống',
    CONDITION_GROUP string COMMENT 'Nhóm điều kiện',
    MIN_AVERAGE_BALANCE string COMMENT 'Số dư bình quân tối thiểu',
    BELOW_AVER_BAL_FEE string COMMENT 'Số tiền phí thu khi số dư TK dưới SDBQ',
    ATM_MAX_AMT_TRANS string COMMENT 'Số tiền max giao dịch ATM',
    ATM_MAX_DAILY_AMT string COMMENT 'Số tiền max giao dịch ATM hàng ngày',
    ATM_NOT_OCB_FEE string COMMENT 'Số tiền phí giao dịch khác ATM',
    WITHDRAW_CASH_TT_AMT string COMMENT 'Số tiền được phép rút tiền mặt',
    WITHDRAW_CASH_TT_FEE string COMMENT 'Tiền phí rút tiền mặt',
    WITHDRAW_CASH_TT_PL string COMMENT 'Mã PL thu phí rút tiền mặt',
    FT_CHANNEL string COMMENT 'Kênh giao dịch FT',
    INTERNAL_FT_FEE string COMMENT 'Tiền phí FT nội bộ',
    INTERNAL_FT_COMM_TYPE string COMMENT 'Mã phí FT nội bộ',
    BILL_PAYMENT_FEE string COMMENT 'Tiền phí thanh toán hóa đơn',
    BILL_PAYMENT_COMM_TYPE string COMMENT 'Mã phí thanh toán hóa đơn',
    PACKAGE_CUSTOMER_TYPE string COMMENT 'Loại khách hàng',
    PACKAGE_REGISTER_PL string COMMENT 'Mã PL thu phí đăng ký gói',
    BELOW_AVER_BAL_PL string COMMENT 'Mã PL thu phí dưới SDBQ',
    ATM_NOT_OCB_PL string COMMENT 'Mã PL thu phí các giao dịch khác ATM',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbh_product_package ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbh_product_package ADD CONSTRAINT ref_t24_ocbh_product_package_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_ocbt_sub_industry (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_ID_PARENT string COMMENT 'Mã ngành kinh tế',
    T_ORDER bigint COMMENT 'Thứ tự sắp xếp',
    T_ACTIVE bigint COMMENT 'Cờ hiệu lực/đang hoạt động',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_ocbt_sub_industry ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_ocbt_sub_industry ADD CONSTRAINT ref_t24_ocbt_sub_industry_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_occupation (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_occupation ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_occupation ADD CONSTRAINT ref_t24_occupation_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_posting_restrict (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_RESTRICTION_TYPE string COMMENT 'Loại hạn chế',
    T_DISPO_OFFICER string COMMENT 'Trường không sử dụng',
    T_ALLOW_TXN string COMMENT 'Cho phép Hạn chế theo trans code?',
    T_TXN_CODE string COMMENT 'Mã trans code được cho phép/ ko cho phép hạn chế',
    T_LOCAL_REF string COMMENT 'Không có trong bảng POSTING.RESTRICT',
    T_ALT_OVERRIDE string COMMENT 'Không có trong bảng POSTING.RESTRICT',
    T_BLOCK_REASON_CODES string COMMENT 'Mã lý do hạn chế',
    T_UNBLOCK_REASON_CODES string COMMENT 'Mã lý do gỡ hạn chế',
    T_CO_CODE string COMMENT 'Mã CN quản lý',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_posting_restrict ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_posting_restrict ADD CONSTRAINT ref_t24_posting_restrict_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_province (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'không dùng ( do thay thế bằng bảng OCBT.PROVINCE)',
    T_NATIONALITY string COMMENT 'không dùng ( do thay thế bằng bảng OCBT.PROVINCE)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_province ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_province ADD CONSTRAINT ref_t24_province_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_re_stat_line_cont (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu (ngày snapshot từ hệ thống nguồn)',
    T_TYPE string COMMENT 'Loại/phân loại',
    T_PROFIT_CCY string COMMENT 'Loại tiền hạch toán lợi nhuận',
    T_ASST_CONSOL_KEY string COMMENT 'Khóa hợp nhất tài sản',
    T_ASSET_TYPE string COMMENT 'Loại tài sản',
    T_PRFT_CONSOL_KEY string COMMENT 'Khóa hợp nhất lợi nhuận',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_re_stat_line_cont ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_re_stat_line_cont ADD CONSTRAINT ref_t24_re_stat_line_cont_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_re_stat_rep_line (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Không dùng',
    T_K_TYPE string COMMENT 'Không dùng',
    T_CO_CODE string COMMENT 'Không dùng',
    T_INPUTTER string COMMENT 'Không dùng',
    T_DATE_TIME string COMMENT 'Không dùng',
    T_AUTHORISER string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_re_stat_rep_line ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_re_stat_rep_line ADD CONSTRAINT ref_t24_re_stat_rep_line_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_sc_trans_name (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_sc_trans_name ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_sc_trans_name ADD CONSTRAINT ref_t24_sc_trans_name_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_sec_acc_master (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_ACCOUNT_OFFICER string COMMENT 'RM/ mã phòng ban quản lý',
    T_CUSTOMER_NUMBER string COMMENT 'trường hệ thống',
    T_REFERENCE_CURRENCY string COMMENT 'loại tiền',
    T_DATE_OF_VALUATION string COMMENT 'ngày đánh giá lại',
    T_START_DATE string COMMENT 'ngày bắt đầu',
    T_CO_CODE string COMMENT 'trường hệ thống',
    T_PORTFOLIO_TYPE string COMMENT 'Phân loại portfolio',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_sec_acc_master ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_sec_acc_master ADD CONSTRAINT ref_t24_sec_acc_master_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_sector (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SECTOR_GROUP string COMMENT 'Nhóm thành phần kinh tê',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_sector ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_sector ADD CONSTRAINT ref_t24_sector_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_sub_asset_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_SHORT_DESCR string COMMENT 'Tên viết tắt',
    T_ASSET_TYPE_CODE string COMMENT 'Mã phân loại nhóm',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_sub_asset_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_sub_asset_type ADD CONSTRAINT ref_t24_sub_asset_type_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_town (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liêu',
    T_ORDER bigint COMMENT 'Thứ tự sắp xếp',
    T_ACTIVE string COMMENT 'Tình trạng sử dụng',
    T_PROVINCE bigint COMMENT 'Tỉnh/thành phố',
    T_OCB_TOWN_NATION string COMMENT 'Quốc gia/khu vực của thị trấn (OCB)',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_town ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_town ADD CONSTRAINT ref_t24_town_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE ref_t24_transaction (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    DATA_DATE string COMMENT 'Ngày dữ liệu',
    T_TRANSACTION_CODE string COMMENT 'Mã giao dịch',
    T_DATA_CAPTURE string COMMENT 'Không dùng',
    T_CHEQUE_IND string COMMENT 'Không dùng',
    T_MANDATORY_REF_NO string COMMENT 'Không dùng',
    T_DEBIT_CREDIT_IND string COMMENT 'Loại giao dịch ghi nợ hay có',
    T_CHARGE_KEY string COMMENT 'Không dùng',
    T_IMMEDIATE_CHARGE string COMMENT 'Không dùng',
    T_DEFAULT_VALUE_DATE string COMMENT 'Không dùng',
    T_EXPOSURE_DATE string COMMENT 'Không dùng',
    T_RECORD_STATUS string COMMENT 'Tình trạng bản ghi',
    T_CURR_NO string COMMENT 'Số lần thay đổi',
    T_CO_CODE string COMMENT 'Mã chi nhánh thực hiện',
    T_DEPT_CODE string COMMENT 'Không dùng',
    T_AUDITOR_CODE string COMMENT 'Không dùng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_t24_transaction ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_t24_transaction ADD CONSTRAINT ref_t24_transaction_pk PRIMARY KEY (Ref_hashkey);



CREATE OR REPLACE TABLE effsat_link_collateral_collateral_right (
    link_collateral_collateral_right_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_collateral_collateral_right ALTER COLUMN link_collateral_collateral_right_hashkey SET NOT NULL;
ALTER TABLE effsat_link_collateral_collateral_right ADD CONSTRAINT effsat_link_collateral_collateral_right_pk PRIMARY KEY (link_collateral_collateral_right_hashkey);



CREATE OR REPLACE TABLE effsat_link_collateral_right_limit (
    link_collateral_right_limit_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_collateral_right_limit ALTER COLUMN link_collateral_right_limit_hashkey SET NOT NULL;
ALTER TABLE effsat_link_collateral_right_limit ADD CONSTRAINT effsat_link_collateral_right_limit_pk PRIMARY KEY (link_collateral_right_limit_hashkey);



CREATE OR REPLACE TABLE effsat_link_repo_security (
    link_repo_security_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_repo_security ALTER COLUMN link_repo_security_hashkey SET NOT NULL;
ALTER TABLE effsat_link_repo_security ADD CONSTRAINT effsat_link_repo_security_pk PRIMARY KEY (link_repo_security_hashkey);



CREATE OR REPLACE TABLE sts_hub_account (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account ADD CONSTRAINT sts_hub_account_pk PRIMARY KEY (account_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_account_credit_int (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_credit_int ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_credit_int ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_credit_int ADD CONSTRAINT sts_hub_account_credit_int_pk PRIMARY KEY (account_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_account_debit_int (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_debit_int ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_debit_int ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_debit_int ADD CONSTRAINT sts_hub_account_debit_int_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_account_accr_acct_cr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_accr_acct_cr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_cr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_cr ADD CONSTRAINT sts_hub_account_accr_acct_cr_pk PRIMARY KEY (account_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_account_accr_acct_dr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_accr_acct_dr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_dr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_accr_acct_dr ADD CONSTRAINT sts_hub_account_accr_acct_dr_pk PRIMARY KEY (account_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_account_ac_restrict (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_ac_restrict ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_ac_restrict ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_ac_restrict ADD CONSTRAINT sts_hub_account_ac_restrict_pk PRIMARY KEY (account_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_account_stmt_acct_cr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_stmt_acct_cr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_cr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_cr ADD CONSTRAINT sts_hub_account_stmt_acct_cr_pk PRIMARY KEY (account_hashkey, source_event_date);

CREATE OR REPLACE TABLE sts_hub_account_stmt_acct_dr (
    account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_stmt_acct_dr ALTER COLUMN account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_dr ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_stmt_acct_dr ADD CONSTRAINT sts_hub_account_stmt_acct_dr_pk PRIMARY KEY (account_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_account_locked_events (
    ac_locked_events_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_account_locked_events ALTER COLUMN ac_locked_events_hashkey SET NOT NULL;
ALTER TABLE sts_hub_account_locked_events ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_account_locked_events ADD CONSTRAINT sts_hub_account_locked_events_pk PRIMARY KEY (ac_locked_events_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_acct_officer (
    dept_acct_officer_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_acct_officer ALTER COLUMN dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE sts_hub_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_acct_officer ADD CONSTRAINT sts_hub_acct_officer_pk PRIMARY KEY (dept_acct_officer_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_branch (
    branch_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_branch ALTER COLUMN branch_hashkey SET NOT NULL;
ALTER TABLE sts_hub_branch ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_branch ADD CONSTRAINT sts_hub_branch_pk PRIMARY KEY (branch_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_clearing_citad (
    clearing_citad_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_clearing_citad ALTER COLUMN clearing_citad_hashkey SET NOT NULL;
ALTER TABLE sts_hub_clearing_citad ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_clearing_citad ADD CONSTRAINT sts_hub_clearing_citad_pk PRIMARY KEY (clearing_citad_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_collateral (
    collateral_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_collateral ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sts_hub_collateral ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_collateral ADD CONSTRAINT sts_hub_collateral_pk PRIMARY KEY (collateral_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_collateral_basel (
    collateral_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_collateral_basel ALTER COLUMN collateral_hashkey SET NOT NULL;
ALTER TABLE sts_hub_collateral_basel ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_collateral_basel ADD CONSTRAINT sts_hub_collateral_basel_pk PRIMARY KEY (collateral_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_collateral_right (
    collateral_right_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_collateral_right ALTER COLUMN collateral_right_hashkey SET NOT NULL;
ALTER TABLE sts_hub_collateral_right ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_collateral_right ADD CONSTRAINT sts_hub_collateral_right_pk PRIMARY KEY (collateral_right_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_consolidate_profit_n_loss (
    consolidate_profit_n_loss_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_consolidate_profit_n_loss ALTER COLUMN consolidate_profit_n_loss_hashkey SET NOT NULL;
ALTER TABLE sts_hub_consolidate_profit_n_loss ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_consolidate_profit_n_loss ADD CONSTRAINT sts_hub_consolidate_profit_n_loss_pk PRIMARY KEY (consolidate_profit_n_loss_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_crb (
    crb_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_crb ALTER COLUMN crb_hashkey SET NOT NULL;
ALTER TABLE sts_hub_crb ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_crb ADD CONSTRAINT sts_hub_crb_pk PRIMARY KEY (crb_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_customer (
    customer_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_customer ALTER COLUMN customer_hashkey SET NOT NULL;
ALTER TABLE sts_hub_customer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_customer ADD CONSTRAINT sts_hub_customer_pk PRIMARY KEY (customer_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_deposits (
    deposit_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_deposits ALTER COLUMN deposit_hashkey SET NOT NULL;
ALTER TABLE sts_hub_deposits ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_deposits ADD CONSTRAINT sts_hub_deposits_pk PRIMARY KEY (deposit_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_drawings (
    drawings_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_drawings ALTER COLUMN drawings_hashkey SET NOT NULL;
ALTER TABLE sts_hub_drawings ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_drawings ADD CONSTRAINT sts_hub_drawings_pk PRIMARY KEY (drawings_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_forex (
    forex_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_forex ALTER COLUMN forex_hashkey SET NOT NULL;
ALTER TABLE sts_hub_forex ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_forex ADD CONSTRAINT sts_hub_forex_pk PRIMARY KEY (forex_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_gci (
    gci_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_gci ALTER COLUMN gci_hashkey SET NOT NULL;
ALTER TABLE sts_hub_gci ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_gci ADD CONSTRAINT sts_hub_gci_pk PRIMARY KEY (gci_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_gdi (
    gdi_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_gdi ALTER COLUMN gdi_hashkey SET NOT NULL;
ALTER TABLE sts_hub_gdi ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_gdi ADD CONSTRAINT sts_hub_gdi_pk PRIMARY KEY (gdi_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_letter_of_credit (
    letter_of_credit_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_letter_of_credit ALTER COLUMN letter_of_credit_hashkey SET NOT NULL;
ALTER TABLE sts_hub_letter_of_credit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_letter_of_credit ADD CONSTRAINT sts_hub_letter_of_credit_pk PRIMARY KEY (letter_of_credit_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_limit (
    limit_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_limit ALTER COLUMN limit_hashkey SET NOT NULL;
ALTER TABLE sts_hub_limit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_limit ADD CONSTRAINT sts_hub_limit_pk PRIMARY KEY (limit_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans ADD CONSTRAINT sts_hub_loans_pk PRIMARY KEY (loans_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans_ld_aprv_info (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_ld_aprv_info ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_aprv_info ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_aprv_info ADD CONSTRAINT sts_hub_loans_ld_aprv_info_pk PRIMARY KEY (loans_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans_ld_basel (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_ld_basel ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_basel ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_basel ADD CONSTRAINT sts_hub_loans_ld_basel_pk PRIMARY KEY (loans_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans_ld_extra_info (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_ld_extra_info ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_extra_info ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_extra_info ADD CONSTRAINT sts_hub_loans_ld_extra_info_pk PRIMARY KEY (loans_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans_ld_schedule_define (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_ld_schedule_define ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_schedule_define ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_ld_schedule_define ADD CONSTRAINT sts_hub_loans_ld_schedule_define_pk PRIMARY KEY (loans_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans_lmm_account_balances (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_lmm_account_balances ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_lmm_account_balances ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_lmm_account_balances ADD CONSTRAINT sts_hub_loans_lmm_account_balances_pk PRIMARY KEY (loans_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_loans_ln_cust_revs (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_ln_cust_revs ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_ln_cust_revs ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_ln_cust_revs ADD CONSTRAINT sts_hub_loans_ln_cust_revs_pk PRIMARY KEY (loans_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_loans_bank_assure_inp (
    loans_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_bank_assure_inp ALTER COLUMN loans_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_bank_assure_inp ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_bank_assure_inp ADD CONSTRAINT sts_hub_loans_bank_assure_inp_pk PRIMARY KEY (loans_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_loans_payment_due (
    loans_payment_due_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_loans_payment_due ALTER COLUMN loans_payment_due_hashkey SET NOT NULL;
ALTER TABLE sts_hub_loans_payment_due ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_loans_payment_due ADD CONSTRAINT sts_hub_loans_payment_due_pk PRIMARY KEY (loans_payment_due_hashkey, source_event_date);


CREATE OR REPLACE TABLE sts_hub_md_deal (
    md_deal_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_md_deal ALTER COLUMN md_deal_hashkey SET NOT NULL;
ALTER TABLE sts_hub_md_deal ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_md_deal ADD CONSTRAINT sts_hub_md_deal_pk PRIMARY KEY (md_deal_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_money_market (
    money_market_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_money_market ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sts_hub_money_market ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_money_market ADD CONSTRAINT sts_hub_money_market_pk PRIMARY KEY (money_market_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_money_market_lmm_account_balances (
    money_market_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_money_market_lmm_account_balances ALTER COLUMN money_market_hashkey SET NOT NULL;
ALTER TABLE sts_hub_money_market_lmm_account_balances ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_money_market_lmm_account_balances ADD CONSTRAINT sts_hub_money_market_lmm_account_balances_pk PRIMARY KEY (money_market_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_product_package_partner (
    product_package_partner_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_product_package_partner ALTER COLUMN product_package_partner_hashkey SET NOT NULL;
ALTER TABLE sts_hub_product_package_partner ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_product_package_partner ADD CONSTRAINT sts_hub_product_package_partner_pk PRIMARY KEY (product_package_partner_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_repo (
    repo_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_repo ALTER COLUMN repo_hashkey SET NOT NULL;
ALTER TABLE sts_hub_repo ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_repo ADD CONSTRAINT sts_hub_repo_pk PRIMARY KEY (repo_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_sc_trading_position (
    sc_trading_position_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_sc_trading_position ALTER COLUMN sc_trading_position_hashkey SET NOT NULL;
ALTER TABLE sts_hub_sc_trading_position ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_sc_trading_position ADD CONSTRAINT sts_hub_sc_trading_position_pk PRIMARY KEY (sc_trading_position_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_security (
    security_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_security ALTER COLUMN security_hashkey SET NOT NULL;
ALTER TABLE sts_hub_security ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_security ADD CONSTRAINT sts_hub_security_pk PRIMARY KEY (security_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_sec_trade (
    sec_trade_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_sec_trade ALTER COLUMN sec_trade_hashkey SET NOT NULL;
ALTER TABLE sts_hub_sec_trade ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_sec_trade ADD CONSTRAINT sts_hub_sec_trade_pk PRIMARY KEY (sec_trade_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_user (
    user_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_user ALTER COLUMN user_hashkey SET NOT NULL;
ALTER TABLE sts_hub_user ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_user ADD CONSTRAINT sts_hub_user_pk PRIMARY KEY (user_hashkey, source_event_date);



CREATE OR REPLACE TABLE sts_hub_virtual_account (
    virtual_account_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_virtual_account ALTER COLUMN virtual_account_hashkey SET NOT NULL;
ALTER TABLE sts_hub_virtual_account ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_virtual_account ADD CONSTRAINT sts_hub_virtual_account_pk PRIMARY KEY (virtual_account_hashkey, source_event_date);



CREATE OR REPLACE TABLE checkpoint_etlpipeline_dbt_metadata (
    id string,
    database_name string,
    schema_name string,
    name string,
    model_name string,
    source_name string,
    execution_time DOUBLE ,
    etl_date string,
    started_at timestamp,
    completed_at timestamp,
    rows_affected INTEGER,
    status string,
    message string,
    run_id string
) CLUSTER BY AUTO;



CREATE OR REPLACE TABLE dq_test_log (
    ELT_DATE string,
    test_name string,
    model_name string,
    column_name string,
    test_type string,
    status string,
    error_rows int,
    error_message string,
    excution_time double,
    run_at timestamp,
    record_source string
) CLUSTER BY AUTO;



CREATE OR REPLACE TABLE effsat_link_account_limit (
    link_account_limit_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_account_limit ALTER COLUMN link_account_limit_hashkey SET NOT NULL;
ALTER TABLE effsat_link_account_limit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_account_limit ADD CONSTRAINT effsat_link_account_limit_pk PRIMARY KEY (link_account_limit_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_account_dept_acct_officer (
    link_account_dept_acct_officer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_account_dept_acct_officer ALTER COLUMN link_account_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_account_dept_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_account_dept_acct_officer ADD CONSTRAINT effsat_link_account_dept_acct_officer_pk PRIMARY KEY (link_account_dept_acct_officer_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_crb_branch (
    link_crb_branch_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_crb_branch ALTER COLUMN link_crb_branch_hashkey SET NOT NULL;
ALTER TABLE effsat_link_crb_branch ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_crb_branch ADD CONSTRAINT effsat_link_crb_branch_pk PRIMARY KEY (link_crb_branch_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_crb_customer (
    link_crb_customer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_crb_customer ALTER COLUMN link_crb_customer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_crb_customer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_crb_customer ADD CONSTRAINT effsat_link_crb_customer_pk PRIMARY KEY (link_crb_customer_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_customer_dept_acct_officer_nvql (
    link_customer_dept_acct_officer_nvql_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_customer_dept_acct_officer_nvql ALTER COLUMN link_customer_dept_acct_officer_nvql_hashkey SET NOT NULL;
ALTER TABLE effsat_link_customer_dept_acct_officer_nvql ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_customer_dept_acct_officer_nvql ADD CONSTRAINT effsat_link_customer_dept_acct_officer_nvql_pk PRIMARY KEY (link_customer_dept_acct_officer_nvql_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_customer_dept_acct_officer_nvgt (
    link_customer_dept_acct_officer_nvgt_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_customer_dept_acct_officer_nvgt ALTER COLUMN link_customer_dept_acct_officer_nvgt_hashkey SET NOT NULL;
ALTER TABLE effsat_link_customer_dept_acct_officer_nvgt ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_customer_dept_acct_officer_nvgt ADD CONSTRAINT effsat_link_customer_dept_acct_officer_nvgt_pk PRIMARY KEY (link_customer_dept_acct_officer_nvgt_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_forex_dept_acct_officer (
    link_forex_dept_acct_officer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_forex_dept_acct_officer ALTER COLUMN link_forex_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_forex_dept_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_forex_dept_acct_officer ADD CONSTRAINT effsat_link_forex_dept_acct_officer_pk PRIMARY KEY (link_forex_dept_acct_officer_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_loans_dept_acct_officer_nvql (
    link_loans_dept_acct_officer_nvql_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_loans_dept_acct_officer_nvql ALTER COLUMN link_loans_dept_acct_officer_nvql_hashkey SET NOT NULL;
ALTER TABLE effsat_link_loans_dept_acct_officer_nvql ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_loans_dept_acct_officer_nvql ADD CONSTRAINT effsat_link_loans_dept_acct_officer_nvql_pk PRIMARY KEY (link_loans_dept_acct_officer_nvql_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_loans_dept_acct_officer_nvgt (
    link_loans_dept_acct_officer_nvgt_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_loans_dept_acct_officer_nvgt ALTER COLUMN link_loans_dept_acct_officer_nvgt_hashkey SET NOT NULL;
ALTER TABLE effsat_link_loans_dept_acct_officer_nvgt ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_loans_dept_acct_officer_nvgt ADD CONSTRAINT effsat_link_loans_dept_acct_officer_nvgt_pk PRIMARY KEY (link_loans_dept_acct_officer_nvgt_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_loans_saleid (
    link_loans_saleid_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_loans_saleid ALTER COLUMN link_loans_saleid_hashkey SET NOT NULL;
ALTER TABLE effsat_link_loans_saleid ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_loans_saleid ADD CONSTRAINT effsat_link_loans_saleid_pk PRIMARY KEY (link_loans_saleid_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_loans_limit (
    link_loans_limit_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_loans_limit ALTER COLUMN link_loans_limit_hashkey SET NOT NULL;
ALTER TABLE effsat_link_loans_limit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_loans_limit ADD CONSTRAINT effsat_link_loans_limit_pk PRIMARY KEY (link_loans_limit_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_money_market_dept_acct_officer (
    link_money_market_dept_acct_officer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_money_market_dept_acct_officer ALTER COLUMN link_money_market_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_money_market_dept_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_money_market_dept_acct_officer ADD CONSTRAINT effsat_link_money_market_dept_acct_officer_pk PRIMARY KEY (link_money_market_dept_acct_officer_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_letter_of_credit_dept_acct_officer (
    link_letter_of_credit_dept_acct_officer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_letter_of_credit_dept_acct_officer ALTER COLUMN link_letter_of_credit_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_letter_of_credit_dept_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_letter_of_credit_dept_acct_officer ADD CONSTRAINT effsat_link_letter_of_credit_dept_acct_officer_pk PRIMARY KEY (link_letter_of_credit_dept_acct_officer_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_letter_of_credit_limit (
    link_letter_of_credit_limit_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_letter_of_credit_limit ALTER COLUMN link_letter_of_credit_limit_hashkey SET NOT NULL;
ALTER TABLE effsat_link_letter_of_credit_limit ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_letter_of_credit_limit ADD CONSTRAINT effsat_link_letter_of_credit_limit_pk PRIMARY KEY (link_letter_of_credit_limit_hashkey, source_event_date);



CREATE OR REPLACE TABLE effsat_link_md_deal_dept_acct_officer (
    link_md_deal_dept_acct_officer_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Truong ky thuat: Ngay su kien thay doi co hieu luc tu he thong nguon.',
    record_source string COMMENT 'Truong ky thuat: Nguon goc cua ban ghi dung de xac dinh bang nguon du lieu.',
    load_timestamp timestamp COMMENT 'Truong ky thuat: Thoi diem ban ghi duoc nap vao he thong nguon.',
    active_flag int COMMENT 'Co trang thai hieu luc (1 = dang hoat dong, 0 = het hieu luc)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_md_deal_dept_acct_officer ALTER COLUMN link_md_deal_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE effsat_link_md_deal_dept_acct_officer ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE effsat_link_md_deal_dept_acct_officer ADD CONSTRAINT effsat_link_md_deal_dept_acct_officer_pk PRIMARY KEY (link_md_deal_dept_acct_officer_hashkey, source_event_date);




CREATE OR REPLACE TABLE etl_model_checkpoint (
    id string,
    run_id string,
    job_id string,
    task_key string,
    database_name string,
    schema_name string,
    name string,
    model_name string,
    source_name string,
    execution_time double,
    etl_date string,
    started_at timestamp,
    completed_at timestamp,
    rows_affected bigint,
    status string,
    message string,
    created_by string,
    created_at timestamp,
    updated_by string,
    updated_at timestamp
) CLUSTER BY AUTO;



CREATE OR REPLACE TABLE etl_quality_check (
    id string,
    run_id string,
    job_id string,
    task_key string,
    test_name string,
    model_name string,
    column_name string,
    severity string,
    status string,
    message string,
    compiled_sql string,
    source_name string,
    etl_date string,
    started_at timestamp,
    completed_at timestamp,
    created_by string,
    created_at timestamp,
    updated_by string,
    updated_at timestamp
) CLUSTER BY AUTO;
