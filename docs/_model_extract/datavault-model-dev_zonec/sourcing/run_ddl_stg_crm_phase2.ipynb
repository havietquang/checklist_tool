# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- Phase 2
CREATE OR REPLACE VIEW v_stg_crm_crm_contact_hist AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS INT) AS CIF,
    CAST(NULL AS STRING) AS DATE_CONTACT,
    CAST(NULL AS STRING) AS FUNC_GROUP,
    CAST(NULL AS STRING) AS BRANCH_CODE,
    CAST(NULL AS STRING) AS NOTES,
    CAST(NULL AS STRING) AS SOUCRE,
    CAST(NULL AS INT) AS CONTACT_STATUS_ID,
    CAST(NULL AS INT) AS CONTACT_TYPE_ID,
    CAST(NULL AS INT) AS CONTACT_RESULT_ID,
    CAST(NULL AS INT) AS CONTACTNOTEID,
    CAST(NULL AS BIGINT) AS IMPORT_ID,
    CAST(NULL AS INT) AS PROGRAM_NOTYFY_ID,
    CAST(NULL AS INT) AS SALE_CODE,
    CAST(NULL AS STRING) AS PROMISE_DATE,
    CAST(NULL AS STRING) AS RECALL_DATE,
    CAST(NULL AS STRING) AS CONDITION_DATE,
    CAST(NULL AS STRING) AS REFERENCES_DATE,
    CAST(NULL AS STRING) AS DIALID,
    CAST(NULL AS TIMESTAMP) AS DATETIME_CREATED,
    CAST(NULL AS STRING) AS DATETIME_UPDATED,
    CAST(NULL AS STRING) AS USER_CREATED,
    CAST(NULL AS STRING) AS USER_UPDATED,
    CAST(NULL AS DECIMAL(38,10)) AS UPDATE_TIMES,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_contact_hist_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_crm_crm_contact_notes AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS NAME,
    CAST(NULL AS STRING) AS STATUS,
    CAST(NULL AS STRING) AS DATE_CREATED,
    CAST(NULL AS STRING) AS USER_CREATED,
    CAST(NULL AS STRING) AS DATE_UPDATED,
    CAST(NULL AS STRING) AS USER_UPDATED,
    CAST(NULL AS INT) AS IS_IMPORTED,
    CAST(NULL AS STRING) AS PROGRAM_TYPE,
    CAST(NULL AS STRING) AS PROGRAM_CODE,
    CAST(NULL AS INT) AS IS_PROGRAM_HOT,
    CAST(NULL AS STRING) AS END_DATE_PROGRAM,
    CAST(NULL AS STRING) AS START_DATE_PROGRAM,
    CAST(NULL AS DECIMAL(38,10)) AS ID_PRODUCT,
    CAST(NULL AS STRING) AS CUSTGROUP,
    CAST(NULL AS STRING) AS DEPARTMENT,
    CAST(NULL AS STRING) AS PARENT_KEY,
    CAST(NULL AS STRING) AS FILE_BANNER,
    CAST(NULL AS STRING) AS FILE_MANUAL,
    CAST(NULL AS STRING) AS FILE_INFO_PROD,
    CAST(NULL AS STRING) AS DATA_TYPE,
    CAST(NULL AS INT) AS POSITION,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_contact_notes_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_crm_crm_contact_result AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS INT) AS contact_result_id,
    CAST(NULL AS STRING) AS contact_result_name,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS INT) AS position,
    CAST(NULL AS STRING) AS insurance,
    CAST(NULL AS STRING) AS expired_card_prio,
    CAST(NULL AS STRING) AS cust_group,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_crm_crm_contact_status AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS INT) AS contact_status_id,
    CAST(NULL AS STRING) AS contact_status_name,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS INT) AS position,
    CAST(NULL AS STRING) AS kh_denhan_bh,
    CAST(NULL AS STRING) AS kh_cosp_dexuat,
    CAST(NULL AS STRING) AS kh_roibo,
    CAST(NULL AS STRING) AS hd_tiengui_denhan,
    CAST(NULL AS STRING) AS sn_khachhang,
    CAST(NULL AS STRING) AS kh_hienhuu,
    CAST(NULL AS STRING) AS taikichhoat,
    CAST(NULL AS STRING) AS kh_expiredcard,
    CAST(NULL AS STRING) AS chbh_ganden,
    CAST(NULL AS STRING) AS cust_group,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_crm_crm_contact_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS INT) AS contact_type_id,
    CAST(NULL AS STRING) AS contact_type_name,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS INT) AS position,
    CAST(NULL AS STRING) AS kh_denhan_bh,
    CAST(NULL AS STRING) AS kh_cosp_dexuat,
    CAST(NULL AS STRING) AS kh_roibo,
    CAST(NULL AS STRING) AS hd_tiengui_denhan,
    CAST(NULL AS STRING) AS sn_khachhang,
    CAST(NULL AS STRING) AS kh_hienhuu,
    CAST(NULL AS STRING) AS taikichhoat,
    CAST(NULL AS STRING) AS kh_expiredcard,
    CAST(NULL AS STRING) AS chbh_ganden,
    CAST(NULL AS STRING) AS cust_group,
    CAST(NULL AS STRING) AS iscall,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_crm_crm_naming_custgroup AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS custgroup,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS parent_key,
    CAST(NULL AS STRING) AS user_created,
    CAST(NULL AS STRING) AS date_created,
    CAST(NULL AS STRING) AS user_updated,
    CAST(NULL AS STRING) AS date_updated,
    CAST(NULL AS STRING) AS user_deleted,
    CAST(NULL AS STRING) AS date_deleted,
    CAST(NULL AS STRING) AS isactive,
    CAST(NULL AS STRING) AS isdeleted,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_crm_crm_users AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS user_id,
    CAST(NULL AS STRING) AS user_last_name,
    CAST(NULL AS STRING) AS user_first_name,
    CAST(NULL AS STRING) AS user_full_name,
    CAST(NULL AS STRING) AS user_status_id,
    CAST(NULL AS STRING) AS date_last_off,
    CAST(NULL AS STRING) AS session_id,
    CAST(NULL AS STRING) AS user_email,
    CAST(NULL AS STRING) AS extension,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS user_phone,
    CAST(NULL AS STRING) AS omni,
    CAST(NULL AS STRING) AS telext,
    CAST(NULL AS STRING) AS branch_code,
    CAST(NULL AS STRING) AS custgroup,
    CAST(NULL AS STRING) AS func_group,
    CAST(NULL AS STRING) AS account_officer_id,
    CAST(NULL AS STRING) AS job_key,
    CAST(NULL AS STRING) AS nearly_job_title,
    CAST(NULL AS STRING) AS is_team_manage,
    CAST(NULL AS STRING) AS isactive,
    CAST(NULL AS STRING) AS isdeleted,
    CAST(NULL AS STRING) AS is_enable_market_place,
    CAST(NULL AS STRING) AS is_lso_sk,
    CAST(NULL AS STRING) AS is_out_of_line,
    CAST(NULL AS STRING) AS old_custgroup,
    CAST(NULL AS STRING) AS old_branch_code,
    CAST(NULL AS STRING) AS old_user_full_name,
    CAST(NULL AS STRING) AS old_account_officer_id,
    CAST(NULL AS STRING) AS old_func_group,
    CAST(NULL AS STRING) AS old_user_phone,
    CAST(NULL AS STRING) AS old_telext,
    CAST(NULL AS STRING) AS user_created,
    CAST(NULL AS STRING) AS date_created,
    CAST(NULL AS STRING) AS user_updated,
    CAST(NULL AS STRING) AS date_updated,
    CAST(NULL AS STRING) AS user_deleted,
    CAST(NULL AS STRING) AS date_deleted,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_crm_users_information,
    CAST(NULL AS STRING) AS hashdiff_crm_users_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
