# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE hub_client (
    client_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_client ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE hub_client ADD CONSTRAINT hub_client_pk PRIMARY KEY (client_hashkey);

CREATE OR REPLACE TABLE sat_client_cs_status_log (
    client_hashkey string COMMENT 'Tham chiếu Hub client',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status_date string COMMENT 'Ngày ghi nhận trạng thái',
    bank_date_to string COMMENT 'Ngày hết hiệu lực của trạng thái (theo lịch ngân hàng)',
    start_local_date string COMMENT 'Ngày bắt đầu hiệu lực trạng thái',
    end_local_date string COMMENT 'Ngày kết thúc hiệu lực trạng thái',
    status_type bigint COMMENT 'Loại trạng thái',
    status_value bigint COMMENT 'Giá trị trạng thái',
    status_value_prev bigint COMMENT 'Giá trị trạng thái trước',
    descript string COMMENT 'Diễn giải nội dung thay đối trạng thái',
    is_active string COMMENT 'Flag đánh dấu trạng thái còn hiệu lực hay không',
    ext_data string COMMENT 'Thông tin mở rộng',
    event_action string COMMENT 'Hành động kích hoạt thay đổi trạng thái',
    event_code string COMMENT 'Mã sự kiện',
    officer bigint COMMENT 'Mã định danh của nhân viên thay đổi trạng thái',
    bank_date string COMMENT 'Ngày làm việc của ngân hàng tại thời điểm ghi nhận thay đổi',
    value_extension string COMMENT 'Giá trị mở rộng',
    usage_action bigint COMMENT 'Mã hành động kích hoạt việc thay đổi trạng thái',
    usage_object string COMMENT 'Mã định danh của đối tượng liên quan đến hành động',
    storno_plan bigint COMMENT 'Mã ID kế hoạch đảo/hủy',
    cre_by_storno_plan bigint COMMENT 'Cờ tạo bởi kế hoạch đảo',
    td_cons__oid bigint COMMENT 'ID đối tượng lưu vết trạng thái'
) CLUSTER BY AUTO;
ALTER TABLE sat_client_cs_status_log ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE sat_client_cs_status_log ADD CONSTRAINT sat_client_cs_status_log_pk PRIMARY KEY (client_hashkey);

CREATE OR REPLACE TABLE sat_client_information (
    client_hashkey string COMMENT 'Tham chiếu Hub client',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    short_name string COMMENT 'Tên hiển thị',
    first_nam string COMMENT 'Tên',
    last_nam string COMMENT 'Họ',
    tr_first_nam string COMMENT 'Tên (phiên âm)',
    tr_last_nam string COMMENT 'Họ (phiên âm)',
    tr_title bigint COMMENT 'Danh xưng',
    birth_date string COMMENT 'Ngày sinh',
    birth_place string COMMENT 'Nơi sinh',
    gender string COMMENT 'Giới tính',
    reg_number_type string COMMENT 'Loại giấy tờ',
    reg_number string COMMENT 'Số giấy tờ (CMND/ĐKKD)',
    reg_details string COMMENT 'Chi tiết nơi cấp/ngày cấp giấy tờ',
    citizenship string COMMENT 'Quốc tịch',
    profession string COMMENT 'Nghề nghiệp',
    marital_status string COMMENT 'Tình trạng hôn nhân',
    language bigint COMMENT 'Ngôn ngữ',
    delivery_type bigint COMMENT 'Hình thức giao nhận',
    father_s_nam string COMMENT 'Tên cha',
    mother_s_nam string COMMENT 'Tên mẹ',
    itn string COMMENT 'Mã số người nộp thuế',
    social_number string COMMENT 'Số bảo hiểm xã hội',
    tax_position string COMMENT 'Phân loại thuế',
    company_nam string COMMENT 'Tên công ty/doanh nghiệp',
    trade_nam string COMMENT 'Tên thương mại',
    company_department string COMMENT 'Phòng ban/Bộ phận làm việc',
    tr_company_nam string COMMENT 'Tên công ty (phiên âm)',
    date_open string COMMENT 'Ngày mở cif',
    date_expire string COMMENT 'Ngày hết hạn cif',
    enable_affiliation string COMMENT 'Không dùng ',
    affiliation_type string COMMENT 'Không dùng '
) CLUSTER BY AUTO;
ALTER TABLE sat_client_information ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE sat_client_information ADD CONSTRAINT sat_client_information_pk PRIMARY KEY (client_hashkey);

CREATE OR REPLACE TABLE sat_client_classification (
    client_hashkey string COMMENT 'Tham chiếu Hub client',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ccat string COMMENT 'Phân loại khách hàng (Personal, A, Corperate)',
    affiliated_with string COMMENT 'Khách hàng liên kết',
    f_i bigint COMMENT 'Tổ chức tài chính',
    branch string COMMENT 'Chi nhánh quản lý khách hàng',
    clt bigint COMMENT 'Mã loại khách hàng',
    pcat string COMMENT 'Phân loại danh mục khách hàng',
    service_group string COMMENT 'Nhóm dịch vụ áp dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_client_classification ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE sat_client_classification ADD CONSTRAINT sat_client_classification_pk PRIMARY KEY (client_hashkey);

CREATE OR REPLACE TABLE sat_client_add_data (
    client_hashkey string COMMENT 'Tham chiếu Hub client',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    add_info_01 string COMMENT 'Thông tin bổ sung 1',
    add_info_02 string COMMENT 'Thông tin bổ sung 2',
    add_info_03 string COMMENT 'Thông tin bổ sung 3',
    add_info_04 string COMMENT 'Thông tin bổ sung 4',
    add_date_01 string COMMENT 'Ngày bổ sung 1',
    add_date_02 string COMMENT 'Ngày bổ sung 2'
) CLUSTER BY AUTO;
ALTER TABLE sat_client_add_data ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE sat_client_add_data ADD CONSTRAINT sat_client_add_data_pk PRIMARY KEY (client_hashkey);

CREATE OR REPLACE TABLE link_client_customer (
    link_client_customer_hashkey string COMMENT 'Link Hash Key (client_hashkey, customer_T24_hashkey)',
    client_hashkey string COMMENT 'Tham chiếu Hub khách hàng (WAY4)',
    customer_hashkey string COMMENT 'Tham chiếu Hub khách hàng (T24 hub_customer)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_client_customer ALTER COLUMN link_client_customer_hashkey SET NOT NULL;
ALTER TABLE link_client_customer ADD CONSTRAINT link_client_customer_pk PRIMARY KEY (link_client_customer_hashkey);

CREATE OR REPLACE TABLE sat_client_address (
    client_hashkey string COMMENT 'Tham chiếu Hub client',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active Business key ( client_address.id )',
    address_name string COMMENT 'Tên địa chỉ',
    address_line_1 string COMMENT 'Địa chỉ dòng 1',
    address_line_2 string COMMENT 'Địa chỉ dòng 2',
    address_line_3 string COMMENT 'Địa chỉ dòng 3',
    address_line_4 string COMMENT 'Địa chỉ dòng 4',
    title string COMMENT 'Mã danh xưng',
    salutation_suffix string COMMENT 'Hậu tố danh xưng',
    first_nam string COMMENT 'Tên của khách hàng',
    last_nam string COMMENT 'Họ của khách hàng',
    birth_nam string COMMENT 'Tên khai sinh',
    address_zip string COMMENT 'Mã bưu chính',
    city string COMMENT 'Thành phố',
    state string COMMENT 'Tỉnh / Bang',
    country string COMMENT 'Quốc gia',
    zip_code string COMMENT 'Mã bưu điện',
    phone string COMMENT 'Điện thoại',
    phone_h string COMMENT 'SĐT nhà',
    phone_m string COMMENT 'SĐT di động',
    fax string COMMENT 'Fax',
    fax_h string COMMENT 'Fax nhà',
    email string COMMENT 'Email',
    url string COMMENT 'Website',
    location string COMMENT 'Vị trí / mô tả địa chỉ',
    address_type string COMMENT 'Loại địa chỉ',
    date_from string COMMENT 'Ngày hiệu lực',
    date_to string COMMENT 'Ngày hết hiệu lực',
    is_active string COMMENT 'Trạng thái hoạt động',
    parent_address string COMMENT 'Mã định danh của địa chỉ cấp cha',
    copy_to_address string COMMENT 'Mã định danh địa chỉ dùng để sao chép thông tin',
    language bigint COMMENT 'Mã ngôn ngữ',
    municipality_code string COMMENT 'Mã định danh khu vực hành chính',
    delivery_type bigint COMMENT 'Phân loại phương thức chuyển phát',
    add_info string COMMENT 'Thông tin bổ sung',
    is_ready string COMMENT 'Cờ xác nhận sẵn sàng sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_client_address ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE sat_client_address ADD CONSTRAINT sat_client_address_pk PRIMARY KEY (client_hashkey);

CREATE OR REPLACE TABLE hub_device (
    device_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_device ALTER COLUMN device_hashkey SET NOT NULL;
ALTER TABLE hub_device ADD CONSTRAINT hub_device_pk PRIMARY KEY (device_hashkey);

CREATE OR REPLACE TABLE sat_device_information (
    device_hashkey string COMMENT 'Tham chiếu Hub device',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    terminal_id string COMMENT 'Mã terminal',
    term_cat string COMMENT 'Loại thiết bị (A=ATM, P=POS)',
    device_type__id bigint COMMENT 'Chi tiết loại thiết bị',
    device_name string COMMENT 'Tên thiết bị',
    location string COMMENT 'Vị trí lắp đặt',
    postal_code string COMMENT 'Mã bưu điện',
    trans_location string COMMENT 'Địa điểm giao dịch',
    serial_number string COMMENT 'Số seri',
    phone string COMMENT 'Số điện thoại',
    protocol string COMMENT 'Giao thức kết nối',
    device_url string COMMENT 'URL cấu hình thiết bị',
    service_group string COMMENT 'Nhóm dịch vụ',
    member_id string COMMENT 'Mã thành viên',
    merchant_id string COMMENT 'Mã merchant',
    configuration bigint COMMENT 'Cấu hình',
    x_25_address string COMMENT 'Địa chỉ mạng X.25',
    f_i bigint COMMENT 'Tổ chức tài chính',
    data_capt_reg string COMMENT 'Đăng ký bắt giữ dữ liệu',
    key_hierarchy bigint COMMENT 'Phân cấp khóa bảo mật',
    pin_prevalidation string COMMENT 'Cấu hình xác thực PIN',
    socket string COMMENT 'Cấu hình cổng kết nối',
    hardware__id bigint COMMENT 'Mã định danh phần cứng',
    mac_status string COMMENT 'Trạng thái MAC'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_information ALTER COLUMN device_hashkey SET NOT NULL;
ALTER TABLE sat_device_information ADD CONSTRAINT sat_device_information_pk PRIMARY KEY (device_hashkey);

CREATE OR REPLACE TABLE sat_device_time (
    device_hashkey string COMMENT 'Tham chiếu Hub device',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    gmt_offset bigint COMMENT 'Múi giờ',
    time_from string COMMENT 'Thời gian hoạt động từ',
    time_to string COMMENT 'Thời gian hoạt động đến',
    working_time string COMMENT 'Giờ làm việc',
    cut_off_time string COMMENT 'Giờ kết sổ'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_time ALTER COLUMN device_hashkey SET NOT NULL;
ALTER TABLE sat_device_time ADD CONSTRAINT sat_device_time_pk PRIMARY KEY (device_hashkey);

CREATE OR REPLACE TABLE sat_device_limit (
    device_hashkey string COMMENT 'Tham chiếu Hub device',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    transaction_class string COMMENT 'Loại giao dịch (Retail/Cash)',
    curr string COMMENT 'Loại tiền tệ',
    coin_limit bigint COMMENT 'Hạn mức tiền lẻ',
    global_limit decimal(38,10) COMMENT 'Hạn mức toàn cầu',
    denom_dict bigint COMMENT 'Từ điển mệnh giá'
) CLUSTER BY AUTO;
ALTER TABLE sat_device_limit ALTER COLUMN device_hashkey SET NOT NULL;
ALTER TABLE sat_device_limit ADD CONSTRAINT sat_device_limit_pk PRIMARY KEY (device_hashkey);

CREATE OR REPLACE TABLE link_liability_contract_account_contract (
    link_liability_contract_account_contract_hashkey string COMMENT 'Link Hash Key',
    liability_contract_hashkey string COMMENT 'Tham chiếu Hub liablity contract',
    account_contract_hashkey string COMMENT 'Tham chiếu Hub account contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_liability_contract_account_contract ALTER COLUMN link_liability_contract_account_contract_hashkey SET NOT NULL;
ALTER TABLE link_liability_contract_account_contract ADD CONSTRAINT link_liability_contract_account_contract_pk PRIMARY KEY (link_liability_contract_account_contract_hashkey);

CREATE OR REPLACE TABLE link_account_contract_card (
    link_account_contract_card_hashkey string COMMENT 'Link Hash Key',
    account_contract_hashkey string COMMENT 'Tham chiếu Hub account contract',
    card_hashkey string COMMENT 'Tham chiếu Hub card',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_account_contract_card ALTER COLUMN link_account_contract_card_hashkey SET NOT NULL;
ALTER TABLE link_account_contract_card ADD CONSTRAINT link_account_contract_card_pk PRIMARY KEY (link_account_contract_card_hashkey);

CREATE OR REPLACE TABLE hub_document (
    document_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_document ALTER COLUMN document_hashkey SET NOT NULL;
ALTER TABLE hub_document ADD CONSTRAINT hub_document_pk PRIMARY KEY (document_hashkey);

CREATE OR REPLACE TABLE link_doc_fin_auth (
    link_doc_fin_auth_hashkey string COMMENT 'Link Hash Key',
    document_fin_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    document_auth_hashkey string COMMENT 'Tham chiếu Hub giao dịch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_doc_fin_auth ALTER COLUMN link_doc_fin_auth_hashkey SET NOT NULL;
ALTER TABLE link_doc_fin_auth ADD CONSTRAINT link_doc_fin_auth_pk PRIMARY KEY (link_doc_fin_auth_hashkey);

CREATE OR REPLACE TABLE sat_document_source (
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    source_number string COMMENT 'Tài khoản nguồn',
    source_channel string COMMENT 'Kênh nguồn',
    source_code string COMMENT 'Mã nguồn',
    source_fee_code string COMMENT 'Mã loại phí nguồn',
    source_idt_scheme string COMMENT 'Loại định danh nguồn',
    source_member_id string COMMENT 'Mã thành viên nguồn',
    source_spc string COMMENT 'Mã xử lý nguồn',
    source_acc_type string COMMENT 'Loại tài khoản nguồn',
    source_service bigint COMMENT 'Dịch vụ nguồn',
    s_cat string COMMENT 'Phân loại nguồn',
    source_fee_curr string COMMENT 'Loại đồng tiền',
    source_fee_amount decimal(38,10) COMMENT 'Phí giao dịch',
    sending_bin string COMMENT 'Mã BIN gửi giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_document_source ALTER COLUMN document_hashkey SET NOT NULL;
ALTER TABLE sat_document_source ADD CONSTRAINT sat_document_source_pk PRIMARY KEY (document_hashkey);

CREATE OR REPLACE TABLE sat_document_target (
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    target_number string COMMENT 'Tài khoản đích',
    target_channel string COMMENT 'Kênh đích',
    target_code string COMMENT 'Mã đích',
    target_fee_code string COMMENT 'Mã loại phí đích',
    t_cat string COMMENT 'Phân loại đích',
    target_idt_scheme string COMMENT 'Loại định danh đích',
    target_member_id string COMMENT 'Mã thành viên đích',
    target_bin_id bigint COMMENT 'Mã bin đích',
    target_spc string COMMENT 'Mã xử lý đích',
    target_acc_type string COMMENT 'Loại tài khoản đích',
    target_service bigint COMMENT 'Dịch vụ đích',
    target_fee_curr string COMMENT 'Loại đồng tiền',
    target_fee_amount decimal(38,10) COMMENT 'Phí giao dịch',
    target_country string COMMENT 'Mã quốc gia đích'
) CLUSTER BY AUTO;
ALTER TABLE sat_document_target ALTER COLUMN document_hashkey SET NOT NULL;
ALTER TABLE sat_document_target ADD CONSTRAINT sat_document_target_pk PRIMARY KEY (document_hashkey);

CREATE OR REPLACE TABLE sat_document_classification (
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    request_category string COMMENT '- P: Advice - Q: Request - R: Reversal',
    is_authorization string COMMENT '- N: financial request - Y: authorization request',
    service_class string COMMENT '- T: Transaction - I: Interest - M: Misc fee - A: Account transfer - B: Balance inquiry',
    posting_status string COMMENT '- P: Posted - W: Waiting',
    outward_status string COMMENT 'Trạng thái gửi đi',
    message_category string COMMENT 'Nhóm message',
    trans_type bigint COMMENT 'Mã loại giao dịch',
    trans_condition string COMMENT 'Điều kiện giao dịch',
    trans_cond_attr bigint COMMENT 'Cờ/Thuộc tính điều kiện của giao dịch chính',
    sec_trans_cond_att bigint COMMENT 'Thuộc tính điều kiện của giao dịch phụ',
    requirement string COMMENT 'Yêu cầu áp dụng cho chứng từ'
) CLUSTER BY AUTO;
ALTER TABLE sat_document_classification ALTER COLUMN document_hashkey SET NOT NULL;
ALTER TABLE sat_document_classification ADD CONSTRAINT sat_document_classification_pk PRIMARY KEY (document_hashkey);

CREATE OR REPLACE TABLE sat_document_description (
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    merchant_id string COMMENT 'Mã merchant',
    doc__chain__id bigint COMMENT 'ID chuỗi giao dịch',
    doc__orig__id bigint COMMENT 'ID giao dịch gốc',
    doc__summ__id bigint COMMENT 'ID giao dịch tổng hợp',
    rec_member_id string COMMENT 'Mã định danh thành viên nhận',
    send_member_id string COMMENT 'Mã định danh thành viên gửi',
    sic_code string COMMENT 'Mã ngành nghề',
    trans_city string COMMENT 'Thành phố giao dịch',
    trans_country string COMMENT 'Quốc gia giao dịch',
    trans_state string COMMENT 'Bang giao dịch',
    trans_curr string COMMENT 'Tiền tệ giao dịch',
    trans_amount decimal(38,10) COMMENT 'Số tiền giao dịch',
    trans_details string COMMENT 'Chi tiết giao dịch',
    trans_date string COMMENT 'Ngày giao dịch',
    posting_date string COMMENT 'Ngày ghi sổ',
    settl_curr string COMMENT 'Tiền tệ sau khi settle',
    settl_amount decimal(38,10) COMMENT 'Giá trị giao dịch sau khi settle',
    fx_settl_date string COMMENT 'Ngày settle',
    rec_date string COMMENT 'Ngày đối soát',
    reason_code string COMMENT 'Mã lý do / reject code',
    reason_details string COMMENT 'Mô tả lý do',
    return_code bigint COMMENT 'Mã trả về',
    recons_amount decimal(38,10) COMMENT 'Số tiền dùng để đối soát/bù trừ',
    recons_curr string COMMENT 'Loại tiền tệ dùng để đối soát/bù trừ',
    sec_trans_date string COMMENT 'Ngày diễn ra giao dịch phụ/bổ sung',
    card_expire string COMMENT 'Ngày hết hạn thẻ',
    card_seqv_number string COMMENT 'Số thứ tự phát hành thẻ',
    add_info string COMMENT 'Thông tin bổ sung',
    comment_text string COMMENT 'Ghi chú/diễn giải'
) CLUSTER BY AUTO;
ALTER TABLE sat_document_description ALTER COLUMN document_hashkey SET NOT NULL;
ALTER TABLE sat_document_description ADD CONSTRAINT sat_document_description_pk PRIMARY KEY (document_hashkey);

CREATE OR REPLACE TABLE sat_document_identifiers (
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    auth_code string COMMENT 'Mã xác thực (F38 ISO8583)',
    source_reg_num string COMMENT 'Mã tham chiếu tới hệ thống khác',
    ret_ref_number string COMMENT 'Mã tham chiếu (F37 ISO8583)',
    acq_ref_number string COMMENT 'Mã tham chiếu acquiring',
    iss_ref_number string COMMENT 'Mã tham chiếu issuing',
    ps_ref_number string COMMENT 'Mã tham chiếu payment system',
    nw_ref_date string COMMENT 'Ngày tham chiếu',
    number_of_sub_s bigint COMMENT 'Tổng số lượng giao dịch con',
    number_in_chain bigint COMMENT 'Số thứ tự trong chuỗi',
    action string COMMENT 'Mã hành động',
    partition_key string COMMENT 'Khóa phân vùng dữ liệu vật lý trên hệ thống lõi',
    change_version bigint COMMENT 'Số phiên bản thay đổi của bản ghi chứng từ',
    synch_tag string COMMENT 'Thẻ đồng bộ hóa dữ liệu hệ thống',
    bin_record bigint COMMENT 'Mã định danh/bản ghi cấu hình BIN liên quan'
) CLUSTER BY AUTO;
ALTER TABLE sat_document_identifiers ALTER COLUMN document_hashkey SET NOT NULL;
ALTER TABLE sat_document_identifiers ADD CONSTRAINT sat_document_identifiers_pk PRIMARY KEY (document_hashkey);

CREATE OR REPLACE TABLE hub_m_transaction (
    m_transaction_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (Mã giao dịch settle)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_m_transaction ALTER COLUMN m_transaction_hashkey SET NOT NULL;
ALTER TABLE hub_m_transaction ADD CONSTRAINT hub_m_transaction_pk PRIMARY KEY (m_transaction_hashkey);

CREATE OR REPLACE TABLE sat_m_transaction_information (
    m_transaction_hashkey string COMMENT 'Tham chiếu Hub m_transaction',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    posting_date string COMMENT 'Ngày hạch toán',
    local_date string COMMENT 'Ngày giao dịch (local)',
    due_date string COMMENT 'Ngày đáo hạn',
    posting_db_date string COMMENT 'Ngày hệ thống',
    posting_status string COMMENT 'Trạng thái ghi sổ',
    entry_type string COMMENT 'Loại bút toán',
    request_cat string COMMENT 'Loại yêu cầu',
    service_class string COMMENT 'Nhóm dịch vụ',
    trans_subtype bigint COMMENT 'Phân loại giao dịch',
    direction bigint COMMENT 'Chiều giao dịch',
    trans_code string COMMENT 'Mã giao dịch',
    trans_curr string COMMENT 'Tiền tệ giao dịch',
    trans_amount decimal(38,10) COMMENT 'Số tiền giao dịch',
    local_amount decimal(38,10) COMMENT 'Số tiền hạch toán',
    fx_seqv_n bigint COMMENT 'Số FX sequence',
    portion bigint COMMENT 'Phần giao dịch',
    mtr_details string COMMENT 'Diễn giải',
    f_i bigint COMMENT 'Tổ chức tài chính',
    contract bigint COMMENT 'Mã hợp đồng/tài khoản',
    partition_key string COMMENT 'Khóa phân vùng dữ liệu vật lý',
    hash__id bigint COMMENT 'Mã băm'
) CLUSTER BY AUTO;
ALTER TABLE sat_m_transaction_information ALTER COLUMN m_transaction_hashkey SET NOT NULL;
ALTER TABLE sat_m_transaction_information ADD CONSTRAINT sat_m_transaction_information_pk PRIMARY KEY (m_transaction_hashkey);

CREATE OR REPLACE TABLE sat_m_transaction_source (
    m_transaction_hashkey string COMMENT 'Tham chiếu Hub m_transaction',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    source_account string COMMENT 'Tài khoản nguồn (kế toán)',
    s_amount decimal(38,10) COMMENT 'Số tiền nguồn',
    s_fee_amount decimal(38,10) COMMENT 'Phí nguồn',
    source_code string COMMENT 'Mã nguồn',
    source_service bigint COMMENT 'Dịch vụ nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_m_transaction_source ALTER COLUMN m_transaction_hashkey SET NOT NULL;
ALTER TABLE sat_m_transaction_source ADD CONSTRAINT sat_m_transaction_source_pk PRIMARY KEY (m_transaction_hashkey);

CREATE OR REPLACE TABLE sat_m_transaction_target (
    m_transaction_hashkey string COMMENT 'Tham chiếu Hub m_transaction',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    target_account string COMMENT 'Tài khoản đích (kế toán)',
    t_amount decimal(38,10) COMMENT 'Số tiền đích',
    t_fee_amount decimal(38,10) COMMENT 'Phí đích',
    target_code string COMMENT 'Mã đích',
    target_service bigint COMMENT 'Dịch vụ đích'
) CLUSTER BY AUTO;
ALTER TABLE sat_m_transaction_target ALTER COLUMN m_transaction_hashkey SET NOT NULL;
ALTER TABLE sat_m_transaction_target ADD CONSTRAINT sat_m_transaction_target_pk PRIMARY KEY (m_transaction_hashkey);

CREATE OR REPLACE TABLE link_doc_m_transaction (
    link_doc_m_transaction_hashkey string COMMENT 'Link Hash Key',
    m_transaction_hashkey string COMMENT 'Tham chiếu Hub giao dịch settle',
    document_hashkey string COMMENT 'Tham chiếu Hub doc',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_doc_m_transaction ALTER COLUMN link_doc_m_transaction_hashkey SET NOT NULL;
ALTER TABLE link_doc_m_transaction ADD CONSTRAINT link_doc_m_transaction_pk PRIMARY KEY (link_doc_m_transaction_hashkey);

CREATE OR REPLACE TABLE hub_product (
    product_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_product ALTER COLUMN product_hashkey SET NOT NULL;
ALTER TABLE hub_product ADD CONSTRAINT hub_product_pk PRIMARY KEY (product_hashkey);

CREATE OR REPLACE TABLE sat_product_information (
    product_hashkey string COMMENT 'Tham chiếu Hub product',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    code string COMMENT 'Mã sản phẩm',
    code_2 string COMMENT 'Mã sản phẩm 2',
    code_3 string COMMENT 'Mã sản phẩm 3',
    internal_code string COMMENT 'Mã nội bộ hệ thống (auto generated)',
    name string COMMENT 'Tên sản phẩm',
    main_product bigint COMMENT 'Mã sản phẩm chính',
    product_group string COMMENT 'Nhóm sản phẩm',
    service_pack bigint COMMENT 'Gói dịch vụ',
    acc_scheme bigint COMMENT 'Cấu hình hạch toán',
    tariff_domain bigint COMMENT 'Miền biểu phí',
    custom_data string COMMENT 'Dữ liệu tùy chỉnh bổ sung',
    is_active string COMMENT 'Cờ trạng thái hoạt động',
    product_status string COMMENT 'Trạng thái hiện tại của sản phẩm',
    icon string COMMENT 'Biểu tượng hiển thị',
    is_ready string COMMENT 'Cờ xác nhận sẵn sàng sử dụng',
    ccat string COMMENT 'Phân loại khách hàng',
    pcat string COMMENT 'Phân loại sản phẩm',
    f_i bigint COMMENT 'Tổ chức tài chính',
    client_type bigint COMMENT 'Phân loại đối tượng khách hàng',
    con_cat string COMMENT 'Phân loại hợp đồng',
    serv_pack_type bigint COMMENT 'Loại gói dịch vụ áp dụng',
    contract_role string COMMENT 'Vai trò của hợp đồng',
    base_relation string COMMENT 'Mối quan hệ cơ sở',
    liab_category string COMMENT 'Phân loại tài chính/công nợ của hợp đồng',
    report_type string COMMENT 'Loại hình báo cáo',
    contr_type bigint COMMENT 'Loại hợp đồng',
    contr_subtype bigint COMMENT 'Phân loại phụ của hợp đồng',
    appl_pr_group__id bigint COMMENT 'ID nhóm sản phẩm ứng dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_product_information ALTER COLUMN product_hashkey SET NOT NULL;
ALTER TABLE sat_product_information ADD CONSTRAINT sat_product_information_pk PRIMARY KEY (product_hashkey);

CREATE OR REPLACE TABLE sat_product_limit (
    product_hashkey string COMMENT 'Tham chiếu Hub product',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    max_credit_limit bigint COMMENT 'Hạn mức tín dụng tối đa',
    min_credit_limit bigint COMMENT 'Hạn mức tín dụng tối thiểu',
    default_credit_limit bigint COMMENT 'Hạn mức tín dụng mặc định',
    n_contracts bigint COMMENT 'Số lượng hợp đồng tối đa',
    scoring_model bigint COMMENT 'Mô hình chấm điểm tín dụng',
    check_available string COMMENT 'Quy tắc kiểm tra hạn mức',
    check_usage string COMMENT 'Quy tắc kiểm tra mức độ sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_product_limit ALTER COLUMN product_hashkey SET NOT NULL;
ALTER TABLE sat_product_limit ADD CONSTRAINT sat_product_limit_pk PRIMARY KEY (product_hashkey);

CREATE OR REPLACE TABLE sat_product_reference (
    product_hashkey string COMMENT 'Tham chiếu Hub product',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    tariff_domain_template bigint COMMENT 'Mẫu miền biểu phí áp dụng',
    copy_from_product bigint COMMENT 'Nguồn sao chép cấu hình sản phẩm',
    base_product bigint COMMENT 'Mã sản phẩm cơ sở',
    parent_code string COMMENT 'Mã sản phẩm cha',
    reporting_product bigint COMMENT 'Sản phẩm dùng để tổng hợp báo cáo',
    product_template bigint COMMENT 'Mẫu sản phẩm được áp dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_product_reference ALTER COLUMN product_hashkey SET NOT NULL;
ALTER TABLE sat_product_reference ADD CONSTRAINT sat_product_reference_pk PRIMARY KEY (product_hashkey);

CREATE OR REPLACE TABLE sat_product_date (
    product_hashkey string COMMENT 'Tham chiếu Hub product',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    date_from string COMMENT 'Ngày bắt đầu hiệu lực',
    date_to string COMMENT 'Ngày kết thúc hiệu lực',
    date_scheme bigint COMMENT 'Sơ đồ cấu hình'
) CLUSTER BY AUTO;
ALTER TABLE sat_product_date ALTER COLUMN product_hashkey SET NOT NULL;
ALTER TABLE sat_product_date ADD CONSTRAINT sat_product_date_pk PRIMARY KEY (product_hashkey);

CREATE OR REPLACE TABLE hub_balance (
    balance_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_balance ALTER COLUMN balance_hashkey SET NOT NULL;
ALTER TABLE hub_balance ADD CONSTRAINT hub_balance_pk PRIMARY KEY (balance_hashkey);

CREATE OR REPLACE TABLE sat_balance_information (
    balance_hashkey string COMMENT 'Tham chiếu Hub balance',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    total_balance decimal(38,10) COMMENT 'Tổng số dư hiện tại',
    total_blocked bigint COMMENT 'Tổng số tiền đang bị phong tỏa',
    credit_balance decimal(38,10) COMMENT 'Số dư có (tiền khách hàng nạp dư)',
    past_due_balance decimal(38,10) COMMENT 'Tổng dư nợ đã quá hạn thanh toán',
    provision_balance decimal(38,10) COMMENT 'Số dư trích lập dự phòng',
    dispute bigint COMMENT 'Số dư đang trong quá trình tra soát/khiếu nại',
    savings_balance decimal(38,10) COMMENT 'Số dư tài khoản tiết kiệm',
    fixed_term_balance decimal(38,10) COMMENT 'Số dư có kỳ hạn cố định',
    flexible_term_balance decimal(38,10) COMMENT 'Số dư có kỳ hạn linh hoạt',
    issuing_number string COMMENT 'Số phát hành',
    branch string COMMENT 'Mã chi nhánh',
    previous_banking_date string COMMENT 'Ngày làm việc ngân hàng trước đó',
    banking_date string COMMENT 'Ngày làm việc ngân hàng hiện tại',
    processing_date string COMMENT 'Ngày giờ xử lý thực tế trên hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_balance_information ALTER COLUMN balance_hashkey SET NOT NULL;
ALTER TABLE sat_balance_information ADD CONSTRAINT sat_balance_information_pk PRIMARY KEY (balance_hashkey);

CREATE OR REPLACE TABLE sat_balance_principal (
    balance_hashkey string COMMENT 'Tham chiếu Hub balance',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    principal_balance decimal(38,10) COMMENT 'Tổng dư nợ gốc',
    principal_sale bigint COMMENT 'Dư nợ gốc từ giao dịch mua sắm',
    principal_cash bigint COMMENT 'Dư nợ gốc từ giao dịch rút tiền mặt',
    principal_fee decimal(38,10) COMMENT 'Dư nợ gốc hình thành từ phí',
    principal_instalment bigint COMMENT 'Dư nợ gốc từ các khoản trả góp',
    dlq_value bigint COMMENT 'Giá trị khoản nợ chậm trả',
    debt_level bigint COMMENT 'Nhóm nợ hiện tại',
    debt_level_by_late_date bigint COMMENT 'Nhóm nợ được tính toán dựa trên số ngày chậm trả'
) CLUSTER BY AUTO;
ALTER TABLE sat_balance_principal ALTER COLUMN balance_hashkey SET NOT NULL;
ALTER TABLE sat_balance_principal ADD CONSTRAINT sat_balance_principal_pk PRIMARY KEY (balance_hashkey);

CREATE OR REPLACE TABLE sat_balance_interest_fee (
    balance_hashkey string COMMENT 'Tham chiếu Hub balance',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    interest decimal(38,10) COMMENT 'Số dư lãi thông thường',
    sale_interest decimal(38,10) COMMENT 'Số dư lãi từ giao dịch mua sắm',
    cash_interest decimal(38,10) COMMENT 'Số dư lãi từ rút tiền mặt',
    accrued_interest decimal(38,10) COMMENT 'Lãi cộng dồn/dự thu',
    ovd_interest decimal(38,10) COMMENT 'Số dư lãi quá hạn',
    late_payment_fee decimal(38,10) COMMENT 'Phí phạt chậm thanh toán',
    ovd_late_payment_fee decimal(38,10) COMMENT 'Phí phạt chậm thanh toán đã quá hạn',
    late_date bigint COMMENT 'Ngày trễ hạn thanh toán',
    ovd_date bigint COMMENT 'Ngày chính thức chuyển sang trạng thái quá hạn',
    provision_ind bigint COMMENT 'Cờ báo hiệu khoản nợ gốc cần trích lập dự phòng',
    grace_ind bigint COMMENT 'Cờ báo hiệu tài khoản đang trong thời gian ân hạn miễn lãi'
) CLUSTER BY AUTO;
ALTER TABLE sat_balance_interest_fee ALTER COLUMN balance_hashkey SET NOT NULL;
ALTER TABLE sat_balance_interest_fee ADD CONSTRAINT sat_balance_interest_fee_pk PRIMARY KEY (balance_hashkey);

CREATE OR REPLACE TABLE sat_balance_instalment (
    balance_hashkey string COMMENT 'Tham chiếu Hub balance',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    instalment_balance decimal(38,10) COMMENT 'Tổng dư nợ trả góp',
    short_instalment_balance decimal(38,10) COMMENT 'Dư nợ trả góp ngắn hạn',
    medium_instalment_balance decimal(38,10) COMMENT 'Dư nợ trả góp trung hạn',
    long_instalment_balance decimal(38,10) COMMENT 'Dư nợ trả góp dài hạn'
) CLUSTER BY AUTO;
ALTER TABLE sat_balance_instalment ALTER COLUMN balance_hashkey SET NOT NULL;
ALTER TABLE sat_balance_instalment ADD CONSTRAINT sat_balance_instalment_pk PRIMARY KEY (balance_hashkey);

CREATE OR REPLACE TABLE hub_acq_dev_cycle (
    acq_dev_cycle_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_acq_dev_cycle ALTER COLUMN acq_dev_cycle_hashkey SET NOT NULL;
ALTER TABLE hub_acq_dev_cycle ADD CONSTRAINT hub_acq_dev_cycle_pk PRIMARY KEY (acq_dev_cycle_hashkey);

CREATE OR REPLACE TABLE link_acq_dev_cycle_device (
    link_acq_dev_cycle_device_hashkey string COMMENT 'Link Hash Key',
    acq_dev_cycle_hashkey string COMMENT 'Tham chiếu Hub acq_dev_cycle',
    device_hashkey string COMMENT 'Tham chiếu Hub device',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_acq_dev_cycle_device ALTER COLUMN link_acq_dev_cycle_device_hashkey SET NOT NULL;
ALTER TABLE link_acq_dev_cycle_device ADD CONSTRAINT link_acq_dev_cycle_device_pk PRIMARY KEY (link_acq_dev_cycle_device_hashkey);

CREATE OR REPLACE TABLE sat_acq_dev_cycle_information (
    acq_dev_cycle_hashkey string COMMENT 'Tham chiếu Hub acq_dev_cycle',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    device_name string COMMENT 'Tên định danh của thiết bị (cây ATM)',
    cycle_type string COMMENT 'Phân loại chu kỳ',
    cycle_number bigint COMMENT 'Số thứ tự hoặc mã số tham chiếu của chu kỳ',
    cycle_code string COMMENT 'Mã chu kỳ nghiệp vụ',
    date_from string COMMENT 'Thời điểm bắt đầu chu kỳ',
    date_to string COMMENT 'Thời điểm kết thúc chu kỳ',
    card_retained bigint COMMENT 'Số lượng thẻ bị nuốt/giữ lại trong chu kỳ này',
    cycle_event string COMMENT 'Sự kiện phát sinh hoặc trạng thái của chu kỳ',
    state_version bigint COMMENT 'Phiên bản trạng thái của bản ghi',
    repl_cycle bigint COMMENT 'Chỉ số/Chu kỳ tiếp quỹ',
    repl_cycle_event string COMMENT 'Sự kiện chi tiết liên quan đến quá trình tiếp quỹ',
    merchant_card_cont bigint COMMENT 'Định danh hoặc số đếm thẻ liên quan đến Merchant'
) CLUSTER BY AUTO;
ALTER TABLE sat_acq_dev_cycle_information ALTER COLUMN acq_dev_cycle_hashkey SET NOT NULL;
ALTER TABLE sat_acq_dev_cycle_information ADD CONSTRAINT sat_acq_dev_cycle_information_pk PRIMARY KEY (acq_dev_cycle_hashkey);

CREATE OR REPLACE TABLE hub_billing (
    billing_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_billing ALTER COLUMN billing_hashkey SET NOT NULL;
ALTER TABLE hub_billing ADD CONSTRAINT hub_billing_pk PRIMARY KEY (billing_hashkey);

CREATE OR REPLACE TABLE sat_billing_information (
    billing_hashkey string COMMENT 'Tham chiếu Hub billing',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    billing_date string COMMENT 'Ngày sao kê',
    issuing_number string COMMENT 'Số định danh phát hành/Số thẻ',
    due_date string COMMENT 'Ngày đến hạn thanh toán',
    processing_date string COMMENT 'Ngày process',
    banking_date string COMMENT 'Ngày hạch toán',
    credit_limit decimal(38,10) COMMENT 'Hạn mức tín dụng',
    instalment_balance decimal(38,10) COMMENT 'Dư nợ trả góp còn lại',
    total_balance decimal(38,10) COMMENT 'Dư nợ',
    due_amount decimal(38,10) COMMENT 'Số tiền quá hạn',
    debit_amount decimal(38,10) COMMENT 'Dư nợ',
    credit_amount decimal(38,10) COMMENT 'Dư có',
    fee_amount decimal(38,10) COMMENT 'Phí',
    interest_amount decimal(38,10) COMMENT 'Lãi',
    instalment_amount decimal(38,10) COMMENT 'Dư nợ trả góp cần thanh toán trong kì',
    opening_balance decimal(38,10) COMMENT 'Số dư đầu kỳ sao kê',
    instalment_creation bigint COMMENT 'Giá trị/Số tiền khởi tạo trả góp',
    suspended_interest_amount decimal(38,10) COMMENT 'Số tiền lãi bị treo/chưa hạch toán',
    deposit_interest_amount decimal(38,10) COMMENT 'Số dư tiền lãi huy động/tiền gửi',
    ovd_interest_amount decimal(38,10) COMMENT 'Số tiền lãi phát sinh do quá hạn',
    transit_interest_amount decimal(38,10) COMMENT 'Lãi chuyển tiếp',
    row_number bigint COMMENT 'Số dòng'
) CLUSTER BY AUTO;
ALTER TABLE sat_billing_information ALTER COLUMN billing_hashkey SET NOT NULL;
ALTER TABLE sat_billing_information ADD CONSTRAINT sat_billing_information_pk PRIMARY KEY (billing_hashkey);

CREATE OR REPLACE TABLE sat_billing_status (
    billing_hashkey string COMMENT 'Tham chiếu Hub billing',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    email_status string COMMENT 'Trạng thái gửi mail sao kê',
    postal_status string COMMENT 'Trạng thái gửi thư sao kê',
    sms_status string COMMENT 'Trạng thái gửi sms sao kê',
    generate_status string COMMENT 'Trạng thái tạo sao kê',
    send_date string COMMENT 'Ngày gửi',
    sent_sms_date string COMMENT 'Ngày gửi sms',
    sent_postal_date string COMMENT 'Ngày gửi thư',
    generated_date string COMMENT 'Ngày file sao kê được tạo ra',
    sent_email_date string COMMENT 'Ngày thực tế đã gửi file sao kê qua email',
    sent_noti_date string COMMENT 'Ngày thực tế đã gửi thông báo',
    url_ind string COMMENT 'Cờ đánh dấu sao kê có kèm URL tải file',
    receive_email string COMMENT 'Tùy chọn KH đăng ký nhận qua email',
    receive_sms string COMMENT 'Tùy chọn KH đăng ký nhận qua SMS',
    receive_noti string COMMENT 'Tùy chọn KH đăng ký nhận thông báo qua app',
    send_ind string COMMENT 'Cờ/Chỉ báo hệ thống cần gửi sao kê hay không',
    issuing_status_code string COMMENT 'Mã trạng thái hợp đồng/thẻ tại kỳ sao kê',
    noti_status string COMMENT 'Trạng thái gửi các thông báo khác',
    provision_ind string COMMENT 'Cờ/Chỉ báo liên quan đến trích lập dự phòng',
    delivery_type string COMMENT 'Phương thức ưu tiên nhận sao kê của KH'
) CLUSTER BY AUTO;
ALTER TABLE sat_billing_status ALTER COLUMN billing_hashkey SET NOT NULL;
ALTER TABLE sat_billing_status ADD CONSTRAINT sat_billing_status_pk PRIMARY KEY (billing_hashkey);

CREATE OR REPLACE TABLE hub_payment (
    payment_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_payment ALTER COLUMN payment_hashkey SET NOT NULL;
ALTER TABLE hub_payment ADD CONSTRAINT hub_payment_pk PRIMARY KEY (payment_hashkey);

CREATE OR REPLACE TABLE link_payment_card (
    link_payment_card_hashkey string COMMENT 'Link Hash Key',
    payment_hashkey string COMMENT 'Tham chiếu Hub payment',
    card_hashkey string COMMENT 'Tham chiếu Hub card',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_card ALTER COLUMN link_payment_card_hashkey SET NOT NULL;
ALTER TABLE link_payment_card ADD CONSTRAINT link_payment_card_pk PRIMARY KEY (link_payment_card_hashkey);

CREATE OR REPLACE TABLE link_payment_m_transaction (
    link_payment_m_transaction_hashkey string COMMENT 'Link Hash Key',
    payment_hashkey string COMMENT 'Tham chiếu Hub payment',
    m_transaction_hashkey string COMMENT 'Tham chiếu Hub giao dịch settle',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_m_transaction ALTER COLUMN link_payment_m_transaction_hashkey SET NOT NULL;
ALTER TABLE link_payment_m_transaction ADD CONSTRAINT link_payment_m_transaction_pk PRIMARY KEY (link_payment_m_transaction_hashkey);

CREATE OR REPLACE TABLE sat_payment_information (
    payment_hashkey string COMMENT 'Tham chiếu Hub payment',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    transaction_date string COMMENT 'Ngày thực hiện giao dịch thanh toán',
    posting_date string COMMENT 'Ngày giao dịch thanh toán được hạch toán vào hệ thống',
    issuing_number string COMMENT 'Số định danh phát hành liên quan đến khoản thanh toán',
    card_number string COMMENT 'Số thẻ thực hiện giao dịch',
    currency string COMMENT 'Loại tiền tệ của giao dịch thanh toán',
    trans_subtype bigint COMMENT 'Mã phân loại chi tiết/loại hình giao dịch thanh toán',
    source_table string COMMENT 'Tên bảng gốc chứa dữ liệu thanh toán',
    source_ref_id bigint COMMENT 'ID tham chiếu đến bảng gốc'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_information ALTER COLUMN payment_hashkey SET NOT NULL;
ALTER TABLE sat_payment_information ADD CONSTRAINT sat_payment_information_pk PRIMARY KEY (payment_hashkey);

CREATE OR REPLACE TABLE sat_payment_amount (
    payment_hashkey string COMMENT 'Tham chiếu Hub payment',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    amount decimal(38,10) COMMENT 'Số tiền thanh toán nguyên tệ',
    settlement_amount decimal(38,10) COMMENT 'Số tiền thanh toán sau khi đã quyết toán/chuyển đổi ngoại tệ',
    interest decimal(38,10) COMMENT 'Số tiền thanh toán được phân bổ cho tiền lãi',
    late_payment_fee decimal(38,10) COMMENT 'Số tiền thanh toán được phân bổ cho phí phạt trả chậm',
    provision bigint COMMENT 'Số tiền liên quan đến dự phòng rủi ro'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_amount ALTER COLUMN payment_hashkey SET NOT NULL;
ALTER TABLE sat_payment_amount ADD CONSTRAINT sat_payment_amount_pk PRIMARY KEY (payment_hashkey);

CREATE OR REPLACE TABLE sat_payment_principal (
    payment_hashkey string COMMENT 'Tham chiếu Hub payment',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    principal_cash bigint COMMENT 'Số tiền thanh toán được phân bổ cho nợ gốc rút tiền mặt',
    principal_sale bigint COMMENT 'Số tiền thanh toán được phân bổ cho nợ gốc mua sắm',
    principal_instalment bigint COMMENT 'Số tiền thanh toán được phân bổ cho nợ gốc trả góp',
    principal_fee decimal(38,10) COMMENT 'Số tiền thanh toán được phân bổ cho các khoản nợ gốc từ phí'
) CLUSTER BY AUTO;
ALTER TABLE sat_payment_principal ALTER COLUMN payment_hashkey SET NOT NULL;
ALTER TABLE sat_payment_principal ADD CONSTRAINT sat_payment_principal_pk PRIMARY KEY (payment_hashkey);

CREATE OR REPLACE TABLE hub_billing_log (
    billing_log_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_billing_log ALTER COLUMN billing_log_hashkey SET NOT NULL;
ALTER TABLE hub_billing_log ADD CONSTRAINT hub_billing_log_pk PRIMARY KEY (billing_log_hashkey);

CREATE OR REPLACE TABLE sat_billing_log_information (
    billing_log_hashkey string COMMENT 'Tham chiếu Hub billing_log',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    total_balance decimal(38,10) COMMENT 'Tổng số dư nợ tại thời điểm chốt',
    statement_balance decimal(38,10) COMMENT 'Số dư chính thức hiển thị trên sao kê',
    total_due bigint COMMENT 'Tổng số tiền tối thiểu/đến hạn cần thanh toán',
    credit_limit bigint COMMENT 'Hạn mức tín dụng tại thời điểm chốt',
    bal_list string COMMENT 'Danh sách chi tiết các loại số dư',
    curr string COMMENT 'Loại tiền tệ của kỳ sao kê'
) CLUSTER BY AUTO;
ALTER TABLE sat_billing_log_information ALTER COLUMN billing_log_hashkey SET NOT NULL;
ALTER TABLE sat_billing_log_information ADD CONSTRAINT sat_billing_log_information_pk PRIMARY KEY (billing_log_hashkey);

CREATE OR REPLACE TABLE sat_billing_log_cycle (
    billing_log_hashkey string COMMENT 'Tham chiếu Hub billing_log',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    cycle_n string COMMENT 'Mã số hoặc tên định danh của chu kỳ sao kê',
    start_billing_date string COMMENT 'Ngày bắt đầu của kỳ sao kê',
    finish_billing_date string COMMENT 'Ngày kết thúc/chốt sổ của kỳ sao kê',
    due_date string COMMENT 'Ngày hạn cuối cùng phải thanh toán cho kỳ này',
    grace_date string COMMENT 'Ngày kết thúc thời gian ân hạn miễn lãi',
    acc_scheme bigint COMMENT 'Cấu hình hạch toán',
    beh_type bigint COMMENT 'Mã loại hành vi của tài khoản',
    serv_pack bigint COMMENT 'Mã gói dịch vụ được áp dụng',
    f_i bigint COMMENT 'Tổ chức tài chính'
) CLUSTER BY AUTO;
ALTER TABLE sat_billing_log_cycle ALTER COLUMN billing_log_hashkey SET NOT NULL;
ALTER TABLE sat_billing_log_cycle ADD CONSTRAINT sat_billing_log_cycle_pk PRIMARY KEY (billing_log_hashkey);

CREATE OR REPLACE TABLE hub_entry (
    entry_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_entry ALTER COLUMN entry_hashkey SET NOT NULL;
ALTER TABLE hub_entry ADD CONSTRAINT hub_entry_pk PRIMARY KEY (entry_hashkey);

CREATE OR REPLACE TABLE link_entry_m_transaction (
    link_entry_m_transaction_hashkey string COMMENT 'Link Hash Key',
    entry_hashkey string COMMENT 'Tham chiếu Hub entry',
    m_transaction_hashkey string COMMENT 'Tham chiếu Hub m_transaction',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_entry_m_transaction ALTER COLUMN link_entry_m_transaction_hashkey SET NOT NULL;
ALTER TABLE link_entry_m_transaction ADD CONSTRAINT link_entry_m_transaction_pk PRIMARY KEY (link_entry_m_transaction_hashkey);

CREATE OR REPLACE TABLE link_entry_document (
    link_entry_document_hashkey string COMMENT 'Link Hash Key',
    entry_hashkey string COMMENT 'Tham chiếu Hub entry',
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_entry_document ALTER COLUMN link_entry_document_hashkey SET NOT NULL;
ALTER TABLE link_entry_document ADD CONSTRAINT link_entry_document_pk PRIMARY KEY (link_entry_document_hashkey);

CREATE OR REPLACE TABLE sat_entry_information (
    entry_hashkey string COMMENT 'Tham chiếu Hub entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    entry_level_type string COMMENT 'Cấp độ bút toán',
    tariff_id bigint COMMENT 'Mã thuế',
    contract_for bigint COMMENT 'Tài khoản/Hợp đồng đích nhận dòng tiền (bút toán)',
    request_cat string COMMENT 'Danh mục yêu cầu',
    service_class string COMMENT 'Phân loại dịch vụ',
    n_c string COMMENT 'Mã phân loại kỹ thuật',
    is_reversed string COMMENT 'Cờ đánh dấu đảo ngược',
    storno_plan bigint COMMENT 'Kế hoạch đảo bút toán',
    cre_by_storno_plan bigint COMMENT 'Cờ tạo bởi kế hoạch đảo',
    partition_key string COMMENT 'Khóa phân vùng dữ liệu',
    item__id bigint COMMENT 'ID hạng mục/bút toán chi tiết',
    due_mtr_id bigint COMMENT 'ID bộ đếm theo dõi đến hạn/khoản nợ',
    service_id bigint COMMENT 'ID dịch vụ',
    analytic_item__id bigint COMMENT 'ID hạng mục phân tích số liệu/kế toán',
    top_entry_id bigint COMMENT 'ID bút toán cha/bút toán gốc'
) CLUSTER BY AUTO;
ALTER TABLE sat_entry_information ALTER COLUMN entry_hashkey SET NOT NULL;
ALTER TABLE sat_entry_information ADD CONSTRAINT sat_entry_information_pk PRIMARY KEY (entry_hashkey);

CREATE OR REPLACE TABLE sat_entry_amount (
    entry_hashkey string COMMENT 'Tham chiếu Hub entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    trans_amount decimal(38,10) COMMENT 'Số tiền giao dịch gốc',
    amount decimal(38,10) COMMENT 'Số tiền hạch toán',
    fee_amount decimal(38,10) COMMENT 'Số tiền phí phát sinh',
    interest_factor decimal(38,10) COMMENT 'Tỷ lệ tính lãi',
    balance decimal(38,10) COMMENT 'Số dư liên quan'
) CLUSTER BY AUTO;
ALTER TABLE sat_entry_amount ALTER COLUMN entry_hashkey SET NOT NULL;
ALTER TABLE sat_entry_amount ADD CONSTRAINT sat_entry_amount_pk PRIMARY KEY (entry_hashkey);

CREATE OR REPLACE TABLE sat_entry_trans_detail (
    entry_hashkey string COMMENT 'Tham chiếu Hub entry',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    trans_code string COMMENT 'Mã loại giao dịch',
    auth_code string COMMENT 'Mã chuẩn chi',
    trans_curr string COMMENT 'Tiền tệ giao dịch',
    trans_country string COMMENT 'Quốc gia giao dịch',
    trans_city string COMMENT 'Thành phố giao dịch',
    trans_date string COMMENT 'Ngày giao dịch gốc',
    local_date string COMMENT 'Ngày hệ thống',
    posting_date string COMMENT 'Ngày hạch toán',
    trans_details string COMMENT 'Mô tả chi tiết giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_entry_trans_detail ALTER COLUMN entry_hashkey SET NOT NULL;
ALTER TABLE sat_entry_trans_detail ADD CONSTRAINT sat_entry_trans_detail_pk PRIMARY KEY (entry_hashkey);

CREATE OR REPLACE TABLE hub_templ_approved (
    templ_approved_hashkey string COMMENT 'Hub Hash Key (ID)',
    business_key bigint COMMENT 'Business Key (ID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_templ_approved ALTER COLUMN templ_approved_hashkey SET NOT NULL;
ALTER TABLE hub_templ_approved ADD CONSTRAINT hub_templ_approved_pk PRIMARY KEY (templ_approved_hashkey);

CREATE OR REPLACE TABLE sat_templ_approved_information (
    templ_approved_hashkey string COMMENT 'Tham chiếu Hub templ_approved',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    account_type bigint COMMENT 'Loại tài khoản',
    account_name string COMMENT 'Tên mẫu tài khoản',
    group_code string COMMENT 'Mã nhóm tài khoản',
    curr string COMMENT 'Loại tiền tệ mặc định',
    acat string COMMENT 'Danh mục phân loại kế toán',
    f_i bigint COMMENT 'Phân loại kỹ thuật tài chính',
    fx_type string COMMENT 'Loại quy tắc chuyển đổi ngoại tệ',
    event_type bigint COMMENT 'Loại sự kiện kích hoạt',
    template_details string COMMENT 'Chi tiết cấu hình bổ sung',
    date_from string COMMENT 'Ngày bắt đầu hiệu lực',
    date_to string COMMENT 'Ngày kết thúc hiệu lực',
    is_active string COMMENT 'Cờ trạng thái hoạt động',
    officer bigint COMMENT 'Mã ID người phê duyệt/cập nhật',
    acc_scheme__id bigint COMMENT 'Mã scheme',
    code string COMMENT 'Mã dạng chuỗi',
    acc_templ__oid bigint COMMENT 'Mã tham chiếu liên kết đến giao dịch được settle',
    account_numeration string COMMENT 'Không dùng'
) CLUSTER BY AUTO;
ALTER TABLE sat_templ_approved_information ALTER COLUMN templ_approved_hashkey SET NOT NULL;
ALTER TABLE sat_templ_approved_information ADD CONSTRAINT sat_templ_approved_information_pk PRIMARY KEY (templ_approved_hashkey);

CREATE OR REPLACE TABLE sat_templ_approved_repayment (
    templ_approved_hashkey string COMMENT 'Tham chiếu Hub templ_approved',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    due_acc_templ bigint COMMENT 'Mẫu tài khoản trích nợ',
    alt_due_templ bigint COMMENT 'Mẫu tài khoản trích nợ dự phòng',
    due_type string COMMENT 'Loại hình thu nợ',
    due_period bigint COMMENT 'Chu kỳ thanh toán',
    grace_period bigint COMMENT 'Thời gian ân hạn miễn lãi',
    due_to_work_day string COMMENT 'Quy tắc dời ngày thanh toán',
    min_repayment bigint COMMENT 'Số tiền thanh toán tối thiểu cố định',
    min_rq_repayment bigint COMMENT 'Yêu cầu thanh toán tối thiểu bắt buộc',
    repayment_percent bigint COMMENT 'Tỷ lệ phần trăm thanh toán',
    ageing_tariff string COMMENT 'Biểu phí/luồng chuyển nhóm nợ',
    ageing_priority bigint COMMENT 'Độ ưu tiên chuyển nhóm nợ'
) CLUSTER BY AUTO;
ALTER TABLE sat_templ_approved_repayment ALTER COLUMN templ_approved_hashkey SET NOT NULL;
ALTER TABLE sat_templ_approved_repayment ADD CONSTRAINT sat_templ_approved_repayment_pk PRIMARY KEY (templ_approved_hashkey);

CREATE OR REPLACE TABLE sat_templ_approved_interest (
    templ_approved_hashkey string COMMENT 'Tham chiếu Hub templ_approved',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    interest_scheme decimal(38,10) COMMENT 'Sơ đồ tính lãi',
    interest_algorithm string COMMENT 'Thuật toán tính lãi',
    interest_rate decimal(38,10) COMMENT 'Lãi suất áp dụng',
    interest_tariff string COMMENT 'Biểu tính lãi suất',
    interest_fee decimal(38,10) COMMENT 'Phí áp dụng cùng lãi suất',
    interest_fee_type bigint COMMENT 'Loại phí tính kèm lãi',
    charge_for_open bigint COMMENT 'Phí phát sinh mở tài khoản',
    fee_rate_regime string COMMENT 'Chế độ áp dụng tỷ lệ phí',
    interest_delay string COMMENT 'Thời gian chờ trước khi tính lãi',
    calc_when_credit string COMMENT 'Quy tắc tính lãi dư có'
) CLUSTER BY AUTO;
ALTER TABLE sat_templ_approved_interest ALTER COLUMN templ_approved_hashkey SET NOT NULL;
ALTER TABLE sat_templ_approved_interest ADD CONSTRAINT sat_templ_approved_interest_pk PRIMARY KEY (templ_approved_hashkey);

CREATE OR REPLACE TABLE sat_templ_approved_gl (
    templ_approved_hashkey string COMMENT 'Tham chiếu Hub templ_approved',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    gl_type string COMMENT 'Loại tài khoản sổ cái',
    gl_number string COMMENT 'Số tài khoản sổ cái nội bộ',
    hd_gl_number string COMMENT 'Số tài khoản sổ cái cấp cao',
    gl_tariff string COMMENT 'Biểu phí hạch toán GL',
    interest_acc_templ decimal(38,10) COMMENT 'Mẫu tài khoản ghi nhận lãi',
    int_accrual_acc bigint COMMENT 'Tài khoản dồn tích lãi',
    int_fee_account string COMMENT 'Tài khoản ghi nhận phí lãi',
    int_rev_exp_acc bigint COMMENT 'Tài khoản doanh thu/chi phí lãi',
    offbalance_xf_acc decimal(38,10) COMMENT 'Tài khoản ngoại bảng',
    suppl_cr_account string COMMENT 'Tài khoản có phụ trợ',
    suppl_dr_account string COMMENT 'Tài khoản nợ phụ trợ',
    use_gl string COMMENT 'Cờ đẩy dữ liệu sang GL'
) CLUSTER BY AUTO;
ALTER TABLE sat_templ_approved_gl ALTER COLUMN templ_approved_hashkey SET NOT NULL;
ALTER TABLE sat_templ_approved_gl ADD CONSTRAINT sat_templ_approved_gl_pk PRIMARY KEY (templ_approved_hashkey);

CREATE OR REPLACE TABLE sat_templ_approved_limit (
    templ_approved_hashkey string COMMENT 'Tham chiếu Hub templ_approved',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    balance_type bigint COMMENT 'Loại số dư áp dụng',
    upp_lim_amount decimal(38,10) COMMENT 'Giá trị hạn mức trần',
    low_lim_amount decimal(38,10) COMMENT 'Giá trị hạn mức đáy',
    upp_lim_acc_templ bigint COMMENT 'Mẫu tài khoản xử lý chạm trần',
    low_lim_acc_templ bigint COMMENT 'Mẫu tài khoản xử lý chạm đáy',
    priority bigint COMMENT 'Độ ưu tiên xử lý tài khoản',
    is_am_available string COMMENT 'Cờ đánh giá số dư khả dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_templ_approved_limit ALTER COLUMN templ_approved_hashkey SET NOT NULL;
ALTER TABLE sat_templ_approved_limit ADD CONSTRAINT sat_templ_approved_limit_pk PRIMARY KEY (templ_approved_hashkey);

-- BPM Vault Mapping

-- CRM CC Vault Mapping

CREATE OR REPLACE TABLE ref_way4_account_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'Trạng thái sửa đổi bản ghi (A = đang hiệu lực)',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    GROUP_NAME string COMMENT 'Tên nhóm',
    PCAT string COMMENT 'product categroy A: accounting, B: bank accounting, C: issuing, M: acquiring',
    ACAT string COMMENT 'account category, S: shared limit, P: Payment due, C: Pers limit, O: Other, I: Pay Imediate',
    IS_AM_AVAILABLE string COMMENT 'Y: Yes, N: No',
    DUE_TYPE string COMMENT 'Loại kỳ hạn',
    CHARGE_FOR_OPEN bigint COMMENT 'Phí khi mở',
    SEND_CREDIT_TO bigint COMMENT 'Tài khoản nhận ghi có',
    SEND_DEBIT_TO bigint COMMENT 'Tài khoản nhận ghi nợ',
    PAYMENT_PRIORITY bigint COMMENT 'Thứ tự ưu tiên thanh toán',
    ACCOUNT_STATUS string COMMENT 'Trạng thái tài khoản',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_account_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_account_type ADD CONSTRAINT ref_way4_account_type_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_contr_status (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'A for active value',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    CON_CAT string COMMENT 'contract category, C: card, M: device, A: account',
    EXTERNAL_CODE string COMMENT 'external code',
    IS_VALID string COMMENT 'Cờ hợp lệ',
    ACTION_TYPE string COMMENT 'Loại hành động',
    RESTRICTION_CODE string COMMENT 'Mã hạn chế',
    PRIORITY_CODE string COMMENT 'Mã độ ưu tiên',
    FRAUD_TYPE string COMMENT 'Loại gian lận',
    AUTH_RC bigint COMMENT 'Mã phản hồi xác thực (authorization response code)',
    CODE_PARMS string COMMENT 'Tham số của mã',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_contr_status ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_contr_status ADD CONSTRAINT ref_way4_contr_status_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_cs_status_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_STATE string COMMENT 'A for active',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    CODE string COMMENT 'code',
    GROUP_CODE string COMMENT 'Mã nhóm',
    DEFAULT_VALUE bigint COMMENT 'Giá trị mặc định',
    APPLIES_TO string COMMENT 'Phạm vi/đối tượng áp dụng',
    PCAT string COMMENT 'Nhóm sản phẩm (product category)',
    CON_CAT string COMMENT 'Nhóm hợp đồng (contract category)',
    CCAT string COMMENT 'Nhóm thẻ (card category)',
    STATUS_CATEGORY string COMMENT 'Nhóm trạng thái',
    LOG_FLAG string COMMENT 'Cờ ghi log',
    IS_PRIMARY string COMMENT 'Cờ bản ghi chính',
    ON_OFF_MODE string COMMENT 'Chế độ bật/tắt',
    DOMAIN_CODE string COMMENT 'Mã miền (domain)',
    DOMAIN_TYPE__ID bigint COMMENT 'Định danh loại miền',
    ADD_INFO string COMMENT 'Thông tin bổ sung',
    IS_READY string COMMENT 'Cờ sẵn sàng sử dụng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_cs_status_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_cs_status_type ADD CONSTRAINT ref_way4_cs_status_type_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_cs_status_value (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_STATE string COMMENT 'A for active',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    CS_STATUS_TYPE__OID bigint COMMENT 'Định danh loại trạng thái khách hàng (CS status type)',
    STATUS_TYPE_CODE string COMMENT 'Mã loại trạng thái',
    NAME string COMMENT 'name',
    IS_OK string COMMENT 'Cờ trạng thái hợp lệ',
    RESULT_EVENT_CODE string COMMENT 'Mã sự kiện kết quả',
    SEVERITY_LEVEL bigint COMMENT 'Mức độ nghiêm trọng',
    TO_RULES string COMMENT 'Quy tắc trạng thái đích',
    FROM_RULES string COMMENT 'Quy tắc trạng thái nguồn',
    ADD_INFO string COMMENT 'Thông tin bổ sung',
    IS_ACTIVE string COMMENT 'Cờ đang hoạt động',
    DATE_FROM string COMMENT 'Ngày bắt đầu hiệu lực',
    DATE_TO string COMMENT 'Ngày kết thúc hiệu lực',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_cs_status_value ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_cs_status_value ADD CONSTRAINT ref_way4_cs_status_value_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_mess_channel (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'A for active',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    CONTRA_CHANNEL string COMMENT 'Kênh đối ứng',
    DATA_SOURCE string COMMENT 'Nguồn dữ liệu',
    IS_ON_US string COMMENT 'Cờ giao dịch nội bộ (on-us)',
    SETTL_DATE string COMMENT 'Ngày quyết toán',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_mess_channel ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_mess_channel ADD CONSTRAINT ref_way4_mess_channel_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_resp_code (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'A for active',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    RESP_LEVEL bigint COMMENT 'Cấp độ phản hồi',
    MESSAGE_CODE string COMMENT 'Mã thông điệp',
    IS_STATUS string COMMENT 'Cờ là trạng thái',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_resp_code ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_resp_code ADD CONSTRAINT ref_way4_resp_code_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_sic (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'A for active value',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    GROUP_CODE string COMMENT 'Merchant Category Group',
    CUSTOM_CODE string COMMENT 'Mã tùy biến',
    LIMIT_CODE string COMMENT 'Mã hạn mức',
    SIC_GROUP_DFLT bigint COMMENT 'Nhóm SIC mặc định',
    USE_IN_BANK string COMMENT 'Cờ sử dụng trong ngân hàng',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_sic ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_sic ADD CONSTRAINT ref_way4_sic_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_trans_cond (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'A for active value',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    TERM_CAT string COMMENT 'Nhóm điều khoản',
    CATEGORY_CODE string COMMENT 'Mã nhóm phân loại',
    DEFAULT_CONDITION bigint COMMENT 'Điều kiện mặc định',
    LATE_CONDITION bigint COMMENT 'Điều kiện trễ hạn',
    SECURITY_CODE string COMMENT 'Mã bảo mật',
    ADDENDUM string COMMENT 'Phụ lục/điều khoản bổ sung',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_trans_cond ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_trans_cond ADD CONSTRAINT ref_way4_trans_cond_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_way4_trans_type (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    AMND_STATE string COMMENT 'A for active value',
    AMND_DATE string COMMENT 'Ngày dữ liệu',
    AMND_OFFICER bigint COMMENT 'Mã nhân viên sửa đổi bản ghi gần nhất',
    AMND_PREV bigint COMMENT 'ID phiên bản trước của bản ghi',
    SERVICE_CLASS string COMMENT 'T: Transaction, M: Miscellaneous',
    S_CAT string COMMENT 'Nhóm dịch vụ (service category)',
    T_CAT string COMMENT 'Nhóm giao dịch (transaction category)',
    DR_CR bigint COMMENT 'Chiều hạch toán ghi nợ/ghi có',
    IS_IMPERSONAL string COMMENT 'Cờ tài khoản phi cá nhân',
    IS_AUTHORIZED string COMMENT 'Cờ đã được xác thực',
    IS_REQUIRED string COMMENT 'Cờ bắt buộc',
    ENABLE_ADJUSTMENT string COMMENT 'Cho phép điều chỉnh',
    ENABLE_REVERSAL string COMMENT 'Cho phép đảo giao dịch',
    ENABLE_REQUEST string COMMENT 'Cho phép tạo yêu cầu',
    PREV_TRANS_TYPE bigint COMMENT 'Loại giao dịch trước đó',
    CHAIN_TYPE string COMMENT 'Loại chuỗi giao dịch',
    CHARGE_EVENT string COMMENT 'Sự kiện tính phí',
    DISPUTE_TRN_CLASS string COMMENT 'Nhóm giao dịch tranh chấp',
    TERMINAL_CATEGORY string COMMENT 'Nhóm thiết bị đầu cuối',
    PRODUCTION_TYPE string COMMENT 'Loại phát hành',
    PRODUCTION_EVENT string COMMENT 'Sự kiện phát hành',
    TRANS_CODE string COMMENT 'Mã giao dịch',
    REVERSAL_CODE string COMMENT 'Mã giao dịch đảo',
    TRANS_TYPE_IDT string COMMENT 'Định danh loại giao dịch',
    PRIORITY bigint COMMENT 'Độ ưu tiên',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_way4_trans_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_way4_trans_type ADD CONSTRAINT ref_way4_trans_type_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE effsat_link_account_contract_card (
    link_account_contract_card_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_account_contract_card ALTER COLUMN link_account_contract_card_hashkey SET NOT NULL;
ALTER TABLE effsat_link_account_contract_card ADD CONSTRAINT effsat_link_account_contract_card_pk PRIMARY KEY (link_account_contract_card_hashkey);

CREATE OR REPLACE TABLE effsat_link_liability_contract_account_contract (
    link_liability_contract_account_contract_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_liability_contract_account_contract ALTER COLUMN link_liability_contract_account_contract_hashkey SET NOT NULL;
ALTER TABLE effsat_link_liability_contract_account_contract ADD CONSTRAINT effsat_link_liability_contract_account_contract_pk PRIMARY KEY (link_liability_contract_account_contract_hashkey);

CREATE OR REPLACE TABLE sts_hub_client (
    client_hashkey string COMMENT 'STS Hub Hash Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    cdc_status string COMMENT 'Trường kỹ thuật: Trạng thái CDC (D = Deleted).'
) CLUSTER BY AUTO;
ALTER TABLE sts_hub_client ALTER COLUMN client_hashkey SET NOT NULL;
ALTER TABLE sts_hub_client ALTER COLUMN source_event_date SET NOT NULL;
ALTER TABLE sts_hub_client ADD CONSTRAINT sts_hub_client_pk PRIMARY KEY (client_hashkey, source_event_date);

CREATE OR REPLACE TABLE hub_acnt_contract (
    acnt_contract_hashkey string COMMENT 'Hub Hash Key',
    business_key bigint COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_acnt_contract ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE hub_acnt_contract ADD CONSTRAINT hub_acnt_contract_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_acnt_contract_account_t24 (
    link_acnt_contract_account_t24_hashkey string COMMENT 'Link Hash Key',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract (id của cấp card)',
    acnt_contract_t24_hashkey string COMMENT 'Tham chiếu Hub acnt contract (id của cấp card tham chiếu tới tài khoản của t24)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_acnt_contract_account_t24 ALTER COLUMN link_acnt_contract_account_t24_hashkey SET NOT NULL;
ALTER TABLE link_acnt_contract_account_t24 ADD CONSTRAINT link_acnt_contract_account_t24_pk PRIMARY KEY (link_acnt_contract_account_t24_hashkey);

CREATE OR REPLACE TABLE link_acnt_contract_branch (
    link_acnt_contract_branch_hashkey string COMMENT 'Link Hash Key',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    branch_hashkey string COMMENT 'Tham chiếu Hub branch',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_acnt_contract_branch ALTER COLUMN link_acnt_contract_branch_hashkey SET NOT NULL;
ALTER TABLE link_acnt_contract_branch ADD CONSTRAINT link_acnt_contract_branch_pk PRIMARY KEY (link_acnt_contract_branch_hashkey);

CREATE OR REPLACE TABLE link_acnt_contract_client (
    link_acnt_contract_client_hashkey string COMMENT 'Link Hash Key',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    client_hashkey string COMMENT 'Tham chiếu Hub client',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_acnt_contract_client ALTER COLUMN link_acnt_contract_client_hashkey SET NOT NULL;
ALTER TABLE link_acnt_contract_client ADD CONSTRAINT link_acnt_contract_client_pk PRIMARY KEY (link_acnt_contract_client_hashkey);

CREATE OR REPLACE TABLE link_acnt_contract_product (
    link_acnt_contract_product_hashkey string COMMENT 'Link Hash Key',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    product_hashkey string COMMENT 'Tham chiếu Hub product',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_acnt_contract_product ALTER COLUMN link_acnt_contract_product_hashkey SET NOT NULL;
ALTER TABLE link_acnt_contract_product ADD CONSTRAINT link_acnt_contract_product_pk PRIMARY KEY (link_acnt_contract_product_hashkey);

CREATE OR REPLACE TABLE link_balance_acnt_contract (
    link_balance_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    balance_hashkey string COMMENT 'Tham chiếu Hub balance',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_balance_acnt_contract ALTER COLUMN link_balance_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_balance_acnt_contract ADD CONSTRAINT link_balance_acnt_contract_pk PRIMARY KEY (link_balance_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_billing_acnt_contract (
    link_billing_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    billing_hashkey string COMMENT 'Tham chiếu Hub billing',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_billing_acnt_contract ALTER COLUMN link_billing_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_billing_acnt_contract ADD CONSTRAINT link_billing_acnt_contract_pk PRIMARY KEY (link_billing_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_billing_log_acnt_contract (
    link_billing_log_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    billing_log_hashkey string COMMENT 'Tham chiếu Hub billing_log',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_billing_log_acnt_contract ALTER COLUMN link_billing_log_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_billing_log_acnt_contract ADD CONSTRAINT link_billing_log_acnt_contract_pk PRIMARY KEY (link_billing_log_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_device_acnt_contract (
    link_device_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    device_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub device',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_device_acnt_contract ALTER COLUMN link_device_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_device_acnt_contract ADD CONSTRAINT link_device_acnt_contract_pk PRIMARY KEY (link_device_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_doc_source_acnt_contract (
    link_doc_source_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_doc_source_acnt_contract ALTER COLUMN link_doc_source_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_doc_source_acnt_contract ADD CONSTRAINT link_doc_source_acnt_contract_pk PRIMARY KEY (link_doc_source_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_doc_target_acnt_contract (
    link_doc_target_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    document_hashkey string COMMENT 'Tham chiếu Hub document',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_doc_target_acnt_contract ALTER COLUMN link_doc_target_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_doc_target_acnt_contract ADD CONSTRAINT link_doc_target_acnt_contract_pk PRIMARY KEY (link_doc_target_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_entry_acnt_contract (
    link_entry_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    entry_hashkey string COMMENT 'Tham chiếu Hub entry',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_entry_acnt_contract ALTER COLUMN link_entry_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_entry_acnt_contract ADD CONSTRAINT link_entry_acnt_contract_pk PRIMARY KEY (link_entry_acnt_contract_hashkey);

CREATE OR REPLACE TABLE link_payment_acnt_contract (
    link_payment_acnt_contract_hashkey string COMMENT 'Link Hash Key',
    payment_hashkey string COMMENT 'Tham chiếu Hub payment',
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_payment_acnt_contract ALTER COLUMN link_payment_acnt_contract_hashkey SET NOT NULL;
ALTER TABLE link_payment_acnt_contract ADD CONSTRAINT link_payment_acnt_contract_pk PRIMARY KEY (link_payment_acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_acnt_contract_add_data (
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    add_info_01 string COMMENT 'Thông tin bổ sung 1',
    add_info_02 string COMMENT 'Thông tin bổ sung 2',
    add_info_03 string COMMENT 'Thông tin bổ sung 3',
    add_info_04 string COMMENT 'Thông tin bổ sung 4',
    report_address string COMMENT 'Địa chỉ report'
) CLUSTER BY AUTO;
ALTER TABLE sat_acnt_contract_add_data ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sat_acnt_contract_add_data ADD CONSTRAINT sat_acnt_contract_add_data_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_acnt_contract_cs_status_log (
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    status_date string COMMENT 'Ngày ghi nhận trạng thái',
    bank_date_to string COMMENT 'Ngày ghi nhận trạng thái',
    start_local_date string COMMENT 'Ngày bắt đầu trạng thái',
    end_local_date string COMMENT 'Ngày kết thúc trạng thái',
    status_type bigint COMMENT 'Loại trạng thái',
    status_value bigint COMMENT 'Giá trị trạng thái',
    status_value_prev bigint COMMENT 'Giá trị trạng thái trước',
    is_active string COMMENT 'Flag đánh dấu trạng thái còn hiệu lực hay không',
    ext_data string COMMENT 'Thông tin mở rộng',
    descript string COMMENT 'Diễn giải nội dung thay đổi trạng thái',
    event_action string COMMENT 'Hành động kích hoạt thay đổi trạng thái',
    event_code string COMMENT 'Mã sự kiện',
    officer bigint COMMENT 'Mã định danh của nhân viên thay đổi trạng thái',
    bank_date string COMMENT 'Ngày làm việc của ngân hàng tại thời điểm ghi nhận thay đổi',
    value_extension string COMMENT 'Giá trị mở rộng',
    usage_action bigint COMMENT 'Mã hành động kích hoạt việc thay đổi trạng thái',
    usage_object string COMMENT 'Mã định danh của đối tượng liên quan đến hành động',
    storno_plan bigint COMMENT 'Mã ID kế hoạch đảo/hủy',
    cre_by_storno_plan bigint COMMENT 'Cờ tạo bởi kế hoạch đảo',
    td_cons__oid bigint COMMENT 'ID đối tượng lưu vết trạng thái'
) CLUSTER BY AUTO;
ALTER TABLE sat_acnt_contract_cs_status_log ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sat_acnt_contract_cs_status_log ADD CONSTRAINT sat_acnt_contract_cs_status_log_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_acnt_contract_information (
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    contract_number string COMMENT 'Số hợp đồng',
    contract_name string COMMENT 'Tên hợp đồng',
    rbs_number string COMMENT 'Tài khoản thanh toán tự động trên T24',
    comment_text string COMMENT 'Ghi chú',
    contr_type bigint COMMENT 'Loại hợp đồng',
    contr_subtype__id bigint COMMENT 'Phân loại hợp đồng con',
    behavior_group bigint COMMENT 'Nhóm hành vi',
    behavior_type bigint COMMENT 'Loại hành vi',
    serv_pack__id bigint COMMENT 'Gói dịch vụ',
    channel string COMMENT 'Kênh',
    curr string COMMENT 'Mã tiền tệ',
    date_open string COMMENT 'Ngày mở hợp đồng',
    date_expire string COMMENT 'Ngày hết hạn',
    last_billing_date string COMMENT 'Ngày sao kê kì trước',
    next_billing_date string COMMENT 'Ngày sao kê tiếp theo',
    last_scan string COMMENT 'Ngày quét hợp đồng gần nhất',
    contract_level string COMMENT 'Cấp hợp đồng',
    contr_status bigint COMMENT 'Trạng thái hợp đồng',
    liab_contract bigint COMMENT 'Mã ID của hợp đồng liability liên kết',
    liab_contract_prev bigint COMMENT 'Mã ID của hợp đồng trước đó',
    billing_contract bigint COMMENT 'Mã ID của hợp đồng sao kê và thanh toán',
    auth_limit_amount decimal(38,10) COMMENT 'Hạn mức tín dụng',
    base_auth_limit bigint COMMENT 'Hạn mức cấp phép cơ sở',
    own_balance decimal(38,10) COMMENT 'Số dư tài khoản gốc',
    own_blocked decimal(38,10) COMMENT 'Số tiền bị phong tỏa tài khoản gốc',
    sub_blocked decimal(38,10) COMMENT 'Số tiền bị phong tỏa tài khoản phụ',
    sub_balance decimal(38,10) COMMENT 'Số dư tài khoản phụ',
    total_blocked decimal(38,10) COMMENT 'Tổng số tiền bị phong tỏa',
    total_balance decimal(38,10) COMMENT 'Tổng dư',
    shared_blocked decimal(38,10) COMMENT 'Số tiền bị phong tỏa hạn mức chung',
    shared_balance decimal(38,10) COMMENT 'Dư hạn mức chung',
    amount_available decimal(38,10) COMMENT 'Số dư khả dụng',
    acc_scheme__id bigint COMMENT 'Mã scheme'
) CLUSTER BY AUTO;
ALTER TABLE sat_acnt_contract_information ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sat_acnt_contract_information ADD CONSTRAINT sat_acnt_contract_information_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_acnt_contract_other (
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    terminal_category string COMMENT 'Phân loại nhóm thiết bị đầu cuối',
    f_i bigint COMMENT 'Tổ chức tài chính',
    service_group string COMMENT 'Nhóm dịch vụ',
    old_pack bigint COMMENT 'Mã gói sản phẩm/dịch vụ cũ',
    old_scheme bigint COMMENT 'Cấu hình tính toán cũ',
    parent_product string COMMENT 'Mã sản phẩm cha',
    product_prev string COMMENT 'Mã sản phẩm trước đó',
    main_product bigint COMMENT 'Mã định danh của sản phẩm chính',
    client_type bigint COMMENT 'Loại khách hàng sở hữu hợp đồng',
    behavior_type_prev bigint COMMENT 'Loại hành vi giao dịch/tín dụng trước đó',
    old_curr string COMMENT 'Loại tiền tệ cũ',
    production_status string COMMENT 'Trạng thái sản xuất',
    report_type string COMMENT 'Loại hình báo cáo',
    max_pin_attempts bigint COMMENT 'Số lần nhập sai mã PIN tối đa cho phép trước khi khóa',
    pin_attempts bigint COMMENT 'Số lần đã nhập sai mã PIN hiện tại',
    risk_scheme bigint COMMENT 'Lược đồ/cấu hình quản lý rủi ro',
    risk_factor bigint COMMENT 'Hệ số đánh giá rủi ro hiện tại',
    risk_factor_prev bigint COMMENT 'Hệ số rủi ro trước đó',
    share_balance string COMMENT 'Cờ cấu hình chia sẻ số dư',
    is_multycurrency string COMMENT 'Cờ hợp đồng hỗ trợ đa tiền tệ',
    enables_item string COMMENT 'Cờ/danh sách các tính năng được phép kích hoạt',
    cycle_length bigint COMMENT 'Độ dài của một chu kỳ',
    interval_type string COMMENT 'Đơn vị tính của chu kỳ',
    status_category string COMMENT 'Phân loại nhóm trạng thái',
    limit_is_active string COMMENT 'Cờ trạng thái hiệu lực của hạn mức tín dụng',
    routing_idt string COMMENT 'Định danh dùng để định tuyến giao dịch',
    is_ready string COMMENT 'Cờ hợp đồng đã sẵn sàng',
    settlement_type string COMMENT 'Loại hình/phương thức thanh toán bù trừ',
    auth_seq_n bigint COMMENT 'Số thứ tự chuỗi cấp phép giao dịch',
    apply_dt string COMMENT 'Ngày bắt đầu áp dụng hợp đồng hoặc cấu hình mới',
    local_version bigint COMMENT 'Phiên bản bản ghi lưu tại cơ sở dữ liệu cục bộ',
    remote_version bigint COMMENT 'Phiên bản bản ghi từ hệ thống từ xa',
    acnt_contract__id bigint COMMENT 'Mã ID hợp đồng tài khoản chính liên kết',
    liab_contract bigint COMMENT 'Mã ID hợp đồng liability liên kết',
    product string COMMENT 'Mã sản phẩm',
    liab_balance decimal(38,10) COMMENT 'Dư nghĩa vụ',
    liab_blocked bigint COMMENT 'Tổng bị khóa',
    card_expire string COMMENT 'Ngày hết hạn của thẻ',
    rbs_member_id string COMMENT 'Mã thành viên liên kết trong hệ thống ngân hàng bán lẻ',
    chip_scheme bigint COMMENT 'Cấu hình tham số thẻ chip',
    merchant_id string COMMENT 'Mã merchant',
    tr_title bigint COMMENT 'Mã danh xưng',
    tr_company string COMMENT 'Tên công ty',
    tr_country string COMMENT 'Quốc gia',
    tr_first_nam string COMMENT 'Tên chủ thẻ (embossing name)',
    tr_last_nam string COMMENT 'Họ chủ thẻ (embossing name)',
    tr_sic string COMMENT 'Mã sic'
) CLUSTER BY AUTO;
ALTER TABLE sat_acnt_contract_other ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sat_acnt_contract_other ADD CONSTRAINT sat_acnt_contract_other_pk PRIMARY KEY (acnt_contract_hashkey);

CREATE OR REPLACE TABLE sat_acnt_contract_type (
    acnt_contract_hashkey string COMMENT 'Tham chiếu Hub acnt_contract',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    pcat string COMMENT 'Loại sản phẩm',
    con_cat string COMMENT 'Loại hợp đồng',
    ccat string COMMENT 'Phân loại khách hàng',
    base_relation string COMMENT 'Mối quan hệ cơ sở',
    check_available string COMMENT 'Cờ kiểm tra khả dụng',
    check_usage string COMMENT 'Cờ kiểm tra sử dụng',
    ext_data string COMMENT 'Thông tin mở rộng',
    liab_category string COMMENT 'Phân loại nghĩa vụ',
    relation_tag string COMMENT 'Nhãn quan hệ'
) CLUSTER BY AUTO;
ALTER TABLE sat_acnt_contract_type ALTER COLUMN acnt_contract_hashkey SET NOT NULL;
ALTER TABLE sat_acnt_contract_type ADD CONSTRAINT sat_acnt_contract_type_pk PRIMARY KEY (acnt_contract_hashkey);
