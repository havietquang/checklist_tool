# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;



CREATE TABLE IF NOT EXISTS hub_giao_dich (
    giao_dich_hashkey string NOT NULL COMMENT 'Hub Hashkey Giao Dịch BPM',
    business_key string COMMENT 'Business Key - Mã giao dịch BPM',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_giao_dich ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE hub_giao_dich DROP CONSTRAINT IF EXISTS hub_giao_dich_pk;
ALTER TABLE hub_giao_dich ADD CONSTRAINT hub_giao_dich_pk PRIMARY KEY (giao_dich_hashkey);


CREATE TABLE IF NOT EXISTS hub_khach_hang (
    khach_hang_hashkey string NOT NULL COMMENT 'Hub Hashkey Khách Hàng BPM',
    business_key bigint COMMENT 'Business Key - Mã khách hàng BPM',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_khach_hang ALTER COLUMN khach_hang_hashkey SET NOT NULL;
ALTER TABLE hub_khach_hang DROP CONSTRAINT IF EXISTS hub_khach_hang_pk;
ALTER TABLE hub_khach_hang ADD CONSTRAINT hub_khach_hang_pk PRIMARY KEY (khach_hang_hashkey);


CREATE TABLE IF NOT EXISTS hub_pdtd_nhom_giao_dich (
    pdtd_nhom_giao_dich_hashkey string NOT NULL COMMENT 'Hub Hashkey Nhóm Giao Dịch PDTD',
    business_key string COMMENT 'Business Key - Mã nhóm giao dịch PDTD',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_pdtd_nhom_giao_dich ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE hub_pdtd_nhom_giao_dich DROP CONSTRAINT IF EXISTS hub_pdtd_nhom_giao_dich_pk;
ALTER TABLE hub_pdtd_nhom_giao_dich ADD CONSTRAINT hub_pdtd_nhom_giao_dich_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);


CREATE OR REPLACE TABLE hub_tsbd_chu_so_huu (
    tsbd_chu_so_huu_hashkey string NOT NULL COMMENT 'Hub Hashkey Chủ Sở Hữu TSBD',
    business_key bigint COMMENT 'Business Key - Mã chủ sở hữu TSBD',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_tsbd_chu_so_huu ALTER COLUMN tsbd_chu_so_huu_hashkey SET NOT NULL;
ALTER TABLE hub_tsbd_chu_so_huu ADD CONSTRAINT hub_tsbd_chu_so_huu_pk PRIMARY KEY (tsbd_chu_so_huu_hashkey);


CREATE OR REPLACE TABLE t_link_tsbd_giaodich_taisan_chusohuu (
    t_link_tsbd_giaodich_taisan_chusohuu_hashkey string NOT NULL COMMENT 'Link Hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    tsbd_giaodich_chinh_hashkey string COMMENT 'FK tới hub giao dịch chính TSBD',
    tsbd_tai_san_hashkey string COMMENT 'FK tới hub tài sản TSBD',
    tsbd_chu_so_huu_hashkey string COMMENT 'FK tới hub chủ sở hữu TSBD',
    giaodich_id bigint COMMENT 'ID giao dịch',
    taisan_id bigint COMMENT 'ID tài sản',
    ten_tai_san string COMMENT 'Tên tài sản',
    taisan_tinh_tp_id bigint COMMENT 'ID tỉnh/thành phố của tài sản',
    taisan_quan_huyen_id bigint COMMENT 'ID quận/huyện của tài sản',
    bds_can_cu_dg bigint COMMENT 'Căn cứ định giá BĐS',
    bds_ma_can_ho string COMMENT 'Mã căn hộ BĐS',
    bds_ngay_cap_cn string COMMENT 'Ngày cấp chứng nhận BĐS',
    so_giay_cn string COMMENT 'Số giấy chứng nhận',
    giayto_to_chuc string COMMENT 'Giấy tờ tổ chức',
    giayto_menh_gia decimal(38,10) COMMENT 'Mệnh giá giấy tờ',
    giayto_ky_han string COMMENT 'Kỳ hạn giấy tờ',
    quyenphatsinh_ten string COMMENT 'Tên quyền phát sinh',
    quyenphatsinh_sohopdong string COMMENT 'Số hợp đồng quyền phát sinh',
    vongop_mack string COMMENT 'Mã CK vốn góp',
    vongop_tochucnhan string COMMENT 'Tổ chức nhận vốn góp',
    ptvt_loaiphuongtien_id bigint COMMENT 'ID loại phương tiện vận tải',
    ptvt_hangxs string COMMENT 'Hãng xe sản xuất',
    ptvt_bienks string COMMENT 'Biển kiểm soát',
    ptvt_congnang string COMMENT 'Công năng phương tiện',
    ptvt_tentau string COMMENT 'Tên tàu',
    ptvt_sodky string COMMENT 'Số đăng ký',
    ptvt_taitrong string COMMENT 'Tải trọng',
    hanghoa_tenquycach string COMMENT 'Tên quy cách hàng hóa',
    tskhac_tt_taisan string COMMENT 'Thông tin tài sản khác',
    tskhac_ghichu string COMMENT 'Ghi chú tài sản khác',
    taisan_mo_ta string COMMENT 'Mô tả tài sản',
    taisan_dia_chi string COMMENT 'Địa chỉ tài sản',
    nhom_tai_san_id bigint COMMENT 'ID nhóm tài sản',
    loai_tai_san_id bigint COMMENT 'ID loại tài sản',
    ctiet_tai_san_id bigint COMMENT 'ID chi tiết tài sản',
    csh_ho_ten string COMMENT 'Họ tên chủ sở hữu',
    csh_cmnd string COMMENT 'CMND chủ sở hữu',
    csh_ngay_sinh string COMMENT 'Ngày sinh chủ sở hữu',
    trang_thai bigint COMMENT 'Trạng thái',
    nguoi_tao string COMMENT 'Người tạo',
    ngay_tao string COMMENT 'Ngày tạo',
    dong_xe string COMMENT 'Dòng xe'
) CLUSTER BY AUTO;
ALTER TABLE t_link_tsbd_giaodich_taisan_chusohuu ALTER COLUMN t_link_tsbd_giaodich_taisan_chusohuu_hashkey SET NOT NULL;
ALTER TABLE t_link_tsbd_giaodich_taisan_chusohuu ADD CONSTRAINT t_link_tsbd_giaodich_taisan_chusohuu_pk PRIMARY KEY (t_link_tsbd_giaodich_taisan_chusohuu_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tcstk_thong_tin_bao_dam (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    ten_tsbd string COMMENT 'Tên tài sản bảo đảm',
    ma_tsbd string COMMENT 'Mã tài sản bảo đảm',
    gia_tri_tsbd decimal(19,4) COMMENT 'Giá trị tài sản bảo đảm',
    tyle_bao_dam double COMMENT 'Tỷ lệ bảo đảm',
    trang_thai_ts string COMMENT 'Trạng thái tài sản',
    ngay_bat_dau_co_hl string COMMENT 'Ngày bắt đầu có hiệu lực',
    ngay_het_han string COMMENT 'Ngày hết hạn',
    han_muc_tc_bd decimal(19,4) COMMENT 'Hạn mức tín chấp bảo đảm',
    hm_tc_con_lai bigint COMMENT 'Hạn mức tín chấp còn lại',
    hm_dc_da_sd bigint COMMENT 'Hạn mức điều chỉnh đã sử dụng',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao string COMMENT 'Người tạo',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    nguoi_cap_nhat string COMMENT 'Người cập nhật',
    is_delete int COMMENT 'Cờ xóa',
    id_ttgd bigint COMMENT 'ID thông tin giao dịch',
    giatri_baodam decimal(38,10) COMMENT 'Giá trị bảo đảm',
    ngay_ms string COMMENT 'Ngày mở sổ',
    ngay_dao_han string COMMENT 'Ngày đáo hạn',
    ma_hm string COMMENT 'Mã hạn mức',
    ma_lkq string COMMENT 'Mã liên kết quyền',
    trang_thai_phong_toa string COMMENT 'Trạng thái phong tỏa',
    status bigint COMMENT 'Trạng thái',
    loai_tien string COMMENT 'Loại tiền',
    lai_suat bigint COMMENT 'Lãi suất',
    so_so_tk string COMMENT 'Số sổ tài khoản',
    ki_han string COMMENT 'Kỳ hạn',
    ten_san_pham string COMMENT 'Tên sản phẩm',
    productcode string COMMENT 'Mã sản phẩm',
    lai_suat_tk bigint COMMENT 'Lãi suất tài khoản',
    stt_so bigint COMMENT 'STT sổ',
    trang_thaihm string COMMENT 'Trạng thái hạn mức',
    ly_do string COMMENT 'Lý do',
    hinh_thuc_tt_stk string COMMENT 'Hình thức thanh toán sổ tiết kiệm',
    ma_phong_toa string COMMENT 'Mã phong tỏa',
    so_tai_khoan_so string COMMENT 'Số tài khoản sổ',
    madcaz string COMMENT 'Mã DCAZ',
    is_checkstk bigint COMMENT 'Cờ kiểm tra sổ tiết kiệm',
    is_tao_ts_bd bigint COMMENT 'Cờ tạo tài sản bảo đảm',
    is_dieu_chinh bigint COMMENT 'Cờ điều chỉnh',
    is_phong_toa bigint COMMENT 'Cờ phong tỏa',
    ma_chi_nhanh_stk string COMMENT 'Mã chi nhánh sổ tiết kiệm',
    is_giai_toa_ts bigint COMMENT 'Cờ giải tỏa tài sản',
    ma_giaitoa string COMMENT 'Mã giải tỏa',
    is_giai_chap_ts bigint COMMENT 'Cờ giải chấp tài sản',
    ma_giaichap string COMMENT 'Mã giải chấp',
    is_tat_toan bigint COMMENT 'Cờ tất toán',
    ma_tat_toan string COMMENT 'Mã tất toán'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tcstk_thong_tin_bao_dam ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tcstk_thong_tin_bao_dam ADD CONSTRAINT sat_giao_dich_tcstk_thong_tin_bao_dam_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tcstk_thong_tin_chung (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id int COMMENT 'ID giao dịch',
    ma_gd_omni string COMMENT 'Mã giao dịch Omni',
    nguoi_tao_gd_omni string COMMENT 'Người tạo giao dịch Omni',
    ngay_tao_gd_omni string COMMENT 'Ngày tạo giao dịch Omni',
    so_tien_de_nghi decimal(19,4) COMMENT 'Số tiền đề nghị',
    loai_tien_dn string COMMENT 'Loại tiền đề nghị',
    so_tien_de_xuat decimal(19,4) COMMENT 'Số tiền đề xuất',
    loai_tien_dx string COMMENT 'Loại tiền đề xuất',
    so_tien_hm_pd decimal(19,4) COMMENT 'Số tiền hạn mức phê duyệt',
    loai_tien_pd string COMMENT 'Loại tiền phê duyệt',
    trang_thai_gd int COMMENT 'Trạng thái giao dịch',
    ngay_bd_hm string COMMENT 'Ngày bắt đầu hạn mức',
    ngay_kt_hm string COMMENT 'Ngày kết thúc hạn mức',
    nguoi_pd string COMMENT 'Người phê duyệt',
    ngay_pd string COMMENT 'Ngày phê duyệt',
    loai_gd string COMMENT 'Loại giao dịch',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao string COMMENT 'Người tạo',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    nguoi_cap_nhat string COMMENT 'Người cập nhật',
    is_delete int COMMENT 'Cờ xóa',
    trang_thai_gd_omni string COMMENT 'Trạng thái giao dịch Omni',
    action bigint COMMENT 'Hành động',
    tkwa string COMMENT 'Tài khoản WA',
    biendols bigint COMMENT 'Biên độ lãi suất',
    ngay_kh_dx string COMMENT 'Ngày khách hàng đề xuất',
    ma_hm string COMMENT 'Mã hạn mức',
    ma_lkq string COMMENT 'Mã liên kết quyền',
    ma_don_vi_khoi_tao string COMMENT 'Mã đơn vị khởi tạo',
    decesion bigint COMMENT 'Quyết định',
    don_vi_khoi_tao bigint COMMENT 'Đơn vị khởi tạo',
    next_decesion bigint COMMENT 'Quyết định tiếp theo',
    so_cif string COMMENT 'Số CIF',
    ten_kh string COMMENT 'Tên khách hàng',
    trang_thai_hoat_dong bigint COMMENT 'Trạng thái hoạt động',
    so_tk_tc string COMMENT 'Số tài khoản tín chấp',
    email string COMMENT 'Email',
    sodt string COMMENT 'Số điện thoại',
    trang_thai bigint COMMENT 'Trạng thái',
    laisuat decimal(38,10) COMMENT 'Lãi suất',
    is_tat_toan bigint COMMENT 'Cờ tất toán',
    nghiep_vu bigint COMMENT 'Nghiệp vụ',
    ma_gd_mo string COMMENT 'Mã giao dịch mở',
    no_goc bigint COMMENT 'Nợ gốc',
    no_lai bigint COMMENT 'Nợ lãi',
    du_no_goc_api decimal(38,10) COMMENT 'Dư nợ gốc (API)',
    du_no_lai_api decimal(38,10) COMMENT 'Dư nợ lãi (API)',
    ngay_tat_toan string COMMENT 'Ngày tất toán',
    tong_du_no decimal(38,10) COMMENT 'Tổng dư nợ',
    loai_tien string COMMENT 'Loại tiền',
    list_tai_lieu string COMMENT 'Danh sách tài liệu',
    list_ts string COMMENT 'Danh sách tài sản',
    is_tao_tk_tc bigint COMMENT 'Cờ tạo tài khoản tín chấp',
    is_tao_lkq bigint COMMENT 'Cờ tạo liên kết quyền',
    is_tao_hm bigint COMMENT 'Cờ tạo hạn mức',
    is_cai_dat_hm bigint COMMENT 'Cờ cài đặt hạn mức',
    is_tao_wa bigint COMMENT 'Cờ tạo WA',
    is_gan_hm bigint COMMENT 'Cờ gán hạn mức',
    is_dc_hm_tc bigint COMMENT 'Cờ điều chỉnh hạn mức tín chấp',
    is_go_hm_tc bigint COMMENT 'Cờ gỡ hạn mức tín chấp',
    is_kep_lai bigint COMMENT 'Cờ kép lãi'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tcstk_thong_tin_chung ADD CONSTRAINT sat_giao_dich_tcstk_thong_tin_chung_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tcstk_thong_tin_giao_dich (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id int COMMENT 'ID giao dịch',
    ma_gd_omni string COMMENT 'Mã giao dịch Omni',
    nguoi_tao_gd_omni string COMMENT 'Người tạo giao dịch Omni',
    ngay_tao_gd_omni string COMMENT 'Ngày tạo giao dịch Omni',
    so_tien_de_nghi decimal(19,4) COMMENT 'Số tiền đề nghị',
    loai_tien_dn string COMMENT 'Loại tiền đề nghị',
    so_tien_de_xuat decimal(19,4) COMMENT 'Số tiền đề xuất',
    loai_tien_dx string COMMENT 'Loại tiền đề xuất',
    so_tien_hm_pd decimal(19,4) COMMENT 'Số tiền hạn mức phê duyệt',
    loai_tien_pd string COMMENT 'Loại tiền phê duyệt',
    trang_thai_gd int COMMENT 'Trạng thái giao dịch',
    khach_hang_id bigint COMMENT 'ID khách hàng',
    tt_tai_khoan_tc string COMMENT 'Thông tin tài khoản tín chấp',
    tong_so_tien_vay decimal(19,4) COMMENT 'Tổng số tiền vay',
    ngay_bd_hm string COMMENT 'Ngày bắt đầu hạn mức',
    han_muc_tc_bd decimal(19,4) COMMENT 'Hạn mức tín chấp bảo đảm',
    hm_tc_con_lai decimal(19,4) COMMENT 'Hạn mức tín chấp còn lại',
    hm_dc_da_sd decimal(19,4) COMMENT 'Hạn mức điều chỉnh đã sử dụng',
    ngay_tat_toan string COMMENT 'Ngày tất toán',
    lai_suat_khi_tat_toan int COMMENT 'Lãi suất khi tất toán',
    so_tien_khi_tat_toan decimal(19,4) COMMENT 'Số tiền khi tất toán',
    ma_don_vi_kd_ql string COMMENT 'Mã đơn vị kinh doanh quản lý',
    ma_don_vi_khoi_tao string COMMENT 'Mã đơn vị khởi tạo',
    don_vi_kt int COMMENT 'Đơn vị kế toán',
    ngay_kt_hm string COMMENT 'Ngày kết thúc hạn mức',
    nguoi_pd string COMMENT 'Người phê duyệt',
    ngay_pd string COMMENT 'Ngày phê duyệt',
    loai_gd string COMMENT 'Loại giao dịch',
    laisuat int COMMENT 'Lãi suất',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao string COMMENT 'Người tạo',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    nguoi_cap_nhat string COMMENT 'Người cập nhật',
    is_delete int COMMENT 'Cờ xóa',
    trang_thai_gd_omni string COMMENT 'Trạng thái giao dịch Omni',
    loai_gd_id bigint COMMENT 'ID loại giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tcstk_thong_tin_giao_dich ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tcstk_thong_tin_giao_dich ADD CONSTRAINT sat_giao_dich_tcstk_thong_tin_giao_dich_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tc_stk_lich_su (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key int COMMENT 'Mã key đa hành',
    ma_giao_dich string COMMENT 'Mã giao dịch',
    process_id int COMMENT 'ID quy trình BPM',
    trang_thai_bpm int COMMENT 'Trạng thái BPM',
    ngay_phe_duyet string COMMENT 'Ngày phê duyệt',
    nguoi_phe_duyet string COMMENT 'Người phê duyệt',
    ngay_xuat_file string COMMENT 'Ngày xuất file',
    dien_giai_loi_bpm string COMMENT 'Diễn giải lỗi BPM',
    ngay_tao string COMMENT 'Ngày tạo'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tc_stk_lich_su ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tc_stk_lich_su ADD CONSTRAINT sat_giao_dich_tc_stk_lich_su_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key int COMMENT 'Mã key đa hành',
    ma_giao_dich string COMMENT 'Mã giao dịch',
    ngay_kh_de_xuat string COMMENT 'Ngày khách hàng đề xuất',
    ngay_pd_tk string COMMENT 'Ngày phê duyệt tài khoản',
    so_cif string COMMENT 'Số CIF',
    cmnd string COMMENT 'Số CMND',
    ho_ten string COMMENT 'Họ tên khách hàng',
    so_tktc string COMMENT 'Số tài khoản tín chấp',
    sdt string COMMENT 'Số điện thoại',
    email string COMMENT 'Email',
    so_stk string COMMENT 'Số sổ tiết kiệm',
    gia_tri_tsbd decimal(38,10) COMMENT 'Giá trị tài sản bảo đảm',
    ma_tsbd string COMMENT 'Mã tài sản bảo đảm',
    ngay_bat_dau_hm string COMMENT 'Ngày bắt đầu hạn mức',
    ngay_ket_thuc_hm string COMMENT 'Ngày kết thúc hạn mức',
    ma_han_muc string COMMENT 'Mã hạn mức',
    so_tien_hm decimal(38,10) COMMENT 'Số tiền hạn mức',
    loai_tien string COMMENT 'Loại tiền',
    ma_trang_thai string COMMENT 'Mã trạng thái',
    trang_thai_bpm int COMMENT 'Trạng thái BPM',
    ngay_tao string COMMENT 'Ngày tạo',
    ngay_phe_duyet string COMMENT 'Ngày phê duyệt',
    nguoi_phe_duyet string COMMENT 'Người phê duyệt',
    ngay_xuat_file string COMMENT 'Ngày xuất file',
    process_id string COMMENT 'ID quy trình BPM',
    cn_ql_tktc string COMMENT 'Chi nhánh quản lý tài khoản tín chấp',
    cat_tktc string COMMENT 'Category tài khoản tín chấp',
    cn_ql_stk string COMMENT 'Chi nhánh quản lý sổ tiết kiệm',
    ls_so_stk string COMMENT 'Lãi suất sổ tiết kiệm',
    bien_do_ls decimal(38,10) COMMENT 'Biên độ lãi suất',
    ma_lien_ket_quyen string COMMENT 'Mã liên kết quyền',
    cn_ql_lien_ket_quyen string COMMENT 'Chi nhánh quản lý liên kết quyền',
    tai_khoan_wa string COMMENT 'Tài khoản WA',
    dien_giai_loi string COMMENT 'Diễn giải lỗi',
    ngay_ky string COMMENT 'Ngày ký',
    transaction_id string COMMENT 'ID giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tc_stk_thong_tin_tong_hop ADD CONSTRAINT sat_giao_dich_tc_stk_thong_tin_tong_hop_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tdcn_chi_tiet_san_pham (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    san_pham_id bigint COMMENT 'ID sản phẩm',
    loai_san_pham bigint COMMENT 'Loại sản phẩm',
    dong_xe bigint COMMENT 'Dòng xe',
    loai_xe bigint COMMENT 'Loại xe',
    gia_tri_ts decimal(38,10) COMMENT 'Giá trị tài sản',
    fast_lane bigint COMMENT 'Cờ fast lane',
    gd_tsbd string COMMENT 'Giao dịch tài sản bảo đảm',
    trang_thai_gd_tsbd bigint COMMENT 'Trạng thái giao dịch tài sản bảo đảm'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_chi_tiet_san_pham ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_chi_tiet_san_pham ADD CONSTRAINT sat_giao_dich_tdcn_chi_tiet_san_pham_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tdcn_khoan_cap_td_the (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID bản ghi',
    nhom_the string COMMENT 'Nhóm thẻ',
    hm_the_dx decimal(38,10) COMMENT 'Hạn mức thẻ đề xuất',
    nghia_vu_tra_no_kh decimal(38,10) COMMENT 'Nghĩa vụ trả nợ khách hàng',
    dti decimal(38,10) COMMENT 'DTI',
    ltv decimal(38,10) COMMENT 'LTV',
    tong_muc_cap_td_dx decimal(38,10) COMMENT 'Tổng mức cấp tín dụng đề xuất',
    rrtd_sp_co_va_khong_tsbd decimal(38,10) COMMENT 'RRTD sản phẩm có và không TSBD',
    rrtd_sp_khong_tsbd decimal(38,10) COMMENT 'RRTD sản phẩm không TSBD',
    rrtd_sp_thong_thuong decimal(38,10) COMMENT 'RRTD sản phẩm thông thường',
    rrtd_sp_thong_thuong_ko_tsbd decimal(38,10) COMMENT 'RRTD sản phẩm thông thường không TSBD',
    rrtd_kh_tai_ocb decimal(38,10) COMMENT 'RRTD khách hàng tại OCB',
    nguoi_tao string COMMENT 'Người tạo',
    ngay_tao string COMMENT 'Ngày tạo',
    cap_td_kem_khoan_vay bigint COMMENT 'Cấp tín dụng kèm khoản vay',
    hm_the_dx_pd decimal(38,10) COMMENT 'Hạn mức thẻ đề xuất phê duyệt',
    rrtd_sp_co_va_khong_tsbd_pd decimal(38,10) COMMENT 'RRTD sản phẩm có và không TSBD phê duyệt',
    rrtd_sp_khong_tsbd_pd decimal(38,10) COMMENT 'RRTD sản phẩm không TSBD phê duyệt'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_khoan_cap_td_the ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_khoan_cap_td_the ADD CONSTRAINT sat_giao_dich_tdcn_khoan_cap_td_the_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tdcn_nguoi_dong_vay (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    parent_id bigint COMMENT 'ID bản ghi cha',
    sub_id bigint COMMENT 'ID phụ',
    ngay_sinh string COMMENT 'Ngày sinh người đồng vay',
    khach_hang_no string COMMENT 'Khách hàng nợ',
    so_cif string COMMENT 'Số CIF',
    quan_he_id bigint COMMENT 'ID quan hệ',
    quoc_tich string COMMENT 'Quốc tịch',
    thoi_gian_con_o_vn bigint COMMENT 'Thời gian còn ở Việt Nam',
    so_tuoi string COMMENT 'Số tuổi',
    ngay_tao string COMMENT 'Ngày tạo'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_nguoi_dong_vay ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_nguoi_dong_vay ADD CONSTRAINT sat_giao_dich_tdcn_nguoi_dong_vay_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tdcn_sp_nhu_cau_td (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    san_pham_id bigint COMMENT 'ID sản phẩm',
    loai_san_pham bigint COMMENT 'Loại sản phẩm',
    phan_nhom_kh_theo_sp bigint COMMENT 'Phân nhóm khách hàng theo sản phẩm',
    phuong_thuc_cho_vay bigint COMMENT 'Phương thức cho vay',
    ty_le_vay decimal(38,10) COMMENT 'Tỷ lệ vay',
    tong_nhu_cau_von decimal(38,10) COMMENT 'Tổng nhu cầu vốn',
    so_tien_vay_dx decimal(38,10) COMMENT 'Số tiền vay đề xuất',
    thoi_gian_vay bigint COMMENT 'Thời gian vay',
    lai_suat_vay_du_kien decimal(38,10) COMMENT 'Lãi suất vay dự kiến',
    du_no_hien_tai_sp decimal(38,10) COMMENT 'Dư nợ hiện tại sản phẩm',
    rrtd_co_tsbd decimal(38,10) COMMENT 'RRTD có TSBD',
    rrtd_khong_co_tsbd decimal(38,10) COMMENT 'RRTD không có TSBD',
    rrtd_tat_ca_sp decimal(38,10) COMMENT 'RRTD tất cả sản phẩm',
    rrtd_tat_ca_sp_khong_tsbd decimal(38,10) COMMENT 'RRTD tất cả sản phẩm không TSBD',
    rrtd_sp_thong_thuong decimal(38,10) COMMENT 'RRTD sản phẩm thông thường',
    rrtd_sp_thong_thuong_khong_tsbd decimal(38,10) COMMENT 'RRTD sản phẩm thông thường không TSBD',
    ngay_tao string COMMENT 'Ngày tạo',
    dong_vay_co_cic bigint COMMENT 'Đồng vay có CIC',
    so_tien_pd decimal(38,10) COMMENT 'Số tiền phê duyệt',
    rrtd_co_tsbd_pd decimal(38,10) COMMENT 'RRTD có TSBD phê duyệt',
    rrtd_khong_co_tsbd_pd decimal(38,10) COMMENT 'RRTD không có TSBD phê duyệt',
    rrtd_tat_ca_sp_pd decimal(38,10) COMMENT 'RRTD tất cả sản phẩm phê duyệt',
    rrtd_tat_ca_sp_khong_tsbd_pd decimal(38,10) COMMENT 'RRTD tất cả sản phẩm không TSBD phê duyệt',
    rrtd_sp_thong_thuong_pd decimal(38,10) COMMENT 'RRTD sản phẩm thông thường phê duyệt',
    rrtd_sp_thong_thuong_khong_tsbd_pd decimal(38,10) COMMENT 'RRTD sản phẩm thông thường không TSBD phê duyệt',
    tong_rrtd_st decimal(38,10) COMMENT 'Tổng RRTD sơ thẩm',
    tong_rrtd_xl decimal(38,10) COMMENT 'Tổng RRTD xét lại',
    dieu_kien_bu_dap bigint COMMENT 'Điều kiện bù đắp',
    nguoi_so_ts_tu_von_vay bigint COMMENT 'Người sở hữu tài sản từ vốn vay',
    rrtd_doi_voi_kh_ocb decimal(38,10) COMMENT 'RRTD đối với khách hàng OCB',
    muc_dich_vay bigint COMMENT 'Mục đích vay',
    rrtd_doi_voi_kh_ocb_pd decimal(38,10) COMMENT 'RRTD đối với khách hàng OCB phê duyệt',
    rrtd_trinhcaptd_lan_nay decimal(38,10) COMMENT 'RRTD trình cấp tín dụng lần này',
    rrtd_trinhcaptd_lan_nay_pd decimal(38,10) COMMENT 'RRTD trình cấp tín dụng lần này phê duyệt',
    thoi_gian_an_han bigint COMMENT 'Thời gian ân hạn',
    mua_ban_uy_quyen bigint COMMENT 'Mua bán ủy quyền',
    rrtd_tat_ca_sp_khong_tsbd_temp decimal(38,10) COMMENT 'RRTD tất cả sản phẩm không TSBD tạm',
    khu_vuc_khach_hang bigint COMMENT 'Khu vực khách hàng',
    phuong_phap_cm_thu_nhap bigint COMMENT 'Phương pháp chứng minh thu nhập',
    khoan_vay_theo_cs_cbnv bigint COMMENT 'Khoản vay theo chính sách CBNV',
    muc_dich bigint COMMENT 'Mục đích',
    phuong_phap_cmtn bigint COMMENT 'Phương pháp chứng minh thu nhập (rút gọn)',
    khoan_vay_cs_cbnv bigint COMMENT 'Khoản vay chính sách CBNV'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_sp_nhu_cau_td ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_sp_nhu_cau_td ADD CONSTRAINT sat_giao_dich_tdcn_sp_nhu_cau_td_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_tdcn_thu_nhap_tra_no (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    thu_nhap_cua bigint COMMENT 'Thu nhập của',
    chi_tiet_nguon_tn bigint COMMENT 'Chi tiết nguồn thu nhập',
    so_tien decimal(38,10) COMMENT 'Số tiền',
    ngay_tao string COMMENT 'Ngày tạo',
    ngoai_le_thu_nhap_tra_no bigint COMMENT 'Ngoại lệ thu nhập trả nợ',
    noi_dung_ngoai_le string COMMENT 'Nội dung ngoại lệ',
    chung_tu_nguon_thu bigint COMMENT 'Chứng từ nguồn thu'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_thu_nhap_tra_no ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_thu_nhap_tra_no ADD CONSTRAINT sat_giao_dich_tdcn_thu_nhap_tra_no_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_the (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key int COMMENT 'Mã key đa hành',
    kh_id bigint COMMENT 'ID khách hàng',
    so_the string COMMENT 'Số thẻ',
    loai_the int COMMENT 'Loại thẻ',
    loai_the_t24 string COMMENT 'Loại thẻ T24',
    loai_the_chi_tiet int COMMENT 'Loại thẻ chi tiết',
    ten_in_tren_the string COMMENT 'Tên in trên thẻ',
    han_muc_de_xuat decimal(38,10) COMMENT 'Hạn mức đề xuất',
    han_muc_phe_duyet decimal(38,10) COMMENT 'Hạn mức phê duyệt',
    dia_chi string COMMENT 'Địa chỉ',
    the_chinh_phu int COMMENT 'Thẻ chính phủ',
    tinh_trang_the string COMMENT 'Tình trạng thẻ',
    so_tk_the string COMMENT 'Số tài khoản thẻ',
    tinh_trang_tk_the string COMMENT 'Tình trạng tài khoản thẻ',
    the_pre_approved int COMMENT 'Thẻ pre-approved',
    nhom_cskh string COMMENT 'Nhóm chăm sóc khách hàng',
    hieu_luc_the string COMMENT 'Hiệu lực thẻ',
    branch_code string COMMENT 'Mã chi nhánh',
    phat_hanh_the_phu string COMMENT 'Phát hành thẻ phụ',
    y_kien string COMMENT 'Ý kiến',
    sys_date string COMMENT 'Ngày hệ thống',
    loai_the_ttt string COMMENT 'Loại thẻ TTT',
    status_code string COMMENT 'Mã trạng thái',
    reason_message string COMMENT 'Thông điệp lý do'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_the ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_the ADD CONSTRAINT sat_giao_dich_the_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_giao_dich_ttd_igen (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID bản ghi',
    refnewfo string COMMENT 'Mã tham chiếu Newfo',
    khach_hang_id string COMMENT 'ID khách hàng',
    tenkhachhang string COMMENT 'Tên khách hàng',
    cif string COMMENT 'Số CIF',
    ngaysinh string COMMENT 'Ngày sinh',
    gioitinh string COMMENT 'Giới tính',
    sogiaytotuythan string COMMENT 'Số giấy tờ tùy thân',
    ngaycap bigint COMMENT 'Ngày cấp giấy tờ',
    noicap string COMMENT 'Nơi cấp giấy tờ',
    sodienthoai string COMMENT 'Số điện thoại',
    email string COMMENT 'Email',
    quoctich string COMMENT 'Quốc tịch',
    hokhauthuongtru string COMMENT 'Hộ khẩu thường trú',
    noiohientai string COMMENT 'Nơi ở hiện tại',
    xhtd string COMMENT 'Xếp hạng tín dụng',
    nhomcskhomni string COMMENT 'Nhóm CSKH Omni',
    hanmucdexuat bigint COMMENT 'Hạn mức đề xuất',
    hanmucpheduyet bigint COMMENT 'Hạn mức phê duyệt',
    tenintrenthe string COMMENT 'Tên in trên thẻ',
    chiphisinhhoat bigint COMMENT 'Chi phí sinh hoạt',
    chiphitranotctdkhac decimal(38,10) COMMENT 'Chi phí trả nợ TCTD khác',
    tinhtrangnghenghiep string COMMENT 'Tình trạng nghề nghiệp',
    chucvu string COMMENT 'Chức vụ',
    ascore string COMMENT 'A-score',
    bscore string COMMENT 'B-score',
    loaithechitietdexuat bigint COMMENT 'Loại thẻ chi tiết đề xuất',
    loaithedexuat bigint COMMENT 'Loại thẻ đề xuất',
    nghiepvuchitiet string COMMENT 'Nghiệp vụ chi tiết',
    doituongkh bigint COMMENT 'Đối tượng khách hàng',
    nhomcskhchung bigint COMMENT 'Nhóm CSKH chung',
    nhomcskhchitiet bigint COMMENT 'Nhóm CSKH chi tiết',
    ngay_tao string COMMENT 'Ngày tạo',
    user_tao string COMMENT 'User tạo',
    trang_thai bigint COMMENT 'Trạng thái',
    hinhthucbaodam bigint COMMENT 'Hình thức bảo đảm',
    tinhtranghonnhan string COMMENT 'Tình trạng hôn nhân',
    giatritsbd bigint COMMENT 'Giá trị TSBD',
    trangthaithe bigint COMMENT 'Trạng thái thẻ',
    matsbd string COMMENT 'Mã TSBD',
    mahm string COMMENT 'Mã hạn mức',
    hmthe decimal(38,10) COMMENT 'Hạn mức thẻ',
    donvitiente string COMMENT 'Đơn vị tiền thẻ',
    sothe string COMMENT 'Số thẻ',
    sanphamthe string COMMENT 'Sản phẩm thẻ',
    ngoithamdinh string COMMENT 'Ngồi thẩm định',
    donvipht string COMMENT 'Đơn vị phát hành thẻ',
    loaithew4 string COMMENT 'Loại thẻ W4',
    tenkhachhangdoitac string COMMENT 'Tên khách hàng đối tác',
    gtttdoitac string COMMENT 'GTTT đối tác',
    sdtdoitac string COMMENT 'SĐT đối tác',
    thunhapchiuthuedoitac bigint COMMENT 'Thu nhập chịu thuế đối tác',
    loaikhomni string COMMENT 'Loại KH Omni',
    gtttcu string COMMENT 'GTTT cũ',
    hanmuckhhh bigint COMMENT 'Hạn mức KH hiện hữu',
    hm_thethamchieu decimal(38,10) COMMENT 'Hạn mức thẻ tham chiếu',
    dunobinhquan_6t decimal(38,10) COMMENT 'Dư nợ bình quân 6 tháng',
    tyleduno_thoidiemxetcap decimal(38,10) COMMENT 'Tỷ lệ dư nợ thời điểm xét cấp',
    solantongduno decimal(38,10) COMMENT 'Số lần tổng dư nợ',
    tong_hm_the decimal(38,10) COMMENT 'Tổng hạn mức thẻ',
    ma_chi_nhanh string COMMENT 'Mã chi nhánh',
    ngaykhdexuat bigint COMMENT 'Ngày KH đề xuất',
    ngaypheduyetyeccaumothe bigint COMMENT 'Ngày phê duyệt yêu cầu mở thẻ',
    ngaybatdauhm bigint COMMENT 'Ngày bắt đầu hạn mức',
    ngayketthuchm bigint COMMENT 'Ngày kết thúc hạn mức',
    banghoitin string COMMENT 'Bảng hỏi tín',
    hinhanh string COMMENT 'Hình ảnh',
    source string COMMENT 'Nguồn',
    tong_thu_nhap decimal(38,10) COMMENT 'Tổng thu nhập',
    loaithepheduyet bigint COMMENT 'Loại thẻ phê duyệt',
    loaithechitietpheduyet bigint COMMENT 'Loại thẻ chi tiết phê duyệt',
    ketquaaml bigint COMMENT 'Kết quả AML',
    thethamchieu string COMMENT 'Thẻ tham chiếu'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_ttd_igen ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_ttd_igen ADD CONSTRAINT sat_giao_dich_ttd_igen_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_h_pdtd_gdich_ctiet_pduyet (
    pdtd_nhom_giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub PDTD Nhóm Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    trang_thai_bat_dau_id bigint COMMENT 'ID trạng thái bắt đầu',
    ngay_bat_dau string COMMENT 'Ngày bắt đầu',
    ngay_ket_thuc string COMMENT 'Ngày kết thúc',
    nguoi_thao_tac_id bigint COMMENT 'ID người thao tác',
    trang_thai_ket_thuc_id bigint COMMENT 'ID trạng thái kết thúc',
    ma_giao_dich string COMMENT 'Mã giao dịch',
    nguoi_thao_tac string COMMENT 'Người thao tác',
    process_id bigint COMMENT 'ID quy trình BPM',
    role_id bigint COMMENT 'ID vai trò',
    ket_qua_id bigint COMMENT 'ID kết quả',
    ten_tac_vu string COMMENT 'Tên tác vụ',
    role_tiep_theo_id bigint COMMENT 'ID vai trò tiếp theo',
    so_lan bigint COMMENT 'Số lần',
    thoi_gian_thuc_hien bigint COMMENT 'Thời gian thực hiện'
) CLUSTER BY AUTO;
ALTER TABLE sat_h_pdtd_gdich_ctiet_pduyet ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_h_pdtd_gdich_ctiet_pduyet ADD CONSTRAINT sat_h_pdtd_gdich_ctiet_pduyet_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_h_pdtd_gdich_lsu_pduyet (
    pdtd_nhom_giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub PDTD Nhóm Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    dvi_phe_duyet bigint COMMENT 'Đơn vị phê duyệt',
    nguoi_phe_duyet bigint COMMENT 'Người phê duyệt',
    ngay_phe_duyet string COMMENT 'Ngày phê duyệt',
    noi_dung_phe_duyet string COMMENT 'Nội dung phê duyệt',
    chu_thich string COMMENT 'Chú thích',
    trang_thai bigint COMMENT 'Trạng thái',
    dang_phe_duyet bigint COMMENT 'Đang phê duyệt',
    phe_duyet_id bigint COMMENT 'ID phê duyệt',
    noi_dung_phe_duyet1 string COMMENT 'Nội dung phê duyệt 1',
    noi_dung_phe_duyet2 string COMMENT 'Nội dung phê duyệt 2',
    noi_dung_phe_duyet3 string COMMENT 'Nội dung phê duyệt 3',
    noi_dung_phe_duyet4 string COMMENT 'Nội dung phê duyệt 4',
    noi_dung_phe_duyet5 string COMMENT 'Nội dung phê duyệt 5',
    noi_dung_phe_duyet6 string COMMENT 'Nội dung phê duyệt 6',
    noi_dung_phe_duyet7 string COMMENT 'Nội dung phê duyệt 7',
    noi_dung_phe_duyet8 string COMMENT 'Nội dung phê duyệt 8',
    noi_dung_phe_duyet9 string COMMENT 'Nội dung phê duyệt 9',
    nhom_id bigint COMMENT 'ID nhóm',
    tham_quyen string COMMENT 'Thẩm quyền'
) CLUSTER BY AUTO;
ALTER TABLE sat_h_pdtd_gdich_lsu_pduyet ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_h_pdtd_gdich_lsu_pduyet ADD CONSTRAINT sat_h_pdtd_gdich_lsu_pduyet_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_khach_hang_ca_nhan (
    khach_hang_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Khách Hàng',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID khách hàng cá nhân',
    ngay_sinh string COMMENT 'Ngày sinh',
    cmnd string COMMENT 'Số CMND',
    noi_cap_cmnd string COMMENT 'Nơi cấp CMND',
    ngay_cap_cmnd string COMMENT 'Ngày cấp CMND',
    ho_khau_thuong_tru string COMMENT 'Hộ khẩu thường trú',
    noi_o_hien_tai string COMMENT 'Nơi ở hiện tại',
    so_dien_thoai string COMMENT 'Số điện thoại',
    email string COMMENT 'Email',
    ngay_tao string COMMENT 'Ngày tạo',
    trang_thai bigint COMMENT 'Trạng thái',
    tinh_trang_hnhan_id bigint COMMENT 'ID tình trạng hôn nhân',
    tinh_trang_hnhan string COMMENT 'Tình trạng hôn nhân',
    ho_chieu string COMMENT 'Số hộ chiếu',
    can_cuoc_cong_dan string COMMENT 'Số căn cước công dân',
    gioi_tinh bigint COMMENT 'Giới tính',
    visa string COMMENT 'Số visa',
    ngay_cap_visa string COMMENT 'Ngày cấp visa',
    ngay_het_han_visa string COMMENT 'Ngày hết hạn visa',
    ngay_hieu_luc_visa string COMMENT 'Ngày hiệu lực visa',
    noi_cap_visa string COMMENT 'Nơi cấp visa',
    thoi_han_cu_tru_vn string COMMENT 'Thời hạn cư trú tại Việt Nam',
    ngay_het_han_cmnd string COMMENT 'Ngày hết hạn CMND',
    thu_nhap_hang_thang decimal(38,10) COMMENT 'Thu nhập hàng tháng',
    tham_nien_lam_viec decimal(38,10) COMMENT 'Thâm niên làm việc',
    the_can_cuoc string COMMENT 'Thẻ căn cước',
    quoc_tich string COMMENT 'Quốc tịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_khach_hang_ca_nhan ALTER COLUMN khach_hang_hashkey SET NOT NULL;
ALTER TABLE sat_khach_hang_ca_nhan ADD CONSTRAINT sat_khach_hang_ca_nhan_pk PRIMARY KEY (khach_hang_hashkey);


CREATE OR REPLACE TABLE sat_khach_hang_doanh_nghiep (
    khach_hang_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Khách Hàng',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID khách hàng doanh nghiệp',
    ma_dang_ky_kinh_doanh string COMMENT 'Mã đăng ký kinh doanh',
    ngay_cap string COMMENT 'Ngày cấp',
    noi_cap string COMMENT 'Nơi cấp',
    thoi_han_hoat_dong bigint COMMENT 'Thời hạn hoạt động',
    giay_phep_nganh_nghe string COMMENT 'Giấy phép ngành nghề',
    ma_giay_phep_nganh_nghe string COMMENT 'Mã giấy phép ngành nghề',
    noi_cap_giay_phep_nganh_nghe string COMMENT 'Nơi cấp giấy phép ngành nghề',
    ngay_cap_giay_phep_nganh_nghe string COMMENT 'Ngày cấp giấy phép ngành nghề',
    hluc_giay_phep_nganh_nghe string COMMENT 'Hiệu lực giấy phép ngành nghề',
    ngay_hoat_dong string COMMENT 'Ngày hoạt động',
    nganh_dang_ky_chinh string COMMENT 'Ngành đăng ký chính',
    von_dieu_le bigint COMMENT 'Vốn điều lệ',
    nguoi_dai_dien_phap_luat string COMMENT 'Người đại diện pháp luật',
    chuc_vu_nguoi_dd string COMMENT 'Chức vụ người đại diện',
    so_nhan_vien_van_phong bigint COMMENT 'Số nhân viên văn phòng',
    so_nhan_vien_cong_xuong bigint COMMENT 'Số nhân viên công xưởng',
    ngay_tao string COMMENT 'Ngày tạo',
    trang_thai bigint COMMENT 'Trạng thái',
    doanh_thu_nam_gan_nhat decimal(38,10) COMMENT 'Doanh thu năm gần nhất',
    tong_tai_san_nam_gan_nhat decimal(38,10) COMMENT 'Tổng tài sản năm gần nhất',
    tong_du_no_tctd decimal(38,10) COMMENT 'Tổng dư nợ TCTD',
    phan_khuc_khach_hang_id bigint COMMENT 'ID phân khúc khách hàng',
    ngay_thanh_lap string COMMENT 'Ngày thành lập',
    dia_chi_dkkd string COMMENT 'Địa chỉ đăng ký kinh doanh',
    nganh_nghe_dky_id bigint COMMENT 'ID ngành nghề đăng ký',
    giay_chung_nhan_dau_tu string COMMENT 'Giấy chứng nhận đầu tư',
    doanh_thu_nhom_kh_lien_quan bigint COMMENT 'Doanh thu nhóm khách hàng liên quan',
    han_muc_rrtd_cua_kh decimal(38,10) COMMENT 'Hạn mức RRTD của khách hàng',
    dn_co_phat_trien_da_dac_thu bigint COMMENT 'Doanh nghiệp có phát triển đặc thù'
) CLUSTER BY AUTO;
ALTER TABLE sat_khach_hang_doanh_nghiep ALTER COLUMN khach_hang_hashkey SET NOT NULL;
ALTER TABLE sat_khach_hang_doanh_nghiep ADD CONSTRAINT sat_khach_hang_doanh_nghiep_pk PRIMARY KEY (khach_hang_hashkey);


CREATE OR REPLACE TABLE sat_lich_su_giao_dich (
    giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    vai_tro_nguoi_xl bigint COMMENT 'Vai trò người xử lý',
    vai_tro_tiep_theo bigint COMMENT 'Vai trò tiếp theo',
    vai_tro_truoc bigint COMMENT 'Vai trò trước',
    thoi_diem_bat_dau string COMMENT 'Thời điểm bắt đầu',
    thoi_diem_ket_thuc string COMMENT 'Thời điểm kết thúc',
    ten_tac_vu string COMMENT 'Tên tác vụ',
    trang_thai_ban_dau bigint COMMENT 'Trạng thái ban đầu',
    trang_thai_ket_thuc bigint COMMENT 'Trạng thái kết thúc',
    luong_id bigint COMMENT 'ID luồng',
    ket_qua_xu_ly bigint COMMENT 'Kết quả xử lý',
    task_id string COMMENT 'ID tác vụ',
    nguoi_tao_id string COMMENT 'ID người tạo',
    ngay_tao string COMMENT 'Ngày tạo',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    chuc_danh bigint COMMENT 'Chức danh',
    thoi_gian_xu_ly bigint COMMENT 'Thời gian xử lý',
    don_vi_id bigint COMMENT 'ID đơn vị'
) CLUSTER BY AUTO;
ALTER TABLE sat_lich_su_giao_dich ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_lich_su_giao_dich ADD CONSTRAINT sat_lich_su_giao_dich_pk PRIMARY KEY (giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_pdtd_giao_dich_tin_dung (
    pdtd_nhom_giao_dich_hashkey string NOT NULL COMMENT 'Tham chiếu Hub PDTD Nhóm Giao Dịch',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Mã key đa hành',
    so_tien_vay_de_xuat decimal(38,10) COMMENT 'Số tiền vay đề xuất',
    tong_hmrr_100 decimal(38,10) COMMENT 'Tổng HMRR 100%',
    tong_hmrr_ko_100 decimal(38,10) COMMENT 'Tổng HMRR không 100%',
    tong_dthu_gan_nhat decimal(38,10) COMMENT 'Tổng doanh thu gần nhất',
    tong_tsan_gan_nhat decimal(38,10) COMMENT 'Tổng tài sản gần nhất',
    du_no_vay_tctd decimal(38,10) COMMENT 'Dư nợ vay TCTD',
    ttin_tien_gui bigint COMMENT 'Thông tin tiền gửi',
    tvay_la_tgui bigint COMMENT 'Tỷ vay là tỷ gửi',
    loai_tsdb bigint COMMENT 'Loại TSDB',
    phan_loai_tsdb bigint COMMENT 'Phân loại TSDB',
    ty_le_dam_bao decimal(38,10) COMMENT 'Tỷ lệ đảm bảo',
    qche_chovay_bao_khac bigint COMMENT 'Quy chế cho vay bảo đảm khác',
    qdinh_tin_dung bigint COMMENT 'Quy định tín dụng',
    cstindung_theokh bigint COMMENT 'Chính sách tín dụng theo khách hàng',
    spham_tindung bigint COMMENT 'Sản phẩm tín dụng',
    tyle_baodam_ngoaile bigint COMMENT 'Tỷ lệ bảo đảm ngoại lệ',
    ngoai_le_cv_nv_ocb bigint COMMENT 'Ngoại lệ cho vay nhân viên OCB',
    pdnl_upload string COMMENT 'PDNL upload',
    ds_xe_mua_khanga bigint COMMENT 'Danh sách xe mua kho',
    dsdv_banxe_ocb_cnhan bigint COMMENT 'DSDV bán xe OCB cá nhân',
    tsbd bigint COMMENT 'Tài sản bảo đảm',
    csh_tsbd bigint COMMENT 'Chủ sở hữu TSBD',
    ploai_bds bigint COMMENT 'Phân loại BĐS',
    dvkd_tpho_trung_uong bigint COMMENT 'DVKD thành phố trung ương',
    tle_cvay_dgia_tsbd bigint COMMENT 'Tỷ lệ cho vay / định giá TSBD',
    loai_bdsmua bigint COMMENT 'Loại BĐS mua',
    loaikh bigint COMMENT 'Loại khách hàng',
    kh_nocic_12thang bigint COMMENT 'KH nợ CIC 12 tháng',
    diaban_dvkd bigint COMMENT 'Địa bàn DVKD',
    vitritsbd_khanga bigint COMMENT 'Vị trí TSBD kho',
    mien_bcao_gsat_tdung bigint COMMENT 'Miễn báo cáo giám sát tín dụng',
    tdiem_bcao_gsat_tdung string COMMENT 'Thời điểm báo cáo giám sát tín dụng',
    ngung_qhtd_ocb_nho_6thang bigint COMMENT 'Ngừng QHTD OCB nhỏ 6 tháng',
    ngung_qhtd_ocb_nho_3thang bigint COMMENT 'Ngừng QHTD OCB nhỏ 3 tháng',
    no_qua_han bigint COMMENT 'Nợ quá hạn',
    kqua_bcao_gstd bigint COMMENT 'Kết quả báo cáo giám sát tín dụng',
    tdiem_bcao_gstd_3t bigint COMMENT 'Thời điểm báo cáo giám sát 3 tháng',
    tong_hmuc_rui_ro decimal(38,10) COMMENT 'Tổng hạn mức rủi ro',
    loai_tdung_da_cap bigint COMMENT 'Loại tín dụng đã cấp',
    tsbd_hang_hoa bigint COMMENT 'TSBD hàng hóa',
    tdiem_cap_tdung_hon_3thang bigint COMMENT 'Thời điểm cấp tín dụng hơn 3 tháng',
    kh_mien_tdinh_ttiep bigint COMMENT 'KH miễn thẩm định tiếp',
    filedinhkem string COMMENT 'File đính kèm',
    ngay_tdtt_truocday string COMMENT 'Ngày thẩm định trước đây',
    no_nhom2_12thang bigint COMMENT 'Nợ nhóm 2 trong 12 tháng',
    tthu_dk_pduyet bigint COMMENT 'Thông tin điều kiện phê duyệt',
    datadate string COMMENT 'Ngày dữ liệu',
    json_tin_dung_cap_moi string COMMENT 'JSON tín dụng cấp mới',
    json_tai_cap string COMMENT 'JSON tái cấp',
    tai_san_dam_bao string COMMENT 'Tài sản đảm bảo',
    to_trinh_goc_id bigint COMMENT 'ID tờ trình gốc',
    loai_hinh_vay bigint COMMENT 'Loại hình vay',
    nhom_giao_dich bigint COMMENT 'Nhóm giao dịch',
    loai_giao_dich bigint COMMENT 'Loại giao dịch',
    so_tien_da_cap decimal(38,10) COMMENT 'Số tiền đã cấp'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_giao_dich_tin_dung ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_giao_dich_tin_dung ADD CONSTRAINT sat_pdtd_giao_dich_tin_dung_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);


CREATE OR REPLACE TABLE sat_qlns_nguoi_lao_dong_info_don_vi (
    qlns_nguoi_lao_dong_info_hashkey string NOT NULL COMMENT 'Tham chiếu Hub QLNS Người Lao Động',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    khoi string COMMENT 'Khối',
    ma_khoi string COMMENT 'Mã khối',
    don_vi string COMMENT 'Đơn vị',
    ma_don_vi string COMMENT 'Mã đơn vị',
    phong_ban string COMMENT 'Phòng ban',
    ma_phong_ban string COMMENT 'Mã phòng ban',
    bo_phan string COMMENT 'Bộ phận',
    ma_bo_phan string COMMENT 'Mã bộ phận',
    to_nhom string COMMENT 'Tổ nhóm',
    ma_to_nhom string COMMENT 'Mã tổ nhóm',
    noi_lam_viec string COMMENT 'Nơi làm việc',
    chuc_danh string COMMENT 'Chức danh',
    ma_chuc_danh string COMMENT 'Mã chức danh',
    chuc_danh_nnv string COMMENT 'Chức danh người nhà việc',
    ma_chuc_danh_nnv string COMMENT 'Mã chức danh NNV',
    chuc_danh_1 string COMMENT 'Chức danh 1',
    phan_nhom_chuc_danh string COMMENT 'Phân nhóm chức danh',
    cap_bac string COMMENT 'Cấp bậc',
    ma_cap_bac string COMMENT 'Mã cấp bậc',
    tham_nien_vi_tri string COMMENT 'Thâm niên vị trí',
    ten_dang_nhap string COMMENT 'Tên đăng nhập'
) CLUSTER BY AUTO;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_don_vi ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_don_vi ADD CONSTRAINT sat_qlns_nguoi_lao_dong_info_don_vi_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);


CREATE OR REPLACE TABLE sat_tsbd_chu_so_huu (
    tsbd_chu_so_huu_hashkey string NOT NULL COMMENT 'Tham chiếu Hub Chủ Sở Hữu TSBD',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ho_ten string COMMENT 'Họ tên chủ sở hữu',
    cmnd string COMMENT 'Số CMND',
    dia_chi string COMMENT 'Địa chỉ',
    nguoi_tao bigint COMMENT 'Người tạo',
    ngay_tao string COMMENT 'Ngày tạo',
    ngay_sinh string COMMENT 'Ngày sinh',
    trang_thai bigint COMMENT 'Trạng thái',
    t24 bigint COMMENT 'Mã T24',
    loai_chu_so_huu bigint COMMENT 'Loại chủ sở hữu',
    isho bigint COMMENT 'Cờ hộ khẩu',
    ma_chu_so_huu string COMMENT 'Mã chủ sở hữu',
    khach_hang_id bigint COMMENT 'ID khách hàng'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_chu_so_huu ALTER COLUMN tsbd_chu_so_huu_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_chu_so_huu ADD CONSTRAINT sat_tsbd_chu_so_huu_pk PRIMARY KEY (tsbd_chu_so_huu_hashkey);
