# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- ============================================================
-- SOURCE: T24
-- ============================================================

CREATE OR REPLACE VIEW v_stg_t24_t24_ac_locked_events AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_ACCOUNT_NUMBER,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_FROM_DATE,
    CAST(NULL AS STRING) AS T_TO_DATE,
    CAST(NULL AS DECIMAL) AS T_LOCKED_AMOUNT,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_locked_events,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_account AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS INT) AS T_CUSTOMER,
    CAST(NULL AS INT) AS T_CATEGORY,
    CAST(NULL AS STRING) AS T_ACCOUNT_TITLE_1,
    CAST(NULL AS STRING) AS T_ACCOUNT_TITLE_2,
    CAST(NULL AS STRING) AS T_SHORT_TITLE,
    CAST(NULL AS STRING) AS T_CURRENCY,
    CAST(NULL AS STRING) AS T_ACCOUNT_OFFICER,
    CAST(NULL AS DECIMAL) AS T_OPEN_ACTUAL_BAL,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_classification,
    CAST(NULL AS STRING) AS hashdiff_account_balance,
    CAST(NULL AS STRING) AS hashdiff_account_system,
    CAST(NULL AS STRING) AS hashdiff_account_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_account_closed AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_ACCT_CLOSE_DATE,
    CAST(NULL AS STRING) AS T_ACCOUNT_NO,
    CAST(NULL AS STRING) AS T_CUSTOMER_ID,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_account_credit_int AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS t_interest_day_basic,
    CAST(NULL AS STRING) AS t_cr_balance_type,
    CAST(NULL AS STRING) AS t_cr_calcul_type,
    CAST(NULL AS STRING) AS t_cr_int_rate,
    CAST(NULL AS STRING) AS t_cre_margin_rate,
    CAST(NULL AS DECIMAL) AS t_cr_minimum_bal,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_credit_int_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_account_debit_int AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CHARGE_KEY,
    CAST(NULL AS STRING) AS T_INTEREST_DAY_BASIS,
    CAST(NULL AS STRING) AS T_DR_BALANCE_TYPE,
    CAST(NULL AS STRING) AS T_DR_CALCUL_TYPE,
    CAST(NULL AS DECIMAL) AS T_DR_INT_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_debit_int_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_az_account AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_MATURITY_DATE,
    CAST(NULL AS DECIMAL) AS T_INTEREST_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_deposits_terms,
    CAST(NULL AS STRING) AS hashdiff_deposits_system,
    CAST(NULL AS STRING) AS hashdiff_deposits_rate,
    CAST(NULL AS STRING) AS hashdiff_deposits_information,
    CAST(NULL AS STRING) AS hashdiff_deposits_ftp,
    CAST(NULL AS STRING) AS hashdiff_deposits_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_az_product_parameter AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS DECIMAL) AS T_ALLOWED_CATEG,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_basic_interest AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_INTEREST_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_bc_sort_code AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_NAME,
    CAST(NULL AS STRING) AS T_TELEPHONE_NO,
    CAST(NULL AS STRING) AS T_IDENTITY_KIND,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_categ_entry AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_TRANS_REFERENCE,
    CAST(NULL AS DECIMAL) AS T_PRODUCT_CATEGORY,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_categ_entry_audit,
    CAST(NULL AS STRING) AS hashdiff_categ_entry_classification,
    CAST(NULL AS STRING) AS hashdiff_categ_entry_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_category AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_collateral AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_COLLATERAL_TYPE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_collateral_information,
    CAST(NULL AS STRING) AS hashdiff_collateral_insurance,
    CAST(NULL AS STRING) AS hashdiff_collateral_instrument,
    CAST(NULL AS STRING) AS hashdiff_collateral_valuation,
    CAST(NULL AS STRING) AS hashdiff_collateral_vehicle,
    CAST(NULL AS STRING) AS hashdiff_collateral_other,
    CAST(NULL AS STRING) AS hashdiff_collateral_real_estate,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_collateral_code AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_collateral_right AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_LIMIT_REFERENCE,
    CAST(NULL AS STRING) AS T_LIMIT_REF_CUST,
    CAST(NULL AS STRING) AS T_PERCENT_ALLOC,
    CAST(NULL AS STRING) AS T_COMPANY_ID,
    CAST(NULL AS STRING) AS T_VALIDITY_DATE,
    CAST(NULL AS STRING) AS T_EXPIRY_DATE,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_STATUS,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_COLLATERAL_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_collateral_right_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_collateral_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_company AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_MNEMONIC,
    CAST(NULL AS STRING) AS T_COMPANY_NAME,
    CAST(NULL AS STRING) AS T_CONSOLIDATION_MARK,
    CAST(NULL AS STRING) AS T_DEFAULT_NO_OF_AUTH,
    CAST(NULL AS STRING) AS T_PGM_AUTOM_ID,
    CAST(NULL AS STRING) AS T_APPLICATIONS,
    CAST(NULL AS STRING) AS T_TAX_CODE,
    CAST(NULL AS STRING) AS T_FINANCIAL_YEAR_END,
    CAST(NULL AS STRING) AS T_SUB_DIVISION_CODE,
    CAST(NULL AS STRING) AS T_OFFICIAL_HOLIDAY,
    CAST(NULL AS STRING) AS T_BRANCH_HOLIDAY,
    CAST(NULL AS STRING) AS T_BATCH_HOLIDAY,
    CAST(NULL AS STRING) AS T_NAME_ADDRESS,
    CAST(NULL AS STRING) AS T_LANGUAGE_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_branch_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_consolidate_prft_loss AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_PL_CATEGORY,
    CAST(NULL AS STRING) AS T_CURRENCY,
    CAST(NULL AS STRING) AS T_CCY_BALANCE_YTD,
    CAST(NULL AS STRING) AS T_BALANCE_YTD,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_consolidate_profit_n_loss_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_country AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_COUNTRY_NAME,
    CAST(NULL AS STRING) AS T_SHORT_NAME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_crb AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS CHINHANH,
    CAST(NULL AS STRING) AS NGOAITE,
    CAST(NULL AS STRING) AS GL,
    CAST(NULL AS STRING) AS TIEUKHOAN,
    CAST(NULL AS STRING) AS TEN,
    CAST(NULL AS STRING) AS NGOAITE1,
    CAST(NULL AS STRING) AS NOITE,
    CAST(NULL AS STRING) AS SOTKCU,
    CAST(NULL AS STRING) AS LAISUAT,
    CAST(NULL AS STRING) AS KYHAN,
    CAST(NULL AS STRING) AS STARTDATE,
    CAST(NULL AS STRING) AS ENDDATE,
    CAST(NULL AS STRING) AS MASP,
    CAST(NULL AS STRING) AS LAIDATRA,
    CAST(NULL AS STRING) AS LOANCLASS,
    CAST(NULL AS INT) AS CIF,
    CAST(NULL AS INT) AS CATEGORY,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS DECIMAL) AS SODU,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_crb_balance,
    CAST(NULL AS STRING) AS hashdiff_crb_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_currency AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_NUMERIC_CCY_CODE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_currency,
    CAST(NULL AS STRING) AS hashdiff_currency_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_cus_pkg AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_PRODUCT_PACKAGE_ID,
    CAST(NULL AS STRING) AS T_BEGIN_DATE,
    CAST(NULL AS STRING) AS T_EXPIRE_DATE,
    CAST(NULL AS STRING) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_DEPT_CODE,
    CAST(NULL AS STRING) AS T_ACCOUNT_CHARGE,
    CAST(NULL AS STRING) AS T_PARTNER_ID,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_cust_package,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_customer AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_customer_information,
    CAST(NULL AS STRING) AS hashdiff_customer_other,
    CAST(NULL AS STRING) AS hashdiff_customer_classification,
    CAST(NULL AS STRING) AS hashdiff_customer_contact,
    CAST(NULL AS STRING) AS hashdiff_customer_financial_statement,
    CAST(NULL AS STRING) AS hashdiff_customer_kyc,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_de_bic AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_INSTITUTION,
    CAST(NULL AS STRING) AS T_CITY,
    CAST(NULL AS STRING) AS T_ADDRESS,
    CAST(NULL AS STRING) AS T_COUNTRY,
    CAST(NULL AS STRING) AS T_SUBTYPE_IND,
    CAST(NULL AS STRING) AS T_RECORDKEY,
    CAST(NULL AS STRING) AS T_BRANCH,
    CAST(NULL AS STRING) AS T_BIC_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_dealer_desk AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS DESCRIPTIONS,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_department AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_GROUP_ID,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_dept_acct_officer AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_acct_officer_information,
    CAST(NULL AS STRING) AS hashdiff_acct_officer_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_drawings AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_drawings_system,
    CAST(NULL AS STRING) AS hashdiff_drawings_other,
    CAST(NULL AS STRING) AS hashdiff_drawings_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_forex AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_TRANSACTION_REF_NO,
    CAST(NULL AS DECIMAL) AS T_COUNTERPARTY,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_forex_rate,
    CAST(NULL AS STRING) AS hashdiff_forex_pricing_pnl,
    CAST(NULL AS STRING) AS hashdiff_forex_payment_swift,
    CAST(NULL AS STRING) AS hashdiff_forex_other,
    CAST(NULL AS STRING) AS hashdiff_forex_information,
    CAST(NULL AS STRING) AS hashdiff_forex_classification,
    CAST(NULL AS STRING) AS hashdiff_forex_audit_status,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ft_txn_type_condition AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_SHORT_DESCR,
    CAST(NULL AS STRING) AS T_TXN_CODE_CR,
    CAST(NULL AS STRING) AS T_TXN_CODE_DR,
    CAST(NULL AS STRING) AS T_STO_TXN_CODE_CR,
    CAST(NULL AS STRING) AS T_STO_TXN_CODE_DR,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_funds_transfer AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DEBIT_ACCT_NO,
    CAST(NULL AS STRING) AS T_DEBIT_CURRENCY,
    CAST(NULL AS STRING) AS T_CREDIT_ACCT_NO,
    CAST(NULL AS STRING) AS T_CREDIT_CURRENCY,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_PAYMENT_DETAILS,
    CAST(NULL AS STRING) AS T_TRANSACTION_TYPE,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_funds_transfer_system,
    CAST(NULL AS STRING) AS hashdiff_funds_transfer_party,
    CAST(NULL AS STRING) AS hashdiff_funds_transfer_other,
    CAST(NULL AS STRING) AS hashdiff_funds_transfer_information,
    CAST(NULL AS STRING) AS hashdiff_funds_transfer_fee,
    CAST(NULL AS STRING) AS hashdiff_funds_transfer_account,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_gci AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_INTEREST_DAY_BASIS,
    CAST(NULL AS STRING) AS T_CR_BALANCE_TYPE,
    CAST(NULL AS STRING) AS T_CR_CALCUL_TYPE,
    CAST(NULL AS STRING) AS T_CR_BASIC_RATE,
    CAST(NULL AS STRING) AS T_CR_INT_RATE,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS INT) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS DECIMAL) AS T_CR_MINIMUM_BAL,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_gci_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_gdi AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS INT) AS T_CHARGE_KEY,
    CAST(NULL AS STRING) AS T_INTEREST_DAY_BASIS,
    CAST(NULL AS STRING) AS T_DR_BALANCE_TYPE,
    CAST(NULL AS STRING) AS T_DR_CALCUL_TYPE,
    CAST(NULL AS STRING) AS T_DR_BASIC_RATE,
    CAST(NULL AS STRING) AS T_DR_INT_RATE,
    CAST(NULL AS STRING) AS T_APR_REQUIRED,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS INT) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_DR_LIMIT_AMT,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_gdi_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_holiday AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_JANUARY,
    CAST(NULL AS STRING) AS T_FEBRUARY,
    CAST(NULL AS STRING) AS T_MARCH,
    CAST(NULL AS STRING) AS T_APRIL,
    CAST(NULL AS STRING) AS T_MAY,
    CAST(NULL AS STRING) AS T_JUNE,
    CAST(NULL AS STRING) AS T_JULY,
    CAST(NULL AS STRING) AS T_AUGUST,
    CAST(NULL AS STRING) AS T_SEPTEMBER,
    CAST(NULL AS STRING) AS T_OCTOBER,
    CAST(NULL AS STRING) AS T_NOVEMBER,
    CAST(NULL AS STRING) AS T_DECEMBER,
    CAST(NULL AS STRING) AS T_WEEKEND_DAYS,
    CAST(NULL AS STRING) AS T_MTH_01_TABLE,
    CAST(NULL AS STRING) AS T_MTH_02_TABLE,
    CAST(NULL AS STRING) AS T_MTH_03_TABLE,
    CAST(NULL AS STRING) AS T_MTH_04_TABLE,
    CAST(NULL AS STRING) AS T_MTH_05_TABLE,
    CAST(NULL AS STRING) AS T_MTH_06_TABLE,
    CAST(NULL AS STRING) AS T_MTH_07_TABLE,
    CAST(NULL AS STRING) AS T_MTH_08_TABLE,
    CAST(NULL AS STRING) AS T_MTH_09_TABLE,
    CAST(NULL AS STRING) AS T_MTH_10_TABLE,
    CAST(NULL AS STRING) AS T_MTH_11_TABLE,
    CAST(NULL AS STRING) AS T_MTH_12_TABLE,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS DECIMAL) AS T_CURR_NO,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_industry AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_lc_types AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS DECIMAL) AS T_CATEGORY_CODE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_aprv_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_APRV_DTE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ld_aprv_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_aprv_user AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_APP_USER_NAME,
    CAST(NULL AS STRING) AS T_UBTD1,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_economic_sector AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_PARENT_ID,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_extra_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_SALES_ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ld_extra_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_ins_type_comp AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_INS_TYPE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ld_ins_type_comp,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_partner AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_NAME,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS DECIMAL) AS T_CURR_NO,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_promotion AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ld_schedule_define AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_K_DATE,
    CAST(NULL AS STRING) AS T_SCH_TYPE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_schedule,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_letter_of_credit AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_LC_TYPE,
    CAST(NULL AS STRING) AS T_OPERATION,
    CAST(NULL AS STRING) AS T_EXTERNAL_REFERENCE,
    CAST(NULL AS STRING) AS T_OLD_LC_NUMBER,
    CAST(NULL AS DECIMAL) AS T_ISSUING_BANK_NO,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_letter_of_credit_value,
    CAST(NULL AS STRING) AS hashdiff_letter_of_credit_terms,
    CAST(NULL AS STRING) AS hashdiff_letter_of_credit_system,
    CAST(NULL AS STRING) AS hashdiff_letter_of_credit_party,
    CAST(NULL AS STRING) AS hashdiff_letter_of_credit_other,
    CAST(NULL AS STRING) AS hashdiff_letter_of_credit_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_limit AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_LIMIT_CURRENCY,
    CAST(NULL AS STRING) AS T_COLLATERAL_CODE,
    CAST(NULL AS STRING) AS T_COLLAT_RIGHT,
    CAST(NULL AS STRING) AS T_MAXIMUM_SECURED,
    CAST(NULL AS DECIMAL) AS T_MAXIMUM_UNSECURED,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_limit_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_limit_reference AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_LIMIT_REFERENCE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_line_mvmt_toanhang AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS T_LINE_ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_STT,
    CAST(NULL AS STRING) AS T_Y_KEY_DET,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_line_movement_toanhang,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_lmm_account_balances AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DATE_FROM,
    CAST(NULL AS STRING) AS T_EFFECTIVE_DATE,
    CAST(NULL AS STRING) AS T_TRANS_PRIN_AMT,
    CAST(NULL AS STRING) AS T_OUTS_CURR_PRINC,
    CAST(NULL AS DECIMAL) AS T_OUTS_ACCRUED_INT,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_lmm_account_balances,
    CAST(NULL AS STRING) AS hashdiff_lmm_account_balances_other,
    CAST(NULL AS STRING) AS hashdiff_money_market_lmm_account_balances,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ln_cust_revs_dtls AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DATE,
    CAST(NULL AS STRING) AS ACCOUNT_BALANCE,
    CAST(NULL AS STRING) AS TOTAL_ACCRUAL,
    CAST(NULL AS STRING) AS CUSTOMER,
    CAST(NULL AS STRING) AS CONTRACT_ID,
    CAST(NULL AS STRING) AS OUTS_AMOUNT,
    CAST(NULL AS STRING) AS CURRENCY,
    CAST(NULL AS STRING) AS K_TYPE,
    CAST(NULL AS STRING) AS OUTS_ACCR_INT,
    CAST(NULL AS STRING) AS STMT_NO,
    CAST(NULL AS STRING) AS T_LINE_NO,
    CAST(NULL AS STRING) AS T_ACCOUNT_NO,
    CAST(NULL AS STRING) AS T_PRE_LINE_NO,
    CAST(NULL AS STRING) AS T_PRE_ACCOUNT_NO,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_ln_cust_revs_dtls,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_loan_method AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_LOAN_METHOD,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS DECIMAL) AS T_CURR_NO,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_loan_purpose AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_loan_subproduct AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_loans_and_deposits AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_INTEREST_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_approval,
    CAST(NULL AS STRING) AS hashdiff_loans_classification,
    CAST(NULL AS STRING) AS hashdiff_loans_information,
    CAST(NULL AS STRING) AS hashdiff_loans_other,
    CAST(NULL AS STRING) AS hashdiff_loans_insurance,
    CAST(NULL AS STRING) AS hashdiff_loans_system,
    CAST(NULL AS STRING) AS hashdiff_loans_rate,
    CAST(NULL AS STRING) AS hashdiff_loans_terms,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_md_deal AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS INT) AS T_CUSTOMER,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_md_deal_value,
    CAST(NULL AS STRING) AS hashdiff_md_deal_system,
    CAST(NULL AS STRING) AS hashdiff_md_deal_provision,
    CAST(NULL AS STRING) AS hashdiff_md_deal_other,
    CAST(NULL AS STRING) AS hashdiff_md_deal_information,
    CAST(NULL AS STRING) AS hashdiff_md_deal_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_money_market AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CONTRACT_NO,
    CAST(NULL AS STRING) AS T_DEAL_DATE,
    CAST(NULL AS STRING) AS T_VALUE_DATE,
    CAST(NULL AS STRING) AS T_TERM,
    CAST(NULL AS STRING) AS T_MATURITY_DATE,
    CAST(NULL AS DECIMAL) AS T_PRINCIPAL,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_money_market_rate,
    CAST(NULL AS STRING) AS hashdiff_money_market_classification,
    CAST(NULL AS STRING) AS hashdiff_money_market_audit_status,
    CAST(NULL AS STRING) AS hashdiff_money_market_payment_information,
    CAST(NULL AS STRING) AS hashdiff_money_market_guarantee,
    CAST(NULL AS STRING) AS hashdiff_money_market_information,
    CAST(NULL AS STRING) AS hashdiff_money_market_rollover_schedule,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_classification AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_ACTIVE_STATUS,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_coll_basel AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DBSTK_PUBLISHER,
    CAST(NULL AS STRING) AS T_FITCH_RTG_FORM,
    CAST(NULL AS STRING) AS T_FITCH_RATING,
    CAST(NULL AS STRING) AS T_MOODY_RTG_FORM,
    CAST(NULL AS STRING) AS T_MOODY_RATING,
    CAST(NULL AS STRING) AS T_SP_RTG_FORM,
    CAST(NULL AS STRING) AS T_SP_RATING,
    CAST(NULL AS STRING) AS T_OTHER_RTG_FORM,
    CAST(NULL AS STRING) AS T_OTHER_RATING,
    CAST(NULL AS STRING) AS T_OT_RATING_NAME,
    CAST(NULL AS STRING) AS T_COUPON_INT_RATE,
    CAST(NULL AS STRING) AS T_INT_MODE_PAY,
    CAST(NULL AS STRING) AS T_INTPAY_NUM_YEAR,
    CAST(NULL AS STRING) AS T_STK_EXCHANGE,
    CAST(NULL AS STRING) AS T_SALE_AREA_PERCT,
    CAST(NULL AS STRING) AS T_RE_BUY_MORTGAGE,
    CAST(NULL AS STRING) AS T_VPAPER_ISSG_ORG,
    CAST(NULL AS STRING) AS T_SB_VPAPER_NO,
    CAST(NULL AS STRING) AS T_SV_EXPIRE_DATE,
    CAST(NULL AS STRING) AS T_SB_VP_TERM,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_collateral_basel,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_coll_borrow_purpose AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS ID2,
    CAST(NULL AS STRING) AS T_DETAIL,
    CAST(NULL AS STRING) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_DEPT_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_coll_rev_agent AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_cus_ext_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_COMP_UNDER_1Y,
    CAST(NULL AS STRING) AS T_COMP_FI_STATEMENT,
    CAST(NULL AS STRING) AS T_LD_GUA_BY_DEPOSIT,
    CAST(NULL AS STRING) AS T_SALE_INCOME,
    CAST(NULL AS STRING) AS T_TOTAL_DEBT_LOAN,
    CAST(NULL AS STRING) AS T_EQUITY,
    CAST(NULL AS STRING) AS T_LABOUR_NUMBER,
    CAST(NULL AS STRING) AS T_CUS_INCOME,
    CAST(NULL AS STRING) AS T_TOTAL_IN_DATE,
    CAST(NULL AS STRING) AS T_TOTAL_INCOME,
    CAST(NULL AS STRING) AS T_TOTAL_PROPERTY,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_customer_extra_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_cus_group AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CUST_GROUP_NAME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_deposit_prgm AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_PRGM_NAME,
    CAST(NULL AS STRING) AS T_BEGIN_DATE,
    CAST(NULL AS STRING) AS T_END_DATE,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_ft_outward_purpose AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_PURPOSE_TYPE,
    CAST(NULL AS STRING) AS T_DESC,
    CAST(NULL AS STRING) AS T_CUS_TYPE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_fx_buyfcy_purpose AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_ld_basel AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_BASEL_HOME_PP,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_basel,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_ld_prod_main AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_NAME,
    CAST(NULL AS STRING) AS T_CATEGORY,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS STRING) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_DEPT_CODE,
    CAST(NULL AS STRING) AS T_AUDITOR_CODE,
    CAST(NULL AS STRING) AS T_AUDIT_DATE_TIME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_loan_pro_bundle AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS DESCRIPTION,
    CAST(NULL AS STRING) AS SUB_PRODUCT,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_md_purpose AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_PURPOSE_NAME,
    CAST(NULL AS STRING) AS T_PARENT_ID,
    CAST(NULL AS STRING) AS T_N_USED,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_prod_package_partner AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_PARTNER_NAME,
    CAST(NULL AS STRING) AS T_CIF,
    CAST(NULL AS STRING) AS T_AC_MANAGE_FEE_PER,
    CAST(NULL AS STRING) AS T_AC_MANAGE_FEE_TERM,
    CAST(NULL AS STRING) AS T_EXT_FT_FEE_PER,
    CAST(NULL AS STRING) AS T_EXT_FT_FEE_TERM,
    CAST(NULL AS STRING) AS T_IB_FEE_PER,
    CAST(NULL AS STRING) AS T_IB_FEE_TERM,
    CAST(NULL AS STRING) AS T_MB_FEE_PER,
    CAST(NULL AS STRING) AS T_MB_FEE_TERM,
    CAST(NULL AS STRING) AS T_SMS_FEE_PER,
    CAST(NULL AS STRING) AS T_SMS_FEE_TERM,
    CAST(NULL AS STRING) AS T_PACKAGE_FDATE,
    CAST(NULL AS STRING) AS T_PACKAGE_TDATE,
    CAST(NULL AS STRING) AS T_PROD_PACKAGE_ID,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_product_package_partner,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_product_package AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS STRING) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_PACKAGE_NAME,
    CAST(NULL AS STRING) AS T_PACKAGE_REGISTER_FEE,
    CAST(NULL AS STRING) AS T_MIN_BALANCE,
    CAST(NULL AS STRING) AS T_BEGIN_DATE,
    CAST(NULL AS STRING) AS T_EXPIRE_DATE,
    CAST(NULL AS STRING) AS T_SERVICE,
    CAST(NULL AS STRING) AS T_FT_TRANSACTION_TYPE,
    CAST(NULL AS STRING) AS T_PROVINCE_TYPE,
    CAST(NULL AS STRING) AS T_HIGH_LOW_VALUE,
    CAST(NULL AS STRING) AS T_EXTERNAL_FT_FEE,
    CAST(NULL AS STRING) AS T_EXTERNAL_FT_COMM_TYPE,
    CAST(NULL AS STRING) AS T_CONDITION_GROUP,
    CAST(NULL AS STRING) AS T_MIN_AVERAGE_BALANCE,
    CAST(NULL AS STRING) AS T_BELOW_AVER_BAL_FEE,
    CAST(NULL AS STRING) AS T_ATM_MAX_AMT_TRANS,
    CAST(NULL AS STRING) AS T_ATM_MAX_DAILY_AMT,
    CAST(NULL AS STRING) AS T_ATM_NOT_OCB_FEE,
    CAST(NULL AS STRING) AS T_WITHDRAW_CASH_TT_AMT,
    CAST(NULL AS STRING) AS T_WITHDRAW_CASH_TT_FEE,
    CAST(NULL AS STRING) AS T_WITHDRAW_CASH_TT_PL,
    CAST(NULL AS STRING) AS T_FT_CHANNEL,
    CAST(NULL AS STRING) AS T_INTERNAL_FT_FEE,
    CAST(NULL AS STRING) AS T_INTERNAL_FT_COMM_TYPE,
    CAST(NULL AS STRING) AS T_BILL_PAYMENT_FEE,
    CAST(NULL AS STRING) AS T_BILL_PAYMENT_COMM_TYPE,
    CAST(NULL AS STRING) AS T_PACKAGE_CUSTOMER_TYPE,
    CAST(NULL AS STRING) AS T_PACKAGE_REGISTER_PL,
    CAST(NULL AS STRING) AS T_BELOW_AVER_BAL_PL,
    CAST(NULL AS STRING) AS T_ATM_NOT_OCB_PL,
    CAST(NULL AS STRING) AS T_HIGH_LOW_VALUE_1,
    CAST(NULL AS STRING) AS T_WITHDRAW_CASH_TT_AMT_1,
    CAST(NULL AS STRING) AS T_WITHDRAW_CASH_TT_FEE_1,
    CAST(NULL AS STRING) AS T_WITHDRAW_CASH_TT_PL_1,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbh_sub_virtual_account AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_VA_ID,
    CAST(NULL AS STRING) AS T_SUB_ID,
    CAST(NULL AS STRING) AS T_SUB_VA_NAME,
    CAST(NULL AS STRING) AS T_CREDIT_ACCT_SPA,
    CAST(NULL AS STRING) AS T_SVA_RECORD_STATUS,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_virtual_account,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_ocbt_sub_industry AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_SUB_INDUSTRY_NAME,
    CAST(NULL AS STRING) AS T_ID_PARENT,
    CAST(NULL AS DECIMAL) AS T_ORDER,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_occupation AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS OCCUPATION_DESC,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_payment_due AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CONTRACT_ID,
    CAST(NULL AS STRING) AS T_PAY_TYPE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_loans_payment_due_information,
    CAST(NULL AS STRING) AS hashdiff_loans_payment_due_overdue,
    CAST(NULL AS STRING) AS hashdiff_loans_payment_due_contract,
    CAST(NULL AS STRING) AS hashdiff_loans_payment_due_classification,
    CAST(NULL AS STRING) AS hashdiff_loans_payment_due_repay,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_pc_re_stat_line_bal AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_OPEN_BAL,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_pc_re_stat_line_bal,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_posting_restrict AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_province AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_re_consol_spec_entry AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_COMPANY_CODE,
    CAST(NULL AS DECIMAL) AS T_AMOUNT_LCY,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_re_consol_spec_entry_audit,
    CAST(NULL AS STRING) AS hashdiff_re_consol_spec_entry_classification,
    CAST(NULL AS STRING) AS hashdiff_re_consol_spec_entry_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_re_stat_line_bal AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_OPEN_BAL,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_re_stat_line_bal,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_re_stat_line_cont AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_TYPE,
    CAST(NULL AS STRING) AS T_DESC,
    CAST(NULL AS STRING) AS T_PROFIT_CCY,
    CAST(NULL AS STRING) AS T_ASST_CONSOL_KEY,
    CAST(NULL AS STRING) AS T_ASSET_TYPE,
    CAST(NULL AS STRING) AS T_PRFT_CONSOL_KEY,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_re_stat_rep_line AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_K_TYPE,
    CAST(NULL AS STRING) AS T_DESC,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_INPUTTER,
    CAST(NULL AS STRING) AS T_DATE_TIME,
    CAST(NULL AS STRING) AS T_AUTHORISER,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_repo AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS REPO_TYPE,
    CAST(NULL AS STRING) AS BROKER_NO,
    CAST(NULL AS STRING) AS PRODUCT_CATEGORY,
    CAST(NULL AS STRING) AS CURRENCY,
    CAST(NULL AS DECIMAL) AS PRINCIPAL_AMOUNT_1,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_repo_information,
    CAST(NULL AS STRING) AS hashdiff_repo_deal,
    CAST(NULL AS STRING) AS hashdiff_repo_classification,
    CAST(NULL AS STRING) AS hashdiff_repo_system,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sc_trading_position AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_CONSOL_TRADING_BAL,
    CAST(NULL AS STRING) AS T_CPN_ACCR,
    CAST(NULL AS STRING) AS T_CPN_ACCR_POSTED,
    CAST(NULL AS STRING) AS T_CUR_AVG_PRICE,
    CAST(NULL AS STRING) AS T_CUR_COST_POSITION,
    CAST(NULL AS STRING) AS T_CUR_REALIZED_PL,
    CAST(NULL AS STRING) AS T_CURRENT_POSITION,
    CAST(NULL AS STRING) AS T_DATE,
    CAST(NULL AS STRING) AS T_DATE_LAST_TRADED,
    CAST(NULL AS STRING) AS T_DEALER_BOOK,
    CAST(NULL AS STRING) AS T_DISC_ACCR_POSTED,
    CAST(NULL AS STRING) AS T_DISCOUNT_ACCRUED,
    CAST(NULL AS STRING) AS T_ISSUER,
    CAST(NULL AS STRING) AS T_REVAL_UNREAL_PL,
    CAST(NULL AS STRING) AS T_REVALUATION_DATE,
    CAST(NULL AS STRING) AS T_SECURITY_CCY,
    CAST(NULL AS STRING) AS T_SECURITY_CODE,
    CAST(NULL AS STRING) AS T_SETTLED_POSITION,
    CAST(NULL AS STRING) AS T_SETTLEMENT_CCY,
    CAST(NULL AS STRING) AS T_V_DATE_COST_OF_POS,
    CAST(NULL AS STRING) AS T_V_DATE_REAL_PROFIT,
    CAST(NULL AS STRING) AS T_V_DATED_CPN_ACCR,
    CAST(NULL AS STRING) AS T_V_DATED_DIS_ACC,
    CAST(NULL AS STRING) AS T_VALUE_DATED_POS,
    CAST(NULL AS STRING) AS T_POSITION_KEY,
    CAST(NULL AS STRING) AS T_TAX_BALANCE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_sc_trading_position_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sc_trans_name AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_SHORT_NAME,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sec_acc_master AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_ACCOUNT_OFFICER,
    CAST(NULL AS STRING) AS T_CUSTOMER_NUMBER,
    CAST(NULL AS STRING) AS T_REFERENCE_CURRENCY,
    CAST(NULL AS STRING) AS T_ACCOUNT_NAME,
    CAST(NULL AS STRING) AS T_DATE_OF_VALUATION,
    CAST(NULL AS STRING) AS T_START_DATE,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_PORTFOLIO_TYPE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sec_trade AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS SECURITY_CODE,
    CAST(NULL AS STRING) AS OCB_ALTSIN,
    CAST(NULL AS STRING) AS STOCK_EXCHANGE,
    CAST(NULL AS DECIMAL) AS INTEREST_RATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_sec_trade_amounts,
    CAST(NULL AS STRING) AS hashdiff_sec_trade_system,
    CAST(NULL AS STRING) AS hashdiff_sec_trade_broker,
    CAST(NULL AS STRING) AS hashdiff_sec_trade_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sector AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL) AS ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_security_master AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_COMPANY_NAME,
    CAST(NULL AS STRING) AS T_DESCRIPT,
    CAST(NULL AS STRING) AS T_SHORT_NAME,
    CAST(NULL AS STRING) AS T_MNEMONIC,
    CAST(NULL AS STRING) AS T_SECURITY_CURRENCY,
    CAST(NULL AS STRING) AS T_BOND_OR_SHARE,
    CAST(NULL AS STRING) AS T_QUOTED_LISTED_NO,
    CAST(NULL AS STRING) AS T_SUB_ASSET_TYPE,
    CAST(NULL AS STRING) AS T_LIMIT_REF,
    CAST(NULL AS DECIMAL) AS T_SET_UP_DATE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_security_information,
    CAST(NULL AS STRING) AS hashdiff_security_classification,
    CAST(NULL AS STRING) AS hashdiff_security_terms,
    CAST(NULL AS STRING) AS hashdiff_security_pricing,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_stmt_entry AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_ACCOUNT_NUMBER,
    CAST(NULL AS STRING) AS T_COMPANY_CODE,
    CAST(NULL AS DECIMAL) AS T_AMOUNT_LCY,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_stmt_entry_audit,
    CAST(NULL AS STRING) AS hashdiff_stmt_entry_information,
    CAST(NULL AS STRING) AS hashdiff_stmt_entry_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_sub_asset_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DESCRIPTION,
    CAST(NULL AS STRING) AS T_SHORT_DESCR,
    CAST(NULL AS STRING) AS T_ASSET_TYPE_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_teller AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_DR_CR_MARKER,
    CAST(NULL AS STRING) AS T_ACCOUNT_1,
    CAST(NULL AS INT) AS T_CUSTOMER_1,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_teller_information,
    CAST(NULL AS STRING) AS hashdiff_teller_other,
    CAST(NULL AS STRING) AS hashdiff_teller_vat,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_town AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS DECIMAL) AS T_ORDER,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_transaction AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_TRANSACTION_CODE,
    CAST(NULL AS STRING) AS T_NARRATIVE,
    CAST(NULL AS STRING) AS T_DATA_CAPTURE,
    CAST(NULL AS STRING) AS T_CHEQUE_IND,
    CAST(NULL AS STRING) AS T_MANDATORY_REF_NO,
    CAST(NULL AS STRING) AS T_DEBIT_CREDIT_IND,
    CAST(NULL AS STRING) AS T_CHARGE_KEY,
    CAST(NULL AS STRING) AS T_IMMEDIATE_CHARGE,
    CAST(NULL AS STRING) AS T_DEFAULT_VALUE_DATE,
    CAST(NULL AS STRING) AS T_EXPOSURE_DATE,
    CAST(NULL AS STRING) AS T_RECORD_STATUS,
    CAST(NULL AS STRING) AS T_CURR_NO,
    CAST(NULL AS STRING) AS T_CO_CODE,
    CAST(NULL AS STRING) AS T_DEPT_CODE,
    CAST(NULL AS STRING) AS T_AUDITOR_CODE,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_user AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_USER_NAME,
    CAST(NULL AS STRING) AS T_SIGN_ON_NAME,
    CAST(NULL AS STRING) AS T_CLASSIFICATION,
    CAST(NULL AS DECIMAL) AS T_LANGUAGE,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_user_information,
    CAST(NULL AS STRING) AS hashdiff_user_classification,
    CAST(NULL AS STRING) AS hashdiff_user_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_t24_t24_vmbl_int_clr_citad AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ID,
    CAST(NULL AS STRING) AS DATA_DATE,
    CAST(NULL AS STRING) AS T_TRANS_REF,
    CAST(NULL AS STRING) AS T_TRANS_CODE,
    CAST(NULL AS STRING) AS T_O_CI_CODE,
    CAST(NULL AS STRING) AS T_TRANS_DATE,
    CAST(NULL AS STRING) AS T_R_CI_CODE,
    CAST(NULL AS STRING) AS T_O_PCI_CODE,
    CAST(NULL AS STRING) AS T_R_PCI_CODE,
    CAST(NULL AS STRING) AS T_CURRENCY,
    CAST(NULL AS STRING) AS T_AMOUNT,
    CAST(NULL AS STRING) AS T_SENDING_NAME,
    CAST(NULL AS STRING) AS T_SENDING_ADDR,
    CAST(NULL AS STRING) AS T_DEBIT_ACCT_NO,
    CAST(NULL AS STRING) AS T_CREDIT_ACCT_NO,
    CAST(NULL AS STRING) AS T_RECEIVING_NAME,
    CAST(NULL AS STRING) AS T_RECEIVING_ADDR,
    CAST(NULL AS STRING) AS T_BEN_ACCT_NO,
    CAST(NULL AS STRING) AS T_PAYMENT_DETAILS,
    CAST(NULL AS STRING) AS T_OPERATION_1,
    CAST(NULL AS STRING) AS T_OPERATION_2,
    CAST(NULL AS STRING) AS T_TXN_REF,
    CAST(NULL AS STRING) AS T_MSG_KIND,
    CAST(NULL AS STRING) AS T_IN_OUT,
    CAST(NULL AS STRING) AS T_COM_CO,
    CAST(NULL AS STRING) AS T_STATUS,
    CAST(NULL AS STRING) AS T_PROCESS_DT,
    CAST(NULL AS STRING) AS T_FILE_NAME,
    CAST(NULL AS STRING) AS T_USER_INPUT,
    CAST(NULL AS STRING) AS T_STMT_NO,
    CAST(NULL AS STRING) AS T_SUSP_ACCOUNT,
    CAST(NULL AS STRING) AS T_APPLICATION,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_clearing_citad_classification,
    CAST(NULL AS STRING) AS hashdiff_clearing_citad_payment_information,
    CAST(NULL AS STRING) AS hashdiff_clearing_citad_other,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;


-- ============================================================
-- SOURCE: BPM
-- ============================================================

CREATE OR REPLACE VIEW v_stg_bpm_auth_nhan_vien AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,0)) AS ID,
    CAST(NULL AS STRING) AS TEN_DANG_NHAP,
    CAST(NULL AS STRING) AS TEN_NGUOI_DUNG,
    CAST(NULL AS DECIMAL(38,0)) AS OCB_HRM_UID,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI,
    CAST(NULL AS STRING) AS GHI_CHU,
    CAST(NULL AS DECIMAL(38,0)) AS IS_LOCK,
    CAST(NULL AS STRING) AS NGAY_THAY_DOI,
    CAST(NULL AS DECIMAL(38,0)) AS NHAN_VIEN_QLY,
    CAST(NULL AS STRING) AS EMAIL,
    CAST(NULL AS DECIMAL(38,0)) AS USER_ID_THAY_DOI,
    CAST(NULL AS STRING) AS SO_DIEN_THOAIVARCHAR2,
    CAST(NULL AS DECIMAL(38,0)) AS CHUC_DANH,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_MIN,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_auth_nhan_vien,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_auth_to_chuc_don_vi AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,0)) AS ID,
    CAST(NULL AS STRING) AS MA_DON_VI,
    CAST(NULL AS DECIMAL(38,0)) AS DON_VI_CAP_TREN,
    CAST(NULL AS STRING) AS TEN_DON_VI,
    CAST(NULL AS DECIMAL(38,0)) AS CAP_DO,
    CAST(NULL AS DECIMAL(38,0)) AS LOAI_DON_VI,
    CAST(NULL AS STRING) AS OCB_HRM_ID,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI,
    CAST(NULL AS STRING) AS GHI_CHU,
    CAST(NULL AS DECIMAL(38,0)) AS TINH_TP_ID,
    CAST(NULL AS DECIMAL(38,0)) AS PHAN_CAP_DON_VI,
    CAST(NULL AS DECIMAL(38,0)) AS THAMVAN_CAPKY,
    CAST(NULL AS DECIMAL(38,0)) AS ISHR,
    CAST(NULL AS STRING) AS CIC,
    CAST(NULL AS STRING) AS PHAN_KHUC_KHAI_THAC,
    CAST(NULL AS DECIMAL(38,0)) AS DON_VI_TRIEN_KHAI_DVTD,
    CAST(NULL AS DECIMAL(38,0)) AS CUSTGROUP,
    CAST(NULL AS DECIMAL(38,0)) AS PARENT_ID_KT,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_auth_to_chuc_don_vi,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_giao_dich AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS DECIMAL(38,10)) AS QUY_TRINH,
    CAST(NULL AS DECIMAL(38,10)) AS KHACH_HANG_ID,
    CAST(NULL AS STRING) AS NGUOI_XU_LY_ID,
    CAST(NULL AS DECIMAL(38,10)) AS VAI_TRO_NGUOI_XL,
    CAST(NULL AS STRING) AS NGAY_HOAN_THANH,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_HOAT_DONG,
    CAST(NULL AS STRING) AS LOAI_TIEN,
    CAST(NULL AS DECIMAL(38,10)) AS PROCESS_ID,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_ID,
    CAST(NULL AS STRING) AS GIAO_DICH_CU_ID,
    CAST(NULL AS DECIMAL(38,10)) AS DON_VI_TAO,
    CAST(NULL AS STRING) AS NGUOI_TAO_ID,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS NGAY_CAP_NHAT,
    CAST(NULL AS DECIMAL(38,10)) AS QUY_TRINH_CON,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_thong_tin_chung,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_giao_dich_link AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,0)) AS ID,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS STRING) AS MA_GD_LINK,
    CAST(NULL AS DECIMAL(38,0)) AS QUY_TRINH_LINK,
    CAST(NULL AS DECIMAL(38,0)) AS GIAO_DICH_NGOAI_BPM,
    CAST(NULL AS DECIMAL(38,0)) AS QUY_TRINH_CON,
    CAST(NULL AS STRING) AS CAP_PHE_DUYET,
    CAST(NULL AS STRING) AS NGUOI_PHE_DUYET,
    CAST(NULL AS STRING) AS Y_KIEN_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,0)) AS SO_TIEN,
    CAST(NULL AS STRING) AS NGAY_PHE_DUYET,
    CAST(NULL AS STRING) AS MO_TA,
    CAST(NULL AS STRING) AS LOAI_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,0)) AS LUONG_THEM,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_link,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_giao_dich_sla AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS QUY_TRINH,
    CAST(NULL AS STRING) AS SLA,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_1,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_2,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_1,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_2,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_1_CUOI,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_2_CUOI,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_3,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_4,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_3,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_4,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_3_CUOI,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_4_CUOI,
    CAST(NULL AS STRING) AS THOI_GIAN_DEN_HAN,
    CAST(NULL AS STRING) AS SLA_VITRI_2,
    CAST(NULL AS STRING) AS SLA_VITRI_3,
    CAST(NULL AS STRING) AS SLA_VITRI_5,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_5,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_5,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_5_CUOI,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_6,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_6,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_6_CUOI,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_7,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_7,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_7_CUOI,
    CAST(NULL AS STRING) AS SLA_VITRI_4,
    CAST(NULL AS STRING) AS SLA_VITRI_8,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_8,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_8,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_8_CUOI,
    CAST(NULL AS STRING) AS SLA_VITRI_9,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_9,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_9,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_9_CUOI,
    CAST(NULL AS STRING) AS SLA_VITRI_12,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_12,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_12,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_12_CUOI,
    CAST(NULL AS STRING) AS SLA_VITRI_14,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_XL_VITRI_14,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_14,
    CAST(NULL AS STRING) AS THOI_DIEM_NHAN_VITRI_14_CUOI,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giaodich_sla,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_giao_dich_tsbd AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ROWID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS STRING) AS MA_TSBD,
    CAST(NULL AS STRING) AS QUY_TRINH,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS NGAY_CAP_NHAT,
    CAST(NULL AS STRING) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS NGAY_PHAT_HANH,
    CAST(NULL AS STRING) AS NGAY_DEN_HAN,
    CAST(NULL AS INT) AS GIA_TRI,
    CAST(NULL AS STRING) AS LOAI_TIEN_GUI,
    CAST(NULL AS DECIMAL(38,10)) AS TI_LE_BD,
    CAST(NULL AS DECIMAL(38,10)) AS TINH_TRANG_PHONG_TOA,
    CAST(NULL AS DECIMAL(38,10)) AS MUC_BAO_DAM,
    CAST(NULL AS STRING) AS CHU_SO_HUU,
    CAST(NULL AS STRING) AS LOAI_TIEN_T24,
    CAST(NULL AS STRING) AS CIF,
    CAST(NULL AS STRING) AS CMND,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tsbd,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_khach_hang AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS ID,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_KHACH_HANG,
    CAST(NULL AS STRING) AS TEN_KHACH_HANG,
    CAST(NULL AS STRING) AS GHI_CHU,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS SO_CIF,
    CAST(NULL AS DECIMAL(38,10)) AS XEP_HANG_TIN_DUNG,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_KHACH_HANG_ID,
    CAST(NULL AS STRING) AS KHACH_HANG_NO,
    CAST(NULL AS DECIMAL(38,10)) AS NV_CHAM_SOC_GAN_NHAT,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI,
    CAST(NULL AS DECIMAL(38,10)) AS DVKD_QUAN_LY,
    CAST(NULL AS DECIMAL(38,10)) AS NHAN_VIEN_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_NO_CAO_NHAT,
    CAST(NULL AS STRING) AS PHAN_KHUC_KHANG,
    CAST(NULL AS STRING) AS HANGKH,
    CAST(NULL AS DECIMAL(38,10)) AS ISNEWKH,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_khach_hang_thong_tin_chung,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_pdtd_nhom_giao_dich AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS STRING) AS MA_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,10)) AS KHACH_HANG_ID,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_KHOI_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_DANG_XU_LY,
    CAST(NULL AS DECIMAL(38,10)) AS DON_VI_KDOANH,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_KHACH_HANG,
    CAST(NULL AS DECIMAL(38,10)) AS CBTTD,
    CAST(NULL AS DECIMAL(38,10)) AS GDPDTD,
    CAST(NULL AS DECIMAL(38,10)) AS DON_VI_PDUYET,
    CAST(NULL AS DECIMAL(38,10)) AS TONG_SO_TIEN,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_NHOM_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_HO_SO,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_GIAO_DICH_GOC_ID,
    CAST(NULL AS STRING) AS NOI_DUNG_YCGT,
    CAST(NULL AS DECIMAL(38,10)) AS PROCESS_ID,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_DX_KH_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_DX_KH_KO_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_DX_KH_100_FI_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_DX_KH_NLQ_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_DX_KH_NLQ_KO_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_HTAI_KH_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_HTAI_KH_KO_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_HTAI_KH_NLQ_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_HTAI_KH_NLQ_KO_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_PHU_TRACH,
    CAST(NULL AS DECIMAL(38,10)) AS CAP_PHE_DUYET_CUOI_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_TIEN,
    CAST(NULL AS DECIMAL(38,10)) AS TINH_TRANG_NO_CIC,
    CAST(NULL AS DECIMAL(38,10)) AS TSBD_NHIEU_KH,
    CAST(NULL AS DECIMAL(38,10)) AS TSBD_THUOC_PDUYET_HOI_SO,
    CAST(NULL AS DECIMAL(38,10)) AS QUY_CHE_BLANH_KHAC,
    CAST(NULL AS DECIMAL(38,10)) AS QUY_DINH_TIN_DUNG,
    CAST(NULL AS DECIMAL(38,10)) AS CSACH_TIN_DUNG_KH,
    CAST(NULL AS DECIMAL(38,10)) AS SPHAM_TDUNG_TSBD,
    CAST(NULL AS DECIMAL(38,10)) AS NGOAI_LE_TSDB,
    CAST(NULL AS DECIMAL(38,10)) AS KH_MIEN_PDUYET_TT,
    CAST(NULL AS STRING) AS TDIEM_TDTT,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM2_NO_CIC_12T,
    CAST(NULL AS DECIMAL(38,10)) AS TUAN_THU_DK_PDUYET,
    CAST(NULL AS DECIMAL(38,10)) AS PHE_DUYET_BOI_UY_BAN,
    CAST(NULL AS STRING) AS THOI_DIEM_THAO_TAC_CUOI,
    CAST(NULL AS DECIMAL(38,10)) AS ROLE_DANG_XL,
    CAST(NULL AS STRING) AS NGAY_HOAN_THANH,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_HOAT_DONG,
    CAST(NULL AS DECIMAL(38,10)) AS KET_QUA_THAO_TAC_CUOI,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_KH_KO_TSBD,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_KH_KO_100_TGUI_TRU_TP,
    CAST(NULL AS DECIMAL(38,10)) AS CAP_TD_CO_DU_AN_DT,
    CAST(NULL AS DECIMAL(38,10)) AS CAP_TD_DB_100_BDS_OTO,
    CAST(NULL AS DECIMAL(38,10)) AS LS_THAP_HON_LS_DCV,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_ID,
    CAST(NULL AS DECIMAL(38,10)) AS SO_TIEN_PD,
    CAST(NULL AS DECIMAL(38,10)) AS SO_TIEN_PD_KN,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_PD_KH_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_PD_KH_KO_100_TGUI,
    CAST(NULL AS DECIMAL(38,10)) AS XEP_HANG_TD,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_SP_CU_THE_COVAKO_TSDB,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_SP_CU_THE_KO_TSDB,
    CAST(NULL AS DECIMAL(38,10)) AS BSPO_ID,
    CAST(NULL AS DECIMAL(38,10)) AS MUA_BAO_HIEM,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_PD_SP_CUTHE_COVAKO_TSBD,
    CAST(NULL AS STRING) AS HANGKH,
    CAST(NULL AS DECIMAL(38,10)) AS NGOAI_LE_CAM_KET_VAY_CO_DK,
    CAST(NULL AS DECIMAL(38,10)) AS GTRI_CAM_KET,
    CAST(NULL AS DECIMAL(38,10)) AS TONG_GTRI_CAM_KET,
    CAST(NULL AS STRING) AS KSVTTD,
    CAST(NULL AS STRING) AS CGPDDL,
    CAST(NULL AS STRING) AS RATING_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_TDTT,
    CAST(NULL AS DECIMAL(38,10)) AS QUY_TRINH_CON,
    CAST(NULL AS DECIMAL(38,10)) AS KHOAN_CAP_TIN_DUNG,
    CAST(NULL AS DECIMAL(38,10)) AS TRINH_HO_TRO_LS_THEO_QD,
    CAST(NULL AS STRING) AS NGAY_KY_HDTD,
    CAST(NULL AS STRING) AS NGAY_HET_HAN_HDTD,
    CAST(NULL AS DECIMAL(38,10)) AS DK_DANH_GIA_TIEP_TUC_GIAI_NGAN,
    CAST(NULL AS DECIMAL(38,10)) AS PHUONG_PHAP_CMTN,
    CAST(NULL AS DECIMAL(38,10)) AS KHOAN_VAY_CS_CBNV,
    CAST(NULL AS DECIMAL(38,10)) AS IS_TRINH_VUOT_CAP_D1,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_PD_KH_DAM_BAO,
    CAST(NULL AS DECIMAL(38,10)) AS HMRR_PD_KH_KHONG_DAM_BAO,
    CAST(NULL AS DECIMAL(38,10)) AS TONG_PD_MUC_CAP_TIN_DUNG,
    CAST(NULL AS DECIMAL(38,10)) AS IS_THAY_DOI_TT,
    CAST(NULL AS DECIMAL(38,10)) AS TONG_RRTD_D1,
    CAST(NULL AS DECIMAL(38,10)) AS KHACH_HANG_TCTD,
    CAST(NULL AS DECIMAL(38,10)) AS KH_ADGIAM_TAT_RB,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_pdtd_nhom_giao_dich_ho_so,
    CAST(NULL AS STRING) AS hashdiff_pdtd_nhom_giao_dich_phe_duyet,
    CAST(NULL AS STRING) AS hashdiff_pdtd_nhom_giao_dich_han_muc,
    CAST(NULL AS STRING) AS hashdiff_pdtd_nhom_giao_dich_trang_thai,
    CAST(NULL AS STRING) AS hashdiff_pdtd_nhom_giao_dich_tham_dinh,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_pdtd_san_pham AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS ROWID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS DECIMAL(38,10)) AS GD_CHINH_ID,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_SAN_PHAM_ID,
    CAST(NULL AS DECIMAL(38,10)) AS SAN_PHAM_ID,
    CAST(NULL AS DECIMAL(38,10)) AS MUC_DICH_ID,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_SAN_PHAM,
    CAST(NULL AS DECIMAL(38,10)) AS SO_TIEN_DE_XUAT,
    CAST(NULL AS DECIMAL(38,10)) AS SO_TIEN_PHE_DUYET,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_CO_TSBD_SP_CUTHE,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_KO_TSBD_SP_CUTHE,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_CO_TSBD_SP_CUTHE_PD,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_KO_TSBD_SP_CUTHE_PD,
    CAST(NULL AS DECIMAL(38,10)) AS DU_NO_HIEN_TAI,
    CAST(NULL AS DECIMAL(38,10)) AS RRTD_DA_PHE_DUYET,
    CAST(NULL AS STRING) AS NGAY_HET_HAN_HIEU_LUC_HM,
    CAST(NULL AS STRING) AS NGAY_LAP_TT_PH_CKCTD,
    CAST(NULL AS STRING) AS NGAY_DU_KIEN_PH_CKCTD,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_pdtd_san_pham,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_pdtd_tsbd_link AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS GD_PDTD,
    CAST(NULL AS STRING) AS GD_TSBD,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_qlns_nguoi_lao_dong_info AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS MA_NHAN_VIEN,
    CAST(NULL AS STRING) AS HO_TEN,
    CAST(NULL AS STRING) AS TEN_DANG_NHAP,
    CAST(NULL AS STRING) AS NGAY_SINH,
    CAST(NULL AS STRING) AS GIOI_TINH,
    CAST(NULL AS DECIMAL(38,0)) AS MA_GIOI_TINH,
    CAST(NULL AS STRING) AS CMND,
    CAST(NULL AS STRING) AS SO_DIEN_THOAI,
    CAST(NULL AS STRING) AS KHOI,
    CAST(NULL AS STRING) AS MA_KHOI,
    CAST(NULL AS STRING) AS DON_VI,
    CAST(NULL AS STRING) AS MA_DON_VI,
    CAST(NULL AS STRING) AS PHONG_BAN,
    CAST(NULL AS STRING) AS MA_PHONG_BAN,
    CAST(NULL AS STRING) AS BO_PHAN,
    CAST(NULL AS STRING) AS MA_BO_PHAN,
    CAST(NULL AS STRING) AS TO_NHOM,
    CAST(NULL AS STRING) AS MA_TO_NHOM,
    CAST(NULL AS STRING) AS CHUC_DANH,
    CAST(NULL AS STRING) AS MA_CHUC_DANH,
    CAST(NULL AS STRING) AS PHAN_NHOM_CHUC_DANH,
    CAST(NULL AS STRING) AS LOAI_HD_HIEN_TAI,
    CAST(NULL AS STRING) AS MA_LOAI_HD,
    CAST(NULL AS STRING) AS HDLD_TU_NGAY,
    CAST(NULL AS STRING) AS HDLD_DEN_NGAY,
    CAST(NULL AS STRING) AS CAP_BAC,
    CAST(NULL AS STRING) AS MA_CAP_BAC,
    CAST(NULL AS STRING) AS TINH_TRANG_KY_LUAT,
    CAST(NULL AS STRING) AS MA_TINH_TRANG_KY_LUAT,
    CAST(NULL AS STRING) AS THAM_NIEN_VI_TRI,
    CAST(NULL AS DECIMAL(38,0)) AS SO_LAN_DA_KY_HD,
    CAST(NULL AS STRING) AS THOI_HAN_DEN_HAN_TAI_BO_NHIEM,
    CAST(NULL AS STRING) AS NGAY_CANH_BAO_QT_LAM_VIEC,
    CAST(NULL AS STRING) AS TRINH_DO,
    CAST(NULL AS STRING) AS CHUYEN_NGANH,
    CAST(NULL AS STRING) AS CHUC_DANH_NNV,
    CAST(NULL AS STRING) AS MA_CHUC_DANH_NNV,
    CAST(NULL AS STRING) AS KQ_DANH_GIA_GAN_NHAT,
    CAST(NULL AS STRING) AS THU_NHAP,
    CAST(NULL AS STRING) AS DIA_CHI_THUONG_TRU,
    CAST(NULL AS STRING) AS EMAIL_CA_NHAN,
    CAST(NULL AS STRING) AS NGAY_CAP_CMND,
    CAST(NULL AS STRING) AS NOI_CAP,
    CAST(NULL AS STRING) AS NGAY_VAO_OCB,
    CAST(NULL AS STRING) AS KQDG_KY_TRUOC,
    CAST(NULL AS STRING) AS EMAIL_CO_QUAN,
    CAST(NULL AS DECIMAL(38,0)) AS THAM_NIEN_NAM,
    CAST(NULL AS DECIMAL(38,0)) AS THAM_NIEN_THANG,
    CAST(NULL AS DECIMAL(38,0)) AS TUOI,
    CAST(NULL AS STRING) AS CHUC_DANH_1,
    CAST(NULL AS STRING) AS NOI_LAM_VIEC,
    CAST(NULL AS STRING) AS MA_LOAI_NHAN_VIEN,
    CAST(NULL AS STRING) AS NGAY_LAM_VIEC_CUOI_CUNG,
    CAST(NULL AS STRING) AS NGAY_THOI_VIEC,
    CAST(NULL AS STRING) AS TINH_TRANG_NHAN_VIEN,
    CAST(NULL AS STRING) AS NGAY_NOP_DON_THOI_VIEC,
    CAST(NULL AS STRING) AS TG_THI_HANH_KL,
    CAST(NULL AS STRING) AS TG_KET_THUC_THI_HANH_KL,
    CAST(NULL AS STRING) AS LOAI_NGHI_PHEP,
    CAST(NULL AS STRING) AS THOI_GIAN_BAT_DAU_NGHI_PHEP,
    CAST(NULL AS STRING) AS THOI_GIAN_KET_THUC_NGHI_PHEP,
    CAST(NULL AS DECIMAL(38,0)) AS SO_NGAY_NGHI_PHEP,
    CAST(NULL AS STRING) AS LY_DO_NGHI,
    CAST(NULL AS STRING) AS MA_THANG_LUONG,
    CAST(NULL AS STRING) AS MA_NGACH_LUONG,
    CAST(NULL AS STRING) AS MA_BAC_LUONG,
    CAST(NULL AS STRING) AS LUONG_CHUC_DANH,
    CAST(NULL AS STRING) AS THUONG_NANG_SUAT,
    CAST(NULL AS STRING) AS HO_TRO_XANG_XE,
    CAST(NULL AS STRING) AS PHU_CAP_DOC_HAI,
    CAST(NULL AS STRING) AS HO_TRO_TIEN_AN_GIUA_CA,
    CAST(NULL AS STRING) AS HO_TRO_DIEN_THOAI,
    CAST(NULL AS STRING) AS PHU_CAP_THU_HUT,
    CAST(NULL AS STRING) AS TAM_UNG_HIEU_SUAT,
    CAST(NULL AS STRING) AS NGAY_VAO_OCB_CHINH_THUC,
    CAST(NULL AS STRING) AS NGAY_DONG_BO,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_qlns_nguoi_lao_dong_info_ca_nhan,
    CAST(NULL AS STRING) AS hashdiff_qlns_nguoi_lao_dong_info_don_vi,
    CAST(NULL AS STRING) AS hashdiff_qlns_nguoi_lao_dong_info_hop_dong_lao_dong,
    CAST(NULL AS STRING) AS hashdiff_qlns_nguoi_lao_dong_info_ky_luat,
    CAST(NULL AS STRING) AS hashdiff_qlns_nguoi_lao_dong_info_luong_thuong,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tdcn_tai_san_bao_dam AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS DECIMAL(38,10)) AS ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TSBD_CHO_SAN_PHAM,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_TSBD,
    CAST(NULL AS DECIMAL(38,10)) AS VI_TRI,
    CAST(NULL AS DECIMAL(38,10)) AS CHU_SO_HUU,
    CAST(NULL AS DECIMAL(38,10)) AS PHAN_LOAI_TSBD,
    CAST(NULL AS DECIMAL(38,10)) AS TY_LE_DAM_BAO_CAO_NHAT,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS SO_LUONG,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_THEM,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tdcn_tai_san_bao_dam,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tdcn_thong_tin_chung AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS STRING) AS XEP_HANG_TIN_DUNG,
    CAST(NULL AS STRING) AS TT_NGOAI_LE,
    CAST(NULL AS DECIMAL(38,10)) AS HINH_THUC_BD,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_XU_LY,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_SOAN_THAO,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS IS_THAY_DOI_TT,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS SO_CAP_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS VI_TRI_BUOC_GIAO_DICH,
    CAST(NULL AS STRING) AS RATING_ID,
    CAST(NULL AS STRING) AS NOI_CU_TRU,
    CAST(NULL AS DECIMAL(38,10)) AS IS_DONG_VAY,
    CAST(NULL AS DECIMAL(38,10)) AS TONG_THU_NHAP_TRA_NO,
    CAST(NULL AS DECIMAL(38,10)) AS NO_THANG_DAU,
    CAST(NULL AS DECIMAL(38,10)) AS NO_HIEN_CO,
    CAST(NULL AS DECIMAL(38,10)) AS NO_TAI_TCTD_KHAC,
    CAST(NULL AS DECIMAL(38,10)) AS DTI,
    CAST(NULL AS STRING) AS SO_TUOI,
    CAST(NULL AS DECIMAL(38,10)) AS DIEU_KIEN_SP_ID,
    CAST(NULL AS STRING) AS LY_DO,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_TDTT,
    CAST(NULL AS STRING) AS THOI_DIEM_TDTT,
    CAST(NULL AS DECIMAL(38,10)) AS KCTD_NGOAI_LE_CHO_VAY,
    CAST(NULL AS DECIMAL(38,10)) AS KCTD_NGOAI_LE_TIN_DUNG,
    CAST(NULL AS DECIMAL(38,10)) AS KCTD_NGOAI_LE_XEP_HANG_KH,
    CAST(NULL AS DECIMAL(38,10)) AS KCTD_NGOAI_LE_SP_TIN_DUNG,
    CAST(NULL AS DECIMAL(38,10)) AS KCTD_TRINH_YBTD,
    CAST(NULL AS DECIMAL(38,10)) AS TSBD_PHAI_DUOC_UBTD_PD,
    CAST(NULL AS DECIMAL(38,10)) AS THANH_VIEN_POS,
    CAST(NULL AS STRING) AS THANH_VIEN_UBTD,
    CAST(NULL AS STRING) AS MUC_DICH_XHTD,
    CAST(NULL AS DECIMAL(38,10)) AS IS_DONG_VAY_NHPHOI,
    CAST(NULL AS DECIMAL(38,10)) AS SOAN_THAO_HS,
    CAST(NULL AS DECIMAL(38,10)) AS XU_LY_HS,
    CAST(NULL AS DECIMAL(38,10)) AS IS_PHAP_CHE,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_GD,
    CAST(NULL AS DECIMAL(38,10)) AS DVI_TRIEN_KHAI,
    CAST(NULL AS DECIMAL(38,10)) AS KH_ADGIAM_TAT_RB,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tdcn_thong_tin_chung,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tdcn_xl_gdtd AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS DECIMAL(38,0)) AS ID,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS NGHIEP_VU_CHI_TIET,
    CAST(NULL AS DECIMAL(38,0)) AS MUC_BAO_DAM,
    CAST(NULL AS DECIMAL(38,0)) AS SO_LUONG,
    CAST(NULL AS STRING) AS NGUOI_DE_NGHI,
    CAST(NULL AS DECIMAL(38,0)) AS NGUOI_DE_NGHI_CHON,
    CAST(NULL AS STRING) AS NGUOI_PD,
    CAST(NULL AS DECIMAL(38,0)) AS NGUOI_PD_CHON,
    CAST(NULL AS STRING) AS NGAY_DUYET,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS LUONG_XL,
    CAST(NULL AS DECIMAL(38,0)) AS SO_CAP_DUYET,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tdcn_xl_gdtd,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tdtc_nghiep_vu_xl_gdtd AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS DECIMAL(38,0)) AS ID,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS NGHIEP_VU_ID,
    CAST(NULL AS DECIMAL(38,0)) AS NGHIEP_VU_CT_ID,
    CAST(NULL AS DECIMAL(38,0)) AS SO_TIEN_GD,
    CAST(NULL AS STRING) AS GHI_CHU,
    CAST(NULL AS DECIMAL(38,0)) AS QUY_TRINH,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tdtc_nghiep_vu_xl_gdtd,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tdtc_thong_tin_chung AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS STRING) AS XEP_HANG_TIN_DUNG,
    CAST(NULL AS STRING) AS TT_NGOAI_LE,
    CAST(NULL AS INT) AS HINH_THUC_BD,
    CAST(NULL AS INT) AS LUONG_XU_LY,
    CAST(NULL AS INT) AS LUONG_SOAN_THAO,
    CAST(NULL AS INT) AS LUONG_PHE_DUYET,
    CAST(NULL AS INT) AS IS_THAY_DOI_TT,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS NGUOI_TAO,
    CAST(NULL AS INT) AS SO_CAP_DUYET,
    CAST(NULL AS INT) AS VI_TRI_BUOC_GIAO_DICH,
    CAST(NULL AS STRING) AS MA_SO_THUE_DN,
    CAST(NULL AS INT) AS IS_KH_RB,
    CAST(NULL AS INT) AS SOAN_THAO_HS,
    CAST(NULL AS INT) AS XU_LY_HS,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tdtc_thong_tin_chung,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tdtc_thong_tin_to_trinh AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS INT) AS ID,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS INT) AS KHACH_HANG_ID,
    CAST(NULL AS INT) AS SAN_PHAM_ID,
    CAST(NULL AS STRING) AS HANG_KH,
    CAST(NULL AS STRING) AS QUOC_TICH,
    CAST(NULL AS STRING) AS HO_KHAU_THUONG_TRU,
    CAST(NULL AS STRING) AS NOI_O_HIEN_TAI,
    CAST(NULL AS INT) AS TINH_THANH_HIEN_TAI,
    CAST(NULL AS BIGINT) AS SDT,
    CAST(NULL AS STRING) AS EMAIL,
    CAST(NULL AS DOUBLE) AS THU_NHAP_BQ_THANG,
    CAST(NULL AS INT) AS LOAI_HINH_DN,
    CAST(NULL AS INT) AS THOI_GIAN_DONG_THUE,
    CAST(NULL AS INT) AS DN_NHOM_NO_HIEN_TAI,
    CAST(NULL AS INT) AS DN_LS_NO_NHOM_2_TRO_LEN,
    CAST(NULL AS INT) AS CN_NHOM_NO_HIEN_TAI,
    CAST(NULL AS INT) AS CN_LS_NO_CAN_CHU_Y,
    CAST(NULL AS INT) AS CN_LS_NO_XAU,
    CAST(NULL AS DOUBLE) AS CAN_DOI_TRA_NO,
    CAST(NULL AS INT) AS TONG_RR_HIEN_TAI,
    CAST(NULL AS INT) AS SO_DU_NO_HIEN_TAI,
    CAST(NULL AS DOUBLE) AS TONG_RR_DX,
    CAST(NULL AS DOUBLE) AS DE_XUAT_MOI,
    CAST(NULL AS INT) AS THOI_HAN_DX_MOI,
    CAST(NULL AS DOUBLE) AS KCTD_SO_TIEN,
    CAST(NULL AS STRING) AS KCTD_MUC_DICH_VAY,
    CAST(NULL AS INT) AS KCTD_THOI_HAN_VAY,
    CAST(NULL AS STRING) AS KCTD_LS_CHO_VAY,
    CAST(NULL AS INT) AS KCTD_PHUONG_THUC_TRA_NO,
    CAST(NULL AS DOUBLE) AS TY_LE_TAI_TRO_TOI_DA,
    CAST(NULL AS INT) AS DK_TK_PAYROLL,
    CAST(NULL AS DOUBLE) AS DTI,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS TEN_DOANH_NGHIEP,
    CAST(NULL AS STRING) AS MA_SO_THUE_DN,
    CAST(NULL AS INT) AS TONG_THU_NHAP_BQ_THANG,
    CAST(NULL AS STRING) AS XEP_HANG_KH,
    CAST(NULL AS INT) AS HINH_THUC_GN,
    CAST(NULL AS DOUBLE) AS DO_TUOI_KH,
    CAST(NULL AS DOUBLE) AS SO_TIEN_PD,
    CAST(NULL AS DOUBLE) AS TONG_RRTD_PD,
    CAST(NULL AS STRING) AS XEP_HANG_DN,
    CAST(NULL AS INT) AS TINH_THANH_CONG_TAC,
    CAST(NULL AS INT) AS VI_TRI_CONG_TAC,
    CAST(NULL AS DOUBLE) AS TONG_TN_BQ_THANG_BDS,
    CAST(NULL AS DOUBLE) AS DTI_KHONG_TSBD,
    CAST(NULL AS INT) AS NHP_LS_NO_CAN_CHU_Y,
    CAST(NULL AS INT) AS NHP_LS_NO_XAU,
    CAST(NULL AS INT) AS NHP_NHOM_NO_HIEN_TAI,
    CAST(NULL AS INT) AS RATING_ID,
    CAST(NULL AS INT) AS XHTD_ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tdtc_thong_tin_to_trinh,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tht_nhom_chinh_sach_the AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS DECIMAL(38,0)) AS ID,
    CAST(NULL AS STRING) AS GD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS ID_THE_CHINH,
    CAST(NULL AS STRING) AS MA_NHOM_CHINH_SACH,
    CAST(NULL AS STRING) AS NHOM_CHINH_SACH_TEN,
    CAST(NULL AS STRING) AS MA_CHI_TIET_1,
    CAST(NULL AS STRING) AS CHI_TIET_1_TEN,
    CAST(NULL AS STRING) AS MA_CHI_TIET_2,
    CAST(NULL AS STRING) AS CHI_TIET_2_TEN,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS SIZE_CHI_TIET_1,
    CAST(NULL AS DECIMAL(38,0)) AS IS_THE_PHU,
    CAST(NULL AS STRING) AS SAN_PHAM_THE,
    CAST(NULL AS STRING) AS GIAY_TO_THE_PHU,
    CAST(NULL AS TIMESTAMP) AS etl_timestamp,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_giao_dich_tht_nhom_chinh_sach_the,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tsbd_giaodich_chinh AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS GD_TSBD_ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS STRING) AS MA_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,10)) AS KHACH_HANG_ID,
    CAST(NULL AS DECIMAL(38,10)) AS KH_HAN_CHE,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,10)) AS TAI_SAN_ID,
    CAST(NULL AS STRING) AS MA_TAI_SAN,
    CAST(NULL AS DECIMAL(38,10)) AS MUC_DICH_VAY,
    CAST(NULL AS DECIMAL(38,10)) AS TS_CUNG_DB_DVKD,
    CAST(NULL AS DECIMAL(38,10)) AS TS_MOI,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_DVDG,
    CAST(NULL AS DECIMAL(38,10)) AS DVDG_BEN_3_ID,
    CAST(NULL AS DECIMAL(38,10)) AS DVDG_KHAC,
    CAST(NULL AS STRING) AS DVDG_KHAC_TEN,
    CAST(NULL AS DECIMAL(38,10)) AS GIA_TRI_DG,
    CAST(NULL AS STRING) AS NGAY_HOAN_TAT_DG,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI,
    CAST(NULL AS DECIMAL(38,10)) AS GIAO_DICH_GOC,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS CAN_BO_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS CAN_BO_DANG_XLY,
    CAST(NULL AS DECIMAL(38,10)) AS DVKD_DANG_XLY,
    CAST(NULL AS DECIMAL(38,10)) AS QUY_TRINH,
    CAST(NULL AS DECIMAL(38,10)) AS GD_PDTD_THAM_CHIEU_ID,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_SAN_PHAM_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TONG_HMRR_KH_DEXUAT,
    CAST(NULL AS DECIMAL(38,10)) AS DON_GIA_DAT_DG,
    CAST(NULL AS STRING) AS LY_DO_DEXUAT,
    CAST(NULL AS DECIMAL(38,10)) AS PROCESS_ID,
    CAST(NULL AS STRING) AS NGAY_CAP_NHAT,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_CAP_NHAT,
    CAST(NULL AS DECIMAL(38,10)) AS DEACTIVE,
    CAST(NULL AS DECIMAL(38,10)) AS DINH_GIA_MOI,
    CAST(NULL AS DECIMAL(38,10)) AS HOAN_THANH,
    CAST(NULL AS DECIMAL(38,10)) AS YEU_CAU_BEN_3_DG,
    CAST(NULL AS DECIMAL(38,10)) AS YEU_CAU_CAP_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS YEU_CAU_HOI_SO,
    CAST(NULL AS STRING) AS NGAY_DE_XUAT_PQLTS_TD,
    CAST(NULL AS STRING) AS MA_GD_PDTD_THAM_CHIEU,
    CAST(NULL AS DECIMAL(38,10)) AS NGUYEN_TAC_TINH_DIEM_PC,
    CAST(NULL AS DECIMAL(38,10)) AS TDV,
    CAST(NULL AS DECIMAL(38,10)) AS CB_PQLTSDB,
    CAST(NULL AS DECIMAL(38,10)) AS TBP_PQLTSDB,
    CAST(NULL AS DECIMAL(38,10)) AS TP_PQLTSDB,
    CAST(NULL AS DECIMAL(38,10)) AS DON_GIA_DG_ID,
    CAST(NULL AS DECIMAL(38,10)) AS CB_KIEM_TRA_KQDG,
    CAST(NULL AS DECIMAL(38,10)) AS ID_TINH_DIEM_PC_KTKQDG,
    CAST(NULL AS DECIMAL(38,10)) AS Y_KIEN_DVKD,
    CAST(NULL AS DECIMAL(38,10)) AS Y_KIEN_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,10)) AS DVDG_BEN_3_DE_XUAT_ID,
    CAST(NULL AS DECIMAL(38,10)) AS DVDG_DE_XUAT_KHAC,
    CAST(NULL AS STRING) AS DVDG_DE_XUAT_KHAC_TEN,
    CAST(NULL AS STRING) AS NGAY_CHUYEN_TASK_CBKT,
    CAST(NULL AS DECIMAL(38,10)) AS RM2,
    CAST(NULL AS DECIMAL(38,10)) AS TBP_KTKQDG,
    CAST(NULL AS DECIMAL(38,10)) AS DVKD_KHOI_TAO,
    CAST(NULL AS DOUBLE) AS DIEM_PHAN_CONG,
    CAST(NULL AS DECIMAL(38,10)) AS TAI_SAN_DU_DK_THAMDINH,
    CAST(NULL AS STRING) AS NGAY_HOAN_THANH_PQLTS_TD,
    CAST(NULL AS STRING) AS NHOM_DANG_XU_LY,
    CAST(NULL AS DECIMAL(38,10)) AS BSPO_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TAI_SAN_TDTT,
    CAST(NULL AS STRING) AS SO_BIEN_BAN_DINH_GIA,
    CAST(NULL AS DECIMAL(38,10)) AS CB_BAOGIA,
    CAST(NULL AS DECIMAL(38,10)) AS CPD_BAOGIA,
    CAST(NULL AS DECIMAL(38,10)) AS KET_QUA_DANH_GIA,
    CAST(NULL AS DECIMAL(38,10)) AS MUC_DICH_THAM_DINH_ID,
    CAST(NULL AS STRING) AS MUC_DICH_THAM_DINH_KHAC_TEN,
    CAST(NULL AS DECIMAL(38,10)) AS LUONG_XU_LY,
    CAST(NULL AS STRING) AS TEN_NGUOI_HD_KHAO_SAT,
    CAST(NULL AS STRING) AS SDT_NGUOI_HD_KHAO_SAT,
    CAST(NULL AS STRING) AS NGAY_BAT_DAU_PQLTS_TD,
    CAST(NULL AS STRING) AS NGAY_BAT_DAU_PQLTS_TD_STRING,
    CAST(NULL AS STRING) AS GIO_BAT_DAU_PQLTS_TD,
    CAST(NULL AS STRING) AS PHUT_BAT_DAU_PQLTS_TD,
    CAST(NULL AS STRING) AS JSON_LINK_TAI_LIEU,
    CAST(NULL AS STRING) AS IS_XN_TGKS_TDTT,
    CAST(NULL AS STRING) AS CPD1_TEN_DN,
    CAST(NULL AS STRING) AS CPD2_TEN_DN,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_KH_UU_TIEN,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_tsbd_giaodich_chinh_thong_tin_chung,
    CAST(NULL AS STRING) AS hashdiff_tsbd_giaodich_chinh_khoi_tao_phe_duyet,
    CAST(NULL AS STRING) AS hashdiff_tsbd_giaodich_chinh_thong_tin_dinh_gia,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tsbd_giaodich_chitiet AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS MA_GIAO_DICH,
    CAST(NULL AS STRING) AS NGAY_BAT_DAU_TOTRINH,
    CAST(NULL AS STRING) AS NGAY_KET_THUC_TOTRINH,
    CAST(NULL AS STRING) AS CB_LAP,
    CAST(NULL AS DECIMAL(38,0)) AS LOAI_DVDG,
    CAST(NULL AS STRING) AS Y_KIEN_ID,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI_TO_TRINH,
    CAST(NULL AS STRING) AS NGAY_BAT_DAU_TOTRINH_KIEMTRA,
    CAST(NULL AS STRING) AS NGAY_KET_THUC_TOTRINH_KIEMTRA,
    CAST(NULL AS STRING) AS CB_KIEMTRA,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI_TO_TRINH_KIEM_TRA,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_VITRI_1,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_VITRI_2,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_VITRI_3,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_VITRI_4,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_VITRI_5,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_VITRI_6,
    CAST(NULL AS STRING) AS USER_VITRI_1,
    CAST(NULL AS STRING) AS USER_VITRI_2,
    CAST(NULL AS STRING) AS USER_VITRI_3,
    CAST(NULL AS STRING) AS USER_VITRI_4,
    CAST(NULL AS STRING) AS USER_VITRI_5,
    CAST(NULL AS STRING) AS USER_VITRI_6,
    CAST(NULL AS DECIMAL(38,0)) AS KHU_VUC_NV_ID,
    CAST(NULL AS DECIMAL(38,0)) AS KHOANG_CACH_DIA_BAN,
    CAST(NULL AS DECIMAL(38,0)) AS HE_SO_DIA_BAN,
    CAST(NULL AS DECIMAL(38,0)) AS SLA_TRUCTIEP,
    CAST(NULL AS DECIMAL(38,0)) AS SLA_GIANTIEP,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_CBKTKQDG,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_TBPKTKQDG,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_CBPQLTSBD,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_TBPPQLTSBD,
    CAST(NULL AS STRING) AS LY_DO,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_DI_CHUYEN,
    CAST(NULL AS DECIMAL(38,0)) AS THOI_GIAN_KHAO_SAT,
    CAST(NULL AS DECIMAL(38,0)) AS TONG_THOI_GIAN_KHAO_SAT,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_tsbd_giaodich_chi_tiet,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tsbd_giaodich_lich_su_v2 AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS INT) AS ID,
    CAST(NULL AS INT) AS GD_TSBD_ID,
    CAST(NULL AS STRING) AS MA_GIAO_DICH,
    CAST(NULL AS INT) AS USER_THUC_HIEN,
    CAST(NULL AS STRING) AS USERNAME_THUC_HIEN,
    CAST(NULL AS STRING) AS ROLE_THUC_HIEN,
    CAST(NULL AS INT) AS USER_CHUYEN_TOI,
    CAST(NULL AS STRING) AS USERNAME_CHUYEN_TOI,
    CAST(NULL AS STRING) AS ROLE_CHUYEN_TOI,
    CAST(NULL AS STRING) AS NGAY_NHAN_TASK,
    CAST(NULL AS INT) AS TASK_ID,
    CAST(NULL AS INT) AS THAO_TAC_ID,
    CAST(NULL AS INT) AS TRANG_THAI_KET_THUC,
    CAST(NULL AS INT) AS TRANG_THAI_BAT_DAU,
    CAST(NULL AS STRING) AS NGAY_BAT_DAU,
    CAST(NULL AS STRING) AS NGAY_KET_THUC,
    CAST(NULL AS INT) AS BO_SUNG_TDV,
    CAST(NULL AS INT) AS BO_SUNG_CBPQLTSBD,
    CAST(NULL AS INT) AS BO_SUNG_TBPPQLTSBD,
    CAST(NULL AS INT) AS BO_SUNG_Y_KIEN_TDV,
    CAST(NULL AS INT) AS BO_SUNG_Y_KIEN_CBKTKQDG,
    CAST(NULL AS INT) AS MA_LUONG_DVDG,
    CAST(NULL AS STRING) AS TEN_LUONG_DVDG,
    CAST(NULL AS STRING) AS CHU_THICH,
    CAST(NULL AS INT) AS TRANG_THAI,
    CAST(NULL AS INT) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS INT) AS THOI_GIAN_THUC_HIEN,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_tsbd_giaodich_lich_su_v2,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tsbd_giaodich_taisan_chusohuu AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS DECIMAL(38,10)) AS GIAODICH_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TAISAN_ID,
    CAST(NULL AS STRING) AS MA_TAI_SAN,
    CAST(NULL AS STRING) AS TEN_TAI_SAN,
    CAST(NULL AS DECIMAL(38,10)) AS TAISAN_TINH_TP_ID,
    CAST(NULL AS DECIMAL(38,10)) AS TAISAN_QUAN_HUYEN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS BDS_CAN_CU_DG,
    CAST(NULL AS STRING) AS BDS_MA_CAN_HO,
    CAST(NULL AS STRING) AS BDS_NGAY_CAP_CN,
    CAST(NULL AS STRING) AS SO_GIAY_CN,
    CAST(NULL AS STRING) AS GIAYTO_TO_CHUC,
    CAST(NULL AS DECIMAL(38,10)) AS GIAYTO_MENH_GIA,
    CAST(NULL AS STRING) AS GIAYTO_KY_HAN,
    CAST(NULL AS STRING) AS QUYENPHATSINH_TEN,
    CAST(NULL AS STRING) AS QUYENPHATSINH_SOHOPDONG,
    CAST(NULL AS STRING) AS VONGOP_MACK,
    CAST(NULL AS STRING) AS VONGOP_TOCHUCNHAN,
    CAST(NULL AS DECIMAL(38,10)) AS PTVT_LOAIPHUONGTIEN_ID,
    CAST(NULL AS STRING) AS PTVT_HANGXS,
    CAST(NULL AS STRING) AS PTVT_BIENKS,
    CAST(NULL AS STRING) AS PTVT_CONGNANG,
    CAST(NULL AS STRING) AS PTVT_TENTAU,
    CAST(NULL AS STRING) AS PTVT_SODKY,
    CAST(NULL AS STRING) AS PTVT_TAITRONG,
    CAST(NULL AS STRING) AS HANGHOA_TENQUYCACH,
    CAST(NULL AS STRING) AS TSKHAC_TT_TAISAN,
    CAST(NULL AS STRING) AS TSKHAC_GHICHU,
    CAST(NULL AS STRING) AS TAISAN_MO_TA,
    CAST(NULL AS STRING) AS TAISAN_DIA_CHI,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_TAI_SAN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_TAI_SAN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS CTIET_TAI_SAN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS CSH_ID,
    CAST(NULL AS STRING) AS CSH_HO_TEN,
    CAST(NULL AS STRING) AS CSH_CMND,
    CAST(NULL AS STRING) AS CSH_NGAY_SINH,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI,
    CAST(NULL AS STRING) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS STRING) AS DONG_XE,
    CAST(NULL AS STRING) AS MA_GIAO_DICH,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_tsbd_tai_san AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS TAI_SAN_ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS STRING) AS MA_TAI_SAN,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_TAI_SAN,
    CAST(NULL AS STRING) AS TEN_TAI_SAN,
    CAST(NULL AS DECIMAL(38,10)) AS TINH_TP_ID,
    CAST(NULL AS DECIMAL(38,10)) AS QUAN_HUYEN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS BDS_CAN_CU_DG,
    CAST(NULL AS STRING) AS BDS_MA_CAN_HO,
    CAST(NULL AS STRING) AS BDS_NGAY_CAP_CN,
    CAST(NULL AS STRING) AS SO_GIAY_CN,
    CAST(NULL AS STRING) AS GIAYTO_TO_CHUC,
    CAST(NULL AS DECIMAL(38,10)) AS GIAYTO_MENH_GIA,
    CAST(NULL AS STRING) AS GIAYTO_KY_HAN,
    CAST(NULL AS STRING) AS QUYENPHATSINH_TEN,
    CAST(NULL AS STRING) AS QUYENPHATSINH_SOHOPDONG,
    CAST(NULL AS STRING) AS VONGOP_MACK,
    CAST(NULL AS STRING) AS VONGOP_TOCHUCNHAN,
    CAST(NULL AS DECIMAL(38,10)) AS PTVT_LOAIPHUONGTIEN_ID,
    CAST(NULL AS STRING) AS PTVT_HANGXS,
    CAST(NULL AS STRING) AS PTVT_BIENKS,
    CAST(NULL AS STRING) AS PTVT_CONGNANG,
    CAST(NULL AS STRING) AS PTVT_TENTAU,
    CAST(NULL AS STRING) AS PTVT_SODKY,
    CAST(NULL AS STRING) AS PTVT_TAITRONG,
    CAST(NULL AS STRING) AS HANGHOA_TENQUYCACH,
    CAST(NULL AS STRING) AS TSKHAC_TT_TAISAN,
    CAST(NULL AS STRING) AS TSKHAC_GHICHU,
    CAST(NULL AS STRING) AS MO_TA,
    CAST(NULL AS STRING) AS DIA_CHI,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_XU_LY,
    CAST(NULL AS STRING) AS NGAY_CHUYEN_XU_LY,
    CAST(NULL AS DECIMAL(38,10)) AS TRANG_THAI,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS TAI_SAN_GOC,
    CAST(NULL AS DECIMAL(38,10)) AS NHOM_TAI_SAN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS LOAI_TAI_SAN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS CTIET_TAI_SAN_ID,
    CAST(NULL AS DECIMAL(38,10)) AS NGUON_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS NGUOI_CAP_NHAT,
    CAST(NULL AS STRING) AS NGAY_CAP_NHAT,
    CAST(NULL AS DECIMAL(38,10)) AS DONG_XE,
    CAST(NULL AS STRING) AS MA_TS_T24,
    CAST(NULL AS DECIMAL(38,10)) AS DVKD_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS PHUONG_XA_ID,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_tsbd_tai_san_thong_tin_khac,
    CAST(NULL AS STRING) AS hashdiff_tsbd_tai_san_thong_tin_chung,
    CAST(NULL AS STRING) AS hashdiff_tsbd_tai_san_phuong_tien,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_xl_ct_han_muc AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,0)) AS GD_CHINH_ID,
    CAST(NULL AS DECIMAL(38,0)) AS HAN_MUC_ID,
    CAST(NULL AS DECIMAL(38,0)) AS SAN_PHAM_ID,
    CAST(NULL AS DECIMAL(38,0)) AS TONG_HMRR,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS NGUOI_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS GIA_TRI_GD,
    CAST(NULL AS DECIMAL(38,0)) AS TONG_HMRR_KHAC,
    CAST(NULL AS DECIMAL(38,0)) AS HINH_THUC_CAP_TD,
    CAST(NULL AS STRING) AS LOAI_HO_SO,
    CAST(NULL AS DECIMAL(38,0)) AS TONG_HMRR_DONG,
    CAST(NULL AS DECIMAL(38,0)) AS GIA_TRI_GD_DONG,
    CAST(NULL AS DECIMAL(38,0)) AS TONG_HMRR_KHAC_DONG,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_xl_ct_han_muc,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_xl_ct_lich_su AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS INT) AS GD_CHINH_ID,
    CAST(NULL AS INT) AS ID,
    CAST(NULL AS INT) AS TRANG_THAI_HS,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS INT) AS NGUOI_TAO,
    CAST(NULL AS STRING) AS CPD_DE_XUAT,
    CAST(NULL AS STRING) AS YKIEN_CHITIET,
    CAST(NULL AS STRING) AS LYDO_DONGY_ID,
    CAST(NULL AS STRING) AS LYDO_DONGY_CT,
    CAST(NULL AS STRING) AS LYDO_KHONG_ID,
    CAST(NULL AS STRING) AS LYDO_KHONG_CT,
    CAST(NULL AS INT) AS TASK_ID,
    CAST(NULL AS INT) AS TEAM_ID,
    CAST(NULL AS INT) AS TRANG_THAI_BAT_DAU,
    CAST(NULL AS INT) AS TRANG_THAI_KET_THUC,
    CAST(NULL AS INT) AS KET_QUA_XU_LY_USER,
    CAST(NULL AS STRING) AS TEN_TAC_VU,
    CAST(NULL AS STRING) AS THOI_DIEM_KET_THUC,
    CAST(NULL AS STRING) AS THOI_DIEM_BAT_DAU,
    CAST(NULL AS INT) AS SO_LAN_YCBS,
    CAST(NULL AS INT) AS ROLE_NHAN_TASK,
    CAST(NULL AS INT) AS ROLE_CHUYEN_TASK,
    CAST(NULL AS STRING) AS LUONG,
    CAST(NULL AS INT) AS LUONG_ID,
    CAST(NULL AS INT) AS TONG_TGIAN_XU_LY,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_xl_ct_lich_su,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_xl_ksgn_chung AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,0)) AS GD_CHINH_ID,
    CAST(NULL AS DECIMAL(38,0)) AS KHACH_HANG_ID,
    CAST(NULL AS STRING) AS MA_GIAO_DICH,
    CAST(NULL AS DECIMAL(38,0)) AS PDTD_GD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS GD_TRANGTHAI,
    CAST(NULL AS DECIMAL(38,0)) AS DONVI_XULY,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS NGUOI_TAO,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI,
    CAST(NULL AS DECIMAL(38,0)) AS NGUOI_DANG_XU_LY,
    CAST(NULL AS DECIMAL(38,0)) AS PROCESS_ID,
    CAST(NULL AS DECIMAL(38,0)) AS CAP_PHE_DUYET,
    CAST(NULL AS DECIMAL(38,0)) AS QUY_TRINH,
    CAST(NULL AS DECIMAL(38,0)) AS LOAI_SOAN_THAO,
    CAST(NULL AS DECIMAL(38,0)) AS CBDVTD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS DVKD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS CBGDTD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS CBTMTTTM_ID,
    CAST(NULL AS DECIMAL(38,0)) AS TRANG_THAI_PHE_DUYET,
    CAST(NULL AS STRING) AS NGAY_HOAN_THANH,
    CAST(NULL AS DECIMAL(38,0)) AS LOAI_CONG_VIEC,
    CAST(NULL AS DECIMAL(38,0)) AS DL_TOAN_VEN,
    CAST(NULL AS DECIMAL(38,0)) AS GD_GOC_ID,
    CAST(NULL AS STRING) AS NGAY_DXUAT_BSUNG_PDNL,
    CAST(NULL AS STRING) AS NGAY_PDNL_HO_SO,
    CAST(NULL AS DECIMAL(38,0)) AS NGOAI_TE,
    CAST(NULL AS DECIMAL(38,0)) AS SO_TIEN_QUY_DOI,
    CAST(NULL AS STRING) AS MA_HAN_MUC,
    CAST(NULL AS DECIMAL(38,0)) AS SO_TAT_TOAN,
    CAST(NULL AS STRING) AS WORKING_ACCOUNT,
    CAST(NULL AS STRING) AS CHI_TIET_HOP_DONG,
    CAST(NULL AS DECIMAL(38,0)) AS KY_QUY,
    CAST(NULL AS STRING) AS MA_HAN_MUC_T24,
    CAST(NULL AS DECIMAL(38,0)) AS SO_LUONG_MD,
    CAST(NULL AS DECIMAL(38,0)) AS SO_LUONG_PD,
    CAST(NULL AS DECIMAL(38,0)) AS SO_LUONG_LD,
    CAST(NULL AS STRING) AS NGAY_DX_BSUNG,
    CAST(NULL AS DECIMAL(38,0)) AS CAP_PHE_DUYET_GAN_NHAT,
    CAST(NULL AS DECIMAL(38,0)) AS SL_HS_PHAI_DU,
    CAST(NULL AS DECIMAL(38,0)) AS SL_HS_THUC_TE,
    CAST(NULL AS STRING) AS REF_CODE,
    CAST(NULL AS DECIMAL(38,0)) AS CBQHKH_ID,
    CAST(NULL AS DECIMAL(38,0)) AS GDK_ID,
    CAST(NULL AS DECIMAL(38,0)) AS GDKQLRR_ID,
    CAST(NULL AS DECIMAL(38,0)) AS TDV_ID,
    CAST(NULL AS DECIMAL(38,0)) AS KSVGDTD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS KSVTNTTTM_ID,
    CAST(NULL AS DECIMAL(38,0)) AS TPXLGDTD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS CBTNTTTM_ID,
    CAST(NULL AS DECIMAL(38,0)) AS LUONG_QUY_TRINH,
    CAST(NULL AS DECIMAL(38,0)) AS BSPO_ID,
    CAST(NULL AS STRING) AS SO_LC,
    CAST(NULL AS STRING) AS NGAY_PHAT_HANH_LC,
    CAST(NULL AS STRING) AS SO_TF,
    CAST(NULL AS STRING) AS HINH_THUC_KY_QUY,
    CAST(NULL AS DECIMAL(38,0)) AS SO_TIEN_KY_QUY,
    CAST(NULL AS DECIMAL(38,0)) AS TY_LE_KY_QUY,
    CAST(NULL AS STRING) AS SO_MD,
    CAST(NULL AS DECIMAL(38,0)) AS CAP_DO_DANG_XLY,
    CAST(NULL AS STRING) AS SO_LD,
    CAST(NULL AS DECIMAL(38,0)) AS NGAN_HANG_PHAT_HANH,
    CAST(NULL AS DECIMAL(38,0)) AS SU_CO_HE_THONG,
    CAST(NULL AS STRING) AS HO_SO_XU_LY_TAI,
    CAST(NULL AS STRING) AS THOI_GIAN_NHAN_TASK_MOI_NHAT,
    CAST(NULL AS STRING) AS CBDVTD_TGIAN_NHAN_TASK,
    CAST(NULL AS STRING) AS CBTNTTTM_TGIAN_NHAN_TASK,
    CAST(NULL AS STRING) AS CBGDTD_TGIAN_NHAN_TASK,
    CAST(NULL AS DECIMAL(38,0)) AS KSH_ID,
    CAST(NULL AS DECIMAL(38,0)) AS KET_QUA_PHE_DUYET,
    CAST(NULL AS STRING) AS NHOM_CBXL_TNTTTM,
    CAST(NULL AS STRING) AS NHOM_CBXL_GDTDV,
    CAST(NULL AS STRING) AS NHOM_CBXL_DVTD,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_TNTTTM,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_GDTD,
    CAST(NULL AS DECIMAL(38,0)) AS DIEM_DVTD,
    CAST(NULL AS DECIMAL(38,0)) AS NHOM_KHACH_HANG,
    CAST(NULL AS DECIMAL(38,0)) AS CAP_PD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS ST_CAP_PD_ID,
    CAST(NULL AS DECIMAL(38,0)) AS CB_PHAP_CHE_ID,
    CAST(NULL AS DECIMAL(38,0)) AS IS_PHAP_CHE,
    CAST(NULL AS DECIMAL(38,0)) AS SO_CAP_DUYET,
    CAST(NULL AS DECIMAL(38,0)) AS CAP_PD_CHUNG_ID,
    CAST(NULL AS STRING) AS MA_GD_GOC,
    CAST(NULL AS DECIMAL(38,0)) AS XU_LY_HS,
    CAST(NULL AS DECIMAL(38,0)) AS CO_GIAM_TAT,
    CAST(NULL AS DECIMAL(38,0)) AS LOAI_HAN_MUC,
    CAST(NULL AS DECIMAL(38,0)) AS CBQL_HDTD,
    CAST(NULL AS DECIMAL(38,0)) AS DONG_HDTD_CU,
    CAST(NULL AS DECIMAL(38,0)) AS DIEU_CHINH_HDTD,
    CAST(NULL AS STRING) AS CAN_BO_THEO_GIOI,
    CAST(NULL AS STRING) AS REFCODE_OMNI,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_xl_ksgn_chung_quy_trinh_trang_thai,
    CAST(NULL AS STRING) AS hashdiff_xl_ksgn_chung_ho_so_chung_tu,
    CAST(NULL AS STRING) AS hashdiff_xl_ksgn_chung_don_vi_khoi_tao_phe_duyet,
    CAST(NULL AS STRING) AS hashdiff_xl_ksgn_chung_can_bo_danh_gia,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_xl_ksgn_ct AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS ma_key,
    CAST(NULL AS STRING) AS GD_CHINH_ID,
    CAST(NULL AS INT) AS GD_CHITIET_ID,
    CAST(NULL AS INT) AS GIAODICH_LOAI,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS INT) AS NGUOI_TAO,
    CAST(NULL AS INT) AS NHOM_NGHIEPVU,
    CAST(NULL AS INT) AS NGHIEPVU_CT,
    CAST(NULL AS INT) AS SO_TIEN_GD,
    CAST(NULL AS STRING) AS GHI_CHU,
    CAST(NULL AS INT) AS SO_LUONG,
    CAST(NULL AS DOUBLE) AS GTRI_GIAODICH,
    CAST(NULL AS BIGINT) AS GTRI_GIAODICH_DONG,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_xl_ksgn_ct,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_xl_pdtd_link AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS ID,
    CAST(NULL AS STRING) AS DATADATE,
    CAST(NULL AS DECIMAL(38,10)) AS GD_CHINH_ID,
    CAST(NULL AS STRING) AS MA_GIAO_DICH_XL,
    CAST(NULL AS DECIMAL(38,10)) AS GD_PDTD_ID,
    CAST(NULL AS STRING) AS MA_GIAO_DICH_PDTD,
    CAST(NULL AS STRING) AS NGAY_TAO,
    CAST(NULL AS DECIMAL(38,10)) AS GD_NGOAI_BPM,
    CAST(NULL AS STRING) AS KHOAN_TIN_DUNG,
    CAST(NULL AS STRING) AS NGAY_PHE_DUYET,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_xl_pdtd_link,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
-- SOURCE: OMNI
-- ============================================================

CREATE OR REPLACE VIEW v_stg_omni_account_information AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS uuid,
    CAST(NULL AS STRING) AS party_id,
    CAST(NULL AS STRING) AS account_number,
    CAST(NULL AS STRING) AS `alias`,
    CAST(NULL AS STRING) AS bank_address_line1,
    CAST(NULL AS STRING) AS bank_address_line2,
    CAST(NULL AS STRING) AS bank_street_name,
    CAST(NULL AS STRING) AS bank_town,
    CAST(NULL AS STRING) AS bank_code,
    CAST(NULL AS STRING) AS bank_country,
    CAST(NULL AS STRING) AS bank_name,
    CAST(NULL AS STRING) AS bank_post_code,
    CAST(NULL AS STRING) AS bank_country_sub_division,
    CAST(NULL AS STRING) AS bic,
    CAST(NULL AS STRING) AS iban,
    CAST(NULL AS STRING) AS phone_number,
    CAST(NULL AS STRING) AS email,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS acc_holder_addr_line1,
    CAST(NULL AS STRING) AS acc_holder_addr_line2,
    CAST(NULL AS STRING) AS acc_holder_street_name,
    CAST(NULL AS STRING) AS acc_holder_town,
    CAST(NULL AS STRING) AS acc_holder_country,
    CAST(NULL AS STRING) AS acc_holder_post_code,
    CAST(NULL AS STRING) AS acc_holder_country_sub_div,
    CAST(NULL AS STRING) AS external_id,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS account_type,
    CAST(NULL AS STRING) AS other_identifier,
    CAST(NULL AS STRING) AS bank_address_source,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_acknowledgement AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS internal_user_id,
    CAST(NULL AS BIGINT) AS notification_id,
    CAST(NULL AS TIMESTAMP) AS effective_date,
    CAST(NULL AS TINYINT) AS acknowledgement_code,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_audit_message AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS actor_user_id,
    CAST(NULL AS TIMESTAMP) AS event_time,
    CAST(NULL AS STRING) AS actor_username,
    CAST(NULL AS STRING) AS event_category,
    CAST(NULL AS STRING) AS object_type,
    CAST(NULL AS STRING) AS event_action,
    CAST(NULL AS STRING) AS event_desc,
    CAST(NULL AS STRING) AS message_set_id,
    CAST(NULL AS STRING) AS legal_entity_id,
    CAST(NULL AS BIGINT) AS sa_id,
    CAST(NULL AS STRING) AS ip_address,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS INT) AS schema_version,
    CAST(NULL AS STRING) AS error,
    CAST(NULL AS STRING) AS metadata,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS temp_legacy_id,
    CAST(NULL AS STRING) AS emulator_user_id,
    CAST(NULL AS STRING) AS emulator_username,
    CAST(NULL AS STRING) AS emulator_domain,
    CAST(NULL AS STRING) AS session_id,
    CAST(NULL AS STRING) AS device_id,
    CAST(NULL AS INT) AS day_of_month,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_audit_message_device,
    CAST(NULL AS STRING) AS hashdiff_audit_message_information,
    CAST(NULL AS STRING) AS hashdiff_audit_message_emulator,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_auto_debit AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS order_code,
    CAST(NULL AS STRING) AS bill_code,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS account_number,
    CAST(NULL AS STRING) AS account_name,
    CAST(NULL AS STRING) AS service_code,
    CAST(NULL AS STRING) AS provider_code,
    CAST(NULL AS STRING) AS payment_setting,
    CAST(NULL AS DECIMAL(38,18)) AS amount_limit,
    CAST(NULL AS STRING) AS recurring_period,
    CAST(NULL AS STRING) AS finish_date,
    CAST(NULL AS STRING) AS payment_date,
    CAST(NULL AS INT) AS status,
    CAST(NULL AS INT) AS is_deleted,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS modified_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS modified_by,
    CAST(NULL AS BIGINT) AS service_provider_id,
    CAST(NULL AS STRING) AS prop1,
    CAST(NULL AS STRING) AS prop2,
    CAST(NULL AS DECIMAL(38,18)) AS prop3,
    CAST(NULL AS BIGINT) AS prop4,
    CAST(NULL AS STRING) AS prop5,
    CAST(NULL AS STRING) AS arrangement_id,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS card_number,
    CAST(NULL AS STRING) AS card_account_num,
    CAST(NULL AS STRING) AS customer_name,
    CAST(NULL AS STRING) AS alt_provider_code,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_auto_debit_audit,
    CAST(NULL AS STRING) AS hashdiff_auto_debit_information,
    CAST(NULL AS STRING) AS hashdiff_auto_debit_customer,
    CAST(NULL AS STRING) AS hashdiff_auto_debit_properties,
    CAST(NULL AS STRING) AS hashdiff_auto_debit_schedule,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_credit_card_registration AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS birthday,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS contact_address,
    CAST(NULL AS STRING) AS contract_file_path,
    CAST(NULL AS STRING) AS created_date,
    CAST(NULL AS STRING) AS customer_name,
    CAST(NULL AS STRING) AS email,
    CAST(NULL AS STRING) AS face_liveness_status,
    CAST(NULL AS STRING) AS face_matching_status,
    CAST(NULL AS STRING) AS face_sanity_status,
    CAST(NULL AS STRING) AS id_card_ocr_status,
    CAST(NULL AS STRING) AS id_card_sanity_status,
    CAST(NULL AS STRING) AS id_card_tampering_status,
    CAST(NULL AS BOOLEAN) AS in_import_list,
    CAST(NULL AS STRING) AS job,
    CAST(NULL AS STRING) AS legal_id_num,
    CAST(NULL AS STRING) AS legal_issue_date,
    CAST(NULL AS STRING) AS legal_issue_place,
    CAST(NULL AS DECIMAL(38,2)) AS limit_suggest,
    CAST(NULL AS STRING) AS marital_status,
    CAST(NULL AS STRING) AS legal_id_num_other,
    CAST(NULL AS STRING) AS permanent_address,
    CAST(NULL AS STRING) AS phone_number,
    CAST(NULL AS STRING) AS product_code,
    CAST(NULL AS STRING) AS product_name,
    CAST(NULL AS STRING) AS reference_id,
    CAST(NULL AS STRING) AS signed_contract_file_path,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS type_of_labor_contract,
    CAST(NULL AS STRING) AS updated_date,
    CAST(NULL AS STRING) AS working_time,
    CAST(NULL AS STRING) AS branch_name,
    CAST(NULL AS STRING) AS branch_code,
    CAST(NULL AS STRING) AS card_repayment_type,
    CAST(NULL AS STRING) AS card_repayment_account_no,
    CAST(NULL AS STRING) AS company_name,
    CAST(NULL AS STRING) AS position,
    CAST(NULL AS DECIMAL(38,2)) AS debt_expenses_to_pay_other_credit_institutions,
    CAST(NULL AS DECIMAL(38,2)) AS real_monthly_income,
    CAST(NULL AS DECIMAL(38,2)) AS living_expenses,
    CAST(NULL AS STRING) AS delivery_address,
    CAST(NULL AS STRING) AS old_legal_id_no,
    CAST(NULL AS STRING) AS legal_id_type,
    CAST(NULL AS STRING) AS legal_expired_date,
    CAST(NULL AS STRING) AS gender,
    CAST(NULL AS STRING) AS company_address,
    CAST(NULL AS STRING) AS document_id,
    CAST(NULL AS STRING) AS sale_name,
    CAST(NULL AS STRING) AS nationality,
    CAST(NULL AS DECIMAL(38,2)) AS salary_income,
    CAST(NULL AS DECIMAL(38,2)) AS business_income,
    CAST(NULL AS DECIMAL(38,2)) AS vehicle_rental_income,
    CAST(NULL AS DECIMAL(38,2)) AS real_estate_rental_income,
    CAST(NULL AS DECIMAL(38,2)) AS other_income,
    CAST(NULL AS STRING) AS sale_code,
    CAST(NULL AS STRING) AS education_level,
    CAST(NULL AS STRING) AS income_method,
    CAST(NULL AS STRING) AS contract_no,
    CAST(NULL AS STRING) AS card_token_number,
    CAST(NULL AS STRING) AS spouse_name,
    CAST(NULL AS STRING) AS spouse_legal_type,
    CAST(NULL AS STRING) AS spouse_legal_id,
    CAST(NULL AS STRING) AS agreement_uuid,
    CAST(NULL AS STRING) AS product_code_offer,
    CAST(NULL AS STRING) AS product_name_offer,
    CAST(NULL AS DECIMAL(38,2)) AS card_limit_approved,
    CAST(NULL AS STRING) AS company_address_info,
    CAST(NULL AS STRING) AS introduce_code,
    CAST(NULL AS STRING) AS introduce_name,
    CAST(NULL AS INT) AS number_of_dependents,
    CAST(NULL AS STRING) AS referral_code,
    CAST(NULL AS STRING) AS ekyc_type,
    CAST(NULL AS STRING) AS personal_rank,
    CAST(NULL AS STRING) AS personal_rank_start,
    CAST(NULL AS STRING) AS personal_rank_renew,
    CAST(NULL AS STRING) AS group_personal_rank,
    CAST(NULL AS STRING) AS card_issuance_type,
    CAST(NULL AS STRING) AS process_type,
    CAST(NULL AS STRING) AS product_code_offer_list,
    CAST(NULL AS STRING) AS spouse_phone_number,
    CAST(NULL AS STRING) AS reference_name,
    CAST(NULL AS STRING) AS reference_phone_number,
    CAST(NULL AS STRING) AS relationship_type,
    CAST(NULL AS STRING) AS policy_groups,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_credit_card_registration_information,
    CAST(NULL AS STRING) AS hashdiff_credit_card_registration_flow,
    CAST(NULL AS STRING) AS hashdiff_credit_card_registration_financial_profile,
    CAST(NULL AS STRING) AS hashdiff_credit_card_registration_customer_info,
    CAST(NULL AS STRING) AS hashdiff_credit_card_registration_introduce,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_customer_data_sharing_consent AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS partner_code,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS consent_status,
    CAST(NULL AS STRING) AS os_info,
    CAST(NULL AS STRING) AS device_name,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS tracking_schema,
    CAST(NULL AS STRING) AS tracking_item,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_data_sharing_consent_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_customers AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS customer_status,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_omni_customer_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_device AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS device_id,
    CAST(NULL AS STRING) AS user_id,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS BIGINT) AS created_date_time,
    CAST(NULL AS BIGINT) AS updated_date_time,
    CAST(NULL AS STRING) AS dbs_user_id,
    CAST(NULL AS STRING) AS friendly_name,
    CAST(NULL AS STRING) AS vendor,
    CAST(NULL AS STRING) AS model,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS push_token,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_device_omni_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_device_detail AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS device_id,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS TINYINT) AS nfc_enabled,
    CAST(NULL AS STRING) AS omni_version,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS unique_device_id,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_en_user AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS external_id,
    CAST(NULL AS STRING) AS legal_entity_id,
    CAST(NULL AS STRING) AS full_name,
    CAST(NULL AS STRING) AS preferred_language,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS external_id_up,
    CAST(NULL AS STRING) AS full_name_up,
    CAST(NULL AS STRING) AS idp_id,
    CAST(NULL AS STRING) AS realm_id,
    CAST(NULL AS STRING) AS cb_user_id,
    CAST(NULL AS STRING) AS cb_issuer,
    CAST(NULL AS STRING) AS username,
    CAST(NULL AS STRING) AS username_up,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_omni_user_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_master_data AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS description,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS type,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_od_linked_deposit AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS deposit_account_no,
    CAST(NULL AS STRING) AS od_registration_id,
    CAST(NULL AS BOOLEAN) AS is_additional_request,
    CAST(NULL AS DECIMAL(38,2)) AS deposit_balance,
    CAST(NULL AS STRING) AS maturity_date,
    CAST(NULL AS STRING) AS opening_date,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_od_registration AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS address,
    CAST(NULL AS DECIMAL(38,2)) AS approved_limit_amount,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS due_date,
    CAST(NULL AS STRING) AS email,
    CAST(NULL AS STRING) AS full_name,
    CAST(NULL AS STRING) AS identity_number,
    CAST(NULL AS DOUBLE) AS interest_rate,
    CAST(NULL AS STRING) AS overdraft_account_no,
    CAST(NULL AS STRING) AS phone_number,
    CAST(NULL AS STRING) AS requested_date,
    CAST(NULL AS DECIMAL(38,2)) AS requested_limit_amount,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS user_id,
    CAST(NULL AS STRING) AS effective_date,
    CAST(NULL AS STRING) AS contract_file_id,
    CAST(NULL AS STRING) AS result_file_id,
    CAST(NULL AS STRING) AS approval_file_id,
    CAST(NULL AS STRING) AS confirmation_id,
    CAST(NULL AS STRING) AS username,
    CAST(NULL AS STRING) AS contract_bill_code,
    CAST(NULL AS STRING) AS first_approval_agreement_uuid,
    CAST(NULL AS STRING) AS first_approval_bill_code,
    CAST(NULL AS STRING) AS second_approval_agreement_uuid,
    CAST(NULL AS STRING) AS second_approval_bill_code,
    CAST(NULL AS STRING) AS bpm_id,
    CAST(NULL AS STRING) AS ecm_approval_document_id,
    CAST(NULL AS STRING) AS ecm_contract_document_id,
    CAST(NULL AS STRING) AS approval_agreement_id,
    CAST(NULL AS STRING) AS issued_by,
    CAST(NULL AS STRING) AS issued_date,
    CAST(NULL AS STRING) AS prepare_certificate_request_id,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_od_registration_limit,
    CAST(NULL AS STRING) AS hashdiff_od_registration_date,
    CAST(NULL AS STRING) AS hashdiff_od_registration_agreement,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_omni_service AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS account_number_temp,
    CAST(NULL AS STRING) AS branch_code,
    CAST(NULL AS STRING) AS branch_name,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS created_from,
    CAST(NULL AS STRING) AS email,
    CAST(NULL AS DECIMAL(38,10)) AS limit,
    CAST(NULL AS STRING) AS locking_reason,
    CAST(NULL AS STRING) AS package_mounting_account,
    CAST(NULL AS STRING) AS package_offer_code,
    CAST(NULL AS STRING) AS package_offer_name,
    CAST(NULL AS STRING) AS phone_number,
    CAST(NULL AS STRING) AS sale_employee_id,
    CAST(NULL AS STRING) AS service_agreement_id,
    CAST(NULL AS STRING) AS smart_account_package_code,
    CAST(NULL AS STRING) AS smart_account_package_name,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS username,
    CAST(NULL AS STRING) AS authentication_type_id,
    CAST(NULL AS STRING) AS package_id,
    CAST(NULL AS STRING) AS fee_discount_id,
    CAST(NULL AS BINARY) AS is_same_username_group,
    CAST(NULL AS STRING) AS old_omni_username,
    CAST(NULL AS STRING) AS account_package_code,
    CAST(NULL AS STRING) AS account_package_date,
    CAST(NULL AS STRING) AS locked_by,
    CAST(NULL AS STRING) AS locked_at,
    CAST(NULL AS STRING) AS first_login_new_omni_app_at,
    CAST(NULL AS STRING) AS last_login_platform,
    CAST(NULL AS STRING) AS last_login_device_id,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_service_package,
    CAST(NULL AS STRING) AS hashdiff_service_information,
    CAST(NULL AS STRING) AS hashdiff_service_audit,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_onboarding_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS case_key,
    CAST(NULL AS STRING) AS report_data,
    CAST(NULL AS STRING) AS step_name,
    CAST(NULL AS STRING) AS phone_number,
    CAST(NULL AS STRING) AS email,
    CAST(NULL AS STRING) AS identity_number,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS full_name,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS modified_at,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_onboarding_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_oversea_ft_request AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS user_id,
    CAST(NULL AS STRING) AS internal_reference,
    CAST(NULL AS STRING) AS external_id,
    CAST(NULL AS STRING) AS external_reference,
    CAST(NULL AS STRING) AS purpose_code,
    CAST(NULL AS STRING) AS currency,
    CAST(NULL AS DECIMAL(38,18)) AS req_amount,
    CAST(NULL AS STRING) AS req_charge_type,
    CAST(NULL AS STRING) AS ben_name,
    CAST(NULL AS STRING) AS ben_address,
    CAST(NULL AS STRING) AS ben_bank_name,
    CAST(NULL AS STRING) AS ben_bank_code,
    CAST(NULL AS STRING) AS ben_bank_address,
    CAST(NULL AS STRING) AS ben_account_no,
    CAST(NULL AS STRING) AS related_name,
    CAST(NULL AS STRING) AS related_legal_id_no,
    CAST(NULL AS STRING) AS related_address,
    CAST(NULL AS STRING) AS related_relationship_code,
    CAST(NULL AS STRING) AS is_debt_visa_bit,
    CAST(NULL AS STRING) AS visa_commit_date,
    CAST(NULL AS STRING) AS visa_commit_id,
    CAST(NULL AS STRING) AS visa_commit_reference,
    CAST(NULL AS STRING) AS rm_code,
    CAST(NULL AS STRING) AS rm_name,
    CAST(NULL AS STRING) AS latest_bpm_comment,
    CAST(NULL AS STRING) AS lasted_bpm_updated_at,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS ft_reference,
    CAST(NULL AS STRING) AS charge_reference,
    CAST(NULL AS STRING) AS mt103_reference,
    CAST(NULL AS DECIMAL(38,18)) AS transferred_amount,
    CAST(NULL AS STRING) AS transferred_cur,
    CAST(NULL AS STRING) AS transferred_at,
    CAST(NULL AS STRING) AS transferred_status,
    CAST(NULL AS DECIMAL(38,18)) AS exchange_rate,
    CAST(NULL AS DECIMAL(38,18)) AS charge_amt_before,
    CAST(NULL AS DECIMAL(38,18)) AS charge_amt,
    CAST(NULL AS STRING) AS charge_type,
    CAST(NULL AS DECIMAL(38,18)) AS discount,
    CAST(NULL AS STRING) AS account_number,
    CAST(NULL AS STRING) AS account_cur,
    CAST(NULL AS STRING) AS deleted,
    CAST(NULL AS STRING) AS contract_limit_id,
    CAST(NULL AS STRING) AS beneficiary_branch_code,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_oversea_ft_request_beneficiary,
    CAST(NULL AS STRING) AS hashdiff_oversea_ft_request_audit,
    CAST(NULL AS STRING) AS hashdiff_oversea_ft_request_related_party,
    CAST(NULL AS STRING) AS hashdiff_oversea_ft_request_execution,
    CAST(NULL AS STRING) AS hashdiff_oversea_ft_request_information,
    CAST(NULL AS STRING) AS hashdiff_oversea_ft_request_visa_commit,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_package AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS description,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS TINYINT) AS can_register_ep_portal,
    CAST(NULL AS DATE) AS effective_date,
    CAST(NULL AS DATE) AS package_discontinuation_date,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_party AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS INT) AS access_context_scope,
    CAST(NULL AS STRING) AS address_line1,
    CAST(NULL AS STRING) AS address_line2,
    CAST(NULL AS STRING) AS street_name,
    CAST(NULL AS STRING) AS town,
    CAST(NULL AS STRING) AS `alias`,
    CAST(NULL AS STRING) AS bb_id,
    CAST(NULL AS STRING) AS category,
    CAST(NULL AS STRING) AS contact_person,
    CAST(NULL AS STRING) AS country,
    CAST(NULL AS STRING) AS email_id,
    CAST(NULL AS STRING) AS legal_entity_id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS phone_number,
    CAST(NULL AS STRING) AS service_agreement_id,
    CAST(NULL AS STRING) AS post_code,
    CAST(NULL AS STRING) AS country_sub_division,
    CAST(NULL AS STRING) AS external_id,
    CAST(NULL AS STRING) AS approval_id,
    CAST(NULL AS STRING) AS active_party_id,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS action,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS internal_user_id,
    CAST(NULL AS STRING) AS import_id,
    CAST(NULL AS STRING) AS user_reference,
    CAST(NULL AS STRING) AS contact_reference,
    CAST(NULL AS STRING) AS searchable_field_one,
    CAST(NULL AS STRING) AS searchable_field_two,
    CAST(NULL AS DATE) AS last_payment_date,
    CAST(NULL AS DECIMAL(23,5)) AS last_payment_amount,
    CAST(NULL AS STRING) AS type,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_party_information,
    CAST(NULL AS STRING) AS hashdiff_party_classification,
    CAST(NULL AS STRING) AS hashdiff_party_business,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_payment_history AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS arrangement_id,
    CAST(NULL AS STRING) AS payment_order_id,
    CAST(NULL AS STRING) AS bank_reference_id,
    CAST(NULL AS BIGINT) AS core_counter_party_bank_id,
    CAST(NULL AS STRING) AS to_account_number,
    CAST(NULL AS STRING) AS to_card_number,
    CAST(NULL AS STRING) AS payment_type,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS modified_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS modified_by,
    CAST(NULL AS STRING) AS counter_party_name,
    CAST(NULL AS BIGINT) AS bank_branch,
    CAST(NULL AS BIGINT) AS bank_province,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS prop1,
    CAST(NULL AS STRING) AS prop2,
    CAST(NULL AS STRING) AS prop3,
    CAST(NULL AS STRING) AS prop4,
    CAST(NULL AS STRING) AS prop5,
    CAST(NULL AS STRING) AS internal_user_id,
    CAST(NULL AS STRING) AS description,
    CAST(NULL AS BIGINT) AS amount,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS detail_code,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_payment_history_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_payment_order AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS internal_user_id,
    CAST(NULL AS STRING) AS bank_reference_id,
    CAST(NULL AS STRING) AS payment_setup_id,
    CAST(NULL AS STRING) AS payment_submission_id,
    CAST(NULL AS STRING) AS amount,
    CAST(NULL AS STRING) AS currency,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS bank_status,
    CAST(NULL AS STRING) AS rejection_reason,
    CAST(NULL AS STRING) AS pmt_mode,
    CAST(NULL AS STRING) AS pmt_type,
    CAST(NULL AS STRING) AS priority,
    CAST(NULL AS STRING) AS requested_exec_date,
    CAST(NULL AS STRING) AS reason_code,
    CAST(NULL AS STRING) AS reason_text,
    CAST(NULL AS STRING) AS error_description,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS start_date,
    CAST(NULL AS STRING) AS end_date,
    CAST(NULL AS STRING) AS frequency,
    CAST(NULL AS STRING) AS non_working_day_strategy,
    CAST(NULL AS STRING) AS every,
    CAST(NULL AS BIGINT) AS when_execute,
    CAST(NULL AS BIGINT) AS repetition,
    CAST(NULL AS STRING) AS role,
    CAST(NULL AS STRING) AS arrangement_id,
    CAST(NULL AS STRING) AS ext_arrangement_id,
    CAST(NULL AS STRING) AS account_scheme,
    CAST(NULL AS STRING) AS account,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS address_line1,
    CAST(NULL AS STRING) AS address_line2,
    CAST(NULL AS STRING) AS street_name,
    CAST(NULL AS STRING) AS post_code,
    CAST(NULL AS STRING) AS country_sub_division,
    CAST(NULL AS STRING) AS town,
    CAST(NULL AS STRING) AS country,
    CAST(NULL AS STRING) AS approval_id,
    CAST(NULL AS STRING) AS entry_class,
    CAST(NULL AS BINARY) AS intra_legal_entity,
    CAST(NULL AS STRING) AS service_agreement_id,
    CAST(NULL AS STRING) AS orig_acc_currency,
    CAST(NULL AS STRING) AS confirmation_id,
    CAST(NULL AS STRING) AS send_to_core_datetime,
    CAST(NULL AS STRING) AS parent_payment_id,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS delivery_date,
    CAST(NULL AS BIGINT) AS remaining_occurrences,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_payment_order_classification,
    CAST(NULL AS STRING) AS hashdiff_payment_order_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_service_provider AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS provider_code,
    CAST(NULL AS STRING) AS provider_name,
    CAST(NULL AS STRING) AS provider_icon,
    CAST(NULL AS BIGINT) AS services_id,
    CAST(NULL AS STRING) AS service_code,
    CAST(NULL AS STRING) AS provider_group_code,
    CAST(NULL AS STRING) AS provider_group_name,
    CAST(NULL AS STRING) AS auto_bill,
    CAST(NULL AS STRING) AS title,
    CAST(NULL AS STRING) AS image,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS modified_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS modified_by,
    CAST(NULL AS BIGINT) AS provider_group_service_id,
    CAST(NULL AS STRING) AS prop1,
    CAST(NULL AS STRING) AS prop2,
    CAST(NULL AS DECIMAL(19,2)) AS prop3,
    CAST(NULL AS BIGINT) AS prop4,
    CAST(NULL AS STRING) AS prop5,
    CAST(NULL AS STRING) AS gateway_id,
    CAST(NULL AS INT) AS visible,
    CAST(NULL AS INT) AS allow_credit_card,
    CAST(NULL AS STRING) AS content_en,
    CAST(NULL AS STRING) AS content_vi,
    CAST(NULL AS STRING) AS content_reason,
    CAST(NULL AS BIGINT) AS provider_order,
    CAST(NULL AS STRING) AS save_my_bill,
    CAST(NULL AS STRING) AS module,
    CAST(NULL AS STRING) AS group_service,
    CAST(NULL AS INT) AS has_fee,
    CAST(NULL AS INT) AS allow_in_group,
    CAST(NULL AS INT) AS allow_fav_trans,
    CAST(NULL AS STRING) AS alt_provider_code,
    CAST(NULL AS STRING) AS alt_gateway_id,
    CAST(NULL AS STRING) AS content_ko,
    CAST(NULL AS STRING) AS content_ja,
    CAST(NULL AS BOOLEAN) AS instant_bill_temp,
    CAST(NULL AS BOOLEAN) AS entrust_payment_temp,
    CAST(NULL AS TINYINT) AS auto_bill_permission,
    CAST(NULL AS TINYINT) AS manual_bill_permission,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_services AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS service_code,
    CAST(NULL AS STRING) AS service_name,
    CAST(NULL AS STRING) AS service_icon,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS modified_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS modified_by,
    CAST(NULL AS STRING) AS prop1,
    CAST(NULL AS STRING) AS prop2,
    CAST(NULL AS DECIMAL(19,2)) AS prop3,
    CAST(NULL AS BIGINT) AS prop4,
    CAST(NULL AS STRING) AS prop5,
    CAST(NULL AS INT) AS service_order,
    CAST(NULL AS STRING) AS service_code_new,
    CAST(NULL AS INT) AS visible,
    CAST(NULL AS STRING) AS group_service,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_transfer_bill_history AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS description,
    CAST(NULL AS STRING) AS reference_id,
    CAST(NULL AS STRING) AS provider_code,
    CAST(NULL AS STRING) AS ft_trans_no,
    CAST(NULL AS STRING) AS service_code,
    CAST(NULL AS STRING) AS currency,
    CAST(NULL AS STRING) AS amount,
    CAST(NULL AS STRING) AS bill_type,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS STRING) AS account_number,
    CAST(NULL AS STRING) AS account_name,
    CAST(NULL AS STRING) AS bill_code,
    CAST(NULL AS DECIMAL(38,10)) AS amount_per_month,
    CAST(NULL AS BIGINT) AS quantity,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS modified_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS modified_by,
    CAST(NULL AS STRING) AS prop1,
    CAST(NULL AS STRING) AS prop2,
    CAST(NULL AS DECIMAL(38,10)) AS prop3,
    CAST(NULL AS BIGINT) AS prop4,
    CAST(NULL AS TIMESTAMP) AS prop5,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS extras,
    CAST(NULL AS STRING) AS customer_name,
    CAST(NULL AS STRING) AS card_number,
    CAST(NULL AS STRING) AS card_account_num,
    CAST(NULL AS STRING) AS method,
    CAST(NULL AS STRING) AS client_trans_id,
    CAST(NULL AS STRING) AS consumption_id,
    CAST(NULL AS STRING) AS payment_order_id,
    CAST(NULL AS STRING) AS core_response,
    CAST(NULL AS STRING) AS core_response_time,
    CAST(NULL AS STRING) AS bill_item_no,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_transfer_bill_response,
    CAST(NULL AS STRING) AS hashdiff_transfer_bill_information,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_user_notification AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS uuid,
    CAST(NULL AS STRING) AS effective_date,
    CAST(NULL AS STRING) AS management_id,
    CAST(NULL AS STRING) AS internal_user_id,
    CAST(NULL AS STRING) AS legal_entity_id,
    CAST(NULL AS STRING) AS created_on,
    CAST(NULL AS STRING) AS severity_level,
    CAST(NULL AS TINYINT) AS target_group_code,
    CAST(NULL AS STRING) AS title,
    CAST(NULL AS STRING) AS message,
    CAST(NULL AS STRING) AS link,
    CAST(NULL AS STRING) AS valid_from,
    CAST(NULL AS STRING) AS expires_on,
    CAST(NULL AS STRING) AS origin,
    CAST(NULL AS STRING) AS where_to,
    CAST(NULL AS STRING) AS additions,
    CAST(NULL AS STRING) AS route_data,
    CAST(NULL AS STRING) AS service_agreement_id,
    CAST(NULL AS TINYINT) AS acknowledgement_code,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_voucher AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS voucher_code,
    CAST(NULL AS STRING) AS service_type_code,
    CAST(NULL AS STRING) AS discount_type,
    CAST(NULL AS INT) AS discount_price,
    CAST(NULL AS INT) AS discount_percentage,
    CAST(NULL AS INT) AS max_discount,
    CAST(NULL AS INT) AS min_price_acceptable,
    CAST(NULL AS STRING) AS refund_liability_account,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_voucher_campaign AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS voucher_campaign_code,
    CAST(NULL AS STRING) AS voucher_campaign_description,
    CAST(NULL AS INT) AS max_quantity_use_voucher,
    CAST(NULL AS INT) AS current_used_voucher,
    CAST(NULL AS INT) AS budget_limit,
    CAST(NULL AS INT) AS time_pending_refund,
    CAST(NULL AS STRING) AS effect_date,
    CAST(NULL AS STRING) AS end_effect_date,
    CAST(NULL AS STRING) AS voucher_id,
    CAST(NULL AS STRING) AS voucher_user_group_id,
    CAST(NULL AS INT) AS number_generated,
    CAST(NULL AS INT) AS current_budget,
    CAST(NULL AS STRING) AS import_status,
    CAST(NULL AS STRING) AS refund_account,
    CAST(NULL AS STRING) AS limit_date,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_omni_voucher_generate AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS id,
    CAST(NULL AS STRING) AS created_at,
    CAST(NULL AS STRING) AS updated_at,
    CAST(NULL AS STRING) AS created_by,
    CAST(NULL AS STRING) AS updated_by,
    CAST(NULL AS STRING) AS voucher_campaign_id,
    CAST(NULL AS STRING) AS cif,
    CAST(NULL AS STRING) AS user_id,
    CAST(NULL AS STRING) AS voucher_serial_code,
    CAST(NULL AS STRING) AS status,
    CAST(NULL AS TINYINT) AS is_show,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

-- ============================================================
-- SOURCE: WAY4
-- ============================================================


CREATE OR REPLACE VIEW v_stg_way4_balance AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS issuing_number,
    CAST(NULL AS DECIMAL(38,10)) AS principal_balance,
    CAST(NULL AS DECIMAL(38,10)) AS instalment_balance,
    CAST(NULL AS DECIMAL(38,10)) AS interest,
    CAST(NULL AS DECIMAL(38,10)) AS ovd_interest,
    CAST(NULL AS DECIMAL(38,10)) AS late_payment_fee,
    CAST(NULL AS DECIMAL(38,10)) AS ovd_late_payment_fee,
    CAST(NULL AS DECIMAL(38,10)) AS credit_balance,
    CAST(NULL AS DECIMAL(38,10)) AS provision_balance,
    CAST(NULL AS DECIMAL(38,10)) AS dlq_value,
    CAST(NULL AS DECIMAL(38,10)) AS debt_level,
    CAST(NULL AS DECIMAL(38,10)) AS debt_level_by_late_date,
    CAST(NULL AS DECIMAL(38,10)) AS late_date,
    CAST(NULL AS DECIMAL(38,10)) AS ovd_date,
    CAST(NULL AS STRING) AS previous_banking_date,
    CAST(NULL AS STRING) AS banking_date,
    CAST(NULL AS DECIMAL(38,10)) AS total_balance,
    CAST(NULL AS DECIMAL(38,10)) AS total_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS dispute,
    CAST(NULL AS STRING) AS processing_date,
    CAST(NULL AS DECIMAL(38,10)) AS principal_sale,
    CAST(NULL AS DECIMAL(38,10)) AS principal_cash,
    CAST(NULL AS DECIMAL(38,10)) AS principal_fee,
    CAST(NULL AS DECIMAL(38,10)) AS principal_instalment,
    CAST(NULL AS DECIMAL(38,10)) AS sale_interest,
    CAST(NULL AS DECIMAL(38,10)) AS cash_interest,
    CAST(NULL AS STRING) AS branch,
    CAST(NULL AS DECIMAL(38,10)) AS past_due_balance,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract_id,
    CAST(NULL AS DECIMAL(38,10)) AS long_instalment_balance,
    CAST(NULL AS DECIMAL(38,10)) AS short_instalment_balance,
    CAST(NULL AS DECIMAL(38,10)) AS medium_instalment_balance,
    CAST(NULL AS DECIMAL(38,10)) AS savings_balance,
    CAST(NULL AS DECIMAL(38,10)) AS fixed_term_balance,
    CAST(NULL AS DECIMAL(38,10)) AS flexible_term_balance,
    CAST(NULL AS DECIMAL(10,0)) AS grace_ind,
    CAST(NULL AS DECIMAL(10,0)) AS provision_ind,
    CAST(NULL AS DECIMAL(38,10)) AS accrued_interest,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_billing AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS issuing_number,
    CAST(NULL AS DECIMAL(38,10)) AS credit_limit,
    CAST(NULL AS DECIMAL(38,10)) AS instalment_balance,
    CAST(NULL AS STRING) AS billing_date,
    CAST(NULL AS STRING) AS due_date,
    CAST(NULL AS DECIMAL(38,10)) AS total_balance,
    CAST(NULL AS DECIMAL(38,10)) AS due_amount,
    CAST(NULL AS DECIMAL(38,10)) AS debit_amount,
    CAST(NULL AS DECIMAL(38,10)) AS credit_amount,
    CAST(NULL AS DECIMAL(38,10)) AS fee_amount,
    CAST(NULL AS DECIMAL(38,10)) AS interest_amount,
    CAST(NULL AS DECIMAL(38,10)) AS instalment_amount,
    CAST(NULL AS STRING) AS processing_date,
    CAST(NULL AS DECIMAL(38,10)) AS instalment_creation,
    CAST(NULL AS STRING) AS banking_date,
    CAST(NULL AS STRING) AS email_status,
    CAST(NULL AS STRING) AS postal_status,
    CAST(NULL AS STRING) AS send_date,
    CAST(NULL AS STRING) AS sms_status,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract_id,
    CAST(NULL AS STRING) AS generate_status,
    CAST(NULL AS DECIMAL(38,10)) AS row_number,
    CAST(NULL AS STRING) AS provision_ind,
    CAST(NULL AS STRING) AS sent_sms_date,
    CAST(NULL AS STRING) AS sent_email_date,
    CAST(NULL AS STRING) AS sent_postal_date,
    CAST(NULL AS STRING) AS send_ind,
    CAST(NULL AS STRING) AS generated_date,
    CAST(NULL AS STRING) AS issuing_status_code,
    CAST(NULL AS DECIMAL(38,10)) AS opening_balance,
    CAST(NULL AS STRING) AS delivery_type,
    CAST(NULL AS DECIMAL(38,10)) AS suspended_interest_amount,
    CAST(NULL AS DECIMAL(38,10)) AS deposit_interest_amount,
    CAST(NULL AS DECIMAL(38,10)) AS ovd_interest_amount,
    CAST(NULL AS DECIMAL(38,10)) AS transit_interest_amount,
    CAST(NULL AS STRING) AS receive_email,
    CAST(NULL AS STRING) AS receive_sms,
    CAST(NULL AS STRING) AS url_ind,
    CAST(NULL AS STRING) AS sent_noti_date,
    CAST(NULL AS STRING) AS noti_status,
    CAST(NULL AS STRING) AS receive_noti,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_account_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS group_name,
    CAST(NULL AS STRING) AS pcat,
    CAST(NULL AS STRING) AS acat,
    CAST(NULL AS STRING) AS is_am_available,
    CAST(NULL AS STRING) AS due_type,
    CAST(NULL AS DECIMAL(38,10)) AS charge_for_open,
    CAST(NULL AS DECIMAL(38,10)) AS send_credit_to,
    CAST(NULL AS DECIMAL(38,10)) AS send_debit_to,
    CAST(NULL AS DECIMAL(38,10)) AS payment_priority,
    CAST(NULL AS STRING) AS account_status,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_acnt_contract AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS pcat,
    CAST(NULL AS STRING) AS con_cat,
    CAST(NULL AS STRING) AS terminal_category,
    CAST(NULL AS STRING) AS ccat,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS STRING) AS branch,
    CAST(NULL AS STRING) AS service_group,
    CAST(NULL AS STRING) AS contract_number,
    CAST(NULL AS STRING) AS base_relation,
    CAST(NULL AS STRING) AS contract_name,
    CAST(NULL AS STRING) AS comment_text,
    CAST(NULL AS STRING) AS relation_tag,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__id,
    CAST(NULL AS DECIMAL(38,10)) AS contr_type,
    CAST(NULL AS DECIMAL(38,10)) AS contr_subtype__id,
    CAST(NULL AS DECIMAL(38,10)) AS serv_pack__id,
    CAST(NULL AS DECIMAL(38,10)) AS acc_scheme__id,
    CAST(NULL AS DECIMAL(38,10)) AS old_pack,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS DECIMAL(38,10)) AS old_scheme,
    CAST(NULL AS STRING) AS product,
    CAST(NULL AS STRING) AS parent_product,
    CAST(NULL AS STRING) AS product_prev,
    CAST(NULL AS DECIMAL(38,10)) AS main_product,
    CAST(NULL AS STRING) AS liab_category,
    CAST(NULL AS DECIMAL(38,10)) AS client__id,
    CAST(NULL AS DECIMAL(38,10)) AS client_type,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__oid,
    CAST(NULL AS DECIMAL(38,10)) AS liab_contract,
    CAST(NULL AS DECIMAL(38,10)) AS liab_contract_prev,
    CAST(NULL AS DECIMAL(38,10)) AS billing_contract,
    CAST(NULL AS DECIMAL(38,10)) AS behavior_group,
    CAST(NULL AS DECIMAL(38,10)) AS behavior_type,
    CAST(NULL AS DECIMAL(38,10)) AS behavior_type_prev,
    CAST(NULL AS STRING) AS check_available,
    CAST(NULL AS STRING) AS check_usage,
    CAST(NULL AS STRING) AS curr,
    CAST(NULL AS STRING) AS old_curr,
    CAST(NULL AS DECIMAL(38,10)) AS auth_limit_amount,
    CAST(NULL AS DECIMAL(38,10)) AS base_auth_limit,
    CAST(NULL AS DECIMAL(38,10)) AS liab_balance,
    CAST(NULL AS DECIMAL(38,10)) AS liab_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS own_balance,
    CAST(NULL AS DECIMAL(38,10)) AS own_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS sub_balance,
    CAST(NULL AS DECIMAL(38,10)) AS sub_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS total_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS total_balance,
    CAST(NULL AS DECIMAL(38,10)) AS shared_balance,
    CAST(NULL AS DECIMAL(38,10)) AS shared_blocked,
    CAST(NULL AS DECIMAL(38,10)) AS amount_available,
    CAST(NULL AS STRING) AS date_open,
    CAST(NULL AS STRING) AS date_expire,
    CAST(NULL AS STRING) AS last_billing_date,
    CAST(NULL AS STRING) AS next_billing_date,
    CAST(NULL AS STRING) AS last_scan,
    CAST(NULL AS STRING) AS card_expire,
    CAST(NULL AS STRING) AS production_status,
    CAST(NULL AS STRING) AS rbs_member_id,
    CAST(NULL AS STRING) AS rbs_number,
    CAST(NULL AS DECIMAL(38,10)) AS report_type,
    CAST(NULL AS DECIMAL(38,10)) AS max_pin_attempts,
    CAST(NULL AS DECIMAL(38,10)) AS pin_attempts,
    CAST(NULL AS DECIMAL(38,10)) AS risk_scheme,
    CAST(NULL AS DECIMAL(38,10)) AS chip_scheme,
    CAST(NULL AS DECIMAL(38,10)) AS risk_factor,
    CAST(NULL AS DECIMAL(38,10)) AS risk_factor_prev,
    CAST(NULL AS DECIMAL(38,10)) AS contr_status,
    CAST(NULL AS STRING) AS merchant_id,
    CAST(NULL AS DECIMAL(38,10)) AS tr_title,
    CAST(NULL AS STRING) AS tr_company,
    CAST(NULL AS STRING) AS tr_country,
    CAST(NULL AS STRING) AS tr_first_nam,
    CAST(NULL AS STRING) AS tr_last_nam,
    CAST(NULL AS STRING) AS tr_sic,
    CAST(NULL AS STRING) AS add_info_01,
    CAST(NULL AS STRING) AS add_info_02,
    CAST(NULL AS STRING) AS add_info_03,
    CAST(NULL AS STRING) AS add_info_04,
    CAST(NULL AS STRING) AS contract_level,
    CAST(NULL AS STRING) AS ext_data,
    CAST(NULL AS STRING) AS report_address,
    CAST(NULL AS STRING) AS share_balance,
    CAST(NULL AS STRING) AS is_multycurrency,
    CAST(NULL AS STRING) AS enables_item,
    CAST(NULL AS DECIMAL(38,10)) AS cycle_length,
    CAST(NULL AS STRING) AS interval_type,
    CAST(NULL AS STRING) AS status_category,
    CAST(NULL AS STRING) AS limit_is_active,
    CAST(NULL AS STRING) AS routing_idt,
    CAST(NULL AS STRING) AS is_ready,
    CAST(NULL AS DECIMAL(38,10)) AS auth_seq_n,
    CAST(NULL AS STRING) AS apply_dt,
    CAST(NULL AS DECIMAL(38,10)) AS local_version,
    CAST(NULL AS DECIMAL(38,10)) AS remote_version,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS data_date,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_acq_dev_cycle AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS device_rec__oid,
    CAST(NULL AS STRING) AS device_name,
    CAST(NULL AS STRING) AS cycle_type,
    CAST(NULL AS DECIMAL(38,10)) AS cycle_number,
    CAST(NULL AS STRING) AS cycle_code,
    CAST(NULL AS STRING) AS date_from,
    CAST(NULL AS STRING) AS date_to,
    CAST(NULL AS DECIMAL(38,10)) AS card_retained,
    CAST(NULL AS STRING) AS cycle_event,
    CAST(NULL AS DECIMAL(38,10)) AS state_version,
    CAST(NULL AS DECIMAL(38,10)) AS repl_cycle,
    CAST(NULL AS STRING) AS repl_cycle_event,
    CAST(NULL AS DECIMAL(38,10)) AS merchant_card_cont,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_appl_product AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS code_2,
    CAST(NULL AS STRING) AS code_3,
    CAST(NULL AS STRING) AS internal_code,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS STRING) AS ccat,
    CAST(NULL AS DECIMAL(38,10)) AS client_type,
    CAST(NULL AS STRING) AS pcat,
    CAST(NULL AS STRING) AS con_cat,
    CAST(NULL AS DECIMAL(38,10)) AS contr_type,
    CAST(NULL AS DECIMAL(38,10)) AS contr_subtype,
    CAST(NULL AS STRING) AS base_relation,
    CAST(NULL AS STRING) AS check_available,
    CAST(NULL AS STRING) AS check_usage,
    CAST(NULL AS STRING) AS liab_category,
    CAST(NULL AS DECIMAL(38,10)) AS acc_scheme,
    CAST(NULL AS DECIMAL(38,10)) AS max_credit_limit,
    CAST(NULL AS DECIMAL(38,10)) AS min_credit_limit,
    CAST(NULL AS DECIMAL(38,10)) AS default_credit_limit,
    CAST(NULL AS DECIMAL(38,10)) AS report_type,
    CAST(NULL AS DECIMAL(38,10)) AS serv_pack_type,
    CAST(NULL AS DECIMAL(38,10)) AS service_pack,
    CAST(NULL AS DECIMAL(38,10)) AS scoring_model,
    CAST(NULL AS DECIMAL(38,10)) AS tariff_domain,
    CAST(NULL AS DECIMAL(38,10)) AS tariff_domain_template,
    CAST(NULL AS DECIMAL(38,10)) AS copy_from_product,
    CAST(NULL AS DECIMAL(38,10)) AS base_product,
    CAST(NULL AS STRING) AS custom_data,
    CAST(NULL AS STRING) AS is_active,
    CAST(NULL AS STRING) AS date_from,
    CAST(NULL AS STRING) AS date_to,
    CAST(NULL AS DECIMAL(38,10)) AS n_contracts,
    CAST(NULL AS DECIMAL(38,10)) AS appl_product__oid,
    CAST(NULL AS STRING) AS parent_code,
    CAST(NULL AS DECIMAL(38,10)) AS reporting_product,
    CAST(NULL AS DECIMAL(38,10)) AS main_product,
    CAST(NULL AS DECIMAL(38,10)) AS appl_pr_group__id,
    CAST(NULL AS STRING) AS product_group,
    CAST(NULL AS STRING) AS product_status,
    CAST(NULL AS STRING) AS contract_role,
    CAST(NULL AS STRING) AS icon,
    CAST(NULL AS DECIMAL(38,10)) AS product_template,
    CAST(NULL AS DECIMAL(38,10)) AS date_scheme,
    CAST(NULL AS STRING) AS is_ready,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_billing_log AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS cycle_n,
    CAST(NULL AS STRING) AS grace_date,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__oid,
    CAST(NULL AS STRING) AS finish_billing_date,
    CAST(NULL AS DECIMAL(38,10)) AS total_balance,
    CAST(NULL AS DECIMAL(38,10)) AS credit_limit,
    CAST(NULL AS STRING) AS due_date,
    CAST(NULL AS DECIMAL(38,10)) AS acc_scheme,
    CAST(NULL AS DECIMAL(38,10)) AS beh_type,
    CAST(NULL AS DECIMAL(38,10)) AS serv_pack,
    CAST(NULL AS DECIMAL(38,10)) AS total_due,
    CAST(NULL AS DECIMAL(38,10)) AS statement_balance,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS start_billing_date,
    CAST(NULL AS STRING) AS bal_list,
    CAST(NULL AS STRING) AS curr,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_billing_log_information,
    CAST(NULL AS STRING) AS hashdiff_billing_log_cycle,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp

WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_client AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS is_ready,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS STRING) AS branch,
    CAST(NULL AS STRING) AS ccat,
    CAST(NULL AS DECIMAL(38,10)) AS clt,
    CAST(NULL AS STRING) AS pcat,
    CAST(NULL AS STRING) AS service_group,
    CAST(NULL AS STRING) AS short_name,
    CAST(NULL AS STRING) AS title,
    CAST(NULL AS STRING) AS salutation_suffix,
    CAST(NULL AS STRING) AS first_nam,
    CAST(NULL AS STRING) AS last_nam,
    CAST(NULL AS STRING) AS father_s_nam,
    CAST(NULL AS STRING) AS birth_nam,
    CAST(NULL AS STRING) AS mother_s_nam,
    CAST(NULL AS STRING) AS birth_date,
    CAST(NULL AS STRING) AS birth_place,
    CAST(NULL AS STRING) AS gender,
    CAST(NULL AS STRING) AS enable_affiliation,
    CAST(NULL AS STRING) AS affiliation_type,
    CAST(NULL AS STRING) AS affiliated_with,
    CAST(NULL AS STRING) AS marital_status,
    CAST(NULL AS STRING) AS company_nam,
    CAST(NULL AS STRING) AS trade_nam,
    CAST(NULL AS STRING) AS company_department,
    CAST(NULL AS STRING) AS client_number,
    CAST(NULL AS STRING) AS reg_number_type,
    CAST(NULL AS STRING) AS reg_number,
    CAST(NULL AS STRING) AS reg_details,
    CAST(NULL AS STRING) AS itn,
    CAST(NULL AS STRING) AS social_number,
    CAST(NULL AS STRING) AS tax_position,
    CAST(NULL AS STRING) AS profession,
    CAST(NULL AS DECIMAL(38,10)) AS language,
    CAST(NULL AS STRING) AS citizenship,
    CAST(NULL AS STRING) AS date_expire,
    CAST(NULL AS STRING) AS date_open,
    CAST(NULL AS DECIMAL(38,10)) AS tr_title,
    CAST(NULL AS STRING) AS tr_first_nam,
    CAST(NULL AS STRING) AS tr_last_nam,
    CAST(NULL AS STRING) AS country,
    CAST(NULL AS STRING) AS address_zip,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS address_line_1,
    CAST(NULL AS STRING) AS address_line_2,
    CAST(NULL AS STRING) AS address_line_3,
    CAST(NULL AS STRING) AS address_line_4,
    CAST(NULL AS STRING) AS phone,
    CAST(NULL AS STRING) AS phone_h,
    CAST(NULL AS STRING) AS phone_m,
    CAST(NULL AS STRING) AS fax,
    CAST(NULL AS STRING) AS fax_h,
    CAST(NULL AS STRING) AS e_mail,
    CAST(NULL AS STRING) AS url,
    CAST(NULL AS DECIMAL(38,10)) AS delivery_type,
    CAST(NULL AS STRING) AS tr_company_nam,
    CAST(NULL AS STRING) AS add_date_01,
    CAST(NULL AS STRING) AS add_date_02,
    CAST(NULL AS STRING) AS add_info_01,
    CAST(NULL AS STRING) AS add_info_02,
    CAST(NULL AS STRING) AS add_info_03,
    CAST(NULL AS STRING) AS add_info_04,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_client_information,
    CAST(NULL AS STRING) AS hashdiff_client_add_data,
    CAST(NULL AS STRING) AS hashdiff_client_classification,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_client_address AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS client__oid,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__oid,
    CAST(NULL AS STRING) AS parent_address,
    CAST(NULL AS STRING) AS address_type,
    CAST(NULL AS STRING) AS address_name,
    CAST(NULL AS STRING) AS copy_to_address,
    CAST(NULL AS STRING) AS title,
    CAST(NULL AS STRING) AS salutation_suffix,
    CAST(NULL AS STRING) AS first_nam,
    CAST(NULL AS STRING) AS last_nam,
    CAST(NULL AS STRING) AS birth_nam,
    CAST(NULL AS DECIMAL(38,10)) AS language,
    CAST(NULL AS STRING) AS country,
    CAST(NULL AS STRING) AS address_zip,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS municipality_code,
    CAST(NULL AS STRING) AS location,
    CAST(NULL AS STRING) AS address_line_1,
    CAST(NULL AS STRING) AS address_line_2,
    CAST(NULL AS STRING) AS address_line_3,
    CAST(NULL AS STRING) AS address_line_4,
    CAST(NULL AS STRING) AS zip_code,
    CAST(NULL AS STRING) AS phone,
    CAST(NULL AS STRING) AS phone_h,
    CAST(NULL AS STRING) AS phone_m,
    CAST(NULL AS STRING) AS fax,
    CAST(NULL AS STRING) AS fax_h,
    CAST(NULL AS STRING) AS e_mail,
    CAST(NULL AS STRING) AS url,
    CAST(NULL AS DECIMAL(38,10)) AS delivery_type,
    CAST(NULL AS STRING) AS add_info,
    CAST(NULL AS STRING) AS date_to,
    CAST(NULL AS STRING) AS date_from,
    CAST(NULL AS STRING) AS is_active,
    CAST(NULL AS STRING) AS is_ready,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_client_address,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp

WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_contr_status AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS con_cat,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS external_code,
    CAST(NULL AS STRING) AS is_valid,
    CAST(NULL AS STRING) AS action_type,
    CAST(NULL AS STRING) AS restriction_code,
    CAST(NULL AS STRING) AS priority_code,
    CAST(NULL AS STRING) AS fraud_type,
    CAST(NULL AS DECIMAL(38,10)) AS auth_rc,
    CAST(NULL AS STRING) AS code_parms,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_cs_status_log AS
SELECT
    CAST(NULL AS STRING) AS hashkey,

    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS client__oid,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__oid,
    CAST(NULL AS DECIMAL(38,10)) AS td_cons__oid,
    CAST(NULL AS STRING) AS event_action,
    CAST(NULL AS STRING) AS event_code,
    CAST(NULL AS DECIMAL(38,10)) AS officer,
    CAST(NULL AS STRING) AS status_date,
    CAST(NULL AS STRING) AS bank_date,
    CAST(NULL AS STRING) AS bank_date_to,
    CAST(NULL AS STRING) AS start_local_date,
    CAST(NULL AS STRING) AS end_local_date,
    CAST(NULL AS DECIMAL(38,10)) AS status_type,
    CAST(NULL AS DECIMAL(38,10)) AS status_value,
    CAST(NULL AS DECIMAL(38,10)) AS status_value_prev,
    CAST(NULL AS STRING) AS value_extension,
    CAST(NULL AS DECIMAL(38,10)) AS usage_action,
    CAST(NULL AS STRING) AS usage_object,
    CAST(NULL AS STRING) AS is_active,
    CAST(NULL AS STRING) AS descript,
    CAST(NULL AS STRING) AS ext_data,
    CAST(NULL AS DECIMAL(38,10)) AS storno_plan,
    CAST(NULL AS DECIMAL(38,10)) AS cre_by_storno_plan,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_account_contract_cs_status_log,
    CAST(NULL AS STRING) AS hashdiff_device_cs_status_log,
    CAST(NULL AS STRING) AS hashdiff_client_cs_status_log,
    CAST(NULL AS STRING) AS hashdiff_liability_contract_cs_status_log,
    CAST(NULL AS STRING) AS hashdiff_card_cs_status_log,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_cs_status_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS group_code,
    CAST(NULL AS DECIMAL(38,10)) AS default_value,
    CAST(NULL AS STRING) AS applies_to,
    CAST(NULL AS STRING) AS pcat,
    CAST(NULL AS STRING) AS con_cat,
    CAST(NULL AS STRING) AS ccat,
    CAST(NULL AS STRING) AS status_category,
    CAST(NULL AS STRING) AS log_flag,
    CAST(NULL AS STRING) AS is_primary,
    CAST(NULL AS STRING) AS on_off_mode,
    CAST(NULL AS STRING) AS domain_code,
    CAST(NULL AS DECIMAL(38,10)) AS domain_type__id,
    CAST(NULL AS STRING) AS add_info,
    CAST(NULL AS STRING) AS is_ready,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp

WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_cs_status_value AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS cs_status_type__oid,
    CAST(NULL AS STRING) AS status_type_code,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS is_ok,
    CAST(NULL AS STRING) AS result_event_code,
    CAST(NULL AS DECIMAL(38,10)) AS severity_level,
    CAST(NULL AS STRING) AS to_rules,
    CAST(NULL AS STRING) AS from_rules,
    CAST(NULL AS STRING) AS add_info,
    CAST(NULL AS STRING) AS is_active,
    CAST(NULL AS STRING) AS date_from,
    CAST(NULL AS STRING) AS date_to,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_device_rec AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__oid,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS STRING) AS terminal_id,
    CAST(NULL AS STRING) AS term_cat,
    CAST(NULL AS DECIMAL(38,10)) AS device_type__id,
    CAST(NULL AS STRING) AS transaction_class,
    CAST(NULL AS STRING) AS curr,
    CAST(NULL AS STRING) AS device_name,
    CAST(NULL AS DECIMAL(38,10)) AS gmt_offset,
    CAST(NULL AS STRING) AS time_from,
    CAST(NULL AS STRING) AS time_to,
    CAST(NULL AS STRING) AS working_time,
    CAST(NULL AS STRING) AS cut_off_time,
    CAST(NULL AS DECIMAL(38,10)) AS global_limit,
    CAST(NULL AS DECIMAL(38,10)) AS coin_limit,
    CAST(NULL AS DECIMAL(38,10)) AS configuration,
    CAST(NULL AS DECIMAL(38,10)) AS denom_dict,
    CAST(NULL AS STRING) AS data_capt_reg,
    CAST(NULL AS STRING) AS device_url,
    CAST(NULL AS DECIMAL(38,10)) AS key_hierarchy,
    CAST(NULL AS STRING) AS location,
    CAST(NULL AS STRING) AS mac_status,
    CAST(NULL AS STRING) AS pin_prevalidation,
    CAST(NULL AS STRING) AS protocol,
    CAST(NULL AS STRING) AS service_group,
    CAST(NULL AS STRING) AS serial_number,
    CAST(NULL AS STRING) AS socket,
    CAST(NULL AS STRING) AS x_25_address,
    CAST(NULL AS DECIMAL(38,10)) AS hardware__id,
    CAST(NULL AS STRING) AS member_id,
    CAST(NULL AS STRING) AS merchant_id,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS trans_location,
    CAST(NULL AS STRING) AS phone,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_device_information,
    CAST(NULL AS STRING) AS hashdiff_device_limit,
    CAST(NULL AS STRING) AS hashdiff_device_time,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_doc AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS posting_status,
    CAST(NULL AS STRING) AS outward_status,
    CAST(NULL AS DECIMAL(38,10)) AS return_code,
    CAST(NULL AS STRING) AS add_info,
    CAST(NULL AS DECIMAL(38,10)) AS change_version,
    CAST(NULL AS STRING) AS partition_key,
    CAST(NULL AS STRING) AS synch_tag,
    CAST(NULL AS STRING) AS target_country,
    CAST(NULL AS STRING) AS rec_date,
    CAST(NULL AS STRING) AS comment_text,
    CAST(NULL AS DECIMAL(38,10)) AS doc__chain__id,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS doc__orig__id,
    CAST(NULL AS DECIMAL(38,10)) AS doc__prev__id,
    CAST(NULL AS DECIMAL(38,10)) AS doc__summ__id,
    CAST(NULL AS DECIMAL(38,10)) AS number_of_sub_s,
    CAST(NULL AS DECIMAL(38,10)) AS number_in_chain,
    CAST(NULL AS STRING) AS action,
    CAST(NULL AS STRING) AS message_category,
    CAST(NULL AS STRING) AS source_reg_num,
    CAST(NULL AS STRING) AS acq_ref_number,
    CAST(NULL AS STRING) AS ret_ref_number,
    CAST(NULL AS STRING) AS iss_ref_number,
    CAST(NULL AS STRING) AS ps_ref_number,
    CAST(NULL AS STRING) AS nw_ref_date,
    CAST(NULL AS STRING) AS auth_code,
    CAST(NULL AS STRING) AS is_authorization,
    CAST(NULL AS STRING) AS request_category,
    CAST(NULL AS STRING) AS service_class,
    CAST(NULL AS STRING) AS source_code,
    CAST(NULL AS STRING) AS source_fee_code,
    CAST(NULL AS STRING) AS target_code,
    CAST(NULL AS STRING) AS target_fee_code,
    CAST(NULL AS DECIMAL(38,10)) AS trans_type,
    CAST(NULL AS STRING) AS source_channel,
    CAST(NULL AS STRING) AS s_cat,
    CAST(NULL AS STRING) AS source_idt_scheme,
    CAST(NULL AS STRING) AS source_member_id,
    CAST(NULL AS STRING) AS rec_member_id,
    CAST(NULL AS STRING) AS source_number,
    CAST(NULL AS STRING) AS source_spc,
    CAST(NULL AS STRING) AS source_acc_type,
    CAST(NULL AS DECIMAL(38,10)) AS source_contract,
    CAST(NULL AS DECIMAL(38,10)) AS source_service,
    CAST(NULL AS STRING) AS target_channel,
    CAST(NULL AS STRING) AS t_cat,
    CAST(NULL AS STRING) AS target_idt_scheme,
    CAST(NULL AS STRING) AS target_member_id,
    CAST(NULL AS STRING) AS send_member_id,
    CAST(NULL AS STRING) AS sending_bin,
    CAST(NULL AS DECIMAL(38,10)) AS target_bin_id,
    CAST(NULL AS STRING) AS target_number,
    CAST(NULL AS STRING) AS target_spc,
    CAST(NULL AS STRING) AS target_acc_type,
    CAST(NULL AS DECIMAL(38,10)) AS target_contract,
    CAST(NULL AS DECIMAL(38,10)) AS target_service,
    CAST(NULL AS STRING) AS card_expire,
    CAST(NULL AS STRING) AS card_seqv_number,
    CAST(NULL AS STRING) AS merchant_id,
    CAST(NULL AS STRING) AS sic_code,
    CAST(NULL AS STRING) AS trans_condition,
    CAST(NULL AS DECIMAL(38,10)) AS trans_cond_attr,
    CAST(NULL AS DECIMAL(38,10)) AS sec_trans_cond_att,
    CAST(NULL AS STRING) AS recons_curr,
    CAST(NULL AS DECIMAL(38,10)) AS recons_amount,
    CAST(NULL AS STRING) AS settl_curr,
    CAST(NULL AS DECIMAL(38,10)) AS settl_amount,
    CAST(NULL AS STRING) AS source_fee_curr,
    CAST(NULL AS DECIMAL(38,10)) AS source_fee_amount,
    CAST(NULL AS STRING) AS target_fee_curr,
    CAST(NULL AS DECIMAL(38,10)) AS target_fee_amount,
    CAST(NULL AS STRING) AS trans_date,
    CAST(NULL AS STRING) AS sec_trans_date,
    CAST(NULL AS STRING) AS trans_country,
    CAST(NULL AS STRING) AS trans_state,
    CAST(NULL AS STRING) AS trans_city,
    CAST(NULL AS STRING) AS trans_details,
    CAST(NULL AS DECIMAL(38,10)) AS trans_amount,
    CAST(NULL AS STRING) AS trans_curr,
    CAST(NULL AS DECIMAL(38,10)) AS bin_record,
    CAST(NULL AS STRING) AS reason_code,
    CAST(NULL AS STRING) AS reason_details,
    CAST(NULL AS STRING) AS requirement,
    CAST(NULL AS STRING) AS posting_date,
    CAST(NULL AS STRING) AS fx_settl_date,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_document_classification,
    CAST(NULL AS STRING) AS hashdiff_document_description,
    CAST(NULL AS STRING) AS hashdiff_document_identifiers,
    CAST(NULL AS STRING) AS hashdiff_document_source,
    CAST(NULL AS STRING) AS hashdiff_document_target,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_entry AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS item__id,
    CAST(NULL AS STRING) AS n_c,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract__id,
    CAST(NULL AS DECIMAL(38,10)) AS m_transaction__id,
    CAST(NULL AS DECIMAL(38,10)) AS due_mtr_id,
    CAST(NULL AS DECIMAL(38,10)) AS service_id,
    CAST(NULL AS DECIMAL(38,10)) AS tariff_id,
    CAST(NULL AS DECIMAL(38,10)) AS doc_id,
    CAST(NULL AS DECIMAL(38,10)) AS contract_for,
    CAST(NULL AS DECIMAL(38,10)) AS amount,
    CAST(NULL AS DECIMAL(38,10)) AS fee_amount,
    CAST(NULL AS DECIMAL(38,10)) AS balance,
    CAST(NULL AS DECIMAL(38,10)) AS interest_factor,
    CAST(NULL AS STRING) AS is_reversed,
    CAST(NULL AS STRING) AS local_date,
    CAST(NULL AS STRING) AS posting_date,
    CAST(NULL AS STRING) AS request_cat,
    CAST(NULL AS STRING) AS service_class,
    CAST(NULL AS STRING) AS auth_code,
    CAST(NULL AS DECIMAL(38,10)) AS trans_amount,
    CAST(NULL AS STRING) AS trans_city,
    CAST(NULL AS STRING) AS trans_code,
    CAST(NULL AS STRING) AS trans_country,
    CAST(NULL AS STRING) AS trans_curr,
    CAST(NULL AS STRING) AS trans_date,
    CAST(NULL AS STRING) AS trans_details,
    CAST(NULL AS DECIMAL(38,10)) AS analytic_item__id,
    CAST(NULL AS STRING) AS partition_key,
    CAST(NULL AS STRING) AS entry_level_type,
    CAST(NULL AS DECIMAL(38,10)) AS top_entry_id,
    CAST(NULL AS DECIMAL(38,10)) AS storno_plan,
    CAST(NULL AS DECIMAL(38,10)) AS cre_by_storno_plan,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_entry_information,
    CAST(NULL AS STRING) AS hashdiff_entry_amount,
    CAST(NULL AS STRING) AS hashdiff_entry_trans_detail,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_m_transaction AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS posting_date,
    CAST(NULL AS STRING) AS local_date,
    CAST(NULL AS STRING) AS due_date,
    CAST(NULL AS STRING) AS posting_db_date,
    CAST(NULL AS DECIMAL(38,10)) AS portion,
    CAST(NULL AS STRING) AS posting_status,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS STRING) AS entry_type,
    CAST(NULL AS STRING) AS request_cat,
    CAST(NULL AS STRING) AS service_class,
    CAST(NULL AS DECIMAL(38,10)) AS trans_subtype,
    CAST(NULL AS DECIMAL(38,10)) AS direction,
    CAST(NULL AS STRING) AS trans_code,
    CAST(NULL AS STRING) AS trans_curr,
    CAST(NULL AS DECIMAL(38,10)) AS trans_amount,
    CAST(NULL AS DECIMAL(38,10)) AS fx_seqv_n,
    CAST(NULL AS DECIMAL(38,10)) AS local_amount,
    CAST(NULL AS DECIMAL(38,10)) AS source_account,
    CAST(NULL AS DECIMAL(38,10)) AS s_amount,
    CAST(NULL AS DECIMAL(38,10)) AS s_fee_amount,
    CAST(NULL AS STRING) AS source_code,
    CAST(NULL AS DECIMAL(38,10)) AS source_service,
    CAST(NULL AS DECIMAL(38,10)) AS target_account,
    CAST(NULL AS DECIMAL(38,10)) AS t_amount,
    CAST(NULL AS DECIMAL(38,10)) AS t_fee_amount,
    CAST(NULL AS STRING) AS target_code,
    CAST(NULL AS DECIMAL(38,10)) AS target_service,
    CAST(NULL AS STRING) AS mtr_details,
    CAST(NULL AS DECIMAL(38,10)) AS m_transaction__oid,
    CAST(NULL AS DECIMAL(38,10)) AS doc__oid,
    CAST(NULL AS DECIMAL(38,10)) AS contract,
    CAST(NULL AS STRING) AS partition_key,
    CAST(NULL AS DECIMAL(38,10)) AS hash__id,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_m_transaction_information,
    CAST(NULL AS STRING) AS hashdiff_m_transaction_source,
    CAST(NULL AS STRING) AS hashdiff_m_transaction_target,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_mess_channel AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS contra_channel,
    CAST(NULL AS STRING) AS data_source,
    CAST(NULL AS STRING) AS is_on_us,
    CAST(NULL AS STRING) AS settl_date,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp

WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_payment AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS transaction_date,
    CAST(NULL AS STRING) AS issuing_number,
    CAST(NULL AS STRING) AS card_number,
    CAST(NULL AS DECIMAL(38,10)) AS amount,
    CAST(NULL AS STRING) AS currency,
    CAST(NULL AS STRING) AS source_table,
    CAST(NULL AS DECIMAL(38,10)) AS source_ref_id,
    CAST(NULL AS STRING) AS posting_date,
    CAST(NULL AS DECIMAL(38,10)) AS settlement_amount,
    CAST(NULL AS DECIMAL(38,10)) AS acnt_contract_id,
    CAST(NULL AS DECIMAL(38,10)) AS principal_cash,
    CAST(NULL AS DECIMAL(38,10)) AS principal_sale,
    CAST(NULL AS DECIMAL(38,10)) AS principal_instalment,
    CAST(NULL AS DECIMAL(38,10)) AS principal_fee,
    CAST(NULL AS DECIMAL(38,10)) AS interest,
    CAST(NULL AS DECIMAL(38,10)) AS late_payment_fee,
    CAST(NULL AS DECIMAL(38,10)) AS m_transaction_id,
    CAST(NULL AS DECIMAL(38,10)) AS provision,
    CAST(NULL AS DECIMAL(38,10)) AS trans_subtype,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_payment_information,
    CAST(NULL AS STRING) AS hashdiff_payment_amount,
    CAST(NULL AS STRING) AS hashdiff_payment_principal,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_resp_code AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS DECIMAL(38,10)) AS resp_code,
    CAST(NULL AS STRING) AS resp_text,
    CAST(NULL AS DECIMAL(38,10)) AS resp_level,
    CAST(NULL AS STRING) AS message_code,
    CAST(NULL AS STRING) AS is_status,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp

WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_sic AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS group_code,
    CAST(NULL AS STRING) AS custom_code,
    CAST(NULL AS STRING) AS limit_code,
    CAST(NULL AS DECIMAL(38,10)) AS sic_group_dflt,
    CAST(NULL AS STRING) AS use_in_bank,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_templ_approved AS
SELECT
    CAST(NULL AS STRING) AS hashkey,

    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS account_name,
    CAST(NULL AS STRING) AS account_numeration,
    CAST(NULL AS DECIMAL(38,10)) AS acc_scheme__id,
    CAST(NULL AS DECIMAL(38,10)) AS account_type,
    CAST(NULL AS STRING) AS ageing_tariff,
    CAST(NULL AS DECIMAL(38,10)) AS alt_due_templ,
    CAST(NULL AS DECIMAL(38,10)) AS balance_type,
    CAST(NULL AS STRING) AS calc_when_credit,
    CAST(NULL AS STRING) AS acat,
    CAST(NULL AS DECIMAL(38,10)) AS charge_for_open,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS curr,
    CAST(NULL AS STRING) AS date_from,
    CAST(NULL AS STRING) AS date_to,
    CAST(NULL AS DECIMAL(38,10)) AS due_acc_templ,
    CAST(NULL AS DECIMAL(38,10)) AS due_period,
    CAST(NULL AS STRING) AS due_to_work_day,
    CAST(NULL AS STRING) AS due_type,
    CAST(NULL AS DECIMAL(38,10)) AS event_type,
    CAST(NULL AS STRING) AS fee_rate_regime,
    CAST(NULL AS DECIMAL(38,10)) AS f_i,
    CAST(NULL AS STRING) AS fx_type,
    CAST(NULL AS DECIMAL(38,10)) AS grace_period,
    CAST(NULL AS STRING) AS group_code,
    CAST(NULL AS STRING) AS gl_number,
    CAST(NULL AS STRING) AS hd_gl_number,
    CAST(NULL AS STRING) AS gl_tariff,
    CAST(NULL AS DECIMAL(38,10)) AS int_accrual_acc,
    CAST(NULL AS DECIMAL(38,10)) AS interest_acc_templ,
    CAST(NULL AS STRING) AS interest_algorithm,
    CAST(NULL AS STRING) AS interest_delay,
    CAST(NULL AS DECIMAL(38,10)) AS interest_fee,
    CAST(NULL AS STRING) AS int_fee_account,
    CAST(NULL AS DECIMAL(38,10)) AS interest_fee_type,
    CAST(NULL AS DECIMAL(38,10)) AS interest_rate,
    CAST(NULL AS DECIMAL(38,10)) AS interest_scheme,
    CAST(NULL AS STRING) AS interest_tariff,
    CAST(NULL AS DECIMAL(38,10)) AS int_rev_exp_acc,
    CAST(NULL AS STRING) AS is_active,
    CAST(NULL AS STRING) AS is_am_available,
    CAST(NULL AS DECIMAL(38,10)) AS low_lim_acc_templ,
    CAST(NULL AS DECIMAL(38,10)) AS low_lim_amount,
    CAST(NULL AS DECIMAL(38,10)) AS min_repayment,
    CAST(NULL AS DECIMAL(38,10)) AS min_rq_repayment,
    CAST(NULL AS DECIMAL(38,10)) AS offbalance_xf_acc,
    CAST(NULL AS DECIMAL(38,10)) AS officer,
    CAST(NULL AS DECIMAL(38,10)) AS priority,
    CAST(NULL AS DECIMAL(38,10)) AS ageing_priority,
    CAST(NULL AS DECIMAL(38,10)) AS repayment_percent,
    CAST(NULL AS STRING) AS suppl_cr_account,
    CAST(NULL AS STRING) AS suppl_dr_account,
    CAST(NULL AS DECIMAL(38,10)) AS acc_templ__oid,
    CAST(NULL AS STRING) AS template_details,
    CAST(NULL AS DECIMAL(38,10)) AS upp_lim_acc_templ,
    CAST(NULL AS DECIMAL(38,10)) AS upp_lim_amount,
    CAST(NULL AS STRING) AS use_gl,
    CAST(NULL AS STRING) AS gl_type,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_templ_approved_information,
    CAST(NULL AS STRING) AS hashdiff_templ_approved_repayment,
    CAST(NULL AS STRING) AS hashdiff_templ_approved_interest,
    CAST(NULL AS STRING) AS hashdiff_templ_approved_gl,
    CAST(NULL AS STRING) AS hashdiff_templ_approved_limit,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_trans_cond AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS code,
    CAST(NULL AS STRING) AS term_cat,
    CAST(NULL AS STRING) AS category_code,
    CAST(NULL AS STRING) AS condition_details,
    CAST(NULL AS DECIMAL(38,10)) AS default_condition,
    CAST(NULL AS DECIMAL(38,10)) AS late_condition,
    CAST(NULL AS STRING) AS security_code,
    CAST(NULL AS STRING) AS addendum,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_way4_trans_type AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS amnd_state,
    CAST(NULL AS STRING) AS amnd_date,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_officer,
    CAST(NULL AS DECIMAL(38,10)) AS amnd_prev,
    CAST(NULL AS DECIMAL(38,10)) AS id,
    CAST(NULL AS STRING) AS name,
    CAST(NULL AS STRING) AS service_class,
    CAST(NULL AS STRING) AS s_cat,
    CAST(NULL AS STRING) AS t_cat,
    CAST(NULL AS DECIMAL(38,10)) AS dr_cr,
    CAST(NULL AS STRING) AS is_impersonal,
    CAST(NULL AS STRING) AS is_authorized,
    CAST(NULL AS STRING) AS is_required,
    CAST(NULL AS STRING) AS enable_adjustment,
    CAST(NULL AS STRING) AS enable_reversal,
    CAST(NULL AS STRING) AS enable_request,
    CAST(NULL AS DECIMAL(38,10)) AS prev_trans_type,
    CAST(NULL AS STRING) AS chain_type,
    CAST(NULL AS STRING) AS charge_event,
    CAST(NULL AS STRING) AS dispute_trn_class,
    CAST(NULL AS STRING) AS terminal_category,
    CAST(NULL AS STRING) AS production_type,
    CAST(NULL AS STRING) AS production_event,
    CAST(NULL AS STRING) AS trans_code,
    CAST(NULL AS STRING) AS reversal_code,
    CAST(NULL AS STRING) AS trans_type_idt,
    CAST(NULL AS DECIMAL(38,10)) AS priority,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

-- ============================================================
-- SOURCE: BPM REFERENCE
-- ============================================================

CREATE OR REPLACE VIEW v_stg_bpm_auth_nhom AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS ten_nhom_viet_tat,
    CAST(NULL AS STRING) AS ten_nhom_day_du,
    CAST(NULL AS BIGINT) AS trang_thai,
    CAST(NULL AS STRING) AS ghi_chu,
    CAST(NULL AS BIGINT) AS ocb_hrm_id,
    CAST(NULL AS BIGINT) AS nhom_cap_tren,
    CAST(NULL AS BIGINT) AS search_scope,
    CAST(NULL AS BIGINT) AS nhom_dai_dien,
    CAST(NULL AS BIGINT) AS cap_phe_duyet,
    CAST(NULL AS STRING) AS ma_nhom,
    CAST(NULL AS BIGINT) AS quy_trinh,
    CAST(NULL AS BIGINT) AS cap_do,
    CAST(NULL AS BIGINT) AS cap_do_tim_kiem,
    CAST(NULL AS BIGINT) AS cap_do_ecm,
    CAST(NULL AS BIGINT) AS cap_do_ecm_xlgdtd,
    CAST(NULL AS BIGINT) AS cap_do_ecm_tsbd,
    CAST(NULL AS STRING) AS json_ecm,
    CAST(NULL AS STRING) AS ma_nhom_ten,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_c_danh_muc AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS BIGINT) AS loai_danh_muc,
    CAST(NULL AS STRING) AS ten_danh_muc,
    CAST(NULL AS STRING) AS ghi_chu,
    CAST(NULL AS BIGINT) AS parent_id,
    CAST(NULL AS BIGINT) AS trang_thai,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_danh_muc AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS ma,
    CAST(NULL AS STRING) AS ten,
    CAST(NULL AS BIGINT) AS loai,
    CAST(NULL AS STRING) AS ghi_chu,
    CAST(NULL AS BIGINT) AS stt,
    CAST(NULL AS BIGINT) AS trang_thai,
    CAST(NULL AS BIGINT) AS nguoi_tao,
    CAST(NULL AS STRING) AS ngay_tao,
    CAST(NULL AS BIGINT) AS nguoi_update,
    CAST(NULL AS STRING) AS ngay_update,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_bpm_sk10_san_pham AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS BIGINT) AS id,
    CAST(NULL AS STRING) AS ma_san_pham,
    CAST(NULL AS STRING) AS ten_san_pham,
    CAST(NULL AS STRING) AS phan_nhom_san_pham,
    CAST(NULL AS STRING) AS parent_group,
    CAST(NULL AS STRING) AS hieu_luc_sp,
    CAST(NULL AS STRING) AS ghi_chu,
    CAST(NULL AS STRING) AS category_t24,
    CAST(NULL AS STRING) AS loan_support_t24,
    CAST(NULL AS STRING) AS dieu_kien_t24,
    CAST(NULL AS STRING) AS ngay_tao,
    CAST(NULL AS TIMESTAMP) AS etl_time,
    CAST(NULL AS STRING) AS etl_by,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
