# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;



CREATE OR REPLACE TABLE hub_crm_contact_hist (
    crm_contact_hist_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Contact Hist',
    business_key int COMMENT 'Khóa lịch sử liên hệ CRM – ID tự tăng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_crm_contact_hist ALTER COLUMN crm_contact_hist_hashkey SET NOT NULL;
ALTER TABLE hub_crm_contact_hist ADD CONSTRAINT hub_crm_contact_hist_pk PRIMARY KEY (crm_contact_hist_hashkey);


CREATE OR REPLACE TABLE hub_crm_contact_notes (
    crm_contact_notes_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Contact Notes',
    business_key string COMMENT 'Khóa chiến dịch CRM – ID tự tăng',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_crm_contact_notes ALTER COLUMN crm_contact_notes_hashkey SET NOT NULL;
ALTER TABLE hub_crm_contact_notes ADD CONSTRAINT hub_crm_contact_notes_pk PRIMARY KEY (crm_contact_notes_hashkey);


CREATE OR REPLACE TABLE hub_crm_users (
    crm_users_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Users',
    business_key string COMMENT 'Business key: User ID',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_crm_users ALTER COLUMN crm_users_hashkey SET NOT NULL;
ALTER TABLE hub_crm_users ADD CONSTRAINT hub_crm_users_pk PRIMARY KEY (crm_users_hashkey);


CREATE OR REPLACE TABLE sat_crm_users_information (
    crm_users_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Users',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    user_last_name string COMMENT 'Tên (họ) người dùng',
    user_first_name string COMMENT 'Tên (tên gọi) người dùng',
    user_full_name string COMMENT 'Họ và tên đầy đủ người dùng',
    user_status_id string COMMENT 'Trạng thái tài khoản người dùng',
    date_last_off string COMMENT 'Ngày người dùng offline lần cuối',
    session_id string COMMENT 'Session ID hiện tại của người dùng',
    user_email string COMMENT 'Địa chỉ email người dùng',
    extension string COMMENT 'Số nội bộ (extension) điện thoại bàn',
    language string COMMENT 'Ngôn ngữ giao diện của người dùng',
    user_phone string COMMENT 'Số điện thoại di động người dùng',
    omni string COMMENT 'Flag tích hợp kênh OMNI',
    telext string COMMENT 'Số extension tổng đài SIP của người dùng',
    branch_code string COMMENT 'Mã chi nhánh/đơn vị người dùng thuộc về',
    custgroup string COMMENT 'Mã khối khách hàng người dùng phụ trách',
    func_group string COMMENT 'Nhóm chức năng nghiệp vụ của người dùng',
    account_officer_id string COMMENT 'Định danh account officer liên kết với người dùng',
    job_key string COMMENT 'Mã chức vụ của người dùng',
    nearly_job_title string COMMENT 'Chức danh gần nhất'
) CLUSTER BY AUTO;
ALTER TABLE sat_crm_users_information ALTER COLUMN crm_users_hashkey SET NOT NULL;
ALTER TABLE sat_crm_users_information ADD CONSTRAINT sat_crm_users_information_pk PRIMARY KEY (crm_users_hashkey);


CREATE OR REPLACE TABLE sat_crm_users_other (
    crm_users_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Users',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    is_team_manage string COMMENT 'Flag là quản lý team (Y/N)',
    isactive string COMMENT 'Flag tài khoản đang hoạt động (Y/N)',
    isdeleted string COMMENT 'Flag tài khoản đã bị xóa (Y/N)',
    is_enable_market_place string COMMENT 'Flag bật tính năng marketplace',
    is_lso_sk string COMMENT 'Flag LSO SK',
    is_out_of_line string COMMENT 'Flag out-of-line – ngoài phân cấp hệ thống',
    old_custgroup string COMMENT 'Mã khối cũ trước khi thay đổi',
    old_branch_code string COMMENT 'Mã chi nhánh cũ trước khi thay đổi',
    old_user_full_name string COMMENT 'Họ tên cũ trước khi thay đổi',
    old_account_officer_id string COMMENT 'Account officer ID cũ',
    old_func_group string COMMENT 'Nhóm chức năng cũ',
    old_user_phone string COMMENT 'Số điện thoại cũ',
    old_telext string COMMENT 'Số extension cũ',
    user_created string COMMENT 'User khởi tạo tài khoản',
    date_created string COMMENT 'Ngày tạo tài khoản',
    user_updated string COMMENT 'User cập nhật tài khoản',
    date_updated string COMMENT 'Ngày cập nhật tài khoản',
    user_deleted string COMMENT 'User xóa tài khoản',
    date_deleted string COMMENT 'Ngày xóa tài khoản'
) CLUSTER BY AUTO;
ALTER TABLE sat_crm_users_other ALTER COLUMN crm_users_hashkey SET NOT NULL;
ALTER TABLE sat_crm_users_other ADD CONSTRAINT sat_crm_users_other_pk PRIMARY KEY (crm_users_hashkey);


CREATE OR REPLACE TABLE sat_crm_contact_notes_information (
    crm_contact_notes_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Contact Notes',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    name string COMMENT 'Tên chương trình CRM',
    status string COMMENT 'Trạng thái hiển thị chương trình (YES/NO)',
    date_created string COMMENT 'Ngày tạo chương trình',
    user_created string COMMENT 'User tạo chương trình',
    date_updated string COMMENT 'Ngày cập nhật chương trình',
    user_updated string COMMENT 'User cập nhật chương trình',
    is_imported int COMMENT 'Chương trình được import từ file (1=Yes, 0=No)',
    program_type string COMMENT 'Loại chương trình (Chăm sóc / Bán hàng)',
    program_code string COMMENT 'Mã chương trình',
    is_program_hot int COMMENT 'Flag chương trình HOT – biểu tượng HOT hiển thị trang chủ',
    end_date_program string COMMENT 'Ngày kết thúc chương trình',
    start_date_program string COMMENT 'Ngày bắt đầu chương trình',
    id_product decimal(38,10) COMMENT 'Mã sản phẩm liên kết với chương trình',
    custgroup int COMMENT 'Mã khối khách hàng',
    department string COMMENT 'Phòng ban phụ trách chương trình',
    parent_key string COMMENT 'Thông tin nhóm khối (RB, SME, CIB)',
    file_banner string COMMENT 'Đường dẫn hình ảnh/file banner chương trình',
    file_manual string COMMENT 'Đường dẫn file hướng dẫn tư vấn',
    file_info_prod string COMMENT 'Đường dẫn file thông tin sản phẩm',
    data_type string COMMENT 'Loại dữ liệu (Có liên quan đến CIF / Không liên quan đến CIF)',
    position int COMMENT 'Vị trí ô hiển thị trên màn hình thông báo'
) CLUSTER BY AUTO;
ALTER TABLE sat_crm_contact_notes_information ALTER COLUMN crm_contact_notes_hashkey SET NOT NULL;
ALTER TABLE sat_crm_contact_notes_information ADD CONSTRAINT sat_crm_contact_notes_information_pk PRIMARY KEY (crm_contact_notes_hashkey);


CREATE OR REPLACE TABLE sat_crm_contact_hist_information (
    crm_contact_hist_hashkey string NOT NULL COMMENT 'Hashkey Hub CRM Contact Hist',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    CIF int COMMENT 'Số CIF khách hàng được liên hệ',
    DATE_CONTACT string COMMENT 'Ngày liên hệ thực tế với khách hàng',
    FUNC_GROUP string COMMENT 'Vai trò của nhân viên thực hiện liên hệ',
    BRANCH_CODE string COMMENT 'Mã đơn vị thực hiện liên hệ',
    NOTES string COMMENT 'Ghi chú nội dung liên hệ',
    SOUCRE string COMMENT 'Nguồn dữ liệu đầu vào (lỗi chính tả trong source – giữ nguyên)',
    CONTACT_STATUS_ID int COMMENT 'Mã tình trạng liên hệ',
    CONTACT_TYPE_ID int COMMENT 'Mã hình thức liên hệ',
    CONTACT_RESULT_ID int COMMENT 'Mã kết quả liên hệ',
    CONTACTNOTEID int COMMENT 'Mã chương trình CRM (FK → crm_contact_notes.ID)',
    IMPORT_ID bigint COMMENT 'Mã tự sinh khi import chương trình từ file',
    PROGRAM_NOTYFY_ID int COMMENT 'ID chương trình thông báo',
    SALE_CODE int COMMENT 'Mã bán hàng được nhập tại file import',
    PROMISE_DATE string COMMENT 'Ngày hẹn đóng sản phẩm/khoản vay',
    RECALL_DATE string COMMENT 'Ngày gọi lại theo lịch hẹn',
    CONDITION_DATE string COMMENT 'Ngày tham chiếu điều kiện (đến hạn, sinh nhật KH)',
    REFERENCES_DATE string COMMENT 'Ngày tham chiếu thông tin',
    DIALID string COMMENT 'Mã liên kết CRM ↔ CallCenter (CRM_yyyyMMddHHmmss|ProgramId|User)',
    DATETIME_CREATED timestamp COMMENT 'Thời điểm tạo bản ghi tình trạng liên hệ',
    DATETIME_UPDATED string COMMENT 'Thời gian cập nhật bản ghi (dạng string)',
    USER_CREATED string COMMENT 'User tạo bản ghi tình trạng liên hệ',
    USER_UPDATED string COMMENT 'User cập nhật bản ghi tình trạng liên hệ',
    UPDATE_TIMES decimal(38,10) COMMENT 'Thời gian cập nhật (epoch decimal)'
) CLUSTER BY AUTO;
ALTER TABLE sat_crm_contact_hist_information ALTER COLUMN crm_contact_hist_hashkey SET NOT NULL;
ALTER TABLE sat_crm_contact_hist_information ADD CONSTRAINT sat_crm_contact_hist_information_pk PRIMARY KEY (crm_contact_hist_hashkey);


CREATE OR REPLACE TABLE link_crm_users_dept_acct_officer (
    link_crm_users_dept_acct_officer_hashkey string NOT NULL COMMENT 'Link Hashkey',
    crm_users_hashkey string COMMENT 'FK tới hub_crm_users',
    dept_acct_officer_hashkey string COMMENT 'FK tới hub_acct_officer',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_crm_users_dept_acct_officer ALTER COLUMN link_crm_users_dept_acct_officer_hashkey SET NOT NULL;
ALTER TABLE link_crm_users_dept_acct_officer ADD CONSTRAINT link_crm_users_dept_acct_officer_pk PRIMARY KEY (link_crm_users_dept_acct_officer_hashkey);


CREATE OR REPLACE TABLE link_crm_users_branch (
    link_crm_users_branch_hashkey string NOT NULL COMMENT 'Link Hashkey – MD5(crm_users.USER_ID || crm_users.BRANCH_CODE)',
    crm_users_hashkey string COMMENT 'FK đến hub_crm_users',
    branch_hashkey string COMMENT 'FK đến hub_branch (T24) – mapping qua BRANCH_CODE',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_crm_users_branch ALTER COLUMN link_crm_users_branch_hashkey SET NOT NULL;
ALTER TABLE link_crm_users_branch ADD CONSTRAINT link_crm_users_branch_pk PRIMARY KEY (link_crm_users_branch_hashkey);


CREATE OR REPLACE TABLE link_contact_hist_branch (
    link_contact_hist_branch_hashkey string NOT NULL COMMENT 'Link Hashkey – MD5(crm_contact_hist.ID || crm_contact_hist.BRANCH_CODE)',
    crm_contact_hist_hashkey string COMMENT 'FK đến hub_crm_contact_hist',
    branch_hashkey string COMMENT 'FK đến hub_branch (T24) – mapping qua BRANCH_CODE',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_contact_hist_branch ALTER COLUMN link_contact_hist_branch_hashkey SET NOT NULL;
ALTER TABLE link_contact_hist_branch ADD CONSTRAINT link_contact_hist_branch_pk PRIMARY KEY (link_contact_hist_branch_hashkey);


CREATE OR REPLACE TABLE link_contact_hist_customer (
    link_contact_hist_customer_hashkey string NOT NULL COMMENT 'Link Hashkey – MD5(crm_contact_hist.ID || crm_contact_hist.CIF)',
    crm_contact_hist_hashkey string COMMENT 'FK đến hub_crm_contact_hist',
    customer_hashkey string COMMENT 'FK đến hub_customer (T24) – mapping qua CIF',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_contact_hist_customer ALTER COLUMN link_contact_hist_customer_hashkey SET NOT NULL;
ALTER TABLE link_contact_hist_customer ADD CONSTRAINT link_contact_hist_customer_pk PRIMARY KEY (link_contact_hist_customer_hashkey);


CREATE OR REPLACE TABLE link_contact_hist_contact_notes (
    link_contact_hist_contact_notes_hashkey string NOT NULL COMMENT 'Link Hashkey – MD5(crm_contact_hist.ID || crm_contact_notes.ID)',
    crm_contact_hist_hashkey string COMMENT 'FK đến hub_crm_contact_hist',
    crm_contact_notes_hashkey string COMMENT 'FK đến hub_crm_contact_notes (via CONTACTNOTEID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_contact_hist_contact_notes ALTER COLUMN link_contact_hist_contact_notes_hashkey SET NOT NULL;
ALTER TABLE link_contact_hist_contact_notes ADD CONSTRAINT link_contact_hist_contact_notes_pk PRIMARY KEY (link_contact_hist_contact_notes_hashkey);


CREATE OR REPLACE TABLE link_contact_hist_callcenter (
    link_contact_hist_callcenter_hashkey string NOT NULL COMMENT 'Link Hashkey – MD5(crm_contact_hist.ID || callcenter._id)',
    crm_contact_hist_hashkey string COMMENT 'FK đến hub_crm_contact_hist',
    callcenter_hashkey string COMMENT 'FK đến hub_callcenter (via DIALID)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE link_contact_hist_callcenter ALTER COLUMN link_contact_hist_callcenter_hashkey SET NOT NULL;
ALTER TABLE link_contact_hist_callcenter ADD CONSTRAINT link_contact_hist_callcenter_pk PRIMARY KEY (link_contact_hist_callcenter_hashkey);


-- Reference (Phase 2)
CREATE OR REPLACE TABLE ref_crm_contact_result (
    Ref_hashkey string NOT NULL COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    status string COMMENT 'Trạng thái hiển thị (YES/NO)',
    position string COMMENT 'Vị trí hiển thị',
    insurance string COMMENT 'Flag áp dụng cho sản phẩm bảo hiểm',
    expired_card_prio string COMMENT 'Ưu tiên cho thẻ hết hạn',
    cust_group string COMMENT 'Khối khách hàng áp dụng',
    hashdiff_full string COMMENT 'Hash diff của bản ghi',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_crm_contact_result ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_crm_contact_result ADD CONSTRAINT ref_crm_contact_result_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_crm_contact_status (
    Ref_hashkey string NOT NULL COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    status string COMMENT 'Trạng thái hiển thị (YES/NO)',
    position string COMMENT 'Vị trí hiển thị',
    kh_denhan_bh string COMMENT 'Khách hàng đề nghị nhận bảo hiểm',
    kh_cosp_dexuat string COMMENT 'Khách hàng có sản phẩm đề xuất',
    kh_roibo string COMMENT 'Khách hàng rời bỏ',
    hd_tiengui_denhan string COMMENT 'Hợp đồng tiền gửi đến hạn',
    sn_khachhang string COMMENT 'Sinh nhật khách hàng',
    kh_hienhuu string COMMENT 'Khách hàng hiện hữu',
    taikichhoat string COMMENT 'Tái kích hoạt',
    kh_expiredcard string COMMENT 'Khách hàng có thẻ hết hạn',
    chbh_ganden string COMMENT 'Chương trình bán hàng gần đến',
    cust_group string COMMENT 'Khối khách hàng áp dụng',
    hashdiff_full string COMMENT 'Hash diff của bản ghi',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_crm_contact_status ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_crm_contact_status ADD CONSTRAINT ref_crm_contact_status_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_crm_contact_type (
    Ref_hashkey string NOT NULL COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    status string COMMENT 'Trạng thái hiển thị (YES/NO)',
    position string COMMENT 'Vị trí hiển thị',
    kh_denhan_bh string COMMENT 'Khách hàng đề nghị nhận bảo hiểm',
    kh_cosp_dexuat string COMMENT 'Khách hàng có sản phẩm đề xuất',
    kh_roibo string COMMENT 'Khách hàng rời bỏ',
    hd_tiengui_denhan string COMMENT 'Hợp đồng tiền gửi đến hạn',
    sn_khachhang string COMMENT 'Sinh nhật khách hàng',
    kh_hienhuu string COMMENT 'Khách hàng hiện hữu',
    taikichhoat string COMMENT 'Tái kích hoạt',
    kh_expiredcard string COMMENT 'Khách hàng có thẻ hết hạn',
    chbh_ganden string COMMENT 'Chương trình bán hàng gần đến',
    cust_group string COMMENT 'Khối khách hàng áp dụng',
    iscall string COMMENT 'Flag là cuộc gọi (Y/N)',
    hashdiff_full string COMMENT 'Hash diff của bản ghi',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_crm_contact_type ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_crm_contact_type ADD CONSTRAINT ref_crm_contact_type_pk PRIMARY KEY (Ref_hashkey);


CREATE OR REPLACE TABLE ref_crm_custgroup (
    Ref_hashkey string NOT NULL COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    parent_key string COMMENT 'Khóa cha (nhóm khối: RB/SME/CIB)',
    user_created string COMMENT 'User tạo bản ghi',
    date_created date COMMENT 'Ngày tạo bản ghi',
    user_updated string COMMENT 'User cập nhật bản ghi',
    date_updated date COMMENT 'Ngày cập nhật bản ghi',
    user_deleted string COMMENT 'User xóa bản ghi',
    date_deleted date COMMENT 'Ngày xóa bản ghi',
    isactive string COMMENT 'Flag đang hoạt động (Y/N)',
    isdeleted string COMMENT 'Flag đã xóa (Y/N)',
    hashdiff_full string COMMENT 'Hash diff của bản ghi',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_crm_custgroup ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_crm_custgroup ADD CONSTRAINT ref_crm_custgroup_pk PRIMARY KEY (Ref_hashkey);
