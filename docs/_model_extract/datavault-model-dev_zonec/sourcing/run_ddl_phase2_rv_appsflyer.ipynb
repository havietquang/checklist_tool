# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;


CREATE OR REPLACE TABLE hub_appsflyer (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    business_key string COMMENT 'Khóa nghiệp vụ: AppsFlyer ID (AFID) – định danh duy nhất mỗi lần install, reinstall',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.'
) CLUSTER BY AUTO;
ALTER TABLE hub_appsflyer ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE hub_appsflyer ADD CONSTRAINT hub_appsflyer_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_installs_report_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_installs_report_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_installs_report_event ADD CONSTRAINT sat_installs_report_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_installs_report_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_installs_report_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_installs_report_device ADD CONSTRAINT sat_installs_report_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_organic_installs_report_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_organic_installs_report_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_organic_installs_report_event ADD CONSTRAINT sat_organic_installs_report_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_organic_installs_report_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_organic_installs_report_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_organic_installs_report_device ADD CONSTRAINT sat_organic_installs_report_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_reinstalls_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_reinstalls_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_reinstalls_event ADD CONSTRAINT sat_reinstalls_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_reinstalls_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_reinstalls_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_reinstalls_device ADD CONSTRAINT sat_reinstalls_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_reinstalls_organic_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_reinstalls_organic_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_reinstalls_organic_event ADD CONSTRAINT sat_reinstalls_organic_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_reinstalls_organic_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_reinstalls_organic_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_reinstalls_organic_device ADD CONSTRAINT sat_reinstalls_organic_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_uninstall_events_report_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_uninstall_events_report_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_uninstall_events_report_event ADD CONSTRAINT sat_uninstall_events_report_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_uninstall_events_report_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_uninstall_events_report_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_uninstall_events_report_device ADD CONSTRAINT sat_uninstall_events_report_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_organic_uninstall_events_report_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE sat_organic_uninstall_events_report_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_organic_uninstall_events_report_event ADD CONSTRAINT sat_organic_uninstall_events_report_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE sat_organic_uninstall_events_report_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    hashdiff string COMMENT 'Hash diff của các cột satellite',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_organic_uninstall_events_report_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE sat_organic_uninstall_events_report_device ADD CONSTRAINT sat_organic_uninstall_events_report_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE non_his_sat_in_app_events_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE non_his_sat_in_app_events_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE non_his_sat_in_app_events_event ADD CONSTRAINT non_his_sat_in_app_events_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE non_his_sat_in_app_events_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'iOS Advertising ID (resettable bởi người dùng)'
) CLUSTER BY AUTO;
ALTER TABLE non_his_sat_in_app_events_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE non_his_sat_in_app_events_device ADD CONSTRAINT non_his_sat_in_app_events_device_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE non_his_sat_organic_in_app_events_event (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    install_time string COMMENT 'UA: Khởi chạy đầu tiên sau khi cài đặt. Retargeting: Khởi chạy đầu tiên sau tái tương tác/tái phân bổ',
    event_time string COMMENT 'Thời gian sự kiện xảy ra',
    event_name string COMMENT 'Loại sự kiện phân bổ hoặc tên sự kiện in-app do nhà phát triển định nghĩa',
    event_value string COMMENT 'Nội dung chi tiết sự kiện (JSON, tối đa 1000 ký tự)',
    event_revenue string COMMENT 'Giá trị doanh thu từ sự kiện (theo event_revenue_currency)',
    event_revenue_currency string COMMENT 'Mã tiền tệ doanh thu sự kiện do SDK báo cáo',
    event_revenue_usd string COMMENT 'Doanh thu sự kiện quy đổi sang USD',
    event_source string COMMENT 'Nguồn sự kiện: SDK hoặc S2S',
    is_receipt_validated string COMMENT 'Xác thực biên lai mua hàng in-app: TRUE / FALSE / NULL',
    attributed_touch_type string COMMENT 'Loại chạm phân bổ: click / impression / pre-installed',
    attributed_touch_time string COMMENT 'Thời điểm của chạm được phân bổ',
    partner string COMMENT 'Mã định danh agency / PMD (luôn viết thường)',
    media_source string COMMENT 'Nguồn phương tiện quảng cáo (tên mạng quảng cáo)',
    channel string COMMENT 'Kênh quảng cáo (ví dụ: YouTube cho Google Ads)',
    keywords string COMMENT 'Từ khóa tìm kiếm của người dùng (Search Ads)',
    campaign string COMMENT 'Tên chiến dịch quảng cáo',
    campaign_id string COMMENT 'Mã chiến dịch quảng cáo',
    adset string COMMENT 'Tên nhóm quảng cáo (Adset)',
    adset_id string COMMENT 'Mã nhóm quảng cáo',
    ad string COMMENT 'Tên quảng cáo cụ thể',
    ad_id string COMMENT 'Mã quảng cáo cụ thể',
    ad_type string COMMENT 'Loại quảng cáo: banner, footer, v.v.',
    site_id string COMMENT 'Mã nhà xuất bản (Publisher ID)',
    sub_site_id string COMMENT 'Mã nhà xuất bản phụ',
    sub_param_1 string COMMENT 'Tham số phụ 1 do nhà quảng cáo định nghĩa',
    sub_param_2 string COMMENT 'Tham số phụ 2 do nhà quảng cáo định nghĩa',
    sub_param_3 string COMMENT 'Tham số phụ 3 do nhà quảng cáo định nghĩa',
    sub_param_4 string COMMENT 'Tham số phụ 4 do nhà quảng cáo định nghĩa',
    sub_param_5 string COMMENT 'Tham số phụ 5 do nhà quảng cáo định nghĩa',
    carrier string COMMENT 'Tên nhà mạng di động (từ Android getSimCarrierIdName())',
    cost_model string COMMENT 'Mô hình chi phí: CPC / CPI / CPM / Other',
    cost_value string COMMENT 'Giá trị chi phí (tối đa 4 chữ số thập phân)',
    cost_currency string COMMENT 'Mã tiền tệ ISO-4217, mặc định USD',
    contributor_1_partner string COMMENT 'Agency hoặc PMD của contributor 1 (viết thường)',
    contributor_1_media_source string COMMENT 'Nguồn phương tiện của contributor 1',
    contributor_1_campaign string COMMENT 'Tên chiến dịch của contributor 1',
    contributor_1_touch_type string COMMENT 'Loại chạm của contributor 1: click / impression',
    contributor_1_touch_time string COMMENT 'Thời gian chạm của contributor 1',
    contributor_2_partner string COMMENT 'Agency hoặc PMD của contributor 2',
    contributor_2_media_source string COMMENT 'Nguồn phương tiện của contributor 2',
    contributor_2_campaign string COMMENT 'Tên chiến dịch của contributor 2',
    contributor_2_touch_type string COMMENT 'Loại chạm của contributor 2',
    contributor_2_touch_time string COMMENT 'Thời gian chạm của contributor 2',
    contributor_3_partner string COMMENT 'Agency hoặc PMD của contributor 3',
    contributor_3_media_source string COMMENT 'Nguồn phương tiện của contributor 3',
    contributor_3_campaign string COMMENT 'Tên chiến dịch của contributor 3',
    contributor_3_touch_type string COMMENT 'Loại chạm của contributor 3',
    contributor_3_touch_time string COMMENT 'Thời gian chạm của contributor 3',
    is_retargeting string COMMENT 'UA: FALSE / Retargeting: TRUE',
    retargeting_conversion_type string COMMENT 'UA: Reinstall / Retargeting: Re-engagement hoặc Re-attribution (deprecated)',
    attribution_lookback string COMMENT 'Khoảng thời gian lookback tối đa cho attribution (tính từ thời điểm click)',
    reengagement_window string COMMENT 'Khoảng thời gian tái tương tác cho retargeting campaign',
    is_primary_attribution string COMMENT 'UA: TRUE / Retargeting: phụ thuộc vào cấu hình nguồn'
) CLUSTER BY AUTO;
ALTER TABLE non_his_sat_organic_in_app_events_event ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE non_his_sat_organic_in_app_events_event ADD CONSTRAINT non_his_sat_organic_in_app_events_event_pk PRIMARY KEY (appsflyer_hashkey);


CREATE OR REPLACE TABLE non_his_sat_organic_in_app_events_device (
    appsflyer_hashkey string NOT NULL COMMENT 'Hashkey Hub Appsfyler',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    city string COMMENT 'Vị trí địa lý chi tiết nhất xác định từ IP thiết bị',
    wifi string COMMENT 'Kết nối WiFi: TRUE / FALSE',
    operator string COMMENT 'Tên nhà mạng di động từ SIM (MCCMNC)',
    language string COMMENT 'Ngôn ngữ thiết bị (định dạng ll-DD, ví dụ: vi-VN)',
    advertising_id string COMMENT 'GAID – Google Advertising ID (Android resettable)',
    idfa string COMMENT 'iOS Advertising ID (resettable bởi người dùng)',
    android_id string COMMENT 'Android Permanent Device ID',
    customer_user_id string COMMENT 'App User ID do nhà phát triển gán (CIF của KH trên OMNI)',
    imei string COMMENT 'IMEI thiết bị (Android)',
    idfv string COMMENT 'iOS Identifier for Vendors',
    platform string COMMENT 'Nền tảng: iOS / Android / Windows Mobile',
    device_type string COMMENT 'Tên mô hình thương mại của thiết bị',
    os_version string COMMENT 'Phiên bản hệ điều hành',
    app_version string COMMENT 'Phiên bản ứng dụng (do nhà quảng cáo / SDK đặt)',
    sdk_version string COMMENT 'Phiên bản AppsFlyer SDK',
    app_id string COMMENT 'Mã định danh ứng dụng duy nhất trên app store',
    app_name string COMMENT 'Tên ứng dụng (do nhà quảng cáo đặt)',
    bundle_id string COMMENT 'iOS bundle ID / Android App ID',
    country_code string COMMENT 'Mã quốc gia ISO 3166 alpha-2 (ví dụ: VN, US)',
    dma string COMMENT 'Designated Market Area (Nielsen) – khu vực thị trường',
    ip string COMMENT 'Địa chỉ IP thiết bị (IPv4/IPv6)',
    postal_code string COMMENT 'Mã bưu điện xác định theo IP thiết bị',
    region string COMMENT 'Khu vực địa lý xác định theo IP thiết bị',
    state string COMMENT 'Tỉnh/Bang xác định theo IP thiết bị',
    user_agent string COMMENT 'User Agent của URL/thiết bị',
    http_referrer string COMMENT 'Địa chỉ trang web giới thiệu dẫn đến click URL',
    original_url string COMMENT 'Click/impression URL được sử dụng'
) CLUSTER BY AUTO;
ALTER TABLE non_his_sat_organic_in_app_events_device ALTER COLUMN appsflyer_hashkey SET NOT NULL;
ALTER TABLE non_his_sat_organic_in_app_events_device ADD CONSTRAINT non_his_sat_organic_in_app_events_device_pk PRIMARY KEY (appsflyer_hashkey);
