# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `staging`;


-- Phase 2
CREATE OR REPLACE VIEW v_stg_appsflyer_in_app_events_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_non_his_in_app_events_event,
    CAST(NULL AS STRING) AS hashdiff_non_his_in_app_events_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_installs_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_installs_report_event,
    CAST(NULL AS STRING) AS hashdiff_installs_report_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_organic_in_app_events_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_non_his_organic_in_app_events_report_event,
    CAST(NULL AS STRING) AS hashdiff_non_his_organic_in_app_events_report_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_organic_installs_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_organic_installs_report_event,
    CAST(NULL AS STRING) AS hashdiff_organic_installs_report_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_organic_uninstall_events_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_organic_uninstall_events_report_event,
    CAST(NULL AS STRING) AS hashdiff_organic_uninstall_events_report_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_reinstalls AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_reinstalls_event,
    CAST(NULL AS STRING) AS hashdiff_reinstalls_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_reinstalls_organic AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_reinstalls_organic_event,
    CAST(NULL AS STRING) AS hashdiff_reinstalls_organic_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;

CREATE OR REPLACE VIEW v_stg_appsflyer_uninstall_events_report AS
SELECT
    CAST(NULL AS STRING) AS hashkey,
    CAST(NULL AS STRING) AS appsflyer_id,
    CAST(NULL AS STRING) AS install_time,
    CAST(NULL AS STRING) AS event_time,
    CAST(NULL AS STRING) AS event_name,
    CAST(NULL AS STRING) AS event_value,
    CAST(NULL AS STRING) AS event_revenue,
    CAST(NULL AS STRING) AS event_revenue_currency,
    CAST(NULL AS STRING) AS event_revenue_usd,
    CAST(NULL AS STRING) AS event_source,
    CAST(NULL AS STRING) AS is_receipt_validated,
    CAST(NULL AS STRING) AS attributed_touch_type,
    CAST(NULL AS STRING) AS attributed_touch_time,
    CAST(NULL AS STRING) AS partner,
    CAST(NULL AS STRING) AS media_source,
    CAST(NULL AS STRING) AS channel,
    CAST(NULL AS STRING) AS keywords,
    CAST(NULL AS STRING) AS campaign,
    CAST(NULL AS STRING) AS campaign_id,
    CAST(NULL AS STRING) AS adset,
    CAST(NULL AS STRING) AS adset_id,
    CAST(NULL AS STRING) AS ad,
    CAST(NULL AS STRING) AS ad_id,
    CAST(NULL AS STRING) AS ad_type,
    CAST(NULL AS STRING) AS site_id,
    CAST(NULL AS STRING) AS sub_site_id,
    CAST(NULL AS STRING) AS sub_param_1,
    CAST(NULL AS STRING) AS sub_param_2,
    CAST(NULL AS STRING) AS sub_param_3,
    CAST(NULL AS STRING) AS sub_param_4,
    CAST(NULL AS STRING) AS sub_param_5,
    CAST(NULL AS STRING) AS carrier,
    CAST(NULL AS STRING) AS cost_model,
    CAST(NULL AS STRING) AS cost_value,
    CAST(NULL AS STRING) AS cost_currency,
    CAST(NULL AS STRING) AS contributor_1_partner,
    CAST(NULL AS STRING) AS contributor_1_media_source,
    CAST(NULL AS STRING) AS contributor_1_campaign,
    CAST(NULL AS STRING) AS contributor_1_touch_type,
    CAST(NULL AS STRING) AS contributor_1_touch_time,
    CAST(NULL AS STRING) AS contributor_2_partner,
    CAST(NULL AS STRING) AS contributor_2_media_source,
    CAST(NULL AS STRING) AS contributor_2_campaign,
    CAST(NULL AS STRING) AS contributor_2_touch_type,
    CAST(NULL AS STRING) AS contributor_2_touch_time,
    CAST(NULL AS STRING) AS contributor_3_partner,
    CAST(NULL AS STRING) AS contributor_3_media_source,
    CAST(NULL AS STRING) AS contributor_3_campaign,
    CAST(NULL AS STRING) AS contributor_3_touch_type,
    CAST(NULL AS STRING) AS contributor_3_touch_time,
    CAST(NULL AS STRING) AS is_retargeting,
    CAST(NULL AS STRING) AS retargeting_conversion_type,
    CAST(NULL AS STRING) AS attribution_lookback,
    CAST(NULL AS STRING) AS reengagement_window,
    CAST(NULL AS STRING) AS is_primary_attribution,
    CAST(NULL AS STRING) AS city,
    CAST(NULL AS STRING) AS wifi,
    CAST(NULL AS STRING) AS operator,
    CAST(NULL AS STRING) AS language,
    CAST(NULL AS STRING) AS advertising_id,
    CAST(NULL AS STRING) AS idfa,
    CAST(NULL AS STRING) AS android_id,
    CAST(NULL AS STRING) AS customer_user_id,
    CAST(NULL AS STRING) AS imei,
    CAST(NULL AS STRING) AS idfv,
    CAST(NULL AS STRING) AS platform,
    CAST(NULL AS STRING) AS device_type,
    CAST(NULL AS STRING) AS os_version,
    CAST(NULL AS STRING) AS app_version,
    CAST(NULL AS STRING) AS sdk_version,
    CAST(NULL AS STRING) AS app_id,
    CAST(NULL AS STRING) AS app_name,
    CAST(NULL AS STRING) AS bundle_id,
    CAST(NULL AS STRING) AS country_code,
    CAST(NULL AS STRING) AS dma,
    CAST(NULL AS STRING) AS ip,
    CAST(NULL AS STRING) AS postal_code,
    CAST(NULL AS STRING) AS region,
    CAST(NULL AS STRING) AS state,
    CAST(NULL AS STRING) AS user_agent,
    CAST(NULL AS STRING) AS http_referrer,
    CAST(NULL AS STRING) AS original_url,
    CAST(NULL AS STRING) AS hashdiff_full,
    CAST(NULL AS STRING) AS hashdiff_uninstall_events_report_event,
    CAST(NULL AS STRING) AS hashdiff_uninstall_events_report_device,
    CAST(NULL AS DATE) AS source_event_date,
    CAST(NULL AS STRING) AS record_source,
    CAST(NULL AS TIMESTAMP) AS load_timestamp
WHERE 1=0;
