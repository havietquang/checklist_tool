# %%
# %sql
USE CATALOG `ocb_datavault_${environment}_cleaned`;
USE SCHEMA `${target_schema}`;

CREATE OR REPLACE TABLE hub_auth_to_chuc_don_vi (
    auth_to_chuc_don_vi_hashkey STRING COMMENT 'Hub Hash Key',
    business_key bigint COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_auth_to_chuc_don_vi ALTER COLUMN auth_to_chuc_don_vi_hashkey SET NOT NULL;
ALTER TABLE hub_auth_to_chuc_don_vi ADD CONSTRAINT hub_auth_to_chuc_don_vi_pk PRIMARY KEY (auth_to_chuc_don_vi_hashkey);

CREATE OR REPLACE TABLE sat_auth_to_chuc_don_vi (
    auth_to_chuc_don_vi_hashkey STRING COMMENT 'FK đến hub_auth_to_chuc_don_vi',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_don_vi STRING COMMENT 'Mã đơn vị',
    don_vi_cap_tren bigint COMMENT 'đơn vị cấp trên',
    ten_don_vi STRING COMMENT 'Tên đơn vị',
    cap_do bigint COMMENT 'Cấp độ',
    loai_don_vi bigint COMMENT 'Loại đơn vị',
    ocb_hrm_id STRING COMMENT 'Định danh từ hệ thống nhân sự',
    trang_thai bigint COMMENT 'Trạng thái',
    ghi_chu STRING COMMENT 'Ghi chú',
    tinh_tp_id bigint COMMENT 'Định danh tỉnh/thành phố',
    phan_cap_don_vi bigint COMMENT 'Phân cấp đơn vị',
    thamvan_capky bigint COMMENT 'Tham vấn cấp ký',
    ishr bigint COMMENT 'Chỉ báo nhân sự',
    cic STRING COMMENT 'Trung tâm thông tin tín dụng',
    phan_khuc_khai_thac STRING COMMENT 'Phân khúc khai thác',
    don_vi_trien_khai_dvtd bigint COMMENT 'Đơn vị triển khai tín dụng',
    custgroup bigint COMMENT 'Nhóm khách hàng',
    parent_id_kt bigint COMMENT 'định danh cha'
) CLUSTER BY AUTO;
ALTER TABLE sat_auth_to_chuc_don_vi ALTER COLUMN auth_to_chuc_don_vi_hashkey SET NOT NULL;
ALTER TABLE sat_auth_to_chuc_don_vi ADD CONSTRAINT sat_auth_to_chuc_don_vi_pk PRIMARY KEY (auth_to_chuc_don_vi_hashkey);

CREATE OR REPLACE TABLE hub_auth_nhan_vien (
    auth_nhan_vien_hashkey STRING COMMENT 'Hub Hash Key',
    business_key bigint COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_auth_nhan_vien ALTER COLUMN auth_nhan_vien_hashkey SET NOT NULL;
ALTER TABLE hub_auth_nhan_vien ADD CONSTRAINT hub_auth_nhan_vien_pk PRIMARY KEY (auth_nhan_vien_hashkey);

CREATE OR REPLACE TABLE sat_auth_nhan_vien (
    auth_nhan_vien_hashkey STRING COMMENT 'FK den hub_auth_nhan_vien',
    hashdiff STRING COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ten_dang_nhap STRING COMMENT 'Ten dang nhap',
    ten_nguoi_dung STRING COMMENT 'Ten nguoi dung',
    ocb_hrm_uid bigint COMMENT 'Dinh danh he thong nhan su',
    trang_thai bigint COMMENT 'Trang thai',
    ghi_chu STRING COMMENT 'Ghi chu',
    is_lock bigint COMMENT 'Da khoa',
    ngay_thay_doi string COMMENT 'Ngay thay doi',
    nhan_vien_qly bigint COMMENT 'Nhan vien quan ly',
    email STRING COMMENT 'Email',
    user_id_thay_doi bigint COMMENT 'Ma nguoi dung thay doi',
    so_dien_thoai STRING COMMENT 'So dien thoai',
    chuc_danh bigint COMMENT 'Chuc danh',
    diem_min bigint COMMENT 'Diem min'
) CLUSTER BY AUTO;
ALTER TABLE sat_auth_nhan_vien ALTER COLUMN auth_nhan_vien_hashkey SET NOT NULL;
ALTER TABLE sat_auth_nhan_vien ADD CONSTRAINT sat_auth_nhan_vien_pk PRIMARY KEY (auth_nhan_vien_hashkey);

CREATE OR REPLACE TABLE hub_qlns_nguoi_lao_dong_info (
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'Hub Hash Key',
    business_key STRING COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_qlns_nguoi_lao_dong_info ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE hub_qlns_nguoi_lao_dong_info ADD CONSTRAINT hub_qlns_nguoi_lao_dong_info_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);

CREATE OR REPLACE TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan (
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'FK đến hub_qlns_nguoi_lao_dong_info',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ho_ten STRING COMMENT 'Họ tên',
    ngay_sinh string COMMENT 'Ngày Sinh',
    gioi_tinh STRING COMMENT 'Giới tính',
    ma_gioi_tinh bigint COMMENT 'Mã Giới tính',
    cmnd STRING COMMENT 'CMND',
    ngay_cap_cmnd string COMMENT 'Ngày cấp CMND',
    noi_cap STRING COMMENT 'Nơi cấp',
    so_dien_thoai STRING COMMENT 'Số điện thoại',
    email_ca_nhan STRING COMMENT 'Email Cá Nhân',
    email_co_quan STRING COMMENT 'Email cơ quan',
    dia_chi_thuong_tru STRING COMMENT 'Địa chỉ thường trú',
    trinh_do STRING COMMENT 'Trình độ',
    chuyen_nganh STRING COMMENT 'Chuyên Ngành',
    ngay_dong_bo string COMMENT 'Ngày đồng bộ'
) CLUSTER BY AUTO;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ca_nhan ADD CONSTRAINT sat_qlns_nguoi_lao_dong_info_ca_nhan_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);

CREATE OR REPLACE TABLE sat_qlns_nguoi_lao_dong_info_don_vi (
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'FK đến hub_qlns_nguoi_lao_dong_info',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    khoi STRING COMMENT 'Khối',
    ma_khoi STRING COMMENT 'Mã Khối',
    don_vi STRING COMMENT 'Đơn vị',
    ma_don_vi STRING COMMENT 'Mã Đơn vị',
    phong_ban STRING COMMENT 'Phòng ban',
    ma_phong_ban STRING COMMENT 'Mã Phòng ban',
    bo_phan STRING COMMENT 'Bộ phận',
    ma_bo_phan STRING COMMENT 'Mã Bộ phận',
    to_nhom STRING COMMENT 'Tổ nhóm',
    ma_to_nhom STRING COMMENT 'Mã Tổ nhóm',
    noi_lam_viec STRING COMMENT 'Nơi làm việc',
    chuc_danh STRING COMMENT 'Chức danh',
    ma_chuc_danh STRING COMMENT 'Mã Chức danh',
    chuc_danh_nnv STRING COMMENT 'Chức danh NNV',
    ma_chuc_danh_nnv STRING COMMENT 'Mã Chức danh NNV',
    chuc_danh_1 STRING COMMENT 'Chức danh 1',
    phan_nhom_chuc_danh STRING COMMENT 'Phân Nhóm Chức danh',
    cap_bac STRING COMMENT 'Cấp bậc',
    ma_cap_bac STRING COMMENT 'Mã Cấp bậc',
    tham_nien_vi_tri STRING COMMENT 'Thâm niên vị trí'
) CLUSTER BY AUTO;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_don_vi ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_don_vi ADD CONSTRAINT sat_qlns_nguoi_lao_dong_info_don_vi_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);

CREATE OR REPLACE TABLE sat_qlns_nguoi_lao_dong_info_hop_dong_lao_dong (
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'FK đến hub_qlns_nguoi_lao_dong_info',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    loai_hd_hien_tai STRING COMMENT 'Loại hợp đồng hiện tại',
    ma_loai_hd STRING COMMENT 'Mã Loại Hợp đồng',
    hdld_tu_ngay string COMMENT 'Hợp đồng lao động từ ngày',
    hdld_den_ngay string COMMENT 'Hợp đồng lao động đến ngày',
    so_lan_da_ky_hd bigint COMMENT 'Số lần đã ký hợp đồng',
    ma_loai_nhan_vien STRING COMMENT 'Mã Loại Nhân Viên',
    tinh_trang_nhan_vien STRING COMMENT 'Tình Trạng Nhân Viên',
    ngay_vao_ocb string COMMENT 'Ngày Vào OCB',
    loai_nghi_phep STRING COMMENT 'Loại nghỉ phép',
    thoi_gian_bat_dau_nghi_phep string COMMENT 'Thời gian bắt đầu nghỉ phép',
    thoi_gian_ket_thuc_nghi_phep string COMMENT 'Thời gian kết thúc nghỉ phép',
    so_ngay_nghi_phep bigint COMMENT 'Số ngày nghỉ phép',
    ly_do_nghi STRING COMMENT 'Lý do nghỉ',
    ngay_vao_ocb_chinh_thuc string COMMENT 'Ngày Vào OCB Chính Thức',
    ngay_lam_viec_cuoi_cung string COMMENT 'Ngày làm việc cuối cùng',
    ngay_thoi_viec string COMMENT 'Ngày thôi việc',
    ngay_nop_don_thoi_viec string COMMENT 'Ngày nộp đơn thôi việc',
    thoi_han_den_han_tai_bo_nhiem STRING COMMENT 'Thời hạn đến hạn tái bổ nhiệm',
    ngay_canh_bao_qt_lam_viec string COMMENT 'Ngày cảnh báo quá trình làm việc',
    tham_nien_nam bigint COMMENT 'Thâm niên năm',
    tham_nien_thang bigint COMMENT 'Thâm niên Tháng',
    tuoi bigint COMMENT 'Tuổi'
) CLUSTER BY AUTO;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_hop_dong_lao_dong ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_hop_dong_lao_dong ADD CONSTRAINT sat_qlns_nguoi_lao_dong_info_hop_dong_lao_dong_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);

CREATE OR REPLACE TABLE sat_qlns_nguoi_lao_dong_info_luong_thuong (
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'FK đến hub_qlns_nguoi_lao_dong_info',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_thang_luong STRING COMMENT 'Mã thang lương',
    ma_ngach_luong STRING COMMENT 'Mã ngạch lương',
    ma_bac_luong STRING COMMENT 'Mã bậc lương',
    luong_chuc_danh STRING COMMENT 'Lương chức danh',
    thuong_nang_suat STRING COMMENT 'Thưởng năng suất',
    thu_nhap STRING COMMENT 'Thu nhập',
    ho_tro_xang_xe STRING COMMENT 'Hỗ trợ xăng xe',
    phu_cap_doc_hai STRING COMMENT 'Phụ cấp độc hại',
    ho_tro_tien_an_giua_ca STRING COMMENT 'Hỗ trợ tiền ăn giữa ca',
    ho_tro_dien_thoai STRING COMMENT 'Hỗ trợ điện thoại',
    phu_cap_thu_hut STRING COMMENT 'Phụ cấp thu hút',
    tam_ung_hieu_suat STRING COMMENT 'Tạm ứng hiệu suất'
) CLUSTER BY AUTO;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_luong_thuong ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_luong_thuong ADD CONSTRAINT sat_qlns_nguoi_lao_dong_info_luong_thuong_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);

CREATE OR REPLACE TABLE sat_qlns_nguoi_lao_dong_info_ky_luat (
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'FK đến hub_qlns_nguoi_lao_dong_info',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    tinh_trang_ky_luat STRING COMMENT 'Tình trạng kỷ luật',
    ma_tinh_trang_ky_luat STRING COMMENT 'Mã Tình trạng kỷ luật',
    tg_thi_hanh_kl STRING COMMENT 'Thời gian thi hành kỷ luật',
    tg_ket_thuc_thi_hanh_kl STRING COMMENT 'Thời gian kết thúc thi hành kỷ luật',
    kq_danh_gia_gan_nhat STRING COMMENT 'Kết quả đánh giá gần nhất',
    kqdg_ky_truoc STRING COMMENT 'Kết quả đánh giá kỳ trước'
) CLUSTER BY AUTO;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ky_luat ALTER COLUMN qlns_nguoi_lao_dong_info_hashkey SET NOT NULL;
ALTER TABLE sat_qlns_nguoi_lao_dong_info_ky_luat ADD CONSTRAINT sat_qlns_nguoi_lao_dong_info_ky_luat_pk PRIMARY KEY (qlns_nguoi_lao_dong_info_hashkey);

CREATE OR REPLACE TABLE link_qlns_nguoi_lao_dong_info_auth_nhan_vien (
    link_qlns_nguoi_lao_dong_info_auth_nhan_vien_hashkey STRING COMMENT 'Khóa chính Link',
    qlns_nguoi_lao_dong_info_hashkey STRING COMMENT 'FK đến hub_qlns_nguoi_lao_dong_info',
    auth_nhan_vien_hashkey STRING COMMENT 'FK đến hub_auth_nhan_vien',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_qlns_nguoi_lao_dong_info_auth_nhan_vien ALTER COLUMN link_qlns_nguoi_lao_dong_info_auth_nhan_vien_hashkey SET NOT NULL;
ALTER TABLE link_qlns_nguoi_lao_dong_info_auth_nhan_vien ADD CONSTRAINT link_qlns_nguoi_lao_dong_info_auth_nhan_vien_pk PRIMARY KEY (link_qlns_nguoi_lao_dong_info_auth_nhan_vien_hashkey);

CREATE OR REPLACE TABLE hub_khach_hang (
    khach_hang_hashkey STRING COMMENT 'Hub hashkey',
    business_key bigint COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_khach_hang ALTER COLUMN khach_hang_hashkey SET NOT NULL;
ALTER TABLE hub_khach_hang ADD CONSTRAINT hub_khach_hang_pk PRIMARY KEY (khach_hang_hashkey);

CREATE OR REPLACE TABLE link_khach_hang_cif_t24 (
    link_khach_hang_customer_hashkey STRING COMMENT 'Link hashkey',
    khach_hang_hashkey STRING COMMENT 'FK đến hub_khach_hang',
    customer_hashkey STRING COMMENT 'FK đến t24_customer.id',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_khach_hang_cif_t24 ALTER COLUMN link_khach_hang_customer_hashkey SET NOT NULL;
ALTER TABLE link_khach_hang_cif_t24 ADD CONSTRAINT link_khach_hang_cif_t24_pk PRIMARY KEY (link_khach_hang_customer_hashkey);

CREATE OR REPLACE TABLE sat_khach_hang_thong_tin_chung (
    khach_hang_hashkey STRING COMMENT 'FK đến hub_khach_hang',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    loai_khach_hang bigint COMMENT 'Loại khách hàng',
    ten_khach_hang STRING COMMENT 'Tên khách hàng',
    ghi_chu STRING COMMENT 'Ghi chú',
    ngay_tao string COMMENT 'Ngày tạo khách hàng',
    xep_hang_tin_dung bigint COMMENT 'Xếp hạng tín dụng',
    nhom_khach_hang_id bigint COMMENT 'Nhóm khách hàng/ loại khách hàng',
    khach_hang_no STRING COMMENT 'khách hàng cá nhân: Chứng minh nhân dân/CCCD, khách hàng doanh nghiệp: mã sp dkdh',
    nv_cham_soc_gan_nhat bigint COMMENT 'Nhân viên CS khách hàng gần nhất',
    dvkd_quan_ly bigint COMMENT 'Đơn vị quản lý khách hàng',
    trang_thai bigint COMMENT '0 Không còn trong hệ thống, 1 còn trong hệ thống,2 chưa active',
    nhom_no_cao_nhat bigint COMMENT 'Hiển thị thông tin nhóm nợ cao nhất tại TC tín dụng khác theo GS tín dụng giá trị từ 1-> 5, không có thì để trống bóc tách thông tin từ file import của GStín dụng',
    phan_khuc_khang STRING COMMENT 'Phân khúc khách hàng',
    hangkh STRING COMMENT 'Hạng khách hàng, Silver, Gold, Platinum',
    isnewkh bigint COMMENT 'Sử dụng trong Kho Quý, khi sync 1 khách hàng chưa có trong BPM'
) CLUSTER BY AUTO;
ALTER TABLE sat_khach_hang_thong_tin_chung ALTER COLUMN khach_hang_hashkey SET NOT NULL;
ALTER TABLE sat_khach_hang_thong_tin_chung ADD CONSTRAINT sat_khach_hang_thong_tin_chung_pk PRIMARY KEY (khach_hang_hashkey);

CREATE OR REPLACE TABLE link_khach_hang_nhan_vien (
    link_khach_hang_nhan_vien_hashkey STRING COMMENT 'Khóa chính link',
    khach_hang_hashkey STRING COMMENT 'FK đến hub_khach_hang',
    auth_nhan_vien_hashkey STRING COMMENT 'FK đến hub_auth_nhan_vien',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_khach_hang_nhan_vien ALTER COLUMN link_khach_hang_nhan_vien_hashkey SET NOT NULL;
ALTER TABLE link_khach_hang_nhan_vien ADD CONSTRAINT link_khach_hang_nhan_vien_pk PRIMARY KEY (link_khach_hang_nhan_vien_hashkey);

CREATE OR REPLACE TABLE hub_pdtd_nhom_giao_dich (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'Hub Hash Key',
    business_key STRING COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_pdtd_nhom_giao_dich ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE hub_pdtd_nhom_giao_dich ADD CONSTRAINT hub_pdtd_nhom_giao_dich_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_nhom_giao_dich_trang_thai (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff STRING COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    trang_thai_giao_dich bigint COMMENT 'Trạng thái của giao dịch',
    trang_thai_phe_duyet bigint COMMENT 'Trạng thái giao dịch lúc phê duyệt',
    role_dang_xl bigint COMMENT 'Vai trò đang xử lý',
    trang_thai_hoat_dong bigint COMMENT 'Trạng thái hoạt động của gd',
    ket_qua_thao_tac_cuoi bigint COMMENT 'Kết quả thao tác cuối',
    process_id bigint COMMENT 'ID tiến trình',
    luong_id bigint COMMENT 'Luồng Quy trình Phê duyệt tín dụng',
    ngay_tao string COMMENT 'Ngày tạo',
    thoi_diem_thao_tac_cuoi string COMMENT 'Thời điểm thao tác cuối',
    ngay_hoan_thanh string COMMENT 'Ngày hoàn thành giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_nhom_giao_dich_trang_thai ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_nhom_giao_dich_trang_thai ADD CONSTRAINT sat_pdtd_nhom_giao_dich_trang_thai_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_nhom_giao_dich_ho_so (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff STRING COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID bản ghi',
    tong_so_tien decimal(38,10) COMMENT 'Tổng số tiền đề xuất',
    so_tien_pd decimal(38,10) COMMENT 'Tổng số tiền được phê duyệt',
    so_tien_pd_kn decimal(38,10) COMMENT 'Tổng số tiền được phê duyệt',
    tong_pd_muc_cap_tin_dung decimal(38,10) COMMENT 'Tổng rủi ro tín dụng của khách hàng',
    tong_rrtd_d1 decimal(38,10) COMMENT 'Tổng rủi ro tín dụng của khách hàng - giao dịch D1 - cơ cấu nợ',
    quy_che_blanh_khac bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Quy chế cho vay, 1 có 2 không',
    quy_dinh_tin_dung bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Quy định tín dụng/Sản phẩm tín chấp, 1 có 2 không',
    csach_tin_dung_kh bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Chính sách tín dụng theo xếp hạng khách hàng, 1 có 2 không',
    tuan_thu_dk_pduyet bigint COMMENT 'Tuân thủ điều kiện phê duyệt, 1 có 2 không',
    phe_duyet_boi_uy_ban bigint COMMENT 'Phê duyệt bởi ủy ban, 1 có 0 không',
    cap_td_co_du_an_dt bigint COMMENT 'Khoản cấp tín dụng có thẩm định dự án đầu tư không? 1: có, 0: không',
    cap_td_db_100_bds_oto bigint COMMENT 'Khoản cấp tín dụng có được đảm bảo bằng 100% tài sản bảo đảm là bất động sản, xe ôtô không? 1: có, 0: không',
    ls_thap_hon_ls_dcv bigint COMMENT 'Lãi suất áp dụng sau khi đề xuất giảm có thấp hơn lãi suất điều chuyển vốn hay không? 1: có, 0: không',
    mua_bao_hiem bigint COMMENT '1: Đồng ý mua, 2: Không đồng ý mua',
    ngoai_le_cam_ket_vay_co_dk bigint COMMENT 'Hạng khách hàng, SILVER GOLD …',
    ksvttd STRING COMMENT 'khách hàng có ngoại lệ ở quy định phát hành cam kết vay có đk',
    khoan_vay_cs_cbnv bigint COMMENT 'Khoản vay có theo chính sách cán bộ nhân viên?',
    is_trinh_vuot_cap_d1 bigint COMMENT 'Trình vượt cấp luồng D1- Cơ cấu nợ',
    is_thay_doi_tt bigint COMMENT 'Kiểm tra tờ trình có thay đổi hay không',
    khach_hang_tctd bigint COMMENT 'Khách hàng là Tổ chức tín dụng',
    trinh_ho_tro_ls_theo_qd bigint COMMENT 'Trình hỗ trợ lãi suất theo quyết định',
    kh_adgiam_tat_rb bigint COMMENT 'Áp dụng giảm TAT của khối RB',
    noi_dung_ycgt STRING COMMENT 'Nội dung yêu cầu giải trình'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_nhom_giao_dich_ho_so ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_nhom_giao_dich_ho_so ADD CONSTRAINT sat_pdtd_nhom_giao_dich_ho_so_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_nhom_giao_dich_han_muc (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    hmrr_dx_kh_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng được đảm bảo bằng 100% tiền gửi tại OCB theo SP tiền gửi',
    hmrr_dx_kh_ko_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng không được đảm bảo bằng 100% tiền gửi tại OCB',
    hmrr_dx_kh_100_fi_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng đề xuất của khách hàng không được đảm bảo bằng 100% tiền gửi tại OCB trừ đầu tư trái phiếu do các TCtín dụng/Hạn công ty/TĐNN phát hành',
    hmrr_dx_kh_nlq_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng và nhóm liên quan được đảm bảo bằng 100% tiền gửi tại OCB theo SP tiền gửi',
    hmrr_dx_kh_nlq_ko_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng và nhóm liên quan không được đảm bảo bằng 100% tiền gửi tại OCB',
    hmrr_htai_kh_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng 100% tiền gửi',
    hmrr_htai_kh_ko_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng không 100% tiền gửi',
    hmrr_htai_kh_nlq_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng và nhóm liên quan 100% tiền gửi',
    hmrr_htai_kh_nlq_ko_100_tgui decimal(38,10) COMMENT 'Hạn mức rủi ro tín dụng của khách hàng và nhóm liên quan không 100% tiền gửi',
    rrtd_kh_ko_tsbd decimal(38,10) COMMENT 'Tổng mức rủi ro tín dụng của khách hàng không có tài sản bảo đảm',
    rrtd_kh_ko_100_tgui_tru_tp decimal(38,10) COMMENT 'Tổng mức rủi ro tín dụng đề xuất của khách hàng không được đảm bảo bằng 100% tiền gửi tại OCB trừ đầu tư trái phiếu do các TCtín dụng/Tổng Cty/Tập đoàn Nhà nước phát hành',
    hmrr_pd_kh_100_tgui decimal(38,10) COMMENT 'Tổng mức rủi ro tín dụng của khách hàng được đảm bảo bằng 100% tiền gửi tại OCB theo SP tiền gửi',
    hmrr_pd_kh_ko_100_tgui decimal(38,10) COMMENT 'Tổng mức rủi ro tín dụng của khách hàng không được đảm bảo bằng 100% tiền gửi tại OCB theo SP tiền gửi',
    hmrr_sp_cu_the_covako_tsdb decimal(38,10) COMMENT 'Hạn mức rủi ro sản phẩm cụ thể có và không tài sản bảo đảm',
    hmrr_sp_cu_the_ko_tsdb decimal(38,10) COMMENT 'Hạn mức rủi ro sản phẩm cụ thể không tài sản bảo đảm',
    rrtd_pd_sp_cuthe_covako_tsbd decimal(38,10) COMMENT 'rủi ro tín dụng phê duyệt sản phẩm cụ thể có và không tài sản bảo đảm',
    hmrr_pd_kh_dam_bao decimal(38,10) COMMENT 'Hạn mức rủi ro phê duyệt tín dụng đảm bảo 100% tiền gửi của khách hàng',
    hmrr_pd_kh_khong_dam_bao decimal(38,10) COMMENT 'Hạn mức rủi ro phê duyệt tín dụng không đảm bảo 100% tiền gửi của khách hàng'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_nhom_giao_dich_han_muc ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_nhom_giao_dich_han_muc ADD CONSTRAINT sat_pdtd_nhom_giao_dich_han_muc_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_nhom_giao_dich_tham_dinh (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    loai_tien bigint COMMENT 'Loại tiền',
    tinh_trang_no_cic bigint COMMENT 'Tình trạng nợ tại trung tâm thông tin tín dụng',
    tsbd_nhieu_kh bigint COMMENT 'tài sản bảo đảm thuộc nhiều khách hàng, 1 có 2 không',
    tsbd_thuoc_pduyet_hoi_so bigint COMMENT 'tài sản bảo đảm thuộc phê duyệt của hội sở, 1 có 2 không',
    spham_tdung_tsbd bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Sản phẩm tín dụng Có đề tài sản bảo đảm, 1 có 2 không',
    ngoai_le_tsdb bigint COMMENT 'Khoản tín dụng thuộc trường hợp phải trình ủy ban tín dụng theo khoản 3, điều 4, quyết định 444/2018/quyết định-TGĐ, 1 có 2 không',
    kh_mien_pduyet_tt bigint COMMENT 'Khách hàng miễn duyệt tờ trình, 1 có 2 không',
    tdiem_tdtt string COMMENT 'Thời điểm thẩm định trực tiếp',
    nhom2_no_cic_12t bigint COMMENT 'Nhóm 2 nợ trung tâm thông tin tín dụng 12T, 1 có 2 không',
    xep_hang_td bigint COMMENT 'Xếp hạng tín dụng',
    gtri_cam_ket decimal(38,10) COMMENT 'Giá trị cam kết E2',
    tong_gtri_cam_ket decimal(38,10) COMMENT 'Tổng giá trị cam kết tại OCB của khách hàng',
    trang_thai_tdtt bigint COMMENT '0:Chưa gửi Thẩm định trực tiếp; 1:Chưa có kết quả thẩm định trực tiếp; 2:CBT tín dụng đồng ý; 3:CBT tín dụng không đồng ý; 4:Được miễn thẩm định trực tiếp',
    quy_trinh_con bigint COMMENT '0: phê duyệt tín dụng thường, 8930: quy trình trái phiếu',
    khoan_cap_tin_dung bigint COMMENT 'Khoản cấp tín dụng',
    ngay_ky_hdtd string COMMENT 'Ngày ký hợp đồng tín dụng',
    ngay_het_han_hdtd string COMMENT 'Ngày hết hạn hợp đồng tín dụng',
    dk_danh_gia_tiep_tuc_giai_ngan bigint COMMENT 'Điều kiện đánh giá tiếp tục giải ngân',
    phuong_phap_cmtn bigint COMMENT 'Phương pháp chứng minh thu nhập'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_nhom_giao_dich_tham_dinh ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_nhom_giao_dich_tham_dinh ADD CONSTRAINT sat_pdtd_nhom_giao_dich_tham_dinh_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_nhom_giao_dich_phe_duyet (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    nguoi_khoi_tao bigint COMMENT 'Người khởi tạo',
    nguoi_dang_xu_ly bigint COMMENT 'Người đang xử lý',
    don_vi_kdoanh bigint COMMENT 'Đơn vị kinh doanh',
    cbttd bigint COMMENT 'Cán bộ tái thẩm định',
    gdpdtd bigint COMMENT 'Giám đốc phê duyệt tín dụng',
    don_vi_pduyet bigint COMMENT 'đơn vị phê duyệt',
    nguoi_phu_trach bigint COMMENT 'Người phụ trách',
    bspo_id bigint COMMENT 'user duyệt BSTL',
    cgpddl STRING COMMENT 'user Phê duyệt tín dụng - Chuyên gia phê duyệt độc lập',
    cap_phe_duyet_cuoi_id bigint COMMENT 'ID Cấp phê duyệt cuối cùng',
    nhom_khach_hang bigint COMMENT '100000 = khách hàng cá nhân, 100001 = khách hàng doanh nghiệp',
    loai_nhom_giao_dich bigint COMMENT '1 : Khởi tạo mới, 2 : Giao dịch khiếu nại, 3 : Hủy, 4: BSTL',
    nhom_ho_so bigint COMMENT '1: N1, 2: N2, 3:N3, 4:N4, 5: N5, 6 : N6',
    nhom_giao_dich_goc_id string COMMENT 'ID giao dịch Phê duyệt tín dụng gốc, dành cho các gd hủy, clone …',
    hangkh STRING COMMENT 'rủi ro tín dụng phê duyệt sản phẩm cụ thể có và không tài sản bảo đảm',
    rating_id STRING COMMENT 'Rating ID, ref phần mềm định giá'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_nhom_giao_dich_phe_duyet ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_nhom_giao_dich_phe_duyet ADD CONSTRAINT sat_pdtd_nhom_giao_dich_phe_duyet_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_nhom_giao_dich_sla (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    quy_trinh bigint COMMENT 'Quy trình',
    sla STRING COMMENT 'Chỉ tiêu SLA tổng hợp của giao dịch',
    thoi_gian_xl_vitri_1 bigint COMMENT 'Thời gian xử lý tại vị trí 1',
    thoi_gian_xl_vitri_2 bigint COMMENT 'Thời gian xử lý tại vị trí 2',
    thoi_diem_nhan_vitri_1 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 1',
    thoi_diem_nhan_vitri_1_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 1',
    thoi_diem_nhan_vitri_2_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 2',
    thoi_gian_xl_vitri_3 bigint COMMENT 'Thời gian xử lý tại vị trí 3',
    thoi_gian_xl_vitri_4 bigint COMMENT 'Thời gian xử lý tại vị trí 4',
    thoi_diem_nhan_vitri_3 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 3',
    thoi_diem_nhan_vitri_4 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 4',
    thoi_diem_nhan_vitri_3_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 3',
    thoi_diem_nhan_vitri_4_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 4',
    thoi_gian_den_han string COMMENT 'Thời gian đến hạn',
    sla_vitri_2 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 2',
    sla_vitri_3 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 3',
    sla_vitri_5 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 5',
    thoi_gian_xl_vitri_5 bigint COMMENT 'Thời gian xử lý tại vị trí 5',
    thoi_diem_nhan_vitri_5 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 5',
    thoi_diem_nhan_vitri_5_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 5',
    trang_thai bigint COMMENT 'Trạng thái xử lý của giao dịch',
    thoi_gian_xl_vitri_6 bigint COMMENT 'Thời gian xử lý tại vị trí 6',
    thoi_diem_nhan_vitri_6 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 6',
    thoi_diem_nhan_vitri_6_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 6',
    thoi_gian_xl_vitri_7 bigint COMMENT 'Thời gian xử lý tại vị trí 7',
    thoi_diem_nhan_vitri_7 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 7',
    thoi_diem_nhan_vitri_7_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 7',
    sla_vitri_4 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 4',
    sla_vitri_8 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 8',
    thoi_gian_xl_vitri_8 bigint COMMENT 'Thời gian xử lý tại vị trí 8',
    thoi_diem_nhan_vitri_8 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 8',
    thoi_diem_nhan_vitri_8_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 8',
    sla_vitri_9 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 9',
    thoi_gian_xl_vitri_9 bigint COMMENT 'Thời gian xử lý tại vị trí 9',
    thoi_diem_nhan_vitri_9 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 9',
    thoi_diem_nhan_vitri_9_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 9',
    sla_vitri_12 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 12',
    thoi_gian_xl_vitri_12 bigint COMMENT 'Thời gian xử lý tại vị trí 12',
    thoi_diem_nhan_vitri_12 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 12',
    thoi_diem_nhan_vitri_12_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 12',
    sla_vitri_14 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 14',
    thoi_gian_xl_vitri_14 bigint COMMENT 'Thời gian xử lý tại vị trí 14',
    thoi_diem_nhan_vitri_14 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 14',
    thoi_diem_nhan_vitri_14_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 14'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_nhom_giao_dich_sla ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_nhom_giao_dich_sla ADD CONSTRAINT sat_pdtd_nhom_giao_dich_sla_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey);

CREATE OR REPLACE TABLE link_xl_pdtd_link (
    link_xl_pdtd_link_hashkey STRING COMMENT 'Khóa chính link',
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    xl_ksgn_chung_hashkey STRING COMMENT 'FK đến hub_xl_ksgn_chung',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_xl_pdtd_link ALTER COLUMN link_xl_pdtd_link_hashkey SET NOT NULL;
ALTER TABLE link_xl_pdtd_link ADD CONSTRAINT link_xl_pdtd_link_pk PRIMARY KEY (link_xl_pdtd_link_hashkey);

CREATE OR REPLACE TABLE sat_link_xl_pdtd_link (
    link_xl_pdtd_link_hashkey STRING COMMENT 'FK den link_xl_pdtd_link',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID ban ghi',
    gd_pdtd_id bigint COMMENT 'ID giao dich phe duyet tin dung',
    gd_chinh_id bigint COMMENT 'ID giao dich chinh',
    ngay_tao STRING COMMENT 'Ngay tao',
    gd_ngoai_bpm bigint COMMENT 'Giao dich ngoai BPM',
    khoan_tin_dung STRING COMMENT 'Khoan tin dung',
    ngay_phe_duyet STRING COMMENT 'Ngay phe duyet'
) CLUSTER BY AUTO;
ALTER TABLE sat_link_xl_pdtd_link ALTER COLUMN link_xl_pdtd_link_hashkey SET NOT NULL;
ALTER TABLE sat_link_xl_pdtd_link ADD CONSTRAINT sat_link_xl_pdtd_link_pk PRIMARY KEY (link_xl_pdtd_link_hashkey);

CREATE OR REPLACE TABLE link_pdtd_nhom_giao_dich_khach_hang (
    link_pdtd_nhom_giao_dich_khach_hang_hashkey STRING COMMENT 'Khóa chính link',
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    khach_hang_hashkey STRING COMMENT 'FK đến hub_khach_hang',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_pdtd_nhom_giao_dich_khach_hang ALTER COLUMN link_pdtd_nhom_giao_dich_khach_hang_hashkey SET NOT NULL;
ALTER TABLE link_pdtd_nhom_giao_dich_khach_hang ADD CONSTRAINT link_pdtd_nhom_giao_dich_khach_hang_pk PRIMARY KEY (link_pdtd_nhom_giao_dich_khach_hang_hashkey);

CREATE OR REPLACE TABLE link_pdtd_nhom_giao_dich_tsbd_giaodich_chinh (
    link_pdtd_nhom_giao_dich__tsbd_giaodich_chinh_hashkey STRING COMMENT 'Khóa chính Link',
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich (MA_GIAO_DICH)',
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'FK đến hub_tsbd_giaodich_chinh (MA_GIAO_DICH)',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_pdtd_nhom_giao_dich_tsbd_giaodich_chinh ALTER COLUMN link_pdtd_nhom_giao_dich__tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE link_pdtd_nhom_giao_dich_tsbd_giaodich_chinh ADD CONSTRAINT link_pdtd_nhom_giao_dich_tsbd_giaodich_chinh_pk PRIMARY KEY (link_pdtd_nhom_giao_dich__tsbd_giaodich_chinh_hashkey);

CREATE OR REPLACE TABLE sat_pdtd_san_pham (
    pdtd_nhom_giao_dich_hashkey STRING COMMENT 'FK đến hub_pdtd_nhom_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    rowid string COMMENT 'ID tu tang pk',
    datadate string COMMENT 'Ngay tao',
    gd_chinh_id bigint COMMENT 'ID giao dich chinh',
    muc_dich_id bigint COMMENT 'Mục đích',
    nhom_san_pham_id bigint COMMENT 'mã nhóm sản phẩm',
    san_pham_id bigint COMMENT 'mã sản phẩm',
    loai_san_pham bigint COMMENT '1: SP MỚI, 2: SP CŨ',
    so_tien_de_xuat decimal(38,10) COMMENT 'Số tiền đề xuất',
    so_tien_phe_duyet decimal(38,10) COMMENT 'Số tiền phê duyệt',
    ngay_tao string COMMENT 'Ngày tạo',
    rrtd_co_tsbd_sp_cuthe decimal(38,10) COMMENT 'rủi ro tín dụng có tài sản bảo đảm ở sản phẩm cụ thể',
    rrtd_ko_tsbd_sp_cuthe decimal(38,10) COMMENT 'rủi ro tín dụng không có tài sản bảo đảm ở sản phẩm cụ thể',
    rrtd_co_tsbd_sp_cuthe_pd decimal(38,10) COMMENT 'rủi ro tín dụng có tài sản bảo đảm ở sản phẩm cụ thể - PD',
    rrtd_ko_tsbd_sp_cuthe_pd decimal(38,10) COMMENT 'rủi ro tín dụng không có tài sản bảo đảm ở sản phẩm cụ thể - PD',
    du_no_hien_tai decimal(38,10) COMMENT 'Dư nợ hiện tại',
    rrtd_da_phe_duyet decimal(38,10) COMMENT 'rủi ro tín dụng đã phê duyệt',
    ngay_het_han_hieu_luc_hm string COMMENT 'Ngày hết hạn hiệu lực hạn mức',
    ngay_lap_tt_ph_ckctd string COMMENT 'Ngày lập tờ trình phát hành',
    ngay_du_kien_ph_ckctd string COMMENT 'Ngày dự kiến phát hành'
) CLUSTER BY AUTO;
ALTER TABLE sat_pdtd_san_pham ALTER COLUMN pdtd_nhom_giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_pdtd_san_pham ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_pdtd_san_pham ADD CONSTRAINT sat_pdtd_san_pham_pk PRIMARY KEY (pdtd_nhom_giao_dich_hashkey, ma_key);

CREATE OR REPLACE TABLE hub_giao_dich (
    giao_dich_hashkey STRING COMMENT 'Hub hash key',
    business_key STRING COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_giao_dich ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE hub_giao_dich ADD CONSTRAINT hub_giao_dich_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_giao_dich_thong_tin_chung (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    quy_trinh bigint COMMENT 'Quy Trình',
    nguoi_xu_ly_id STRING COMMENT 'Mã người xử lý',
    vai_tro_nguoi_xl bigint COMMENT 'Vai trò người xử lý',
    ngay_hoan_thanh STRING COMMENT 'Ngày hoàn thành',
    trang_thai bigint COMMENT 'Trạng thái',
    trang_thai_hoat_dong bigint COMMENT 'Trạng thái hoạt động',
    loai_tien STRING COMMENT 'Loại tiền',
    process_id bigint COMMENT 'Mã tiến trình',
    luong_id bigint COMMENT 'Mã luồng',
    giao_dich_cu_id STRING COMMENT 'Mã giao dịch cũ',
    don_vi_tao bigint COMMENT 'Đơn vị tạo',
    nguoi_tao_id STRING COMMENT 'Mã người tạo',
    ngay_tao STRING COMMENT 'Ngày tạo',
    ngay_cap_nhat STRING COMMENT 'Ngày cập nhật',
    quy_trinh_con bigint COMMENT 'Quy trình con'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_thong_tin_chung ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_thong_tin_chung ADD CONSTRAINT sat_giao_dich_thong_tin_chung_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE link_giao_dich_khach_hang (
    link_giao_dich_khach_hang_hashkey STRING COMMENT 'khóa chính Link',
    giao_dich_hashkey STRING COMMENT 'Fk tới hub_giao_dich.gd_id',
    khach_hang_hashkey STRING COMMENT 'Fk tới hub_khach_hang.id',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_giao_dich_khach_hang ALTER COLUMN link_giao_dich_khach_hang_hashkey SET NOT NULL;
ALTER TABLE link_giao_dich_khach_hang ADD CONSTRAINT link_giao_dich_khach_hang_pk PRIMARY KEY (link_giao_dich_khach_hang_hashkey);

CREATE OR REPLACE TABLE sat_giao_dich_tsbd (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_tsbd STRING COMMENT 'Mã tài sản đảm bảo',
    quy_trinh string COMMENT 'Quy trình',
    ngay_tao string COMMENT 'Ngày tạo',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    nguoi_tao STRING COMMENT 'Người tạo',
    ngay_phat_hanh string COMMENT 'Ngày phát hành',
    ngay_den_han string COMMENT 'Ngày đến hạn',
    gia_tri int COMMENT 'Giá trị',
    loai_tien_gui STRING COMMENT 'Loại tiền gửi',
    ti_le_bd decimal(38,10) COMMENT 'Tỷ lệ bảo đảm',
    tinh_trang_phong_toa bigint COMMENT 'Tình trạng phong tỏa',
    muc_bao_dam decimal(38,10) COMMENT 'Mức bảo đảm',
    chu_so_huu string COMMENT 'Chủ sở hữu',
    loai_tien_t24 STRING COMMENT 'Loại tiền trên hệ thống T24',
    cif STRING COMMENT 'CIF',
    cmnd STRING COMMENT 'CMND'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tsbd ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tsbd ADD CONSTRAINT sat_giao_dich_tsbd_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_giaodich_sla (
    giao_dich_hashkey STRING COMMENT 'Tham chieu toi hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    quy_trinh bigint COMMENT 'Quy trinh',
    sla STRING COMMENT 'Chi tieu SLA tong hop cua giao dich',
    thoi_gian_xl_vitri_1 bigint COMMENT 'Thoi gian xu ly tai vi tri 1',
    thoi_gian_xl_vitri_2 bigint COMMENT 'Thoi gian xu ly tai vi tri 2',
    thoi_diem_nhan_vitri_1 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 1',
    thoi_diem_nhan_vitri_2 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 2',
    thoi_diem_nhan_vitri_1_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 1',
    thoi_diem_nhan_vitri_2_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 2',
    thoi_gian_xl_vitri_3 bigint COMMENT 'Thoi gian xu ly tai vi tri 3',
    thoi_gian_xl_vitri_4 bigint COMMENT 'Thoi gian xu ly tai vi tri 4',
    thoi_diem_nhan_vitri_3 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 3',
    thoi_diem_nhan_vitri_4 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 4',
    thoi_diem_nhan_vitri_3_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 3',
    thoi_diem_nhan_vitri_4_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 4',
    thoi_gian_den_han string COMMENT 'Thoi gian den han SLA cua giao dich',
    sla_vitri_2 STRING COMMENT 'Chi tieu SLA tai vi tri 2',
    sla_vitri_3 STRING COMMENT 'Chi tieu SLA tai vi tri 3',
    sla_vitri_4 STRING COMMENT 'Chi tieu SLA tai vi tri 4',
    sla_vitri_5 STRING COMMENT 'Chi tieu SLA tai vi tri 5',
    thoi_gian_xl_vitri_5 bigint COMMENT 'Thoi gian xu ly tai vi tri 5',
    thoi_diem_nhan_vitri_5 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 5',
    thoi_diem_nhan_vitri_5_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 5',
    trang_thai bigint COMMENT 'Trang thai xu ly cua giao dich',
    thoi_gian_xl_vitri_6 bigint COMMENT 'Thoi gian xu ly tai vi tri 6',
    thoi_diem_nhan_vitri_6 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 6',
    thoi_diem_nhan_vitri_6_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 6',
    thoi_gian_xl_vitri_7 bigint COMMENT 'Thoi gian xu ly tai vi tri 7',
    thoi_diem_nhan_vitri_7 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 7',
    thoi_diem_nhan_vitri_7_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 7',
    sla_vitri_8 STRING COMMENT 'Chi tieu SLA tai vi tri 8',
    thoi_gian_xl_vitri_8 bigint COMMENT 'Thoi gian xu ly tai vi tri 8',
    thoi_diem_nhan_vitri_8 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 8',
    thoi_diem_nhan_vitri_8_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 8',
    sla_vitri_9 STRING COMMENT 'Chi tieu SLA tai vi tri 9',
    thoi_gian_xl_vitri_9 bigint COMMENT 'Thoi gian xu ly tai vi tri 9',
    thoi_diem_nhan_vitri_9 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 9',
    thoi_diem_nhan_vitri_9_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 9',
    sla_vitri_12 STRING COMMENT 'Chi tieu SLA tai vi tri 12',
    thoi_gian_xl_vitri_12 bigint COMMENT 'Thoi gian xu ly tai vi tri 12',
    thoi_diem_nhan_vitri_12 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 12',
    thoi_diem_nhan_vitri_12_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 12',
    sla_vitri_14 STRING COMMENT 'Chi tieu SLA tai vi tri 14',
    thoi_gian_xl_vitri_14 bigint COMMENT 'Thoi gian xu ly tai vi tri 14',
    thoi_diem_nhan_vitri_14 STRING COMMENT 'Thoi diem nhan tac vu toi vi tri 14',
    thoi_diem_nhan_vitri_14_cuoi STRING COMMENT 'Thoi diem nhan tac vu lan cuoi toi vi tri 14'
) CLUSTER BY AUTO;
ALTER TABLE sat_giaodich_sla ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giaodich_sla ADD CONSTRAINT sat_giaodich_sla_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_xl_ksgn_chung_sla (
    xl_ksgn_chung_hashkey STRING COMMENT 'FK đến hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    quy_trinh bigint COMMENT 'Quy trình',
    sla STRING COMMENT 'Chỉ tiêu SLA tổng hợp của giao dịch',
    thoi_gian_xl_vitri_1 bigint COMMENT 'Thời gian xử lý tại vị trí 1',
    thoi_gian_xl_vitri_2 bigint COMMENT 'Thời gian xử lý tại vị trí 2',
    thoi_diem_nhan_vitri_1 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 1',
    thoi_diem_nhan_vitri_1_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 1',
    thoi_diem_nhan_vitri_2_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 2',
    thoi_gian_xl_vitri_3 bigint COMMENT 'Thời gian xử lý tại vị trí 3',
    thoi_gian_xl_vitri_4 bigint COMMENT 'Thời gian xử lý tại vị trí 4',
    thoi_diem_nhan_vitri_3 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 3',
    thoi_diem_nhan_vitri_4 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 4',
    thoi_diem_nhan_vitri_3_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 3',
    thoi_diem_nhan_vitri_4_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 4',
    thoi_gian_den_han string COMMENT 'Thời gian đến hạn',
    sla_vitri_2 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 2',
    sla_vitri_3 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 3',
    sla_vitri_5 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 5',
    thoi_gian_xl_vitri_5 bigint COMMENT 'Thời gian xử lý tại vị trí 5',
    thoi_diem_nhan_vitri_5 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 5',
    thoi_diem_nhan_vitri_5_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 5',
    trang_thai bigint COMMENT 'Trạng thái xử lý của giao dịch',
    thoi_gian_xl_vitri_6 bigint COMMENT 'Thời gian xử lý tại vị trí 6',
    thoi_diem_nhan_vitri_6 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 6',
    thoi_diem_nhan_vitri_6_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 6',
    thoi_gian_xl_vitri_7 bigint COMMENT 'Thời gian xử lý tại vị trí 7',
    thoi_diem_nhan_vitri_7 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 7',
    thoi_diem_nhan_vitri_7_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 7',
    sla_vitri_4 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 4',
    sla_vitri_8 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 8',
    thoi_gian_xl_vitri_8 bigint COMMENT 'Thời gian xử lý tại vị trí 8',
    thoi_diem_nhan_vitri_8 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 8',
    thoi_diem_nhan_vitri_8_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 8',
    sla_vitri_9 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 9',
    thoi_gian_xl_vitri_9 bigint COMMENT 'Thời gian xử lý tại vị trí 9',
    thoi_diem_nhan_vitri_9 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 9',
    thoi_diem_nhan_vitri_9_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 9',
    sla_vitri_12 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 12',
    thoi_gian_xl_vitri_12 bigint COMMENT 'Thời gian xử lý tại vị trí 12',
    thoi_diem_nhan_vitri_12 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 12',
    thoi_diem_nhan_vitri_12_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 12',
    sla_vitri_14 STRING COMMENT 'Chỉ tiêu SLA tại vị trí 14',
    thoi_gian_xl_vitri_14 bigint COMMENT 'Thời gian xử lý tại vị trí 14',
    thoi_diem_nhan_vitri_14 STRING COMMENT 'Thời điểm nhận tác vụ tới vị trí 14',
    thoi_diem_nhan_vitri_14_cuoi STRING COMMENT 'Thời điểm nhận tác vụ lần cuối tới vị trí 14'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ksgn_chung_sla ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ksgn_chung_sla ADD CONSTRAINT sat_xl_ksgn_chung_sla_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE link_giao_dich_link (
    link_giao_dich_link_hashkey STRING COMMENT 'Khóa chính link',
    giao_dich_hashkey STRING COMMENT 'tham chiếu hub_giao_dich',
    giao_dich_link_hashkey STRING COMMENT 'tham chiếu giao_dich_hashkey',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_giao_dich_link ALTER COLUMN link_giao_dich_link_hashkey SET NOT NULL;
ALTER TABLE link_giao_dich_link ADD CONSTRAINT link_giao_dich_link_pk PRIMARY KEY (link_giao_dich_link_hashkey);

CREATE OR REPLACE TABLE sat_link_giao_dich_link (
    link_giao_dich_link_hashkey STRING COMMENT 'Tham chiếu tới link_giao_dich_link',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID bản ghi',
    quy_trinh_link bigint COMMENT 'Mã quy trình liên kết trên',
    giao_dich_ngoai_bpm bigint COMMENT 'Cờ đánh dấu giao dịch ngoài BPM',
    quy_trinh_con bigint COMMENT 'Mã quy trình con/liên quan theo',
    cap_phe_duyet STRING COMMENT 'Cấp phê duyệt',
    nguoi_phe_duyet STRING COMMENT 'Người phê duyệt',
    y_kien_phe_duyet STRING COMMENT 'Ý kiến phê duyệt',
    so_tien decimal(38,0) COMMENT 'Số tiền liên quan giao dịch liên kết theo',
    ngay_phe_duyet STRING COMMENT 'Ngày phê duyệt',
    mo_ta STRING COMMENT 'Mô tả giao dịch liên kết',
    loai_giao_dich STRING COMMENT 'Loại giao dịch liên kết theo',
    luong_them bigint COMMENT 'Phụ luồng/luồng bổ sung nếu có'
) CLUSTER BY AUTO;
ALTER TABLE sat_link_giao_dich_link ALTER COLUMN link_giao_dich_link_hashkey SET NOT NULL;
ALTER TABLE sat_link_giao_dich_link ADD CONSTRAINT sat_link_giao_dich_link_pk PRIMARY KEY (link_giao_dich_link_hashkey);

CREATE OR REPLACE TABLE sat_giao_dich_tdcn_thong_tin_chung (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id bigint COMMENT 'ID bản ghi',
    xep_hang_tin_dung STRING COMMENT 'Xếp hạng tín dụng',
    tt_ngoai_le STRING COMMENT 'Thông tin ngoại lệ',
    hinh_thuc_bd bigint COMMENT 'Hình thức bảo đảm',
    luong_xu_ly bigint COMMENT 'Luồng xử lý tín dụng',
    luong_soan_thao bigint COMMENT 'Luồng soạn thảo',
    luong_phe_duyet bigint COMMENT 'Luồng phê duyệt',
    is_thay_doi_tt bigint COMMENT 'Kiểm tra tờ trình có thay đổi hay không',
    ngay_tao string COMMENT 'Ngày tạo giao dịch',
    nguoi_tao STRING COMMENT 'Người tạo giao dịch',
    so_cap_duyet STRING COMMENT 'Số cấp phê duyệt',
    vi_tri_buoc_giao_dich bigint COMMENT 'Vị trí bước giao dịch',
    rating_id STRING COMMENT 'Mã định danh xếp hạng tín dụng',
    noi_cu_tru STRING COMMENT 'Nơi cư trú - được ghi dưới dạng mã định danh để tham chiếu',
    is_dong_vay bigint COMMENT 'Khách hàng có người đồng vay hay không',
    tong_thu_nhap_tra_no decimal(38,10) COMMENT 'Tổng thu nhập trả nợ',
    no_thang_dau decimal(38,10) COMMENT 'Nợ tháng đầu',
    no_hien_co decimal(38,10) COMMENT 'Nợ hiện có',
    no_tai_tctd_khac decimal(38,10) COMMENT 'Nợ tại tổ chức tín dụng khác',
    dti decimal(38,10) COMMENT 'Tỷ lệ nợ trên thu nhập',
    so_tuoi string COMMENT 'Số tuổi',
    dieu_kien_sp_id bigint COMMENT 'Mã định danh điều kiện sản phẩm',
    ly_do STRING COMMENT 'Lý do',
    trang_thai_tdtt bigint COMMENT 'Trạng thái thẩm định trực tiếp',
    thoi_diem_tdtt string COMMENT 'Thời điểm thẩm định trực tiếp',
    kctd_ngoai_le_cho_vay bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Quy chế cho vay/Quy chế bảo lãnh/Quy chế bảo đảm/Quy chế khác',
    kctd_ngoai_le_tin_dung bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Quy định tín dụng',
    kctd_ngoai_le_xep_hang_kh bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Chính sách tín dụng theo xếp hạng khách hàng',
    kctd_ngoai_le_sp_tin_dung bigint COMMENT 'Khoản cấp tín dụng có ngoại lệ về Sản phẩm tín dụng',
    kctd_trinh_ybtd bigint COMMENT 'Khoản tín dụng thuộc trường hợp phải trình Ủy ban tín dụng theo khoản 2, điều 4, Quyết định 433B/2019/QĐ-TGĐ',
    tsbd_phai_duoc_ubtd_pd bigint COMMENT 'Tài sản thuộc Hội đồng tín dụng phê duyệt',
    thanh_vien_pos bigint COMMENT 'Ngưỡng sử dụng',
    thanh_vien_ubtd STRING COMMENT 'Thành viên Hội đồng tín dụng',
    muc_dich_xhtd STRING COMMENT 'Mục đích xếp hạng tín dụng',
    is_dong_vay_nhphoi bigint COMMENT 'Người đồng vay/ người hôn phối',
    soan_thao_hs bigint COMMENT 'Soạn thảo hồ sơ',
    xu_ly_hs bigint COMMENT 'Xử lý hồ sơ',
    is_phap_che bigint COMMENT 'Pháp chế',
    loai_gd bigint COMMENT 'Loại giao dịch',
    dvi_trien_khai bigint COMMENT 'Đơn vị triển khai',
    kh_adgiam_tat_rb bigint COMMENT 'Khách hàng áp dụng giảm thời gian xử lý của khối Ngân hàng bán lẻ'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_thong_tin_chung ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_thong_tin_chung ADD CONSTRAINT sat_giao_dich_tdcn_thong_tin_chung_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_giao_dich_tdcn_tai_san_bao_dam (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    id bigint COMMENT 'ID bản ghi',
    tsbd_cho_san_pham bigint COMMENT 'Tài sản bảo đảm cho sản phẩm',
    loai_tsbd bigint COMMENT 'Loại Tài sản bảo đảm',
    vi_tri bigint COMMENT 'Vị trí',
    chu_so_huu bigint COMMENT 'Chủ sở hữu',
    phan_loai_tsbd bigint COMMENT 'Phân loại tài sản bảo đảm',
    ty_le_dam_bao_cao_nhat decimal(38,10) COMMENT 'Tỷ lệ bảo đảm cao nhất',
    ngay_tao string COMMENT 'Ngày tạo giao dịch',
    so_luong bigint COMMENT 'Số lượng',
    luong_them bigint COMMENT '1. Phê duyệt, 539. Soạn Thảo, 540. Xử lý'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_tai_san_bao_dam ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_tai_san_bao_dam ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_tai_san_bao_dam ADD CONSTRAINT sat_giao_dich_tdcn_tai_san_bao_dam_pk PRIMARY KEY (giao_dich_hashkey, ma_key);

CREATE OR REPLACE TABLE sat_giao_dich_tdcn_xl_gdtd (
    giao_dich_hashkey STRING COMMENT 'Hash key tham chiếu hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    id bigint COMMENT 'ID bản ghi',
    nghiep_vu_chi_tiet bigint COMMENT 'Nghiệp vụ chi tiết',
    muc_bao_dam bigint COMMENT 'Mức bảo đảm',
    so_luong bigint COMMENT 'Số lượng',
    nguoi_de_nghi STRING COMMENT 'Người đề nghi',
    nguoi_de_nghi_chon bigint COMMENT 'Người đề nghị chọn',
    nguoi_pd STRING COMMENT 'Người phê duyệt',
    nguoi_pd_chon bigint COMMENT 'Người phê duyệt chọn',
    ngay_duyet STRING COMMENT 'Ngày phê duyệt',
    ngay_tao STRING COMMENT 'Ngày tạo',
    luong_xl bigint COMMENT 'Luồng xử lý',
    so_cap_duyet bigint COMMENT 'Số cấp duyệt'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdcn_xl_gdtd ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_xl_gdtd ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_giao_dich_tdcn_xl_gdtd ADD CONSTRAINT sat_giao_dich_tdcn_xl_gdtd_pk PRIMARY KEY (giao_dich_hashkey, ma_key);

CREATE OR REPLACE TABLE sat_giao_dich_tdtc_thong_tin_chung (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff STRING COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    xep_hang_tin_dung STRING COMMENT 'Xếp hạng tín dụng',
    tt_ngoai_le STRING COMMENT 'Thông tin ngoại lệ',
    hinh_thuc_bd int COMMENT 'Hình thức bảo đảm',
    luong_xu_ly int COMMENT 'Luồng xử lý',
    luong_soan_thao int COMMENT 'Luồng soạn thảo',
    luong_phe_duyet int COMMENT 'Luồng phê duyệt',
    is_thay_doi_tt int COMMENT 'Kiểm tra tờ trình có thay đổi hay không',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao STRING COMMENT 'Người tạo',
    so_cap_duyet int COMMENT 'Số cấp phê duyệt',
    vi_tri_buoc_giao_dich int COMMENT 'Vị trí bước giao dịch',
    ma_so_thue_dn STRING COMMENT 'Mã số thuế doanh nghiệp',
    is_kh_rb int COMMENT 'Cờ khách hàng thuộc khối Ngân hàng bán lẻ (RB)',
    soan_thao_hs int COMMENT 'Soạn thảo hồ sơ',
    xu_ly_hs int COMMENT 'Xử lý hồ sơ'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdtc_thong_tin_chung ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdtc_thong_tin_chung ADD CONSTRAINT sat_giao_dich_tdtc_thong_tin_chung_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_giao_dich_tdtc_thong_tin_to_trinh (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff STRING COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    id int COMMENT 'ID bản ghi',
    khach_hang_id int COMMENT 'ID khách hàng',
    san_pham_id int COMMENT 'ID sản phẩm',
    hang_kh STRING COMMENT 'Hạng khách hàng',
    quoc_tich STRING COMMENT 'Quốc tịch',
    ho_khau_thuong_tru STRING COMMENT 'Hộ khẩu thường trú',
    noi_o_hien_tai STRING COMMENT 'Nơi ở hiện tại',
    tinh_thanh_hien_tai int COMMENT 'Tỉnh/Thành hiện tại',
    sdt string COMMENT 'Số điện thoại',
    email STRING COMMENT 'Email',
    thu_nhap_bq_thang double COMMENT 'Thu nhập bình quân tháng',
    loai_hinh_dn int COMMENT 'Loại hình doanh nghiệp',
    thoi_gian_dong_thue int COMMENT 'Thời gian đóng thuế',
    dn_nhom_no_hien_tai int COMMENT 'Doanh nghiệp - nhóm nợ hiện tại',
    dn_ls_no_nhom_2_tro_len int COMMENT 'Doanh nghiệp - lịch sử nợ nhóm 2 trở lên',
    cn_nhom_no_hien_tai int COMMENT 'Cá nhân - nhóm nợ hiện tại',
    cn_ls_no_can_chu_y int COMMENT 'Cá nhân - lịch sử nợ cần chú ý',
    cn_ls_no_xau int COMMENT 'Cá nhân - lịch sử nợ xấu',
    can_doi_tra_no double COMMENT 'Cân đối trả nợ',
    tong_rr_hien_tai int COMMENT 'Tổng rủi ro hiện tại',
    so_du_no_hien_tai int COMMENT 'Số dư nợ hiện tại',
    tong_rr_dx double COMMENT 'Tổng rủi ro đề xuất',
    de_xuat_moi double COMMENT 'Đề xuất mới',
    thoi_han_dx_moi int COMMENT 'Thời hạn Đề xuất mới',
    kctd_so_tien double COMMENT 'Khoản cấp tín dụng - số tiền',
    kctd_muc_dich_vay STRING COMMENT 'Khoản cấp tín dụng - mục đích vay',
    kctd_thoi_han_vay int COMMENT 'Khoản cấp tín dụng - thời hạn vay',
    kctd_ls_cho_vay STRING COMMENT 'Khoản cấp tín dụng - lãi suất cho vay',
    kctd_phuong_thuc_tra_no int COMMENT 'Khoản cấp tín dụng - phương thức trả nợ',
    ty_le_tai_tro_toi_da double COMMENT 'Tỷ lệ tài trợ tối đa',
    dk_tk_payroll int COMMENT 'Điều kiện tài khoản Payroll',
    dti double COMMENT 'T nợ trên thu nhập (DTI)',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao STRING COMMENT 'Người tạo',
    ten_doanh_nghiep STRING COMMENT 'Tên doanh nghiệp',
    ma_so_thue_dn STRING COMMENT 'Mã số thuế doanh nghiệp',
    tong_thu_nhap_bq_thang int COMMENT 'Tổng thu nhập bình quân tháng',
    xep_hang_kh string COMMENT 'Xếp hạng khách hàng',
    hinh_thuc_gn int COMMENT 'Hình thức giải ngân',
    do_tuoi_kh double COMMENT 'Độ tuổi khách hàng',
    so_tien_pd double COMMENT 'Số tiền phê duyệt',
    tong_rrtd_pd double COMMENT 'Tổng rủi ro tín dụng phê duyệt',
    xep_hang_dn STRING COMMENT 'Xếp hạng doanh nghiệp',
    tinh_thanh_cong_tac int COMMENT 'Tỉnh/Thành công tác',
    vi_tri_cong_tac int COMMENT 'Vị trí công tác',
    tong_tn_bq_thang_bds double COMMENT 'Tổng thu nhập bình quân tháng (BĐS)',
    dti_khong_tsbd double COMMENT 'DTI không có tài sản bảo đảm',
    nhp_ls_no_can_chu_y int COMMENT 'NHP - lịch sử nợ cần chú ý',
    nhp_ls_no_xau int COMMENT 'NHP - lịch sử nợ xấu',
    nhp_nhom_no_hien_tai int COMMENT 'NHP - nhóm nợ hiện tại',
    rating_id int COMMENT 'Mã định danh xếp hạng tín dụng',
    xhtd_id int COMMENT 'ID xếp hạng tín dụng'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdtc_thong_tin_to_trinh ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdtc_thong_tin_to_trinh ADD CONSTRAINT sat_giao_dich_tdtc_thong_tin_to_trinh_pk PRIMARY KEY (giao_dich_hashkey);

CREATE OR REPLACE TABLE sat_giao_dich_tdtc_nghiep_vu_xl_gdtd (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    id bigint COMMENT 'ID bản ghi',
    nghiep_vu_id bigint COMMENT 'Mã nghiệp vụ',
    nghiep_vu_ct_id bigint COMMENT 'Mã nghiệp vụ chi tiết',
    so_tien_gd decimal(38,0) COMMENT 'Số tiền giao dịch',
    ghi_chu STRING COMMENT 'Ghi chú',
    quy_trinh bigint COMMENT 'Mã quy trình',
    ngay_tao STRING COMMENT 'Ngày tạo',
    nguoi_tao STRING COMMENT 'Người tạo'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tdtc_nghiep_vu_xl_gdtd ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tdtc_nghiep_vu_xl_gdtd ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_giao_dich_tdtc_nghiep_vu_xl_gdtd ADD CONSTRAINT sat_giao_dich_tdtc_nghiep_vu_xl_gdtd_pk PRIMARY KEY (giao_dich_hashkey, ma_key);

CREATE OR REPLACE TABLE sat_giao_dich_tht_nhom_chinh_sach_the (
    giao_dich_hashkey STRING COMMENT 'FK đến hub_giao_dich',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    nhom_chinh_sach_ten STRING COMMENT 'Nhóm chính sách tên',
    ngay_tao STRING COMMENT 'Ngày tạo',
    size_chi_tiet_1 bigint COMMENT 'Kích cỡ chi tiết 1',
    is_the_phu bigint COMMENT 'Có phải thẻ phụ không',
    ma_nhom_chinh_sach STRING COMMENT 'Mã nhóm chính sách',
    giay_to_the_phu STRING COMMENT 'Giấy tờ thẻ phụ',
    ma_chi_tiet_1 STRING COMMENT 'Mã chi tiết 1',
    chi_tiet_1_ten STRING COMMENT 'Chi tiết 1 tên',
    ma_chi_tiet_2 STRING COMMENT 'Mã chi tiết 2',
    chi_tiet_2_ten STRING COMMENT 'Chi tiết 2 tên',
    san_pham_the STRING COMMENT 'Sản phẩm thẻ',
    id_the_chinh bigint COMMENT 'ID thẻ chính'
) CLUSTER BY AUTO;
ALTER TABLE sat_giao_dich_tht_nhom_chinh_sach_the ALTER COLUMN giao_dich_hashkey SET NOT NULL;
ALTER TABLE sat_giao_dich_tht_nhom_chinh_sach_the ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_giao_dich_tht_nhom_chinh_sach_the ADD CONSTRAINT sat_giao_dich_tht_nhom_chinh_sach_the_pk PRIMARY KEY (giao_dich_hashkey, ma_key);

CREATE OR REPLACE TABLE hub_xl_ksgn_chung (
    xl_ksgn_chung_hashkey STRING COMMENT 'Hub Hash key',
    business_key string COMMENT 'Business Key',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_xl_ksgn_chung ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE hub_xl_ksgn_chung ADD CONSTRAINT hub_xl_ksgn_chung_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE sat_xl_ksgn_chung_can_bo_danh_gia (
    xl_ksgn_chung_hashkey STRING COMMENT 'Tham chiếu hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    thoi_gian_nhan_task_moi_nhat STRING COMMENT 'Thời gian nhận task mới nhất',
    cbdvtd_tgian_nhan_task STRING COMMENT 'thời gian nhận nhiệm vụ - cán bộ dịch vụ tín dụng',
    cbtntttm_tgian_nhan_task STRING COMMENT 'thời gian nhận nhiệm vụ - cán bộ tác nghiệp thẻ tại trung tâm thẻ',
    cbgdtd_tgian_nhan_task STRING COMMENT 'Thời gian nhận nhiệm vụ - cán bộ giao dịch tín dụng',
    cbtntttm_id bigint COMMENT 'mã cán bộ nhận tác nghiệp tại trung tâm thẻ',
    ket_qua_phe_duyet bigint COMMENT 'Kết quả phê duyệt',
    nhom_cbxl_tntttm STRING COMMENT 'Nhóm cán bộ xử lý thuộc bộ phận tác nghiệp thẻ tại Trung tâm thẻ',
    st_cap_pd_id bigint COMMENT 'mã soạn thảo cấp phê duyệt',
    cb_phap_che_id bigint COMMENT 'mã cán bộ pháp chế',
    nhom_cbxl_dvtd STRING COMMENT 'Nhóm cán bộ xử lý dịch vụ tín dụng',
    diem_tntttm bigint COMMENT 'Điểm tác nghiệp thẻ tại Trung tâm thẻ',
    diem_gdtd bigint COMMENT 'Điểm giao dịch tín dụng',
    diem_dvtd bigint COMMENT 'Điểm dịch vụ tín dụng',
    nhom_khach_hang bigint COMMENT 'Nhóm khách hàng',
    xu_ly_hs bigint COMMENT 'Xử lý hồ sơ',
    co_giam_tat bigint COMMENT 'Có giảm TAT',
    cbql_hdtd bigint COMMENT 'Cán bộ quản lý hợp đồng tín dụng',
    dong_hdtd_cu bigint COMMENT 'Dòng hợp đồng tín dụng cũ',
    dieu_chinh_hdtd bigint COMMENT 'Điều chỉnh hợp đồng tín dụng',
    can_bo_theo_gioi STRING COMMENT 'Cán bộ theo giới'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ksgn_chung_can_bo_danh_gia ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ksgn_chung_can_bo_danh_gia ADD CONSTRAINT sat_xl_ksgn_chung_can_bo_danh_gia_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE sat_xl_ksgn_chung_quy_trinh_trang_thai (
    xl_ksgn_chung_hashkey STRING COMMENT 'Tham chiếu hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    quy_trinh bigint COMMENT 'Quy trình',
    trang_thai bigint COMMENT 'Trạng thái xử lý',
    trang_thai_phe_duyet bigint COMMENT 'Trạng thái tại thời điểm phê duyệt',
    gd_trangthai bigint COMMENT 'Trạng thái giao dịch',
    loai_soan_thao bigint COMMENT 'Loại soạn thảo',
    loai_cong_viec bigint COMMENT 'Loại công việc',
    ngoai_te bigint COMMENT 'Ngoại tệ',
    dl_toan_ven bigint COMMENT 'dl toàn vẹn',
    chi_tiet_hop_dong STRING COMMENT 'Chi tiết hợp đồng',
    ma_han_muc STRING COMMENT 'Mã hạn mức',
    loai_han_muc decimal(38,0) COMMENT 'Loại hạn mức',
    ma_han_muc_t24 string COMMENT 'Mã hạn mức T24',
    cap_phe_duyet_gan_nhat bigint COMMENT 'Cấp phê duyệt gần nhất',
    luong_quy_trinh bigint COMMENT 'Luồng quy trình',
    so_tien_quy_doi decimal(38,0) COMMENT 'Số tiền quy đổi',
    so_tat_toan bigint COMMENT 'Số tất toán',
    working_account STRING COMMENT 'Tài khoản tác nghiệp',
    cap_do_dang_xly bigint COMMENT 'Cấp độ đang xử lý',
    MA_GIAO_DICH STRING COMMENT 'Mã giao dịch'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ksgn_chung_quy_trinh_trang_thai ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ksgn_chung_quy_trinh_trang_thai ADD CONSTRAINT sat_xl_ksgn_chung_quy_trinh_trang_thai_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE sat_xl_ksgn_chung_ho_so_chung_tu (
    xl_ksgn_chung_hashkey STRING COMMENT 'Tham chiếu hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ky_quy bigint COMMENT 'Ký quỹ',
    so_luong_md bigint COMMENT 'Số lượng MD',
    so_luong_pd bigint COMMENT 'Số lượng PD',
    so_luong_ld bigint COMMENT 'Số lượng LD',
    sl_hs_phai_du bigint COMMENT 'Số lượng hồ sơ phải đủ',
    sl_hs_thuc_te bigint COMMENT 'Số lượng hồ sơ thực tế',
    ref_code STRING COMMENT 'Mã tham chiếu',
    is_phap_che bigint COMMENT 'là pháp chế',
    so_lc STRING COMMENT 'Số LC',
    ngay_phat_hanh_lc string COMMENT 'Ngày phát hành LC',
    so_tf STRING COMMENT 'Số TF',
    hinh_thuc_ky_quy STRING COMMENT 'Hình thức ký quỹ',
    so_tien_ky_quy decimal(38,0) COMMENT 'Số tiền ký quỹ',
    ty_le_ky_quy decimal(38,0) COMMENT 'Tỷ lệ ký quỹ',
    so_md STRING COMMENT 'Số MD',
    so_ld STRING COMMENT 'Số LD',
    ngan_hang_phat_hanh bigint COMMENT 'Ngân hàng phát hành',
    su_co_he_thong bigint COMMENT 'Sự cố hệ thống'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ksgn_chung_ho_so_chung_tu ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ksgn_chung_ho_so_chung_tu ADD CONSTRAINT sat_xl_ksgn_chung_ho_so_chung_tu_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE sat_xl_ksgn_chung_don_vi_khoi_tao_phe_duyet (
    xl_ksgn_chung_hashkey STRING COMMENT 'Tham chiếu hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    gd_chinh_id bigint COMMENT 'ID giao dịch chính',
    pdtd_gd_id bigint COMMENT 'ID giao dịch phê duyệt tín dụng',
    ngay_tao string COMMENT 'Ngày tạo bản ghi',
    nguoi_tao bigint COMMENT 'Người tạo',
    ngay_hoan_thanh string COMMENT 'Ngày hoàn thành',
    nguoi_dang_xu_ly bigint COMMENT 'Người đang xử lý',
    donvi_xuly bigint COMMENT 'Đơn vị xử lý',
    dvkd_id bigint COMMENT 'đơn vị kinh doanh',
    cbdvtd_id bigint COMMENT 'ID cán bộ dịch vụ tín dụng',
    cbgdtd_id bigint COMMENT 'ID cán bộ giao dịch tín dụng',
    ngay_dxuat_bsung_pdnl string COMMENT 'Ngày đề xuất bổ sung phê duyệt ngoại lệ',
    ngay_pdnl_ho_so string COMMENT 'Ngày phê duyệt ngoại lệ hồ sơ',
    ngay_dx_bsung string COMMENT 'Ngày đề xuất bổ sung',
    ho_so_xu_ly_tai STRING COMMENT 'Hồ sơ xử lý tại',
    cap_phe_duyet bigint COMMENT 'Cấp phê duyệt',
    ksh_id bigint COMMENT 'KSH ID',
    cbqhkh_id bigint COMMENT 'ID Cán bộ Quan hệ Khách hàng',
    gdk_id bigint COMMENT 'giao dịchK ID',
    gdkqlrr_id bigint COMMENT 'ID giao dịch Khối Quản lý Rủi ro',
    tdv_id bigint COMMENT 'ID Cán bộ Tín dụng',
    ksvgdtd_id bigint COMMENT 'ID Kiểm soát viên xử lý giao dịch tín dụng',
    ksvtntttm_id bigint COMMENT 'ID Kiểm soát viên tác nghiệp thẻ tại trung tâm thẻ',
    tpxlgdtd_id bigint COMMENT 'ID Trưởng phòng xử lý giao dịch tín dụng',
    cbtntttm_id bigint COMMENT 'ID Cán bộ tác nghiệp thẻ tại trung tâm thẻ',
    bspo_id bigint COMMENT 'ID người dùng duyệt giao dịch loại BSTL',
    gd_goc_id bigint COMMENT 'ID giao dịch gốc',
    refcode_omni STRING COMMENT 'mã tham chiếu OMNI',
    so_cap_duyet bigint COMMENT 'Số cấp duyệt'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ksgn_chung_don_vi_khoi_tao_phe_duyet ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ksgn_chung_don_vi_khoi_tao_phe_duyet ADD CONSTRAINT sat_xl_ksgn_chung_don_vi_khoi_tao_phe_duyet_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE link_xl_ksgn_chung_khach_hang (
    link_xl_ksgn_chung_khach_hang_hashkey STRING COMMENT 'khóa chính link',
    xl_ksgn_chung_hashkey string COMMENT 'FK đến hub_xl_ksgn_chung',
    khach_hang_hashkey string COMMENT 'FK đến hub_khach_hang',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_xl_ksgn_chung_khach_hang ALTER COLUMN link_xl_ksgn_chung_khach_hang_hashkey SET NOT NULL;
ALTER TABLE link_xl_ksgn_chung_khach_hang ADD CONSTRAINT link_xl_ksgn_chung_khach_hang_pk PRIMARY KEY (link_xl_ksgn_chung_khach_hang_hashkey);

CREATE OR REPLACE TABLE sat_xl_ct_han_muc (
    xl_ksgn_chung_hashkey STRING COMMENT 'FK đến hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    han_muc_id decimal(38,0) COMMENT 'Mã hạn mức',
    tong_hmrr decimal(38,0) COMMENT 'Tổng hạn mức rủi ro',
    ngay_tao STRING COMMENT 'Ngày tạo',
    nguoi_tao bigint COMMENT 'Người tạo',
    gia_tri_gd decimal(38,0) COMMENT 'Giá trị giao dịch',
    tong_hmrr_khac decimal(38,0) COMMENT 'Tổng hạn mức rủi ro khác',
    hinh_thuc_cap_td bigint COMMENT 'Hình thức cấp tín dụng',
    loai_ho_so STRING COMMENT 'Loại hồ sơ',
    tong_hmrr_dong decimal(38,0) COMMENT 'Tổng dòng hạn mức rủi ro',
    gia_tri_gd_dong decimal(38,0) COMMENT 'Giá trị dòng giao dịch',
    tong_hmrr_khac_dong decimal(38,0) COMMENT 'Tổng hạn mức rủi ro khác dòng',
    san_pham_id bigint COMMENT 'mã sản phẩm'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ct_han_muc ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ct_han_muc ADD CONSTRAINT sat_xl_ct_han_muc_pk PRIMARY KEY (xl_ksgn_chung_hashkey);

CREATE OR REPLACE TABLE sat_xl_ksgn_ct (
    xl_ksgn_chung_hashkey STRING COMMENT 'FK đến hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    gd_chitiet_id int COMMENT 'ID giao dich chi tiet',
    giaodich_loai int COMMENT 'Loại giao dịch',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao int COMMENT 'Người tạo (ID)',
    nhom_nghiepvu int COMMENT 'Nhóm nghiệp vụ (ID)',
    nghiepvu_ct int COMMENT 'Nghiệp vụ chi tiết (ID)',
    so_tien_gd int COMMENT 'Số tiền giao dịch',
    ghi_chu STRING COMMENT 'Ghi chú',
    so_luong int COMMENT 'Số lượng',
    gtri_giaodich double COMMENT 'Giá trị giao dịch',
    gtri_giaodich_dong bigint COMMENT 'Giá trị giao dịch (đồng)'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ksgn_ct ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ksgn_ct ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_xl_ksgn_ct ADD CONSTRAINT sat_xl_ksgn_ct_pk PRIMARY KEY (xl_ksgn_chung_hashkey, ma_key);

CREATE OR REPLACE TABLE sat_xl_ct_lich_su (
    xl_ksgn_chung_hashkey STRING COMMENT 'FK đến hub_xl_ksgn_chung',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    id int COMMENT 'ID bản ghi',
    trang_thai_hs int COMMENT 'Trạng thái hồ sơ',
    ngay_tao string COMMENT 'Ngày tạo',
    nguoi_tao int COMMENT 'Người tạo (ID)',
    cpd_de_xuat string COMMENT 'Cấp phê duyệt Đề xuất (ID)',
    ykien_chitiet STRING COMMENT 'Ý kiến chi tiết',
    lydo_dongy_id string COMMENT 'Lý do đồng ý (ID)',
    lydo_dongy_ct string COMMENT 'Lý do đồng ý (chi tiết)',
    lydo_khong_id string COMMENT 'Lý do không đồng ý (ID)',
    lydo_khong_ct string COMMENT 'Lý do không đồng ý (chi tiết)',
    task_id int COMMENT 'ID tác vụ',
    team_id int COMMENT 'ID nhóm/đội',
    trang_thai_bat_dau int COMMENT 'Trạng thái bắt đầu',
    trang_thai_ket_thuc int COMMENT 'Trạng thái kết thúc',
    ket_qua_xu_ly_user int COMMENT 'Kết quả xử lý (user)',
    ten_tac_vu STRING COMMENT 'Tên tác vụ',
    thoi_diem_ket_thuc string COMMENT 'Thời điểm kết thúc',
    thoi_diem_bat_dau string COMMENT 'Thời điểm bắt đầu',
    so_lan_ycbs int COMMENT 'Số lần yêu cầu bổ sung',
    role_nhan_task int COMMENT 'Role nhận task (ID)',
    role_chuyen_task int COMMENT 'Role chuyển task (ID)',
    luong string COMMENT 'Luồng',
    luong_id int COMMENT 'ID luồng',
    tong_tgian_xu_ly int COMMENT 'Tổng thời gian xử lý'
) CLUSTER BY AUTO;
ALTER TABLE sat_xl_ct_lich_su ALTER COLUMN xl_ksgn_chung_hashkey SET NOT NULL;
ALTER TABLE sat_xl_ct_lich_su ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_xl_ct_lich_su ADD CONSTRAINT sat_xl_ct_lich_su_pk PRIMARY KEY (xl_ksgn_chung_hashkey, ma_key);

CREATE OR REPLACE TABLE hub_tsbd_giaodich_chinh (
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'Hub Hashkey',
    business_key STRING COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_tsbd_giaodich_chinh ALTER COLUMN tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE hub_tsbd_giaodich_chinh ADD CONSTRAINT hub_tsbd_giaodich_chinh_pk PRIMARY KEY (tsbd_giaodich_chinh_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_giaodich_chinh_thong_tin_chung (
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'FK đến hub_tsbd_giaodich_chinh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    kh_han_che bigint COMMENT 'Khách hàng hạn chế',
    loai_giao_dich bigint COMMENT 'Loại giao dịch',
    muc_dich_vay bigint COMMENT 'Mục đích vay',
    ngay_tao string COMMENT 'Ngày tạo',
    gd_pdtd_tham_chieu_id bigint COMMENT 'ID giao dịch PDTD tham chiếu',
    ma_gd_pdtd_tham_chieu STRING COMMENT 'Mã giao dịch PDTD tham chiếu',
    tai_san_id bigint COMMENT 'ID tài sản',
    nguoi_tao bigint COMMENT 'Người tạo',
    trang_thai bigint COMMENT 'Trạng thái',
    giao_dich_goc string COMMENT 'Giao dịch gốc',
    trang_thai_phe_duyet bigint COMMENT 'Trạng thái phê duyệt',
    nhom_san_pham_id bigint COMMENT 'ID nhóm sản phẩm',
    deactive bigint COMMENT 'hủy kích hoạt',
    diem_phan_cong double COMMENT 'điểm phân cấp',
    dvkd_khoi_tao bigint COMMENT 'đơn vị kinh doanh khởi tạo',
    can_bo_phe_duyet bigint COMMENT 'Cán bộ phê duyệt',
    can_bo_dang_xly bigint COMMENT 'Cán bộ đang xử lý',
    dvkd_dang_xly bigint COMMENT 'Đơn vị kinh doanh đang xử lý',
    quy_trinh bigint COMMENT 'Quy trình',
    ly_do_dexuat STRING COMMENT 'Lý do đề xuất',
    process_id bigint COMMENT 'ID Process',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    nguoi_cap_nhat bigint COMMENT 'Người cập nhật',
    ngay_chuyen_task_cbkt string COMMENT 'Ngày chuyển task',
    bspo_id bigint COMMENT 'ID BSPO',
    luong_xu_ly bigint COMMENT 'Luồng xử lý',
    muc_dich_tham_dinh_id bigint COMMENT 'ID mục đích thẩm định',
    ngay_de_xuat_pqlts_td string COMMENT 'Ngày đề xuất phòng quản lý tài sản tín dụng',
    ngay_bat_dau_pqlts_td string COMMENT 'Ngày bắt đầu quản lý tài sản tín dụng',
    gio_bat_dau_pqlts_td STRING COMMENT 'Giờ bắt đầu quản lý tài sản tín dụng',
    phut_bat_dau_pqlts_td STRING COMMENT 'Phút bắt đầu quản lý tài sản tín dụng',
    muc_dich_tham_dinh_khac_ten STRING COMMENT 'Mục đích thẩm định khác tên',
    ngay_bat_dau_pqlts_td_string STRING COMMENT 'Ngày bắt đầu quản lý tài sản tín dụng String',
    ngay_hoan_thanh_pqlts_td string COMMENT 'Ngày hoàn thành quản lý tài sản tín dụng',
    nhom_kh_uu_tien bigint COMMENT 'Nhóm khách hàng ưu tiên',
    sdt_nguoi_hd_khao_sat STRING COMMENT 'số điện thoại người hướng dẫn khảo sát',
    so_bien_ban_dinh_gia STRING COMMENT 'Số biên bản định giá',
    tai_san_du_dk_thamdinh bigint COMMENT 'Tài sản đủ điều kiện thẩm định',
    tai_san_tdtt bigint COMMENT 'Tài sản thẩm định',
    ts_cung_db_dvkd bigint COMMENT 'tài sản đảm bảo đơn vị kinh doanh',
    ts_moi bigint COMMENT 'Tài sản mới'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_chung ALTER COLUMN tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_chung ADD CONSTRAINT sat_tsbd_giaodich_chinh_thong_tin_chung_pk PRIMARY KEY (tsbd_giaodich_chinh_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_giaodich_chinh_thong_tin_dinh_gia (
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'FK đến hub_tsbd_giaodich_chinh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    hoan_thanh bigint COMMENT 'Hoàn thành',
    id_tinh_diem_pc_ktkqdg bigint COMMENT 'Mã tính điểm',
    is_xn_tgks_tdtt string COMMENT 'Đã xác nhận',
    json_link_tai_lieu string COMMENT 'jSON link tài liệu',
    loai_dvdg bigint COMMENT 'Đơn vị định giá',
    dvdg_ben_3_id bigint COMMENT 'ID Đơn vị định giá thứ 3',
    dvdg_khac bigint COMMENT 'Đơn vị định giá khác',
    dvdg_khac_ten STRING COMMENT 'Tên đơn vị định giá khác',
    gia_tri_dg decimal(38,10) COMMENT 'Giá trị định giá',
    ngay_hoan_tat_dg string COMMENT 'Ngày hoàn tất định giá',
    don_gia_dat_dg decimal(38,10) COMMENT 'Đơn giá đặt định giá',
    dinh_gia_moi bigint COMMENT 'Định giá mới',
    ten_nguoi_hd_khao_sat STRING COMMENT 'tên người hướng dẫn khảo sát',
    yeu_cau_ben_3_dg bigint COMMENT 'Yêu cầu bên 3 định giá',
    yeu_cau_cap_phe_duyet bigint COMMENT 'Yêu cầu cấp phê duyệt',
    don_gia_dg_id bigint COMMENT 'ID đơn giá định giá',
    y_kien_dvkd bigint COMMENT 'Ý kiến đơn vị kinh doanh',
    y_kien_phe_duyet bigint COMMENT 'Ý kiến phê duyệt',
    dvdg_ben_3_de_xuat_id bigint COMMENT 'ID đề xuất đơn vị định giá bên 3',
    dvdg_de_xuat_khac bigint COMMENT 'Đơn vị định giá đề xuất khác',
    dvdg_de_xuat_khac_ten STRING COMMENT 'Tên đơn vị định giá đề xuất khác',
    ket_qua_danh_gia bigint COMMENT 'Kết quả đánh giá',
    nguyen_tac_tinh_diem_pc bigint COMMENT 'Nguyên tắc tính điểm PC',
    tong_hmrr_kh_dexuat decimal(38,10) COMMENT 'Tổng hạn mức rủi ro khách hàng đề xuất'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_dinh_gia ALTER COLUMN tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_chinh_thong_tin_dinh_gia ADD CONSTRAINT sat_tsbd_giaodich_chinh_thong_tin_dinh_gia_pk PRIMARY KEY (tsbd_giaodich_chinh_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_giaodich_chinh_khoi_tao_phe_duyet (
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'FK đến hub_tsbd_giaodich_chinh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    yeu_cau_hoi_so bigint COMMENT 'Yêu cầu hội sở',
    tdv bigint COMMENT 'Trưởng đơn vị',
    cb_pqltsdb bigint COMMENT 'Cán bộ phòng quản lý tài sản đảm bảo',
    tbp_pqltsdb bigint COMMENT 'Trưởng bộ phận phòng quản lý tài sản đảm bảo',
    tp_pqltsdb bigint COMMENT 'Trưởng phòng quản lý tài sản đảm bảo',
    cb_kiem_tra_kqdg bigint COMMENT 'Cán bộ kiểm tra kết quả định giá',
    rm2 bigint COMMENT 'Mã nhân viên quản lý',
    tbp_ktkqdg bigint COMMENT 'Trưởng bộ phận kiểm tra kết quả định giá',
    nhom_dang_xu_ly STRING COMMENT 'Nhóm đang xử lý',
    cb_baogia bigint COMMENT 'Cán bộ báo giá',
    cpd_baogia bigint COMMENT 'Cấp phê duyệt báo giá',
    cpd1_ten_dn STRING COMMENT 'Cấp phê duyệt tên doanh nghiệp 1',
    cpd2_ten_dn STRING COMMENT 'Cấp phê duyệt tên doanh nghiệp 2'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_giaodich_chinh_khoi_tao_phe_duyet ALTER COLUMN tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_chinh_khoi_tao_phe_duyet ADD CONSTRAINT sat_tsbd_giaodich_chinh_khoi_tao_phe_duyet_pk PRIMARY KEY (tsbd_giaodich_chinh_hashkey);

CREATE OR REPLACE TABLE link_tsbd_giaodich_chinh_khach_hang (
    link_tsbd_giaodich_chinh_khach_hang_hashkey STRING COMMENT 'Khóa chính Link',
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'FK đến hub_tsbd_giaodich_chinh',
    khach_hang_hashkey STRING COMMENT 'FK đến hub_khach_hang',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE link_tsbd_giaodich_chinh_khach_hang ALTER COLUMN link_tsbd_giaodich_chinh_khach_hang_hashkey SET NOT NULL;
ALTER TABLE link_tsbd_giaodich_chinh_khach_hang ADD CONSTRAINT link_tsbd_giaodich_chinh_khach_hang_pk PRIMARY KEY (link_tsbd_giaodich_chinh_khach_hang_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_giaodich_lich_su_v2 (
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'FK den hub_tsbd_giaodich_chinh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    id int COMMENT 'ID ban ghi',
    gd_tsbd_id int COMMENT 'ID giao dich TSBD',
    user_thuc_hien int COMMENT 'Nguoi dung thuc hien',
    username_thuc_hien STRING COMMENT 'Ten nguoi dung thuc hien',
    role_thuc_hien STRING COMMENT 'Vai tro thuc hien',
    user_chuyen_toi int COMMENT 'Nguoi dung chuyen toi',
    username_chuyen_toi STRING COMMENT 'Ten nguoi dung chuyen toi',
    role_chuyen_toi STRING COMMENT 'Vai tro chuyen toi',
    ngay_nhan_task STRING COMMENT 'Ngay nhan task',
    task_id int COMMENT 'Ma nhiem vu',
    thao_tac_id int COMMENT 'Ma thao tac',
    trang_thai_ket_thuc int COMMENT 'Trang thai ket thuc',
    trang_thai_bat_dau int COMMENT 'Trang thai bat dau',
    ngay_bat_dau STRING COMMENT 'Ngay bat dau',
    ngay_ket_thuc STRING COMMENT 'Ngay ket thuc',
    bo_sung_tdv int COMMENT 'Bo sung TDV',
    bo_sung_cbpqltsbd int COMMENT 'Bo sung Can bo quan ly tai san bao dam',
    bo_sung_tbppqltsbd int COMMENT 'Bo sung TBPPQLTSBD',
    bo_sung_y_kien_tdv int COMMENT 'Bo sung y kien TDV',
    bo_sung_y_kien_cbktkqdg int COMMENT 'Bo sung y kien CBKTKQDG',
    ma_luong_dvdg int COMMENT 'Ma luong don vi dinh gia',
    ten_luong_dvdg STRING COMMENT 'Ten luong don vi dinh gia',
    chu_thich STRING COMMENT 'Chu thich',
    trang_thai int COMMENT 'Trang thai',
    nguoi_tao int COMMENT 'Nguoi tao',
    ngay_tao STRING COMMENT 'Ngay tao',
    thoi_gian_thuc_hien int COMMENT 'Thoi gian thuc hien'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_giaodich_lich_su_v2 ALTER COLUMN tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_lich_su_v2 ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_lich_su_v2 ADD CONSTRAINT sat_tsbd_giaodich_lich_su_v2_pk PRIMARY KEY (tsbd_giaodich_chinh_hashkey, ma_key);

CREATE OR REPLACE TABLE sat_tsbd_giaodich_chi_tiet (
    tsbd_giaodich_chinh_hashkey STRING COMMENT 'Tham chiếu hub_tsbd_giaodich_chinh',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ma_key string COMMENT 'Multi active child key',
    ngay_bat_dau_totrinh STRING COMMENT 'Ngày bắt đầu tờ trình',
    ngay_ket_thuc_totrinh STRING COMMENT 'Ngày kết thúc tờ trình',
    cb_lap STRING COMMENT 'Cán bộ lập tờ trình',
    loai_dvdg bigint COMMENT 'Loại đơn vị thực hiện định giá',
    y_kien_id STRING COMMENT 'ID bản ghi ý kiến',
    ngay_tao STRING COMMENT 'ngày tạo',
    trang_thai_to_trinh bigint COMMENT 'Trạng thái tờ trình',
    ngay_bat_dau_totrinh_kiemtra STRING COMMENT 'Ngày bắt đầu kiểm tra tờ trình',
    ngay_ket_thuc_totrinh_kiemtra STRING COMMENT 'Ngày kết thúc kiểm tra tờ trình',
    cb_kiemtra STRING COMMENT 'Cán bộ kiểm tra',
    trang_thai_to_trinh_kiem_tra bigint COMMENT 'Trạng thái tờ trình ở bước kiểm tra',
    diem_vitri_1 bigint COMMENT 'Điểm vị trí 1',
    diem_vitri_2 bigint COMMENT 'Điểm vị trí 2',
    diem_vitri_3 bigint COMMENT 'Điểm vị trí 3',
    diem_vitri_4 bigint COMMENT 'Điểm vị trí 4',
    diem_vitri_5 bigint COMMENT 'Điểm vị trí 5',
    diem_vitri_6 bigint COMMENT 'Điểm vị trí 6',
    user_vitri_1 STRING COMMENT 'vị trí người dùng 1',
    user_vitri_2 STRING COMMENT 'vị trí người dùng 2',
    user_vitri_3 STRING COMMENT 'vị trí người dùng 3',
    user_vitri_4 STRING COMMENT 'vị trí người dùng 4',
    user_vitri_5 STRING COMMENT 'vị trí người dùng 5',
    user_vitri_6 STRING COMMENT 'vị trí người dùng 6',
    khu_vuc_nv_id bigint COMMENT 'ID khu vực nhân viên xử lý',
    khoang_cach_dia_ban bigint COMMENT 'Khoảng cách địa bàn định giá',
    he_so_dia_ban bigint COMMENT 'Hệ số địa bàn áp dụng theo quy định nội bộ',
    sla_tructiep bigint COMMENT 'SLA xử lý đối với trường hợp thẩm định trực tiếp',
    sla_giantiep bigint COMMENT 'SLA xử lý đối với trường hợp thẩm định/khảo sát gián tiếp',
    thoi_gian_cbktkqdg bigint COMMENT 'Thời gian cán bộ kiểm tra kết quả định giá',
    thoi_gian_tbpktkqdg bigint COMMENT 'Thời gian thông báo/phản hồi kiểm tra kết quả định giá của bộ phận kiểm tra',
    thoi_gian_cbpqltsbd bigint COMMENT 'Thời gian cán bộ quản lý tài sản bảo đảm xử lý liên quan hồ sơ',
    thoi_gian_tbppqltsbd bigint COMMENT 'Thời gian thông báo của bộ phận quản lý tài sản bảo đảm',
    ly_do STRING COMMENT 'Lý do',
    thoi_gian_di_chuyen bigint COMMENT 'Thời gian di chuyển',
    thoi_gian_khao_sat bigint COMMENT 'thời gian khảo sát',
    tong_thoi_gian_khao_sat decimal(38,0) COMMENT 'Tổng thời gian khảo sát'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_giaodich_chi_tiet ALTER COLUMN tsbd_giaodich_chinh_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_chi_tiet ALTER COLUMN ma_key SET NOT NULL;
ALTER TABLE sat_tsbd_giaodich_chi_tiet ADD CONSTRAINT sat_tsbd_giaodich_chi_tiet_pk PRIMARY KEY (tsbd_giaodich_chinh_hashkey, ma_key);

CREATE OR REPLACE TABLE ref_bpm_auth_nhom (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    TEN_NHOM_VIET_TAT string COMMENT 'Tên nhóm viết tắt',
    TEN_NHOM_DAY_DU string COMMENT 'Tên nhóm đầy đủ',
    TRANG_THAI bigint COMMENT 'Trạng thái',
    GHI_CHU string COMMENT 'Ghi chú',
    OCB_HRM_ID bigint COMMENT 'Mã nhân sự trên hệ thống OCB HRM',
    NHOM_CAP_TREN bigint COMMENT 'Nhóm cấp trên',
    SEARCH_SCOPE bigint COMMENT 'Phạm vi tìm kiếm',
    NHOM_DAI_DIEN bigint COMMENT 'Nhóm đại diện',
    CAP_PHE_DUYET bigint COMMENT 'Cấp phê duyệt',
    QUY_TRINH bigint COMMENT 'Quy trình nghiệp vụ',
    CAP_DO bigint COMMENT 'Cấp độ',
    CAP_DO_TIM_KIEM bigint COMMENT 'Cấp độ tìm kiếm',
    CAP_DO_ECM bigint COMMENT 'Cấp độ ECM',
    CAP_DO_ECM_XLGDTD bigint COMMENT 'Cấp độ ECM cho xử lý giao dịch tín dụng',
    CAP_DO_ECM_TSBD bigint COMMENT 'Cấp độ ECM cho tài sản bảo đảm',
    JSON_ECM string COMMENT 'Dữ liệu ECM dạng JSON',
    MA_NHOM_TEN string COMMENT 'Mã nhóm ghép tên',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_bpm_auth_nhom ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_bpm_auth_nhom ADD CONSTRAINT ref_bpm_auth_nhom_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_bpm_c_danh_muc (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    TEN_DANH_MUC string COMMENT 'Tên danh mục',
    GHI_CHU string COMMENT 'Ghi chú',
    PARENT_ID bigint COMMENT 'Mã bản ghi cha',
    TRANG_THAI bigint COMMENT 'Trạng thái',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_bpm_c_danh_muc ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_bpm_c_danh_muc ADD CONSTRAINT ref_bpm_c_danh_muc_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_bpm_danh_muc (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    GHI_CHU string COMMENT 'Ghi chú',
    STT bigint COMMENT 'Số thứ tự',
    TRANG_THAI bigint COMMENT 'Trạng thái',
    NGUOI_TAO bigint COMMENT 'Người tạo bản ghi',
    NGAY_TAO string COMMENT 'Ngày tạo',
    NGUOI_UPDATE bigint COMMENT 'Người cập nhật bản ghi',
    NGAY_UPDATE string COMMENT 'Ngày cập nhật',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_bpm_danh_muc ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_bpm_danh_muc ADD CONSTRAINT ref_bpm_danh_muc_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE ref_bpm_sk10_san_pham (
    Ref_hashkey string COMMENT 'Reference hash key',
    Ref_type string COMMENT 'Reference type',
    Ref_code string COMMENT 'Reference code',
    Ref_description string COMMENT 'Reference description',
    TEN_SAN_PHAM string COMMENT 'Tên sản phẩm',
    PHAN_NHOM_SAN_PHAM string COMMENT 'Phân nhóm sản phẩm',
    PARENT_GROUP string COMMENT 'Nhóm cha',
    HIEU_LUC_SP string COMMENT 'Hiệu lực của sản phẩm',
    GHI_CHU string COMMENT 'Ghi chú',
    CATEGORY_T24 string COMMENT 'Mã category tương ứng bên T24',
    LOAN_SUPPORT_T24 string COMMENT 'Cờ hỗ trợ khoản vay bên T24',
    DIEU_KIEN_T24 string COMMENT 'Điều kiện áp dụng bên T24',
    NGAY_TAO string COMMENT 'Ngày tạo bản ghi',
    hashdiff_full string COMMENT 'Trường kỹ thuật: hashdiff toàn bản ghi (so sánh thay đổi).',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    Record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE ref_bpm_sk10_san_pham ALTER COLUMN Ref_hashkey SET NOT NULL;
ALTER TABLE ref_bpm_sk10_san_pham ADD CONSTRAINT ref_bpm_sk10_san_pham_pk PRIMARY KEY (Ref_hashkey);

CREATE OR REPLACE TABLE hub_tsbd_tai_san (
    tsbd_tai_san_hashkey STRING COMMENT 'Hub hashkey',
    business_key STRING COMMENT 'Khóa nghiệp vụ',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.'
) CLUSTER BY AUTO;
ALTER TABLE hub_tsbd_tai_san ALTER COLUMN tsbd_tai_san_hashkey SET NOT NULL;
ALTER TABLE hub_tsbd_tai_san ADD CONSTRAINT hub_tsbd_tai_san_pk PRIMARY KEY (tsbd_tai_san_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_tai_san_thong_tin_chung (
    tsbd_tai_san_hashkey STRING COMMENT 'FK đến hub_tsbd_tai_san',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    loai_tai_san bigint COMMENT 'Loại Tài sản bảo đảm',
    ten_tai_san STRING COMMENT 'Tên tài sản',
    tinh_tp_id bigint COMMENT 'Mã tỉnh thành phố',
    quan_huyen_id bigint COMMENT 'Mã quận huyện',
    mo_ta STRING COMMENT 'Mô tả',
    dia_chi STRING COMMENT 'Địa chỉ',
    trang_thai bigint COMMENT 'Trạng thái',
    ngay_tao string COMMENT 'Ngày tạo',
    nhom_tai_san_id bigint COMMENT 'Nhóm tài sản',
    loai_tai_san_id bigint COMMENT 'ID của loại tài sản',
    ctiet_tai_san_id bigint COMMENT 'ID chi tiết tài sản',
    nguon_tao bigint COMMENT 'Nguồn tạo',
    nguoi_cap_nhat bigint COMMENT 'Người cập nhật',
    ngay_cap_nhat string COMMENT 'Ngày cập nhật',
    phuong_xa_id bigint COMMENT 'ID Phường xã của tài sản',
    nguoi_tao bigint COMMENT 'Người tạo',
    nguoi_xu_ly bigint COMMENT 'Người xử lý',
    ngay_chuyen_xu_ly string COMMENT 'Ngày chuyên xử lý',
    tai_san_goc bigint COMMENT 'Tài sản gốc',
    ma_ts_t24 STRING COMMENT 'Mã tài sản trên hệ thống T24',
    dvkd_tao bigint COMMENT 'Đơn vị kinh doanh tạo mã tài sản'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_tai_san_thong_tin_chung ALTER COLUMN tsbd_tai_san_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_tai_san_thong_tin_chung ADD CONSTRAINT sat_tsbd_tai_san_thong_tin_chung_pk PRIMARY KEY (tsbd_tai_san_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_tai_san_phuong_tien (
    tsbd_tai_san_hashkey STRING COMMENT 'FK đến hub_tsbd_tai_san',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    ptvt_loaiphuongtien_id bigint COMMENT 'ID của loại phương tiện vận tải',
    ptvt_hangxs STRING COMMENT 'Hãng sản xuất của phương tiện vận tải',
    ptvt_bienks STRING COMMENT 'Biển kiểm soát của phương tiện vận tải',
    ptvt_congnang STRING COMMENT 'Công năng của phương tiện vận tải',
    ptvt_tentau STRING COMMENT 'Tên tàu của phương tiện vận tải',
    ptvt_sodky STRING COMMENT 'Số đăng ký của phương tiện vận tải',
    ptvt_taitrong STRING COMMENT 'Tải trọng của phương tiện vận tải',
    dong_xe bigint COMMENT 'Dòng xe'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_tai_san_phuong_tien ALTER COLUMN tsbd_tai_san_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_tai_san_phuong_tien ADD CONSTRAINT sat_tsbd_tai_san_phuong_tien_pk PRIMARY KEY (tsbd_tai_san_hashkey);

CREATE OR REPLACE TABLE sat_tsbd_tai_san_thong_tin_khac (
    tsbd_tai_san_hashkey STRING COMMENT 'FK đến hub_tsbd_tai_san',
    hashdiff string COMMENT 'Trường kỹ thuật: Phục vụ cơ chế SCD Type 2 trong Satellite.',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    tai_san_id bigint COMMENT 'Mã tài sản',
    vongop_mack STRING COMMENT 'Mã chứng khoán vốn góp',
    vongop_tochucnhan STRING COMMENT 'Tổ chức nhận vốn góp',
    hanghoa_tenquycach STRING COMMENT 'Tên quy cách hàng hóa',
    tskhac_tt_taisan STRING COMMENT 'Tài sản khác',
    tskhac_ghichu STRING COMMENT 'Ghi chú của Tài sản khác',
    bds_can_cu_dg bigint COMMENT 'Căn cứ định giá',
    bds_ma_can_ho STRING COMMENT 'Mã căn hộ của bất động sản',
    bds_ngay_cap_cn string COMMENT 'Ngày cấp giấy chứng nhận cua bất động sản',
    so_giay_cn STRING COMMENT 'Số giấy chứng nhận',
    giayto_to_chuc STRING COMMENT 'Giấy tờ tổ chức',
    giayto_menh_gia decimal(38,10) COMMENT 'Mệnh giá của giấy tờ có giá',
    giayto_ky_han STRING COMMENT 'Kỳ hạn của giấy tờ có giá',
    quyenphatsinh_ten STRING COMMENT 'Tên của quyền phát sinh',
    quyenphatsinh_sohopdong STRING COMMENT 'Số hợp đồng của quyền phát sinh'
) CLUSTER BY AUTO;
ALTER TABLE sat_tsbd_tai_san_thong_tin_khac ALTER COLUMN tsbd_tai_san_hashkey SET NOT NULL;
ALTER TABLE sat_tsbd_tai_san_thong_tin_khac ADD CONSTRAINT sat_tsbd_tai_san_thong_tin_khac_pk PRIMARY KEY (tsbd_tai_san_hashkey);

CREATE OR REPLACE TABLE effsat_link_giao_dich_link (
    link_giao_dich_link_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
        active_flag int COMMENT 'Technical field: 1 = active, 0 = inactive.'
    ) CLUSTER BY AUTO;
ALTER TABLE effsat_link_giao_dich_link ALTER COLUMN link_giao_dich_link_hashkey SET NOT NULL;
ALTER TABLE effsat_link_giao_dich_link ADD CONSTRAINT effsat_link_giao_dich_link_pk PRIMARY KEY (link_giao_dich_link_hashkey);

CREATE OR REPLACE TABLE effsat_link_xl_ksgn_chung_khach_hang (
    link_xl_ksgn_chung_khach_hang_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT 'Cờ trạng thái hiệu lực (1 = đang hoạt động, 0 = hết hiệu lực)'
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_xl_ksgn_chung_khach_hang ALTER COLUMN link_xl_ksgn_chung_khach_hang_hashkey SET NOT NULL;
ALTER TABLE effsat_link_xl_ksgn_chung_khach_hang ADD CONSTRAINT effsat_link_xl_ksgn_chung_khach_hang_pk PRIMARY KEY (link_xl_ksgn_chung_khach_hang_hashkey);

CREATE OR REPLACE TABLE effsat_link_xl_pdtd_link (
    link_xl_pdtd_link_hashkey string COMMENT 'Link HK',
    source_event_date date COMMENT 'Trường kỹ thuật: Ngày sự kiện thay đổi có hiệu lực từ hệ thống nguồn.',
    load_timestamp timestamp COMMENT 'Trường kỹ thuật: Thời điểm bản ghi được nạp vào hệ thống nguồn.',
    record_source string COMMENT 'Trường kỹ thuật: Nguồn gốc của bản ghi dùng để xác định bảng nguồn dữ liệu.',
    active_flag int COMMENT ''
) CLUSTER BY AUTO;
ALTER TABLE effsat_link_xl_pdtd_link ALTER COLUMN link_xl_pdtd_link_hashkey SET NOT NULL;
ALTER TABLE effsat_link_xl_pdtd_link ADD CONSTRAINT effsat_link_xl_pdtd_link_pk PRIMARY KEY (link_xl_pdtd_link_hashkey);

-- ============================================================
-- CROSS SOURCE CALENDAR VIEW
-- ============================================================

CREATE OR REPLACE VIEW t24_cal_calendar AS
SELECT
    CAST(NULL AS STRING) AS msr_prd_id,
    CAST(NULL AS DATE)   AS msr_prd_dt,
    CAST(NULL AS INT)    AS bsn_day_f,
    CAST(NULL AS DATE)   AS last_wk_dt
WHERE 1=0;

-- ============================================================
-- STS HUB TABLES
-- ============================================================
